# %%
# importing sys
import sys
# This is how you import modules that exist outside of working directory 
# adding mosaique to the system path
sys.path.insert(1, '/workspaces/QML-QPF/mosaiQue') 
sys.path.insert(1, '/workspaces/QML-QPF/Quantifying_Entanglement')

import mosaique as mq
import scipy
from concurrent.futures import ProcessPoolExecutor, as_completed
import itertools
import numpy as np
import pennylane as qml
import os
from mosaique.models.operation import OperationLayer
from tensorflow import keras
import tensorflow as tf 
import time
from Entropy import compute_entropy_for_pair_batch
# Out:
# 2026-01-31 06:10:56.793513: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-31 06:10:56.837386: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# if the below cell raise this error [ModuleNotFoundError: No module named 'tensorrt']
# uncomment and run the next line, then restart the kernel 
# pip install tensorrt

# %% [markdown]
# ## Check GPU installation is working

# %%
import tensorrt as trt

print(f' tensorflow version {tf.__version__}')

print(f' tensorrt version {trt.__version__}')

print(tf.config.list_physical_devices('GPU'))
# Out:
#  tensorflow version 2.15.0
#  tensorrt version 10.12.0.36
# []

# %%
# Set the environment for asynchronous GPU usage
os.environ['TF_GPU_ALLOCATOR'] = 'cuda_malloc_async'

# %%
def operation():
    dev = qml.device("default.qubit.tf", wires=4)
    @qml.qnode(dev, interface='tf')
    def cnot(inputs):
        inputs = inputs * np.pi
        qml.AngleEmbedding(inputs[:,...], wires=range(4), rotation='Y')

        qml.CNOT(wires=[0, 1])
        qml.CNOT(wires=[2, 3])

        # Measurement producing 4 classical output values
        return [qml.expval(qml.PauliZ(j)) for j in range(4)]
    return cnot

# %%
def preset():
     # load the data tf.keras.datasets.fashion_mnist.load_data()

    fashion_mnist_dataset = keras.datasets.fashion_mnist
    (tr_images, tr_labels), (te_images, te_labels) = fashion_mnist_dataset.load_data()
    
    # name of the folder where will save the filtered images for training
    tr_layer = mq.ConvolutionLayer4x4("_OA_results_FashionMnist_train_with_val")
    # name of the folder where will save the filtered images for testing
    te_layer = mq.ConvolutionLayer4x4("_OA_results_FashionMnist_test_with_val")
    
    #if you want slice the data for check reasons
    # tr_images = tr_images[:50:]
    # tr_labels = tr_labels[:50]
    # te_images = te_images[:10:]
    # te_labels = te_labels[:10]
    tr_layer.fit(tr_images)
    te_layer.fit(te_images)
    tr_images = tr_layer.transform(tr_images)
    te_images = te_layer.transform(te_images)
    return ((tr_layer, (tr_images, tr_labels)), (te_layer,(te_images, te_labels)))

with ProcessPoolExecutor() as executor:
    future = executor.submit(preset)

((train_layer, (train_images, train_labels)), (test_layer,(test_images, test_labels))) = future.result() #This blocks until the task completes

# %%
permutations = np.asarray(list(itertools.permutations(range(4))))

def pool(x, call, p, l):
    op = OperationLayer(call())
    predict = l.post_transform(op.pre_op.predict(x,batch_size=1000))
    l.save(predict, p)

# %%
# # not using PorcessPoolExecutor

# for p in permutations:
#     pool(train_images[:,:,p],)

# %%
for j in range(3):
    with ProcessPoolExecutor(8) as executor:
        runner = {
            executor.submit(pool, x=train_images[:,:,p], call=operation, p=p, l=train_layer): p for p in permutations[8*j:8*(j+1)]
        }
        for future in as_completed(runner):
            runner.pop(future)
# Out:
# 60/60 [==============================] - 25s 398ms/step
# 60/60 [==============================] - 27s 424ms/step
# 60/60 [==============================] - 27s 430ms/step
# 60/60 [==============================] - 27s 422ms/step
# 60/60 [==============================] - 27s 424ms/step
# 60/60 [==============================] - 27s 415ms/step
# 60/60 [==============================] - 27s 404ms/step
# 60/60 [==============================] - 26s 393ms/step
# 60/60 [==============================] - 24s 390ms/step
# 60/60 [==============================] - 27s 430ms/step
# 60/60 [==============================] - 27s 433ms/step
# 60/60 [==============================] - 27s 430ms/step
# 60/60 [==============================] - 27s 432ms/step
# 60/60 [==============================] - 28s 428ms/step
# 60/60 [==============================] - 27s 418ms/step
# 60/60 [==============================] - 27s 412ms/step
# 60/60 [==============================] - 27s 421ms/step
# 60/60 [==============================] - 28s 443ms/step
# 60/60 [==============================] - 29s 457ms/step
# 60/60 [==============================] - 28s 446ms/step
# 60/60 [==============================] - 29s 458ms/step
# 60/60 [==============================] - 29s 443ms/step
# 60/60 [==============================] - 29s 441ms/step
# 60/60 [==============================] - 28s 422ms/step

# %%
for j in range(3):
    with ProcessPoolExecutor(8) as executor:
        runner = {
            executor.submit(pool, x=test_images[:,:,p], call=operation, p=p, l=test_layer): p for p in permutations[8*j:8*(j+1)]
        }
        for future in as_completed(runner):
            runner.pop(future)
# Out:
# 10/10 [==============================] - 6s 464ms/step
# 10/10 [==============================] - 6s 479ms/step
# 10/10 [==============================] - 6s 498ms/step
# 10/10 [==============================] - 7s 514ms/step
# 10/10 [==============================] - 7s 513ms/step
# 10/10 [==============================] - 7s 470ms/step
# 10/10 [==============================] - 7s 459ms/step
# 10/10 [==============================] - 7s 464ms/step
# 10/10 [==============================] - 6s 465ms/step
# 10/10 [==============================] - 6s 492ms/step
# 10/10 [==============================] - 6s 487ms/step
# 10/10 [==============================] - 6s 474ms/step
# 10/10 [==============================] - 6s 470ms/step
# 10/10 [==============================] - 6s 462ms/step
# 10/10 [==============================] - 6s 442ms/step
# 10/10 [==============================] - 6s 400ms/step
# 10/10 [==============================] - 5s 433ms/step
# 10/10 [==============================] - 6s 486ms/step
# 10/10 [==============================] - 6s 489ms/step
# 10/10 [==============================] - 6s 486ms/step
# 10/10 [==============================] - 6s 488ms/step
# 10/10 [==============================] - 6s 430ms/step
# 10/10 [==============================] - 6s 467ms/step
# 10/10 [==============================] - 6s 474ms/step

# %% [markdown]
# ## Filtering Data by Entropy degree

# %%
# --- Function to process a single input type ---
def process_input_type(input_data, config, entropy_dict_for_symm):
    """
    Helper function to encapsulate the parallel processing logic for one input type.
    """
    input_system_03 = input_data[:, :, :2]
    input_system_21 = input_data[:, :, 2:4] # Assuming the same slicing  input_system_03 = input_data[:, :, :2]

    task_inputs = list(zip(input_system_03, input_system_21))
    # print("Im inside process_input_type")
    # print("len of task inputs is ", len(task_inputs) )
    # print(f"\nStarting parallel entropy computation for {data_name} data ({len(task_inputs)} batches)...")
    type_start_time = time.time()
    # from collections import defaultdict

    # entropy_dict_for_symm = defaultdict(list)   # missing keys become []
    # config = ''.join(map(str, config)) 
    with ProcessPoolExecutor(max_workers=None) as executor:
        results_iterator = executor.map(compute_entropy_for_pair_batch, task_inputs)

        for i, result in enumerate(results_iterator):
            # print(f"i is {i} and result is {type(result)} len {len(result)}")
            (avg_s1_rho0, avg_s1_rho1), \
            (avg_s2_rho0, avg_s2_rho1), \
            (max_s1_rho0, max_s1_rho1), \
            (max_s2_rho0, max_s2_rho1), \
            (S1_rho_0), \
            (S1_rho_1), \
            (S2_rho_0), \
            (S2_rho_1) = result
            
            # Append to the lists directly from the dictionary
            # Using dictionary keys here
            entropy_dict_for_symm['Total_Avg_' + config + '_Entropy_S1'].append((avg_s1_rho0, avg_s1_rho1))
            entropy_dict_for_symm['Total_Avg_' + config + '_Entropy_S2'].append((avg_s2_rho0, avg_s2_rho1))
            entropy_dict_for_symm['Total_Max_' + config + '_Entropy_S1'].append((max_s1_rho0, max_s1_rho1))
            entropy_dict_for_symm['Total_Max_' + config + '_Entropy_S2'].append((max_s2_rho0, max_s2_rho1))
            # New ones to capture pair entanglement for subsequent filtering
            entropy_dict_for_symm['S1_rho_0_' + config + '_Entropy_S1_0'].append(S1_rho_0)
            entropy_dict_for_symm['S1_rho_1_' + config + '_Entropy_S1_1'].append(S1_rho_1)
            entropy_dict_for_symm['S2_rho_0_' + config + '_Entropy_S2_0'].append(S2_rho_0)
            entropy_dict_for_symm['S2_rho_1_' + config + '_Entropy_S2_1'].append(S2_rho_1)

            if (i + 1) % 100 == 0:
                print(f"Processed {i + 1}/{len(task_inputs)} batches for {config}.")
                
        
        # Convert lists to NumPy arrays
        entropy_dict_for_symm['Total_Avg_' + config + '_Entropy_S1'] = np.array(entropy_dict_for_symm['Total_Avg_' + config + '_Entropy_S1'])
        entropy_dict_for_symm['Total_Avg_' + config + '_Entropy_S2'] = np.array(entropy_dict_for_symm['Total_Avg_' + config + '_Entropy_S2'])
        entropy_dict_for_symm['Total_Max_' + config + '_Entropy_S1'] = np.array(entropy_dict_for_symm['Total_Max_' + config + '_Entropy_S1'])
        entropy_dict_for_symm['Total_Max_' + config + '_Entropy_S2'] = np.array(entropy_dict_for_symm['Total_Max_' + config + '_Entropy_S2'])
        # New ones to capture pair entanglement for subsequent filtering
        entropy_dict_for_symm['S1_rho_0_' + config + '_Entropy_S1_0']  = np.array(entropy_dict_for_symm['S1_rho_0_' + config + '_Entropy_S1_0'])    
        entropy_dict_for_symm['S1_rho_1_' + config + '_Entropy_S1_1']  = np.array(entropy_dict_for_symm['S1_rho_1_' + config + '_Entropy_S1_1'])
        entropy_dict_for_symm['S2_rho_0_' + config + '_Entropy_S2_0']  = np.array(entropy_dict_for_symm['S2_rho_0_' + config + '_Entropy_S2_0'])
        entropy_dict_for_symm['S2_rho_1_' + config + '_Entropy_S2_1']  = np.array(entropy_dict_for_symm['S2_rho_1_' + config + '_Entropy_S2_1'])
        
        # compute the total entry of the entire system S1 + S2
        # Compute the total entropy of the entire system S1 + S2
        # Ensure avg_s1_array and avg_s2_array are in the correct shape (N, 2)
        # The output of compute_entropy_for_pair_batch is (rho0, rho1) tuples, which will become (N, 2) arrays.
        entropy_dict_for_symm['Total_Avg_' + config + '_Entropy_S1_S2'] = entropy_dict_for_symm['Total_Avg_' + config + '_Entropy_S1'] \
                                                                            + entropy_dict_for_symm['Total_Avg_' + config + '_Entropy_S2']
        entropy_dict_for_symm[f'Total_Max_{config}_Entropy_S1_S2'] = entropy_dict_for_symm['Total_Max_' + config + '_Entropy_S1'] \
                                                                            + entropy_dict_for_symm['Total_Max_' + config + '_Entropy_S2']

    # --- Saving Data as CSV ---
    # 1. Create the data_name specific folder

    entropy_folder_name = train_layer.name + f"/{config}/Entropy"
    # train
    # entropy_folder_name = "_OA_train"
    output_folder_path = os.path.join(entropy_folder_name) # Replace spaces for folder names
    os.makedirs(output_folder_path, exist_ok=True)
    print(f"Created/Ensured directory: {output_folder_path}")

    # 2. Save each list/array corresponding to each key as a CSV file
    for key, value in entropy_dict_for_symm.items():
        if isinstance(value, np.ndarray): # Only save if it's a NumPy array
            file_path = os.path.join(output_folder_path, f"{key}.csv")
            # Use fmt='%.8f' for float formatting, delimiter=',' for CSV
            np.savetxt(file_path, value, delimiter=',', fmt='%.8f')
            print(f"Saved {key}.csv to {output_folder_path}")
        else:
            print(f"Skipping saving for key '{key}' as it's not a NumPy array (type: {type(value)})")
    type_end_time = time.time()
    print(f"Finished parallel computation for data for config {config} in {type_end_time - type_start_time:.2f} seconds.")

# %%
# checked
D = {"Configs": {  #  configuration that yields the best validation accuracy
                "P_diagonal_config" : np.asarray([1,2,3,0]),
                "P_vertical_config" : np.asarray([0,1,3,2]),
                "P_horizontal_config" : np.asarray([2,0,1,3])
              }
    }
D_configs = D["Configs"].values()

# %%
# Scaling data
scaled_sample = train_images/255.
# Encoding data using angle encoding
scaled_sample = scaled_sample * np.pi
from collections import defaultdict


for config in D_configs:
    # rearranging the input in respect to the configs
    input = scaled_sample[:,:,config]

    entropy_dict_for_symm = defaultdict(list)   # missing keys become []
    config = ''.join(map(str, config))
    process_input_type(input, config, entropy_dict_for_symm)
    # break
# Out:
# Processed 100/60000 batches for 1230.
# Processed 200/60000 batches for 1230.
# Processed 300/60000 batches for 1230.
# Processed 400/60000 batches for 1230.
# Processed 500/60000 batches for 1230.
# Processed 600/60000 batches for 1230.
# Processed 700/60000 batches for 1230.
# Processed 800/60000 batches for 1230.
# Processed 900/60000 batches for 1230.
# Processed 1000/60000 batches for 1230.
# Processed 1100/60000 batches for 1230.
# Processed 1200/60000 batches for 1230.
# Processed 1300/60000 batches for 1230.
# Processed 1400/60000 batches for 1230.
# Processed 1500/60000 batches for 1230.
# Processed 1600/60000 batches for 1230.
# Processed 1700/60000 batches for 1230.
# Processed 1800/60000 batches for 1230.
# Processed 1900/60000 batches for 1230.
# Processed 2000/60000 batches for 1230.
# Processed 2100/60000 batches for 1230.
# Processed 2200/60000 batches for 1230.
# Processed 2300/60000 batches for 1230.
# Processed 2400/60000 batches for 1230.
# Processed 2500/60000 batches for 1230.
# Processed 2600/60000 batches for 1230.
# Processed 2700/60000 batches for 1230.
# Processed 2800/60000 batches for 1230.
# Processed 2900/60000 batches for 1230.
# Processed 3000/60000 batches for 1230.
# Processed 3100/60000 batches for 1230.
# Processed 3200/60000 batches for 1230.
# Processed 3300/60000 batches for 1230.
# Processed 3400/60000 batches for 1230.
# Processed 3500/60000 batches for 1230.
# Processed 3600/60000 batches for 1230.
# Processed 3700/60000 batches for 1230.
# Processed 3800/60000 batches for 1230.
# Processed 3900/60000 batches for 1230.
# Processed 4000/60000 batches for 1230.
# Processed 4100/60000 batches for 1230.
# Processed 4200/60000 batches for 1230.
# Processed 4300/60000 batches for 1230.
# Processed 4400/60000 batches for 1230.
# Processed 4500/60000 batches for 1230.
# Processed 4600/60000 batches for 1230.
# Processed 4700/60000 batches for 1230.
# Processed 4800/60000 batches for 1230.
# Processed 4900/60000 batches for 1230.
# Processed 5000/60000 batches for 1230.
# Processed 5100/60000 batches for 1230.
# Processed 5200/60000 batches for 1230.
# Processed 5300/60000 batches for 1230.
# Processed 5400/60000 batches for 1230.
# Processed 5500/60000 batches for 1230.
# Processed 5600/60000 batches for 1230.
# Processed 5700/60000 batches for 1230.
# Processed 5800/60000 batches for 1230.
# Processed 5900/60000 batches for 1230.
# Processed 6000/60000 batches for 1230.
# Processed 6100/60000 batches for 1230.
# Processed 6200/60000 batches for 1230.
# Processed 6300/60000 batches for 1230.
# Processed 6400/60000 batches for 1230.
# Processed 6500/60000 batches for 1230.
# Processed 6600/60000 batches for 1230.
# Processed 6700/60000 batches for 1230.
# Processed 6800/60000 batches for 1230.
# Processed 6900/60000 batches for 1230.
# Processed 7000/60000 batches for 1230.
# Processed 7100/60000 batches for 1230.
# Processed 7200/60000 batches for 1230.
# Processed 7300/60000 batches for 1230.
# Processed 7400/60000 batches for 1230.
# Processed 7500/60000 batches for 1230.
# Processed 7600/60000 batches for 1230.
# Processed 7700/60000 batches for 1230.
# Processed 7800/60000 batches for 1230.
# Processed 7900/60000 batches for 1230.
# Processed 8000/60000 batches for 1230.
# Processed 8100/60000 batches for 1230.
# Processed 8200/60000 batches for 1230.
# Processed 8300/60000 batches for 1230.
# Processed 8400/60000 batches for 1230.
# Processed 8500/60000 batches for 1230.
# Processed 8600/60000 batches for 1230.
# Processed 8700/60000 batches for 1230.
# Processed 8800/60000 batches for 1230.
# Processed 8900/60000 batches for 1230.
# Processed 9000/60000 batches for 1230.
# Processed 9100/60000 batches for 1230.
# Processed 9200/60000 batches for 1230.
# Processed 9300/60000 batches for 1230.
# Processed 9400/60000 batches for 1230.
# Processed 9500/60000 batches for 1230.
# Processed 9600/60000 batches for 1230.
# Processed 9700/60000 batches for 1230.
# Processed 9800/60000 batches for 1230.
# Processed 9900/60000 batches for 1230.
# Processed 10000/60000 batches for 1230.
# Processed 10100/60000 batches for 1230.
# Processed 10200/60000 batches for 1230.
# Processed 10300/60000 batches for 1230.
# Processed 10400/60000 batches for 1230.
# Processed 10500/60000 batches for 1230.
# Processed 10600/60000 batches for 1230.
# Processed 10700/60000 batches for 1230.
# Processed 10800/60000 batches for 1230.
# Processed 10900/60000 batches for 1230.
# Processed 11000/60000 batches for 1230.
# Processed 11100/60000 batches for 1230.
# Processed 11200/60000 batches for 1230.
# Processed 11300/60000 batches for 1230.
# Processed 11400/60000 batches for 1230.
# Processed 11500/60000 batches for 1230.
# Processed 11600/60000 batches for 1230.
# Processed 11700/60000 batches for 1230.
# Processed 11800/60000 batches for 1230.
# Processed 11900/60000 batches for 1230.
# Processed 12000/60000 batches for 1230.
# Processed 12100/60000 batches for 1230.
# Processed 12200/60000 batches for 1230.
# Processed 12300/60000 batches for 1230.
# Processed 12400/60000 batches for 1230.
# Processed 12500/60000 batches for 1230.
# Processed 12600/60000 batches for 1230.
# Processed 12700/60000 batches for 1230.
# Processed 12800/60000 batches for 1230.
# Processed 12900/60000 batches for 1230.
# Processed 13000/60000 batches for 1230.
# Processed 13100/60000 batches for 1230.
# Processed 13200/60000 batches for 1230.
# Processed 13300/60000 batches for 1230.
# Processed 13400/60000 batches for 1230.
# Processed 13500/60000 batches for 1230.
# Processed 13600/60000 batches for 1230.
# Processed 13700/60000 batches for 1230.
# Processed 13800/60000 batches for 1230.
# Processed 13900/60000 batches for 1230.
# Processed 14000/60000 batches for 1230.
# Processed 14100/60000 batches for 1230.
# Processed 14200/60000 batches for 1230.
# Processed 14300/60000 batches for 1230.
# Processed 14400/60000 batches for 1230.
# Processed 14500/60000 batches for 1230.
# Processed 14600/60000 batches for 1230.
# Processed 14700/60000 batches for 1230.
# Processed 14800/60000 batches for 1230.
# Processed 14900/60000 batches for 1230.
# Processed 15000/60000 batches for 1230.
# Processed 15100/60000 batches for 1230.
# Processed 15200/60000 batches for 1230.
# Processed 15300/60000 batches for 1230.
# Processed 15400/60000 batches for 1230.
# Processed 15500/60000 batches for 1230.
# Processed 15600/60000 batches for 1230.
# Processed 15700/60000 batches for 1230.
# Processed 15800/60000 batches for 1230.
# Processed 15900/60000 batches for 1230.
# Processed 16000/60000 batches for 1230.
# Processed 16100/60000 batches for 1230.
# Processed 16200/60000 batches for 1230.
# Processed 16300/60000 batches for 1230.
# Processed 16400/60000 batches for 1230.
# Processed 16500/60000 batches for 1230.
# Processed 16600/60000 batches for 1230.
# Processed 16700/60000 batches for 1230.
# Processed 16800/60000 batches for 1230.
# Processed 16900/60000 batches for 1230.
# Processed 17000/60000 batches for 1230.
# Processed 17100/60000 batches for 1230.
# Processed 17200/60000 batches for 1230.
# Processed 17300/60000 batches for 1230.
# Processed 17400/60000 batches for 1230.
# Processed 17500/60000 batches for 1230.
# Processed 17600/60000 batches for 1230.
# Processed 17700/60000 batches for 1230.
# Processed 17800/60000 batches for 1230.
# Processed 17900/60000 batches for 1230.
# Processed 18000/60000 batches for 1230.
# Processed 18100/60000 batches for 1230.
# Processed 18200/60000 batches for 1230.
# Processed 18300/60000 batches for 1230.
# Processed 18400/60000 batches for 1230.
# Processed 18500/60000 batches for 1230.
# Processed 18600/60000 batches for 1230.
# Processed 18700/60000 batches for 1230.
# Processed 18800/60000 batches for 1230.
# Processed 18900/60000 batches for 1230.
# Processed 19000/60000 batches for 1230.
# Processed 19100/60000 batches for 1230.
# Processed 19200/60000 batches for 1230.
# Processed 19300/60000 batches for 1230.
# Processed 19400/60000 batches for 1230.
# Processed 19500/60000 batches for 1230.
# Processed 19600/60000 batches for 1230.
# Processed 19700/60000 batches for 1230.
# Processed 19800/60000 batches for 1230.
# Processed 19900/60000 batches for 1230.
# Processed 20000/60000 batches for 1230.
# Processed 20100/60000 batches for 1230.
# Processed 20200/60000 batches for 1230.
# Processed 20300/60000 batches for 1230.
# Processed 20400/60000 batches for 1230.
# Processed 20500/60000 batches for 1230.
# Processed 20600/60000 batches for 1230.
# Processed 20700/60000 batches for 1230.
# Processed 20800/60000 batches for 1230.
# Processed 20900/60000 batches for 1230.
# Processed 21000/60000 batches for 1230.
# Processed 21100/60000 batches for 1230.
# Processed 21200/60000 batches for 1230.
# Processed 21300/60000 batches for 1230.
# Processed 21400/60000 batches for 1230.
# Processed 21500/60000 batches for 1230.
# Processed 21600/60000 batches for 1230.
# Processed 21700/60000 batches for 1230.
# Processed 21800/60000 batches for 1230.
# Processed 21900/60000 batches for 1230.
# Processed 22000/60000 batches for 1230.
# Processed 22100/60000 batches for 1230.
# Processed 22200/60000 batches for 1230.
# Processed 22300/60000 batches for 1230.
# Processed 22400/60000 batches for 1230.
# Processed 22500/60000 batches for 1230.
# Processed 22600/60000 batches for 1230.
# Processed 22700/60000 batches for 1230.
# Processed 22800/60000 batches for 1230.
# Processed 22900/60000 batches for 1230.
# Processed 23000/60000 batches for 1230.
# Processed 23100/60000 batches for 1230.
# Processed 23200/60000 batches for 1230.
# Processed 23300/60000 batches for 1230.
# Processed 23400/60000 batches for 1230.
# Processed 23500/60000 batches for 1230.
# Processed 23600/60000 batches for 1230.
# Processed 23700/60000 batches for 1230.
# Processed 23800/60000 batches for 1230.
# Processed 23900/60000 batches for 1230.
# Processed 24000/60000 batches for 1230.
# Processed 24100/60000 batches for 1230.
# Processed 24200/60000 batches for 1230.
# Processed 24300/60000 batches for 1230.
# Processed 24400/60000 batches for 1230.
# Processed 24500/60000 batches for 1230.
# Processed 24600/60000 batches for 1230.
# Processed 24700/60000 batches for 1230.
# Processed 24800/60000 batches for 1230.
# Processed 24900/60000 batches for 1230.
# Processed 25000/60000 batches for 1230.
# Processed 25100/60000 batches for 1230.
# Processed 25200/60000 batches for 1230.
# Processed 25300/60000 batches for 1230.
# Processed 25400/60000 batches for 1230.
# Processed 25500/60000 batches for 1230.
# Processed 25600/60000 batches for 1230.
# Processed 25700/60000 batches for 1230.
# Processed 25800/60000 batches for 1230.
# Processed 25900/60000 batches for 1230.
# Processed 26000/60000 batches for 1230.
# Processed 26100/60000 batches for 1230.
# Processed 26200/60000 batches for 1230.
# Processed 26300/60000 batches for 1230.
# Processed 26400/60000 batches for 1230.
# Processed 26500/60000 batches for 1230.
# Processed 26600/60000 batches for 1230.
# Processed 26700/60000 batches for 1230.
# Processed 26800/60000 batches for 1230.
# Processed 26900/60000 batches for 1230.
# Processed 27000/60000 batches for 1230.
# Processed 27100/60000 batches for 1230.
# Processed 27200/60000 batches for 1230.
# Processed 27300/60000 batches for 1230.
# Processed 27400/60000 batches for 1230.
# Processed 27500/60000 batches for 1230.
# Processed 27600/60000 batches for 1230.
# Processed 27700/60000 batches for 1230.
# Processed 27800/60000 batches for 1230.
# Processed 27900/60000 batches for 1230.
# Processed 28000/60000 batches for 1230.
# Processed 28100/60000 batches for 1230.
# Processed 28200/60000 batches for 1230.
# Processed 28300/60000 batches for 1230.
# Processed 28400/60000 batches for 1230.
# Processed 28500/60000 batches for 1230.
# Processed 28600/60000 batches for 1230.
# Processed 28700/60000 batches for 1230.
# Processed 28800/60000 batches for 1230.
# Processed 28900/60000 batches for 1230.
# Processed 29000/60000 batches for 1230.
# Processed 29100/60000 batches for 1230.
# Processed 29200/60000 batches for 1230.
# Processed 29300/60000 batches for 1230.
# Processed 29400/60000 batches for 1230.
# Processed 29500/60000 batches for 1230.
# Processed 29600/60000 batches for 1230.
# Processed 29700/60000 batches for 1230.
# Processed 29800/60000 batches for 1230.
# Processed 29900/60000 batches for 1230.
# Processed 30000/60000 batches for 1230.
# Processed 30100/60000 batches for 1230.
# Processed 30200/60000 batches for 1230.
# Processed 30300/60000 batches for 1230.
# Processed 30400/60000 batches for 1230.
# Processed 30500/60000 batches for 1230.
# Processed 30600/60000 batches for 1230.
# Processed 30700/60000 batches for 1230.
# Processed 30800/60000 batches for 1230.
# Processed 30900/60000 batches for 1230.
# Processed 31000/60000 batches for 1230.
# Processed 31100/60000 batches for 1230.
# Processed 31200/60000 batches for 1230.
# Processed 31300/60000 batches for 1230.
# Processed 31400/60000 batches for 1230.
# Processed 31500/60000 batches for 1230.
# Processed 31600/60000 batches for 1230.
# Processed 31700/60000 batches for 1230.
# Processed 31800/60000 batches for 1230.
# Processed 31900/60000 batches for 1230.
# Processed 32000/60000 batches for 1230.
# Processed 32100/60000 batches for 1230.
# Processed 32200/60000 batches for 1230.
# Processed 32300/60000 batches for 1230.
# Processed 32400/60000 batches for 1230.
# Processed 32500/60000 batches for 1230.
# Processed 32600/60000 batches for 1230.
# Processed 32700/60000 batches for 1230.
# Processed 32800/60000 batches for 1230.
# Processed 32900/60000 batches for 1230.
# Processed 33000/60000 batches for 1230.
# Processed 33100/60000 batches for 1230.
# Processed 33200/60000 batches for 1230.
# Processed 33300/60000 batches for 1230.
# Processed 33400/60000 batches for 1230.
# Processed 33500/60000 batches for 1230.
# Processed 33600/60000 batches for 1230.
# Processed 33700/60000 batches for 1230.
# Processed 33800/60000 batches for 1230.
# Processed 33900/60000 batches for 1230.
# Processed 34000/60000 batches for 1230.
# Processed 34100/60000 batches for 1230.
# Processed 34200/60000 batches for 1230.
# Processed 34300/60000 batches for 1230.
# Processed 34400/60000 batches for 1230.
# Processed 34500/60000 batches for 1230.
# Processed 34600/60000 batches for 1230.
# Processed 34700/60000 batches for 1230.
# Processed 34800/60000 batches for 1230.
# Processed 34900/60000 batches for 1230.
# Processed 35000/60000 batches for 1230.
# Processed 35100/60000 batches for 1230.
# Processed 35200/60000 batches for 1230.
# Processed 35300/60000 batches for 1230.
# Processed 35400/60000 batches for 1230.
# Processed 35500/60000 batches for 1230.
# Processed 35600/60000 batches for 1230.
# Processed 35700/60000 batches for 1230.
# Processed 35800/60000 batches for 1230.
# Processed 35900/60000 batches for 1230.
# Processed 36000/60000 batches for 1230.
# Processed 36100/60000 batches for 1230.
# Processed 36200/60000 batches for 1230.
# Processed 36300/60000 batches for 1230.
# Processed 36400/60000 batches for 1230.
# Processed 36500/60000 batches for 1230.
# Processed 36600/60000 batches for 1230.
# Processed 36700/60000 batches for 1230.
# Processed 36800/60000 batches for 1230.
# Processed 36900/60000 batches for 1230.
# Processed 37000/60000 batches for 1230.
# Processed 37100/60000 batches for 1230.
# Processed 37200/60000 batches for 1230.
# Processed 37300/60000 batches for 1230.
# Processed 37400/60000 batches for 1230.
# Processed 37500/60000 batches for 1230.
# Processed 37600/60000 batches for 1230.
# Processed 37700/60000 batches for 1230.
# Processed 37800/60000 batches for 1230.
# Processed 37900/60000 batches for 1230.
# Processed 38000/60000 batches for 1230.
# Processed 38100/60000 batches for 1230.
# Processed 38200/60000 batches for 1230.
# Processed 38300/60000 batches for 1230.
# Processed 38400/60000 batches for 1230.
# Processed 38500/60000 batches for 1230.
# Processed 38600/60000 batches for 1230.
# Processed 38700/60000 batches for 1230.
# Processed 38800/60000 batches for 1230.
# Processed 38900/60000 batches for 1230.
# Processed 39000/60000 batches for 1230.
# Processed 39100/60000 batches for 1230.
# Processed 39200/60000 batches for 1230.
# Processed 39300/60000 batches for 1230.
# Processed 39400/60000 batches for 1230.
# Processed 39500/60000 batches for 1230.
# Processed 39600/60000 batches for 1230.
# Processed 39700/60000 batches for 1230.
# Processed 39800/60000 batches for 1230.
# Processed 39900/60000 batches for 1230.
# Processed 40000/60000 batches for 1230.
# Processed 40100/60000 batches for 1230.
# Processed 40200/60000 batches for 1230.
# Processed 40300/60000 batches for 1230.
# Processed 40400/60000 batches for 1230.
# Processed 40500/60000 batches for 1230.
# Processed 40600/60000 batches for 1230.
# Processed 40700/60000 batches for 1230.
# Processed 40800/60000 batches for 1230.
# Processed 40900/60000 batches for 1230.
# Processed 41000/60000 batches for 1230.
# Processed 41100/60000 batches for 1230.
# Processed 41200/60000 batches for 1230.
# Processed 41300/60000 batches for 1230.
# Processed 41400/60000 batches for 1230.
# Processed 41500/60000 batches for 1230.
# Processed 41600/60000 batches for 1230.
# Processed 41700/60000 batches for 1230.
# Processed 41800/60000 batches for 1230.
# Processed 41900/60000 batches for 1230.
# Processed 42000/60000 batches for 1230.
# Processed 42100/60000 batches for 1230.
# Processed 42200/60000 batches for 1230.
# Processed 42300/60000 batches for 1230.
# Processed 42400/60000 batches for 1230.
# Processed 42500/60000 batches for 1230.
# Processed 42600/60000 batches for 1230.
# Processed 42700/60000 batches for 1230.
# Processed 42800/60000 batches for 1230.
# Processed 42900/60000 batches for 1230.
# Processed 43000/60000 batches for 1230.
# Processed 43100/60000 batches for 1230.
# Processed 43200/60000 batches for 1230.
# Processed 43300/60000 batches for 1230.
# Processed 43400/60000 batches for 1230.
# Processed 43500/60000 batches for 1230.
# Processed 43600/60000 batches for 1230.
# Processed 43700/60000 batches for 1230.
# Processed 43800/60000 batches for 1230.
# Processed 43900/60000 batches for 1230.
# Processed 44000/60000 batches for 1230.
# Processed 44100/60000 batches for 1230.
# Processed 44200/60000 batches for 1230.
# Processed 44300/60000 batches for 1230.
# Processed 44400/60000 batches for 1230.
# Processed 44500/60000 batches for 1230.
# Processed 44600/60000 batches for 1230.
# Processed 44700/60000 batches for 1230.
# Processed 44800/60000 batches for 1230.
# Processed 44900/60000 batches for 1230.
# Processed 45000/60000 batches for 1230.
# Processed 45100/60000 batches for 1230.
# Processed 45200/60000 batches for 1230.
# Processed 45300/60000 batches for 1230.
# Processed 45400/60000 batches for 1230.
# Processed 45500/60000 batches for 1230.
# Processed 45600/60000 batches for 1230.
# Processed 45700/60000 batches for 1230.
# Processed 45800/60000 batches for 1230.
# Processed 45900/60000 batches for 1230.
# Processed 46000/60000 batches for 1230.
# Processed 46100/60000 batches for 1230.
# Processed 46200/60000 batches for 1230.
# Processed 46300/60000 batches for 1230.
# Processed 46400/60000 batches for 1230.
# Processed 46500/60000 batches for 1230.
# Processed 46600/60000 batches for 1230.
# Processed 46700/60000 batches for 1230.
# Processed 46800/60000 batches for 1230.
# Processed 46900/60000 batches for 1230.
# Processed 47000/60000 batches for 1230.
# Processed 47100/60000 batches for 1230.
# Processed 47200/60000 batches for 1230.
# Processed 47300/60000 batches for 1230.
# Processed 47400/60000 batches for 1230.
# Processed 47500/60000 batches for 1230.
# Processed 47600/60000 batches for 1230.
# Processed 47700/60000 batches for 1230.
# Processed 47800/60000 batches for 1230.
# Processed 47900/60000 batches for 1230.
# Processed 48000/60000 batches for 1230.
# Processed 48100/60000 batches for 1230.
# Processed 48200/60000 batches for 1230.
# Processed 48300/60000 batches for 1230.
# Processed 48400/60000 batches for 1230.
# Processed 48500/60000 batches for 1230.
# Processed 48600/60000 batches for 1230.
# Processed 48700/60000 batches for 1230.
# Processed 48800/60000 batches for 1230.
# Processed 48900/60000 batches for 1230.
# Processed 49000/60000 batches for 1230.
# Processed 49100/60000 batches for 1230.
# Processed 49200/60000 batches for 1230.
# Processed 49300/60000 batches for 1230.
# Processed 49400/60000 batches for 1230.
# Processed 49500/60000 batches for 1230.
# Processed 49600/60000 batches for 1230.
# Processed 49700/60000 batches for 1230.
# Processed 49800/60000 batches for 1230.
# Processed 49900/60000 batches for 1230.
# Processed 50000/60000 batches for 1230.
# Processed 50100/60000 batches for 1230.
# Processed 50200/60000 batches for 1230.
# Processed 50300/60000 batches for 1230.
# Processed 50400/60000 batches for 1230.
# Processed 50500/60000 batches for 1230.
# Processed 50600/60000 batches for 1230.
# Processed 50700/60000 batches for 1230.
# Processed 50800/60000 batches for 1230.
# Processed 50900/60000 batches for 1230.
# Processed 51000/60000 batches for 1230.
# Processed 51100/60000 batches for 1230.
# Processed 51200/60000 batches for 1230.
# Processed 51300/60000 batches for 1230.
# Processed 51400/60000 batches for 1230.
# Processed 51500/60000 batches for 1230.
# Processed 51600/60000 batches for 1230.
# Processed 51700/60000 batches for 1230.
# Processed 51800/60000 batches for 1230.
# Processed 51900/60000 batches for 1230.
# Processed 52000/60000 batches for 1230.
# Processed 52100/60000 batches for 1230.
# Processed 52200/60000 batches for 1230.
# Processed 52300/60000 batches for 1230.
# Processed 52400/60000 batches for 1230.
# Processed 52500/60000 batches for 1230.
# Processed 52600/60000 batches for 1230.
# Processed 52700/60000 batches for 1230.
# Processed 52800/60000 batches for 1230.
# Processed 52900/60000 batches for 1230.
# Processed 53000/60000 batches for 1230.
# Processed 53100/60000 batches for 1230.
# Processed 53200/60000 batches for 1230.
# Processed 53300/60000 batches for 1230.
# Processed 53400/60000 batches for 1230.
# Processed 53500/60000 batches for 1230.
# Processed 53600/60000 batches for 1230.
# Processed 53700/60000 batches for 1230.
# Processed 53800/60000 batches for 1230.
# Processed 53900/60000 batches for 1230.
# Processed 54000/60000 batches for 1230.
# Processed 54100/60000 batches for 1230.
# Processed 54200/60000 batches for 1230.
# Processed 54300/60000 batches for 1230.
# Processed 54400/60000 batches for 1230.
# Processed 54500/60000 batches for 1230.
# Processed 54600/60000 batches for 1230.
# Processed 54700/60000 batches for 1230.
# Processed 54800/60000 batches for 1230.
# Processed 54900/60000 batches for 1230.
# Processed 55000/60000 batches for 1230.
# Processed 55100/60000 batches for 1230.
# Processed 55200/60000 batches for 1230.
# Processed 55300/60000 batches for 1230.
# Processed 55400/60000 batches for 1230.
# Processed 55500/60000 batches for 1230.
# Processed 55600/60000 batches for 1230.
# Processed 55700/60000 batches for 1230.
# Processed 55800/60000 batches for 1230.
# Processed 55900/60000 batches for 1230.
# Processed 56000/60000 batches for 1230.
# Processed 56100/60000 batches for 1230.
# Processed 56200/60000 batches for 1230.
# Processed 56300/60000 batches for 1230.
# Processed 56400/60000 batches for 1230.
# Processed 56500/60000 batches for 1230.
# Processed 56600/60000 batches for 1230.
# Processed 56700/60000 batches for 1230.
# Processed 56800/60000 batches for 1230.
# Processed 56900/60000 batches for 1230.
# Processed 57000/60000 batches for 1230.
# Processed 57100/60000 batches for 1230.
# Processed 57200/60000 batches for 1230.
# Processed 57300/60000 batches for 1230.
# Processed 57400/60000 batches for 1230.
# Processed 57500/60000 batches for 1230.
# Processed 57600/60000 batches for 1230.
# Processed 57700/60000 batches for 1230.
# Processed 57800/60000 batches for 1230.
# Processed 57900/60000 batches for 1230.
# Processed 58000/60000 batches for 1230.
# Processed 58100/60000 batches for 1230.
# Processed 58200/60000 batches for 1230.
# Processed 58300/60000 batches for 1230.
# Processed 58400/60000 batches for 1230.
# Processed 58500/60000 batches for 1230.
# Processed 58600/60000 batches for 1230.
# Processed 58700/60000 batches for 1230.
# Processed 58800/60000 batches for 1230.
# Processed 58900/60000 batches for 1230.
# Processed 59000/60000 batches for 1230.
# Processed 59100/60000 batches for 1230.
# Processed 59200/60000 batches for 1230.
# Processed 59300/60000 batches for 1230.
# Processed 59400/60000 batches for 1230.
# Processed 59500/60000 batches for 1230.
# Processed 59600/60000 batches for 1230.
# Processed 59700/60000 batches for 1230.
# Processed 59800/60000 batches for 1230.
# Processed 59900/60000 batches for 1230.
# Processed 60000/60000 batches for 1230.
# Created/Ensured directory: _OA_results_FashionMnist_train_with_val/1230/Entropy
# Saved Total_Avg_1230_Entropy_S1.csv to _OA_results_FashionMnist_train_with_val/1230/Entropy
# Saved Total_Avg_1230_Entropy_S2.csv to _OA_results_FashionMnist_train_with_val/1230/Entropy
# Saved Total_Max_1230_Entropy_S1.csv to _OA_results_FashionMnist_train_with_val/1230/Entropy
# Saved Total_Max_1230_Entropy_S2.csv to _OA_results_FashionMnist_train_with_val/1230/Entropy
# Saved S1_rho_0_1230_Entropy_S1_0.csv to _OA_results_FashionMnist_train_with_val/1230/Entropy
# Saved S1_rho_1_1230_Entropy_S1_1.csv to _OA_results_FashionMnist_train_with_val/1230/Entropy
# Saved S2_rho_0_1230_Entropy_S2_0.csv to _OA_results_FashionMnist_train_with_val/1230/Entropy
# Saved S2_rho_1_1230_Entropy_S2_1.csv to _OA_results_FashionMnist_train_with_val/1230/Entropy
# Saved Total_Avg_1230_Entropy_S1_S2.csv to _OA_results_FashionMnist_train_with_val/1230/Entropy
# Saved Total_Max_1230_Entropy_S1_S2.csv to _OA_results_FashionMnist_train_with_val/1230/Entropy
# Finished parallel computation for data for config 1230 in 77.34 seconds.
# Processed 100/60000 batches for 0132.
# Processed 200/60000 batches for 0132.
# Processed 300/60000 batches for 0132.
# Processed 400/60000 batches for 0132.
# Processed 500/60000 batches for 0132.
# Processed 600/60000 batches for 0132.
# Processed 700/60000 batches for 0132.
# Processed 800/60000 batches for 0132.
# Processed 900/60000 batches for 0132.
# Processed 1000/60000 batches for 0132.
# Processed 1100/60000 batches for 0132.
# Processed 1200/60000 batches for 0132.
# Processed 1300/60000 batches for 0132.
# Processed 1400/60000 batches for 0132.
# Processed 1500/60000 batches for 0132.
# Processed 1600/60000 batches for 0132.
# Processed 1700/60000 batches for 0132.
# Processed 1800/60000 batches for 0132.
# Processed 1900/60000 batches for 0132.
# Processed 2000/60000 batches for 0132.
# Processed 2100/60000 batches for 0132.
# Processed 2200/60000 batches for 0132.
# Processed 2300/60000 batches for 0132.
# Processed 2400/60000 batches for 0132.
# Processed 2500/60000 batches for 0132.
# Processed 2600/60000 batches for 0132.
# Processed 2700/60000 batches for 0132.
# Processed 2800/60000 batches for 0132.
# Processed 2900/60000 batches for 0132.
# Processed 3000/60000 batches for 0132.
# Processed 3100/60000 batches for 0132.
# Processed 3200/60000 batches for 0132.
# Processed 3300/60000 batches for 0132.
# Processed 3400/60000 batches for 0132.
# Processed 3500/60000 batches for 0132.
# Processed 3600/60000 batches for 0132.
# Processed 3700/60000 batches for 0132.
# Processed 3800/60000 batches for 0132.
# Processed 3900/60000 batches for 0132.
# Processed 4000/60000 batches for 0132.
# Processed 4100/60000 batches for 0132.
# Processed 4200/60000 batches for 0132.
# Processed 4300/60000 batches for 0132.
# Processed 4400/60000 batches for 0132.
# Processed 4500/60000 batches for 0132.
# Processed 4600/60000 batches for 0132.
# Processed 4700/60000 batches for 0132.
# Processed 4800/60000 batches for 0132.
# Processed 4900/60000 batches for 0132.
# Processed 5000/60000 batches for 0132.
# Processed 5100/60000 batches for 0132.
# Processed 5200/60000 batches for 0132.
# Processed 5300/60000 batches for 0132.
# Processed 5400/60000 batches for 0132.
# Processed 5500/60000 batches for 0132.
# Processed 5600/60000 batches for 0132.
# Processed 5700/60000 batches for 0132.
# Processed 5800/60000 batches for 0132.
# Processed 5900/60000 batches for 0132.
# Processed 6000/60000 batches for 0132.
# Processed 6100/60000 batches for 0132.
# Processed 6200/60000 batches for 0132.
# Processed 6300/60000 batches for 0132.
# Processed 6400/60000 batches for 0132.
# Processed 6500/60000 batches for 0132.
# Processed 6600/60000 batches for 0132.
# Processed 6700/60000 batches for 0132.
# Processed 6800/60000 batches for 0132.
# Processed 6900/60000 batches for 0132.
# Processed 7000/60000 batches for 0132.
# Processed 7100/60000 batches for 0132.
# Processed 7200/60000 batches for 0132.
# Processed 7300/60000 batches for 0132.
# Processed 7400/60000 batches for 0132.
# Processed 7500/60000 batches for 0132.
# Processed 7600/60000 batches for 0132.
# Processed 7700/60000 batches for 0132.
# Processed 7800/60000 batches for 0132.
# Processed 7900/60000 batches for 0132.
# Processed 8000/60000 batches for 0132.
# Processed 8100/60000 batches for 0132.
# Processed 8200/60000 batches for 0132.
# Processed 8300/60000 batches for 0132.
# Processed 8400/60000 batches for 0132.
# Processed 8500/60000 batches for 0132.
# Processed 8600/60000 batches for 0132.
# Processed 8700/60000 batches for 0132.
# Processed 8800/60000 batches for 0132.
# Processed 8900/60000 batches for 0132.
# Processed 9000/60000 batches for 0132.
# Processed 9100/60000 batches for 0132.
# Processed 9200/60000 batches for 0132.
# Processed 9300/60000 batches for 0132.
# Processed 9400/60000 batches for 0132.
# Processed 9500/60000 batches for 0132.
# Processed 9600/60000 batches for 0132.
# Processed 9700/60000 batches for 0132.
# Processed 9800/60000 batches for 0132.
# Processed 9900/60000 batches for 0132.
# Processed 10000/60000 batches for 0132.
# Processed 10100/60000 batches for 0132.
# Processed 10200/60000 batches for 0132.
# Processed 10300/60000 batches for 0132.
# Processed 10400/60000 batches for 0132.
# Processed 10500/60000 batches for 0132.
# Processed 10600/60000 batches for 0132.
# Processed 10700/60000 batches for 0132.
# Processed 10800/60000 batches for 0132.
# Processed 10900/60000 batches for 0132.
# Processed 11000/60000 batches for 0132.
# Processed 11100/60000 batches for 0132.
# Processed 11200/60000 batches for 0132.
# Processed 11300/60000 batches for 0132.
# Processed 11400/60000 batches for 0132.
# Processed 11500/60000 batches for 0132.
# Processed 11600/60000 batches for 0132.
# Processed 11700/60000 batches for 0132.
# Processed 11800/60000 batches for 0132.
# Processed 11900/60000 batches for 0132.
# Processed 12000/60000 batches for 0132.
# Processed 12100/60000 batches for 0132.
# Processed 12200/60000 batches for 0132.
# Processed 12300/60000 batches for 0132.
# Processed 12400/60000 batches for 0132.
# Processed 12500/60000 batches for 0132.
# Processed 12600/60000 batches for 0132.
# Processed 12700/60000 batches for 0132.
# Processed 12800/60000 batches for 0132.
# Processed 12900/60000 batches for 0132.
# Processed 13000/60000 batches for 0132.
# Processed 13100/60000 batches for 0132.
# Processed 13200/60000 batches for 0132.
# Processed 13300/60000 batches for 0132.
# Processed 13400/60000 batches for 0132.
# Processed 13500/60000 batches for 0132.
# Processed 13600/60000 batches for 0132.
# Processed 13700/60000 batches for 0132.
# Processed 13800/60000 batches for 0132.
# Processed 13900/60000 batches for 0132.
# Processed 14000/60000 batches for 0132.
# Processed 14100/60000 batches for 0132.
# Processed 14200/60000 batches for 0132.
# Processed 14300/60000 batches for 0132.
# Processed 14400/60000 batches for 0132.
# Processed 14500/60000 batches for 0132.
# Processed 14600/60000 batches for 0132.
# Processed 14700/60000 batches for 0132.
# Processed 14800/60000 batches for 0132.
# Processed 14900/60000 batches for 0132.
# Processed 15000/60000 batches for 0132.
# Processed 15100/60000 batches for 0132.
# Processed 15200/60000 batches for 0132.
# Processed 15300/60000 batches for 0132.
# Processed 15400/60000 batches for 0132.
# Processed 15500/60000 batches for 0132.
# Processed 15600/60000 batches for 0132.
# Processed 15700/60000 batches for 0132.
# Processed 15800/60000 batches for 0132.
# Processed 15900/60000 batches for 0132.
# Processed 16000/60000 batches for 0132.
# Processed 16100/60000 batches for 0132.
# Processed 16200/60000 batches for 0132.
# Processed 16300/60000 batches for 0132.
# Processed 16400/60000 batches for 0132.
# Processed 16500/60000 batches for 0132.
# Processed 16600/60000 batches for 0132.
# Processed 16700/60000 batches for 0132.
# Processed 16800/60000 batches for 0132.
# Processed 16900/60000 batches for 0132.
# Processed 17000/60000 batches for 0132.
# Processed 17100/60000 batches for 0132.
# Processed 17200/60000 batches for 0132.
# Processed 17300/60000 batches for 0132.
# Processed 17400/60000 batches for 0132.
# Processed 17500/60000 batches for 0132.
# Processed 17600/60000 batches for 0132.
# Processed 17700/60000 batches for 0132.
# Processed 17800/60000 batches for 0132.
# Processed 17900/60000 batches for 0132.
# Processed 18000/60000 batches for 0132.
# Processed 18100/60000 batches for 0132.
# Processed 18200/60000 batches for 0132.
# Processed 18300/60000 batches for 0132.
# Processed 18400/60000 batches for 0132.
# Processed 18500/60000 batches for 0132.
# Processed 18600/60000 batches for 0132.
# Processed 18700/60000 batches for 0132.
# Processed 18800/60000 batches for 0132.
# Processed 18900/60000 batches for 0132.
# Processed 19000/60000 batches for 0132.
# Processed 19100/60000 batches for 0132.
# Processed 19200/60000 batches for 0132.
# Processed 19300/60000 batches for 0132.
# Processed 19400/60000 batches for 0132.
# Processed 19500/60000 batches for 0132.
# Processed 19600/60000 batches for 0132.
# Processed 19700/60000 batches for 0132.
# Processed 19800/60000 batches for 0132.
# Processed 19900/60000 batches for 0132.
# Processed 20000/60000 batches for 0132.
# Processed 20100/60000 batches for 0132.
# Processed 20200/60000 batches for 0132.
# Processed 20300/60000 batches for 0132.
# Processed 20400/60000 batches for 0132.
# Processed 20500/60000 batches for 0132.
# Processed 20600/60000 batches for 0132.
# Processed 20700/60000 batches for 0132.
# Processed 20800/60000 batches for 0132.
# Processed 20900/60000 batches for 0132.
# Processed 21000/60000 batches for 0132.
# Processed 21100/60000 batches for 0132.
# Processed 21200/60000 batches for 0132.
# Processed 21300/60000 batches for 0132.
# Processed 21400/60000 batches for 0132.
# Processed 21500/60000 batches for 0132.
# Processed 21600/60000 batches for 0132.
# Processed 21700/60000 batches for 0132.
# Processed 21800/60000 batches for 0132.
# Processed 21900/60000 batches for 0132.
# Processed 22000/60000 batches for 0132.
# Processed 22100/60000 batches for 0132.
# Processed 22200/60000 batches for 0132.
# Processed 22300/60000 batches for 0132.
# Processed 22400/60000 batches for 0132.
# Processed 22500/60000 batches for 0132.
# Processed 22600/60000 batches for 0132.
# Processed 22700/60000 batches for 0132.
# Processed 22800/60000 batches for 0132.
# Processed 22900/60000 batches for 0132.
# Processed 23000/60000 batches for 0132.
# Processed 23100/60000 batches for 0132.
# Processed 23200/60000 batches for 0132.
# Processed 23300/60000 batches for 0132.
# Processed 23400/60000 batches for 0132.
# Processed 23500/60000 batches for 0132.
# Processed 23600/60000 batches for 0132.
# Processed 23700/60000 batches for 0132.
# Processed 23800/60000 batches for 0132.
# Processed 23900/60000 batches for 0132.
# Processed 24000/60000 batches for 0132.
# Processed 24100/60000 batches for 0132.
# Processed 24200/60000 batches for 0132.
# Processed 24300/60000 batches for 0132.
# Processed 24400/60000 batches for 0132.
# Processed 24500/60000 batches for 0132.
# Processed 24600/60000 batches for 0132.
# Processed 24700/60000 batches for 0132.
# Processed 24800/60000 batches for 0132.
# Processed 24900/60000 batches for 0132.
# Processed 25000/60000 batches for 0132.
# Processed 25100/60000 batches for 0132.
# Processed 25200/60000 batches for 0132.
# Processed 25300/60000 batches for 0132.
# Processed 25400/60000 batches for 0132.
# Processed 25500/60000 batches for 0132.
# Processed 25600/60000 batches for 0132.
# Processed 25700/60000 batches for 0132.
# Processed 25800/60000 batches for 0132.
# Processed 25900/60000 batches for 0132.
# Processed 26000/60000 batches for 0132.
# Processed 26100/60000 batches for 0132.
# Processed 26200/60000 batches for 0132.
# Processed 26300/60000 batches for 0132.
# Processed 26400/60000 batches for 0132.
# Processed 26500/60000 batches for 0132.
# Processed 26600/60000 batches for 0132.
# Processed 26700/60000 batches for 0132.
# Processed 26800/60000 batches for 0132.
# Processed 26900/60000 batches for 0132.
# Processed 27000/60000 batches for 0132.
# Processed 27100/60000 batches for 0132.
# Processed 27200/60000 batches for 0132.
# Processed 27300/60000 batches for 0132.
# Processed 27400/60000 batches for 0132.
# Processed 27500/60000 batches for 0132.
# Processed 27600/60000 batches for 0132.
# Processed 27700/60000 batches for 0132.
# Processed 27800/60000 batches for 0132.
# Processed 27900/60000 batches for 0132.
# Processed 28000/60000 batches for 0132.
# Processed 28100/60000 batches for 0132.
# Processed 28200/60000 batches for 0132.
# Processed 28300/60000 batches for 0132.
# Processed 28400/60000 batches for 0132.
# Processed 28500/60000 batches for 0132.
# Processed 28600/60000 batches for 0132.
# Processed 28700/60000 batches for 0132.
# Processed 28800/60000 batches for 0132.
# Processed 28900/60000 batches for 0132.
# Processed 29000/60000 batches for 0132.
# Processed 29100/60000 batches for 0132.
# Processed 29200/60000 batches for 0132.
# Processed 29300/60000 batches for 0132.
# Processed 29400/60000 batches for 0132.
# Processed 29500/60000 batches for 0132.
# Processed 29600/60000 batches for 0132.
# Processed 29700/60000 batches for 0132.
# Processed 29800/60000 batches for 0132.
# Processed 29900/60000 batches for 0132.
# Processed 30000/60000 batches for 0132.
# Processed 30100/60000 batches for 0132.
# Processed 30200/60000 batches for 0132.
# Processed 30300/60000 batches for 0132.
# Processed 30400/60000 batches for 0132.
# Processed 30500/60000 batches for 0132.
# Processed 30600/60000 batches for 0132.
# Processed 30700/60000 batches for 0132.
# Processed 30800/60000 batches for 0132.
# Processed 30900/60000 batches for 0132.
# Processed 31000/60000 batches for 0132.
# Processed 31100/60000 batches for 0132.
# Processed 31200/60000 batches for 0132.
# Processed 31300/60000 batches for 0132.
# Processed 31400/60000 batches for 0132.
# Processed 31500/60000 batches for 0132.
# Processed 31600/60000 batches for 0132.
# Processed 31700/60000 batches for 0132.
# Processed 31800/60000 batches for 0132.
# Processed 31900/60000 batches for 0132.
# Processed 32000/60000 batches for 0132.
# Processed 32100/60000 batches for 0132.
# Processed 32200/60000 batches for 0132.
# Processed 32300/60000 batches for 0132.
# Processed 32400/60000 batches for 0132.
# Processed 32500/60000 batches for 0132.
# Processed 32600/60000 batches for 0132.
# Processed 32700/60000 batches for 0132.
# Processed 32800/60000 batches for 0132.
# Processed 32900/60000 batches for 0132.
# Processed 33000/60000 batches for 0132.
# Processed 33100/60000 batches for 0132.
# Processed 33200/60000 batches for 0132.
# Processed 33300/60000 batches for 0132.
# Processed 33400/60000 batches for 0132.
# Processed 33500/60000 batches for 0132.
# Processed 33600/60000 batches for 0132.
# Processed 33700/60000 batches for 0132.
# Processed 33800/60000 batches for 0132.
# Processed 33900/60000 batches for 0132.
# Processed 34000/60000 batches for 0132.
# Processed 34100/60000 batches for 0132.
# Processed 34200/60000 batches for 0132.
# Processed 34300/60000 batches for 0132.
# Processed 34400/60000 batches for 0132.
# Processed 34500/60000 batches for 0132.
# Processed 34600/60000 batches for 0132.
# Processed 34700/60000 batches for 0132.
# Processed 34800/60000 batches for 0132.
# Processed 34900/60000 batches for 0132.
# Processed 35000/60000 batches for 0132.
# Processed 35100/60000 batches for 0132.
# Processed 35200/60000 batches for 0132.
# Processed 35300/60000 batches for 0132.
# Processed 35400/60000 batches for 0132.
# Processed 35500/60000 batches for 0132.
# Processed 35600/60000 batches for 0132.
# Processed 35700/60000 batches for 0132.
# Processed 35800/60000 batches for 0132.
# Processed 35900/60000 batches for 0132.
# Processed 36000/60000 batches for 0132.
# Processed 36100/60000 batches for 0132.
# Processed 36200/60000 batches for 0132.
# Processed 36300/60000 batches for 0132.
# Processed 36400/60000 batches for 0132.
# Processed 36500/60000 batches for 0132.
# Processed 36600/60000 batches for 0132.
# Processed 36700/60000 batches for 0132.
# Processed 36800/60000 batches for 0132.
# Processed 36900/60000 batches for 0132.
# Processed 37000/60000 batches for 0132.
# Processed 37100/60000 batches for 0132.
# Processed 37200/60000 batches for 0132.
# Processed 37300/60000 batches for 0132.
# Processed 37400/60000 batches for 0132.
# Processed 37500/60000 batches for 0132.
# Processed 37600/60000 batches for 0132.
# Processed 37700/60000 batches for 0132.
# Processed 37800/60000 batches for 0132.
# Processed 37900/60000 batches for 0132.
# Processed 38000/60000 batches for 0132.
# Processed 38100/60000 batches for 0132.
# Processed 38200/60000 batches for 0132.
# Processed 38300/60000 batches for 0132.
# Processed 38400/60000 batches for 0132.
# Processed 38500/60000 batches for 0132.
# Processed 38600/60000 batches for 0132.
# Processed 38700/60000 batches for 0132.
# Processed 38800/60000 batches for 0132.
# Processed 38900/60000 batches for 0132.
# Processed 39000/60000 batches for 0132.
# Processed 39100/60000 batches for 0132.
# Processed 39200/60000 batches for 0132.
# Processed 39300/60000 batches for 0132.
# Processed 39400/60000 batches for 0132.
# Processed 39500/60000 batches for 0132.
# Processed 39600/60000 batches for 0132.
# Processed 39700/60000 batches for 0132.
# Processed 39800/60000 batches for 0132.
# Processed 39900/60000 batches for 0132.
# Processed 40000/60000 batches for 0132.
# Processed 40100/60000 batches for 0132.
# Processed 40200/60000 batches for 0132.
# Processed 40300/60000 batches for 0132.
# Processed 40400/60000 batches for 0132.
# Processed 40500/60000 batches for 0132.
# Processed 40600/60000 batches for 0132.
# Processed 40700/60000 batches for 0132.
# Processed 40800/60000 batches for 0132.
# Processed 40900/60000 batches for 0132.
# Processed 41000/60000 batches for 0132.
# Processed 41100/60000 batches for 0132.
# Processed 41200/60000 batches for 0132.
# Processed 41300/60000 batches for 0132.
# Processed 41400/60000 batches for 0132.
# Processed 41500/60000 batches for 0132.
# Processed 41600/60000 batches for 0132.
# Processed 41700/60000 batches for 0132.
# Processed 41800/60000 batches for 0132.
# Processed 41900/60000 batches for 0132.
# Processed 42000/60000 batches for 0132.
# Processed 42100/60000 batches for 0132.
# Processed 42200/60000 batches for 0132.
# Processed 42300/60000 batches for 0132.
# Processed 42400/60000 batches for 0132.
# Processed 42500/60000 batches for 0132.
# Processed 42600/60000 batches for 0132.
# Processed 42700/60000 batches for 0132.
# Processed 42800/60000 batches for 0132.
# Processed 42900/60000 batches for 0132.
# Processed 43000/60000 batches for 0132.
# Processed 43100/60000 batches for 0132.
# Processed 43200/60000 batches for 0132.
# Processed 43300/60000 batches for 0132.
# Processed 43400/60000 batches for 0132.
# Processed 43500/60000 batches for 0132.
# Processed 43600/60000 batches for 0132.
# Processed 43700/60000 batches for 0132.
# Processed 43800/60000 batches for 0132.
# Processed 43900/60000 batches for 0132.
# Processed 44000/60000 batches for 0132.
# Processed 44100/60000 batches for 0132.
# Processed 44200/60000 batches for 0132.
# Processed 44300/60000 batches for 0132.
# Processed 44400/60000 batches for 0132.
# Processed 44500/60000 batches for 0132.
# Processed 44600/60000 batches for 0132.
# Processed 44700/60000 batches for 0132.
# Processed 44800/60000 batches for 0132.
# Processed 44900/60000 batches for 0132.
# Processed 45000/60000 batches for 0132.
# Processed 45100/60000 batches for 0132.
# Processed 45200/60000 batches for 0132.
# Processed 45300/60000 batches for 0132.
# Processed 45400/60000 batches for 0132.
# Processed 45500/60000 batches for 0132.
# Processed 45600/60000 batches for 0132.
# Processed 45700/60000 batches for 0132.
# Processed 45800/60000 batches for 0132.
# Processed 45900/60000 batches for 0132.
# Processed 46000/60000 batches for 0132.
# Processed 46100/60000 batches for 0132.
# Processed 46200/60000 batches for 0132.
# Processed 46300/60000 batches for 0132.
# Processed 46400/60000 batches for 0132.
# Processed 46500/60000 batches for 0132.
# Processed 46600/60000 batches for 0132.
# Processed 46700/60000 batches for 0132.
# Processed 46800/60000 batches for 0132.
# Processed 46900/60000 batches for 0132.
# Processed 47000/60000 batches for 0132.
# Processed 47100/60000 batches for 0132.
# Processed 47200/60000 batches for 0132.
# Processed 47300/60000 batches for 0132.
# Processed 47400/60000 batches for 0132.
# Processed 47500/60000 batches for 0132.
# Processed 47600/60000 batches for 0132.
# Processed 47700/60000 batches for 0132.
# Processed 47800/60000 batches for 0132.
# Processed 47900/60000 batches for 0132.
# Processed 48000/60000 batches for 0132.
# Processed 48100/60000 batches for 0132.
# Processed 48200/60000 batches for 0132.
# Processed 48300/60000 batches for 0132.
# Processed 48400/60000 batches for 0132.
# Processed 48500/60000 batches for 0132.
# Processed 48600/60000 batches for 0132.
# Processed 48700/60000 batches for 0132.
# Processed 48800/60000 batches for 0132.
# Processed 48900/60000 batches for 0132.
# Processed 49000/60000 batches for 0132.
# Processed 49100/60000 batches for 0132.
# Processed 49200/60000 batches for 0132.
# Processed 49300/60000 batches for 0132.
# Processed 49400/60000 batches for 0132.
# Processed 49500/60000 batches for 0132.
# Processed 49600/60000 batches for 0132.
# Processed 49700/60000 batches for 0132.
# Processed 49800/60000 batches for 0132.
# Processed 49900/60000 batches for 0132.
# Processed 50000/60000 batches for 0132.
# Processed 50100/60000 batches for 0132.
# Processed 50200/60000 batches for 0132.
# Processed 50300/60000 batches for 0132.
# Processed 50400/60000 batches for 0132.
# Processed 50500/60000 batches for 0132.
# Processed 50600/60000 batches for 0132.
# Processed 50700/60000 batches for 0132.
# Processed 50800/60000 batches for 0132.
# Processed 50900/60000 batches for 0132.
# Processed 51000/60000 batches for 0132.
# Processed 51100/60000 batches for 0132.
# Processed 51200/60000 batches for 0132.
# Processed 51300/60000 batches for 0132.
# Processed 51400/60000 batches for 0132.
# Processed 51500/60000 batches for 0132.
# Processed 51600/60000 batches for 0132.
# Processed 51700/60000 batches for 0132.
# Processed 51800/60000 batches for 0132.
# Processed 51900/60000 batches for 0132.
# Processed 52000/60000 batches for 0132.
# Processed 52100/60000 batches for 0132.
# Processed 52200/60000 batches for 0132.
# Processed 52300/60000 batches for 0132.
# Processed 52400/60000 batches for 0132.
# Processed 52500/60000 batches for 0132.
# Processed 52600/60000 batches for 0132.
# Processed 52700/60000 batches for 0132.
# Processed 52800/60000 batches for 0132.
# Processed 52900/60000 batches for 0132.
# Processed 53000/60000 batches for 0132.
# Processed 53100/60000 batches for 0132.
# Processed 53200/60000 batches for 0132.
# Processed 53300/60000 batches for 0132.
# Processed 53400/60000 batches for 0132.
# Processed 53500/60000 batches for 0132.
# Processed 53600/60000 batches for 0132.
# Processed 53700/60000 batches for 0132.
# Processed 53800/60000 batches for 0132.
# Processed 53900/60000 batches for 0132.
# Processed 54000/60000 batches for 0132.
# Processed 54100/60000 batches for 0132.
# Processed 54200/60000 batches for 0132.
# Processed 54300/60000 batches for 0132.
# Processed 54400/60000 batches for 0132.
# Processed 54500/60000 batches for 0132.
# Processed 54600/60000 batches for 0132.
# Processed 54700/60000 batches for 0132.
# Processed 54800/60000 batches for 0132.
# Processed 54900/60000 batches for 0132.
# Processed 55000/60000 batches for 0132.
# Processed 55100/60000 batches for 0132.
# Processed 55200/60000 batches for 0132.
# Processed 55300/60000 batches for 0132.
# Processed 55400/60000 batches for 0132.
# Processed 55500/60000 batches for 0132.
# Processed 55600/60000 batches for 0132.
# Processed 55700/60000 batches for 0132.
# Processed 55800/60000 batches for 0132.
# Processed 55900/60000 batches for 0132.
# Processed 56000/60000 batches for 0132.
# Processed 56100/60000 batches for 0132.
# Processed 56200/60000 batches for 0132.
# Processed 56300/60000 batches for 0132.
# Processed 56400/60000 batches for 0132.
# Processed 56500/60000 batches for 0132.
# Processed 56600/60000 batches for 0132.
# Processed 56700/60000 batches for 0132.
# Processed 56800/60000 batches for 0132.
# Processed 56900/60000 batches for 0132.
# Processed 57000/60000 batches for 0132.
# Processed 57100/60000 batches for 0132.
# Processed 57200/60000 batches for 0132.
# Processed 57300/60000 batches for 0132.
# Processed 57400/60000 batches for 0132.
# Processed 57500/60000 batches for 0132.
# Processed 57600/60000 batches for 0132.
# Processed 57700/60000 batches for 0132.
# Processed 57800/60000 batches for 0132.
# ...
# Processed 22900/60000 batches for 2013.
# Processed 23000/60000 batches for 2013.
# Processed 23100/60000 batches for 2013.
# Processed 23200/60000 batches for 2013.
# Processed 23300/60000 batches for 2013.
# Processed 23400/60000 batches for 2013.
# Processed 23500/60000 batches for 2013.
# Processed 23600/60000 batches for 2013.
# Processed 23700/60000 batches for 2013.
# Processed 23800/60000 batches for 2013.
# Processed 23900/60000 batches for 2013.
# Processed 24000/60000 batches for 2013.
# Processed 24100/60000 batches for 2013.
# Processed 24200/60000 batches for 2013.
# Processed 24300/60000 batches for 2013.
# Processed 24400/60000 batches for 2013.
# Processed 24500/60000 batches for 2013.
# Processed 24600/60000 batches for 2013.
# Processed 24700/60000 batches for 2013.
# Processed 24800/60000 batches for 2013.
# Processed 24900/60000 batches for 2013.
# Processed 25000/60000 batches for 2013.
# Processed 25100/60000 batches for 2013.
# Processed 25200/60000 batches for 2013.
# Processed 25300/60000 batches for 2013.
# Processed 25400/60000 batches for 2013.
# Processed 25500/60000 batches for 2013.
# Processed 25600/60000 batches for 2013.
# Processed 25700/60000 batches for 2013.
# Processed 25800/60000 batches for 2013.
# Processed 25900/60000 batches for 2013.
# Processed 26000/60000 batches for 2013.
# Processed 26100/60000 batches for 2013.
# Processed 26200/60000 batches for 2013.
# Processed 26300/60000 batches for 2013.
# Processed 26400/60000 batches for 2013.
# Processed 26500/60000 batches for 2013.
# Processed 26600/60000 batches for 2013.
# Processed 26700/60000 batches for 2013.
# Processed 26800/60000 batches for 2013.
# Processed 26900/60000 batches for 2013.
# Processed 27000/60000 batches for 2013.
# Processed 27100/60000 batches for 2013.
# Processed 27200/60000 batches for 2013.
# Processed 27300/60000 batches for 2013.
# Processed 27400/60000 batches for 2013.
# Processed 27500/60000 batches for 2013.
# Processed 27600/60000 batches for 2013.
# Processed 27700/60000 batches for 2013.
# Processed 27800/60000 batches for 2013.
# Processed 27900/60000 batches for 2013.
# Processed 28000/60000 batches for 2013.
# Processed 28100/60000 batches for 2013.
# Processed 28200/60000 batches for 2013.
# Processed 28300/60000 batches for 2013.
# Processed 28400/60000 batches for 2013.
# Processed 28500/60000 batches for 2013.
# Processed 28600/60000 batches for 2013.
# Processed 28700/60000 batches for 2013.
# Processed 28800/60000 batches for 2013.
# Processed 28900/60000 batches for 2013.
# Processed 29000/60000 batches for 2013.
# Processed 29100/60000 batches for 2013.
# Processed 29200/60000 batches for 2013.
# Processed 29300/60000 batches for 2013.
# Processed 29400/60000 batches for 2013.
# Processed 29500/60000 batches for 2013.
# Processed 29600/60000 batches for 2013.
# Processed 29700/60000 batches for 2013.
# Processed 29800/60000 batches for 2013.
# Processed 29900/60000 batches for 2013.
# Processed 30000/60000 batches for 2013.
# Processed 30100/60000 batches for 2013.
# Processed 30200/60000 batches for 2013.
# Processed 30300/60000 batches for 2013.
# Processed 30400/60000 batches for 2013.
# Processed 30500/60000 batches for 2013.
# Processed 30600/60000 batches for 2013.
# Processed 30700/60000 batches for 2013.
# Processed 30800/60000 batches for 2013.
# Processed 30900/60000 batches for 2013.
# Processed 31000/60000 batches for 2013.
# Processed 31100/60000 batches for 2013.
# Processed 31200/60000 batches for 2013.
# Processed 31300/60000 batches for 2013.
# Processed 31400/60000 batches for 2013.
# Processed 31500/60000 batches for 2013.
# Processed 31600/60000 batches for 2013.
# Processed 31700/60000 batches for 2013.
# Processed 31800/60000 batches for 2013.
# Processed 31900/60000 batches for 2013.
# Processed 32000/60000 batches for 2013.
# Processed 32100/60000 batches for 2013.
# Processed 32200/60000 batches for 2013.
# Processed 32300/60000 batches for 2013.
# Processed 32400/60000 batches for 2013.
# Processed 32500/60000 batches for 2013.
# Processed 32600/60000 batches for 2013.
# Processed 32700/60000 batches for 2013.
# Processed 32800/60000 batches for 2013.
# Processed 32900/60000 batches for 2013.
# Processed 33000/60000 batches for 2013.
# Processed 33100/60000 batches for 2013.
# Processed 33200/60000 batches for 2013.
# Processed 33300/60000 batches for 2013.
# Processed 33400/60000 batches for 2013.
# Processed 33500/60000 batches for 2013.
# Processed 33600/60000 batches for 2013.
# Processed 33700/60000 batches for 2013.
# Processed 33800/60000 batches for 2013.
# Processed 33900/60000 batches for 2013.
# Processed 34000/60000 batches for 2013.
# Processed 34100/60000 batches for 2013.
# Processed 34200/60000 batches for 2013.
# Processed 34300/60000 batches for 2013.
# Processed 34400/60000 batches for 2013.
# Processed 34500/60000 batches for 2013.
# Processed 34600/60000 batches for 2013.
# Processed 34700/60000 batches for 2013.
# Processed 34800/60000 batches for 2013.
# Processed 34900/60000 batches for 2013.
# Processed 35000/60000 batches for 2013.
# Processed 35100/60000 batches for 2013.
# Processed 35200/60000 batches for 2013.
# Processed 35300/60000 batches for 2013.
# Processed 35400/60000 batches for 2013.
# Processed 35500/60000 batches for 2013.
# Processed 35600/60000 batches for 2013.
# Processed 35700/60000 batches for 2013.
# Processed 35800/60000 batches for 2013.
# Processed 35900/60000 batches for 2013.
# Processed 36000/60000 batches for 2013.
# Processed 36100/60000 batches for 2013.
# Processed 36200/60000 batches for 2013.
# Processed 36300/60000 batches for 2013.
# Processed 36400/60000 batches for 2013.
# Processed 36500/60000 batches for 2013.
# Processed 36600/60000 batches for 2013.
# Processed 36700/60000 batches for 2013.
# Processed 36800/60000 batches for 2013.
# Processed 36900/60000 batches for 2013.
# Processed 37000/60000 batches for 2013.
# Processed 37100/60000 batches for 2013.
# Processed 37200/60000 batches for 2013.
# Processed 37300/60000 batches for 2013.
# Processed 37400/60000 batches for 2013.
# Processed 37500/60000 batches for 2013.
# Processed 37600/60000 batches for 2013.
# Processed 37700/60000 batches for 2013.
# Processed 37800/60000 batches for 2013.
# Processed 37900/60000 batches for 2013.
# Processed 38000/60000 batches for 2013.
# Processed 38100/60000 batches for 2013.
# Processed 38200/60000 batches for 2013.
# Processed 38300/60000 batches for 2013.
# Processed 38400/60000 batches for 2013.
# Processed 38500/60000 batches for 2013.
# Processed 38600/60000 batches for 2013.
# Processed 38700/60000 batches for 2013.
# Processed 38800/60000 batches for 2013.
# Processed 38900/60000 batches for 2013.
# Processed 39000/60000 batches for 2013.
# Processed 39100/60000 batches for 2013.
# Processed 39200/60000 batches for 2013.
# Processed 39300/60000 batches for 2013.
# Processed 39400/60000 batches for 2013.
# Processed 39500/60000 batches for 2013.
# Processed 39600/60000 batches for 2013.
# Processed 39700/60000 batches for 2013.
# Processed 39800/60000 batches for 2013.
# Processed 39900/60000 batches for 2013.
# Processed 40000/60000 batches for 2013.
# Processed 40100/60000 batches for 2013.
# Processed 40200/60000 batches for 2013.
# Processed 40300/60000 batches for 2013.
# Processed 40400/60000 batches for 2013.
# Processed 40500/60000 batches for 2013.
# Processed 40600/60000 batches for 2013.
# Processed 40700/60000 batches for 2013.
# Processed 40800/60000 batches for 2013.
# Processed 40900/60000 batches for 2013.
# Processed 41000/60000 batches for 2013.
# Processed 41100/60000 batches for 2013.
# Processed 41200/60000 batches for 2013.
# Processed 41300/60000 batches for 2013.
# Processed 41400/60000 batches for 2013.
# Processed 41500/60000 batches for 2013.
# Processed 41600/60000 batches for 2013.
# Processed 41700/60000 batches for 2013.
# Processed 41800/60000 batches for 2013.
# Processed 41900/60000 batches for 2013.
# Processed 42000/60000 batches for 2013.
# Processed 42100/60000 batches for 2013.
# Processed 42200/60000 batches for 2013.
# Processed 42300/60000 batches for 2013.
# Processed 42400/60000 batches for 2013.
# Processed 42500/60000 batches for 2013.
# Processed 42600/60000 batches for 2013.
# Processed 42700/60000 batches for 2013.
# Processed 42800/60000 batches for 2013.
# Processed 42900/60000 batches for 2013.
# Processed 43000/60000 batches for 2013.
# Processed 43100/60000 batches for 2013.
# Processed 43200/60000 batches for 2013.
# Processed 43300/60000 batches for 2013.
# Processed 43400/60000 batches for 2013.
# Processed 43500/60000 batches for 2013.
# Processed 43600/60000 batches for 2013.
# Processed 43700/60000 batches for 2013.
# Processed 43800/60000 batches for 2013.
# Processed 43900/60000 batches for 2013.
# Processed 44000/60000 batches for 2013.
# Processed 44100/60000 batches for 2013.
# Processed 44200/60000 batches for 2013.
# Processed 44300/60000 batches for 2013.
# Processed 44400/60000 batches for 2013.
# Processed 44500/60000 batches for 2013.
# Processed 44600/60000 batches for 2013.
# Processed 44700/60000 batches for 2013.
# Processed 44800/60000 batches for 2013.
# Processed 44900/60000 batches for 2013.
# Processed 45000/60000 batches for 2013.
# Processed 45100/60000 batches for 2013.
# Processed 45200/60000 batches for 2013.
# Processed 45300/60000 batches for 2013.
# Processed 45400/60000 batches for 2013.
# Processed 45500/60000 batches for 2013.
# Processed 45600/60000 batches for 2013.
# Processed 45700/60000 batches for 2013.
# Processed 45800/60000 batches for 2013.
# Processed 45900/60000 batches for 2013.
# Processed 46000/60000 batches for 2013.
# Processed 46100/60000 batches for 2013.
# Processed 46200/60000 batches for 2013.
# Processed 46300/60000 batches for 2013.
# Processed 46400/60000 batches for 2013.
# Processed 46500/60000 batches for 2013.
# Processed 46600/60000 batches for 2013.
# Processed 46700/60000 batches for 2013.
# Processed 46800/60000 batches for 2013.
# Processed 46900/60000 batches for 2013.
# Processed 47000/60000 batches for 2013.
# Processed 47100/60000 batches for 2013.
# Processed 47200/60000 batches for 2013.
# Processed 47300/60000 batches for 2013.
# Processed 47400/60000 batches for 2013.
# Processed 47500/60000 batches for 2013.
# Processed 47600/60000 batches for 2013.
# Processed 47700/60000 batches for 2013.
# Processed 47800/60000 batches for 2013.
# Processed 47900/60000 batches for 2013.
# Processed 48000/60000 batches for 2013.
# Processed 48100/60000 batches for 2013.
# Processed 48200/60000 batches for 2013.
# Processed 48300/60000 batches for 2013.
# Processed 48400/60000 batches for 2013.
# Processed 48500/60000 batches for 2013.
# Processed 48600/60000 batches for 2013.
# Processed 48700/60000 batches for 2013.
# Processed 48800/60000 batches for 2013.
# Processed 48900/60000 batches for 2013.
# Processed 49000/60000 batches for 2013.
# Processed 49100/60000 batches for 2013.
# Processed 49200/60000 batches for 2013.
# Processed 49300/60000 batches for 2013.
# Processed 49400/60000 batches for 2013.
# Processed 49500/60000 batches for 2013.
# Processed 49600/60000 batches for 2013.
# Processed 49700/60000 batches for 2013.
# Processed 49800/60000 batches for 2013.
# Processed 49900/60000 batches for 2013.
# Processed 50000/60000 batches for 2013.
# Processed 50100/60000 batches for 2013.
# Processed 50200/60000 batches for 2013.
# Processed 50300/60000 batches for 2013.
# Processed 50400/60000 batches for 2013.
# Processed 50500/60000 batches for 2013.
# Processed 50600/60000 batches for 2013.
# Processed 50700/60000 batches for 2013.
# Processed 50800/60000 batches for 2013.
# Processed 50900/60000 batches for 2013.
# Processed 51000/60000 batches for 2013.
# Processed 51100/60000 batches for 2013.
# Processed 51200/60000 batches for 2013.
# Processed 51300/60000 batches for 2013.
# Processed 51400/60000 batches for 2013.
# Processed 51500/60000 batches for 2013.
# Processed 51600/60000 batches for 2013.
# Processed 51700/60000 batches for 2013.
# Processed 51800/60000 batches for 2013.
# Processed 51900/60000 batches for 2013.
# Processed 52000/60000 batches for 2013.
# Processed 52100/60000 batches for 2013.
# Processed 52200/60000 batches for 2013.
# Processed 52300/60000 batches for 2013.
# Processed 52400/60000 batches for 2013.
# Processed 52500/60000 batches for 2013.
# Processed 52600/60000 batches for 2013.
# Processed 52700/60000 batches for 2013.
# Processed 52800/60000 batches for 2013.
# Processed 52900/60000 batches for 2013.
# Processed 53000/60000 batches for 2013.
# Processed 53100/60000 batches for 2013.
# Processed 53200/60000 batches for 2013.
# Processed 53300/60000 batches for 2013.
# Processed 53400/60000 batches for 2013.
# Processed 53500/60000 batches for 2013.
# Processed 53600/60000 batches for 2013.
# Processed 53700/60000 batches for 2013.
# Processed 53800/60000 batches for 2013.
# Processed 53900/60000 batches for 2013.
# Processed 54000/60000 batches for 2013.
# Processed 54100/60000 batches for 2013.
# Processed 54200/60000 batches for 2013.
# Processed 54300/60000 batches for 2013.
# Processed 54400/60000 batches for 2013.
# Processed 54500/60000 batches for 2013.
# Processed 54600/60000 batches for 2013.
# Processed 54700/60000 batches for 2013.
# Processed 54800/60000 batches for 2013.
# Processed 54900/60000 batches for 2013.
# Processed 55000/60000 batches for 2013.
# Processed 55100/60000 batches for 2013.
# Processed 55200/60000 batches for 2013.
# Processed 55300/60000 batches for 2013.
# Processed 55400/60000 batches for 2013.
# Processed 55500/60000 batches for 2013.
# Processed 55600/60000 batches for 2013.
# Processed 55700/60000 batches for 2013.
# Processed 55800/60000 batches for 2013.
# Processed 55900/60000 batches for 2013.
# Processed 56000/60000 batches for 2013.
# Processed 56100/60000 batches for 2013.
# Processed 56200/60000 batches for 2013.
# Processed 56300/60000 batches for 2013.
# Processed 56400/60000 batches for 2013.
# Processed 56500/60000 batches for 2013.
# Processed 56600/60000 batches for 2013.
# Processed 56700/60000 batches for 2013.
# Processed 56800/60000 batches for 2013.
# Processed 56900/60000 batches for 2013.
# Processed 57000/60000 batches for 2013.
# Processed 57100/60000 batches for 2013.
# Processed 57200/60000 batches for 2013.
# Processed 57300/60000 batches for 2013.
# Processed 57400/60000 batches for 2013.
# Processed 57500/60000 batches for 2013.
# Processed 57600/60000 batches for 2013.
# Processed 57700/60000 batches for 2013.
# Processed 57800/60000 batches for 2013.
# Processed 57900/60000 batches for 2013.
# Processed 58000/60000 batches for 2013.
# Processed 58100/60000 batches for 2013.
# Processed 58200/60000 batches for 2013.
# Processed 58300/60000 batches for 2013.
# Processed 58400/60000 batches for 2013.
# Processed 58500/60000 batches for 2013.
# Processed 58600/60000 batches for 2013.
# Processed 58700/60000 batches for 2013.
# Processed 58800/60000 batches for 2013.
# Processed 58900/60000 batches for 2013.
# Processed 59000/60000 batches for 2013.
# Processed 59100/60000 batches for 2013.
# Processed 59200/60000 batches for 2013.
# Processed 59300/60000 batches for 2013.
# Processed 59400/60000 batches for 2013.
# Processed 59500/60000 batches for 2013.
# Processed 59600/60000 batches for 2013.
# Processed 59700/60000 batches for 2013.
# Processed 59800/60000 batches for 2013.
# Processed 59900/60000 batches for 2013.
# Processed 60000/60000 batches for 2013.
# Created/Ensured directory: _OA_results_FashionMnist_train_with_val/2013/Entropy
# Saved Total_Avg_2013_Entropy_S1.csv to _OA_results_FashionMnist_train_with_val/2013/Entropy
# Saved Total_Avg_2013_Entropy_S2.csv to _OA_results_FashionMnist_train_with_val/2013/Entropy
# Saved Total_Max_2013_Entropy_S1.csv to _OA_results_FashionMnist_train_with_val/2013/Entropy
# Saved Total_Max_2013_Entropy_S2.csv to _OA_results_FashionMnist_train_with_val/2013/Entropy
# Saved S1_rho_0_2013_Entropy_S1_0.csv to _OA_results_FashionMnist_train_with_val/2013/Entropy
# Saved S1_rho_1_2013_Entropy_S1_1.csv to _OA_results_FashionMnist_train_with_val/2013/Entropy
# Saved S2_rho_0_2013_Entropy_S2_0.csv to _OA_results_FashionMnist_train_with_val/2013/Entropy
# Saved S2_rho_1_2013_Entropy_S2_1.csv to _OA_results_FashionMnist_train_with_val/2013/Entropy
# Saved Total_Avg_2013_Entropy_S1_S2.csv to _OA_results_FashionMnist_train_with_val/2013/Entropy
# Saved Total_Max_2013_Entropy_S1_S2.csv to _OA_results_FashionMnist_train_with_val/2013/Entropy
# Finished parallel computation for data for config 2013 in 61.45 seconds.

# %% [markdown]
# We will focus only in the best 3 configs.

# %%
def open_load_entropy(symmetry, system, dataset_name="FashionMnist"):
    
    system = str(system)
    file_path = f"/workspaces/QML-QPF/Entanglement_Filtering/Fashion_Mnist/_OA_results_{dataset_name}_train_with_val/{symmetry}/Entropy/S{system}_rho_0_{symmetry}_Entropy_S{system}_0.csv"
    S_rho0 = np.loadtxt(file_path, delimiter=',')
    return S_rho0

# %% [markdown]
# ## Entanglement pooling and saving

# %%
import joblib
import gc

def Entanglement_pooling(input, sample_size, threshold, S1_rho0, S2_rho0,Entanglement_pooled_file_name):
    """
    Function that will filter the output of the quantum circuit based on a threshold e.g. the mean of the entier dataset
    
    """
    # sample_size = reshaped_filtered_input.shape[0]  # number of images
    Entanglement_pooled_sample = list()
    # threshold = 0.106 # The mean of the entire dataset--will update it accordingly
    for i in range(sample_size):
        Entanglement_pooled_img = list()
        for j in range(S1_rho0.shape[-1]):
            #
            tmp_list = list()
            # Checking for S1
            if S1_rho0[i,j] < threshold: # keeping both qubits
                tmp_list.extend(input[i,j,:2]) 
            else: # Keeping only target qubit
                tmp_list.append(input[i,j,1])
                
            # Checking for S2
            if S2_rho0[i,j] < threshold: # keeping both qubits
                tmp_list.extend(input[i,j,2:]) 
            else: # Keeping only target qubit
                tmp_list.append(input[i,j,-1])
            # appending the pooled filtered input to the image
            Entanglement_pooled_img.append(tmp_list)
        # appending the pooled filtered image to the sample
        Entanglement_pooled_sample.append(Entanglement_pooled_img)
        
    joblib.dump(Entanglement_pooled_sample, f'{Entanglement_pooled_file_name}.joblib', compress=3)

    # free memory so the notebook stays fast
    del Entanglement_pooled_sample
    gc.collect()

# %% [markdown]
# ### Entanglement pooling the best 3 symmetries from previous experiment

# %%
for _, value in D.items():
    for _, config in value.items():
        # print(symmetry)
        # filtered_input = train_layer.open(config)
        # reshaped_filtered_input = train_layer.transform(filtered_input)
        
        # input with specific symmetry/config to filter based on entropy level
        filtered_input = train_layer.open(config)
        filtered_input = train_layer.transform(filtered_input)
        
        symmetry = ''.join(map(str,config))
        #S1_rho_0_0321_Entropy_S1 : S1_rho_0 = system 1;Entropy_S1 = qubit 1
        S1_rho0 = open_load_entropy(symmetry, 1)
        S2_rho0 = open_load_entropy(symmetry, 2)
        
        # File namne to store the pooled sample
        Entanglement_pooled_file_name = f"{train_layer.name}/{symmetry}/Entanglement_pooled_{_[2:-7]}_{''.join(map(str,symmetry))}"  
        
        # print(Entanglement_pooled_file_name)
        threshold = np.average(np.average(S1_rho0+S2_rho0, axis=1))
        print(threshold)
        
        # Entanglement filtering
        Entanglement_pooling(input=filtered_input, S1_rho0=S1_rho0, S2_rho0= S2_rho0,threshold=threshold,\
                            sample_size=filtered_input.shape[0],\
                            Entanglement_pooled_file_name=Entanglement_pooled_file_name    )
# Out:
# 0.2882170583814558
# 0.2513782801913308
# 0.26470720128158165

# %% [markdown]
# ## Trainign model

# %% [markdown]
# ### Row-Level Padding

# %%
import numpy as np

def pad_jagged_image(image_list, max_c=4):
    # Create a fixed-size buffer of zeros
    padded_img = np.zeros((len(image_list), max_c))
    
    for i, row in enumerate(image_list):
        # row is a 1D array of length 2, 3, or 4
        length = len(row)
        padded_img[i, :length] = row
        
    return padded_img

# %%
from keras.callbacks import CSVLogger, EarlyStopping, ModelCheckpoint, ReduceLROnPlateau



def run(tr_images, label,  run_subfolder, folder_name, patience=15):
    log_dir = train_layer.name + f"/{label}" + f"/{folder_name}/run{run_subfolder}/"   
    # print(' log_dir ', log_dir)
    
    log_file =  log_dir + f"{folder_name}_{label}"
    # print(' log_file ', log_file)
    os.makedirs(log_dir, exist_ok=True)
    
    csv_logger = CSVLogger(log_file)
    
    
    # tensorboard_callback = keras.callbacks.TensorBoard(
    #     log_dir=log_file,
    #     histogram_freq=1,
    #     write_graph=True,
    #     write_images=True,
    #     write_steps_per_second=True,
    #     update_freq='batch',
    #     profile_batch=1,
    #     embeddings_freq=1,
    #     embeddings_metadata=None
    # )
    
    number_of_classes = len(np.unique(test_labels))
    # Chose which model you want to use depending on the number of hidden layers
    # Uncomment your model and run the code--pay attention to your folder/file naming to keep everything organized 
    ####---------------------------------------------------------------------####
    # 1 FC layer
    if run_subfolder == "_1FC":
        # simple ANN model with 0 hidden layers: 1FC
        q_model = keras.models.Sequential([
            keras.layers.Rescaling(scale=-1. / 127.5, offset=1),
            keras.layers.Flatten(),
            keras.layers.Dense(number_of_classes, activation="softmax")
        ])
    
    ####---------------------------------------------------------------------####
    
    # # 2 FC layer
    if run_subfolder == "_2FC":
    
        # simple ANN model with 1 hidden layers: 2FC
        q_model = keras.models.Sequential([
            keras.layers.Rescaling(scale=-1. / 127.5, offset=1),
            keras.layers.Flatten(),
            keras.layers.Dense(512, activation='relu'),
            keras.layers.Dense(number_of_classes, activation="softmax")
        ])
    
    ####---------------------------------------------------------------------####
    # # 3 FC layer
    if run_subfolder == "_3FC":
    
        # simple ANN model with 2 hidden layers: 3FC
        q_model = keras.models.Sequential([
            keras.layers.Rescaling(scale=-1. / 127.5, offset=1),
            keras.layers.Flatten(),
            keras.layers.Dense(512, activation='relu'),
            keras.layers.Dense(256, activation='relu'),
            keras.layers.Dense(number_of_classes, activation='softmax')
        ])
    
    ####---------------------------------------------------------------------####
    # # 4 FC layer
    if run_subfolder == "_4FC": 
        # simple ANN model with 3 hidden layers: 4FC
        q_model = keras.models.Sequential([
            keras.layers.Rescaling(scale=-1. / 127.5, offset=1),
            keras.layers.Flatten(),
            keras.layers.Dense(512, activation='relu'),
            keras.layers.Dense(256, activation='relu'),
            keras.layers.Dense(128, activation='relu'),
            keras.layers.Dense(number_of_classes, activation='softmax')
        ])
    
    ####---------------------------------------------------------------------####
    
    q_model.compile(
        optimizer='adam',
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    
    # 
    batch_size = 128
    epochs = 60
    
    
    # Stop training when a monitored metric has stopped improving.
    Early_stop = EarlyStopping(monitor="val_accuracy",
                                min_delta=0, # Minimum change in the monitored quantity to qualify as an improvement, i.e. an absolute change of less than min_delta, will count as no improvement.
                                patience=patience, # Number of epochs with no improvement after which training will be stopped.
                                verbose=1, # 1 displays messages when the callback takes an action
                                mode="max", # will stop when the quantity monitored has stopped increasing
                                baseline=None,
                                restore_best_weights=True, # to restore model weights from the epoch with the best value of the monitored quantity
                                start_from_epoch=0, #  Number of epochs to wait before starting to monitor improvement.
                            )

    
    # Callback to save the Keras model or model weights at some frequency.
    checkpoint_filepath = log_file  + 'model.keras'
    model_checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath,
                                                monitor='val_accuracy',
                                                mode='max',
                                                verbose=1,
                                                save_best_only=True
                                                )
    # Reduce learning rate when a metric has stopped improving.
    reduce_lr_acc = ReduceLROnPlateau(monitor='val_accuracy',
                                        factor=0.1, # Float. Factor by which the learning rate will be reduced. new_lr = lr * factor.
                                        patience=10, # Integer. Number of epochs with no improvement after which learning rate will be reduced.
                                        verbose=1, # 1: update messages.
                                        mode="max", # 'max' mode it will be reduced when the quantity monitored has stopped increasing
                                        min_delta=0.0001, # Float. Threshold for measuring the new optimum, to only focus on significant changes.
                                        cooldown=0, #  Integer. Number of epochs to wait before resuming normal operation after the learning rate has been reduced.
                                        min_lr=0.0 #  Float. Lower bound on the learning rate.
                                    )


    
    q_history = q_model.fit(
        tr_images,
        train_labels,
        # validation_data=(te_images, test_labels),
        validation_split=0.2,
        batch_size=batch_size,
        epochs=epochs,
        verbose=2,
        # callbacks=[tensorboard_callback]
        callbacks = [Early_stop,csv_logger,model_checkpoint_callback, reduce_lr_acc]
    )

def model(variant, tr_layer):
    tr_images = Ent_pooled_data_padded_0s_array
    
    
    label = ''.join(map(str,Diagonal))


    run(tr_images, label)

# %%
run_subfolders = [f"_{str(i+1)}FC" for i in range(4)]

for _, value in D.items():
    for _, config in value.items():
        # print(symmetry)
        symmetry = ''.join(map(str,config))
        # File namne to store the pooled sample
        Entanglement_pooled_file_name = f"{train_layer.name}/{symmetry}/Entanglement_pooled_{_[2:-7]}_{symmetry}" 
        # Too long to load: almost 5mins => think of other way probably to save and laod
        Entanglement_pooled_sample = joblib.load(f'{Entanglement_pooled_file_name}.joblib') 
        approachs = ["Padding_0", "Entanglement_pool_summed", "No_Entanglement_pool_summed_avg"]
        for approach in approachs:
            # Padding with 0s
            if approach == "Padding_0":
                
                train_data = np.array([pad_jagged_image(image) for image in Entanglement_pooled_sample])
                # name of the folder for padded data
                folder_name = "Entanglement_pool_padded_0s"
            # Summing the entanglement pooled data
            if approach == "Entanglement_pool_summed":
                train_data = np.array([[sum(p)/len(p) for p in img] for img in Entanglement_pooled_sample])
                # name of the folder for padded data
                folder_name =  "Entanglement_pool_summed"
            
            if approach == "No_Entanglement_pool_summed_avg":
                train_data = train_layer.open(config)
                train_data = train_data.mean(axis=-1)    # shape: (N, H, W)
                # name 
                folder_name =  "No_Entanglement_pool_summed_avg"
                
            for run_subfolder in run_subfolders:
                run(tr_images=train_data, label=symmetry,\
                    run_subfolder=run_subfolder, folder_name=folder_name)
# Out:
# Epoch 1/60
#
# Epoch 1: val_accuracy improved from -inf to 0.80650, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_1FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 2s - loss: 0.7464 - accuracy: 0.7414 - val_loss: 0.5536 - val_accuracy: 0.8065 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 2/60
#
# Epoch 2: val_accuracy improved from 0.80650 to 0.82358, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_1FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 1s - loss: 0.5066 - accuracy: 0.8247 - val_loss: 0.4956 - val_accuracy: 0.8236 - lr: 0.0010 - 1s/epoch - 3ms/step
# Epoch 3/60
#
# Epoch 3: val_accuracy improved from 0.82358 to 0.82992, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_1FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 1s - loss: 0.4650 - accuracy: 0.8379 - val_loss: 0.4778 - val_accuracy: 0.8299 - lr: 0.0010 - 1s/epoch - 3ms/step
# Epoch 4/60
#
# Epoch 4: val_accuracy did not improve from 0.82992
# 375/375 - 1s - loss: 0.4437 - accuracy: 0.8443 - val_loss: 0.4801 - val_accuracy: 0.8253 - lr: 0.0010 - 1s/epoch - 3ms/step
# Epoch 5/60
#
# Epoch 5: val_accuracy improved from 0.82992 to 0.83450, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_1FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 1s - loss: 0.4302 - accuracy: 0.8486 - val_loss: 0.4562 - val_accuracy: 0.8345 - lr: 0.0010 - 1s/epoch - 3ms/step
# Epoch 6/60
#
# Epoch 6: val_accuracy did not improve from 0.83450
# 375/375 - 1s - loss: 0.4210 - accuracy: 0.8523 - val_loss: 0.4557 - val_accuracy: 0.8333 - lr: 0.0010 - 1s/epoch - 3ms/step
# Epoch 7/60
#
# Epoch 7: val_accuracy improved from 0.83450 to 0.83558, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_1FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 1s - loss: 0.4133 - accuracy: 0.8549 - val_loss: 0.4542 - val_accuracy: 0.8356 - lr: 0.0010 - 1s/epoch - 3ms/step
# Epoch 8/60
#
# Epoch 8: val_accuracy did not improve from 0.83558
# 375/375 - 1s - loss: 0.4071 - accuracy: 0.8570 - val_loss: 0.4557 - val_accuracy: 0.8338 - lr: 0.0010 - 1s/epoch - 3ms/step
# Epoch 9/60
#
# Epoch 9: val_accuracy did not improve from 0.83558
# 375/375 - 1s - loss: 0.4037 - accuracy: 0.8578 - val_loss: 0.4574 - val_accuracy: 0.8349 - lr: 0.0010 - 891ms/epoch - 2ms/step
# Epoch 10/60
#
# Epoch 10: val_accuracy improved from 0.83558 to 0.83892, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_1FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 1s - loss: 0.4002 - accuracy: 0.8593 - val_loss: 0.4498 - val_accuracy: 0.8389 - lr: 0.0010 - 1s/epoch - 3ms/step
# Epoch 11/60
#
# Epoch 11: val_accuracy did not improve from 0.83892
# 375/375 - 1s - loss: 0.3952 - accuracy: 0.8607 - val_loss: 0.4521 - val_accuracy: 0.8382 - lr: 0.0010 - 1s/epoch - 3ms/step
# Epoch 12/60
#
# Epoch 12: val_accuracy did not improve from 0.83892
# 375/375 - 1s - loss: 0.3939 - accuracy: 0.8605 - val_loss: 0.4616 - val_accuracy: 0.8338 - lr: 0.0010 - 1s/epoch - 3ms/step
# Epoch 13/60
#
# Epoch 13: val_accuracy improved from 0.83892 to 0.84000, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_1FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 1s - loss: 0.3904 - accuracy: 0.8614 - val_loss: 0.4506 - val_accuracy: 0.8400 - lr: 0.0010 - 1s/epoch - 3ms/step
# Epoch 14/60
#
# Epoch 14: val_accuracy did not improve from 0.84000
# 375/375 - 1s - loss: 0.3865 - accuracy: 0.8643 - val_loss: 0.4677 - val_accuracy: 0.8306 - lr: 0.0010 - 1s/epoch - 3ms/step
# Epoch 15/60
#
# Epoch 15: val_accuracy did not improve from 0.84000
# 375/375 - 1s - loss: 0.3863 - accuracy: 0.8630 - val_loss: 0.4519 - val_accuracy: 0.8371 - lr: 0.0010 - 1s/epoch - 3ms/step
# Epoch 16/60
#
# Epoch 16: val_accuracy did not improve from 0.84000
# 375/375 - 1s - loss: 0.3837 - accuracy: 0.8644 - val_loss: 0.4518 - val_accuracy: 0.8364 - lr: 0.0010 - 906ms/epoch - 2ms/step
# Epoch 17/60
#
# Epoch 17: val_accuracy did not improve from 0.84000
# 375/375 - 1s - loss: 0.3817 - accuracy: 0.8640 - val_loss: 0.4568 - val_accuracy: 0.8398 - lr: 0.0010 - 1s/epoch - 3ms/step
# Epoch 18/60
#
# Epoch 18: val_accuracy did not improve from 0.84000
# 375/375 - 1s - loss: 0.3831 - accuracy: 0.8647 - val_loss: 0.4486 - val_accuracy: 0.8391 - lr: 0.0010 - 1s/epoch - 3ms/step
# Epoch 19/60
#
# Epoch 19: val_accuracy did not improve from 0.84000
# 375/375 - 1s - loss: 0.3798 - accuracy: 0.8646 - val_loss: 0.4538 - val_accuracy: 0.8377 - lr: 0.0010 - 1s/epoch - 3ms/step
# Epoch 20/60
#
# Epoch 20: val_accuracy did not improve from 0.84000
# 375/375 - 1s - loss: 0.3775 - accuracy: 0.8661 - val_loss: 0.4598 - val_accuracy: 0.8339 - lr: 0.0010 - 1s/epoch - 3ms/step
# Epoch 21/60
#
# Epoch 21: val_accuracy did not improve from 0.84000
# 375/375 - 1s - loss: 0.3753 - accuracy: 0.8666 - val_loss: 0.4514 - val_accuracy: 0.8373 - lr: 0.0010 - 1s/epoch - 3ms/step
# Epoch 22/60
#
# Epoch 22: val_accuracy did not improve from 0.84000
# 375/375 - 1s - loss: 0.3760 - accuracy: 0.8659 - val_loss: 0.4580 - val_accuracy: 0.8332 - lr: 0.0010 - 1s/epoch - 3ms/step
# Epoch 23/60
#
# Epoch 23: val_accuracy did not improve from 0.84000
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 375/375 - 1s - loss: 0.3756 - accuracy: 0.8674 - val_loss: 0.4531 - val_accuracy: 0.8399 - lr: 0.0010 - 1s/epoch - 3ms/step
# Epoch 24/60
#
# Epoch 24: val_accuracy improved from 0.84000 to 0.84067, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_1FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 1s - loss: 0.3560 - accuracy: 0.8751 - val_loss: 0.4436 - val_accuracy: 0.8407 - lr: 1.0000e-04 - 1s/epoch - 3ms/step
# Epoch 25/60
#
# Epoch 25: val_accuracy did not improve from 0.84067
# 375/375 - 1s - loss: 0.3550 - accuracy: 0.8755 - val_loss: 0.4442 - val_accuracy: 0.8405 - lr: 1.0000e-04 - 1s/epoch - 3ms/step
# Epoch 26/60
#
# Epoch 26: val_accuracy improved from 0.84067 to 0.84167, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_1FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 1s - loss: 0.3549 - accuracy: 0.8750 - val_loss: 0.4446 - val_accuracy: 0.8417 - lr: 1.0000e-04 - 1s/epoch - 3ms/step
# Epoch 27/60
#
# Epoch 27: val_accuracy did not improve from 0.84167
# 375/375 - 1s - loss: 0.3546 - accuracy: 0.8749 - val_loss: 0.4444 - val_accuracy: 0.8410 - lr: 1.0000e-04 - 918ms/epoch - 2ms/step
# Epoch 28/60
#
# Epoch 28: val_accuracy did not improve from 0.84167
# 375/375 - 1s - loss: 0.3547 - accuracy: 0.8746 - val_loss: 0.4446 - val_accuracy: 0.8402 - lr: 1.0000e-04 - 959ms/epoch - 3ms/step
# Epoch 29/60
#
# Epoch 29: val_accuracy did not improve from 0.84167
# 375/375 - 1s - loss: 0.3545 - accuracy: 0.8752 - val_loss: 0.4437 - val_accuracy: 0.8390 - lr: 1.0000e-04 - 929ms/epoch - 2ms/step
# Epoch 30/60
#
# Epoch 30: val_accuracy did not improve from 0.84167
# 375/375 - 1s - loss: 0.3545 - accuracy: 0.8748 - val_loss: 0.4446 - val_accuracy: 0.8396 - lr: 1.0000e-04 - 959ms/epoch - 3ms/step
# Epoch 31/60
#
# Epoch 31: val_accuracy did not improve from 0.84167
# 375/375 - 1s - loss: 0.3543 - accuracy: 0.8751 - val_loss: 0.4459 - val_accuracy: 0.8398 - lr: 1.0000e-04 - 1s/epoch - 3ms/step
# Epoch 32/60
#
# Epoch 32: val_accuracy did not improve from 0.84167
# 375/375 - 1s - loss: 0.3543 - accuracy: 0.8745 - val_loss: 0.4450 - val_accuracy: 0.8382 - lr: 1.0000e-04 - 1s/epoch - 3ms/step
# Epoch 33/60
#
# Epoch 33: val_accuracy did not improve from 0.84167
# 375/375 - 1s - loss: 0.3540 - accuracy: 0.8756 - val_loss: 0.4449 - val_accuracy: 0.8389 - lr: 1.0000e-04 - 1s/epoch - 3ms/step
# Epoch 34/60
#
# Epoch 34: val_accuracy did not improve from 0.84167
# 375/375 - 2s - loss: 0.3539 - accuracy: 0.8756 - val_loss: 0.4448 - val_accuracy: 0.8393 - lr: 1.0000e-04 - 2s/epoch - 4ms/step
# Epoch 35/60
#
# Epoch 35: val_accuracy did not improve from 0.84167
# 375/375 - 1s - loss: 0.3537 - accuracy: 0.8752 - val_loss: 0.4448 - val_accuracy: 0.8398 - lr: 1.0000e-04 - 1s/epoch - 3ms/step
# Epoch 36/60
#
# Epoch 36: val_accuracy did not improve from 0.84167
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 375/375 - 1s - loss: 0.3536 - accuracy: 0.8750 - val_loss: 0.4462 - val_accuracy: 0.8388 - lr: 1.0000e-04 - 1s/epoch - 3ms/step
# Epoch 37/60
#
# Epoch 37: val_accuracy did not improve from 0.84167
# 375/375 - 1s - loss: 0.3520 - accuracy: 0.8762 - val_loss: 0.4442 - val_accuracy: 0.8397 - lr: 1.0000e-05 - 1s/epoch - 3ms/step
# Epoch 38/60
#
# Epoch 38: val_accuracy did not improve from 0.84167
# 375/375 - 1s - loss: 0.3514 - accuracy: 0.8763 - val_loss: 0.4440 - val_accuracy: 0.8389 - lr: 1.0000e-05 - 1s/epoch - 3ms/step
# Epoch 39/60
#
# Epoch 39: val_accuracy did not improve from 0.84167
# 375/375 - 1s - loss: 0.3514 - accuracy: 0.8764 - val_loss: 0.4440 - val_accuracy: 0.8400 - lr: 1.0000e-05 - 1s/epoch - 3ms/step
# Epoch 40/60
#
# Epoch 40: val_accuracy did not improve from 0.84167
# 375/375 - 1s - loss: 0.3514 - accuracy: 0.8763 - val_loss: 0.4441 - val_accuracy: 0.8394 - lr: 1.0000e-05 - 946ms/epoch - 3ms/step
# Epoch 41/60
# Restoring model weights from the end of the best epoch: 26.
#
# Epoch 41: val_accuracy did not improve from 0.84167
# 375/375 - 1s - loss: 0.3514 - accuracy: 0.8761 - val_loss: 0.4442 - val_accuracy: 0.8398 - lr: 1.0000e-05 - 1s/epoch - 3ms/step
# Epoch 41: early stopping
# Epoch 1/60
#
# Epoch 1: val_accuracy improved from -inf to 0.82283, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_2FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 3s - loss: 0.5573 - accuracy: 0.8009 - val_loss: 0.4872 - val_accuracy: 0.8228 - lr: 0.0010 - 3s/epoch - 8ms/step
# Epoch 2/60
#
# Epoch 2: val_accuracy improved from 0.82283 to 0.83158, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_2FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 2s - loss: 0.4137 - accuracy: 0.8498 - val_loss: 0.4463 - val_accuracy: 0.8316 - lr: 0.0010 - 2s/epoch - 6ms/step
# Epoch 3/60
#
# Epoch 3: val_accuracy improved from 0.83158 to 0.84058, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_2FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 2s - loss: 0.3571 - accuracy: 0.8699 - val_loss: 0.4217 - val_accuracy: 0.8406 - lr: 0.0010 - 2s/epoch - 7ms/step
# Epoch 4/60
#
# Epoch 4: val_accuracy improved from 0.84058 to 0.84892, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_2FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 2s - loss: 0.3207 - accuracy: 0.8829 - val_loss: 0.4035 - val_accuracy: 0.8489 - lr: 0.0010 - 2s/epoch - 6ms/step
# Epoch 5/60
#
# Epoch 5: val_accuracy improved from 0.84892 to 0.85958, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_2FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 3s - loss: 0.2880 - accuracy: 0.8947 - val_loss: 0.3962 - val_accuracy: 0.8596 - lr: 0.0010 - 3s/epoch - 8ms/step
# Epoch 6/60
#
# Epoch 6: val_accuracy improved from 0.85958 to 0.86208, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_2FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 3s - loss: 0.2584 - accuracy: 0.9059 - val_loss: 0.3904 - val_accuracy: 0.8621 - lr: 0.0010 - 3s/epoch - 7ms/step
# Epoch 7/60
#
# Epoch 7: val_accuracy did not improve from 0.86208
# 375/375 - 2s - loss: 0.2286 - accuracy: 0.9169 - val_loss: 0.3997 - val_accuracy: 0.8595 - lr: 0.0010 - 2s/epoch - 7ms/step
# Epoch 8/60
#
# Epoch 8: val_accuracy improved from 0.86208 to 0.86800, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_2FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 2s - loss: 0.2051 - accuracy: 0.9264 - val_loss: 0.3960 - val_accuracy: 0.8680 - lr: 0.0010 - 2s/epoch - 7ms/step
# Epoch 9/60
#
# Epoch 9: val_accuracy did not improve from 0.86800
# 375/375 - 2s - loss: 0.1810 - accuracy: 0.9349 - val_loss: 0.4238 - val_accuracy: 0.8639 - lr: 0.0010 - 2s/epoch - 6ms/step
# Epoch 10/60
#
# Epoch 10: val_accuracy did not improve from 0.86800
# 375/375 - 3s - loss: 0.1618 - accuracy: 0.9415 - val_loss: 0.4355 - val_accuracy: 0.8603 - lr: 0.0010 - 3s/epoch - 8ms/step
# Epoch 11/60
#
# Epoch 11: val_accuracy did not improve from 0.86800
# 375/375 - 3s - loss: 0.1436 - accuracy: 0.9489 - val_loss: 0.4435 - val_accuracy: 0.8659 - lr: 0.0010 - 3s/epoch - 7ms/step
# Epoch 12/60
#
# Epoch 12: val_accuracy did not improve from 0.86800
# 375/375 - 3s - loss: 0.1262 - accuracy: 0.9559 - val_loss: 0.4694 - val_accuracy: 0.8612 - lr: 0.0010 - 3s/epoch - 7ms/step
# Epoch 13/60
#
# Epoch 13: val_accuracy did not improve from 0.86800
# 375/375 - 3s - loss: 0.1120 - accuracy: 0.9613 - val_loss: 0.4747 - val_accuracy: 0.8623 - lr: 0.0010 - 3s/epoch - 7ms/step
# Epoch 14/60
#
# Epoch 14: val_accuracy did not improve from 0.86800
# 375/375 - 2s - loss: 0.1059 - accuracy: 0.9630 - val_loss: 0.5146 - val_accuracy: 0.8606 - lr: 0.0010 - 2s/epoch - 6ms/step
# Epoch 15/60
#
# Epoch 15: val_accuracy did not improve from 0.86800
# 375/375 - 2s - loss: 0.0920 - accuracy: 0.9685 - val_loss: 0.5521 - val_accuracy: 0.8539 - lr: 0.0010 - 2s/epoch - 6ms/step
# Epoch 16/60
#
# Epoch 16: val_accuracy did not improve from 0.86800
# 375/375 - 2s - loss: 0.0803 - accuracy: 0.9727 - val_loss: 0.5409 - val_accuracy: 0.8634 - lr: 0.0010 - 2s/epoch - 6ms/step
# Epoch 17/60
#
# Epoch 17: val_accuracy did not improve from 0.86800
# 375/375 - 2s - loss: 0.0760 - accuracy: 0.9740 - val_loss: 0.5568 - val_accuracy: 0.8587 - lr: 0.0010 - 2s/epoch - 6ms/step
# Epoch 18/60
#
# Epoch 18: val_accuracy did not improve from 0.86800
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 375/375 - 2s - loss: 0.0649 - accuracy: 0.9784 - val_loss: 0.5750 - val_accuracy: 0.8588 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 19/60
#
# Epoch 19: val_accuracy improved from 0.86800 to 0.87183, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_2FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 2s - loss: 0.0312 - accuracy: 0.9927 - val_loss: 0.5481 - val_accuracy: 0.8718 - lr: 1.0000e-04 - 2s/epoch - 5ms/step
# Epoch 20/60
#
# Epoch 20: val_accuracy improved from 0.87183 to 0.87283, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_2FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 3s - loss: 0.0239 - accuracy: 0.9948 - val_loss: 0.5586 - val_accuracy: 0.8728 - lr: 1.0000e-04 - 3s/epoch - 7ms/step
# Epoch 21/60
#
# Epoch 21: val_accuracy improved from 0.87283 to 0.87475, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_2FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 3s - loss: 0.0221 - accuracy: 0.9952 - val_loss: 0.5642 - val_accuracy: 0.8748 - lr: 1.0000e-04 - 3s/epoch - 7ms/step
# Epoch 22/60
#
# Epoch 22: val_accuracy did not improve from 0.87475
# 375/375 - 2s - loss: 0.0209 - accuracy: 0.9953 - val_loss: 0.5705 - val_accuracy: 0.8720 - lr: 1.0000e-04 - 2s/epoch - 6ms/step
# Epoch 23/60
#
# Epoch 23: val_accuracy did not improve from 0.87475
# 375/375 - 2s - loss: 0.0198 - accuracy: 0.9959 - val_loss: 0.5722 - val_accuracy: 0.8733 - lr: 1.0000e-04 - 2s/epoch - 6ms/step
# Epoch 24/60
#
# Epoch 24: val_accuracy did not improve from 0.87475
# 375/375 - 2s - loss: 0.0188 - accuracy: 0.9961 - val_loss: 0.5756 - val_accuracy: 0.8717 - lr: 1.0000e-04 - 2s/epoch - 6ms/step
# Epoch 25/60
#
# Epoch 25: val_accuracy did not improve from 0.87475
# 375/375 - 2s - loss: 0.0179 - accuracy: 0.9966 - val_loss: 0.5826 - val_accuracy: 0.8717 - lr: 1.0000e-04 - 2s/epoch - 6ms/step
# Epoch 26/60
#
# Epoch 26: val_accuracy did not improve from 0.87475
# 375/375 - 2s - loss: 0.0171 - accuracy: 0.9966 - val_loss: 0.5849 - val_accuracy: 0.8732 - lr: 1.0000e-04 - 2s/epoch - 6ms/step
# Epoch 27/60
#
# Epoch 27: val_accuracy did not improve from 0.87475
# 375/375 - 2s - loss: 0.0165 - accuracy: 0.9967 - val_loss: 0.5881 - val_accuracy: 0.8736 - lr: 1.0000e-04 - 2s/epoch - 6ms/step
# Epoch 28/60
#
# Epoch 28: val_accuracy did not improve from 0.87475
# 375/375 - 2s - loss: 0.0154 - accuracy: 0.9974 - val_loss: 0.5969 - val_accuracy: 0.8733 - lr: 1.0000e-04 - 2s/epoch - 6ms/step
# Epoch 29/60
#
# Epoch 29: val_accuracy did not improve from 0.87475
# 375/375 - 2s - loss: 0.0147 - accuracy: 0.9975 - val_loss: 0.6020 - val_accuracy: 0.8718 - lr: 1.0000e-04 - 2s/epoch - 6ms/step
# Epoch 30/60
#
# Epoch 30: val_accuracy did not improve from 0.87475
# 375/375 - 2s - loss: 0.0139 - accuracy: 0.9975 - val_loss: 0.6056 - val_accuracy: 0.8728 - lr: 1.0000e-04 - 2s/epoch - 6ms/step
# Epoch 31/60
#
# Epoch 31: val_accuracy did not improve from 0.87475
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 375/375 - 3s - loss: 0.0132 - accuracy: 0.9976 - val_loss: 0.6174 - val_accuracy: 0.8713 - lr: 1.0000e-04 - 3s/epoch - 7ms/step
# Epoch 32/60
#
# Epoch 32: val_accuracy did not improve from 0.87475
# 375/375 - 2s - loss: 0.0111 - accuracy: 0.9985 - val_loss: 0.6105 - val_accuracy: 0.8726 - lr: 1.0000e-05 - 2s/epoch - 7ms/step
# Epoch 33/60
#
# Epoch 33: val_accuracy did not improve from 0.87475
# 375/375 - 2s - loss: 0.0104 - accuracy: 0.9988 - val_loss: 0.6122 - val_accuracy: 0.8725 - lr: 1.0000e-05 - 2s/epoch - 6ms/step
# Epoch 34/60
#
# Epoch 34: val_accuracy did not improve from 0.87475
# 375/375 - 2s - loss: 0.0103 - accuracy: 0.9987 - val_loss: 0.6134 - val_accuracy: 0.8722 - lr: 1.0000e-05 - 2s/epoch - 6ms/step
# Epoch 35/60
#
# Epoch 35: val_accuracy did not improve from 0.87475
# 375/375 - 2s - loss: 0.0101 - accuracy: 0.9986 - val_loss: 0.6148 - val_accuracy: 0.8721 - lr: 1.0000e-05 - 2s/epoch - 6ms/step
# Epoch 36/60
# Restoring model weights from the end of the best epoch: 21.
#
# Epoch 36: val_accuracy did not improve from 0.87475
# 375/375 - 2s - loss: 0.0101 - accuracy: 0.9987 - val_loss: 0.6154 - val_accuracy: 0.8727 - lr: 1.0000e-05 - 2s/epoch - 6ms/step
# Epoch 36: early stopping
# Epoch 1/60
#
# Epoch 1: val_accuracy improved from -inf to 0.83408, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 4s - loss: 0.5585 - accuracy: 0.7980 - val_loss: 0.4482 - val_accuracy: 0.8341 - lr: 0.0010 - 4s/epoch - 12ms/step
# Epoch 2/60
#
# Epoch 2: val_accuracy improved from 0.83408 to 0.84025, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 3s - loss: 0.4051 - accuracy: 0.8496 - val_loss: 0.4239 - val_accuracy: 0.8403 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 3/60
#
# Epoch 3: val_accuracy improved from 0.84025 to 0.84758, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 3s - loss: 0.3553 - accuracy: 0.8693 - val_loss: 0.4085 - val_accuracy: 0.8476 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 4/60
#
# Epoch 4: val_accuracy improved from 0.84758 to 0.85817, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 3s - loss: 0.3116 - accuracy: 0.8845 - val_loss: 0.3884 - val_accuracy: 0.8582 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 5/60
#
# Epoch 5: val_accuracy did not improve from 0.85817
# 375/375 - 4s - loss: 0.2805 - accuracy: 0.8960 - val_loss: 0.4240 - val_accuracy: 0.8472 - lr: 0.0010 - 4s/epoch - 9ms/step
# Epoch 6/60
#
# Epoch 6: val_accuracy improved from 0.85817 to 0.86417, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 4s - loss: 0.2493 - accuracy: 0.9076 - val_loss: 0.3831 - val_accuracy: 0.8642 - lr: 0.0010 - 4s/epoch - 9ms/step
# Epoch 7/60
#
# Epoch 7: val_accuracy did not improve from 0.86417
# 375/375 - 4s - loss: 0.2213 - accuracy: 0.9180 - val_loss: 0.4133 - val_accuracy: 0.8588 - lr: 0.0010 - 4s/epoch - 9ms/step
# Epoch 8/60
#
# Epoch 8: val_accuracy did not improve from 0.86417
# 375/375 - 4s - loss: 0.1967 - accuracy: 0.9267 - val_loss: 0.4355 - val_accuracy: 0.8599 - lr: 0.0010 - 4s/epoch - 10ms/step
# Epoch 9/60
#
# Epoch 9: val_accuracy improved from 0.86417 to 0.86583, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 4s - loss: 0.1775 - accuracy: 0.9338 - val_loss: 0.4543 - val_accuracy: 0.8658 - lr: 0.0010 - 4s/epoch - 9ms/step
# Epoch 10/60
#
# Epoch 10: val_accuracy did not improve from 0.86583
# 375/375 - 3s - loss: 0.1605 - accuracy: 0.9405 - val_loss: 0.4912 - val_accuracy: 0.8596 - lr: 0.0010 - 3s/epoch - 8ms/step
# Epoch 11/60
#
# Epoch 11: val_accuracy did not improve from 0.86583
# 375/375 - 3s - loss: 0.1405 - accuracy: 0.9481 - val_loss: 0.5113 - val_accuracy: 0.8617 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 12/60
#
# Epoch 12: val_accuracy did not improve from 0.86583
# 375/375 - 3s - loss: 0.1261 - accuracy: 0.9539 - val_loss: 0.5209 - val_accuracy: 0.8647 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 13/60
#
# Epoch 13: val_accuracy did not improve from 0.86583
# 375/375 - 3s - loss: 0.1125 - accuracy: 0.9597 - val_loss: 0.5420 - val_accuracy: 0.8627 - lr: 0.0010 - 3s/epoch - 7ms/step
# Epoch 14/60
#
# Epoch 14: val_accuracy did not improve from 0.86583
# 375/375 - 3s - loss: 0.1084 - accuracy: 0.9598 - val_loss: 0.5794 - val_accuracy: 0.8593 - lr: 0.0010 - 3s/epoch - 8ms/step
# Epoch 15/60
#
# Epoch 15: val_accuracy did not improve from 0.86583
# 375/375 - 3s - loss: 0.0921 - accuracy: 0.9661 - val_loss: 0.6156 - val_accuracy: 0.8602 - lr: 0.0010 - 3s/epoch - 8ms/step
# Epoch 16/60
#
# Epoch 16: val_accuracy did not improve from 0.86583
# 375/375 - 2s - loss: 0.0847 - accuracy: 0.9691 - val_loss: 0.6501 - val_accuracy: 0.8588 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 17/60
#
# Epoch 17: val_accuracy did not improve from 0.86583
# 375/375 - 1s - loss: 0.0787 - accuracy: 0.9709 - val_loss: 0.6388 - val_accuracy: 0.8621 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 18/60
#
# Epoch 18: val_accuracy did not improve from 0.86583
# 375/375 - 1s - loss: 0.0768 - accuracy: 0.9719 - val_loss: 0.6965 - val_accuracy: 0.8565 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 19/60
#
# Epoch 19: val_accuracy did not improve from 0.86583
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 375/375 - 1s - loss: 0.0678 - accuracy: 0.9753 - val_loss: 0.7576 - val_accuracy: 0.8634 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 20/60
#
# Epoch 20: val_accuracy improved from 0.86583 to 0.87425, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 1s - loss: 0.0263 - accuracy: 0.9924 - val_loss: 0.6897 - val_accuracy: 0.8742 - lr: 1.0000e-04 - 1s/epoch - 4ms/step
# Epoch 21/60
#
# Epoch 21: val_accuracy improved from 0.87425 to 0.87508, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 1s - loss: 0.0171 - accuracy: 0.9954 - val_loss: 0.7128 - val_accuracy: 0.8751 - lr: 1.0000e-04 - 1s/epoch - 4ms/step
# Epoch 22/60
#
# Epoch 22: val_accuracy did not improve from 0.87508
# 375/375 - 1s - loss: 0.0147 - accuracy: 0.9963 - val_loss: 0.7382 - val_accuracy: 0.8741 - lr: 1.0000e-04 - 1s/epoch - 3ms/step
# Epoch 23/60
#
# Epoch 23: val_accuracy did not improve from 0.87508
# 375/375 - 1s - loss: 0.0131 - accuracy: 0.9969 - val_loss: 0.7512 - val_accuracy: 0.8732 - lr: 1.0000e-04 - 1s/epoch - 4ms/step
# Epoch 24/60
#
# Epoch 24: val_accuracy did not improve from 0.87508
# 375/375 - 1s - loss: 0.0120 - accuracy: 0.9971 - val_loss: 0.7735 - val_accuracy: 0.8746 - lr: 1.0000e-04 - 1s/epoch - 4ms/step
# Epoch 25/60
#
# Epoch 25: val_accuracy did not improve from 0.87508
# 375/375 - 1s - loss: 0.0106 - accuracy: 0.9974 - val_loss: 0.7994 - val_accuracy: 0.8737 - lr: 1.0000e-04 - 1s/epoch - 4ms/step
# Epoch 26/60
#
# Epoch 26: val_accuracy did not improve from 0.87508
# 375/375 - 1s - loss: 0.0097 - accuracy: 0.9977 - val_loss: 0.8065 - val_accuracy: 0.8720 - lr: 1.0000e-04 - 1s/epoch - 3ms/step
# Epoch 27/60
#
# Epoch 27: val_accuracy did not improve from 0.87508
# 375/375 - 1s - loss: 0.0091 - accuracy: 0.9977 - val_loss: 0.8253 - val_accuracy: 0.8724 - lr: 1.0000e-04 - 1s/epoch - 4ms/step
# Epoch 28/60
#
# Epoch 28: val_accuracy did not improve from 0.87508
# 375/375 - 1s - loss: 0.0081 - accuracy: 0.9981 - val_loss: 0.8465 - val_accuracy: 0.8748 - lr: 1.0000e-04 - 1s/epoch - 3ms/step
# Epoch 29/60
#
# Epoch 29: val_accuracy did not improve from 0.87508
# 375/375 - 1s - loss: 0.0075 - accuracy: 0.9983 - val_loss: 0.8608 - val_accuracy: 0.8737 - lr: 1.0000e-04 - 1s/epoch - 4ms/step
# Epoch 30/60
#
# Epoch 30: val_accuracy did not improve from 0.87508
# 375/375 - 1s - loss: 0.0070 - accuracy: 0.9984 - val_loss: 0.8815 - val_accuracy: 0.8739 - lr: 1.0000e-04 - 1s/epoch - 3ms/step
# Epoch 31/60
#
# Epoch 31: val_accuracy did not improve from 0.87508
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 375/375 - 1s - loss: 0.0061 - accuracy: 0.9988 - val_loss: 0.9017 - val_accuracy: 0.8740 - lr: 1.0000e-04 - 1s/epoch - 4ms/step
# Epoch 32/60
#
# Epoch 32: val_accuracy did not improve from 0.87508
# 375/375 - 1s - loss: 0.0043 - accuracy: 0.9993 - val_loss: 0.9009 - val_accuracy: 0.8748 - lr: 1.0000e-05 - 1s/epoch - 4ms/step
# Epoch 33/60
#
# Epoch 33: val_accuracy did not improve from 0.87508
# 375/375 - 1s - loss: 0.0040 - accuracy: 0.9994 - val_loss: 0.9040 - val_accuracy: 0.8738 - lr: 1.0000e-05 - 1s/epoch - 4ms/step
# Epoch 34/60
#
# Epoch 34: val_accuracy did not improve from 0.87508
# 375/375 - 1s - loss: 0.0038 - accuracy: 0.9995 - val_loss: 0.9075 - val_accuracy: 0.8741 - lr: 1.0000e-05 - 1s/epoch - 4ms/step
# Epoch 35/60
#
# Epoch 35: val_accuracy did not improve from 0.87508
# 375/375 - 1s - loss: 0.0037 - accuracy: 0.9995 - val_loss: 0.9110 - val_accuracy: 0.8745 - lr: 1.0000e-05 - 1s/epoch - 4ms/step
# Epoch 36/60
#
# Epoch 36: val_accuracy improved from 0.87508 to 0.87558, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 1s - loss: 0.0037 - accuracy: 0.9995 - val_loss: 0.9159 - val_accuracy: 0.8756 - lr: 1.0000e-05 - 1s/epoch - 4ms/step
# Epoch 37/60
#
# Epoch 37: val_accuracy did not improve from 0.87558
# 375/375 - 1s - loss: 0.0036 - accuracy: 0.9995 - val_loss: 0.9187 - val_accuracy: 0.8742 - lr: 1.0000e-05 - 1s/epoch - 4ms/step
# Epoch 38/60
#
# Epoch 38: val_accuracy did not improve from 0.87558
# 375/375 - 1s - loss: 0.0035 - accuracy: 0.9995 - val_loss: 0.9227 - val_accuracy: 0.8745 - lr: 1.0000e-05 - 1s/epoch - 4ms/step
# Epoch 39/60
#
# Epoch 39: val_accuracy did not improve from 0.87558
# 375/375 - 1s - loss: 0.0035 - accuracy: 0.9995 - val_loss: 0.9273 - val_accuracy: 0.8747 - lr: 1.0000e-05 - 1s/epoch - 4ms/step
# Epoch 40/60
#
# Epoch 40: val_accuracy did not improve from 0.87558
# 375/375 - 1s - loss: 0.0034 - accuracy: 0.9996 - val_loss: 0.9313 - val_accuracy: 0.8743 - lr: 1.0000e-05 - 1s/epoch - 3ms/step
# Epoch 41/60
#
# Epoch 41: val_accuracy did not improve from 0.87558
# 375/375 - 1s - loss: 0.0033 - accuracy: 0.9996 - val_loss: 0.9350 - val_accuracy: 0.8746 - lr: 1.0000e-05 - 1s/epoch - 4ms/step
# Epoch 42/60
#
# Epoch 42: val_accuracy did not improve from 0.87558
# 375/375 - 1s - loss: 0.0033 - accuracy: 0.9996 - val_loss: 0.9378 - val_accuracy: 0.8744 - lr: 1.0000e-05 - 1s/epoch - 4ms/step
# Epoch 43/60
#
# Epoch 43: val_accuracy did not improve from 0.87558
# 375/375 - 1s - loss: 0.0031 - accuracy: 0.9995 - val_loss: 0.9440 - val_accuracy: 0.8745 - lr: 1.0000e-05 - 1s/epoch - 3ms/step
# Epoch 44/60
#
# Epoch 44: val_accuracy did not improve from 0.87558
# 375/375 - 1s - loss: 0.0031 - accuracy: 0.9996 - val_loss: 0.9480 - val_accuracy: 0.8744 - lr: 1.0000e-05 - 1s/epoch - 4ms/step
# Epoch 45/60
#
# Epoch 45: val_accuracy did not improve from 0.87558
# 375/375 - 1s - loss: 0.0031 - accuracy: 0.9996 - val_loss: 0.9523 - val_accuracy: 0.8740 - lr: 1.0000e-05 - 1s/epoch - 3ms/step
# Epoch 46/60
#
# Epoch 46: val_accuracy did not improve from 0.87558
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 375/375 - 1s - loss: 0.0030 - accuracy: 0.9997 - val_loss: 0.9571 - val_accuracy: 0.8744 - lr: 1.0000e-05 - 1s/epoch - 4ms/step
# Epoch 47/60
#
# Epoch 47: val_accuracy did not improve from 0.87558
# 375/375 - 1s - loss: 0.0028 - accuracy: 0.9996 - val_loss: 0.9575 - val_accuracy: 0.8742 - lr: 1.0000e-06 - 1s/epoch - 4ms/step
# Epoch 48/60
#
# Epoch 48: val_accuracy did not improve from 0.87558
# 375/375 - 1s - loss: 0.0028 - accuracy: 0.9997 - val_loss: 0.9579 - val_accuracy: 0.8742 - lr: 1.0000e-06 - 1s/epoch - 4ms/step
# Epoch 49/60
#
# Epoch 49: val_accuracy did not improve from 0.87558
# 375/375 - 2s - loss: 0.0028 - accuracy: 0.9997 - val_loss: 0.9583 - val_accuracy: 0.8742 - lr: 1.0000e-06 - 2s/epoch - 4ms/step
# Epoch 50/60
#
# Epoch 50: val_accuracy did not improve from 0.87558
# 375/375 - 1s - loss: 0.0027 - accuracy: 0.9997 - val_loss: 0.9589 - val_accuracy: 0.8740 - lr: 1.0000e-06 - 1s/epoch - 4ms/step
# Epoch 51/60
# Restoring model weights from the end of the best epoch: 36.
#
# Epoch 51: val_accuracy did not improve from 0.87558
# 375/375 - 1s - loss: 0.0027 - accuracy: 0.9997 - val_loss: 0.9595 - val_accuracy: 0.8740 - lr: 1.0000e-06 - 1s/epoch - 4ms/step
# Epoch 51: early stopping
# Epoch 1/60
#
# Epoch 1: val_accuracy improved from -inf to 0.82683, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 3s - loss: 0.5614 - accuracy: 0.7957 - val_loss: 0.4710 - val_accuracy: 0.8268 - lr: 0.0010 - 3s/epoch - 7ms/step
# Epoch 2/60
#
# Epoch 2: val_accuracy improved from 0.82683 to 0.84517, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 3s - loss: 0.4080 - accuracy: 0.8510 - val_loss: 0.4140 - val_accuracy: 0.8452 - lr: 0.0010 - 3s/epoch - 7ms/step
# Epoch 3/60
#
# Epoch 3: val_accuracy improved from 0.84517 to 0.85592, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 2s - loss: 0.3575 - accuracy: 0.8676 - val_loss: 0.3949 - val_accuracy: 0.8559 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 4/60
#
# Epoch 4: val_accuracy improved from 0.85592 to 0.86092, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 2s - loss: 0.3207 - accuracy: 0.8821 - val_loss: 0.3831 - val_accuracy: 0.8609 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 5/60
#
# Epoch 5: val_accuracy did not improve from 0.86092
# 375/375 - 3s - loss: 0.2879 - accuracy: 0.8942 - val_loss: 0.3962 - val_accuracy: 0.8606 - lr: 0.0010 - 3s/epoch - 7ms/step
# Epoch 6/60
#
# Epoch 6: val_accuracy did not improve from 0.86092
# 375/375 - 3s - loss: 0.2631 - accuracy: 0.9032 - val_loss: 0.4288 - val_accuracy: 0.8573 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 7/60
#
# Epoch 7: val_accuracy did not improve from 0.86092
# 375/375 - 3s - loss: 0.2344 - accuracy: 0.9126 - val_loss: 0.4119 - val_accuracy: 0.8605 - lr: 0.0010 - 3s/epoch - 7ms/step
# Epoch 8/60
#
# Epoch 8: val_accuracy did not improve from 0.86092
# 375/375 - 2s - loss: 0.2131 - accuracy: 0.9209 - val_loss: 0.4696 - val_accuracy: 0.8457 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 9/60
#
# Epoch 9: val_accuracy did not improve from 0.86092
# 375/375 - 2s - loss: 0.1894 - accuracy: 0.9305 - val_loss: 0.4487 - val_accuracy: 0.8594 - lr: 0.0010 - 2s/epoch - 7ms/step
# Epoch 10/60
#
# Epoch 10: val_accuracy did not improve from 0.86092
# 375/375 - 4s - loss: 0.1709 - accuracy: 0.9379 - val_loss: 0.4839 - val_accuracy: 0.8556 - lr: 0.0010 - 4s/epoch - 10ms/step
# Epoch 11/60
#
# Epoch 11: val_accuracy improved from 0.86092 to 0.86358, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 4s - loss: 0.1549 - accuracy: 0.9438 - val_loss: 0.4874 - val_accuracy: 0.8636 - lr: 0.0010 - 4s/epoch - 9ms/step
# Epoch 12/60
#
# Epoch 12: val_accuracy did not improve from 0.86358
# 375/375 - 3s - loss: 0.1399 - accuracy: 0.9471 - val_loss: 0.5409 - val_accuracy: 0.8573 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 13/60
#
# Epoch 13: val_accuracy did not improve from 0.86358
# 375/375 - 4s - loss: 0.1309 - accuracy: 0.9522 - val_loss: 0.5396 - val_accuracy: 0.8616 - lr: 0.0010 - 4s/epoch - 9ms/step
# Epoch 14/60
#
# Epoch 14: val_accuracy did not improve from 0.86358
# 375/375 - 4s - loss: 0.1185 - accuracy: 0.9566 - val_loss: 0.5808 - val_accuracy: 0.8601 - lr: 0.0010 - 4s/epoch - 10ms/step
# Epoch 15/60
#
# Epoch 15: val_accuracy did not improve from 0.86358
# 375/375 - 4s - loss: 0.1045 - accuracy: 0.9622 - val_loss: 0.6288 - val_accuracy: 0.8617 - lr: 0.0010 - 4s/epoch - 10ms/step
# Epoch 16/60
#
# Epoch 16: val_accuracy did not improve from 0.86358
# 375/375 - 4s - loss: 0.1056 - accuracy: 0.9615 - val_loss: 0.6070 - val_accuracy: 0.8583 - lr: 0.0010 - 4s/epoch - 10ms/step
# Epoch 17/60
#
# Epoch 17: val_accuracy did not improve from 0.86358
# 375/375 - 2s - loss: 0.0984 - accuracy: 0.9632 - val_loss: 0.6538 - val_accuracy: 0.8607 - lr: 0.0010 - 2s/epoch - 6ms/step
# Epoch 18/60
#
# Epoch 18: val_accuracy did not improve from 0.86358
# 375/375 - 3s - loss: 0.0817 - accuracy: 0.9701 - val_loss: 0.6918 - val_accuracy: 0.8575 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 19/60
#
# Epoch 19: val_accuracy improved from 0.86358 to 0.86400, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 4s - loss: 0.0807 - accuracy: 0.9707 - val_loss: 0.7215 - val_accuracy: 0.8640 - lr: 0.0010 - 4s/epoch - 10ms/step
# Epoch 20/60
#
# Epoch 20: val_accuracy did not improve from 0.86400
# 375/375 - 3s - loss: 0.0758 - accuracy: 0.9724 - val_loss: 0.7333 - val_accuracy: 0.8532 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 21/60
#
# Epoch 21: val_accuracy did not improve from 0.86400
# 375/375 - 2s - loss: 0.0712 - accuracy: 0.9741 - val_loss: 0.8612 - val_accuracy: 0.8537 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 22/60
#
# Epoch 22: val_accuracy did not improve from 0.86400
# 375/375 - 2s - loss: 0.0651 - accuracy: 0.9763 - val_loss: 0.7590 - val_accuracy: 0.8624 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 23/60
#
# Epoch 23: val_accuracy did not improve from 0.86400
# 375/375 - 2s - loss: 0.0714 - accuracy: 0.9742 - val_loss: 0.7677 - val_accuracy: 0.8583 - lr: 0.0010 - 2s/epoch - 4ms/step
# Epoch 24/60
#
# Epoch 24: val_accuracy improved from 0.86400 to 0.86775, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 2s - loss: 0.0576 - accuracy: 0.9799 - val_loss: 0.7957 - val_accuracy: 0.8677 - lr: 0.0010 - 2s/epoch - 4ms/step
# Epoch 25/60
#
# Epoch 25: val_accuracy did not improve from 0.86775
# 375/375 - 1s - loss: 0.0596 - accuracy: 0.9793 - val_loss: 0.8853 - val_accuracy: 0.8548 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 26/60
#
# Epoch 26: val_accuracy did not improve from 0.86775
# 375/375 - 2s - loss: 0.0648 - accuracy: 0.9761 - val_loss: 0.8045 - val_accuracy: 0.8575 - lr: 0.0010 - 2s/epoch - 4ms/step
# Epoch 27/60
#
# Epoch 27: val_accuracy did not improve from 0.86775
# 375/375 - 1s - loss: 0.0564 - accuracy: 0.9796 - val_loss: 0.8115 - val_accuracy: 0.8606 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 28/60
#
# Epoch 28: val_accuracy did not improve from 0.86775
# 375/375 - 1s - loss: 0.0569 - accuracy: 0.9793 - val_loss: 0.8451 - val_accuracy: 0.8591 - lr: 0.0010 - 1s/epoch - 4ms/step
# Epoch 29/60
#
# Epoch 29: val_accuracy did not improve from 0.86775
# 375/375 - 2s - loss: 0.0511 - accuracy: 0.9822 - val_loss: 0.9670 - val_accuracy: 0.8443 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 30/60
#
# Epoch 30: val_accuracy did not improve from 0.86775
# 375/375 - 2s - loss: 0.0488 - accuracy: 0.9822 - val_loss: 0.9435 - val_accuracy: 0.8543 - lr: 0.0010 - 2s/epoch - 7ms/step
# Epoch 31/60
#
# Epoch 31: val_accuracy did not improve from 0.86775
# 375/375 - 2s - loss: 0.0488 - accuracy: 0.9825 - val_loss: 0.9030 - val_accuracy: 0.8626 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 32/60
#
# Epoch 32: val_accuracy did not improve from 0.86775
# 375/375 - 3s - loss: 0.0441 - accuracy: 0.9841 - val_loss: 0.9236 - val_accuracy: 0.8534 - lr: 0.0010 - 3s/epoch - 7ms/step
# Epoch 33/60
#
# Epoch 33: val_accuracy did not improve from 0.86775
# 375/375 - 3s - loss: 0.0437 - accuracy: 0.9854 - val_loss: 0.8855 - val_accuracy: 0.8578 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 34/60
#
# Epoch 34: val_accuracy did not improve from 0.86775
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 375/375 - 3s - loss: 0.0501 - accuracy: 0.9822 - val_loss: 0.8287 - val_accuracy: 0.8601 - lr: 0.0010 - 3s/epoch - 8ms/step
# Epoch 35/60
#
# Epoch 35: val_accuracy improved from 0.86775 to 0.87067, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 3s - loss: 0.0131 - accuracy: 0.9966 - val_loss: 0.8135 - val_accuracy: 0.8707 - lr: 1.0000e-04 - 3s/epoch - 9ms/step
# Epoch 36/60
#
# Epoch 36: val_accuracy improved from 0.87067 to 0.87100, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 3s - loss: 0.0071 - accuracy: 0.9986 - val_loss: 0.8532 - val_accuracy: 0.8710 - lr: 1.0000e-04 - 3s/epoch - 8ms/step
# Epoch 37/60
#
# Epoch 37: val_accuracy improved from 0.87100 to 0.87117, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 2s - loss: 0.0058 - accuracy: 0.9987 - val_loss: 0.8852 - val_accuracy: 0.8712 - lr: 1.0000e-04 - 2s/epoch - 6ms/step
# Epoch 38/60
#
# Epoch 38: val_accuracy improved from 0.87117 to 0.87192, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 3s - loss: 0.0050 - accuracy: 0.9989 - val_loss: 0.9108 - val_accuracy: 0.8719 - lr: 1.0000e-04 - 3s/epoch - 9ms/step
# Epoch 39/60
#
# Epoch 39: val_accuracy improved from 0.87192 to 0.87200, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 4s - loss: 0.0042 - accuracy: 0.9990 - val_loss: 0.9433 - val_accuracy: 0.8720 - lr: 1.0000e-04 - 4s/epoch - 11ms/step
# Epoch 40/60
#
# Epoch 40: val_accuracy improved from 0.87200 to 0.87225, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 5s - loss: 0.0037 - accuracy: 0.9990 - val_loss: 0.9738 - val_accuracy: 0.8723 - lr: 1.0000e-04 - 5s/epoch - 13ms/step
# Epoch 41/60
#
# Epoch 41: val_accuracy improved from 0.87225 to 0.87300, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_1230model.keras
# 375/375 - 3s - loss: 0.0034 - accuracy: 0.9992 - val_loss: 1.0037 - val_accuracy: 0.8730 - lr: 1.0000e-04 - 3s/epoch - 9ms/step
# Epoch 42/60
#
# Epoch 42: val_accuracy did not improve from 0.87300
# 375/375 - 2s - loss: 0.0031 - accuracy: 0.9994 - val_loss: 1.0267 - val_accuracy: 0.8727 - lr: 1.0000e-04 - 2s/epoch - 4ms/step
# Epoch 43/60
#
# Epoch 43: val_accuracy did not improve from 0.87300
# 375/375 - 2s - loss: 0.0027 - accuracy: 0.9993 - val_loss: 1.0587 - val_accuracy: 0.8719 - lr: 1.0000e-04 - 2s/epoch - 6ms/step
# Epoch 44/60
#
# Epoch 44: val_accuracy did not improve from 0.87300
# 375/375 - 3s - loss: 0.0027 - accuracy: 0.9993 - val_loss: 1.0844 - val_accuracy: 0.8717 - lr: 1.0000e-04 - 3s/epoch - 8ms/step
# Epoch 45/60
#
# Epoch 45: val_accuracy did not improve from 0.87300
# 375/375 - 2s - loss: 0.0020 - accuracy: 0.9996 - val_loss: 1.1137 - val_accuracy: 0.8723 - lr: 1.0000e-04 - 2s/epoch - 5ms/step
# Epoch 46/60
#
# Epoch 46: val_accuracy did not improve from 0.87300
# 375/375 - 3s - loss: 0.0023 - accuracy: 0.9995 - val_loss: 1.1375 - val_accuracy: 0.8716 - lr: 1.0000e-04 - 3s/epoch - 8ms/step
# Epoch 47/60
#
# Epoch 47: val_accuracy did not improve from 0.87300
# 375/375 - 3s - loss: 0.0020 - accuracy: 0.9994 - val_loss: 1.1748 - val_accuracy: 0.8704 - lr: 1.0000e-04 - 3s/epoch - 9ms/step
# Epoch 48/60
#
# Epoch 48: val_accuracy did not improve from 0.87300
# 375/375 - 2s - loss: 0.0018 - accuracy: 0.9995 - val_loss: 1.1940 - val_accuracy: 0.8709 - lr: 1.0000e-04 - 2s/epoch - 7ms/step
# Epoch 49/60
#
# Epoch 49: val_accuracy did not improve from 0.87300
# 375/375 - 3s - loss: 0.0017 - accuracy: 0.9996 - val_loss: 1.2311 - val_accuracy: 0.8721 - lr: 1.0000e-04 - 3s/epoch - 7ms/step
# Epoch 50/60
#
# Epoch 50: val_accuracy did not improve from 0.87300
# 375/375 - 3s - loss: 0.0016 - accuracy: 0.9996 - val_loss: 1.2529 - val_accuracy: 0.8698 - lr: 1.0000e-04 - 3s/epoch - 9ms/step
# Epoch 51/60
#
# Epoch 51: val_accuracy did not improve from 0.87300
#
# Epoch 51: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 375/375 - 3s - loss: 0.0011 - accuracy: 0.9996 - val_loss: 1.2867 - val_accuracy: 0.8722 - lr: 1.0000e-04 - 3s/epoch - 7ms/step
# Epoch 52/60
#
# Epoch 52: val_accuracy did not improve from 0.87300
# 375/375 - 3s - loss: 6.7048e-04 - accuracy: 0.9999 - val_loss: 1.2880 - val_accuracy: 0.8725 - lr: 1.0000e-05 - 3s/epoch - 7ms/step
# Epoch 53/60
#
# Epoch 53: val_accuracy did not improve from 0.87300
# 375/375 - 3s - loss: 5.0013e-04 - accuracy: 1.0000 - val_loss: 1.2914 - val_accuracy: 0.8723 - lr: 1.0000e-05 - 3s/epoch - 9ms/step
# Epoch 54/60
#
# Epoch 54: val_accuracy did not improve from 0.87300
# 375/375 - 4s - loss: 4.6667e-04 - accuracy: 1.0000 - val_loss: 1.2945 - val_accuracy: 0.8725 - lr: 1.0000e-05 - 4s/epoch - 10ms/step
# Epoch 55/60
#
# Epoch 55: val_accuracy did not improve from 0.87300
# 375/375 - 3s - loss: 4.4333e-04 - accuracy: 1.0000 - val_loss: 1.2996 - val_accuracy: 0.8725 - lr: 1.0000e-05 - 3s/epoch - 8ms/step
# Epoch 56/60
# Restoring model weights from the end of the best epoch: 41.
#
# Epoch 56: val_accuracy did not improve from 0.87300
# 375/375 - 3s - loss: 4.2391e-04 - accuracy: 1.0000 - val_loss: 1.3048 - val_accuracy: 0.8729 - lr: 1.0000e-05 - 3s/epoch - 8ms/step
# Epoch 56: early stopping
# Epoch 1/60
#
# Epoch 1: val_accuracy improved from -inf to 0.71308, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_summed/run_1FC/Entanglement_pool_summed_1230model.keras
# 375/375 - 2s - loss: 1.2389 - accuracy: 0.5994 - val_loss: 0.9042 - val_accuracy: 0.7131 - lr: 0.0010 - 2s/epoch - 4ms/step
# Epoch 2/60
#
# Epoch 2: val_accuracy improved from 0.71308 to 0.73867, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_summed/run_1FC/Entanglement_pool_summed_1230model.keras
# 375/375 - 1s - loss: 0.8348 - accuracy: 0.7333 - val_loss: 0.7867 - val_accuracy: 0.7387 - lr: 0.0010 - 846ms/epoch - 2ms/step
# Epoch 3/60
#
# Epoch 3: val_accuracy improved from 0.73867 to 0.74975, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_summed/run_1FC/Entanglement_pool_summed_1230model.keras
# 375/375 - 1s - loss: 0.7555 - accuracy: 0.7516 - val_loss: 0.7383 - val_accuracy: 0.7498 - lr: 0.0010 - 997ms/epoch - 3ms/step
# Epoch 4/60
#
# Epoch 4: val_accuracy improved from 0.74975 to 0.76042, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_summed/run_1FC/Entanglement_pool_summed_1230model.keras
# 375/375 - 1s - loss: 0.7154 - accuracy: 0.7628 - val_loss: 0.7073 - val_accuracy: 0.7604 - lr: 0.0010 - 1s/epoch - 3ms/step
# Epoch 5/60
#
# Epoch 5: val_accuracy improved from 0.76042 to 0.76233, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_summed/run_1FC/Entanglement_pool_summed_1230model.keras
# 375/375 - 1s - loss: 0.6888 - accuracy: 0.7706 - val_loss: 0.6885 - val_accuracy: 0.7623 - lr: 0.0010 - 1s/epoch - 3ms/step
# Epoch 6/60
#
# Epoch 6: val_accuracy improved from 0.76233 to 0.76833, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_summed/run_1FC/Entanglement_pool_summed_1230model.keras
# 375/375 - 1s - loss: 0.6705 - accuracy: 0.7755 - val_loss: 0.6727 - val_accuracy: 0.7683 - lr: 0.0010 - 897ms/epoch - 2ms/step
# Epoch 7/60
#
# Epoch 7: val_accuracy improved from 0.76833 to 0.77108, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_summed/run_1FC/Entanglement_pool_summed_1230model.keras
# 375/375 - 1s - loss: 0.6571 - accuracy: 0.7799 - val_loss: 0.6630 - val_accuracy: 0.7711 - lr: 0.0010 - 894ms/epoch - 2ms/step
# Epoch 8/60
#
# Epoch 8: val_accuracy improved from 0.77108 to 0.77242, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_summed/run_1FC/Entanglement_pool_summed_1230model.keras
# 375/375 - 1s - loss: 0.6459 - accuracy: 0.7834 - val_loss: 0.6530 - val_accuracy: 0.7724 - lr: 0.0010 - 963ms/epoch - 3ms/step
# Epoch 9/60
#
# Epoch 9: val_accuracy improved from 0.77242 to 0.77358, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_summed/run_1FC/Entanglement_pool_summed_1230model.keras
# 375/375 - 1s - loss: 0.6373 - accuracy: 0.7854 - val_loss: 0.6501 - val_accuracy: 0.7736 - lr: 0.0010 - 899ms/epoch - 2ms/step
# Epoch 10/60
#
# Epoch 10: val_accuracy improved from 0.77358 to 0.77842, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_summed/run_1FC/Entanglement_pool_summed_1230model.keras
# 375/375 - 1s - loss: 0.6308 - accuracy: 0.7876 - val_loss: 0.6401 - val_accuracy: 0.7784 - lr: 0.0010 - 889ms/epoch - 2ms/step
# Epoch 11/60
#
# Epoch 11: val_accuracy improved from 0.77842 to 0.77883, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_summed/run_1FC/Entanglement_pool_summed_1230model.keras
# 375/375 - 1s - loss: 0.6245 - accuracy: 0.7898 - val_loss: 0.6354 - val_accuracy: 0.7788 - lr: 0.0010 - 728ms/epoch - 2ms/step
# Epoch 12/60
#
# Epoch 12: val_accuracy improved from 0.77883 to 0.77900, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_summed/run_1FC/Entanglement_pool_summed_1230model.keras
# 375/375 - 1s - loss: 0.6186 - accuracy: 0.7912 - val_loss: 0.6353 - val_accuracy: 0.7790 - lr: 0.0010 - 787ms/epoch - 2ms/step
# Epoch 13/60
#
# Epoch 13: val_accuracy improved from 0.77900 to 0.78142, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_summed/run_1FC/Entanglement_pool_summed_1230model.keras
# 375/375 - 1s - loss: 0.6143 - accuracy: 0.7925 - val_loss: 0.6278 - val_accuracy: 0.7814 - lr: 0.0010 - 904ms/epoch - 2ms/step
# Epoch 14/60
#
# Epoch 14: val_accuracy improved from 0.78142 to 0.78175, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_summed/run_1FC/Entanglement_pool_summed_1230model.keras
# 375/375 - 1s - loss: 0.6104 - accuracy: 0.7936 - val_loss: 0.6266 - val_accuracy: 0.7818 - lr: 0.0010 - 1s/epoch - 3ms/step
# Epoch 15/60
#
# Epoch 15: val_accuracy improved from 0.78175 to 0.78358, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_summed/run_1FC/Entanglement_pool_summed_1230model.keras
# 375/375 - 1s - loss: 0.6067 - accuracy: 0.7944 - val_loss: 0.6211 - val_accuracy: 0.7836 - lr: 0.0010 - 813ms/epoch - 2ms/step
# Epoch 16/60
#
# Epoch 16: val_accuracy did not improve from 0.78358
# 375/375 - 1s - loss: 0.6036 - accuracy: 0.7951 - val_loss: 0.6198 - val_accuracy: 0.7828 - lr: 0.0010 - 928ms/epoch - 2ms/step
# Epoch 17/60
#
# Epoch 17: val_accuracy improved from 0.78358 to 0.78383, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_summed/run_1FC/Entanglement_pool_summed_1230model.keras
# 375/375 - 1s - loss: 0.6008 - accuracy: 0.7969 - val_loss: 0.6185 - val_accuracy: 0.7838 - lr: 0.0010 - 996ms/epoch - 3ms/step
# Epoch 18/60
#
# Epoch 18: val_accuracy improved from 0.78383 to 0.78608, saving model to _OA_results_FashionMnist_train_with_val/1230/Entanglement_pool_summed/run_1FC/Entanglement_pool_summed_1230model.keras
# ...
# 375/375 - 3s - loss: 0.0777 - accuracy: 0.9738 - val_loss: 0.4376 - val_accuracy: 0.8839 - lr: 1.0000e-04 - 3s/epoch - 8ms/step
# Epoch 35/60
#
# Epoch 35: val_accuracy improved from 0.88392 to 0.88475, saving model to _OA_results_FashionMnist_train_with_val/2013/No_Entanglement_pool_summed_avg/run_3FC/No_Entanglement_pool_summed_avg_2013model.keras
# 375/375 - 3s - loss: 0.0656 - accuracy: 0.9791 - val_loss: 0.4476 - val_accuracy: 0.8848 - lr: 1.0000e-04 - 3s/epoch - 8ms/step
# Epoch 36/60
#
# Epoch 36: val_accuracy did not improve from 0.88475
# 375/375 - 3s - loss: 0.0621 - accuracy: 0.9806 - val_loss: 0.4589 - val_accuracy: 0.8845 - lr: 1.0000e-04 - 3s/epoch - 8ms/step
# Epoch 37/60
#
# Epoch 37: val_accuracy improved from 0.88475 to 0.88483, saving model to _OA_results_FashionMnist_train_with_val/2013/No_Entanglement_pool_summed_avg/run_3FC/No_Entanglement_pool_summed_avg_2013model.keras
# 375/375 - 3s - loss: 0.0598 - accuracy: 0.9815 - val_loss: 0.4644 - val_accuracy: 0.8848 - lr: 1.0000e-04 - 3s/epoch - 8ms/step
# Epoch 38/60
#
# Epoch 38: val_accuracy did not improve from 0.88483
# 375/375 - 3s - loss: 0.0578 - accuracy: 0.9825 - val_loss: 0.4665 - val_accuracy: 0.8835 - lr: 1.0000e-04 - 3s/epoch - 8ms/step
# Epoch 39/60
#
# Epoch 39: val_accuracy did not improve from 0.88483
# 375/375 - 3s - loss: 0.0560 - accuracy: 0.9828 - val_loss: 0.4744 - val_accuracy: 0.8848 - lr: 1.0000e-04 - 3s/epoch - 8ms/step
# Epoch 40/60
#
# Epoch 40: val_accuracy did not improve from 0.88483
# 375/375 - 3s - loss: 0.0542 - accuracy: 0.9838 - val_loss: 0.4773 - val_accuracy: 0.8839 - lr: 1.0000e-04 - 3s/epoch - 8ms/step
# Epoch 41/60
#
# Epoch 41: val_accuracy did not improve from 0.88483
# 375/375 - 3s - loss: 0.0527 - accuracy: 0.9840 - val_loss: 0.4818 - val_accuracy: 0.8835 - lr: 1.0000e-04 - 3s/epoch - 8ms/step
# Epoch 42/60
#
# Epoch 42: val_accuracy did not improve from 0.88483
# 375/375 - 3s - loss: 0.0511 - accuracy: 0.9850 - val_loss: 0.4866 - val_accuracy: 0.8817 - lr: 1.0000e-04 - 3s/epoch - 9ms/step
# Epoch 43/60
#
# Epoch 43: val_accuracy did not improve from 0.88483
# 375/375 - 3s - loss: 0.0496 - accuracy: 0.9856 - val_loss: 0.4884 - val_accuracy: 0.8835 - lr: 1.0000e-04 - 3s/epoch - 8ms/step
# Epoch 44/60
#
# Epoch 44: val_accuracy did not improve from 0.88483
# 375/375 - 3s - loss: 0.0480 - accuracy: 0.9859 - val_loss: 0.4977 - val_accuracy: 0.8826 - lr: 1.0000e-04 - 3s/epoch - 8ms/step
# Epoch 45/60
#
# Epoch 45: val_accuracy did not improve from 0.88483
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 375/375 - 3s - loss: 0.0468 - accuracy: 0.9867 - val_loss: 0.5017 - val_accuracy: 0.8839 - lr: 1.0000e-04 - 3s/epoch - 8ms/step
# Epoch 46/60
#
# Epoch 46: val_accuracy did not improve from 0.88483
# 375/375 - 3s - loss: 0.0422 - accuracy: 0.9889 - val_loss: 0.5004 - val_accuracy: 0.8835 - lr: 1.0000e-05 - 3s/epoch - 8ms/step
# Epoch 47/60
#
# Epoch 47: val_accuracy did not improve from 0.88483
# 375/375 - 3s - loss: 0.0414 - accuracy: 0.9894 - val_loss: 0.5010 - val_accuracy: 0.8840 - lr: 1.0000e-05 - 3s/epoch - 8ms/step
# Epoch 48/60
#
# Epoch 48: val_accuracy did not improve from 0.88483
# 375/375 - 3s - loss: 0.0411 - accuracy: 0.9895 - val_loss: 0.5020 - val_accuracy: 0.8832 - lr: 1.0000e-05 - 3s/epoch - 8ms/step
# Epoch 49/60
#
# Epoch 49: val_accuracy did not improve from 0.88483
# 375/375 - 3s - loss: 0.0409 - accuracy: 0.9895 - val_loss: 0.5015 - val_accuracy: 0.8831 - lr: 1.0000e-05 - 3s/epoch - 8ms/step
# Epoch 50/60
#
# Epoch 50: val_accuracy did not improve from 0.88483
# 375/375 - 3s - loss: 0.0407 - accuracy: 0.9895 - val_loss: 0.5034 - val_accuracy: 0.8838 - lr: 1.0000e-05 - 3s/epoch - 8ms/step
# Epoch 51/60
#
# Epoch 51: val_accuracy did not improve from 0.88483
# 375/375 - 3s - loss: 0.0406 - accuracy: 0.9896 - val_loss: 0.5034 - val_accuracy: 0.8833 - lr: 1.0000e-05 - 3s/epoch - 8ms/step
# Epoch 52/60
# Restoring model weights from the end of the best epoch: 37.
#
# Epoch 52: val_accuracy did not improve from 0.88483
# 375/375 - 3s - loss: 0.0403 - accuracy: 0.9898 - val_loss: 0.5045 - val_accuracy: 0.8831 - lr: 1.0000e-05 - 3s/epoch - 8ms/step
# Epoch 52: early stopping
# Epoch 1/60
#
# Epoch 1: val_accuracy improved from -inf to 0.82967, saving model to _OA_results_FashionMnist_train_with_val/2013/No_Entanglement_pool_summed_avg/run_4FC/No_Entanglement_pool_summed_avg_2013model.keras
# 375/375 - 4s - loss: 0.5883 - accuracy: 0.7834 - val_loss: 0.4565 - val_accuracy: 0.8297 - lr: 0.0010 - 4s/epoch - 11ms/step
# Epoch 2/60
#
# Epoch 2: val_accuracy improved from 0.82967 to 0.83967, saving model to _OA_results_FashionMnist_train_with_val/2013/No_Entanglement_pool_summed_avg/run_4FC/No_Entanglement_pool_summed_avg_2013model.keras
# 375/375 - 3s - loss: 0.4364 - accuracy: 0.8386 - val_loss: 0.4412 - val_accuracy: 0.8397 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 3/60
#
# Epoch 3: val_accuracy improved from 0.83967 to 0.85233, saving model to _OA_results_FashionMnist_train_with_val/2013/No_Entanglement_pool_summed_avg/run_4FC/No_Entanglement_pool_summed_avg_2013model.keras
# 375/375 - 4s - loss: 0.3969 - accuracy: 0.8519 - val_loss: 0.3966 - val_accuracy: 0.8523 - lr: 0.0010 - 4s/epoch - 9ms/step
# Epoch 4/60
#
# Epoch 4: val_accuracy did not improve from 0.85233
# 375/375 - 3s - loss: 0.3694 - accuracy: 0.8621 - val_loss: 0.3989 - val_accuracy: 0.8504 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 5/60
#
# Epoch 5: val_accuracy improved from 0.85233 to 0.85342, saving model to _OA_results_FashionMnist_train_with_val/2013/No_Entanglement_pool_summed_avg/run_4FC/No_Entanglement_pool_summed_avg_2013model.keras
# 375/375 - 3s - loss: 0.3537 - accuracy: 0.8672 - val_loss: 0.3859 - val_accuracy: 0.8534 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 6/60
#
# Epoch 6: val_accuracy improved from 0.85342 to 0.85767, saving model to _OA_results_FashionMnist_train_with_val/2013/No_Entanglement_pool_summed_avg/run_4FC/No_Entanglement_pool_summed_avg_2013model.keras
# 375/375 - 3s - loss: 0.3411 - accuracy: 0.8714 - val_loss: 0.3767 - val_accuracy: 0.8577 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 7/60
#
# Epoch 7: val_accuracy improved from 0.85767 to 0.86375, saving model to _OA_results_FashionMnist_train_with_val/2013/No_Entanglement_pool_summed_avg/run_4FC/No_Entanglement_pool_summed_avg_2013model.keras
# 375/375 - 3s - loss: 0.3209 - accuracy: 0.8783 - val_loss: 0.3627 - val_accuracy: 0.8637 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 8/60
#
# Epoch 8: val_accuracy did not improve from 0.86375
# 375/375 - 3s - loss: 0.3129 - accuracy: 0.8807 - val_loss: 0.3841 - val_accuracy: 0.8617 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 9/60
#
# Epoch 9: val_accuracy improved from 0.86375 to 0.86517, saving model to _OA_results_FashionMnist_train_with_val/2013/No_Entanglement_pool_summed_avg/run_4FC/No_Entanglement_pool_summed_avg_2013model.keras
# 375/375 - 3s - loss: 0.2990 - accuracy: 0.8865 - val_loss: 0.3638 - val_accuracy: 0.8652 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 10/60
#
# Epoch 10: val_accuracy improved from 0.86517 to 0.87225, saving model to _OA_results_FashionMnist_train_with_val/2013/No_Entanglement_pool_summed_avg/run_4FC/No_Entanglement_pool_summed_avg_2013model.keras
# 375/375 - 3s - loss: 0.2889 - accuracy: 0.8909 - val_loss: 0.3558 - val_accuracy: 0.8723 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 11/60
#
# Epoch 11: val_accuracy did not improve from 0.87225
# 375/375 - 3s - loss: 0.2776 - accuracy: 0.8942 - val_loss: 0.3779 - val_accuracy: 0.8633 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 12/60
#
# Epoch 12: val_accuracy did not improve from 0.87225
# 375/375 - 3s - loss: 0.2706 - accuracy: 0.8979 - val_loss: 0.3729 - val_accuracy: 0.8677 - lr: 0.0010 - 3s/epoch - 8ms/step
# Epoch 13/60
#
# Epoch 13: val_accuracy did not improve from 0.87225
# 375/375 - 3s - loss: 0.2608 - accuracy: 0.9017 - val_loss: 0.3782 - val_accuracy: 0.8680 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 14/60
#
# Epoch 14: val_accuracy did not improve from 0.87225
# 375/375 - 3s - loss: 0.2526 - accuracy: 0.9041 - val_loss: 0.3668 - val_accuracy: 0.8712 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 15/60
#
# Epoch 15: val_accuracy improved from 0.87225 to 0.87300, saving model to _OA_results_FashionMnist_train_with_val/2013/No_Entanglement_pool_summed_avg/run_4FC/No_Entanglement_pool_summed_avg_2013model.keras
# 375/375 - 3s - loss: 0.2406 - accuracy: 0.9093 - val_loss: 0.3571 - val_accuracy: 0.8730 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 16/60
#
# Epoch 16: val_accuracy did not improve from 0.87300
# 375/375 - 3s - loss: 0.2310 - accuracy: 0.9119 - val_loss: 0.3796 - val_accuracy: 0.8701 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 17/60
#
# Epoch 17: val_accuracy did not improve from 0.87300
# 375/375 - 3s - loss: 0.2205 - accuracy: 0.9152 - val_loss: 0.3887 - val_accuracy: 0.8723 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 18/60
#
# Epoch 18: val_accuracy did not improve from 0.87300
# 375/375 - 3s - loss: 0.2164 - accuracy: 0.9181 - val_loss: 0.3925 - val_accuracy: 0.8702 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 19/60
#
# Epoch 19: val_accuracy did not improve from 0.87300
# 375/375 - 3s - loss: 0.2092 - accuracy: 0.9194 - val_loss: 0.3935 - val_accuracy: 0.8705 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 20/60
#
# Epoch 20: val_accuracy improved from 0.87300 to 0.87325, saving model to _OA_results_FashionMnist_train_with_val/2013/No_Entanglement_pool_summed_avg/run_4FC/No_Entanglement_pool_summed_avg_2013model.keras
# 375/375 - 3s - loss: 0.1966 - accuracy: 0.9244 - val_loss: 0.3986 - val_accuracy: 0.8733 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 21/60
#
# Epoch 21: val_accuracy did not improve from 0.87325
# 375/375 - 3s - loss: 0.1938 - accuracy: 0.9250 - val_loss: 0.4094 - val_accuracy: 0.8666 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 22/60
#
# Epoch 22: val_accuracy improved from 0.87325 to 0.87450, saving model to _OA_results_FashionMnist_train_with_val/2013/No_Entanglement_pool_summed_avg/run_4FC/No_Entanglement_pool_summed_avg_2013model.keras
# 375/375 - 3s - loss: 0.1809 - accuracy: 0.9302 - val_loss: 0.4102 - val_accuracy: 0.8745 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 23/60
#
# Epoch 23: val_accuracy did not improve from 0.87450
# 375/375 - 3s - loss: 0.1741 - accuracy: 0.9337 - val_loss: 0.4317 - val_accuracy: 0.8709 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 24/60
#
# Epoch 24: val_accuracy did not improve from 0.87450
# 375/375 - 3s - loss: 0.1635 - accuracy: 0.9378 - val_loss: 0.4489 - val_accuracy: 0.8696 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 25/60
#
# Epoch 25: val_accuracy did not improve from 0.87450
# 375/375 - 3s - loss: 0.1596 - accuracy: 0.9386 - val_loss: 0.4305 - val_accuracy: 0.8737 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 26/60
#
# Epoch 26: val_accuracy did not improve from 0.87450
# 375/375 - 3s - loss: 0.1502 - accuracy: 0.9425 - val_loss: 0.4532 - val_accuracy: 0.8704 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 27/60
#
# Epoch 27: val_accuracy did not improve from 0.87450
# 375/375 - 3s - loss: 0.1485 - accuracy: 0.9428 - val_loss: 0.4842 - val_accuracy: 0.8652 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 28/60
#
# Epoch 28: val_accuracy did not improve from 0.87450
# 375/375 - 3s - loss: 0.1407 - accuracy: 0.9471 - val_loss: 0.4734 - val_accuracy: 0.8735 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 29/60
#
# Epoch 29: val_accuracy did not improve from 0.87450
# 375/375 - 3s - loss: 0.1321 - accuracy: 0.9489 - val_loss: 0.5208 - val_accuracy: 0.8643 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 30/60
#
# Epoch 30: val_accuracy did not improve from 0.87450
# 375/375 - 3s - loss: 0.1281 - accuracy: 0.9498 - val_loss: 0.5040 - val_accuracy: 0.8683 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 31/60
#
# Epoch 31: val_accuracy did not improve from 0.87450
# 375/375 - 3s - loss: 0.1256 - accuracy: 0.9519 - val_loss: 0.5380 - val_accuracy: 0.8700 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 32/60
#
# Epoch 32: val_accuracy did not improve from 0.87450
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 375/375 - 3s - loss: 0.1128 - accuracy: 0.9571 - val_loss: 0.5516 - val_accuracy: 0.8677 - lr: 0.0010 - 3s/epoch - 9ms/step
# Epoch 33/60
#
# Epoch 33: val_accuracy improved from 0.87450 to 0.87767, saving model to _OA_results_FashionMnist_train_with_val/2013/No_Entanglement_pool_summed_avg/run_4FC/No_Entanglement_pool_summed_avg_2013model.keras
# 375/375 - 3s - loss: 0.0651 - accuracy: 0.9766 - val_loss: 0.5389 - val_accuracy: 0.8777 - lr: 1.0000e-04 - 3s/epoch - 9ms/step
# Epoch 34/60
#
# Epoch 34: val_accuracy did not improve from 0.87767
# 375/375 - 3s - loss: 0.0529 - accuracy: 0.9822 - val_loss: 0.5553 - val_accuracy: 0.8777 - lr: 1.0000e-04 - 3s/epoch - 9ms/step
# Epoch 35/60
#
# Epoch 35: val_accuracy improved from 0.87767 to 0.88075, saving model to _OA_results_FashionMnist_train_with_val/2013/No_Entanglement_pool_summed_avg/run_4FC/No_Entanglement_pool_summed_avg_2013model.keras
# 375/375 - 3s - loss: 0.0487 - accuracy: 0.9839 - val_loss: 0.5670 - val_accuracy: 0.8808 - lr: 1.0000e-04 - 3s/epoch - 9ms/step
# Epoch 36/60
#
# Epoch 36: val_accuracy did not improve from 0.88075
# 375/375 - 3s - loss: 0.0456 - accuracy: 0.9854 - val_loss: 0.5832 - val_accuracy: 0.8767 - lr: 1.0000e-04 - 3s/epoch - 9ms/step
# Epoch 37/60
#
# Epoch 37: val_accuracy did not improve from 0.88075
# 375/375 - 3s - loss: 0.0430 - accuracy: 0.9861 - val_loss: 0.5966 - val_accuracy: 0.8790 - lr: 1.0000e-04 - 3s/epoch - 9ms/step
# Epoch 38/60
#
# Epoch 38: val_accuracy did not improve from 0.88075
# 375/375 - 3s - loss: 0.0407 - accuracy: 0.9872 - val_loss: 0.6084 - val_accuracy: 0.8773 - lr: 1.0000e-04 - 3s/epoch - 9ms/step
# Epoch 39/60
#
# Epoch 39: val_accuracy did not improve from 0.88075
# 375/375 - 3s - loss: 0.0386 - accuracy: 0.9882 - val_loss: 0.6177 - val_accuracy: 0.8775 - lr: 1.0000e-04 - 3s/epoch - 9ms/step
# Epoch 40/60
#
# Epoch 40: val_accuracy did not improve from 0.88075
# 375/375 - 3s - loss: 0.0366 - accuracy: 0.9891 - val_loss: 0.6371 - val_accuracy: 0.8774 - lr: 1.0000e-04 - 3s/epoch - 9ms/step
# Epoch 41/60
#
# Epoch 41: val_accuracy did not improve from 0.88075
# 375/375 - 3s - loss: 0.0345 - accuracy: 0.9897 - val_loss: 0.6449 - val_accuracy: 0.8779 - lr: 1.0000e-04 - 3s/epoch - 9ms/step
# Epoch 42/60
#
# Epoch 42: val_accuracy did not improve from 0.88075
# 375/375 - 3s - loss: 0.0325 - accuracy: 0.9903 - val_loss: 0.6550 - val_accuracy: 0.8765 - lr: 1.0000e-04 - 3s/epoch - 9ms/step
# Epoch 43/60
#
# Epoch 43: val_accuracy did not improve from 0.88075
# 375/375 - 3s - loss: 0.0307 - accuracy: 0.9913 - val_loss: 0.6698 - val_accuracy: 0.8767 - lr: 1.0000e-04 - 3s/epoch - 9ms/step
# Epoch 44/60
#
# Epoch 44: val_accuracy did not improve from 0.88075
# 375/375 - 3s - loss: 0.0289 - accuracy: 0.9919 - val_loss: 0.6880 - val_accuracy: 0.8778 - lr: 1.0000e-04 - 3s/epoch - 9ms/step
# Epoch 45/60
#
# Epoch 45: val_accuracy did not improve from 0.88075
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 375/375 - 3s - loss: 0.0276 - accuracy: 0.9921 - val_loss: 0.6965 - val_accuracy: 0.8767 - lr: 1.0000e-04 - 3s/epoch - 9ms/step
# Epoch 46/60
#
# Epoch 46: val_accuracy did not improve from 0.88075
# 375/375 - 3s - loss: 0.0230 - accuracy: 0.9945 - val_loss: 0.6972 - val_accuracy: 0.8784 - lr: 1.0000e-05 - 3s/epoch - 9ms/step
# Epoch 47/60
#
# Epoch 47: val_accuracy did not improve from 0.88075
# 375/375 - 3s - loss: 0.0221 - accuracy: 0.9948 - val_loss: 0.7015 - val_accuracy: 0.8783 - lr: 1.0000e-05 - 3s/epoch - 9ms/step
# Epoch 48/60
#
# Epoch 48: val_accuracy did not improve from 0.88075
# 375/375 - 3s - loss: 0.0218 - accuracy: 0.9950 - val_loss: 0.7043 - val_accuracy: 0.8792 - lr: 1.0000e-05 - 3s/epoch - 9ms/step
# Epoch 49/60
#
# Epoch 49: val_accuracy did not improve from 0.88075
# 375/375 - 3s - loss: 0.0215 - accuracy: 0.9952 - val_loss: 0.7062 - val_accuracy: 0.8787 - lr: 1.0000e-05 - 3s/epoch - 9ms/step
# Epoch 50/60
# Restoring model weights from the end of the best epoch: 35.
#
# Epoch 50: val_accuracy did not improve from 0.88075
# 375/375 - 3s - loss: 0.0213 - accuracy: 0.9952 - val_loss: 0.7096 - val_accuracy: 0.8786 - lr: 1.0000e-05 - 3s/epoch - 9ms/step
# Epoch 50: early stopping

# %%
symmetry = np.asarray([1,2,3,0])
symmetry = ''.join(map(str,config))
Entanglement_pooled_file_name = f"{train_layer.name}/{symmetry}/Entanglement_pooled_{_[2:-7]}_{symmetry}" 
# Too long to load: almost 5mins => think of other way probably to save and laod
Entanglement_pooled_sample = joblib.load(f'{Entanglement_pooled_file_name}.joblib')

# %%
len(Entanglement_pooled_sample[0])
# Out:
# 196
