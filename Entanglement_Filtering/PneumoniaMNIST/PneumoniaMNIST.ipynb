# %%
# importing sys
import sys
# This is how you import modules that exist outside of working directory 
# adding mosaique to the system path
sys.path.insert(1, '/workspaces/QML-QPF/mosaiQue') 
sys.path.insert(1, '/workspaces/QML-QPF/Quantifying_Entanglement')

import mosaique as mq
import scipy
from concurrent.futures import ProcessPoolExecutor, as_completed
import itertools
import numpy as np
import pennylane as qml
import os
from mosaique.models.operation import OperationLayer
from tensorflow import keras
import tensorflow as tf 
import time
from Entropy import compute_entropy_for_pair_batch
# Out:
# 2026-02-08 09:34:15.513252: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-08 09:34:15.564881: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# if the below cell raise this error [ModuleNotFoundError: No module named 'tensorrt']
# uncomment and run the next line, then restart the kernel 
# pip install tensorrt

# %% [markdown]
# ## Check GPU installation is working

# %%
import tensorrt as trt

print(f' tensorflow version {tf.__version__}')

print(f' tensorrt version {trt.__version__}')

print(tf.config.list_physical_devices('GPU'))
# Out:
#  tensorflow version 2.15.0
#  tensorrt version 10.12.0.36
# []

# %%
# Set the environment for asynchronous GPU usage
os.environ['TF_GPU_ALLOCATOR'] = 'cuda_malloc_async'

# %%
def operation():
    dev = qml.device("default.qubit.tf", wires=4)
    @qml.qnode(dev, interface='tf')
    def cnot(inputs):
        inputs = inputs * np.pi
        qml.AngleEmbedding(inputs[:,...], wires=range(4), rotation='Y')

        qml.CNOT(wires=[0, 1])
        qml.CNOT(wires=[2, 3])

        # Measurement producing 4 classical output values
        return [qml.expval(qml.PauliZ(j)) for j in range(4)]
    return cnot

# %%
def preset():
    # Import the images
    from medmnist import PneumoniaMNIST
    # size of the images 
    size = 64
    # we'll run the code for 64 to see if we'll get different results
    train_data = PneumoniaMNIST(split="train", download=True,size=size)
    test_data = PneumoniaMNIST(split="test", download=True,size=size)
    # name of the folder where will save the filtered images for training
    tr_layer = mq.ConvolutionLayer4x4("_OA_results_PneumoniaMNIST_train_with_val_64")
    # name of the folder where will save the filtered images for testing
    te_layer = mq.ConvolutionLayer4x4("_OA_results_PneumoniaMNIST_test_with_val_64")
    
    #load the data set want to train
    (tr_images, tr_labels), (te_images, te_labels) = (train_data.imgs, train_data.labels), (test_data.imgs, test_data.labels)
    # tr_size, tr_h, tr_w, te_size, te_h, te_w = *tr_images.shape, *te_images.shape
    # tr_images, te_images = tr_images.reshape(tr_size, tr_h, tr_w, 1), te_images.reshape(te_size, te_h, te_w, 1)
    
  
    tr_layer.fit(tr_images)
    te_layer.fit(te_images)
    # here is the problem wit transform : shape
    tr_images = tr_layer.transform(tr_images)
    te_images = te_layer.transform(te_images)
    return ((tr_layer, (tr_images, tr_labels)), (te_layer,(te_images, te_labels)))

with ProcessPoolExecutor() as executor:
    future = executor.submit(preset)

((train_layer, (train_images, train_labels)), (test_layer,(test_images, test_labels))) = future.result() #This blocks until the task completes

# %%
permutations = np.asarray(list(itertools.permutations(range(4))))

def pool(x, call, p, l):
    op = OperationLayer(call())
    predict = l.post_transform(op.pre_op.predict(x,batch_size=1000))
    l.save(predict, p)

# %%
# # not using PorcessPoolExecutor

# for p in permutations:
#     pool(train_images[:,:,p],)

# %%
for j in range(3):
    with ProcessPoolExecutor(8) as executor:
        runner = {
            executor.submit(pool, x=train_images[:,:,p], call=operation, p=p, l=train_layer): p for p in permutations[8*j:8*(j+1)]
        }
        for future in as_completed(runner):
            runner.pop(future)
# Out:
# 5/5 [==============================] - 12s 2s/step
# 5/5 [==============================] - 14s 3s/step
# 5/5 [==============================] - 14s 2s/step
# 5/5 [==============================] - 14s 3s/step
# 5/5 [==============================] - 15s 2s/step
# 5/5 [==============================] - 15s 2s/step
# 5/5 [==============================] - 15s 2s/step
# 5/5 [==============================] - 14s 2s/step
# 5/5 [==============================] - 12s 2s/step
# 5/5 [==============================] - 13s 2s/step
# 5/5 [==============================] - 13s 2s/step
# 5/5 [==============================] - 13s 2s/step
# 5/5 [==============================] - 13s 2s/step
# 5/5 [==============================] - 13s 2s/step
# 5/5 [==============================] - 14s 2s/step
# 5/5 [==============================] - 13s 2s/step
# 5/5 [==============================] - 12s 2s/step
# 5/5 [==============================] - 12s 2s/step
# 5/5 [==============================] - 12s 2s/step
# 5/5 [==============================] - 13s 2s/step
# 5/5 [==============================] - 13s 2s/step
# 5/5 [==============================] - 13s 2s/step
# 5/5 [==============================] - 14s 2s/step
# 5/5 [==============================] - 13s 2s/step

# %%
for j in range(3):
    with ProcessPoolExecutor(8) as executor:
        runner = {
            executor.submit(pool, x=test_images[:,:,p], call=operation, p=p, l=test_layer): p for p in permutations[8*j:8*(j+1)]
        }
        for future in as_completed(runner):
            runner.pop(future)
# Out:
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step

# %% [markdown]
# ## Filtering Data by Entropy degree

# %%
# --- Function to process a single input type ---
def process_input_type(input_data, config, entropy_dict_for_symm):
    """
    Helper function to encapsulate the parallel processing logic for one input type.
    """
    input_system_03 = input_data[:, :, :2]
    input_system_21 = input_data[:, :, 2:4] # Assuming the same slicing  input_system_03 = input_data[:, :, :2]

    task_inputs = list(zip(input_system_03, input_system_21))
    # print("Im inside process_input_type")
    # print("len of task inputs is ", len(task_inputs) )
    # print(f"\nStarting parallel entropy computation for {data_name} data ({len(task_inputs)} batches)...")
    type_start_time = time.time()
    # from collections import defaultdict

    # entropy_dict_for_symm = defaultdict(list)   # missing keys become []
    # config = ''.join(map(str, config)) 
    with ProcessPoolExecutor(max_workers=None) as executor:
        results_iterator = executor.map(compute_entropy_for_pair_batch, task_inputs)

        for i, result in enumerate(results_iterator):
            # print(f"i is {i} and result is {type(result)} len {len(result)}")
            (avg_s1_rho0, avg_s1_rho1), \
            (avg_s2_rho0, avg_s2_rho1), \
            (max_s1_rho0, max_s1_rho1), \
            (max_s2_rho0, max_s2_rho1), \
            (S1_rho_0), \
            (S1_rho_1), \
            (S2_rho_0), \
            (S2_rho_1) = result
            
            # Append to the lists directly from the dictionary
            # Using dictionary keys here
            entropy_dict_for_symm['Total_Avg_' + config + '_Entropy_S1'].append((avg_s1_rho0, avg_s1_rho1))
            entropy_dict_for_symm['Total_Avg_' + config + '_Entropy_S2'].append((avg_s2_rho0, avg_s2_rho1))
            entropy_dict_for_symm['Total_Max_' + config + '_Entropy_S1'].append((max_s1_rho0, max_s1_rho1))
            entropy_dict_for_symm['Total_Max_' + config + '_Entropy_S2'].append((max_s2_rho0, max_s2_rho1))
            # New ones to capture pair entanglement for subsequent filtering
            entropy_dict_for_symm['S1_rho_0_' + config + '_Entropy_S1_0'].append(S1_rho_0)
            entropy_dict_for_symm['S1_rho_1_' + config + '_Entropy_S1_1'].append(S1_rho_1)
            entropy_dict_for_symm['S2_rho_0_' + config + '_Entropy_S2_0'].append(S2_rho_0)
            entropy_dict_for_symm['S2_rho_1_' + config + '_Entropy_S2_1'].append(S2_rho_1)

            if (i + 1) % 100 == 0:
                print(f"Processed {i + 1}/{len(task_inputs)} batches for {config}.")
                
        
        # Convert lists to NumPy arrays
        entropy_dict_for_symm['Total_Avg_' + config + '_Entropy_S1'] = np.array(entropy_dict_for_symm['Total_Avg_' + config + '_Entropy_S1'])
        entropy_dict_for_symm['Total_Avg_' + config + '_Entropy_S2'] = np.array(entropy_dict_for_symm['Total_Avg_' + config + '_Entropy_S2'])
        entropy_dict_for_symm['Total_Max_' + config + '_Entropy_S1'] = np.array(entropy_dict_for_symm['Total_Max_' + config + '_Entropy_S1'])
        entropy_dict_for_symm['Total_Max_' + config + '_Entropy_S2'] = np.array(entropy_dict_for_symm['Total_Max_' + config + '_Entropy_S2'])
        # New ones to capture pair entanglement for subsequent filtering
        entropy_dict_for_symm['S1_rho_0_' + config + '_Entropy_S1_0']  = np.array(entropy_dict_for_symm['S1_rho_0_' + config + '_Entropy_S1_0'])    
        entropy_dict_for_symm['S1_rho_1_' + config + '_Entropy_S1_1']  = np.array(entropy_dict_for_symm['S1_rho_1_' + config + '_Entropy_S1_1'])
        entropy_dict_for_symm['S2_rho_0_' + config + '_Entropy_S2_0']  = np.array(entropy_dict_for_symm['S2_rho_0_' + config + '_Entropy_S2_0'])
        entropy_dict_for_symm['S2_rho_1_' + config + '_Entropy_S2_1']  = np.array(entropy_dict_for_symm['S2_rho_1_' + config + '_Entropy_S2_1'])
        
        # compute the total entry of the entire system S1 + S2
        # Compute the total entropy of the entire system S1 + S2
        # Ensure avg_s1_array and avg_s2_array are in the correct shape (N, 2)
        # The output of compute_entropy_for_pair_batch is (rho0, rho1) tuples, which will become (N, 2) arrays.
        entropy_dict_for_symm['Total_Avg_' + config + '_Entropy_S1_S2'] = entropy_dict_for_symm['Total_Avg_' + config + '_Entropy_S1'] \
                                                                            + entropy_dict_for_symm['Total_Avg_' + config + '_Entropy_S2']
        entropy_dict_for_symm[f'Total_Max_{config}_Entropy_S1_S2'] = entropy_dict_for_symm['Total_Max_' + config + '_Entropy_S1'] \
                                                                            + entropy_dict_for_symm['Total_Max_' + config + '_Entropy_S2']

    # --- Saving Data as CSV ---
    # 1. Create the data_name specific folder

    entropy_folder_name = train_layer.name + f"/{config}/Entropy"
    # train
    # entropy_folder_name = "_OA_train"
    output_folder_path = os.path.join(entropy_folder_name) # Replace spaces for folder names
    os.makedirs(output_folder_path, exist_ok=True)
    print(f"Created/Ensured directory: {output_folder_path}")

    # 2. Save each list/array corresponding to each key as a CSV file
    for key, value in entropy_dict_for_symm.items():
        if isinstance(value, np.ndarray): # Only save if it's a NumPy array
            file_path = os.path.join(output_folder_path, f"{key}.csv")
            # Use fmt='%.8f' for float formatting, delimiter=',' for CSV
            np.savetxt(file_path, value, delimiter=',', fmt='%.8f')
            print(f"Saved {key}.csv to {output_folder_path}")
        else:
            print(f"Skipping saving for key '{key}' as it's not a NumPy array (type: {type(value)})")
    type_end_time = time.time()
    print(f"Finished parallel computation for data for config {config} in {type_end_time - type_start_time:.2f} seconds.")

# %%
# checked
D = {    #  configuration that yields the best validation accuracy
    "Configs": { 
                "P_diagonal_config" : np.asarray([0,3,2,1]),
                "P_vertical_config" : np.asarray([2,3,0,1]),
                "P_horizontal_config" : np.asarray([3,1,0,2])
              }
    }
D_configs = D["Configs"].values()

# %%
# Scaling data
scaled_sample = train_images/255.
# Encoding data using angle encoding
scaled_sample = scaled_sample * np.pi
from collections import defaultdict


for config in D_configs:
    # rearranging the input in respect to the configs
    input = scaled_sample[:,:,config]

    entropy_dict_for_symm = defaultdict(list)   # missing keys become []
    config = ''.join(map(str, config))
    process_input_type(input, config, entropy_dict_for_symm)
    # break
# Out:
# Processed 100/4708 batches for 0321.
# Processed 200/4708 batches for 0321.
# Processed 300/4708 batches for 0321.
# Processed 400/4708 batches for 0321.
# Processed 500/4708 batches for 0321.
# Processed 600/4708 batches for 0321.
# Processed 700/4708 batches for 0321.
# Processed 800/4708 batches for 0321.
# Processed 900/4708 batches for 0321.
# Processed 1000/4708 batches for 0321.
# Processed 1100/4708 batches for 0321.
# Processed 1200/4708 batches for 0321.
# Processed 1300/4708 batches for 0321.
# Processed 1400/4708 batches for 0321.
# Processed 1500/4708 batches for 0321.
# Processed 1600/4708 batches for 0321.
# Processed 1700/4708 batches for 0321.
# Processed 1800/4708 batches for 0321.
# Processed 1900/4708 batches for 0321.
# Processed 2000/4708 batches for 0321.
# Processed 2100/4708 batches for 0321.
# Processed 2200/4708 batches for 0321.
# Processed 2300/4708 batches for 0321.
# Processed 2400/4708 batches for 0321.
# Processed 2500/4708 batches for 0321.
# Processed 2600/4708 batches for 0321.
# Processed 2700/4708 batches for 0321.
# Processed 2800/4708 batches for 0321.
# Processed 2900/4708 batches for 0321.
# Processed 3000/4708 batches for 0321.
# Processed 3100/4708 batches for 0321.
# Processed 3200/4708 batches for 0321.
# Processed 3300/4708 batches for 0321.
# Processed 3400/4708 batches for 0321.
# Processed 3500/4708 batches for 0321.
# Processed 3600/4708 batches for 0321.
# Processed 3700/4708 batches for 0321.
# Processed 3800/4708 batches for 0321.
# Processed 3900/4708 batches for 0321.
# Processed 4000/4708 batches for 0321.
# Processed 4100/4708 batches for 0321.
# Processed 4200/4708 batches for 0321.
# Processed 4300/4708 batches for 0321.
# Processed 4400/4708 batches for 0321.
# Processed 4500/4708 batches for 0321.
# Processed 4600/4708 batches for 0321.
# Processed 4700/4708 batches for 0321.
# Created/Ensured directory: _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entropy
# Saved Total_Avg_0321_Entropy_S1.csv to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entropy
# Saved Total_Avg_0321_Entropy_S2.csv to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entropy
# Saved Total_Max_0321_Entropy_S1.csv to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entropy
# Saved Total_Max_0321_Entropy_S2.csv to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entropy
# Saved S1_rho_0_0321_Entropy_S1_0.csv to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entropy
# Saved S1_rho_1_0321_Entropy_S1_1.csv to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entropy
# Saved S2_rho_0_0321_Entropy_S2_0.csv to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entropy
# Saved S2_rho_1_0321_Entropy_S2_1.csv to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entropy
# Saved Total_Avg_0321_Entropy_S1_S2.csv to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entropy
# Saved Total_Max_0321_Entropy_S1_S2.csv to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entropy
# Finished parallel computation for data for config 0321 in 11.42 seconds.
# Processed 100/4708 batches for 2301.
# Processed 200/4708 batches for 2301.
# Processed 300/4708 batches for 2301.
# Processed 400/4708 batches for 2301.
# Processed 500/4708 batches for 2301.
# Processed 600/4708 batches for 2301.
# Processed 700/4708 batches for 2301.
# Processed 800/4708 batches for 2301.
# Processed 900/4708 batches for 2301.
# Processed 1000/4708 batches for 2301.
# Processed 1100/4708 batches for 2301.
# Processed 1200/4708 batches for 2301.
# Processed 1300/4708 batches for 2301.
# Processed 1400/4708 batches for 2301.
# Processed 1500/4708 batches for 2301.
# Processed 1600/4708 batches for 2301.
# Processed 1700/4708 batches for 2301.
# Processed 1800/4708 batches for 2301.
# Processed 1900/4708 batches for 2301.
# Processed 2000/4708 batches for 2301.
# Processed 2100/4708 batches for 2301.
# Processed 2200/4708 batches for 2301.
# Processed 2300/4708 batches for 2301.
# Processed 2400/4708 batches for 2301.
# Processed 2500/4708 batches for 2301.
# Processed 2600/4708 batches for 2301.
# Processed 2700/4708 batches for 2301.
# Processed 2800/4708 batches for 2301.
# Processed 2900/4708 batches for 2301.
# Processed 3000/4708 batches for 2301.
# Processed 3100/4708 batches for 2301.
# Processed 3200/4708 batches for 2301.
# Processed 3300/4708 batches for 2301.
# Processed 3400/4708 batches for 2301.
# Processed 3500/4708 batches for 2301.
# Processed 3600/4708 batches for 2301.
# Processed 3700/4708 batches for 2301.
# Processed 3800/4708 batches for 2301.
# Processed 3900/4708 batches for 2301.
# Processed 4000/4708 batches for 2301.
# Processed 4100/4708 batches for 2301.
# Processed 4200/4708 batches for 2301.
# Processed 4300/4708 batches for 2301.
# Processed 4400/4708 batches for 2301.
# Processed 4500/4708 batches for 2301.
# Processed 4600/4708 batches for 2301.
# Processed 4700/4708 batches for 2301.
# Created/Ensured directory: _OA_results_PneumoniaMNIST_train_with_val_64/2301/Entropy
# Saved Total_Avg_2301_Entropy_S1.csv to _OA_results_PneumoniaMNIST_train_with_val_64/2301/Entropy
# Saved Total_Avg_2301_Entropy_S2.csv to _OA_results_PneumoniaMNIST_train_with_val_64/2301/Entropy
# Saved Total_Max_2301_Entropy_S1.csv to _OA_results_PneumoniaMNIST_train_with_val_64/2301/Entropy
# Saved Total_Max_2301_Entropy_S2.csv to _OA_results_PneumoniaMNIST_train_with_val_64/2301/Entropy
# Saved S1_rho_0_2301_Entropy_S1_0.csv to _OA_results_PneumoniaMNIST_train_with_val_64/2301/Entropy
# Saved S1_rho_1_2301_Entropy_S1_1.csv to _OA_results_PneumoniaMNIST_train_with_val_64/2301/Entropy
# Saved S2_rho_0_2301_Entropy_S2_0.csv to _OA_results_PneumoniaMNIST_train_with_val_64/2301/Entropy
# Saved S2_rho_1_2301_Entropy_S2_1.csv to _OA_results_PneumoniaMNIST_train_with_val_64/2301/Entropy
# Saved Total_Avg_2301_Entropy_S1_S2.csv to _OA_results_PneumoniaMNIST_train_with_val_64/2301/Entropy
# Saved Total_Max_2301_Entropy_S1_S2.csv to _OA_results_PneumoniaMNIST_train_with_val_64/2301/Entropy
# Finished parallel computation for data for config 2301 in 11.10 seconds.
# Processed 100/4708 batches for 3102.
# Processed 200/4708 batches for 3102.
# Processed 300/4708 batches for 3102.
# Processed 400/4708 batches for 3102.
# Processed 500/4708 batches for 3102.
# Processed 600/4708 batches for 3102.
# Processed 700/4708 batches for 3102.
# Processed 800/4708 batches for 3102.
# Processed 900/4708 batches for 3102.
# Processed 1000/4708 batches for 3102.
# Processed 1100/4708 batches for 3102.
# Processed 1200/4708 batches for 3102.
# Processed 1300/4708 batches for 3102.
# Processed 1400/4708 batches for 3102.
# Processed 1500/4708 batches for 3102.
# Processed 1600/4708 batches for 3102.
# Processed 1700/4708 batches for 3102.
# Processed 1800/4708 batches for 3102.
# Processed 1900/4708 batches for 3102.
# Processed 2000/4708 batches for 3102.
# Processed 2100/4708 batches for 3102.
# Processed 2200/4708 batches for 3102.
# Processed 2300/4708 batches for 3102.
# Processed 2400/4708 batches for 3102.
# Processed 2500/4708 batches for 3102.
# Processed 2600/4708 batches for 3102.
# Processed 2700/4708 batches for 3102.
# Processed 2800/4708 batches for 3102.
# Processed 2900/4708 batches for 3102.
# Processed 3000/4708 batches for 3102.
# Processed 3100/4708 batches for 3102.
# Processed 3200/4708 batches for 3102.
# Processed 3300/4708 batches for 3102.
# Processed 3400/4708 batches for 3102.
# Processed 3500/4708 batches for 3102.
# Processed 3600/4708 batches for 3102.
# Processed 3700/4708 batches for 3102.
# Processed 3800/4708 batches for 3102.
# Processed 3900/4708 batches for 3102.
# Processed 4000/4708 batches for 3102.
# Processed 4100/4708 batches for 3102.
# Processed 4200/4708 batches for 3102.
# Processed 4300/4708 batches for 3102.
# Processed 4400/4708 batches for 3102.
# Processed 4500/4708 batches for 3102.
# Processed 4600/4708 batches for 3102.
# Processed 4700/4708 batches for 3102.
# Created/Ensured directory: _OA_results_PneumoniaMNIST_train_with_val_64/3102/Entropy
# Saved Total_Avg_3102_Entropy_S1.csv to _OA_results_PneumoniaMNIST_train_with_val_64/3102/Entropy
# Saved Total_Avg_3102_Entropy_S2.csv to _OA_results_PneumoniaMNIST_train_with_val_64/3102/Entropy
# Saved Total_Max_3102_Entropy_S1.csv to _OA_results_PneumoniaMNIST_train_with_val_64/3102/Entropy
# Saved Total_Max_3102_Entropy_S2.csv to _OA_results_PneumoniaMNIST_train_with_val_64/3102/Entropy
# Saved S1_rho_0_3102_Entropy_S1_0.csv to _OA_results_PneumoniaMNIST_train_with_val_64/3102/Entropy
# Saved S1_rho_1_3102_Entropy_S1_1.csv to _OA_results_PneumoniaMNIST_train_with_val_64/3102/Entropy
# Saved S2_rho_0_3102_Entropy_S2_0.csv to _OA_results_PneumoniaMNIST_train_with_val_64/3102/Entropy
# Saved S2_rho_1_3102_Entropy_S2_1.csv to _OA_results_PneumoniaMNIST_train_with_val_64/3102/Entropy
# Saved Total_Avg_3102_Entropy_S1_S2.csv to _OA_results_PneumoniaMNIST_train_with_val_64/3102/Entropy
# Saved Total_Max_3102_Entropy_S1_S2.csv to _OA_results_PneumoniaMNIST_train_with_val_64/3102/Entropy
# Finished parallel computation for data for config 3102 in 11.24 seconds.

# %% [markdown]
# We will focus only in the best 3 configs.

# %%
def open_load_entropy(symmetry, system, dataset_name="PneumoniaMNIST"):
    
    system = str(system)
    file_path = f"/workspaces/QML-QPF/Entanglement_Filtering/PneumoniaMNIST/_OA_results_{dataset_name}_train_with_val_64/{symmetry}/Entropy/S{system}_rho_0_{symmetry}_Entropy_S{system}_0.csv"
    S_rho0 = np.loadtxt(file_path, delimiter=',')
    return S_rho0

# %% [markdown]
# ## Entanglement pooling and saving

# %%
import joblib
import gc

def Entanglement_pooling(input, sample_size, threshold, S1_rho0, S2_rho0,Entanglement_pooled_file_name):
    """
    Function that will filter the output of the quantum circuit based on a threshold e.g. the mean of the entier dataset
    
    """
    # sample_size = reshaped_filtered_input.shape[0]  # number of images
    Entanglement_pooled_sample = list()
    # threshold = 0.106 # The mean of the entire dataset--will update it accordingly
    for i in range(sample_size):
        Entanglement_pooled_img = list()
        for j in range(S1_rho0.shape[-1]):
            #
            tmp_list = list()
            # Checking for S1
            if S1_rho0[i,j] < threshold: # keeping both qubits
                tmp_list.extend(input[i,j,:2]) 
            else: # Keeping only target qubit
                tmp_list.append(input[i,j,1])
                
            # Checking for S2
            if S2_rho0[i,j] < threshold: # keeping both qubits
                tmp_list.extend(input[i,j,2:]) 
            else: # Keeping only target qubit
                tmp_list.append(input[i,j,-1])
            # appending the pooled filtered input to the image
            Entanglement_pooled_img.append(tmp_list)
        # appending the pooled filtered image to the sample
        Entanglement_pooled_sample.append(Entanglement_pooled_img)
        
    joblib.dump(Entanglement_pooled_sample, f'{Entanglement_pooled_file_name}.joblib', compress=3)

    # free memory so the notebook stays fast
    del Entanglement_pooled_sample
    gc.collect()

# %%
import numpy as np

def Entntanglement_pool(input_data, symmetry, Entanglement_pooled_file_name):
    X = input_data.astype(np.float32, copy=False)   # (N,196,4)
    #S1_rho_0_0321_Entropy_S1 : S1_rho_0 = system 1;Entropy_S1 = qubit 1
    S1_rho0 = open_load_entropy(symmetry, 1)
    S2_rho0 = open_load_entropy(symmetry, 2)
    thr1 = S1_rho0.mean(axis=1, keepdims=True)  # (N,1)
    thr2 = S2_rho0.mean(axis=1, keepdims=True)  # (N,1)

    m1 = (S1_rho0 < thr1)  # (N,196)
    m2 = (S2_rho0 < thr2)  # (N,196)

    pooled = np.empty_like(X, dtype=np.float32)
    pooled[..., 0] = X[..., 0] * m1
    pooled[..., 1] = X[..., 1]
    pooled[..., 2] = X[..., 2] * m2
    pooled[..., 3] = X[..., 3]

    np.save(f"{Entanglement_pooled_file_name}.npy", pooled)
    # np.save(f"{Entanglement_pooled_file_name}_thr1.npy", thr1.squeeze().astype(np.float32))  # optional
    # np.save(f"{Entanglement_pooled_file_name}_thr2.npy", thr2.squeeze().astype(np.float32))  # optional

# %% [markdown]
# ### Entanglement pooling the best 3 symmetries from previous experiment

# %%
for _, value in D.items():
    for _, config in value.items():
        # print(symmetry)
        # filtered_input = train_layer.open(config)
        # reshaped_filtered_input = train_layer.transform(filtered_input)
        
        # input with specific symmetry/config to filter based on entropy level
        filtered_input = train_layer.open(config)
        filtered_input = train_layer.transform(filtered_input)
        
        symmetry = ''.join(map(str,config))
        
        # file with _ctr0 : replacing ctr with 0 when Entropy/Entanglement greater than threshold 
        # File namne to store the pooled sample
        Entanglement_pooled_file_name = f"{train_layer.name}/{symmetry}/Entanglement_pooled_{_[2:-7]}_{''.join(map(str,symmetry))}_ctr0"  
        
        # print(Entanglement_pooled_file_name)
        
        Entntanglement_pool(input_data=filtered_input,
                            symmetry=symmetry,\
                            Entanglement_pooled_file_name=Entanglement_pooled_file_name)
        # # Entanglement filtering
        # Entanglement_pooling(input=filtered_input, symmetry=symmetry,\
        #                     sample_size=filtered_input.shape[0],\
        #                     Entanglement_pooled_file_name=Entanglement_pooled_file_name)

# %% [markdown]
# ## Trainign model

# %% [markdown]
# ### Row-Level Padding

# %%
import numpy as np

def pad_jagged_image(image_list, max_c=4):
    # Create a fixed-size buffer of zeros
    padded_img = np.zeros((len(image_list), max_c))
    
    for i, row in enumerate(image_list):
        # row is a 1D array of length 2, 3, or 4
        length = len(row)
        padded_img[i, :length] = row
        
    return padded_img

# %%
from keras.callbacks import CSVLogger, EarlyStopping, ModelCheckpoint, ReduceLROnPlateau



def run(tr_images, label,  run_subfolder, folder_name, patience=15):
    log_dir = train_layer.name + f"/{label}" + f"/{folder_name}/run{run_subfolder}/"   
    # print(' log_dir ', log_dir)
    
    log_file =  log_dir + f"{folder_name}_{label}"
    # print(' log_file ', log_file)
    os.makedirs(log_dir, exist_ok=True)
    
    csv_logger = CSVLogger(log_file)
    
    
    # tensorboard_callback = keras.callbacks.TensorBoard(
    #     log_dir=log_file,
    #     histogram_freq=1,
    #     write_graph=True,
    #     write_images=True,
    #     write_steps_per_second=True,
    #     update_freq='batch',
    #     profile_batch=1,
    #     embeddings_freq=1,
    #     embeddings_metadata=None
    # )
    
    number_of_classes = len(np.unique(test_labels))
    # Chose which model you want to use depending on the number of hidden layers
    # Uncomment your model and run the code--pay attention to your folder/file naming to keep everything organized 
    ####---------------------------------------------------------------------####
    # 1 FC layer
    if run_subfolder == "_1FC":
        # simple ANN model with 0 hidden layers: 1FC
        q_model = keras.models.Sequential([
            keras.layers.Rescaling(scale=-1. / 127.5, offset=1),
            keras.layers.Flatten(),
            keras.layers.Dense(number_of_classes, activation="softmax")
        ])
    
    ####---------------------------------------------------------------------####
    
    # # 2 FC layer
    if run_subfolder == "_2FC":
    
        # simple ANN model with 1 hidden layers: 2FC
        q_model = keras.models.Sequential([
            keras.layers.Rescaling(scale=-1. / 127.5, offset=1),
            keras.layers.Flatten(),
            keras.layers.Dense(512, activation='relu'),
            keras.layers.Dense(number_of_classes, activation="softmax")
        ])
    
    ####---------------------------------------------------------------------####
    # # 3 FC layer
    if run_subfolder == "_3FC":
    
        # simple ANN model with 2 hidden layers: 3FC
        q_model = keras.models.Sequential([
            keras.layers.Rescaling(scale=-1. / 127.5, offset=1),
            keras.layers.Flatten(),
            keras.layers.Dense(512, activation='relu'),
            keras.layers.Dense(256, activation='relu'),
            keras.layers.Dense(number_of_classes, activation='softmax')
        ])
    
    ####---------------------------------------------------------------------####
    # # 4 FC layer
    if run_subfolder == "_4FC": 
        # simple ANN model with 3 hidden layers: 4FC
        q_model = keras.models.Sequential([
            keras.layers.Rescaling(scale=-1. / 127.5, offset=1),
            keras.layers.Flatten(),
            keras.layers.Dense(512, activation='relu'),
            keras.layers.Dense(256, activation='relu'),
            keras.layers.Dense(128, activation='relu'),
            keras.layers.Dense(number_of_classes, activation='softmax')
        ])
    
    ####---------------------------------------------------------------------####
    
    q_model.compile(
        optimizer='adam',
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    
    # 
    batch_size = 128
    epochs = 60
    
    
    # Stop training when a monitored metric has stopped improving.
    Early_stop = EarlyStopping(monitor="val_accuracy",
                                min_delta=0, # Minimum change in the monitored quantity to qualify as an improvement, i.e. an absolute change of less than min_delta, will count as no improvement.
                                patience=patience, # Number of epochs with no improvement after which training will be stopped.
                                verbose=1, # 1 displays messages when the callback takes an action
                                mode="max", # will stop when the quantity monitored has stopped increasing
                                baseline=None,
                                restore_best_weights=True, # to restore model weights from the epoch with the best value of the monitored quantity
                                start_from_epoch=0, #  Number of epochs to wait before starting to monitor improvement.
                            )

    
    # Callback to save the Keras model or model weights at some frequency.
    checkpoint_filepath = log_file  + 'model.keras'
    model_checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath,
                                                monitor='val_accuracy',
                                                mode='max',
                                                verbose=1,
                                                save_best_only=True
                                                )
    # Reduce learning rate when a metric has stopped improving.
    reduce_lr_acc = ReduceLROnPlateau(monitor='val_accuracy',
                                        factor=0.1, # Float. Factor by which the learning rate will be reduced. new_lr = lr * factor.
                                        patience=10, # Integer. Number of epochs with no improvement after which learning rate will be reduced.
                                        verbose=1, # 1: update messages.
                                        mode="max", # 'max' mode it will be reduced when the quantity monitored has stopped increasing
                                        min_delta=0.0001, # Float. Threshold for measuring the new optimum, to only focus on significant changes.
                                        cooldown=0, #  Integer. Number of epochs to wait before resuming normal operation after the learning rate has been reduced.
                                        min_lr=0.0 #  Float. Lower bound on the learning rate.
                                    )


    
    q_history = q_model.fit(
        tr_images,
        train_labels,
        # validation_data=(te_images, test_labels),
        validation_split=0.2,
        batch_size=batch_size,
        epochs=epochs,
        verbose=2,
        # callbacks=[tensorboard_callback]
        callbacks = [Early_stop,csv_logger,model_checkpoint_callback, reduce_lr_acc]
    )

def model(variant, tr_layer):
    tr_images = Ent_pooled_data_padded_0s_array
    
    
    label = ''.join(map(str,Diagonal))


    run(tr_images, label)

# %%
run_subfolders = [f"_{str(i+1)}FC" for i in range(4)]

for _, value in D.items():
    for _, config in value.items():
        # print(symmetry)
        symmetry = ''.join(map(str,config))
        # File namne to store the pooled sample
        Entanglement_pooled_file_name = f"{train_layer.name}/{symmetry}/Entanglement_pooled_{_[2:-7]}_{symmetry}_ctr0" 
        # Too long to load: almost 5mins => think of other way probably to save and laod
        Entanglement_pooled_sample = np.load(f"{Entanglement_pooled_file_name}.npy") 
        approachs = ["Padding_0", "Entanglement_pool_summed", "No_Entanglement_pool_summed_avg"]
        for approach in approachs:
            # Padding with 0s
            if approach == "Padding_0":
                # 
                train_data =  Entanglement_pooled_sample
                # name of the folder for padded data
                folder_name = "Entanglement_pool_padded_0s"
            # Summing the entanglement pooled data
            if approach == "Entanglement_pool_summed":
                train_data = np.array([[sum(p)/len(p) for p in img] for img in Entanglement_pooled_sample])
                # name of the folder for padded data
                folder_name =  "Entanglement_pool_summed"
            
            # if approach == "No_Entanglement_pool_summed_avg":
            #     train_data = train_layer.open(config)
            #     train_data = train_data.mean(axis=-1)    # shape: (N, H, W)
            #     # name 
            #     folder_name =  "No_Entanglement_pool_summed_avg"
                
            for run_subfolder in run_subfolders:
                run(tr_images=train_data, label=symmetry,\
                    run_subfolder=run_subfolder, folder_name=folder_name)
# Out:
# Epoch 1/60
#
# Epoch 1: val_accuracy improved from -inf to 0.91932, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_padded_0s/run_1FC/Entanglement_pool_padded_0s_0321model.keras
# 30/30 - 1s - loss: 0.3797 - accuracy: 0.8391 - val_loss: 0.2087 - val_accuracy: 0.9193 - lr: 0.0010 - 1s/epoch - 37ms/step
# Epoch 2/60
#
# Epoch 2: val_accuracy improved from 0.91932 to 0.94692, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_padded_0s/run_1FC/Entanglement_pool_padded_0s_0321model.keras
# 30/30 - 0s - loss: 0.1712 - accuracy: 0.9328 - val_loss: 0.1527 - val_accuracy: 0.9469 - lr: 0.0010 - 211ms/epoch - 7ms/step
# Epoch 3/60
#
# Epoch 3: val_accuracy did not improve from 0.94692
# 30/30 - 0s - loss: 0.1411 - accuracy: 0.9458 - val_loss: 0.1442 - val_accuracy: 0.9416 - lr: 0.0010 - 177ms/epoch - 6ms/step
# Epoch 4/60
#
# Epoch 4: val_accuracy did not improve from 0.94692
# 30/30 - 0s - loss: 0.1210 - accuracy: 0.9551 - val_loss: 0.1318 - val_accuracy: 0.9469 - lr: 0.0010 - 189ms/epoch - 6ms/step
# Epoch 5/60
#
# Epoch 5: val_accuracy improved from 0.94692 to 0.95435, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_padded_0s/run_1FC/Entanglement_pool_padded_0s_0321model.keras
# 30/30 - 0s - loss: 0.1079 - accuracy: 0.9612 - val_loss: 0.1241 - val_accuracy: 0.9544 - lr: 0.0010 - 210ms/epoch - 7ms/step
# Epoch 6/60
#
# Epoch 6: val_accuracy did not improve from 0.95435
# 30/30 - 0s - loss: 0.0987 - accuracy: 0.9657 - val_loss: 0.1188 - val_accuracy: 0.9512 - lr: 0.0010 - 199ms/epoch - 7ms/step
# Epoch 7/60
#
# Epoch 7: val_accuracy did not improve from 0.95435
# 30/30 - 0s - loss: 0.0915 - accuracy: 0.9668 - val_loss: 0.1343 - val_accuracy: 0.9416 - lr: 0.0010 - 190ms/epoch - 6ms/step
# Epoch 8/60
#
# Epoch 8: val_accuracy improved from 0.95435 to 0.95648, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_padded_0s/run_1FC/Entanglement_pool_padded_0s_0321model.keras
# 30/30 - 0s - loss: 0.0872 - accuracy: 0.9703 - val_loss: 0.1145 - val_accuracy: 0.9565 - lr: 0.0010 - 230ms/epoch - 8ms/step
# Epoch 9/60
#
# Epoch 9: val_accuracy did not improve from 0.95648
# 30/30 - 0s - loss: 0.0798 - accuracy: 0.9713 - val_loss: 0.1125 - val_accuracy: 0.9554 - lr: 0.0010 - 181ms/epoch - 6ms/step
# Epoch 10/60
#
# Epoch 10: val_accuracy improved from 0.95648 to 0.95860, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_padded_0s/run_1FC/Entanglement_pool_padded_0s_0321model.keras
# 30/30 - 0s - loss: 0.0727 - accuracy: 0.9742 - val_loss: 0.1090 - val_accuracy: 0.9586 - lr: 0.0010 - 188ms/epoch - 6ms/step
# Epoch 11/60
#
# Epoch 11: val_accuracy did not improve from 0.95860
# 30/30 - 0s - loss: 0.0692 - accuracy: 0.9777 - val_loss: 0.1407 - val_accuracy: 0.9374 - lr: 0.0010 - 162ms/epoch - 5ms/step
# Epoch 12/60
#
# Epoch 12: val_accuracy did not improve from 0.95860
# 30/30 - 0s - loss: 0.0707 - accuracy: 0.9748 - val_loss: 0.1125 - val_accuracy: 0.9565 - lr: 0.0010 - 165ms/epoch - 6ms/step
# Epoch 13/60
#
# Epoch 13: val_accuracy did not improve from 0.95860
# 30/30 - 0s - loss: 0.0593 - accuracy: 0.9814 - val_loss: 0.1079 - val_accuracy: 0.9586 - lr: 0.0010 - 178ms/epoch - 6ms/step
# Epoch 14/60
#
# Epoch 14: val_accuracy did not improve from 0.95860
# 30/30 - 0s - loss: 0.0564 - accuracy: 0.9833 - val_loss: 0.1166 - val_accuracy: 0.9512 - lr: 0.0010 - 197ms/epoch - 7ms/step
# Epoch 15/60
#
# Epoch 15: val_accuracy did not improve from 0.95860
# 30/30 - 0s - loss: 0.0561 - accuracy: 0.9830 - val_loss: 0.1281 - val_accuracy: 0.9469 - lr: 0.0010 - 190ms/epoch - 6ms/step
# Epoch 16/60
#
# Epoch 16: val_accuracy did not improve from 0.95860
# 30/30 - 0s - loss: 0.0535 - accuracy: 0.9830 - val_loss: 0.1078 - val_accuracy: 0.9586 - lr: 0.0010 - 184ms/epoch - 6ms/step
# Epoch 17/60
#
# Epoch 17: val_accuracy did not improve from 0.95860
# 30/30 - 0s - loss: 0.0481 - accuracy: 0.9862 - val_loss: 0.1217 - val_accuracy: 0.9533 - lr: 0.0010 - 167ms/epoch - 6ms/step
# Epoch 18/60
#
# Epoch 18: val_accuracy did not improve from 0.95860
# 30/30 - 0s - loss: 0.0548 - accuracy: 0.9838 - val_loss: 0.1151 - val_accuracy: 0.9544 - lr: 0.0010 - 183ms/epoch - 6ms/step
# Epoch 19/60
#
# Epoch 19: val_accuracy improved from 0.95860 to 0.95966, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_padded_0s/run_1FC/Entanglement_pool_padded_0s_0321model.keras
# 30/30 - 0s - loss: 0.0451 - accuracy: 0.9867 - val_loss: 0.1112 - val_accuracy: 0.9597 - lr: 0.0010 - 186ms/epoch - 6ms/step
# Epoch 20/60
#
# Epoch 20: val_accuracy did not improve from 0.95966
# 30/30 - 0s - loss: 0.0409 - accuracy: 0.9886 - val_loss: 0.1145 - val_accuracy: 0.9586 - lr: 0.0010 - 156ms/epoch - 5ms/step
# Epoch 21/60
#
# Epoch 21: val_accuracy did not improve from 0.95966
# 30/30 - 0s - loss: 0.0398 - accuracy: 0.9902 - val_loss: 0.1230 - val_accuracy: 0.9522 - lr: 0.0010 - 133ms/epoch - 4ms/step
# Epoch 22/60
#
# Epoch 22: val_accuracy did not improve from 0.95966
# 30/30 - 0s - loss: 0.0395 - accuracy: 0.9883 - val_loss: 0.1126 - val_accuracy: 0.9565 - lr: 0.0010 - 158ms/epoch - 5ms/step
# Epoch 23/60
#
# Epoch 23: val_accuracy did not improve from 0.95966
# 30/30 - 0s - loss: 0.0349 - accuracy: 0.9928 - val_loss: 0.1177 - val_accuracy: 0.9565 - lr: 0.0010 - 157ms/epoch - 5ms/step
# Epoch 24/60
#
# Epoch 24: val_accuracy did not improve from 0.95966
# 30/30 - 0s - loss: 0.0333 - accuracy: 0.9942 - val_loss: 0.1101 - val_accuracy: 0.9597 - lr: 0.0010 - 200ms/epoch - 7ms/step
# Epoch 25/60
#
# Epoch 25: val_accuracy did not improve from 0.95966
# 30/30 - 0s - loss: 0.0315 - accuracy: 0.9947 - val_loss: 0.1117 - val_accuracy: 0.9597 - lr: 0.0010 - 187ms/epoch - 6ms/step
# Epoch 26/60
#
# Epoch 26: val_accuracy improved from 0.95966 to 0.96178, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_padded_0s/run_1FC/Entanglement_pool_padded_0s_0321model.keras
# 30/30 - 0s - loss: 0.0306 - accuracy: 0.9952 - val_loss: 0.1110 - val_accuracy: 0.9618 - lr: 0.0010 - 222ms/epoch - 7ms/step
# Epoch 27/60
#
# Epoch 27: val_accuracy improved from 0.96178 to 0.96285, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_padded_0s/run_1FC/Entanglement_pool_padded_0s_0321model.keras
# 30/30 - 0s - loss: 0.0297 - accuracy: 0.9958 - val_loss: 0.1110 - val_accuracy: 0.9628 - lr: 0.0010 - 213ms/epoch - 7ms/step
# Epoch 28/60
#
# Epoch 28: val_accuracy did not improve from 0.96285
# 30/30 - 0s - loss: 0.0274 - accuracy: 0.9965 - val_loss: 0.1167 - val_accuracy: 0.9607 - lr: 0.0010 - 201ms/epoch - 7ms/step
# Epoch 29/60
#
# Epoch 29: val_accuracy did not improve from 0.96285
# 30/30 - 0s - loss: 0.0268 - accuracy: 0.9979 - val_loss: 0.1156 - val_accuracy: 0.9597 - lr: 0.0010 - 218ms/epoch - 7ms/step
# Epoch 30/60
#
# Epoch 30: val_accuracy did not improve from 0.96285
# 30/30 - 0s - loss: 0.0258 - accuracy: 0.9960 - val_loss: 0.1156 - val_accuracy: 0.9586 - lr: 0.0010 - 189ms/epoch - 6ms/step
# Epoch 31/60
#
# Epoch 31: val_accuracy did not improve from 0.96285
# 30/30 - 0s - loss: 0.0245 - accuracy: 0.9981 - val_loss: 0.1143 - val_accuracy: 0.9607 - lr: 0.0010 - 191ms/epoch - 6ms/step
# Epoch 32/60
#
# Epoch 32: val_accuracy did not improve from 0.96285
# 30/30 - 0s - loss: 0.0233 - accuracy: 0.9968 - val_loss: 0.1191 - val_accuracy: 0.9607 - lr: 0.0010 - 210ms/epoch - 7ms/step
# Epoch 33/60
#
# Epoch 33: val_accuracy did not improve from 0.96285
# 30/30 - 0s - loss: 0.0224 - accuracy: 0.9984 - val_loss: 0.1177 - val_accuracy: 0.9628 - lr: 0.0010 - 180ms/epoch - 6ms/step
# Epoch 34/60
#
# Epoch 34: val_accuracy did not improve from 0.96285
# 30/30 - 0s - loss: 0.0221 - accuracy: 0.9984 - val_loss: 0.1193 - val_accuracy: 0.9607 - lr: 0.0010 - 185ms/epoch - 6ms/step
# Epoch 35/60
#
# Epoch 35: val_accuracy did not improve from 0.96285
# 30/30 - 0s - loss: 0.0208 - accuracy: 0.9984 - val_loss: 0.1172 - val_accuracy: 0.9586 - lr: 0.0010 - 182ms/epoch - 6ms/step
# Epoch 36/60
#
# Epoch 36: val_accuracy did not improve from 0.96285
# 30/30 - 0s - loss: 0.0202 - accuracy: 0.9989 - val_loss: 0.1204 - val_accuracy: 0.9597 - lr: 0.0010 - 182ms/epoch - 6ms/step
# Epoch 37/60
#
# Epoch 37: val_accuracy did not improve from 0.96285
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 30/30 - 0s - loss: 0.0196 - accuracy: 0.9989 - val_loss: 0.1216 - val_accuracy: 0.9575 - lr: 0.0010 - 171ms/epoch - 6ms/step
# Epoch 38/60
#
# Epoch 38: val_accuracy did not improve from 0.96285
# 30/30 - 0s - loss: 0.0181 - accuracy: 0.9995 - val_loss: 0.1185 - val_accuracy: 0.9597 - lr: 1.0000e-04 - 173ms/epoch - 6ms/step
# Epoch 39/60
#
# Epoch 39: val_accuracy did not improve from 0.96285
# 30/30 - 0s - loss: 0.0174 - accuracy: 0.9995 - val_loss: 0.1196 - val_accuracy: 0.9597 - lr: 1.0000e-04 - 173ms/epoch - 6ms/step
# Epoch 40/60
#
# Epoch 40: val_accuracy did not improve from 0.96285
# 30/30 - 0s - loss: 0.0172 - accuracy: 0.9995 - val_loss: 0.1190 - val_accuracy: 0.9597 - lr: 1.0000e-04 - 170ms/epoch - 6ms/step
# Epoch 41/60
#
# Epoch 41: val_accuracy did not improve from 0.96285
# 30/30 - 0s - loss: 0.0171 - accuracy: 0.9992 - val_loss: 0.1190 - val_accuracy: 0.9607 - lr: 1.0000e-04 - 168ms/epoch - 6ms/step
# Epoch 42/60
# Restoring model weights from the end of the best epoch: 27.
#
# Epoch 42: val_accuracy did not improve from 0.96285
# 30/30 - 0s - loss: 0.0170 - accuracy: 0.9992 - val_loss: 0.1195 - val_accuracy: 0.9597 - lr: 1.0000e-04 - 174ms/epoch - 6ms/step
# Epoch 42: early stopping
# Epoch 1/60
#
# Epoch 1: val_accuracy improved from -inf to 0.92463, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_padded_0s/run_2FC/Entanglement_pool_padded_0s_0321model.keras
# 30/30 - 2s - loss: 0.9654 - accuracy: 0.8415 - val_loss: 0.2414 - val_accuracy: 0.9246 - lr: 0.0010 - 2s/epoch - 56ms/step
# Epoch 2/60
#
# Epoch 2: val_accuracy improved from 0.92463 to 0.93843, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_padded_0s/run_2FC/Entanglement_pool_padded_0s_0321model.keras
# 30/30 - 0s - loss: 0.1626 - accuracy: 0.9424 - val_loss: 0.1522 - val_accuracy: 0.9384 - lr: 0.0010 - 454ms/epoch - 15ms/step
# Epoch 3/60
#
# Epoch 3: val_accuracy improved from 0.93843 to 0.94904, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_padded_0s/run_2FC/Entanglement_pool_padded_0s_0321model.keras
# 30/30 - 0s - loss: 0.1215 - accuracy: 0.9549 - val_loss: 0.1376 - val_accuracy: 0.9490 - lr: 0.0010 - 413ms/epoch - 14ms/step
# Epoch 4/60
#
# Epoch 4: val_accuracy improved from 0.94904 to 0.95117, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_padded_0s/run_2FC/Entanglement_pool_padded_0s_0321model.keras
# 30/30 - 0s - loss: 0.0938 - accuracy: 0.9652 - val_loss: 0.1244 - val_accuracy: 0.9512 - lr: 0.0010 - 423ms/epoch - 14ms/step
# Epoch 5/60
#
# Epoch 5: val_accuracy improved from 0.95117 to 0.95648, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_padded_0s/run_2FC/Entanglement_pool_padded_0s_0321model.keras
# 30/30 - 0s - loss: 0.0745 - accuracy: 0.9721 - val_loss: 0.1194 - val_accuracy: 0.9565 - lr: 0.0010 - 417ms/epoch - 14ms/step
# Epoch 6/60
#
# Epoch 6: val_accuracy improved from 0.95648 to 0.95966, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_padded_0s/run_2FC/Entanglement_pool_padded_0s_0321model.keras
# 30/30 - 0s - loss: 0.0602 - accuracy: 0.9774 - val_loss: 0.1091 - val_accuracy: 0.9597 - lr: 0.0010 - 422ms/epoch - 14ms/step
# Epoch 7/60
#
# Epoch 7: val_accuracy did not improve from 0.95966
# 30/30 - 0s - loss: 0.0702 - accuracy: 0.9742 - val_loss: 0.1193 - val_accuracy: 0.9586 - lr: 0.0010 - 316ms/epoch - 11ms/step
# Epoch 8/60
#
# Epoch 8: val_accuracy did not improve from 0.95966
# 30/30 - 0s - loss: 0.0447 - accuracy: 0.9854 - val_loss: 0.1182 - val_accuracy: 0.9565 - lr: 0.0010 - 295ms/epoch - 10ms/step
# Epoch 9/60
#
# Epoch 9: val_accuracy did not improve from 0.95966
# 30/30 - 0s - loss: 0.0357 - accuracy: 0.9891 - val_loss: 0.1180 - val_accuracy: 0.9544 - lr: 0.0010 - 306ms/epoch - 10ms/step
# Epoch 10/60
#
# Epoch 10: val_accuracy improved from 0.95966 to 0.96072, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_padded_0s/run_2FC/Entanglement_pool_padded_0s_0321model.keras
# 30/30 - 0s - loss: 0.0256 - accuracy: 0.9931 - val_loss: 0.1097 - val_accuracy: 0.9607 - lr: 0.0010 - 404ms/epoch - 13ms/step
# Epoch 11/60
#
# Epoch 11: val_accuracy did not improve from 0.96072
# 30/30 - 0s - loss: 0.0208 - accuracy: 0.9971 - val_loss: 0.1178 - val_accuracy: 0.9575 - lr: 0.0010 - 309ms/epoch - 10ms/step
# Epoch 12/60
#
# Epoch 12: val_accuracy did not improve from 0.96072
# 30/30 - 0s - loss: 0.0190 - accuracy: 0.9979 - val_loss: 0.1149 - val_accuracy: 0.9597 - lr: 0.0010 - 310ms/epoch - 10ms/step
# Epoch 13/60
#
# Epoch 13: val_accuracy did not improve from 0.96072
# 30/30 - 0s - loss: 0.0143 - accuracy: 0.9987 - val_loss: 0.1301 - val_accuracy: 0.9554 - lr: 0.0010 - 287ms/epoch - 10ms/step
# Epoch 14/60
#
# Epoch 14: val_accuracy improved from 0.96072 to 0.96178, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_padded_0s/run_2FC/Entanglement_pool_padded_0s_0321model.keras
# 30/30 - 0s - loss: 0.0096 - accuracy: 0.9997 - val_loss: 0.1184 - val_accuracy: 0.9618 - lr: 0.0010 - 430ms/epoch - 14ms/step
# Epoch 15/60
#
# Epoch 15: val_accuracy did not improve from 0.96178
# 30/30 - 0s - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.1218 - val_accuracy: 0.9607 - lr: 0.0010 - 293ms/epoch - 10ms/step
# Epoch 16/60
#
# Epoch 16: val_accuracy did not improve from 0.96178
# 30/30 - 0s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.1264 - val_accuracy: 0.9597 - lr: 0.0010 - 299ms/epoch - 10ms/step
# Epoch 17/60
#
# Epoch 17: val_accuracy did not improve from 0.96178
# 30/30 - 0s - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.1259 - val_accuracy: 0.9597 - lr: 0.0010 - 324ms/epoch - 11ms/step
# Epoch 18/60
#
# Epoch 18: val_accuracy did not improve from 0.96178
# 30/30 - 0s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.1251 - val_accuracy: 0.9618 - lr: 0.0010 - 317ms/epoch - 11ms/step
# Epoch 19/60
#
# Epoch 19: val_accuracy did not improve from 0.96178
# 30/30 - 0s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.1303 - val_accuracy: 0.9607 - lr: 0.0010 - 315ms/epoch - 10ms/step
# Epoch 20/60
#
# Epoch 20: val_accuracy did not improve from 0.96178
# 30/30 - 0s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.1292 - val_accuracy: 0.9607 - lr: 0.0010 - 297ms/epoch - 10ms/step
# Epoch 21/60
#
# Epoch 21: val_accuracy did not improve from 0.96178
# 30/30 - 0s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.1337 - val_accuracy: 0.9607 - lr: 0.0010 - 294ms/epoch - 10ms/step
# Epoch 22/60
#
# Epoch 22: val_accuracy did not improve from 0.96178
# 30/30 - 0s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1336 - val_accuracy: 0.9618 - lr: 0.0010 - 291ms/epoch - 10ms/step
# Epoch 23/60
#
# Epoch 23: val_accuracy did not improve from 0.96178
# 30/30 - 0s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1343 - val_accuracy: 0.9607 - lr: 0.0010 - 296ms/epoch - 10ms/step
# Epoch 24/60
#
# Epoch 24: val_accuracy did not improve from 0.96178
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 30/30 - 0s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1344 - val_accuracy: 0.9618 - lr: 0.0010 - 304ms/epoch - 10ms/step
# Epoch 25/60
#
# Epoch 25: val_accuracy did not improve from 0.96178
# 30/30 - 0s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9618 - lr: 1.0000e-04 - 294ms/epoch - 10ms/step
# Epoch 26/60
#
# Epoch 26: val_accuracy did not improve from 0.96178
# 30/30 - 0s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9618 - lr: 1.0000e-04 - 290ms/epoch - 10ms/step
# Epoch 27/60
#
# Epoch 27: val_accuracy did not improve from 0.96178
# 30/30 - 0s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9618 - lr: 1.0000e-04 - 330ms/epoch - 11ms/step
# Epoch 28/60
#
# Epoch 28: val_accuracy did not improve from 0.96178
# 30/30 - 0s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1392 - val_accuracy: 0.9618 - lr: 1.0000e-04 - 291ms/epoch - 10ms/step
# Epoch 29/60
# Restoring model weights from the end of the best epoch: 14.
#
# Epoch 29: val_accuracy did not improve from 0.96178
# 30/30 - 0s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1386 - val_accuracy: 0.9618 - lr: 1.0000e-04 - 313ms/epoch - 10ms/step
# Epoch 29: early stopping
# Epoch 1/60
#
# Epoch 1: val_accuracy improved from -inf to 0.92144, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_0321model.keras
# 30/30 - 2s - loss: 0.5754 - accuracy: 0.8149 - val_loss: 0.1969 - val_accuracy: 0.9214 - lr: 0.0010 - 2s/epoch - 55ms/step
# Epoch 2/60
#
# Epoch 2: val_accuracy improved from 0.92144 to 0.93524, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_0321model.keras
# 30/30 - 0s - loss: 0.1655 - accuracy: 0.9341 - val_loss: 0.1585 - val_accuracy: 0.9352 - lr: 0.0010 - 489ms/epoch - 16ms/step
# Epoch 3/60
#
# Epoch 3: val_accuracy improved from 0.93524 to 0.94480, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_0321model.keras
# 30/30 - 0s - loss: 0.1178 - accuracy: 0.9543 - val_loss: 0.1367 - val_accuracy: 0.9448 - lr: 0.0010 - 467ms/epoch - 16ms/step
# Epoch 4/60
#
# Epoch 4: val_accuracy did not improve from 0.94480
# 30/30 - 0s - loss: 0.0942 - accuracy: 0.9639 - val_loss: 0.1384 - val_accuracy: 0.9437 - lr: 0.0010 - 351ms/epoch - 12ms/step
# Epoch 5/60
#
# Epoch 5: val_accuracy improved from 0.94480 to 0.95117, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_0321model.keras
# 30/30 - 0s - loss: 0.0934 - accuracy: 0.9647 - val_loss: 0.1265 - val_accuracy: 0.9512 - lr: 0.0010 - 430ms/epoch - 14ms/step
# Epoch 6/60
#
# Epoch 6: val_accuracy improved from 0.95117 to 0.95329, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_0321model.keras
# 30/30 - 0s - loss: 0.0772 - accuracy: 0.9695 - val_loss: 0.1169 - val_accuracy: 0.9533 - lr: 0.0010 - 441ms/epoch - 15ms/step
# Epoch 7/60
#
# Epoch 7: val_accuracy improved from 0.95329 to 0.95754, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_0321model.keras
# 30/30 - 0s - loss: 0.0503 - accuracy: 0.9814 - val_loss: 0.1082 - val_accuracy: 0.9575 - lr: 0.0010 - 436ms/epoch - 15ms/step
# Epoch 8/60
#
# Epoch 8: val_accuracy did not improve from 0.95754
# 30/30 - 0s - loss: 0.0434 - accuracy: 0.9854 - val_loss: 0.1109 - val_accuracy: 0.9575 - lr: 0.0010 - 345ms/epoch - 12ms/step
# Epoch 9/60
#
# Epoch 9: val_accuracy did not improve from 0.95754
# 30/30 - 0s - loss: 0.0306 - accuracy: 0.9907 - val_loss: 0.1338 - val_accuracy: 0.9544 - lr: 0.0010 - 350ms/epoch - 12ms/step
# Epoch 10/60
#
# Epoch 10: val_accuracy did not improve from 0.95754
# 30/30 - 0s - loss: 0.0273 - accuracy: 0.9918 - val_loss: 0.1312 - val_accuracy: 0.9544 - lr: 0.0010 - 326ms/epoch - 11ms/step
# Epoch 11/60
#
# Epoch 11: val_accuracy improved from 0.95754 to 0.96072, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_0321model.keras
# 30/30 - 0s - loss: 0.0139 - accuracy: 0.9979 - val_loss: 0.1286 - val_accuracy: 0.9607 - lr: 0.0010 - 423ms/epoch - 14ms/step
# Epoch 12/60
#
# Epoch 12: val_accuracy did not improve from 0.96072
# 30/30 - 0s - loss: 0.0109 - accuracy: 0.9987 - val_loss: 0.1678 - val_accuracy: 0.9522 - lr: 0.0010 - 346ms/epoch - 12ms/step
# Epoch 13/60
#
# Epoch 13: val_accuracy did not improve from 0.96072
# 30/30 - 0s - loss: 0.0061 - accuracy: 0.9997 - val_loss: 0.1377 - val_accuracy: 0.9586 - lr: 0.0010 - 324ms/epoch - 11ms/step
# Epoch 14/60
#
# Epoch 14: val_accuracy did not improve from 0.96072
# 30/30 - 0s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.1450 - val_accuracy: 0.9607 - lr: 0.0010 - 331ms/epoch - 11ms/step
# Epoch 15/60
#
# Epoch 15: val_accuracy did not improve from 0.96072
# 30/30 - 0s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1653 - val_accuracy: 0.9554 - lr: 0.0010 - 320ms/epoch - 11ms/step
# Epoch 16/60
#
# Epoch 16: val_accuracy did not improve from 0.96072
# 30/30 - 0s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1674 - val_accuracy: 0.9597 - lr: 0.0010 - 322ms/epoch - 11ms/step
# Epoch 17/60
#
# Epoch 17: val_accuracy improved from 0.96072 to 0.96178, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_0321model.keras
# 30/30 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1680 - val_accuracy: 0.9618 - lr: 0.0010 - 451ms/epoch - 15ms/step
# Epoch 18/60
#
# Epoch 18: val_accuracy did not improve from 0.96178
# 30/30 - 0s - loss: 7.6004e-04 - accuracy: 1.0000 - val_loss: 0.1753 - val_accuracy: 0.9607 - lr: 0.0010 - 352ms/epoch - 12ms/step
# Epoch 19/60
#
# Epoch 19: val_accuracy did not improve from 0.96178
# 30/30 - 0s - loss: 5.8108e-04 - accuracy: 1.0000 - val_loss: 0.1780 - val_accuracy: 0.9618 - lr: 0.0010 - 341ms/epoch - 11ms/step
# Epoch 20/60
#
# Epoch 20: val_accuracy did not improve from 0.96178
# 30/30 - 0s - loss: 4.7852e-04 - accuracy: 1.0000 - val_loss: 0.1864 - val_accuracy: 0.9607 - lr: 0.0010 - 323ms/epoch - 11ms/step
# Epoch 21/60
#
# Epoch 21: val_accuracy improved from 0.96178 to 0.96285, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_0321model.keras
# 30/30 - 0s - loss: 3.9418e-04 - accuracy: 1.0000 - val_loss: 0.1817 - val_accuracy: 0.9628 - lr: 0.0010 - 445ms/epoch - 15ms/step
# Epoch 22/60
#
# Epoch 22: val_accuracy did not improve from 0.96285
# 30/30 - 0s - loss: 3.3001e-04 - accuracy: 1.0000 - val_loss: 0.1895 - val_accuracy: 0.9618 - lr: 0.0010 - 351ms/epoch - 12ms/step
# Epoch 23/60
#
# Epoch 23: val_accuracy did not improve from 0.96285
# 30/30 - 0s - loss: 2.7947e-04 - accuracy: 1.0000 - val_loss: 0.1941 - val_accuracy: 0.9607 - lr: 0.0010 - 337ms/epoch - 11ms/step
# Epoch 24/60
#
# Epoch 24: val_accuracy improved from 0.96285 to 0.96391, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_0321model.keras
# 30/30 - 0s - loss: 2.3978e-04 - accuracy: 1.0000 - val_loss: 0.1944 - val_accuracy: 0.9639 - lr: 0.0010 - 440ms/epoch - 15ms/step
# Epoch 25/60
#
# Epoch 25: val_accuracy did not improve from 0.96391
# 30/30 - 0s - loss: 2.1405e-04 - accuracy: 1.0000 - val_loss: 0.1981 - val_accuracy: 0.9607 - lr: 0.0010 - 347ms/epoch - 12ms/step
# Epoch 26/60
#
# Epoch 26: val_accuracy did not improve from 0.96391
# 30/30 - 0s - loss: 1.8664e-04 - accuracy: 1.0000 - val_loss: 0.2019 - val_accuracy: 0.9607 - lr: 0.0010 - 350ms/epoch - 12ms/step
# Epoch 27/60
#
# Epoch 27: val_accuracy did not improve from 0.96391
# 30/30 - 0s - loss: 1.6428e-04 - accuracy: 1.0000 - val_loss: 0.2054 - val_accuracy: 0.9618 - lr: 0.0010 - 322ms/epoch - 11ms/step
# Epoch 28/60
#
# Epoch 28: val_accuracy did not improve from 0.96391
# 30/30 - 0s - loss: 1.4474e-04 - accuracy: 1.0000 - val_loss: 0.2041 - val_accuracy: 0.9618 - lr: 0.0010 - 332ms/epoch - 11ms/step
# Epoch 29/60
#
# Epoch 29: val_accuracy did not improve from 0.96391
# 30/30 - 0s - loss: 1.3641e-04 - accuracy: 1.0000 - val_loss: 0.2056 - val_accuracy: 0.9618 - lr: 0.0010 - 320ms/epoch - 11ms/step
# Epoch 30/60
#
# Epoch 30: val_accuracy did not improve from 0.96391
# 30/30 - 0s - loss: 1.1908e-04 - accuracy: 1.0000 - val_loss: 0.2105 - val_accuracy: 0.9618 - lr: 0.0010 - 356ms/epoch - 12ms/step
# Epoch 31/60
#
# Epoch 31: val_accuracy did not improve from 0.96391
# 30/30 - 0s - loss: 1.0698e-04 - accuracy: 1.0000 - val_loss: 0.2131 - val_accuracy: 0.9618 - lr: 0.0010 - 403ms/epoch - 13ms/step
# Epoch 32/60
#
# Epoch 32: val_accuracy did not improve from 0.96391
# 30/30 - 0s - loss: 1.0253e-04 - accuracy: 1.0000 - val_loss: 0.2127 - val_accuracy: 0.9618 - lr: 0.0010 - 450ms/epoch - 15ms/step
# Epoch 33/60
#
# Epoch 33: val_accuracy did not improve from 0.96391
# 30/30 - 0s - loss: 9.5085e-05 - accuracy: 1.0000 - val_loss: 0.2150 - val_accuracy: 0.9628 - lr: 0.0010 - 349ms/epoch - 12ms/step
# Epoch 34/60
#
# Epoch 34: val_accuracy did not improve from 0.96391
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 30/30 - 0s - loss: 8.1424e-05 - accuracy: 1.0000 - val_loss: 0.2196 - val_accuracy: 0.9618 - lr: 0.0010 - 332ms/epoch - 11ms/step
# Epoch 35/60
#
# Epoch 35: val_accuracy did not improve from 0.96391
# 30/30 - 0s - loss: 7.5411e-05 - accuracy: 1.0000 - val_loss: 0.2200 - val_accuracy: 0.9618 - lr: 1.0000e-04 - 318ms/epoch - 11ms/step
# Epoch 36/60
#
# Epoch 36: val_accuracy did not improve from 0.96391
# 30/30 - 0s - loss: 7.4790e-05 - accuracy: 1.0000 - val_loss: 0.2204 - val_accuracy: 0.9628 - lr: 1.0000e-04 - 320ms/epoch - 11ms/step
# Epoch 37/60
#
# Epoch 37: val_accuracy did not improve from 0.96391
# 30/30 - 0s - loss: 7.4145e-05 - accuracy: 1.0000 - val_loss: 0.2206 - val_accuracy: 0.9628 - lr: 1.0000e-04 - 325ms/epoch - 11ms/step
# Epoch 38/60
#
# Epoch 38: val_accuracy did not improve from 0.96391
# 30/30 - 0s - loss: 7.3669e-05 - accuracy: 1.0000 - val_loss: 0.2212 - val_accuracy: 0.9628 - lr: 1.0000e-04 - 353ms/epoch - 12ms/step
# Epoch 39/60
# Restoring model weights from the end of the best epoch: 24.
#
# Epoch 39: val_accuracy did not improve from 0.96391
# 30/30 - 0s - loss: 7.2971e-05 - accuracy: 1.0000 - val_loss: 0.2208 - val_accuracy: 0.9618 - lr: 1.0000e-04 - 342ms/epoch - 11ms/step
# Epoch 39: early stopping
# Epoch 1/60
#
# Epoch 1: val_accuracy improved from -inf to 0.94055, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_0321model.keras
# 30/30 - 2s - loss: 0.4496 - accuracy: 0.8417 - val_loss: 0.1627 - val_accuracy: 0.9406 - lr: 0.0010 - 2s/epoch - 66ms/step
# Epoch 2/60
#
# Epoch 2: val_accuracy improved from 0.94055 to 0.94586, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_0321model.keras
# 30/30 - 1s - loss: 0.1359 - accuracy: 0.9509 - val_loss: 0.1345 - val_accuracy: 0.9459 - lr: 0.0010 - 529ms/epoch - 18ms/step
# Epoch 3/60
#
# Epoch 3: val_accuracy improved from 0.94586 to 0.95117, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_0321model.keras
# 30/30 - 0s - loss: 0.1239 - accuracy: 0.9538 - val_loss: 0.1339 - val_accuracy: 0.9512 - lr: 0.0010 - 489ms/epoch - 16ms/step
# Epoch 4/60
#
# Epoch 4: val_accuracy improved from 0.95117 to 0.95648, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_0321model.keras
# 30/30 - 0s - loss: 0.0938 - accuracy: 0.9639 - val_loss: 0.1117 - val_accuracy: 0.9565 - lr: 0.0010 - 456ms/epoch - 15ms/step
# Epoch 5/60
#
# Epoch 5: val_accuracy did not improve from 0.95648
# 30/30 - 0s - loss: 0.0745 - accuracy: 0.9711 - val_loss: 0.1247 - val_accuracy: 0.9522 - lr: 0.0010 - 372ms/epoch - 12ms/step
# Epoch 6/60
#
# Epoch 6: val_accuracy did not improve from 0.95648
# 30/30 - 0s - loss: 0.0584 - accuracy: 0.9798 - val_loss: 0.1171 - val_accuracy: 0.9522 - lr: 0.0010 - 368ms/epoch - 12ms/step
# Epoch 7/60
#
# Epoch 7: val_accuracy did not improve from 0.95648
# 30/30 - 0s - loss: 0.0410 - accuracy: 0.9859 - val_loss: 0.1239 - val_accuracy: 0.9554 - lr: 0.0010 - 382ms/epoch - 13ms/step
# Epoch 8/60
#
# Epoch 8: val_accuracy improved from 0.95648 to 0.96072, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_0321model.keras
# 30/30 - 1s - loss: 0.0274 - accuracy: 0.9915 - val_loss: 0.1243 - val_accuracy: 0.9607 - lr: 0.0010 - 522ms/epoch - 17ms/step
# Epoch 9/60
#
# Epoch 9: val_accuracy did not improve from 0.96072
# 30/30 - 0s - loss: 0.0205 - accuracy: 0.9939 - val_loss: 0.1569 - val_accuracy: 0.9544 - lr: 0.0010 - 399ms/epoch - 13ms/step
# Epoch 10/60
#
# Epoch 10: val_accuracy did not improve from 0.96072
# 30/30 - 0s - loss: 0.0216 - accuracy: 0.9912 - val_loss: 0.1802 - val_accuracy: 0.9480 - lr: 0.0010 - 450ms/epoch - 15ms/step
# Epoch 11/60
#
# Epoch 11: val_accuracy did not improve from 0.96072
# 30/30 - 0s - loss: 0.0112 - accuracy: 0.9973 - val_loss: 0.1418 - val_accuracy: 0.9597 - lr: 0.0010 - 370ms/epoch - 12ms/step
# Epoch 12/60
#
# Epoch 12: val_accuracy did not improve from 0.96072
# 30/30 - 0s - loss: 0.0149 - accuracy: 0.9952 - val_loss: 0.2257 - val_accuracy: 0.9459 - lr: 0.0010 - 364ms/epoch - 12ms/step
# Epoch 13/60
#
# Epoch 13: val_accuracy did not improve from 0.96072
# 30/30 - 0s - loss: 0.0193 - accuracy: 0.9934 - val_loss: 0.2180 - val_accuracy: 0.9416 - lr: 0.0010 - 338ms/epoch - 11ms/step
# Epoch 14/60
#
# Epoch 14: val_accuracy improved from 0.96072 to 0.96178, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_0321model.keras
# 30/30 - 0s - loss: 0.0128 - accuracy: 0.9950 - val_loss: 0.1724 - val_accuracy: 0.9618 - lr: 0.0010 - 468ms/epoch - 16ms/step
# Epoch 15/60
#
# Epoch 15: val_accuracy did not improve from 0.96178
# 30/30 - 0s - loss: 0.0030 - accuracy: 0.9995 - val_loss: 0.1634 - val_accuracy: 0.9607 - lr: 0.0010 - 367ms/epoch - 12ms/step
# Epoch 16/60
#
# Epoch 16: val_accuracy did not improve from 0.96178
# 30/30 - 0s - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.1739 - val_accuracy: 0.9618 - lr: 0.0010 - 344ms/epoch - 11ms/step
# Epoch 17/60
#
# Epoch 17: val_accuracy did not improve from 0.96178
# 30/30 - 0s - loss: 7.1057e-04 - accuracy: 1.0000 - val_loss: 0.1851 - val_accuracy: 0.9597 - lr: 0.0010 - 350ms/epoch - 12ms/step
# Epoch 18/60
#
# Epoch 18: val_accuracy did not improve from 0.96178
# 30/30 - 0s - loss: 2.8791e-04 - accuracy: 1.0000 - val_loss: 0.1908 - val_accuracy: 0.9618 - lr: 0.0010 - 359ms/epoch - 12ms/step
# Epoch 19/60
#
# Epoch 19: val_accuracy did not improve from 0.96178
# 30/30 - 0s - loss: 2.0638e-04 - accuracy: 1.0000 - val_loss: 0.1998 - val_accuracy: 0.9618 - lr: 0.0010 - 363ms/epoch - 12ms/step
# Epoch 20/60
#
# Epoch 20: val_accuracy did not improve from 0.96178
# 30/30 - 0s - loss: 1.6068e-04 - accuracy: 1.0000 - val_loss: 0.2056 - val_accuracy: 0.9597 - lr: 0.0010 - 373ms/epoch - 12ms/step
# Epoch 21/60
#
# Epoch 21: val_accuracy did not improve from 0.96178
# 30/30 - 0s - loss: 1.1125e-04 - accuracy: 1.0000 - val_loss: 0.2162 - val_accuracy: 0.9586 - lr: 0.0010 - 354ms/epoch - 12ms/step
# Epoch 22/60
#
# Epoch 22: val_accuracy did not improve from 0.96178
# 30/30 - 0s - loss: 7.9087e-05 - accuracy: 1.0000 - val_loss: 0.2211 - val_accuracy: 0.9597 - lr: 0.0010 - 408ms/epoch - 14ms/step
# Epoch 23/60
#
# Epoch 23: val_accuracy did not improve from 0.96178
# 30/30 - 0s - loss: 6.3349e-05 - accuracy: 1.0000 - val_loss: 0.2277 - val_accuracy: 0.9607 - lr: 0.0010 - 388ms/epoch - 13ms/step
# Epoch 24/60
#
# Epoch 24: val_accuracy did not improve from 0.96178
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 30/30 - 0s - loss: 5.2865e-05 - accuracy: 1.0000 - val_loss: 0.2295 - val_accuracy: 0.9586 - lr: 0.0010 - 357ms/epoch - 12ms/step
# Epoch 25/60
#
# Epoch 25: val_accuracy did not improve from 0.96178
# 30/30 - 0s - loss: 4.5719e-05 - accuracy: 1.0000 - val_loss: 0.2302 - val_accuracy: 0.9586 - lr: 1.0000e-04 - 352ms/epoch - 12ms/step
# Epoch 26/60
#
# Epoch 26: val_accuracy did not improve from 0.96178
# 30/30 - 0s - loss: 4.4989e-05 - accuracy: 1.0000 - val_loss: 0.2306 - val_accuracy: 0.9586 - lr: 1.0000e-04 - 373ms/epoch - 12ms/step
# Epoch 27/60
#
# Epoch 27: val_accuracy did not improve from 0.96178
# 30/30 - 0s - loss: 4.4037e-05 - accuracy: 1.0000 - val_loss: 0.2312 - val_accuracy: 0.9586 - lr: 1.0000e-04 - 367ms/epoch - 12ms/step
# Epoch 28/60
#
# Epoch 28: val_accuracy did not improve from 0.96178
# 30/30 - 0s - loss: 4.3288e-05 - accuracy: 1.0000 - val_loss: 0.2317 - val_accuracy: 0.9586 - lr: 1.0000e-04 - 336ms/epoch - 11ms/step
# Epoch 29/60
# Restoring model weights from the end of the best epoch: 14.
#
# Epoch 29: val_accuracy did not improve from 0.96178
# 30/30 - 0s - loss: 4.2458e-05 - accuracy: 1.0000 - val_loss: 0.2322 - val_accuracy: 0.9586 - lr: 1.0000e-04 - 376ms/epoch - 13ms/step
# Epoch 29: early stopping
# Epoch 1/60
#
# Epoch 1: val_accuracy improved from -inf to 0.83121, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_summed/run_1FC/Entanglement_pool_summed_0321model.keras
# 30/30 - 1s - loss: 0.5577 - accuracy: 0.7395 - val_loss: 0.4139 - val_accuracy: 0.8312 - lr: 0.0010 - 761ms/epoch - 25ms/step
# Epoch 2/60
#
# Epoch 2: val_accuracy improved from 0.83121 to 0.88217, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_summed/run_1FC/Entanglement_pool_summed_0321model.keras
# 30/30 - 0s - loss: 0.3827 - accuracy: 0.8428 - val_loss: 0.3209 - val_accuracy: 0.8822 - lr: 0.0010 - 173ms/epoch - 6ms/step
# Epoch 3/60
#
# Epoch 3: val_accuracy improved from 0.88217 to 0.88535, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_summed/run_1FC/Entanglement_pool_summed_0321model.keras
# 30/30 - 0s - loss: 0.3137 - accuracy: 0.8832 - val_loss: 0.2831 - val_accuracy: 0.8854 - lr: 0.0010 - 136ms/epoch - 5ms/step
# Epoch 4/60
#
# Epoch 4: val_accuracy improved from 0.88535 to 0.91083, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_summed/run_1FC/Entanglement_pool_summed_0321model.keras
# 30/30 - 0s - loss: 0.2754 - accuracy: 0.8978 - val_loss: 0.2592 - val_accuracy: 0.9108 - lr: 0.0010 - 197ms/epoch - 7ms/step
# Epoch 5/60
#
# Epoch 5: val_accuracy improved from 0.91083 to 0.91826, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_summed/run_1FC/Entanglement_pool_summed_0321model.keras
# 30/30 - 0s - loss: 0.2493 - accuracy: 0.9105 - val_loss: 0.2374 - val_accuracy: 0.9183 - lr: 0.0010 - 161ms/epoch - 5ms/step
# Epoch 6/60
#
# Epoch 6: val_accuracy improved from 0.91826 to 0.91932, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_summed/run_1FC/Entanglement_pool_summed_0321model.keras
# 30/30 - 0s - loss: 0.2332 - accuracy: 0.9150 - val_loss: 0.2276 - val_accuracy: 0.9193 - lr: 0.0010 - 162ms/epoch - 5ms/step
# Epoch 7/60
#
# Epoch 7: val_accuracy improved from 0.91932 to 0.92144, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_summed/run_1FC/Entanglement_pool_summed_0321model.keras
# 30/30 - 0s - loss: 0.2216 - accuracy: 0.9201 - val_loss: 0.2180 - val_accuracy: 0.9214 - lr: 0.0010 - 154ms/epoch - 5ms/step
# Epoch 8/60
#
# Epoch 8: val_accuracy did not improve from 0.92144
# 30/30 - 0s - loss: 0.2123 - accuracy: 0.9206 - val_loss: 0.2124 - val_accuracy: 0.9214 - lr: 0.0010 - 140ms/epoch - 5ms/step
# Epoch 9/60
#
# Epoch 9: val_accuracy improved from 0.92144 to 0.92569, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_summed/run_1FC/Entanglement_pool_summed_0321model.keras
# 30/30 - 0s - loss: 0.2043 - accuracy: 0.9246 - val_loss: 0.2075 - val_accuracy: 0.9257 - lr: 0.0010 - 189ms/epoch - 6ms/step
# Epoch 10/60
#
# Epoch 10: val_accuracy improved from 0.92569 to 0.93100, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_summed/run_1FC/Entanglement_pool_summed_0321model.keras
# 30/30 - 0s - loss: 0.1980 - accuracy: 0.9283 - val_loss: 0.2024 - val_accuracy: 0.9310 - lr: 0.0010 - 192ms/epoch - 6ms/step
# Epoch 11/60
#
# Epoch 11: val_accuracy improved from 0.93100 to 0.93418, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_summed/run_1FC/Entanglement_pool_summed_0321model.keras
# 30/30 - 0s - loss: 0.1924 - accuracy: 0.9307 - val_loss: 0.1990 - val_accuracy: 0.9342 - lr: 0.0010 - 220ms/epoch - 7ms/step
# Epoch 12/60
#
# Epoch 12: val_accuracy did not improve from 0.93418
# 30/30 - 0s - loss: 0.1868 - accuracy: 0.9331 - val_loss: 0.1992 - val_accuracy: 0.9257 - lr: 0.0010 - 176ms/epoch - 6ms/step
# Epoch 13/60
#
# Epoch 13: val_accuracy did not improve from 0.93418
# 30/30 - 0s - loss: 0.1824 - accuracy: 0.9355 - val_loss: 0.1935 - val_accuracy: 0.9310 - lr: 0.0010 - 163ms/epoch - 5ms/step
# Epoch 14/60
#
# Epoch 14: val_accuracy did not improve from 0.93418
# 30/30 - 0s - loss: 0.1777 - accuracy: 0.9376 - val_loss: 0.1915 - val_accuracy: 0.9310 - lr: 0.0010 - 161ms/epoch - 5ms/step
# Epoch 15/60
#
# Epoch 15: val_accuracy did not improve from 0.93418
# 30/30 - 0s - loss: 0.1753 - accuracy: 0.9379 - val_loss: 0.1900 - val_accuracy: 0.9321 - lr: 0.0010 - 171ms/epoch - 6ms/step
# Epoch 16/60
#
# Epoch 16: val_accuracy did not improve from 0.93418
# 30/30 - 0s - loss: 0.1714 - accuracy: 0.9403 - val_loss: 0.1899 - val_accuracy: 0.9342 - lr: 0.0010 - 174ms/epoch - 6ms/step
# Epoch 17/60
#
# Epoch 17: val_accuracy did not improve from 0.93418
# 30/30 - 0s - loss: 0.1700 - accuracy: 0.9384 - val_loss: 0.1891 - val_accuracy: 0.9278 - lr: 0.0010 - 171ms/epoch - 6ms/step
# Epoch 18/60
#
# Epoch 18: val_accuracy did not improve from 0.93418
# 30/30 - 0s - loss: 0.1647 - accuracy: 0.9421 - val_loss: 0.1865 - val_accuracy: 0.9278 - lr: 0.0010 - 138ms/epoch - 5ms/step
# Epoch 19/60
#
# Epoch 19: val_accuracy did not improve from 0.93418
# 30/30 - 0s - loss: 0.1659 - accuracy: 0.9395 - val_loss: 0.1951 - val_accuracy: 0.9268 - lr: 0.0010 - 156ms/epoch - 5ms/step
# Epoch 20/60
#
# Epoch 20: val_accuracy did not improve from 0.93418
# 30/30 - 0s - loss: 0.1604 - accuracy: 0.9445 - val_loss: 0.1833 - val_accuracy: 0.9299 - lr: 0.0010 - 163ms/epoch - 5ms/step
# Epoch 21/60
#
# Epoch 21: val_accuracy improved from 0.93418 to 0.93631, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_summed/run_1FC/Entanglement_pool_summed_0321model.keras
# 30/30 - 0s - loss: 0.1570 - accuracy: 0.9456 - val_loss: 0.1858 - val_accuracy: 0.9363 - lr: 0.0010 - 195ms/epoch - 6ms/step
# Epoch 22/60
#
# Epoch 22: val_accuracy did not improve from 0.93631
# 30/30 - 0s - loss: 0.1557 - accuracy: 0.9461 - val_loss: 0.1818 - val_accuracy: 0.9310 - lr: 0.0010 - 179ms/epoch - 6ms/step
# Epoch 23/60
#
# Epoch 23: val_accuracy did not improve from 0.93631
# 30/30 - 0s - loss: 0.1532 - accuracy: 0.9477 - val_loss: 0.1833 - val_accuracy: 0.9236 - lr: 0.0010 - 172ms/epoch - 6ms/step
# Epoch 24/60
#
# Epoch 24: val_accuracy improved from 0.93631 to 0.93843, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_summed/run_1FC/Entanglement_pool_summed_0321model.keras
# 30/30 - 0s - loss: 0.1524 - accuracy: 0.9458 - val_loss: 0.1829 - val_accuracy: 0.9384 - lr: 0.0010 - 166ms/epoch - 6ms/step
# Epoch 25/60
#
# Epoch 25: val_accuracy did not improve from 0.93843
# 30/30 - 0s - loss: 0.1493 - accuracy: 0.9469 - val_loss: 0.1799 - val_accuracy: 0.9289 - lr: 0.0010 - 167ms/epoch - 6ms/step
# Epoch 26/60
#
# Epoch 26: val_accuracy did not improve from 0.93843
# 30/30 - 0s - loss: 0.1471 - accuracy: 0.9488 - val_loss: 0.1855 - val_accuracy: 0.9342 - lr: 0.0010 - 161ms/epoch - 5ms/step
# Epoch 27/60
#
# Epoch 27: val_accuracy did not improve from 0.93843
# 30/30 - 0s - loss: 0.1475 - accuracy: 0.9474 - val_loss: 0.1797 - val_accuracy: 0.9268 - lr: 0.0010 - 171ms/epoch - 6ms/step
# Epoch 28/60
#
# Epoch 28: val_accuracy did not improve from 0.93843
# 30/30 - 0s - loss: 0.1438 - accuracy: 0.9501 - val_loss: 0.1786 - val_accuracy: 0.9342 - lr: 0.0010 - 152ms/epoch - 5ms/step
# Epoch 29/60
#
# Epoch 29: val_accuracy did not improve from 0.93843
# 30/30 - 0s - loss: 0.1425 - accuracy: 0.9495 - val_loss: 0.1782 - val_accuracy: 0.9278 - lr: 0.0010 - 181ms/epoch - 6ms/step
# Epoch 30/60
#
# Epoch 30: val_accuracy did not improve from 0.93843
# 30/30 - 0s - loss: 0.1423 - accuracy: 0.9509 - val_loss: 0.1777 - val_accuracy: 0.9289 - lr: 0.0010 - 158ms/epoch - 5ms/step
# Epoch 31/60
#
# Epoch 31: val_accuracy did not improve from 0.93843
# 30/30 - 0s - loss: 0.1413 - accuracy: 0.9503 - val_loss: 0.1779 - val_accuracy: 0.9278 - lr: 0.0010 - 172ms/epoch - 6ms/step
# Epoch 32/60
#
# Epoch 32: val_accuracy did not improve from 0.93843
# 30/30 - 0s - loss: 0.1387 - accuracy: 0.9506 - val_loss: 0.1774 - val_accuracy: 0.9268 - lr: 0.0010 - 153ms/epoch - 5ms/step
# Epoch 33/60
#
# Epoch 33: val_accuracy did not improve from 0.93843
# 30/30 - 0s - loss: 0.1366 - accuracy: 0.9519 - val_loss: 0.1772 - val_accuracy: 0.9278 - lr: 0.0010 - 142ms/epoch - 5ms/step
# Epoch 34/60
#
# Epoch 34: val_accuracy did not improve from 0.93843
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 30/30 - 0s - loss: 0.1361 - accuracy: 0.9533 - val_loss: 0.1769 - val_accuracy: 0.9289 - lr: 0.0010 - 164ms/epoch - 5ms/step
# Epoch 35/60
#
# Epoch 35: val_accuracy did not improve from 0.93843
# 30/30 - 0s - loss: 0.1335 - accuracy: 0.9543 - val_loss: 0.1770 - val_accuracy: 0.9278 - lr: 1.0000e-04 - 147ms/epoch - 5ms/step
# Epoch 36/60
#
# Epoch 36: val_accuracy did not improve from 0.93843
# 30/30 - 0s - loss: 0.1333 - accuracy: 0.9541 - val_loss: 0.1768 - val_accuracy: 0.9278 - lr: 1.0000e-04 - 158ms/epoch - 5ms/step
# Epoch 37/60
#
# Epoch 37: val_accuracy did not improve from 0.93843
# 30/30 - 0s - loss: 0.1333 - accuracy: 0.9538 - val_loss: 0.1769 - val_accuracy: 0.9278 - lr: 1.0000e-04 - 219ms/epoch - 7ms/step
# Epoch 38/60
#
# Epoch 38: val_accuracy did not improve from 0.93843
# 30/30 - 0s - loss: 0.1332 - accuracy: 0.9535 - val_loss: 0.1769 - val_accuracy: 0.9278 - lr: 1.0000e-04 - 126ms/epoch - 4ms/step
# Epoch 39/60
# Restoring model weights from the end of the best epoch: 24.
#
# Epoch 39: val_accuracy did not improve from 0.93843
# 30/30 - 0s - loss: 0.1329 - accuracy: 0.9541 - val_loss: 0.1770 - val_accuracy: 0.9299 - lr: 1.0000e-04 - 155ms/epoch - 5ms/step
# Epoch 39: early stopping
# Epoch 1/60
#
# Epoch 1: val_accuracy improved from -inf to 0.91401, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_summed/run_2FC/Entanglement_pool_summed_0321model.keras
# 30/30 - 1s - loss: 0.4070 - accuracy: 0.8133 - val_loss: 0.2220 - val_accuracy: 0.9140 - lr: 0.0010 - 1s/epoch - 43ms/step
# Epoch 2/60
#
# Epoch 2: val_accuracy improved from 0.91401 to 0.92463, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_summed/run_2FC/Entanglement_pool_summed_0321model.keras
# 30/30 - 0s - loss: 0.2039 - accuracy: 0.9177 - val_loss: 0.1970 - val_accuracy: 0.9246 - lr: 0.0010 - 302ms/epoch - 10ms/step
# Epoch 3/60
#
# Epoch 3: val_accuracy did not improve from 0.92463
# 30/30 - 0s - loss: 0.1694 - accuracy: 0.9363 - val_loss: 0.2109 - val_accuracy: 0.9183 - lr: 0.0010 - 231ms/epoch - 8ms/step
# Epoch 4/60
#
# Epoch 4: val_accuracy improved from 0.92463 to 0.93418, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_summed/run_2FC/Entanglement_pool_summed_0321model.keras
# 30/30 - 0s - loss: 0.1558 - accuracy: 0.9387 - val_loss: 0.1716 - val_accuracy: 0.9342 - lr: 0.0010 - 322ms/epoch - 11ms/step
# Epoch 5/60
#
# Epoch 5: val_accuracy did not improve from 0.93418
# 30/30 - 0s - loss: 0.1368 - accuracy: 0.9477 - val_loss: 0.1692 - val_accuracy: 0.9331 - lr: 0.0010 - 275ms/epoch - 9ms/step
# Epoch 6/60
#
# Epoch 6: val_accuracy improved from 0.93418 to 0.93524, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_summed/run_2FC/Entanglement_pool_summed_0321model.keras
# 30/30 - 0s - loss: 0.1131 - accuracy: 0.9565 - val_loss: 0.1667 - val_accuracy: 0.9352 - lr: 0.0010 - 348ms/epoch - 12ms/step
# Epoch 7/60
#
# Epoch 7: val_accuracy did not improve from 0.93524
# 30/30 - 0s - loss: 0.1079 - accuracy: 0.9575 - val_loss: 0.1635 - val_accuracy: 0.9331 - lr: 0.0010 - 274ms/epoch - 9ms/step
# Epoch 8/60
#
# Epoch 8: val_accuracy did not improve from 0.93524
# 30/30 - 0s - loss: 0.1012 - accuracy: 0.9607 - val_loss: 0.1769 - val_accuracy: 0.9331 - lr: 0.0010 - 257ms/epoch - 9ms/step
# Epoch 9/60
#
# Epoch 9: val_accuracy did not improve from 0.93524
# 30/30 - 0s - loss: 0.0765 - accuracy: 0.9734 - val_loss: 0.1788 - val_accuracy: 0.9310 - lr: 0.0010 - 228ms/epoch - 8ms/step
# Epoch 10/60
#
# Epoch 10: val_accuracy did not improve from 0.93524
# 30/30 - 0s - loss: 0.0672 - accuracy: 0.9793 - val_loss: 0.1689 - val_accuracy: 0.9352 - lr: 0.0010 - 241ms/epoch - 8ms/step
# Epoch 11/60
#
# Epoch 11: val_accuracy improved from 0.93524 to 0.93631, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_summed/run_2FC/Entanglement_pool_summed_0321model.keras
# 30/30 - 0s - loss: 0.0523 - accuracy: 0.9865 - val_loss: 0.1629 - val_accuracy: 0.9363 - lr: 0.0010 - 280ms/epoch - 9ms/step
# Epoch 12/60
#
# Epoch 12: val_accuracy improved from 0.93631 to 0.93737, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_summed/run_2FC/Entanglement_pool_summed_0321model.keras
# 30/30 - 0s - loss: 0.0518 - accuracy: 0.9849 - val_loss: 0.1640 - val_accuracy: 0.9374 - lr: 0.0010 - 316ms/epoch - 11ms/step
# Epoch 13/60
#
# Epoch 13: val_accuracy improved from 0.93737 to 0.94161, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_summed/run_2FC/Entanglement_pool_summed_0321model.keras
# 30/30 - 0s - loss: 0.0395 - accuracy: 0.9928 - val_loss: 0.1647 - val_accuracy: 0.9416 - lr: 0.0010 - 309ms/epoch - 10ms/step
# Epoch 14/60
#
# Epoch 14: val_accuracy did not improve from 0.94161
# 30/30 - 0s - loss: 0.0432 - accuracy: 0.9883 - val_loss: 0.1703 - val_accuracy: 0.9406 - lr: 0.0010 - 247ms/epoch - 8ms/step
# Epoch 15/60
#
# Epoch 15: val_accuracy did not improve from 0.94161
# 30/30 - 0s - loss: 0.0309 - accuracy: 0.9942 - val_loss: 0.1833 - val_accuracy: 0.9374 - lr: 0.0010 - 281ms/epoch - 9ms/step
# Epoch 16/60
#
# Epoch 16: val_accuracy did not improve from 0.94161
# 30/30 - 0s - loss: 0.0235 - accuracy: 0.9971 - val_loss: 0.1785 - val_accuracy: 0.9374 - lr: 0.0010 - 260ms/epoch - 9ms/step
# Epoch 17/60
#
# Epoch 17: val_accuracy improved from 0.94161 to 0.94480, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/0321/Entanglement_pool_summed/run_2FC/Entanglement_pool_summed_0321model.keras
# 30/30 - 0s - loss: 0.0182 - accuracy: 0.9995 - val_loss: 0.1715 - val_accuracy: 0.9448 - lr: 0.0010 - 324ms/epoch - 11ms/step
# Epoch 18/60
#
# Epoch 18: val_accuracy did not improve from 0.94480
# 30/30 - 0s - loss: 0.0149 - accuracy: 0.9992 - val_loss: 0.1796 - val_accuracy: 0.9406 - lr: 0.0010 - 263ms/epoch - 9ms/step
# Epoch 19/60
#
# Epoch 19: val_accuracy did not improve from 0.94480
# 30/30 - 0s - loss: 0.0115 - accuracy: 0.9995 - val_loss: 0.1985 - val_accuracy: 0.9384 - lr: 0.0010 - 237ms/epoch - 8ms/step
# Epoch 20/60
#
# Epoch 20: val_accuracy did not improve from 0.94480
# 30/30 - 0s - loss: 0.0114 - accuracy: 0.9995 - val_loss: 0.1848 - val_accuracy: 0.9406 - lr: 0.0010 - 233ms/epoch - 8ms/step
# Epoch 21/60
#
# Epoch 21: val_accuracy did not improve from 0.94480
# 30/30 - 0s - loss: 0.0089 - accuracy: 0.9995 - val_loss: 0.1890 - val_accuracy: 0.9416 - lr: 0.0010 - 241ms/epoch - 8ms/step
# Epoch 22/60
#
# Epoch 22: val_accuracy did not improve from 0.94480
# 30/30 - 0s - loss: 0.0104 - accuracy: 0.9997 - val_loss: 0.2006 - val_accuracy: 0.9384 - lr: 0.0010 - 239ms/epoch - 8ms/step
# Epoch 23/60
#
# Epoch 23: val_accuracy did not improve from 0.94480
# 30/30 - 0s - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.1932 - val_accuracy: 0.9384 - lr: 0.0010 - 239ms/epoch - 8ms/step
# Epoch 24/60
#
# Epoch 24: val_accuracy did not improve from 0.94480
# 30/30 - 0s - loss: 0.0060 - accuracy: 0.9997 - val_loss: 0.1971 - val_accuracy: 0.9437 - lr: 0.0010 - 256ms/epoch - 9ms/step
# Epoch 25/60
#
# Epoch 25: val_accuracy did not improve from 0.94480
# 30/30 - 0s - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.1987 - val_accuracy: 0.9427 - lr: 0.0010 - 265ms/epoch - 9ms/step
# Epoch 26/60
#
# Epoch 26: val_accuracy did not improve from 0.94480
# 30/30 - 0s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.2047 - val_accuracy: 0.9416 - lr: 0.0010 - 246ms/epoch - 8ms/step
# Epoch 27/60
#
# Epoch 27: val_accuracy did not improve from 0.94480
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 30/30 - 0s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.2076 - val_accuracy: 0.9384 - lr: 0.0010 - 236ms/epoch - 8ms/step
# Epoch 28/60
#
# Epoch 28: val_accuracy did not improve from 0.94480
# 30/30 - 0s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.2059 - val_accuracy: 0.9406 - lr: 1.0000e-04 - 259ms/epoch - 9ms/step
# Epoch 29/60
#
# ...
# 30/30 - 0s - loss: 0.0168 - accuracy: 0.9981 - val_loss: 0.1486 - val_accuracy: 0.9522 - lr: 0.0010 - 264ms/epoch - 9ms/step
# Epoch 16/60
#
# Epoch 16: val_accuracy did not improve from 0.95223
# 30/30 - 0s - loss: 0.0160 - accuracy: 0.9992 - val_loss: 0.1532 - val_accuracy: 0.9501 - lr: 0.0010 - 298ms/epoch - 10ms/step
# Epoch 17/60
#
# Epoch 17: val_accuracy did not improve from 0.95223
# 30/30 - 0s - loss: 0.0165 - accuracy: 0.9976 - val_loss: 0.1412 - val_accuracy: 0.9522 - lr: 0.0010 - 257ms/epoch - 9ms/step
# Epoch 18/60
#
# Epoch 18: val_accuracy did not improve from 0.95223
# 30/30 - 0s - loss: 0.0133 - accuracy: 0.9984 - val_loss: 0.1435 - val_accuracy: 0.9512 - lr: 0.0010 - 246ms/epoch - 8ms/step
# Epoch 19/60
#
# Epoch 19: val_accuracy did not improve from 0.95223
# 30/30 - 0s - loss: 0.0098 - accuracy: 0.9995 - val_loss: 0.1469 - val_accuracy: 0.9512 - lr: 0.0010 - 274ms/epoch - 9ms/step
# Epoch 20/60
#
# Epoch 20: val_accuracy did not improve from 0.95223
# 30/30 - 0s - loss: 0.0070 - accuracy: 0.9997 - val_loss: 0.1483 - val_accuracy: 0.9490 - lr: 0.0010 - 249ms/epoch - 8ms/step
# Epoch 21/60
#
# Epoch 21: val_accuracy did not improve from 0.95223
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 30/30 - 0s - loss: 0.0070 - accuracy: 0.9995 - val_loss: 0.1481 - val_accuracy: 0.9501 - lr: 0.0010 - 282ms/epoch - 9ms/step
# Epoch 22/60
#
# Epoch 22: val_accuracy did not improve from 0.95223
# 30/30 - 0s - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.9512 - lr: 1.0000e-04 - 280ms/epoch - 9ms/step
# Epoch 23/60
#
# Epoch 23: val_accuracy did not improve from 0.95223
# 30/30 - 0s - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9501 - lr: 1.0000e-04 - 311ms/epoch - 10ms/step
# Epoch 24/60
#
# Epoch 24: val_accuracy did not improve from 0.95223
# 30/30 - 0s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9512 - lr: 1.0000e-04 - 272ms/epoch - 9ms/step
# Epoch 25/60
#
# Epoch 25: val_accuracy did not improve from 0.95223
# 30/30 - 0s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.9522 - lr: 1.0000e-04 - 268ms/epoch - 9ms/step
# Epoch 26/60
# Restoring model weights from the end of the best epoch: 11.
#
# Epoch 26: val_accuracy did not improve from 0.95223
# 30/30 - 0s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9512 - lr: 1.0000e-04 - 280ms/epoch - 9ms/step
# Epoch 26: early stopping
# Epoch 1/60
#
# Epoch 1: val_accuracy improved from -inf to 0.92463, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/3102/Entanglement_pool_summed/run_3FC/Entanglement_pool_summed_3102model.keras
# 30/30 - 1s - loss: 0.3994 - accuracy: 0.8197 - val_loss: 0.1898 - val_accuracy: 0.9246 - lr: 0.0010 - 1s/epoch - 48ms/step
# Epoch 2/60
#
# Epoch 2: val_accuracy improved from 0.92463 to 0.94161, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/3102/Entanglement_pool_summed/run_3FC/Entanglement_pool_summed_3102model.keras
# 30/30 - 0s - loss: 0.1666 - accuracy: 0.9357 - val_loss: 0.1625 - val_accuracy: 0.9416 - lr: 0.0010 - 393ms/epoch - 13ms/step
# Epoch 3/60
#
# Epoch 3: val_accuracy improved from 0.94161 to 0.94692, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/3102/Entanglement_pool_summed/run_3FC/Entanglement_pool_summed_3102model.keras
# 30/30 - 0s - loss: 0.1284 - accuracy: 0.9495 - val_loss: 0.1451 - val_accuracy: 0.9469 - lr: 0.0010 - 445ms/epoch - 15ms/step
# Epoch 4/60
#
# Epoch 4: val_accuracy did not improve from 0.94692
# 30/30 - 0s - loss: 0.0991 - accuracy: 0.9623 - val_loss: 0.1476 - val_accuracy: 0.9363 - lr: 0.0010 - 339ms/epoch - 11ms/step
# Epoch 5/60
#
# Epoch 5: val_accuracy did not improve from 0.94692
# 30/30 - 0s - loss: 0.0844 - accuracy: 0.9687 - val_loss: 0.1381 - val_accuracy: 0.9437 - lr: 0.0010 - 362ms/epoch - 12ms/step
# Epoch 6/60
#
# Epoch 6: val_accuracy did not improve from 0.94692
# 30/30 - 0s - loss: 0.0729 - accuracy: 0.9716 - val_loss: 0.1379 - val_accuracy: 0.9427 - lr: 0.0010 - 322ms/epoch - 11ms/step
# Epoch 7/60
#
# Epoch 7: val_accuracy did not improve from 0.94692
# 30/30 - 0s - loss: 0.0832 - accuracy: 0.9665 - val_loss: 0.1411 - val_accuracy: 0.9416 - lr: 0.0010 - 342ms/epoch - 11ms/step
# Epoch 8/60
#
# Epoch 8: val_accuracy improved from 0.94692 to 0.95011, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/3102/Entanglement_pool_summed/run_3FC/Entanglement_pool_summed_3102model.keras
# 30/30 - 0s - loss: 0.0653 - accuracy: 0.9764 - val_loss: 0.1421 - val_accuracy: 0.9501 - lr: 0.0010 - 460ms/epoch - 15ms/step
# Epoch 9/60
#
# Epoch 9: val_accuracy did not improve from 0.95011
# 30/30 - 0s - loss: 0.0464 - accuracy: 0.9851 - val_loss: 0.1455 - val_accuracy: 0.9459 - lr: 0.0010 - 384ms/epoch - 13ms/step
# Epoch 10/60
#
# Epoch 10: val_accuracy improved from 0.95011 to 0.95329, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/3102/Entanglement_pool_summed/run_3FC/Entanglement_pool_summed_3102model.keras
# 30/30 - 0s - loss: 0.0407 - accuracy: 0.9838 - val_loss: 0.1539 - val_accuracy: 0.9533 - lr: 0.0010 - 396ms/epoch - 13ms/step
# Epoch 11/60
#
# Epoch 11: val_accuracy did not improve from 0.95329
# 30/30 - 0s - loss: 0.0219 - accuracy: 0.9955 - val_loss: 0.2120 - val_accuracy: 0.9395 - lr: 0.0010 - 345ms/epoch - 11ms/step
# Epoch 12/60
#
# Epoch 12: val_accuracy did not improve from 0.95329
# 30/30 - 0s - loss: 0.0250 - accuracy: 0.9923 - val_loss: 0.1575 - val_accuracy: 0.9522 - lr: 0.0010 - 324ms/epoch - 11ms/step
# Epoch 13/60
#
# Epoch 13: val_accuracy did not improve from 0.95329
# 30/30 - 0s - loss: 0.0100 - accuracy: 0.9987 - val_loss: 0.1630 - val_accuracy: 0.9533 - lr: 0.0010 - 291ms/epoch - 10ms/step
# Epoch 14/60
#
# Epoch 14: val_accuracy did not improve from 0.95329
# 30/30 - 0s - loss: 0.0087 - accuracy: 0.9984 - val_loss: 0.1672 - val_accuracy: 0.9480 - lr: 0.0010 - 347ms/epoch - 12ms/step
# Epoch 15/60
#
# Epoch 15: val_accuracy did not improve from 0.95329
# 30/30 - 0s - loss: 0.0055 - accuracy: 0.9992 - val_loss: 0.1917 - val_accuracy: 0.9533 - lr: 0.0010 - 317ms/epoch - 11ms/step
# Epoch 16/60
#
# Epoch 16: val_accuracy improved from 0.95329 to 0.95541, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/3102/Entanglement_pool_summed/run_3FC/Entanglement_pool_summed_3102model.keras
# 30/30 - 0s - loss: 0.0039 - accuracy: 0.9997 - val_loss: 0.1783 - val_accuracy: 0.9554 - lr: 0.0010 - 415ms/epoch - 14ms/step
# Epoch 17/60
#
# Epoch 17: val_accuracy did not improve from 0.95541
# 30/30 - 0s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1852 - val_accuracy: 0.9544 - lr: 0.0010 - 331ms/epoch - 11ms/step
# Epoch 18/60
#
# Epoch 18: val_accuracy improved from 0.95541 to 0.95754, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/3102/Entanglement_pool_summed/run_3FC/Entanglement_pool_summed_3102model.keras
# 30/30 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1915 - val_accuracy: 0.9575 - lr: 0.0010 - 424ms/epoch - 14ms/step
# Epoch 19/60
#
# Epoch 19: val_accuracy did not improve from 0.95754
# 30/30 - 0s - loss: 8.5466e-04 - accuracy: 1.0000 - val_loss: 0.1980 - val_accuracy: 0.9565 - lr: 0.0010 - 291ms/epoch - 10ms/step
# Epoch 20/60
#
# Epoch 20: val_accuracy did not improve from 0.95754
# 30/30 - 0s - loss: 6.6313e-04 - accuracy: 1.0000 - val_loss: 0.2025 - val_accuracy: 0.9554 - lr: 0.0010 - 369ms/epoch - 12ms/step
# Epoch 21/60
#
# Epoch 21: val_accuracy did not improve from 0.95754
# 30/30 - 0s - loss: 5.3159e-04 - accuracy: 1.0000 - val_loss: 0.2057 - val_accuracy: 0.9554 - lr: 0.0010 - 306ms/epoch - 10ms/step
# Epoch 22/60
#
# Epoch 22: val_accuracy did not improve from 0.95754
# 30/30 - 0s - loss: 4.4507e-04 - accuracy: 1.0000 - val_loss: 0.2100 - val_accuracy: 0.9554 - lr: 0.0010 - 319ms/epoch - 11ms/step
# Epoch 23/60
#
# Epoch 23: val_accuracy did not improve from 0.95754
# 30/30 - 0s - loss: 3.9325e-04 - accuracy: 1.0000 - val_loss: 0.2126 - val_accuracy: 0.9565 - lr: 0.0010 - 334ms/epoch - 11ms/step
# Epoch 24/60
#
# Epoch 24: val_accuracy did not improve from 0.95754
# 30/30 - 0s - loss: 3.3918e-04 - accuracy: 1.0000 - val_loss: 0.2171 - val_accuracy: 0.9533 - lr: 0.0010 - 330ms/epoch - 11ms/step
# Epoch 25/60
#
# Epoch 25: val_accuracy did not improve from 0.95754
# 30/30 - 0s - loss: 3.0112e-04 - accuracy: 1.0000 - val_loss: 0.2184 - val_accuracy: 0.9565 - lr: 0.0010 - 298ms/epoch - 10ms/step
# Epoch 26/60
#
# Epoch 26: val_accuracy did not improve from 0.95754
# 30/30 - 0s - loss: 2.7059e-04 - accuracy: 1.0000 - val_loss: 0.2216 - val_accuracy: 0.9554 - lr: 0.0010 - 347ms/epoch - 12ms/step
# Epoch 27/60
#
# Epoch 27: val_accuracy did not improve from 0.95754
# 30/30 - 0s - loss: 2.3495e-04 - accuracy: 1.0000 - val_loss: 0.2246 - val_accuracy: 0.9554 - lr: 0.0010 - 322ms/epoch - 11ms/step
# Epoch 28/60
#
# Epoch 28: val_accuracy did not improve from 0.95754
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 30/30 - 0s - loss: 2.0850e-04 - accuracy: 1.0000 - val_loss: 0.2281 - val_accuracy: 0.9533 - lr: 0.0010 - 293ms/epoch - 10ms/step
# Epoch 29/60
#
# Epoch 29: val_accuracy did not improve from 0.95754
# 30/30 - 0s - loss: 1.9060e-04 - accuracy: 1.0000 - val_loss: 0.2274 - val_accuracy: 0.9565 - lr: 1.0000e-04 - 272ms/epoch - 9ms/step
# Epoch 30/60
#
# Epoch 30: val_accuracy did not improve from 0.95754
# 30/30 - 0s - loss: 1.8584e-04 - accuracy: 1.0000 - val_loss: 0.2274 - val_accuracy: 0.9565 - lr: 1.0000e-04 - 260ms/epoch - 9ms/step
# Epoch 31/60
#
# Epoch 31: val_accuracy did not improve from 0.95754
# 30/30 - 0s - loss: 1.8394e-04 - accuracy: 1.0000 - val_loss: 0.2278 - val_accuracy: 0.9565 - lr: 1.0000e-04 - 281ms/epoch - 9ms/step
# Epoch 32/60
#
# Epoch 32: val_accuracy did not improve from 0.95754
# 30/30 - 0s - loss: 1.8175e-04 - accuracy: 1.0000 - val_loss: 0.2280 - val_accuracy: 0.9565 - lr: 1.0000e-04 - 280ms/epoch - 9ms/step
# Epoch 33/60
# Restoring model weights from the end of the best epoch: 18.
#
# Epoch 33: val_accuracy did not improve from 0.95754
# 30/30 - 0s - loss: 1.7960e-04 - accuracy: 1.0000 - val_loss: 0.2284 - val_accuracy: 0.9565 - lr: 1.0000e-04 - 284ms/epoch - 9ms/step
# Epoch 33: early stopping
# Epoch 1/60
#
# Epoch 1: val_accuracy improved from -inf to 0.93631, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/3102/Entanglement_pool_summed/run_4FC/Entanglement_pool_summed_3102model.keras
# 30/30 - 2s - loss: 0.3288 - accuracy: 0.8532 - val_loss: 0.1799 - val_accuracy: 0.9363 - lr: 0.0010 - 2s/epoch - 79ms/step
# Epoch 2/60
#
# Epoch 2: val_accuracy did not improve from 0.93631
# 30/30 - 0s - loss: 0.1444 - accuracy: 0.9434 - val_loss: 0.3066 - val_accuracy: 0.8896 - lr: 0.0010 - 346ms/epoch - 12ms/step
# Epoch 3/60
#
# Epoch 3: val_accuracy did not improve from 0.93631
# 30/30 - 0s - loss: 0.1814 - accuracy: 0.9307 - val_loss: 0.1663 - val_accuracy: 0.9363 - lr: 0.0010 - 328ms/epoch - 11ms/step
# Epoch 4/60
#
# Epoch 4: val_accuracy did not improve from 0.93631
# 30/30 - 0s - loss: 0.1097 - accuracy: 0.9578 - val_loss: 0.1777 - val_accuracy: 0.9289 - lr: 0.0010 - 348ms/epoch - 12ms/step
# Epoch 5/60
#
# Epoch 5: val_accuracy did not improve from 0.93631
# 30/30 - 0s - loss: 0.0863 - accuracy: 0.9687 - val_loss: 0.1880 - val_accuracy: 0.9331 - lr: 0.0010 - 329ms/epoch - 11ms/step
# Epoch 6/60
#
# Epoch 6: val_accuracy improved from 0.93631 to 0.94480, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/3102/Entanglement_pool_summed/run_4FC/Entanglement_pool_summed_3102model.keras
# 30/30 - 0s - loss: 0.0844 - accuracy: 0.9665 - val_loss: 0.1317 - val_accuracy: 0.9448 - lr: 0.0010 - 404ms/epoch - 13ms/step
# Epoch 7/60
#
# Epoch 7: val_accuracy improved from 0.94480 to 0.94586, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/3102/Entanglement_pool_summed/run_4FC/Entanglement_pool_summed_3102model.keras
# 30/30 - 0s - loss: 0.0713 - accuracy: 0.9729 - val_loss: 0.1514 - val_accuracy: 0.9459 - lr: 0.0010 - 395ms/epoch - 13ms/step
# Epoch 8/60
#
# Epoch 8: val_accuracy improved from 0.94586 to 0.94798, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/3102/Entanglement_pool_summed/run_4FC/Entanglement_pool_summed_3102model.keras
# 30/30 - 0s - loss: 0.0527 - accuracy: 0.9806 - val_loss: 0.1643 - val_accuracy: 0.9480 - lr: 0.0010 - 400ms/epoch - 13ms/step
# Epoch 9/60
#
# Epoch 9: val_accuracy did not improve from 0.94798
# 30/30 - 0s - loss: 0.0527 - accuracy: 0.9809 - val_loss: 0.2172 - val_accuracy: 0.9384 - lr: 0.0010 - 350ms/epoch - 12ms/step
# Epoch 10/60
#
# Epoch 10: val_accuracy improved from 0.94798 to 0.95117, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/3102/Entanglement_pool_summed/run_4FC/Entanglement_pool_summed_3102model.keras
# 30/30 - 0s - loss: 0.0377 - accuracy: 0.9846 - val_loss: 0.1346 - val_accuracy: 0.9512 - lr: 0.0010 - 415ms/epoch - 14ms/step
# Epoch 11/60
#
# Epoch 11: val_accuracy improved from 0.95117 to 0.95329, saving model to _OA_results_PneumoniaMNIST_train_with_val_64/3102/Entanglement_pool_summed/run_4FC/Entanglement_pool_summed_3102model.keras
# 30/30 - 0s - loss: 0.0165 - accuracy: 0.9958 - val_loss: 0.1615 - val_accuracy: 0.9533 - lr: 0.0010 - 387ms/epoch - 13ms/step
# Epoch 12/60
#
# Epoch 12: val_accuracy did not improve from 0.95329
# 30/30 - 0s - loss: 0.0110 - accuracy: 0.9979 - val_loss: 0.2115 - val_accuracy: 0.9469 - lr: 0.0010 - 342ms/epoch - 11ms/step
# Epoch 13/60
#
# Epoch 13: val_accuracy did not improve from 0.95329
# 30/30 - 0s - loss: 0.0114 - accuracy: 0.9963 - val_loss: 0.1894 - val_accuracy: 0.9522 - lr: 0.0010 - 372ms/epoch - 12ms/step
# Epoch 14/60
#
# Epoch 14: val_accuracy did not improve from 0.95329
# 30/30 - 0s - loss: 0.0125 - accuracy: 0.9958 - val_loss: 0.1727 - val_accuracy: 0.9501 - lr: 0.0010 - 334ms/epoch - 11ms/step
# Epoch 15/60
#
# Epoch 15: val_accuracy did not improve from 0.95329
# 30/30 - 0s - loss: 0.0057 - accuracy: 0.9984 - val_loss: 0.2068 - val_accuracy: 0.9522 - lr: 0.0010 - 311ms/epoch - 10ms/step
# Epoch 16/60
#
# Epoch 16: val_accuracy did not improve from 0.95329
# 30/30 - 0s - loss: 0.0025 - accuracy: 0.9997 - val_loss: 0.2281 - val_accuracy: 0.9533 - lr: 0.0010 - 334ms/epoch - 11ms/step
# Epoch 17/60
#
# Epoch 17: val_accuracy did not improve from 0.95329
# 30/30 - 0s - loss: 5.8610e-04 - accuracy: 1.0000 - val_loss: 0.2306 - val_accuracy: 0.9522 - lr: 0.0010 - 330ms/epoch - 11ms/step
# Epoch 18/60
#
# Epoch 18: val_accuracy did not improve from 0.95329
# 30/30 - 0s - loss: 2.8897e-04 - accuracy: 1.0000 - val_loss: 0.2392 - val_accuracy: 0.9522 - lr: 0.0010 - 294ms/epoch - 10ms/step
# Epoch 19/60
#
# Epoch 19: val_accuracy did not improve from 0.95329
# 30/30 - 0s - loss: 1.7440e-04 - accuracy: 1.0000 - val_loss: 0.2516 - val_accuracy: 0.9512 - lr: 0.0010 - 292ms/epoch - 10ms/step
# Epoch 20/60
#
# Epoch 20: val_accuracy did not improve from 0.95329
# 30/30 - 0s - loss: 1.2490e-04 - accuracy: 1.0000 - val_loss: 0.2581 - val_accuracy: 0.9522 - lr: 0.0010 - 287ms/epoch - 10ms/step
# Epoch 21/60
#
# Epoch 21: val_accuracy did not improve from 0.95329
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 30/30 - 0s - loss: 1.0079e-04 - accuracy: 1.0000 - val_loss: 0.2627 - val_accuracy: 0.9512 - lr: 0.0010 - 345ms/epoch - 11ms/step
# Epoch 22/60
#
# Epoch 22: val_accuracy did not improve from 0.95329
# 30/30 - 0s - loss: 8.6832e-05 - accuracy: 1.0000 - val_loss: 0.2631 - val_accuracy: 0.9512 - lr: 1.0000e-04 - 297ms/epoch - 10ms/step
# Epoch 23/60
#
# Epoch 23: val_accuracy did not improve from 0.95329
# 30/30 - 0s - loss: 8.5034e-05 - accuracy: 1.0000 - val_loss: 0.2637 - val_accuracy: 0.9512 - lr: 1.0000e-04 - 311ms/epoch - 10ms/step
# Epoch 24/60
#
# Epoch 24: val_accuracy did not improve from 0.95329
# 30/30 - 0s - loss: 8.3596e-05 - accuracy: 1.0000 - val_loss: 0.2642 - val_accuracy: 0.9512 - lr: 1.0000e-04 - 310ms/epoch - 10ms/step
# Epoch 25/60
#
# Epoch 25: val_accuracy did not improve from 0.95329
# 30/30 - 0s - loss: 8.2141e-05 - accuracy: 1.0000 - val_loss: 0.2646 - val_accuracy: 0.9512 - lr: 1.0000e-04 - 312ms/epoch - 10ms/step
# Epoch 26/60
# Restoring model weights from the end of the best epoch: 11.
#
# Epoch 26: val_accuracy did not improve from 0.95329
# 30/30 - 0s - loss: 8.0859e-05 - accuracy: 1.0000 - val_loss: 0.2650 - val_accuracy: 0.9512 - lr: 1.0000e-04 - 314ms/epoch - 10ms/step
# Epoch 26: early stopping

# %%
Entanglement_pooled_sample = joblib.load(f'{Entanglement_pooled_file_name}.joblib')

# %%
len(Entanglement_pooled_sample[0])
# Out:
# 1024

# %%
train_images.shape[1]
# Out:
# 1024
