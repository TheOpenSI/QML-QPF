# %%
# importing sys
import sys
# This is how you import modules that exist outside of working directory 
# adding mosaique to the system path
sys.path.insert(1, '/workspaces/QML-QPF/mosaiQue') 
sys.path.insert(1, '/workspaces/QML-QPF/Quantifying_Entanglement')

import mosaique as mq
import scipy
from concurrent.futures import ProcessPoolExecutor, as_completed
import itertools
import numpy as np
import pennylane as qml
import os
from mosaique.models.operation import OperationLayer
from tensorflow import keras
import tensorflow as tf 
import time
from Entropy import compute_entropy_for_pair_batch

# %%
# if the below cell raise this error [ModuleNotFoundError: No module named 'tensorrt']
# uncomment and run the next line, then restart the kernel 
# pip install tensorrt

# %% [markdown]
# ## Check GPU installation is working

# %%
import tensorrt as trt

print(f' tensorflow version {tf.__version__}')

print(f' tensorrt version {trt.__version__}')

print(tf.config.list_physical_devices('GPU'))
# Out:
#  tensorflow version 2.15.0
#  tensorrt version 10.12.0.36
# []

# %%
# Set the environment for asynchronous GPU usage
os.environ['TF_GPU_ALLOCATOR'] = 'cuda_malloc_async'

# %%
def operation():
    dev = qml.device("default.qubit.tf", wires=4)
    @qml.qnode(dev, interface='tf')
    def cnot(inputs):
        inputs = inputs * np.pi
        qml.AngleEmbedding(inputs[:,...], wires=range(4), rotation='Y')

        qml.CNOT(wires=[0, 1])
        qml.CNOT(wires=[2, 3])

        # Measurement producing 4 classical output values
        return [qml.expval(qml.PauliZ(j)) for j in range(4)]
    return cnot

# %%
def preset():
    from tensorflow import keras
    # Download the eMnist dataset(Matlab format dataset) from this url: 
    # https://www.nist.gov/itl/products-and-services/emnist-dataset
    # Put either emnist-digits.mat or the enire dataset in Dataset folder so you won't need
    # to change the file_name
    # "Digits"
    file_name = r"/workspaces/QML-QPF/Other_Grayscale_datastes_results/eMnist_Digits/Dataset/emnist-digits.mat"
    emnist_digit_dataset = scipy.io.loadmat(file_name)
    
    type_of_class = "Digits"
    
    # # balanced
    # file_name = r"/workspaces/QML-QPF/Other_Grayscale_datastes_results/eMnist/Dataset/emnist-balanced.mat"
    # emnist_digit_dataset = scipy.io.loadmat(file_name)
    
    # type_of_class = "Balanced"
    
    # name of the folder where will save the filtered images for training
    tr_layer = mq.ConvolutionLayer4x4(f"_OA_results_eMnist_{type_of_class}_train_with_val")
    # name of the folder where will save the filtered images for testing
    te_layer = mq.ConvolutionLayer4x4(f"_OA_results_eMnist_{type_of_class}_test_with_val")
    #load the data set want to train
    train_images = emnist_digit_dataset['dataset']['train'][0][0][0][0][0]
    tr_images = train_images.reshape(len(train_images), 28, 28, 1)
    tr_labels = emnist_digit_dataset['dataset']['train'][0][0][0][0][1]

    test_images = emnist_digit_dataset['dataset']['test'][0][0][0][0][0]
    te_images = test_images.reshape(len(test_images), 28, 28, 1)
    te_labels = emnist_digit_dataset['dataset']['test'][0][0][0][0][1]
    #if you want slice the data for check reasons
    # tr_images = tr_images[:50:]
    # tr_labels = tr_labels[:50]
    # te_images = te_images[:10:]
    # te_labels = te_labels[:10]
    tr_layer.fit(tr_images)
    te_layer.fit(te_images)
    tr_images = tr_layer.transform(tr_images)
    te_images = te_layer.transform(te_images)
    return ((tr_layer, (tr_images, tr_labels)), (te_layer,(te_images, te_labels)))

with ProcessPoolExecutor() as executor:
    future = executor.submit(preset)

((train_layer, (train_images, train_labels)), (test_layer,(test_images, test_labels))) = future.result() #This blocks until the task completes

# %%
permutations = np.asarray(list(itertools.permutations(range(4))))

def pool(x, call, p, l):
    op = OperationLayer(call())
    predict = l.post_transform(op.pre_op.predict(x,batch_size=1000))
    l.save(predict, p)

# %%
# # not using PorcessPoolExecutor

# for p in permutations:
#     pool(train_images[:,:,p],)

# %%
for j in range(3):
    with ProcessPoolExecutor(8) as executor:
        runner = {
            executor.submit(pool, x=train_images[:,:,p], call=operation, p=p, l=train_layer): p for p in permutations[8*j:8*(j+1)]
        }
        for future in as_completed(runner):
            runner.pop(future)
# Out:
# 240/240 [==============================] - 92s 379ms/step
# 240/240 [==============================] - 98s 404ms/step
# 240/240 [==============================] - 102s 417ms/step
# 240/240 [==============================] - 103s 423ms/step
# 240/240 [==============================] - 104s 425ms/step
# 240/240 [==============================] - 103s 421ms/step
# 240/240 [==============================] - 101s 412ms/step
# 240/240 [==============================] - 99s 400ms/step
# 240/240 [==============================] - 94s 388ms/step
# 240/240 [==============================] - 99s 408ms/step
# 240/240 [==============================] - 102s 419ms/step
# 240/240 [==============================] - 103s 423ms/step
# 240/240 [==============================] - 103s 423ms/step
# 240/240 [==============================] - 103s 420ms/step
# 240/240 [==============================] - 101s 411ms/step
# 240/240 [==============================] - 99s 399ms/step
# 240/240 [==============================] - 95s 389ms/step
# 240/240 [==============================] - 101s 417ms/step
# 240/240 [==============================] - 104s 426ms/step
# 240/240 [==============================] - 104s 428ms/step
# 240/240 [==============================] - 105s 428ms/step
# 240/240 [==============================] - 104s 424ms/step
# 240/240 [==============================] - 103s 417ms/step
# 240/240 [==============================] - 100s 403ms/step

# %%
for j in range(3):
    with ProcessPoolExecutor(8) as executor:
        runner = {
            executor.submit(pool, x=test_images[:,:,p], call=operation, p=p, l=test_layer): p for p in permutations[8*j:8*(j+1)]
        }
        for future in as_completed(runner):
            runner.pop(future)
# Out:
# 40/40 [==============================] - 17s 398ms/step
# 40/40 [==============================] - 18s 432ms/step
# 40/40 [==============================] - 19s 434ms/step
# 40/40 [==============================] - 19s 435ms/step
# 40/40 [==============================] - 19s 432ms/step
# 40/40 [==============================] - 19s 431ms/step
# 40/40 [==============================] - 19s 416ms/step
# 40/40 [==============================] - 19s 402ms/step
# 40/40 [==============================] - 17s 404ms/step
# 40/40 [==============================] - 18s 418ms/step
# 40/40 [==============================] - 18s 416ms/step
# 40/40 [==============================] - 19s 425ms/step
# 40/40 [==============================] - 19s 421ms/step
# 40/40 [==============================] - 19s 422ms/step
# 40/40 [==============================] - 18s 408ms/step
# 40/40 [==============================] - 18s 393ms/step
# 40/40 [==============================] - 17s 396ms/step
# 40/40 [==============================] - 19s 437ms/step
# 40/40 [==============================] - 19s 442ms/step
# 40/40 [==============================] - 19s 447ms/step
# 40/40 [==============================] - 20s 443ms/step
# 40/40 [==============================] - 19s 438ms/step
# 40/40 [==============================] - 19s 425ms/step
# 40/40 [==============================] - 19s 393ms/step

# %% [markdown]
# ## Filtering Data by Entropy degree

# %%
# --- Function to process a single input type ---
def process_input_type(input_data, config, entropy_dict_for_symm):
    """
    Helper function to encapsulate the parallel processing logic for one input type.
    """
    input_system_03 = input_data[:, :, :2]
    input_system_21 = input_data[:, :, 2:4] # Assuming the same slicing  input_system_03 = input_data[:, :, :2]

    task_inputs = list(zip(input_system_03, input_system_21))
    # print("Im inside process_input_type")
    # print("len of task inputs is ", len(task_inputs) )
    # print(f"\nStarting parallel entropy computation for {data_name} data ({len(task_inputs)} batches)...")
    type_start_time = time.time()
    # from collections import defaultdict

    # entropy_dict_for_symm = defaultdict(list)   # missing keys become []
    # config = ''.join(map(str, config)) 
    with ProcessPoolExecutor(max_workers=None) as executor:
        results_iterator = executor.map(compute_entropy_for_pair_batch, task_inputs)

        for i, result in enumerate(results_iterator):
            # print(f"i is {i} and result is {type(result)} len {len(result)}")
            (avg_s1_rho0, avg_s1_rho1), \
            (avg_s2_rho0, avg_s2_rho1), \
            (max_s1_rho0, max_s1_rho1), \
            (max_s2_rho0, max_s2_rho1), \
            (S1_rho_0), \
            (S1_rho_1), \
            (S2_rho_0), \
            (S2_rho_1) = result
            
            # Append to the lists directly from the dictionary
            # Using dictionary keys here
            entropy_dict_for_symm['Total_Avg_' + config + '_Entropy_S1'].append((avg_s1_rho0, avg_s1_rho1))
            entropy_dict_for_symm['Total_Avg_' + config + '_Entropy_S2'].append((avg_s2_rho0, avg_s2_rho1))
            entropy_dict_for_symm['Total_Max_' + config + '_Entropy_S1'].append((max_s1_rho0, max_s1_rho1))
            entropy_dict_for_symm['Total_Max_' + config + '_Entropy_S2'].append((max_s2_rho0, max_s2_rho1))
            # New ones to capture pair entanglement for subsequent filtering
            entropy_dict_for_symm['S1_rho_0_' + config + '_Entropy_S1_0'].append(S1_rho_0)
            entropy_dict_for_symm['S1_rho_1_' + config + '_Entropy_S1_1'].append(S1_rho_1)
            entropy_dict_for_symm['S2_rho_0_' + config + '_Entropy_S2_0'].append(S2_rho_0)
            entropy_dict_for_symm['S2_rho_1_' + config + '_Entropy_S2_1'].append(S2_rho_1)

            if (i + 1) % 100 == 0:
                print(f"Processed {i + 1}/{len(task_inputs)} batches for {config}.")
                
        
        # Convert lists to NumPy arrays
        entropy_dict_for_symm['Total_Avg_' + config + '_Entropy_S1'] = np.array(entropy_dict_for_symm['Total_Avg_' + config + '_Entropy_S1'])
        entropy_dict_for_symm['Total_Avg_' + config + '_Entropy_S2'] = np.array(entropy_dict_for_symm['Total_Avg_' + config + '_Entropy_S2'])
        entropy_dict_for_symm['Total_Max_' + config + '_Entropy_S1'] = np.array(entropy_dict_for_symm['Total_Max_' + config + '_Entropy_S1'])
        entropy_dict_for_symm['Total_Max_' + config + '_Entropy_S2'] = np.array(entropy_dict_for_symm['Total_Max_' + config + '_Entropy_S2'])
        # New ones to capture pair entanglement for subsequent filtering
        entropy_dict_for_symm['S1_rho_0_' + config + '_Entropy_S1_0']  = np.array(entropy_dict_for_symm['S1_rho_0_' + config + '_Entropy_S1_0'])    
        entropy_dict_for_symm['S1_rho_1_' + config + '_Entropy_S1_1']  = np.array(entropy_dict_for_symm['S1_rho_1_' + config + '_Entropy_S1_1'])
        entropy_dict_for_symm['S2_rho_0_' + config + '_Entropy_S2_0']  = np.array(entropy_dict_for_symm['S2_rho_0_' + config + '_Entropy_S2_0'])
        entropy_dict_for_symm['S2_rho_1_' + config + '_Entropy_S2_1']  = np.array(entropy_dict_for_symm['S2_rho_1_' + config + '_Entropy_S2_1'])
        
        # compute the total entry of the entire system S1 + S2
        # Compute the total entropy of the entire system S1 + S2
        # Ensure avg_s1_array and avg_s2_array are in the correct shape (N, 2)
        # The output of compute_entropy_for_pair_batch is (rho0, rho1) tuples, which will become (N, 2) arrays.
        entropy_dict_for_symm['Total_Avg_' + config + '_Entropy_S1_S2'] = entropy_dict_for_symm['Total_Avg_' + config + '_Entropy_S1'] \
                                                                            + entropy_dict_for_symm['Total_Avg_' + config + '_Entropy_S2']
        entropy_dict_for_symm[f'Total_Max_{config}_Entropy_S1_S2'] = entropy_dict_for_symm['Total_Max_' + config + '_Entropy_S1'] \
                                                                            + entropy_dict_for_symm['Total_Max_' + config + '_Entropy_S2']

    # --- Saving Data as CSV ---
    # 1. Create the data_name specific folder

    entropy_folder_name = train_layer.name + f"/{config}/Entropy"
    # train
    # entropy_folder_name = "_OA_train"
    output_folder_path = os.path.join(entropy_folder_name) # Replace spaces for folder names
    os.makedirs(output_folder_path, exist_ok=True)
    print(f"Created/Ensured directory: {output_folder_path}")

    # 2. Save each list/array corresponding to each key as a CSV file
    for key, value in entropy_dict_for_symm.items():
        if isinstance(value, np.ndarray): # Only save if it's a NumPy array
            file_path = os.path.join(output_folder_path, f"{key}.csv")
            # Use fmt='%.8f' for float formatting, delimiter=',' for CSV
            np.savetxt(file_path, value, delimiter=',', fmt='%.8f')
            print(f"Saved {key}.csv to {output_folder_path}")
        else:
            print(f"Skipping saving for key '{key}' as it's not a NumPy array (type: {type(value)})")
    type_end_time = time.time()
    print(f"Finished parallel computation for data for config {config} in {type_end_time - type_start_time:.2f} seconds.")

# %%
# checked 
D = {    #  configuration that yields the best validation accuracy
    "Configs": { 
                "P_diagonal_config" : np.asarray([2,1,3,0]),
                "P_vertical_config" : np.asarray([1,0,2,3]),
                "P_horizontal_config" : np.asarray([2,0,1,3])
              }
    }
D_configs = D["Configs"].values()

# %%
# Scaling data
scaled_sample = train_images/255.
# Encoding data using angle encoding
scaled_sample = scaled_sample * np.pi
from collections import defaultdict


for config in D_configs:
    # rearranging the input in respect to the configs
    input = scaled_sample[:,:,config]

    entropy_dict_for_symm = defaultdict(list)   # missing keys become []
    config = ''.join(map(str, config))
    process_input_type(input, config, entropy_dict_for_symm)
    # break
# Out:
# Processed 100/240000 batches for 2130.
# Processed 200/240000 batches for 2130.
# Processed 300/240000 batches for 2130.
# Processed 400/240000 batches for 2130.
# Processed 500/240000 batches for 2130.
# Processed 600/240000 batches for 2130.
# Processed 700/240000 batches for 2130.
# Processed 800/240000 batches for 2130.
# Processed 900/240000 batches for 2130.
# Processed 1000/240000 batches for 2130.
# Processed 1100/240000 batches for 2130.
# Processed 1200/240000 batches for 2130.
# Processed 1300/240000 batches for 2130.
# Processed 1400/240000 batches for 2130.
# Processed 1500/240000 batches for 2130.
# Processed 1600/240000 batches for 2130.
# Processed 1700/240000 batches for 2130.
# Processed 1800/240000 batches for 2130.
# Processed 1900/240000 batches for 2130.
# Processed 2000/240000 batches for 2130.
# Processed 2100/240000 batches for 2130.
# Processed 2200/240000 batches for 2130.
# Processed 2300/240000 batches for 2130.
# Processed 2400/240000 batches for 2130.
# Processed 2500/240000 batches for 2130.
# Processed 2600/240000 batches for 2130.
# Processed 2700/240000 batches for 2130.
# Processed 2800/240000 batches for 2130.
# Processed 2900/240000 batches for 2130.
# Processed 3000/240000 batches for 2130.
# Processed 3100/240000 batches for 2130.
# Processed 3200/240000 batches for 2130.
# Processed 3300/240000 batches for 2130.
# Processed 3400/240000 batches for 2130.
# Processed 3500/240000 batches for 2130.
# Processed 3600/240000 batches for 2130.
# Processed 3700/240000 batches for 2130.
# Processed 3800/240000 batches for 2130.
# Processed 3900/240000 batches for 2130.
# Processed 4000/240000 batches for 2130.
# Processed 4100/240000 batches for 2130.
# Processed 4200/240000 batches for 2130.
# Processed 4300/240000 batches for 2130.
# Processed 4400/240000 batches for 2130.
# Processed 4500/240000 batches for 2130.
# Processed 4600/240000 batches for 2130.
# Processed 4700/240000 batches for 2130.
# Processed 4800/240000 batches for 2130.
# Processed 4900/240000 batches for 2130.
# Processed 5000/240000 batches for 2130.
# Processed 5100/240000 batches for 2130.
# Processed 5200/240000 batches for 2130.
# Processed 5300/240000 batches for 2130.
# Processed 5400/240000 batches for 2130.
# Processed 5500/240000 batches for 2130.
# Processed 5600/240000 batches for 2130.
# Processed 5700/240000 batches for 2130.
# Processed 5800/240000 batches for 2130.
# Processed 5900/240000 batches for 2130.
# Processed 6000/240000 batches for 2130.
# Processed 6100/240000 batches for 2130.
# Processed 6200/240000 batches for 2130.
# Processed 6300/240000 batches for 2130.
# Processed 6400/240000 batches for 2130.
# Processed 6500/240000 batches for 2130.
# Processed 6600/240000 batches for 2130.
# Processed 6700/240000 batches for 2130.
# Processed 6800/240000 batches for 2130.
# Processed 6900/240000 batches for 2130.
# Processed 7000/240000 batches for 2130.
# Processed 7100/240000 batches for 2130.
# Processed 7200/240000 batches for 2130.
# Processed 7300/240000 batches for 2130.
# Processed 7400/240000 batches for 2130.
# Processed 7500/240000 batches for 2130.
# Processed 7600/240000 batches for 2130.
# Processed 7700/240000 batches for 2130.
# Processed 7800/240000 batches for 2130.
# Processed 7900/240000 batches for 2130.
# Processed 8000/240000 batches for 2130.
# Processed 8100/240000 batches for 2130.
# Processed 8200/240000 batches for 2130.
# Processed 8300/240000 batches for 2130.
# Processed 8400/240000 batches for 2130.
# Processed 8500/240000 batches for 2130.
# Processed 8600/240000 batches for 2130.
# Processed 8700/240000 batches for 2130.
# Processed 8800/240000 batches for 2130.
# Processed 8900/240000 batches for 2130.
# Processed 9000/240000 batches for 2130.
# Processed 9100/240000 batches for 2130.
# Processed 9200/240000 batches for 2130.
# Processed 9300/240000 batches for 2130.
# Processed 9400/240000 batches for 2130.
# Processed 9500/240000 batches for 2130.
# Processed 9600/240000 batches for 2130.
# Processed 9700/240000 batches for 2130.
# Processed 9800/240000 batches for 2130.
# Processed 9900/240000 batches for 2130.
# Processed 10000/240000 batches for 2130.
# Processed 10100/240000 batches for 2130.
# Processed 10200/240000 batches for 2130.
# Processed 10300/240000 batches for 2130.
# Processed 10400/240000 batches for 2130.
# Processed 10500/240000 batches for 2130.
# Processed 10600/240000 batches for 2130.
# Processed 10700/240000 batches for 2130.
# Processed 10800/240000 batches for 2130.
# Processed 10900/240000 batches for 2130.
# Processed 11000/240000 batches for 2130.
# Processed 11100/240000 batches for 2130.
# Processed 11200/240000 batches for 2130.
# Processed 11300/240000 batches for 2130.
# Processed 11400/240000 batches for 2130.
# Processed 11500/240000 batches for 2130.
# Processed 11600/240000 batches for 2130.
# Processed 11700/240000 batches for 2130.
# Processed 11800/240000 batches for 2130.
# Processed 11900/240000 batches for 2130.
# Processed 12000/240000 batches for 2130.
# Processed 12100/240000 batches for 2130.
# Processed 12200/240000 batches for 2130.
# Processed 12300/240000 batches for 2130.
# Processed 12400/240000 batches for 2130.
# Processed 12500/240000 batches for 2130.
# Processed 12600/240000 batches for 2130.
# Processed 12700/240000 batches for 2130.
# Processed 12800/240000 batches for 2130.
# Processed 12900/240000 batches for 2130.
# Processed 13000/240000 batches for 2130.
# Processed 13100/240000 batches for 2130.
# Processed 13200/240000 batches for 2130.
# Processed 13300/240000 batches for 2130.
# Processed 13400/240000 batches for 2130.
# Processed 13500/240000 batches for 2130.
# Processed 13600/240000 batches for 2130.
# Processed 13700/240000 batches for 2130.
# Processed 13800/240000 batches for 2130.
# Processed 13900/240000 batches for 2130.
# Processed 14000/240000 batches for 2130.
# Processed 14100/240000 batches for 2130.
# Processed 14200/240000 batches for 2130.
# Processed 14300/240000 batches for 2130.
# Processed 14400/240000 batches for 2130.
# Processed 14500/240000 batches for 2130.
# Processed 14600/240000 batches for 2130.
# Processed 14700/240000 batches for 2130.
# Processed 14800/240000 batches for 2130.
# Processed 14900/240000 batches for 2130.
# Processed 15000/240000 batches for 2130.
# Processed 15100/240000 batches for 2130.
# Processed 15200/240000 batches for 2130.
# Processed 15300/240000 batches for 2130.
# Processed 15400/240000 batches for 2130.
# Processed 15500/240000 batches for 2130.
# Processed 15600/240000 batches for 2130.
# Processed 15700/240000 batches for 2130.
# Processed 15800/240000 batches for 2130.
# Processed 15900/240000 batches for 2130.
# Processed 16000/240000 batches for 2130.
# Processed 16100/240000 batches for 2130.
# Processed 16200/240000 batches for 2130.
# Processed 16300/240000 batches for 2130.
# Processed 16400/240000 batches for 2130.
# Processed 16500/240000 batches for 2130.
# Processed 16600/240000 batches for 2130.
# Processed 16700/240000 batches for 2130.
# Processed 16800/240000 batches for 2130.
# Processed 16900/240000 batches for 2130.
# Processed 17000/240000 batches for 2130.
# Processed 17100/240000 batches for 2130.
# Processed 17200/240000 batches for 2130.
# Processed 17300/240000 batches for 2130.
# Processed 17400/240000 batches for 2130.
# Processed 17500/240000 batches for 2130.
# Processed 17600/240000 batches for 2130.
# Processed 17700/240000 batches for 2130.
# Processed 17800/240000 batches for 2130.
# Processed 17900/240000 batches for 2130.
# Processed 18000/240000 batches for 2130.
# Processed 18100/240000 batches for 2130.
# Processed 18200/240000 batches for 2130.
# Processed 18300/240000 batches for 2130.
# Processed 18400/240000 batches for 2130.
# Processed 18500/240000 batches for 2130.
# Processed 18600/240000 batches for 2130.
# Processed 18700/240000 batches for 2130.
# Processed 18800/240000 batches for 2130.
# Processed 18900/240000 batches for 2130.
# Processed 19000/240000 batches for 2130.
# Processed 19100/240000 batches for 2130.
# Processed 19200/240000 batches for 2130.
# Processed 19300/240000 batches for 2130.
# Processed 19400/240000 batches for 2130.
# Processed 19500/240000 batches for 2130.
# Processed 19600/240000 batches for 2130.
# Processed 19700/240000 batches for 2130.
# Processed 19800/240000 batches for 2130.
# Processed 19900/240000 batches for 2130.
# Processed 20000/240000 batches for 2130.
# Processed 20100/240000 batches for 2130.
# Processed 20200/240000 batches for 2130.
# Processed 20300/240000 batches for 2130.
# Processed 20400/240000 batches for 2130.
# Processed 20500/240000 batches for 2130.
# Processed 20600/240000 batches for 2130.
# Processed 20700/240000 batches for 2130.
# Processed 20800/240000 batches for 2130.
# Processed 20900/240000 batches for 2130.
# Processed 21000/240000 batches for 2130.
# Processed 21100/240000 batches for 2130.
# Processed 21200/240000 batches for 2130.
# Processed 21300/240000 batches for 2130.
# Processed 21400/240000 batches for 2130.
# Processed 21500/240000 batches for 2130.
# Processed 21600/240000 batches for 2130.
# Processed 21700/240000 batches for 2130.
# Processed 21800/240000 batches for 2130.
# Processed 21900/240000 batches for 2130.
# Processed 22000/240000 batches for 2130.
# Processed 22100/240000 batches for 2130.
# Processed 22200/240000 batches for 2130.
# Processed 22300/240000 batches for 2130.
# Processed 22400/240000 batches for 2130.
# Processed 22500/240000 batches for 2130.
# Processed 22600/240000 batches for 2130.
# Processed 22700/240000 batches for 2130.
# Processed 22800/240000 batches for 2130.
# Processed 22900/240000 batches for 2130.
# Processed 23000/240000 batches for 2130.
# Processed 23100/240000 batches for 2130.
# Processed 23200/240000 batches for 2130.
# Processed 23300/240000 batches for 2130.
# Processed 23400/240000 batches for 2130.
# Processed 23500/240000 batches for 2130.
# Processed 23600/240000 batches for 2130.
# Processed 23700/240000 batches for 2130.
# Processed 23800/240000 batches for 2130.
# Processed 23900/240000 batches for 2130.
# Processed 24000/240000 batches for 2130.
# Processed 24100/240000 batches for 2130.
# Processed 24200/240000 batches for 2130.
# Processed 24300/240000 batches for 2130.
# Processed 24400/240000 batches for 2130.
# Processed 24500/240000 batches for 2130.
# Processed 24600/240000 batches for 2130.
# Processed 24700/240000 batches for 2130.
# Processed 24800/240000 batches for 2130.
# Processed 24900/240000 batches for 2130.
# Processed 25000/240000 batches for 2130.
# Processed 25100/240000 batches for 2130.
# Processed 25200/240000 batches for 2130.
# Processed 25300/240000 batches for 2130.
# Processed 25400/240000 batches for 2130.
# Processed 25500/240000 batches for 2130.
# Processed 25600/240000 batches for 2130.
# Processed 25700/240000 batches for 2130.
# Processed 25800/240000 batches for 2130.
# Processed 25900/240000 batches for 2130.
# Processed 26000/240000 batches for 2130.
# Processed 26100/240000 batches for 2130.
# Processed 26200/240000 batches for 2130.
# Processed 26300/240000 batches for 2130.
# Processed 26400/240000 batches for 2130.
# Processed 26500/240000 batches for 2130.
# Processed 26600/240000 batches for 2130.
# Processed 26700/240000 batches for 2130.
# Processed 26800/240000 batches for 2130.
# Processed 26900/240000 batches for 2130.
# Processed 27000/240000 batches for 2130.
# Processed 27100/240000 batches for 2130.
# Processed 27200/240000 batches for 2130.
# Processed 27300/240000 batches for 2130.
# Processed 27400/240000 batches for 2130.
# Processed 27500/240000 batches for 2130.
# Processed 27600/240000 batches for 2130.
# Processed 27700/240000 batches for 2130.
# Processed 27800/240000 batches for 2130.
# Processed 27900/240000 batches for 2130.
# Processed 28000/240000 batches for 2130.
# Processed 28100/240000 batches for 2130.
# Processed 28200/240000 batches for 2130.
# Processed 28300/240000 batches for 2130.
# Processed 28400/240000 batches for 2130.
# Processed 28500/240000 batches for 2130.
# Processed 28600/240000 batches for 2130.
# Processed 28700/240000 batches for 2130.
# Processed 28800/240000 batches for 2130.
# Processed 28900/240000 batches for 2130.
# Processed 29000/240000 batches for 2130.
# Processed 29100/240000 batches for 2130.
# Processed 29200/240000 batches for 2130.
# Processed 29300/240000 batches for 2130.
# Processed 29400/240000 batches for 2130.
# Processed 29500/240000 batches for 2130.
# Processed 29600/240000 batches for 2130.
# Processed 29700/240000 batches for 2130.
# Processed 29800/240000 batches for 2130.
# Processed 29900/240000 batches for 2130.
# Processed 30000/240000 batches for 2130.
# Processed 30100/240000 batches for 2130.
# Processed 30200/240000 batches for 2130.
# Processed 30300/240000 batches for 2130.
# Processed 30400/240000 batches for 2130.
# Processed 30500/240000 batches for 2130.
# Processed 30600/240000 batches for 2130.
# Processed 30700/240000 batches for 2130.
# Processed 30800/240000 batches for 2130.
# Processed 30900/240000 batches for 2130.
# Processed 31000/240000 batches for 2130.
# Processed 31100/240000 batches for 2130.
# Processed 31200/240000 batches for 2130.
# Processed 31300/240000 batches for 2130.
# Processed 31400/240000 batches for 2130.
# Processed 31500/240000 batches for 2130.
# Processed 31600/240000 batches for 2130.
# Processed 31700/240000 batches for 2130.
# Processed 31800/240000 batches for 2130.
# Processed 31900/240000 batches for 2130.
# Processed 32000/240000 batches for 2130.
# Processed 32100/240000 batches for 2130.
# Processed 32200/240000 batches for 2130.
# Processed 32300/240000 batches for 2130.
# Processed 32400/240000 batches for 2130.
# Processed 32500/240000 batches for 2130.
# Processed 32600/240000 batches for 2130.
# Processed 32700/240000 batches for 2130.
# Processed 32800/240000 batches for 2130.
# Processed 32900/240000 batches for 2130.
# Processed 33000/240000 batches for 2130.
# Processed 33100/240000 batches for 2130.
# Processed 33200/240000 batches for 2130.
# Processed 33300/240000 batches for 2130.
# Processed 33400/240000 batches for 2130.
# Processed 33500/240000 batches for 2130.
# Processed 33600/240000 batches for 2130.
# Processed 33700/240000 batches for 2130.
# Processed 33800/240000 batches for 2130.
# Processed 33900/240000 batches for 2130.
# Processed 34000/240000 batches for 2130.
# Processed 34100/240000 batches for 2130.
# Processed 34200/240000 batches for 2130.
# Processed 34300/240000 batches for 2130.
# Processed 34400/240000 batches for 2130.
# Processed 34500/240000 batches for 2130.
# Processed 34600/240000 batches for 2130.
# Processed 34700/240000 batches for 2130.
# Processed 34800/240000 batches for 2130.
# Processed 34900/240000 batches for 2130.
# Processed 35000/240000 batches for 2130.
# Processed 35100/240000 batches for 2130.
# Processed 35200/240000 batches for 2130.
# Processed 35300/240000 batches for 2130.
# Processed 35400/240000 batches for 2130.
# Processed 35500/240000 batches for 2130.
# Processed 35600/240000 batches for 2130.
# Processed 35700/240000 batches for 2130.
# Processed 35800/240000 batches for 2130.
# Processed 35900/240000 batches for 2130.
# Processed 36000/240000 batches for 2130.
# Processed 36100/240000 batches for 2130.
# Processed 36200/240000 batches for 2130.
# Processed 36300/240000 batches for 2130.
# Processed 36400/240000 batches for 2130.
# Processed 36500/240000 batches for 2130.
# Processed 36600/240000 batches for 2130.
# Processed 36700/240000 batches for 2130.
# Processed 36800/240000 batches for 2130.
# Processed 36900/240000 batches for 2130.
# Processed 37000/240000 batches for 2130.
# Processed 37100/240000 batches for 2130.
# Processed 37200/240000 batches for 2130.
# Processed 37300/240000 batches for 2130.
# Processed 37400/240000 batches for 2130.
# Processed 37500/240000 batches for 2130.
# Processed 37600/240000 batches for 2130.
# Processed 37700/240000 batches for 2130.
# Processed 37800/240000 batches for 2130.
# Processed 37900/240000 batches for 2130.
# Processed 38000/240000 batches for 2130.
# Processed 38100/240000 batches for 2130.
# Processed 38200/240000 batches for 2130.
# Processed 38300/240000 batches for 2130.
# Processed 38400/240000 batches for 2130.
# Processed 38500/240000 batches for 2130.
# Processed 38600/240000 batches for 2130.
# Processed 38700/240000 batches for 2130.
# Processed 38800/240000 batches for 2130.
# Processed 38900/240000 batches for 2130.
# Processed 39000/240000 batches for 2130.
# Processed 39100/240000 batches for 2130.
# Processed 39200/240000 batches for 2130.
# Processed 39300/240000 batches for 2130.
# Processed 39400/240000 batches for 2130.
# Processed 39500/240000 batches for 2130.
# Processed 39600/240000 batches for 2130.
# Processed 39700/240000 batches for 2130.
# Processed 39800/240000 batches for 2130.
# Processed 39900/240000 batches for 2130.
# Processed 40000/240000 batches for 2130.
# Processed 40100/240000 batches for 2130.
# Processed 40200/240000 batches for 2130.
# Processed 40300/240000 batches for 2130.
# Processed 40400/240000 batches for 2130.
# Processed 40500/240000 batches for 2130.
# Processed 40600/240000 batches for 2130.
# Processed 40700/240000 batches for 2130.
# Processed 40800/240000 batches for 2130.
# Processed 40900/240000 batches for 2130.
# Processed 41000/240000 batches for 2130.
# Processed 41100/240000 batches for 2130.
# Processed 41200/240000 batches for 2130.
# Processed 41300/240000 batches for 2130.
# Processed 41400/240000 batches for 2130.
# Processed 41500/240000 batches for 2130.
# Processed 41600/240000 batches for 2130.
# Processed 41700/240000 batches for 2130.
# Processed 41800/240000 batches for 2130.
# Processed 41900/240000 batches for 2130.
# Processed 42000/240000 batches for 2130.
# Processed 42100/240000 batches for 2130.
# Processed 42200/240000 batches for 2130.
# Processed 42300/240000 batches for 2130.
# Processed 42400/240000 batches for 2130.
# Processed 42500/240000 batches for 2130.
# Processed 42600/240000 batches for 2130.
# Processed 42700/240000 batches for 2130.
# Processed 42800/240000 batches for 2130.
# Processed 42900/240000 batches for 2130.
# Processed 43000/240000 batches for 2130.
# Processed 43100/240000 batches for 2130.
# Processed 43200/240000 batches for 2130.
# Processed 43300/240000 batches for 2130.
# Processed 43400/240000 batches for 2130.
# Processed 43500/240000 batches for 2130.
# Processed 43600/240000 batches for 2130.
# Processed 43700/240000 batches for 2130.
# Processed 43800/240000 batches for 2130.
# Processed 43900/240000 batches for 2130.
# Processed 44000/240000 batches for 2130.
# Processed 44100/240000 batches for 2130.
# Processed 44200/240000 batches for 2130.
# Processed 44300/240000 batches for 2130.
# Processed 44400/240000 batches for 2130.
# Processed 44500/240000 batches for 2130.
# Processed 44600/240000 batches for 2130.
# Processed 44700/240000 batches for 2130.
# Processed 44800/240000 batches for 2130.
# Processed 44900/240000 batches for 2130.
# Processed 45000/240000 batches for 2130.
# Processed 45100/240000 batches for 2130.
# Processed 45200/240000 batches for 2130.
# Processed 45300/240000 batches for 2130.
# Processed 45400/240000 batches for 2130.
# Processed 45500/240000 batches for 2130.
# Processed 45600/240000 batches for 2130.
# Processed 45700/240000 batches for 2130.
# Processed 45800/240000 batches for 2130.
# Processed 45900/240000 batches for 2130.
# Processed 46000/240000 batches for 2130.
# Processed 46100/240000 batches for 2130.
# Processed 46200/240000 batches for 2130.
# Processed 46300/240000 batches for 2130.
# Processed 46400/240000 batches for 2130.
# Processed 46500/240000 batches for 2130.
# Processed 46600/240000 batches for 2130.
# Processed 46700/240000 batches for 2130.
# Processed 46800/240000 batches for 2130.
# Processed 46900/240000 batches for 2130.
# Processed 47000/240000 batches for 2130.
# Processed 47100/240000 batches for 2130.
# Processed 47200/240000 batches for 2130.
# Processed 47300/240000 batches for 2130.
# Processed 47400/240000 batches for 2130.
# Processed 47500/240000 batches for 2130.
# Processed 47600/240000 batches for 2130.
# Processed 47700/240000 batches for 2130.
# Processed 47800/240000 batches for 2130.
# Processed 47900/240000 batches for 2130.
# Processed 48000/240000 batches for 2130.
# Processed 48100/240000 batches for 2130.
# Processed 48200/240000 batches for 2130.
# Processed 48300/240000 batches for 2130.
# Processed 48400/240000 batches for 2130.
# Processed 48500/240000 batches for 2130.
# Processed 48600/240000 batches for 2130.
# Processed 48700/240000 batches for 2130.
# Processed 48800/240000 batches for 2130.
# Processed 48900/240000 batches for 2130.
# Processed 49000/240000 batches for 2130.
# Processed 49100/240000 batches for 2130.
# Processed 49200/240000 batches for 2130.
# Processed 49300/240000 batches for 2130.
# Processed 49400/240000 batches for 2130.
# Processed 49500/240000 batches for 2130.
# Processed 49600/240000 batches for 2130.
# Processed 49700/240000 batches for 2130.
# Processed 49800/240000 batches for 2130.
# Processed 49900/240000 batches for 2130.
# Processed 50000/240000 batches for 2130.
# Processed 50100/240000 batches for 2130.
# Processed 50200/240000 batches for 2130.
# Processed 50300/240000 batches for 2130.
# Processed 50400/240000 batches for 2130.
# Processed 50500/240000 batches for 2130.
# Processed 50600/240000 batches for 2130.
# Processed 50700/240000 batches for 2130.
# Processed 50800/240000 batches for 2130.
# Processed 50900/240000 batches for 2130.
# Processed 51000/240000 batches for 2130.
# Processed 51100/240000 batches for 2130.
# Processed 51200/240000 batches for 2130.
# Processed 51300/240000 batches for 2130.
# Processed 51400/240000 batches for 2130.
# Processed 51500/240000 batches for 2130.
# Processed 51600/240000 batches for 2130.
# Processed 51700/240000 batches for 2130.
# Processed 51800/240000 batches for 2130.
# Processed 51900/240000 batches for 2130.
# Processed 52000/240000 batches for 2130.
# Processed 52100/240000 batches for 2130.
# Processed 52200/240000 batches for 2130.
# Processed 52300/240000 batches for 2130.
# Processed 52400/240000 batches for 2130.
# Processed 52500/240000 batches for 2130.
# Processed 52600/240000 batches for 2130.
# Processed 52700/240000 batches for 2130.
# Processed 52800/240000 batches for 2130.
# Processed 52900/240000 batches for 2130.
# Processed 53000/240000 batches for 2130.
# Processed 53100/240000 batches for 2130.
# Processed 53200/240000 batches for 2130.
# Processed 53300/240000 batches for 2130.
# Processed 53400/240000 batches for 2130.
# Processed 53500/240000 batches for 2130.
# Processed 53600/240000 batches for 2130.
# Processed 53700/240000 batches for 2130.
# Processed 53800/240000 batches for 2130.
# Processed 53900/240000 batches for 2130.
# Processed 54000/240000 batches for 2130.
# Processed 54100/240000 batches for 2130.
# Processed 54200/240000 batches for 2130.
# Processed 54300/240000 batches for 2130.
# Processed 54400/240000 batches for 2130.
# Processed 54500/240000 batches for 2130.
# Processed 54600/240000 batches for 2130.
# Processed 54700/240000 batches for 2130.
# Processed 54800/240000 batches for 2130.
# Processed 54900/240000 batches for 2130.
# Processed 55000/240000 batches for 2130.
# Processed 55100/240000 batches for 2130.
# Processed 55200/240000 batches for 2130.
# Processed 55300/240000 batches for 2130.
# Processed 55400/240000 batches for 2130.
# Processed 55500/240000 batches for 2130.
# Processed 55600/240000 batches for 2130.
# Processed 55700/240000 batches for 2130.
# Processed 55800/240000 batches for 2130.
# Processed 55900/240000 batches for 2130.
# Processed 56000/240000 batches for 2130.
# Processed 56100/240000 batches for 2130.
# Processed 56200/240000 batches for 2130.
# Processed 56300/240000 batches for 2130.
# Processed 56400/240000 batches for 2130.
# Processed 56500/240000 batches for 2130.
# Processed 56600/240000 batches for 2130.
# Processed 56700/240000 batches for 2130.
# Processed 56800/240000 batches for 2130.
# Processed 56900/240000 batches for 2130.
# Processed 57000/240000 batches for 2130.
# Processed 57100/240000 batches for 2130.
# Processed 57200/240000 batches for 2130.
# Processed 57300/240000 batches for 2130.
# Processed 57400/240000 batches for 2130.
# Processed 57500/240000 batches for 2130.
# Processed 57600/240000 batches for 2130.
# Processed 57700/240000 batches for 2130.
# Processed 57800/240000 batches for 2130.
# Processed 57900/240000 batches for 2130.
# Processed 58000/240000 batches for 2130.
# Processed 58100/240000 batches for 2130.
# Processed 58200/240000 batches for 2130.
# Processed 58300/240000 batches for 2130.
# Processed 58400/240000 batches for 2130.
# Processed 58500/240000 batches for 2130.
# Processed 58600/240000 batches for 2130.
# Processed 58700/240000 batches for 2130.
# Processed 58800/240000 batches for 2130.
# Processed 58900/240000 batches for 2130.
# Processed 59000/240000 batches for 2130.
# Processed 59100/240000 batches for 2130.
# Processed 59200/240000 batches for 2130.
# Processed 59300/240000 batches for 2130.
# Processed 59400/240000 batches for 2130.
# Processed 59500/240000 batches for 2130.
# Processed 59600/240000 batches for 2130.
# Processed 59700/240000 batches for 2130.
# Processed 59800/240000 batches for 2130.
# Processed 59900/240000 batches for 2130.
# Processed 60000/240000 batches for 2130.
# Processed 60100/240000 batches for 2130.
# Processed 60200/240000 batches for 2130.
# Processed 60300/240000 batches for 2130.
# Processed 60400/240000 batches for 2130.
# Processed 60500/240000 batches for 2130.
# Processed 60600/240000 batches for 2130.
# Processed 60700/240000 batches for 2130.
# Processed 60800/240000 batches for 2130.
# Processed 60900/240000 batches for 2130.
# Processed 61000/240000 batches for 2130.
# Processed 61100/240000 batches for 2130.
# Processed 61200/240000 batches for 2130.
# Processed 61300/240000 batches for 2130.
# Processed 61400/240000 batches for 2130.
# Processed 61500/240000 batches for 2130.
# Processed 61600/240000 batches for 2130.
# Processed 61700/240000 batches for 2130.
# Processed 61800/240000 batches for 2130.
# Processed 61900/240000 batches for 2130.
# Processed 62000/240000 batches for 2130.
# Processed 62100/240000 batches for 2130.
# Processed 62200/240000 batches for 2130.
# Processed 62300/240000 batches for 2130.
# Processed 62400/240000 batches for 2130.
# Processed 62500/240000 batches for 2130.
# Processed 62600/240000 batches for 2130.
# Processed 62700/240000 batches for 2130.
# Processed 62800/240000 batches for 2130.
# Processed 62900/240000 batches for 2130.
# Processed 63000/240000 batches for 2130.
# Processed 63100/240000 batches for 2130.
# Processed 63200/240000 batches for 2130.
# Processed 63300/240000 batches for 2130.
# Processed 63400/240000 batches for 2130.
# Processed 63500/240000 batches for 2130.
# Processed 63600/240000 batches for 2130.
# Processed 63700/240000 batches for 2130.
# Processed 63800/240000 batches for 2130.
# Processed 63900/240000 batches for 2130.
# Processed 64000/240000 batches for 2130.
# Processed 64100/240000 batches for 2130.
# Processed 64200/240000 batches for 2130.
# Processed 64300/240000 batches for 2130.
# Processed 64400/240000 batches for 2130.
# Processed 64500/240000 batches for 2130.
# Processed 64600/240000 batches for 2130.
# Processed 64700/240000 batches for 2130.
# Processed 64800/240000 batches for 2130.
# Processed 64900/240000 batches for 2130.
# Processed 65000/240000 batches for 2130.
# Processed 65100/240000 batches for 2130.
# Processed 65200/240000 batches for 2130.
# Processed 65300/240000 batches for 2130.
# Processed 65400/240000 batches for 2130.
# Processed 65500/240000 batches for 2130.
# Processed 65600/240000 batches for 2130.
# Processed 65700/240000 batches for 2130.
# Processed 65800/240000 batches for 2130.
# Processed 65900/240000 batches for 2130.
# Processed 66000/240000 batches for 2130.
# Processed 66100/240000 batches for 2130.
# Processed 66200/240000 batches for 2130.
# Processed 66300/240000 batches for 2130.
# Processed 66400/240000 batches for 2130.
# Processed 66500/240000 batches for 2130.
# Processed 66600/240000 batches for 2130.
# Processed 66700/240000 batches for 2130.
# Processed 66800/240000 batches for 2130.
# Processed 66900/240000 batches for 2130.
# Processed 67000/240000 batches for 2130.
# Processed 67100/240000 batches for 2130.
# Processed 67200/240000 batches for 2130.
# Processed 67300/240000 batches for 2130.
# Processed 67400/240000 batches for 2130.
# Processed 67500/240000 batches for 2130.
# Processed 67600/240000 batches for 2130.
# Processed 67700/240000 batches for 2130.
# Processed 67800/240000 batches for 2130.
# Processed 67900/240000 batches for 2130.
# Processed 68000/240000 batches for 2130.
# Processed 68100/240000 batches for 2130.
# Processed 68200/240000 batches for 2130.
# Processed 68300/240000 batches for 2130.
# Processed 68400/240000 batches for 2130.
# Processed 68500/240000 batches for 2130.
# Processed 68600/240000 batches for 2130.
# Processed 68700/240000 batches for 2130.
# Processed 68800/240000 batches for 2130.
# Processed 68900/240000 batches for 2130.
# Processed 69000/240000 batches for 2130.
# Processed 69100/240000 batches for 2130.
# Processed 69200/240000 batches for 2130.
# Processed 69300/240000 batches for 2130.
# Processed 69400/240000 batches for 2130.
# Processed 69500/240000 batches for 2130.
# Processed 69600/240000 batches for 2130.
# Processed 69700/240000 batches for 2130.
# Processed 69800/240000 batches for 2130.
# Processed 69900/240000 batches for 2130.
# Processed 70000/240000 batches for 2130.
# Processed 70100/240000 batches for 2130.
# Processed 70200/240000 batches for 2130.
# Processed 70300/240000 batches for 2130.
# Processed 70400/240000 batches for 2130.
# Processed 70500/240000 batches for 2130.
# Processed 70600/240000 batches for 2130.
# Processed 70700/240000 batches for 2130.
# Processed 70800/240000 batches for 2130.
# Processed 70900/240000 batches for 2130.
# Processed 71000/240000 batches for 2130.
# Processed 71100/240000 batches for 2130.
# Processed 71200/240000 batches for 2130.
# Processed 71300/240000 batches for 2130.
# Processed 71400/240000 batches for 2130.
# Processed 71500/240000 batches for 2130.
# Processed 71600/240000 batches for 2130.
# Processed 71700/240000 batches for 2130.
# Processed 71800/240000 batches for 2130.
# Processed 71900/240000 batches for 2130.
# Processed 72000/240000 batches for 2130.
# Processed 72100/240000 batches for 2130.
# Processed 72200/240000 batches for 2130.
# Processed 72300/240000 batches for 2130.
# Processed 72400/240000 batches for 2130.
# Processed 72500/240000 batches for 2130.
# Processed 72600/240000 batches for 2130.
# Processed 72700/240000 batches for 2130.
# Processed 72800/240000 batches for 2130.
# Processed 72900/240000 batches for 2130.
# Processed 73000/240000 batches for 2130.
# Processed 73100/240000 batches for 2130.
# Processed 73200/240000 batches for 2130.
# Processed 73300/240000 batches for 2130.
# Processed 73400/240000 batches for 2130.
# Processed 73500/240000 batches for 2130.
# Processed 73600/240000 batches for 2130.
# Processed 73700/240000 batches for 2130.
# Processed 73800/240000 batches for 2130.
# Processed 73900/240000 batches for 2130.
# Processed 74000/240000 batches for 2130.
# Processed 74100/240000 batches for 2130.
# Processed 74200/240000 batches for 2130.
# Processed 74300/240000 batches for 2130.
# Processed 74400/240000 batches for 2130.
# Processed 74500/240000 batches for 2130.
# Processed 74600/240000 batches for 2130.
# Processed 74700/240000 batches for 2130.
# Processed 74800/240000 batches for 2130.
# Processed 74900/240000 batches for 2130.
# Processed 75000/240000 batches for 2130.
# Processed 75100/240000 batches for 2130.
# Processed 75200/240000 batches for 2130.
# Processed 75300/240000 batches for 2130.
# Processed 75400/240000 batches for 2130.
# Processed 75500/240000 batches for 2130.
# Processed 75600/240000 batches for 2130.
# Processed 75700/240000 batches for 2130.
# Processed 75800/240000 batches for 2130.
# Processed 75900/240000 batches for 2130.
# Processed 76000/240000 batches for 2130.
# Processed 76100/240000 batches for 2130.
# Processed 76200/240000 batches for 2130.
# Processed 76300/240000 batches for 2130.
# Processed 76400/240000 batches for 2130.
# Processed 76500/240000 batches for 2130.
# Processed 76600/240000 batches for 2130.
# Processed 76700/240000 batches for 2130.
# Processed 76800/240000 batches for 2130.
# Processed 76900/240000 batches for 2130.
# Processed 77000/240000 batches for 2130.
# Processed 77100/240000 batches for 2130.
# Processed 77200/240000 batches for 2130.
# Processed 77300/240000 batches for 2130.
# Processed 77400/240000 batches for 2130.
# Processed 77500/240000 batches for 2130.
# Processed 77600/240000 batches for 2130.
# Processed 77700/240000 batches for 2130.
# Processed 77800/240000 batches for 2130.
# Processed 77900/240000 batches for 2130.
# Processed 78000/240000 batches for 2130.
# Processed 78100/240000 batches for 2130.
# Processed 78200/240000 batches for 2130.
# Processed 78300/240000 batches for 2130.
# Processed 78400/240000 batches for 2130.
# Processed 78500/240000 batches for 2130.
# Processed 78600/240000 batches for 2130.
# Processed 78700/240000 batches for 2130.
# Processed 78800/240000 batches for 2130.
# Processed 78900/240000 batches for 2130.
# Processed 79000/240000 batches for 2130.
# Processed 79100/240000 batches for 2130.
# Processed 79200/240000 batches for 2130.
# Processed 79300/240000 batches for 2130.
# Processed 79400/240000 batches for 2130.
# Processed 79500/240000 batches for 2130.
# Processed 79600/240000 batches for 2130.
# Processed 79700/240000 batches for 2130.
# Processed 79800/240000 batches for 2130.
# Processed 79900/240000 batches for 2130.
# Processed 80000/240000 batches for 2130.
# Processed 80100/240000 batches for 2130.
# Processed 80200/240000 batches for 2130.
# Processed 80300/240000 batches for 2130.
# Processed 80400/240000 batches for 2130.
# Processed 80500/240000 batches for 2130.
# Processed 80600/240000 batches for 2130.
# Processed 80700/240000 batches for 2130.
# Processed 80800/240000 batches for 2130.
# Processed 80900/240000 batches for 2130.
# Processed 81000/240000 batches for 2130.
# Processed 81100/240000 batches for 2130.
# Processed 81200/240000 batches for 2130.
# Processed 81300/240000 batches for 2130.
# Processed 81400/240000 batches for 2130.
# Processed 81500/240000 batches for 2130.
# Processed 81600/240000 batches for 2130.
# Processed 81700/240000 batches for 2130.
# Processed 81800/240000 batches for 2130.
# Processed 81900/240000 batches for 2130.
# Processed 82000/240000 batches for 2130.
# Processed 82100/240000 batches for 2130.
# Processed 82200/240000 batches for 2130.
# Processed 82300/240000 batches for 2130.
# Processed 82400/240000 batches for 2130.
# Processed 82500/240000 batches for 2130.
# Processed 82600/240000 batches for 2130.
# Processed 82700/240000 batches for 2130.
# Processed 82800/240000 batches for 2130.
# Processed 82900/240000 batches for 2130.
# Processed 83000/240000 batches for 2130.
# Processed 83100/240000 batches for 2130.
# Processed 83200/240000 batches for 2130.
# Processed 83300/240000 batches for 2130.
# Processed 83400/240000 batches for 2130.
# Processed 83500/240000 batches for 2130.
# Processed 83600/240000 batches for 2130.
# Processed 83700/240000 batches for 2130.
# Processed 83800/240000 batches for 2130.
# Processed 83900/240000 batches for 2130.
# Processed 84000/240000 batches for 2130.
# Processed 84100/240000 batches for 2130.
# Processed 84200/240000 batches for 2130.
# Processed 84300/240000 batches for 2130.
# Processed 84400/240000 batches for 2130.
# Processed 84500/240000 batches for 2130.
# Processed 84600/240000 batches for 2130.
# Processed 84700/240000 batches for 2130.
# Processed 84800/240000 batches for 2130.
# Processed 84900/240000 batches for 2130.
# Processed 85000/240000 batches for 2130.
# Processed 85100/240000 batches for 2130.
# Processed 85200/240000 batches for 2130.
# Processed 85300/240000 batches for 2130.
# Processed 85400/240000 batches for 2130.
# Processed 85500/240000 batches for 2130.
# Processed 85600/240000 batches for 2130.
# Processed 85700/240000 batches for 2130.
# Processed 85800/240000 batches for 2130.
# Processed 85900/240000 batches for 2130.
# Processed 86000/240000 batches for 2130.
# Processed 86100/240000 batches for 2130.
# Processed 86200/240000 batches for 2130.
# Processed 86300/240000 batches for 2130.
# Processed 86400/240000 batches for 2130.
# Processed 86500/240000 batches for 2130.
# Processed 86600/240000 batches for 2130.
# Processed 86700/240000 batches for 2130.
# Processed 86800/240000 batches for 2130.
# Processed 86900/240000 batches for 2130.
# Processed 87000/240000 batches for 2130.
# Processed 87100/240000 batches for 2130.
# Processed 87200/240000 batches for 2130.
# Processed 87300/240000 batches for 2130.
# Processed 87400/240000 batches for 2130.
# Processed 87500/240000 batches for 2130.
# Processed 87600/240000 batches for 2130.
# Processed 87700/240000 batches for 2130.
# Processed 87800/240000 batches for 2130.
# Processed 87900/240000 batches for 2130.
# Processed 88000/240000 batches for 2130.
# Processed 88100/240000 batches for 2130.
# Processed 88200/240000 batches for 2130.
# Processed 88300/240000 batches for 2130.
# Processed 88400/240000 batches for 2130.
# Processed 88500/240000 batches for 2130.
# Processed 88600/240000 batches for 2130.
# Processed 88700/240000 batches for 2130.
# Processed 88800/240000 batches for 2130.
# Processed 88900/240000 batches for 2130.
# Processed 89000/240000 batches for 2130.
# Processed 89100/240000 batches for 2130.
# Processed 89200/240000 batches for 2130.
# Processed 89300/240000 batches for 2130.
# Processed 89400/240000 batches for 2130.
# Processed 89500/240000 batches for 2130.
# Processed 89600/240000 batches for 2130.
# Processed 89700/240000 batches for 2130.
# Processed 89800/240000 batches for 2130.
# Processed 89900/240000 batches for 2130.
# Processed 90000/240000 batches for 2130.
# Processed 90100/240000 batches for 2130.
# Processed 90200/240000 batches for 2130.
# Processed 90300/240000 batches for 2130.
# Processed 90400/240000 batches for 2130.
# Processed 90500/240000 batches for 2130.
# Processed 90600/240000 batches for 2130.
# Processed 90700/240000 batches for 2130.
# Processed 90800/240000 batches for 2130.
# Processed 90900/240000 batches for 2130.
# Processed 91000/240000 batches for 2130.
# Processed 91100/240000 batches for 2130.
# Processed 91200/240000 batches for 2130.
# Processed 91300/240000 batches for 2130.
# Processed 91400/240000 batches for 2130.
# Processed 91500/240000 batches for 2130.
# Processed 91600/240000 batches for 2130.
# Processed 91700/240000 batches for 2130.
# Processed 91800/240000 batches for 2130.
# Processed 91900/240000 batches for 2130.
# Processed 92000/240000 batches for 2130.
# Processed 92100/240000 batches for 2130.
# Processed 92200/240000 batches for 2130.
# Processed 92300/240000 batches for 2130.
# Processed 92400/240000 batches for 2130.
# Processed 92500/240000 batches for 2130.
# Processed 92600/240000 batches for 2130.
# Processed 92700/240000 batches for 2130.
# Processed 92800/240000 batches for 2130.
# Processed 92900/240000 batches for 2130.
# Processed 93000/240000 batches for 2130.
# Processed 93100/240000 batches for 2130.
# Processed 93200/240000 batches for 2130.
# Processed 93300/240000 batches for 2130.
# Processed 93400/240000 batches for 2130.
# Processed 93500/240000 batches for 2130.
# Processed 93600/240000 batches for 2130.
# Processed 93700/240000 batches for 2130.
# Processed 93800/240000 batches for 2130.
# Processed 93900/240000 batches for 2130.
# Processed 94000/240000 batches for 2130.
# Processed 94100/240000 batches for 2130.
# Processed 94200/240000 batches for 2130.
# Processed 94300/240000 batches for 2130.
# Processed 94400/240000 batches for 2130.
# Processed 94500/240000 batches for 2130.
# Processed 94600/240000 batches for 2130.
# Processed 94700/240000 batches for 2130.
# Processed 94800/240000 batches for 2130.
# Processed 94900/240000 batches for 2130.
# Processed 95000/240000 batches for 2130.
# Processed 95100/240000 batches for 2130.
# Processed 95200/240000 batches for 2130.
# Processed 95300/240000 batches for 2130.
# Processed 95400/240000 batches for 2130.
# Processed 95500/240000 batches for 2130.
# Processed 95600/240000 batches for 2130.
# Processed 95700/240000 batches for 2130.
# Processed 95800/240000 batches for 2130.
# Processed 95900/240000 batches for 2130.
# Processed 96000/240000 batches for 2130.
# Processed 96100/240000 batches for 2130.
# Processed 96200/240000 batches for 2130.
# Processed 96300/240000 batches for 2130.
# Processed 96400/240000 batches for 2130.
# Processed 96500/240000 batches for 2130.
# Processed 96600/240000 batches for 2130.
# Processed 96700/240000 batches for 2130.
# Processed 96800/240000 batches for 2130.
# Processed 96900/240000 batches for 2130.
# Processed 97000/240000 batches for 2130.
# Processed 97100/240000 batches for 2130.
# Processed 97200/240000 batches for 2130.
# Processed 97300/240000 batches for 2130.
# Processed 97400/240000 batches for 2130.
# Processed 97500/240000 batches for 2130.
# Processed 97600/240000 batches for 2130.
# Processed 97700/240000 batches for 2130.
# Processed 97800/240000 batches for 2130.
# Processed 97900/240000 batches for 2130.
# Processed 98000/240000 batches for 2130.
# Processed 98100/240000 batches for 2130.
# Processed 98200/240000 batches for 2130.
# Processed 98300/240000 batches for 2130.
# Processed 98400/240000 batches for 2130.
# Processed 98500/240000 batches for 2130.
# Processed 98600/240000 batches for 2130.
# Processed 98700/240000 batches for 2130.
# Processed 98800/240000 batches for 2130.
# Processed 98900/240000 batches for 2130.
# Processed 99000/240000 batches for 2130.
# Processed 99100/240000 batches for 2130.
# Processed 99200/240000 batches for 2130.
# Processed 99300/240000 batches for 2130.
# Processed 99400/240000 batches for 2130.
# Processed 99500/240000 batches for 2130.
# Processed 99600/240000 batches for 2130.
# Processed 99700/240000 batches for 2130.
# Processed 99800/240000 batches for 2130.
# Processed 99900/240000 batches for 2130.
# Processed 100000/240000 batches for 2130.
# Processed 100100/240000 batches for 2130.
# Processed 100200/240000 batches for 2130.
# Processed 100300/240000 batches for 2130.
# Processed 100400/240000 batches for 2130.
# Processed 100500/240000 batches for 2130.
# Processed 100600/240000 batches for 2130.
# Processed 100700/240000 batches for 2130.
# Processed 100800/240000 batches for 2130.
# Processed 100900/240000 batches for 2130.
# Processed 101000/240000 batches for 2130.
# Processed 101100/240000 batches for 2130.
# Processed 101200/240000 batches for 2130.
# Processed 101300/240000 batches for 2130.
# Processed 101400/240000 batches for 2130.
# Processed 101500/240000 batches for 2130.
# Processed 101600/240000 batches for 2130.
# Processed 101700/240000 batches for 2130.
# Processed 101800/240000 batches for 2130.
# Processed 101900/240000 batches for 2130.
# Processed 102000/240000 batches for 2130.
# Processed 102100/240000 batches for 2130.
# Processed 102200/240000 batches for 2130.
# Processed 102300/240000 batches for 2130.
# Processed 102400/240000 batches for 2130.
# Processed 102500/240000 batches for 2130.
# Processed 102600/240000 batches for 2130.
# Processed 102700/240000 batches for 2130.
# Processed 102800/240000 batches for 2130.
# Processed 102900/240000 batches for 2130.
# Processed 103000/240000 batches for 2130.
# Processed 103100/240000 batches for 2130.
# Processed 103200/240000 batches for 2130.
# Processed 103300/240000 batches for 2130.
# Processed 103400/240000 batches for 2130.
# Processed 103500/240000 batches for 2130.
# Processed 103600/240000 batches for 2130.
# Processed 103700/240000 batches for 2130.
# Processed 103800/240000 batches for 2130.
# Processed 103900/240000 batches for 2130.
# Processed 104000/240000 batches for 2130.
# Processed 104100/240000 batches for 2130.
# Processed 104200/240000 batches for 2130.
# Processed 104300/240000 batches for 2130.
# Processed 104400/240000 batches for 2130.
# Processed 104500/240000 batches for 2130.
# Processed 104600/240000 batches for 2130.
# Processed 104700/240000 batches for 2130.
# Processed 104800/240000 batches for 2130.
# Processed 104900/240000 batches for 2130.
# Processed 105000/240000 batches for 2130.
# Processed 105100/240000 batches for 2130.
# Processed 105200/240000 batches for 2130.
# Processed 105300/240000 batches for 2130.
# Processed 105400/240000 batches for 2130.
# Processed 105500/240000 batches for 2130.
# Processed 105600/240000 batches for 2130.
# Processed 105700/240000 batches for 2130.
# Processed 105800/240000 batches for 2130.
# Processed 105900/240000 batches for 2130.
# Processed 106000/240000 batches for 2130.
# Processed 106100/240000 batches for 2130.
# Processed 106200/240000 batches for 2130.
# Processed 106300/240000 batches for 2130.
# Processed 106400/240000 batches for 2130.
# Processed 106500/240000 batches for 2130.
# Processed 106600/240000 batches for 2130.
# Processed 106700/240000 batches for 2130.
# Processed 106800/240000 batches for 2130.
# Processed 106900/240000 batches for 2130.
# Processed 107000/240000 batches for 2130.
# Processed 107100/240000 batches for 2130.
# Processed 107200/240000 batches for 2130.
# Processed 107300/240000 batches for 2130.
# Processed 107400/240000 batches for 2130.
# Processed 107500/240000 batches for 2130.
# Processed 107600/240000 batches for 2130.
# Processed 107700/240000 batches for 2130.
# Processed 107800/240000 batches for 2130.
# Processed 107900/240000 batches for 2130.
# Processed 108000/240000 batches for 2130.
# Processed 108100/240000 batches for 2130.
# Processed 108200/240000 batches for 2130.
# Processed 108300/240000 batches for 2130.
# Processed 108400/240000 batches for 2130.
# Processed 108500/240000 batches for 2130.
# Processed 108600/240000 batches for 2130.
# Processed 108700/240000 batches for 2130.
# Processed 108800/240000 batches for 2130.
# Processed 108900/240000 batches for 2130.
# Processed 109000/240000 batches for 2130.
# Processed 109100/240000 batches for 2130.
# Processed 109200/240000 batches for 2130.
# Processed 109300/240000 batches for 2130.
# Processed 109400/240000 batches for 2130.
# Processed 109500/240000 batches for 2130.
# Processed 109600/240000 batches for 2130.
# Processed 109700/240000 batches for 2130.
# Processed 109800/240000 batches for 2130.
# Processed 109900/240000 batches for 2130.
# Processed 110000/240000 batches for 2130.
# Processed 110100/240000 batches for 2130.
# Processed 110200/240000 batches for 2130.
# Processed 110300/240000 batches for 2130.
# Processed 110400/240000 batches for 2130.
# Processed 110500/240000 batches for 2130.
# Processed 110600/240000 batches for 2130.
# Processed 110700/240000 batches for 2130.
# Processed 110800/240000 batches for 2130.
# Processed 110900/240000 batches for 2130.
# Processed 111000/240000 batches for 2130.
# Processed 111100/240000 batches for 2130.
# Processed 111200/240000 batches for 2130.
# Processed 111300/240000 batches for 2130.
# Processed 111400/240000 batches for 2130.
# Processed 111500/240000 batches for 2130.
# Processed 111600/240000 batches for 2130.
# Processed 111700/240000 batches for 2130.
# Processed 111800/240000 batches for 2130.
# Processed 111900/240000 batches for 2130.
# Processed 112000/240000 batches for 2130.
# Processed 112100/240000 batches for 2130.
# Processed 112200/240000 batches for 2130.
# Processed 112300/240000 batches for 2130.
# Processed 112400/240000 batches for 2130.
# Processed 112500/240000 batches for 2130.
# Processed 112600/240000 batches for 2130.
# Processed 112700/240000 batches for 2130.
# Processed 112800/240000 batches for 2130.
# Processed 112900/240000 batches for 2130.
# Processed 113000/240000 batches for 2130.
# Processed 113100/240000 batches for 2130.
# Processed 113200/240000 batches for 2130.
# Processed 113300/240000 batches for 2130.
# Processed 113400/240000 batches for 2130.
# Processed 113500/240000 batches for 2130.
# Processed 113600/240000 batches for 2130.
# Processed 113700/240000 batches for 2130.
# Processed 113800/240000 batches for 2130.
# Processed 113900/240000 batches for 2130.
# Processed 114000/240000 batches for 2130.
# Processed 114100/240000 batches for 2130.
# Processed 114200/240000 batches for 2130.
# Processed 114300/240000 batches for 2130.
# Processed 114400/240000 batches for 2130.
# Processed 114500/240000 batches for 2130.
# Processed 114600/240000 batches for 2130.
# Processed 114700/240000 batches for 2130.
# Processed 114800/240000 batches for 2130.
# Processed 114900/240000 batches for 2130.
# Processed 115000/240000 batches for 2130.
# Processed 115100/240000 batches for 2130.
# Processed 115200/240000 batches for 2130.
# Processed 115300/240000 batches for 2130.
# Processed 115400/240000 batches for 2130.
# Processed 115500/240000 batches for 2130.
# Processed 115600/240000 batches for 2130.
# Processed 115700/240000 batches for 2130.
# Processed 115800/240000 batches for 2130.
# Processed 115900/240000 batches for 2130.
# Processed 116000/240000 batches for 2130.
# Processed 116100/240000 batches for 2130.
# Processed 116200/240000 batches for 2130.
# Processed 116300/240000 batches for 2130.
# Processed 116400/240000 batches for 2130.
# Processed 116500/240000 batches for 2130.
# Processed 116600/240000 batches for 2130.
# Processed 116700/240000 batches for 2130.
# Processed 116800/240000 batches for 2130.
# Processed 116900/240000 batches for 2130.
# ...
# Processed 204700/240000 batches for 2013.
# Processed 204800/240000 batches for 2013.
# Processed 204900/240000 batches for 2013.
# Processed 205000/240000 batches for 2013.
# Processed 205100/240000 batches for 2013.
# Processed 205200/240000 batches for 2013.
# Processed 205300/240000 batches for 2013.
# Processed 205400/240000 batches for 2013.
# Processed 205500/240000 batches for 2013.
# Processed 205600/240000 batches for 2013.
# Processed 205700/240000 batches for 2013.
# Processed 205800/240000 batches for 2013.
# Processed 205900/240000 batches for 2013.
# Processed 206000/240000 batches for 2013.
# Processed 206100/240000 batches for 2013.
# Processed 206200/240000 batches for 2013.
# Processed 206300/240000 batches for 2013.
# Processed 206400/240000 batches for 2013.
# Processed 206500/240000 batches for 2013.
# Processed 206600/240000 batches for 2013.
# Processed 206700/240000 batches for 2013.
# Processed 206800/240000 batches for 2013.
# Processed 206900/240000 batches for 2013.
# Processed 207000/240000 batches for 2013.
# Processed 207100/240000 batches for 2013.
# Processed 207200/240000 batches for 2013.
# Processed 207300/240000 batches for 2013.
# Processed 207400/240000 batches for 2013.
# Processed 207500/240000 batches for 2013.
# Processed 207600/240000 batches for 2013.
# Processed 207700/240000 batches for 2013.
# Processed 207800/240000 batches for 2013.
# Processed 207900/240000 batches for 2013.
# Processed 208000/240000 batches for 2013.
# Processed 208100/240000 batches for 2013.
# Processed 208200/240000 batches for 2013.
# Processed 208300/240000 batches for 2013.
# Processed 208400/240000 batches for 2013.
# Processed 208500/240000 batches for 2013.
# Processed 208600/240000 batches for 2013.
# Processed 208700/240000 batches for 2013.
# Processed 208800/240000 batches for 2013.
# Processed 208900/240000 batches for 2013.
# Processed 209000/240000 batches for 2013.
# Processed 209100/240000 batches for 2013.
# Processed 209200/240000 batches for 2013.
# Processed 209300/240000 batches for 2013.
# Processed 209400/240000 batches for 2013.
# Processed 209500/240000 batches for 2013.
# Processed 209600/240000 batches for 2013.
# Processed 209700/240000 batches for 2013.
# Processed 209800/240000 batches for 2013.
# Processed 209900/240000 batches for 2013.
# Processed 210000/240000 batches for 2013.
# Processed 210100/240000 batches for 2013.
# Processed 210200/240000 batches for 2013.
# Processed 210300/240000 batches for 2013.
# Processed 210400/240000 batches for 2013.
# Processed 210500/240000 batches for 2013.
# Processed 210600/240000 batches for 2013.
# Processed 210700/240000 batches for 2013.
# Processed 210800/240000 batches for 2013.
# Processed 210900/240000 batches for 2013.
# Processed 211000/240000 batches for 2013.
# Processed 211100/240000 batches for 2013.
# Processed 211200/240000 batches for 2013.
# Processed 211300/240000 batches for 2013.
# Processed 211400/240000 batches for 2013.
# Processed 211500/240000 batches for 2013.
# Processed 211600/240000 batches for 2013.
# Processed 211700/240000 batches for 2013.
# Processed 211800/240000 batches for 2013.
# Processed 211900/240000 batches for 2013.
# Processed 212000/240000 batches for 2013.
# Processed 212100/240000 batches for 2013.
# Processed 212200/240000 batches for 2013.
# Processed 212300/240000 batches for 2013.
# Processed 212400/240000 batches for 2013.
# Processed 212500/240000 batches for 2013.
# Processed 212600/240000 batches for 2013.
# Processed 212700/240000 batches for 2013.
# Processed 212800/240000 batches for 2013.
# Processed 212900/240000 batches for 2013.
# Processed 213000/240000 batches for 2013.
# Processed 213100/240000 batches for 2013.
# Processed 213200/240000 batches for 2013.
# Processed 213300/240000 batches for 2013.
# Processed 213400/240000 batches for 2013.
# Processed 213500/240000 batches for 2013.
# Processed 213600/240000 batches for 2013.
# Processed 213700/240000 batches for 2013.
# Processed 213800/240000 batches for 2013.
# Processed 213900/240000 batches for 2013.
# Processed 214000/240000 batches for 2013.
# Processed 214100/240000 batches for 2013.
# Processed 214200/240000 batches for 2013.
# Processed 214300/240000 batches for 2013.
# Processed 214400/240000 batches for 2013.
# Processed 214500/240000 batches for 2013.
# Processed 214600/240000 batches for 2013.
# Processed 214700/240000 batches for 2013.
# Processed 214800/240000 batches for 2013.
# Processed 214900/240000 batches for 2013.
# Processed 215000/240000 batches for 2013.
# Processed 215100/240000 batches for 2013.
# Processed 215200/240000 batches for 2013.
# Processed 215300/240000 batches for 2013.
# Processed 215400/240000 batches for 2013.
# Processed 215500/240000 batches for 2013.
# Processed 215600/240000 batches for 2013.
# Processed 215700/240000 batches for 2013.
# Processed 215800/240000 batches for 2013.
# Processed 215900/240000 batches for 2013.
# Processed 216000/240000 batches for 2013.
# Processed 216100/240000 batches for 2013.
# Processed 216200/240000 batches for 2013.
# Processed 216300/240000 batches for 2013.
# Processed 216400/240000 batches for 2013.
# Processed 216500/240000 batches for 2013.
# Processed 216600/240000 batches for 2013.
# Processed 216700/240000 batches for 2013.
# Processed 216800/240000 batches for 2013.
# Processed 216900/240000 batches for 2013.
# Processed 217000/240000 batches for 2013.
# Processed 217100/240000 batches for 2013.
# Processed 217200/240000 batches for 2013.
# Processed 217300/240000 batches for 2013.
# Processed 217400/240000 batches for 2013.
# Processed 217500/240000 batches for 2013.
# Processed 217600/240000 batches for 2013.
# Processed 217700/240000 batches for 2013.
# Processed 217800/240000 batches for 2013.
# Processed 217900/240000 batches for 2013.
# Processed 218000/240000 batches for 2013.
# Processed 218100/240000 batches for 2013.
# Processed 218200/240000 batches for 2013.
# Processed 218300/240000 batches for 2013.
# Processed 218400/240000 batches for 2013.
# Processed 218500/240000 batches for 2013.
# Processed 218600/240000 batches for 2013.
# Processed 218700/240000 batches for 2013.
# Processed 218800/240000 batches for 2013.
# Processed 218900/240000 batches for 2013.
# Processed 219000/240000 batches for 2013.
# Processed 219100/240000 batches for 2013.
# Processed 219200/240000 batches for 2013.
# Processed 219300/240000 batches for 2013.
# Processed 219400/240000 batches for 2013.
# Processed 219500/240000 batches for 2013.
# Processed 219600/240000 batches for 2013.
# Processed 219700/240000 batches for 2013.
# Processed 219800/240000 batches for 2013.
# Processed 219900/240000 batches for 2013.
# Processed 220000/240000 batches for 2013.
# Processed 220100/240000 batches for 2013.
# Processed 220200/240000 batches for 2013.
# Processed 220300/240000 batches for 2013.
# Processed 220400/240000 batches for 2013.
# Processed 220500/240000 batches for 2013.
# Processed 220600/240000 batches for 2013.
# Processed 220700/240000 batches for 2013.
# Processed 220800/240000 batches for 2013.
# Processed 220900/240000 batches for 2013.
# Processed 221000/240000 batches for 2013.
# Processed 221100/240000 batches for 2013.
# Processed 221200/240000 batches for 2013.
# Processed 221300/240000 batches for 2013.
# Processed 221400/240000 batches for 2013.
# Processed 221500/240000 batches for 2013.
# Processed 221600/240000 batches for 2013.
# Processed 221700/240000 batches for 2013.
# Processed 221800/240000 batches for 2013.
# Processed 221900/240000 batches for 2013.
# Processed 222000/240000 batches for 2013.
# Processed 222100/240000 batches for 2013.
# Processed 222200/240000 batches for 2013.
# Processed 222300/240000 batches for 2013.
# Processed 222400/240000 batches for 2013.
# Processed 222500/240000 batches for 2013.
# Processed 222600/240000 batches for 2013.
# Processed 222700/240000 batches for 2013.
# Processed 222800/240000 batches for 2013.
# Processed 222900/240000 batches for 2013.
# Processed 223000/240000 batches for 2013.
# Processed 223100/240000 batches for 2013.
# Processed 223200/240000 batches for 2013.
# Processed 223300/240000 batches for 2013.
# Processed 223400/240000 batches for 2013.
# Processed 223500/240000 batches for 2013.
# Processed 223600/240000 batches for 2013.
# Processed 223700/240000 batches for 2013.
# Processed 223800/240000 batches for 2013.
# Processed 223900/240000 batches for 2013.
# Processed 224000/240000 batches for 2013.
# Processed 224100/240000 batches for 2013.
# Processed 224200/240000 batches for 2013.
# Processed 224300/240000 batches for 2013.
# Processed 224400/240000 batches for 2013.
# Processed 224500/240000 batches for 2013.
# Processed 224600/240000 batches for 2013.
# Processed 224700/240000 batches for 2013.
# Processed 224800/240000 batches for 2013.
# Processed 224900/240000 batches for 2013.
# Processed 225000/240000 batches for 2013.
# Processed 225100/240000 batches for 2013.
# Processed 225200/240000 batches for 2013.
# Processed 225300/240000 batches for 2013.
# Processed 225400/240000 batches for 2013.
# Processed 225500/240000 batches for 2013.
# Processed 225600/240000 batches for 2013.
# Processed 225700/240000 batches for 2013.
# Processed 225800/240000 batches for 2013.
# Processed 225900/240000 batches for 2013.
# Processed 226000/240000 batches for 2013.
# Processed 226100/240000 batches for 2013.
# Processed 226200/240000 batches for 2013.
# Processed 226300/240000 batches for 2013.
# Processed 226400/240000 batches for 2013.
# Processed 226500/240000 batches for 2013.
# Processed 226600/240000 batches for 2013.
# Processed 226700/240000 batches for 2013.
# Processed 226800/240000 batches for 2013.
# Processed 226900/240000 batches for 2013.
# Processed 227000/240000 batches for 2013.
# Processed 227100/240000 batches for 2013.
# Processed 227200/240000 batches for 2013.
# Processed 227300/240000 batches for 2013.
# Processed 227400/240000 batches for 2013.
# Processed 227500/240000 batches for 2013.
# Processed 227600/240000 batches for 2013.
# Processed 227700/240000 batches for 2013.
# Processed 227800/240000 batches for 2013.
# Processed 227900/240000 batches for 2013.
# Processed 228000/240000 batches for 2013.
# Processed 228100/240000 batches for 2013.
# Processed 228200/240000 batches for 2013.
# Processed 228300/240000 batches for 2013.
# Processed 228400/240000 batches for 2013.
# Processed 228500/240000 batches for 2013.
# Processed 228600/240000 batches for 2013.
# Processed 228700/240000 batches for 2013.
# Processed 228800/240000 batches for 2013.
# Processed 228900/240000 batches for 2013.
# Processed 229000/240000 batches for 2013.
# Processed 229100/240000 batches for 2013.
# Processed 229200/240000 batches for 2013.
# Processed 229300/240000 batches for 2013.
# Processed 229400/240000 batches for 2013.
# Processed 229500/240000 batches for 2013.
# Processed 229600/240000 batches for 2013.
# Processed 229700/240000 batches for 2013.
# Processed 229800/240000 batches for 2013.
# Processed 229900/240000 batches for 2013.
# Processed 230000/240000 batches for 2013.
# Processed 230100/240000 batches for 2013.
# Processed 230200/240000 batches for 2013.
# Processed 230300/240000 batches for 2013.
# Processed 230400/240000 batches for 2013.
# Processed 230500/240000 batches for 2013.
# Processed 230600/240000 batches for 2013.
# Processed 230700/240000 batches for 2013.
# Processed 230800/240000 batches for 2013.
# Processed 230900/240000 batches for 2013.
# Processed 231000/240000 batches for 2013.
# Processed 231100/240000 batches for 2013.
# Processed 231200/240000 batches for 2013.
# Processed 231300/240000 batches for 2013.
# Processed 231400/240000 batches for 2013.
# Processed 231500/240000 batches for 2013.
# Processed 231600/240000 batches for 2013.
# Processed 231700/240000 batches for 2013.
# Processed 231800/240000 batches for 2013.
# Processed 231900/240000 batches for 2013.
# Processed 232000/240000 batches for 2013.
# Processed 232100/240000 batches for 2013.
# Processed 232200/240000 batches for 2013.
# Processed 232300/240000 batches for 2013.
# Processed 232400/240000 batches for 2013.
# Processed 232500/240000 batches for 2013.
# Processed 232600/240000 batches for 2013.
# Processed 232700/240000 batches for 2013.
# Processed 232800/240000 batches for 2013.
# Processed 232900/240000 batches for 2013.
# Processed 233000/240000 batches for 2013.
# Processed 233100/240000 batches for 2013.
# Processed 233200/240000 batches for 2013.
# Processed 233300/240000 batches for 2013.
# Processed 233400/240000 batches for 2013.
# Processed 233500/240000 batches for 2013.
# Processed 233600/240000 batches for 2013.
# Processed 233700/240000 batches for 2013.
# Processed 233800/240000 batches for 2013.
# Processed 233900/240000 batches for 2013.
# Processed 234000/240000 batches for 2013.
# Processed 234100/240000 batches for 2013.
# Processed 234200/240000 batches for 2013.
# Processed 234300/240000 batches for 2013.
# Processed 234400/240000 batches for 2013.
# Processed 234500/240000 batches for 2013.
# Processed 234600/240000 batches for 2013.
# Processed 234700/240000 batches for 2013.
# Processed 234800/240000 batches for 2013.
# Processed 234900/240000 batches for 2013.
# Processed 235000/240000 batches for 2013.
# Processed 235100/240000 batches for 2013.
# Processed 235200/240000 batches for 2013.
# Processed 235300/240000 batches for 2013.
# Processed 235400/240000 batches for 2013.
# Processed 235500/240000 batches for 2013.
# Processed 235600/240000 batches for 2013.
# Processed 235700/240000 batches for 2013.
# Processed 235800/240000 batches for 2013.
# Processed 235900/240000 batches for 2013.
# Processed 236000/240000 batches for 2013.
# Processed 236100/240000 batches for 2013.
# Processed 236200/240000 batches for 2013.
# Processed 236300/240000 batches for 2013.
# Processed 236400/240000 batches for 2013.
# Processed 236500/240000 batches for 2013.
# Processed 236600/240000 batches for 2013.
# Processed 236700/240000 batches for 2013.
# Processed 236800/240000 batches for 2013.
# Processed 236900/240000 batches for 2013.
# Processed 237000/240000 batches for 2013.
# Processed 237100/240000 batches for 2013.
# Processed 237200/240000 batches for 2013.
# Processed 237300/240000 batches for 2013.
# Processed 237400/240000 batches for 2013.
# Processed 237500/240000 batches for 2013.
# Processed 237600/240000 batches for 2013.
# Processed 237700/240000 batches for 2013.
# Processed 237800/240000 batches for 2013.
# Processed 237900/240000 batches for 2013.
# Processed 238000/240000 batches for 2013.
# Processed 238100/240000 batches for 2013.
# Processed 238200/240000 batches for 2013.
# Processed 238300/240000 batches for 2013.
# Processed 238400/240000 batches for 2013.
# Processed 238500/240000 batches for 2013.
# Processed 238600/240000 batches for 2013.
# Processed 238700/240000 batches for 2013.
# Processed 238800/240000 batches for 2013.
# Processed 238900/240000 batches for 2013.
# Processed 239000/240000 batches for 2013.
# Processed 239100/240000 batches for 2013.
# Processed 239200/240000 batches for 2013.
# Processed 239300/240000 batches for 2013.
# Processed 239400/240000 batches for 2013.
# Processed 239500/240000 batches for 2013.
# Processed 239600/240000 batches for 2013.
# Processed 239700/240000 batches for 2013.
# Processed 239800/240000 batches for 2013.
# Processed 239900/240000 batches for 2013.
# Processed 240000/240000 batches for 2013.
# Created/Ensured directory: _OA_results_eMnist_Digits_train_with_val/2013/Entropy
# Saved Total_Avg_2013_Entropy_S1.csv to _OA_results_eMnist_Digits_train_with_val/2013/Entropy
# Saved Total_Avg_2013_Entropy_S2.csv to _OA_results_eMnist_Digits_train_with_val/2013/Entropy
# Saved Total_Max_2013_Entropy_S1.csv to _OA_results_eMnist_Digits_train_with_val/2013/Entropy
# Saved Total_Max_2013_Entropy_S2.csv to _OA_results_eMnist_Digits_train_with_val/2013/Entropy
# Saved S1_rho_0_2013_Entropy_S1_0.csv to _OA_results_eMnist_Digits_train_with_val/2013/Entropy
# Saved S1_rho_1_2013_Entropy_S1_1.csv to _OA_results_eMnist_Digits_train_with_val/2013/Entropy
# Saved S2_rho_0_2013_Entropy_S2_0.csv to _OA_results_eMnist_Digits_train_with_val/2013/Entropy
# Saved S2_rho_1_2013_Entropy_S2_1.csv to _OA_results_eMnist_Digits_train_with_val/2013/Entropy
# Saved Total_Avg_2013_Entropy_S1_S2.csv to _OA_results_eMnist_Digits_train_with_val/2013/Entropy
# Saved Total_Max_2013_Entropy_S1_S2.csv to _OA_results_eMnist_Digits_train_with_val/2013/Entropy
# Finished parallel computation for data for config 2013 in 226.11 seconds.

# %% [markdown]
# We will focus only in the best 3 configs.

# %%
def open_load_entropy(symmetry, system, dataset_name="eMnist_Digits"):
    
    system = str(system)
    file_path = f"/workspaces/QML-QPF/Entanglement_Filtering/eMnist_Digits/_OA_results_{dataset_name}_train_with_val/{symmetry}/Entropy/S{system}_rho_0_{symmetry}_Entropy_S{system}_0.csv"
    S_rho0 = np.loadtxt(file_path, delimiter=',')
    return S_rho0

# %% [markdown]
# ## Entanglement pooling and saving

# %%
import joblib
import gc

def Entanglement_pooling(input, sample_size, threshold, S1_rho0, S2_rho0,Entanglement_pooled_file_name):
    """
    Function that will filter the output of the quantum circuit based on a threshold e.g. the mean of the entier dataset
    
    """
    # sample_size = reshaped_filtered_input.shape[0]  # number of images
    Entanglement_pooled_sample = list()
    # threshold = 0.106 # The mean of the entire dataset--will update it accordingly
    for i in range(sample_size):
        Entanglement_pooled_img = list()
        for j in range(S1_rho0.shape[-1]):
            #
            tmp_list = list()
            # Checking for S1
            if S1_rho0[i,j] < threshold: # keeping both qubits
                tmp_list.extend(input[i,j,:2]) 
            else: # Keeping only target qubit
                tmp_list.append(input[i,j,1])
                
            # Checking for S2
            if S2_rho0[i,j] < threshold: # keeping both qubits
                tmp_list.extend(input[i,j,2:]) 
            else: # Keeping only target qubit
                tmp_list.append(input[i,j,-1])
            # appending the pooled filtered input to the image
            Entanglement_pooled_img.append(tmp_list)
        # appending the pooled filtered image to the sample
        Entanglement_pooled_sample.append(Entanglement_pooled_img)
        
    joblib.dump(Entanglement_pooled_sample, f'{Entanglement_pooled_file_name}.joblib', compress=3)

    # free memory so the notebook stays fast
    del Entanglement_pooled_sample
    gc.collect()

# %%
config = np.asarray([2,1,3,0])
symmetry = ''.join(map(str,config))
#S1_rho_0_0321_Entropy_S1 : S1_rho_0 = system 1;Entropy_S1 = qubit 1
S1_rho0 = open_load_entropy(symmetry, 1)
S2_rho0 = open_load_entropy(symmetry, 2)

# %%
thr1 = S1_rho0.mean(axis=1, keepdims=True) 
thr1[:6]
# Out:
# array([[0.08651276],
#        [0.06177731],
#        [0.07814831],
#        [0.07415468],
#        [0.08800133],
#        [0.07059155]])

# %%
m1 = (S1_rho0 < thr1)  # (N,196)
m1[0]
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True, False, False,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True, False,  True,  True, False,  True,  True,  True,
#         True,  True,  True,  True,  True,  True, False,  True,  True,
#        False, False,  True,  True,  True,  True, False,  True,  True,
#        False,  True,  True,  True,  True,  True, False,  True,  True,
#         True,  True,  True, False, False, False,  True,  True,  True,
#        False,  True,  True,  True,  True, False,  True,  True,  True,
#         True, False,  True,  True,  True,  True, False,  True,  True,
#         True,  True,  True, False,  True, False,  True, False,  True,
#        False, False,  True,  True,  True,  True,  True,  True, False,
#         True,  True, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True, False, False, False, False,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True])

# %%
import numpy as np

def Entntanglement_pool(input_data, symmetry, Entanglement_pooled_file_name):
    X = input_data.astype(np.float32, copy=False)   # (N,196,4)
    #S1_rho_0_0321_Entropy_S1 : S1_rho_0 = system 1;Entropy_S1 = qubit 1
    S1_rho0 = open_load_entropy(symmetry, 1)
    S2_rho0 = open_load_entropy(symmetry, 2)
    thr1 = S1_rho0.mean(axis=1, keepdims=True)  # (N,1)
    thr2 = S2_rho0.mean(axis=1, keepdims=True)  # (N,1)

    m1 = (S1_rho0 < thr1)  # (N,196)
    m2 = (S2_rho0 < thr2)  # (N,196)

    pooled = np.empty_like(X, dtype=np.float32)
    pooled[..., 0] = X[..., 0] * m1
    pooled[..., 1] = X[..., 1]
    pooled[..., 2] = X[..., 2] * m2
    pooled[..., 3] = X[..., 3]

    np.save(f"{Entanglement_pooled_file_name}.npy", pooled)
    # np.save(f"{Entanglement_pooled_file_name}_thr1.npy", thr1.squeeze().astype(np.float32))  # optional
    # np.save(f"{Entanglement_pooled_file_name}_thr2.npy", thr2.squeeze().astype(np.float32))  # optional

# %% [markdown]
# ### Entanglement pooling the best 3 symmetries from previous experiment

# %%
for _, value in D.items():
    for _, config in value.items():
        # print(symmetry)
        # filtered_input = train_layer.open(config)
        # reshaped_filtered_input = train_layer.transform(filtered_input)
        
        # input with specific symmetry/config to filter based on entropy level
        filtered_input = train_layer.open(config)
        filtered_input = train_layer.transform(filtered_input)
        
        symmetry = ''.join(map(str,config))
        
        # file with _ctr0 : replacing ctr with 0 when Entropy/Entanglement greater than threshold 
        # File namne to store the pooled sample
        Entanglement_pooled_file_name = f"{train_layer.name}/{symmetry}/Entanglement_pooled_{_[2:-7]}_{''.join(map(str,symmetry))}_ctr0"  
        
        # print(Entanglement_pooled_file_name)
        
        Entntanglement_pool(input_data=filtered_input,
                            symmetry=symmetry,\
                            Entanglement_pooled_file_name=Entanglement_pooled_file_name)
        # # Entanglement filtering
        # Entanglement_pooling(input=filtered_input, symmetry=symmetry,\
        #                     sample_size=filtered_input.shape[0],\
        #                     Entanglement_pooled_file_name=Entanglement_pooled_file_name)

# %% [markdown]
# ## Trainign model

# %% [markdown]
# ### Row-Level Padding

# %%
import numpy as np

def pad_jagged_image(image_list, max_c=4):
    # Create a fixed-size buffer of zeros
    padded_img = np.zeros((len(image_list), max_c))
    
    for i, row in enumerate(image_list):
        # row is a 1D array of length 2, 3, or 4
        length = len(row)
        padded_img[i, :length] = row
        
    return padded_img

# %%
from keras.callbacks import CSVLogger, EarlyStopping, ModelCheckpoint, ReduceLROnPlateau



def run(tr_images, label,  run_subfolder, folder_name, patience=15):
    log_dir = train_layer.name + f"/{label}" + f"/{folder_name}/run{run_subfolder}/"   
    # print(' log_dir ', log_dir)
    
    log_file =  log_dir + f"{folder_name}_{label}"
    # print(' log_file ', log_file)
    os.makedirs(log_dir, exist_ok=True)
    
    csv_logger = CSVLogger(log_file)
    
    
    # tensorboard_callback = keras.callbacks.TensorBoard(
    #     log_dir=log_file,
    #     histogram_freq=1,
    #     write_graph=True,
    #     write_images=True,
    #     write_steps_per_second=True,
    #     update_freq='batch',
    #     profile_batch=1,
    #     embeddings_freq=1,
    #     embeddings_metadata=None
    # )
    
    number_of_classes = len(np.unique(test_labels))
    # Chose which model you want to use depending on the number of hidden layers
    # Uncomment your model and run the code--pay attention to your folder/file naming to keep everything organized 
    ####---------------------------------------------------------------------####
    # 1 FC layer
    if run_subfolder == "_1FC":
        # simple ANN model with 0 hidden layers: 1FC
        q_model = keras.models.Sequential([
            keras.layers.Rescaling(scale=-1. / 127.5, offset=1),
            keras.layers.Flatten(),
            keras.layers.Dense(number_of_classes, activation="softmax")
        ])
    
    ####---------------------------------------------------------------------####
    
    # # 2 FC layer
    if run_subfolder == "_2FC":
    
        # simple ANN model with 1 hidden layers: 2FC
        q_model = keras.models.Sequential([
            keras.layers.Rescaling(scale=-1. / 127.5, offset=1),
            keras.layers.Flatten(),
            keras.layers.Dense(512, activation='relu'),
            keras.layers.Dense(number_of_classes, activation="softmax")
        ])
    
    ####---------------------------------------------------------------------####
    # # 3 FC layer
    if run_subfolder == "_3FC":
    
        # simple ANN model with 2 hidden layers: 3FC
        q_model = keras.models.Sequential([
            keras.layers.Rescaling(scale=-1. / 127.5, offset=1),
            keras.layers.Flatten(),
            keras.layers.Dense(512, activation='relu'),
            keras.layers.Dense(256, activation='relu'),
            keras.layers.Dense(number_of_classes, activation='softmax')
        ])
    
    ####---------------------------------------------------------------------####
    # # 4 FC layer
    if run_subfolder == "_4FC": 
        # simple ANN model with 3 hidden layers: 4FC
        q_model = keras.models.Sequential([
            keras.layers.Rescaling(scale=-1. / 127.5, offset=1),
            keras.layers.Flatten(),
            keras.layers.Dense(512, activation='relu'),
            keras.layers.Dense(256, activation='relu'),
            keras.layers.Dense(128, activation='relu'),
            keras.layers.Dense(number_of_classes, activation='softmax')
        ])
    
    ####---------------------------------------------------------------------####
    
    q_model.compile(
        optimizer='adam',
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    
    # 
    batch_size = 128
    epochs = 60
    
    
    # Stop training when a monitored metric has stopped improving.
    Early_stop = EarlyStopping(monitor="val_accuracy",
                                min_delta=0, # Minimum change in the monitored quantity to qualify as an improvement, i.e. an absolute change of less than min_delta, will count as no improvement.
                                patience=patience, # Number of epochs with no improvement after which training will be stopped.
                                verbose=1, # 1 displays messages when the callback takes an action
                                mode="max", # will stop when the quantity monitored has stopped increasing
                                baseline=None,
                                restore_best_weights=True, # to restore model weights from the epoch with the best value of the monitored quantity
                                start_from_epoch=0, #  Number of epochs to wait before starting to monitor improvement.
                            )

    
    # Callback to save the Keras model or model weights at some frequency.
    checkpoint_filepath = log_file  + 'model.keras'
    model_checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath,
                                                monitor='val_accuracy',
                                                mode='max',
                                                verbose=1,
                                                save_best_only=True
                                                )
    # Reduce learning rate when a metric has stopped improving.
    reduce_lr_acc = ReduceLROnPlateau(monitor='val_accuracy',
                                        factor=0.1, # Float. Factor by which the learning rate will be reduced. new_lr = lr * factor.
                                        patience=10, # Integer. Number of epochs with no improvement after which learning rate will be reduced.
                                        verbose=1, # 1: update messages.
                                        mode="max", # 'max' mode it will be reduced when the quantity monitored has stopped increasing
                                        min_delta=0.0001, # Float. Threshold for measuring the new optimum, to only focus on significant changes.
                                        cooldown=0, #  Integer. Number of epochs to wait before resuming normal operation after the learning rate has been reduced.
                                        min_lr=0.0 #  Float. Lower bound on the learning rate.
                                    )


    
    q_history = q_model.fit(
        tr_images,
        train_labels,
        # validation_data=(te_images, test_labels),
        validation_split=0.2,
        batch_size=batch_size,
        epochs=epochs,
        verbose=2,
        # callbacks=[tensorboard_callback]
        callbacks = [Early_stop,csv_logger,model_checkpoint_callback, reduce_lr_acc]
    )

def model(variant, tr_layer):
    tr_images = Ent_pooled_data_padded_0s_array
    
    
    label = ''.join(map(str,Diagonal))


    run(tr_images, label)

# %%
run_subfolders = [f"_{str(i+1)}FC" for i in range(4)]

for _, value in D.items():
    for _, config in value.items():
        # print(symmetry)
        symmetry = ''.join(map(str,config))
        # File namne to store the pooled sample
        Entanglement_pooled_file_name = f"{train_layer.name}/{symmetry}/Entanglement_pooled_{_[2:-7]}_{symmetry}_ctr0" 
        # Too long to load: almost 5mins => think of other way probably to save and laod
        Entanglement_pooled_sample = np.load(f"{Entanglement_pooled_file_name}.npy") 
        approachs = ["Padding_0", "Entanglement_pool_summed", "No_Entanglement_pool_summed_avg"]
        for approach in approachs:
            # Padding with 0s
            if approach == "Padding_0":
                # 
                train_data =  Entanglement_pooled_sample
                # name of the folder for padded data
                folder_name = "Entanglement_pool_padded_0s"
            # Summing the entanglement pooled data
            if approach == "Entanglement_pool_summed":
                train_data = np.array([[sum(p)/len(p) for p in img] for img in Entanglement_pooled_sample])
                # name of the folder for padded data
                folder_name =  "Entanglement_pool_summed"
            
            # if approach == "No_Entanglement_pool_summed_avg":
            #     train_data = train_layer.open(config)
            #     train_data = train_data.mean(axis=-1)    # shape: (N, H, W)
            #     # name 
            #     folder_name =  "No_Entanglement_pool_summed_avg"
                
            for run_subfolder in run_subfolders:
                run(tr_images=train_data, label=symmetry,\
                    run_subfolder=run_subfolder, folder_name=folder_name)
# Out:
# Epoch 1/60
#
# Epoch 1: val_accuracy improved from -inf to 0.93335, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_1FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 6s - loss: 0.3598 - accuracy: 0.8983 - val_loss: 0.2266 - val_accuracy: 0.9334 - lr: 0.0010 - 6s/epoch - 4ms/step
# Epoch 2/60
#
# Epoch 2: val_accuracy improved from 0.93335 to 0.94590, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_1FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 4s - loss: 0.1988 - accuracy: 0.9439 - val_loss: 0.1909 - val_accuracy: 0.9459 - lr: 0.0010 - 4s/epoch - 3ms/step
# Epoch 3/60
#
# Epoch 3: val_accuracy improved from 0.94590 to 0.94837, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_1FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 4s - loss: 0.1782 - accuracy: 0.9493 - val_loss: 0.1836 - val_accuracy: 0.9484 - lr: 0.0010 - 4s/epoch - 3ms/step
# Epoch 4/60
#
# Epoch 4: val_accuracy improved from 0.94837 to 0.95185, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_1FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 4s - loss: 0.1683 - accuracy: 0.9526 - val_loss: 0.1682 - val_accuracy: 0.9519 - lr: 0.0010 - 4s/epoch - 3ms/step
# Epoch 5/60
#
# Epoch 5: val_accuracy improved from 0.95185 to 0.95379, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_1FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 3s - loss: 0.1618 - accuracy: 0.9533 - val_loss: 0.1636 - val_accuracy: 0.9538 - lr: 0.0010 - 3s/epoch - 2ms/step
# Epoch 6/60
#
# Epoch 6: val_accuracy did not improve from 0.95379
# 1500/1500 - 2s - loss: 0.1580 - accuracy: 0.9545 - val_loss: 0.1678 - val_accuracy: 0.9514 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 7/60
#
# Epoch 7: val_accuracy did not improve from 0.95379
# 1500/1500 - 3s - loss: 0.1554 - accuracy: 0.9549 - val_loss: 0.1645 - val_accuracy: 0.9532 - lr: 0.0010 - 3s/epoch - 2ms/step
# Epoch 8/60
#
# Epoch 8: val_accuracy improved from 0.95379 to 0.95417, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_1FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 3s - loss: 0.1523 - accuracy: 0.9560 - val_loss: 0.1613 - val_accuracy: 0.9542 - lr: 0.0010 - 3s/epoch - 2ms/step
# Epoch 9/60
#
# Epoch 9: val_accuracy did not improve from 0.95417
# 1500/1500 - 3s - loss: 0.1505 - accuracy: 0.9563 - val_loss: 0.1590 - val_accuracy: 0.9540 - lr: 0.0010 - 3s/epoch - 2ms/step
# Epoch 10/60
#
# Epoch 10: val_accuracy improved from 0.95417 to 0.95452, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_1FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 3s - loss: 0.1490 - accuracy: 0.9564 - val_loss: 0.1576 - val_accuracy: 0.9545 - lr: 0.0010 - 3s/epoch - 2ms/step
# Epoch 11/60
#
# Epoch 11: val_accuracy did not improve from 0.95452
# 1500/1500 - 4s - loss: 0.1479 - accuracy: 0.9570 - val_loss: 0.1607 - val_accuracy: 0.9537 - lr: 0.0010 - 4s/epoch - 3ms/step
# Epoch 12/60
#
# Epoch 12: val_accuracy improved from 0.95452 to 0.95483, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_1FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 4s - loss: 0.1466 - accuracy: 0.9574 - val_loss: 0.1583 - val_accuracy: 0.9548 - lr: 0.0010 - 4s/epoch - 3ms/step
# Epoch 13/60
#
# Epoch 13: val_accuracy improved from 0.95483 to 0.95525, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_1FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 4s - loss: 0.1470 - accuracy: 0.9569 - val_loss: 0.1584 - val_accuracy: 0.9553 - lr: 0.0010 - 4s/epoch - 3ms/step
# Epoch 14/60
#
# Epoch 14: val_accuracy did not improve from 0.95525
# 1500/1500 - 4s - loss: 0.1453 - accuracy: 0.9577 - val_loss: 0.1567 - val_accuracy: 0.9549 - lr: 0.0010 - 4s/epoch - 3ms/step
# Epoch 15/60
#
# Epoch 15: val_accuracy did not improve from 0.95525
# 1500/1500 - 5s - loss: 0.1445 - accuracy: 0.9578 - val_loss: 0.1565 - val_accuracy: 0.9546 - lr: 0.0010 - 5s/epoch - 3ms/step
# Epoch 16/60
#
# Epoch 16: val_accuracy did not improve from 0.95525
# 1500/1500 - 4s - loss: 0.1439 - accuracy: 0.9581 - val_loss: 0.1621 - val_accuracy: 0.9539 - lr: 0.0010 - 4s/epoch - 3ms/step
# Epoch 17/60
#
# Epoch 17: val_accuracy improved from 0.95525 to 0.95631, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_1FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 4s - loss: 0.1429 - accuracy: 0.9583 - val_loss: 0.1546 - val_accuracy: 0.9563 - lr: 0.0010 - 4s/epoch - 3ms/step
# Epoch 18/60
#
# Epoch 18: val_accuracy did not improve from 0.95631
# 1500/1500 - 4s - loss: 0.1441 - accuracy: 0.9582 - val_loss: 0.1570 - val_accuracy: 0.9556 - lr: 0.0010 - 4s/epoch - 2ms/step
# Epoch 19/60
#
# Epoch 19: val_accuracy did not improve from 0.95631
# 1500/1500 - 3s - loss: 0.1426 - accuracy: 0.9583 - val_loss: 0.1628 - val_accuracy: 0.9536 - lr: 0.0010 - 3s/epoch - 2ms/step
# Epoch 20/60
#
# Epoch 20: val_accuracy did not improve from 0.95631
# 1500/1500 - 4s - loss: 0.1414 - accuracy: 0.9587 - val_loss: 0.1569 - val_accuracy: 0.9554 - lr: 0.0010 - 4s/epoch - 3ms/step
# Epoch 21/60
#
# Epoch 21: val_accuracy did not improve from 0.95631
# 1500/1500 - 4s - loss: 0.1420 - accuracy: 0.9585 - val_loss: 0.1582 - val_accuracy: 0.9547 - lr: 0.0010 - 4s/epoch - 3ms/step
# Epoch 22/60
#
# Epoch 22: val_accuracy did not improve from 0.95631
# 1500/1500 - 3s - loss: 0.1411 - accuracy: 0.9589 - val_loss: 0.1561 - val_accuracy: 0.9552 - lr: 0.0010 - 3s/epoch - 2ms/step
# Epoch 23/60
#
# Epoch 23: val_accuracy did not improve from 0.95631
# 1500/1500 - 3s - loss: 0.1408 - accuracy: 0.9588 - val_loss: 0.1593 - val_accuracy: 0.9541 - lr: 0.0010 - 3s/epoch - 2ms/step
# Epoch 24/60
#
# Epoch 24: val_accuracy did not improve from 0.95631
# 1500/1500 - 4s - loss: 0.1420 - accuracy: 0.9583 - val_loss: 0.1600 - val_accuracy: 0.9542 - lr: 0.0010 - 4s/epoch - 2ms/step
# Epoch 25/60
#
# Epoch 25: val_accuracy did not improve from 0.95631
# 1500/1500 - 5s - loss: 0.1409 - accuracy: 0.9588 - val_loss: 0.1615 - val_accuracy: 0.9544 - lr: 0.0010 - 5s/epoch - 4ms/step
# Epoch 26/60
#
# Epoch 26: val_accuracy did not improve from 0.95631
# 1500/1500 - 5s - loss: 0.1403 - accuracy: 0.9591 - val_loss: 0.1606 - val_accuracy: 0.9551 - lr: 0.0010 - 5s/epoch - 3ms/step
# Epoch 27/60
#
# Epoch 27: val_accuracy did not improve from 0.95631
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 1500/1500 - 5s - loss: 0.1401 - accuracy: 0.9590 - val_loss: 0.1546 - val_accuracy: 0.9559 - lr: 0.0010 - 5s/epoch - 3ms/step
# Epoch 28/60
#
# Epoch 28: val_accuracy improved from 0.95631 to 0.95742, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_1FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 4s - loss: 0.1290 - accuracy: 0.9626 - val_loss: 0.1497 - val_accuracy: 0.9574 - lr: 1.0000e-04 - 4s/epoch - 3ms/step
# Epoch 29/60
#
# Epoch 29: val_accuracy improved from 0.95742 to 0.95846, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_1FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 4s - loss: 0.1286 - accuracy: 0.9626 - val_loss: 0.1492 - val_accuracy: 0.9585 - lr: 1.0000e-04 - 4s/epoch - 3ms/step
# Epoch 30/60
#
# Epoch 30: val_accuracy did not improve from 0.95846
# 1500/1500 - 4s - loss: 0.1284 - accuracy: 0.9626 - val_loss: 0.1494 - val_accuracy: 0.9576 - lr: 1.0000e-04 - 4s/epoch - 3ms/step
# Epoch 31/60
#
# Epoch 31: val_accuracy did not improve from 0.95846
# 1500/1500 - 5s - loss: 0.1284 - accuracy: 0.9627 - val_loss: 0.1486 - val_accuracy: 0.9582 - lr: 1.0000e-04 - 5s/epoch - 3ms/step
# Epoch 32/60
#
# Epoch 32: val_accuracy did not improve from 0.95846
# 1500/1500 - 4s - loss: 0.1281 - accuracy: 0.9629 - val_loss: 0.1488 - val_accuracy: 0.9583 - lr: 1.0000e-04 - 4s/epoch - 3ms/step
# Epoch 33/60
#
# Epoch 33: val_accuracy did not improve from 0.95846
# 1500/1500 - 3s - loss: 0.1283 - accuracy: 0.9629 - val_loss: 0.1485 - val_accuracy: 0.9580 - lr: 1.0000e-04 - 3s/epoch - 2ms/step
# Epoch 34/60
#
# Epoch 34: val_accuracy did not improve from 0.95846
# 1500/1500 - 3s - loss: 0.1282 - accuracy: 0.9628 - val_loss: 0.1490 - val_accuracy: 0.9580 - lr: 1.0000e-04 - 3s/epoch - 2ms/step
# Epoch 35/60
#
# Epoch 35: val_accuracy did not improve from 0.95846
# 1500/1500 - 5s - loss: 0.1282 - accuracy: 0.9628 - val_loss: 0.1490 - val_accuracy: 0.9578 - lr: 1.0000e-04 - 5s/epoch - 3ms/step
# Epoch 36/60
#
# Epoch 36: val_accuracy did not improve from 0.95846
# 1500/1500 - 5s - loss: 0.1281 - accuracy: 0.9628 - val_loss: 0.1491 - val_accuracy: 0.9581 - lr: 1.0000e-04 - 5s/epoch - 3ms/step
# Epoch 37/60
#
# Epoch 37: val_accuracy did not improve from 0.95846
# 1500/1500 - 5s - loss: 0.1281 - accuracy: 0.9627 - val_loss: 0.1484 - val_accuracy: 0.9582 - lr: 1.0000e-04 - 5s/epoch - 3ms/step
# Epoch 38/60
#
# Epoch 38: val_accuracy did not improve from 0.95846
# 1500/1500 - 5s - loss: 0.1281 - accuracy: 0.9628 - val_loss: 0.1483 - val_accuracy: 0.9583 - lr: 1.0000e-04 - 5s/epoch - 3ms/step
# Epoch 39/60
#
# Epoch 39: val_accuracy did not improve from 0.95846
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 1500/1500 - 5s - loss: 0.1280 - accuracy: 0.9628 - val_loss: 0.1483 - val_accuracy: 0.9581 - lr: 1.0000e-04 - 5s/epoch - 3ms/step
# Epoch 40/60
#
# Epoch 40: val_accuracy did not improve from 0.95846
# 1500/1500 - 5s - loss: 0.1267 - accuracy: 0.9632 - val_loss: 0.1480 - val_accuracy: 0.9582 - lr: 1.0000e-05 - 5s/epoch - 3ms/step
# Epoch 41/60
#
# Epoch 41: val_accuracy did not improve from 0.95846
# 1500/1500 - 5s - loss: 0.1267 - accuracy: 0.9631 - val_loss: 0.1481 - val_accuracy: 0.9584 - lr: 1.0000e-05 - 5s/epoch - 3ms/step
# Epoch 42/60
#
# Epoch 42: val_accuracy did not improve from 0.95846
# 1500/1500 - 5s - loss: 0.1267 - accuracy: 0.9633 - val_loss: 0.1480 - val_accuracy: 0.9584 - lr: 1.0000e-05 - 5s/epoch - 3ms/step
# Epoch 43/60
#
# Epoch 43: val_accuracy did not improve from 0.95846
# 1500/1500 - 5s - loss: 0.1266 - accuracy: 0.9633 - val_loss: 0.1480 - val_accuracy: 0.9583 - lr: 1.0000e-05 - 5s/epoch - 3ms/step
# Epoch 44/60
# Restoring model weights from the end of the best epoch: 29.
#
# Epoch 44: val_accuracy did not improve from 0.95846
# 1500/1500 - 4s - loss: 0.1266 - accuracy: 0.9632 - val_loss: 0.1480 - val_accuracy: 0.9584 - lr: 1.0000e-05 - 4s/epoch - 3ms/step
# Epoch 44: early stopping
# Epoch 1/60
#
# Epoch 1: val_accuracy improved from -inf to 0.96463, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_2FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 11s - loss: 0.2049 - accuracy: 0.9392 - val_loss: 0.1190 - val_accuracy: 0.9646 - lr: 0.0010 - 11s/epoch - 7ms/step
# Epoch 2/60
#
# Epoch 2: val_accuracy improved from 0.96463 to 0.97410, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_2FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 8s - loss: 0.0996 - accuracy: 0.9698 - val_loss: 0.0828 - val_accuracy: 0.9741 - lr: 0.0010 - 8s/epoch - 6ms/step
# Epoch 3/60
#
# Epoch 3: val_accuracy did not improve from 0.97410
# 1500/1500 - 11s - loss: 0.0759 - accuracy: 0.9766 - val_loss: 0.0959 - val_accuracy: 0.9700 - lr: 0.0010 - 11s/epoch - 7ms/step
# Epoch 4/60
#
# Epoch 4: val_accuracy improved from 0.97410 to 0.97871, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_2FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 11s - loss: 0.0637 - accuracy: 0.9800 - val_loss: 0.0695 - val_accuracy: 0.9787 - lr: 0.0010 - 11s/epoch - 7ms/step
# Epoch 5/60
#
# Epoch 5: val_accuracy did not improve from 0.97871
# 1500/1500 - 11s - loss: 0.0540 - accuracy: 0.9828 - val_loss: 0.0817 - val_accuracy: 0.9749 - lr: 0.0010 - 11s/epoch - 7ms/step
# Epoch 6/60
#
# Epoch 6: val_accuracy improved from 0.97871 to 0.98104, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_2FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 11s - loss: 0.0475 - accuracy: 0.9847 - val_loss: 0.0664 - val_accuracy: 0.9810 - lr: 0.0010 - 11s/epoch - 7ms/step
# Epoch 7/60
#
# Epoch 7: val_accuracy did not improve from 0.98104
# 1500/1500 - 11s - loss: 0.0430 - accuracy: 0.9861 - val_loss: 0.0647 - val_accuracy: 0.9806 - lr: 0.0010 - 11s/epoch - 7ms/step
# Epoch 8/60
#
# Epoch 8: val_accuracy did not improve from 0.98104
# 1500/1500 - 10s - loss: 0.0376 - accuracy: 0.9877 - val_loss: 0.0811 - val_accuracy: 0.9774 - lr: 0.0010 - 10s/epoch - 7ms/step
# Epoch 9/60
#
# Epoch 9: val_accuracy did not improve from 0.98104
# 1500/1500 - 11s - loss: 0.0347 - accuracy: 0.9885 - val_loss: 0.0732 - val_accuracy: 0.9805 - lr: 0.0010 - 11s/epoch - 7ms/step
# Epoch 10/60
#
# Epoch 10: val_accuracy improved from 0.98104 to 0.98296, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_2FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 10s - loss: 0.0311 - accuracy: 0.9899 - val_loss: 0.0647 - val_accuracy: 0.9830 - lr: 0.0010 - 10s/epoch - 6ms/step
# Epoch 11/60
#
# Epoch 11: val_accuracy did not improve from 0.98296
# 1500/1500 - 11s - loss: 0.0297 - accuracy: 0.9902 - val_loss: 0.0785 - val_accuracy: 0.9803 - lr: 0.0010 - 11s/epoch - 7ms/step
# Epoch 12/60
#
# Epoch 12: val_accuracy did not improve from 0.98296
# 1500/1500 - 11s - loss: 0.0261 - accuracy: 0.9914 - val_loss: 0.0733 - val_accuracy: 0.9810 - lr: 0.0010 - 11s/epoch - 7ms/step
# Epoch 13/60
#
# Epoch 13: val_accuracy did not improve from 0.98296
# 1500/1500 - 11s - loss: 0.0254 - accuracy: 0.9914 - val_loss: 0.0766 - val_accuracy: 0.9803 - lr: 0.0010 - 11s/epoch - 7ms/step
# Epoch 14/60
#
# Epoch 14: val_accuracy did not improve from 0.98296
# 1500/1500 - 8s - loss: 0.0226 - accuracy: 0.9923 - val_loss: 0.0717 - val_accuracy: 0.9826 - lr: 0.0010 - 8s/epoch - 6ms/step
# Epoch 15/60
#
# Epoch 15: val_accuracy did not improve from 0.98296
# 1500/1500 - 8s - loss: 0.0207 - accuracy: 0.9933 - val_loss: 0.0766 - val_accuracy: 0.9816 - lr: 0.0010 - 8s/epoch - 6ms/step
# Epoch 16/60
#
# Epoch 16: val_accuracy did not improve from 0.98296
# 1500/1500 - 8s - loss: 0.0210 - accuracy: 0.9929 - val_loss: 0.0747 - val_accuracy: 0.9821 - lr: 0.0010 - 8s/epoch - 5ms/step
# Epoch 17/60
#
# Epoch 17: val_accuracy did not improve from 0.98296
# 1500/1500 - 9s - loss: 0.0185 - accuracy: 0.9937 - val_loss: 0.0769 - val_accuracy: 0.9820 - lr: 0.0010 - 9s/epoch - 6ms/step
# Epoch 18/60
#
# Epoch 18: val_accuracy did not improve from 0.98296
# 1500/1500 - 8s - loss: 0.0173 - accuracy: 0.9942 - val_loss: 0.0777 - val_accuracy: 0.9823 - lr: 0.0010 - 8s/epoch - 5ms/step
# Epoch 19/60
#
# Epoch 19: val_accuracy did not improve from 0.98296
# 1500/1500 - 10s - loss: 0.0173 - accuracy: 0.9940 - val_loss: 0.0885 - val_accuracy: 0.9812 - lr: 0.0010 - 10s/epoch - 7ms/step
# Epoch 20/60
#
# Epoch 20: val_accuracy did not improve from 0.98296
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 1500/1500 - 10s - loss: 0.0167 - accuracy: 0.9944 - val_loss: 0.0960 - val_accuracy: 0.9791 - lr: 0.0010 - 10s/epoch - 7ms/step
# Epoch 21/60
#
# Epoch 21: val_accuracy improved from 0.98296 to 0.98627, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_2FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 10s - loss: 0.0049 - accuracy: 0.9986 - val_loss: 0.0661 - val_accuracy: 0.9863 - lr: 1.0000e-04 - 10s/epoch - 7ms/step
# Epoch 22/60
#
# Epoch 22: val_accuracy improved from 0.98627 to 0.98637, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_2FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 10s - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.0666 - val_accuracy: 0.9864 - lr: 1.0000e-04 - 10s/epoch - 7ms/step
# Epoch 23/60
#
# Epoch 23: val_accuracy improved from 0.98637 to 0.98642, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_2FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 10s - loss: 0.0023 - accuracy: 0.9996 - val_loss: 0.0672 - val_accuracy: 0.9864 - lr: 1.0000e-04 - 10s/epoch - 7ms/step
# Epoch 24/60
#
# Epoch 24: val_accuracy did not improve from 0.98642
# 1500/1500 - 11s - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.0688 - val_accuracy: 0.9862 - lr: 1.0000e-04 - 11s/epoch - 7ms/step
# Epoch 25/60
#
# Epoch 25: val_accuracy did not improve from 0.98642
# 1500/1500 - 10s - loss: 0.0017 - accuracy: 0.9998 - val_loss: 0.0691 - val_accuracy: 0.9864 - lr: 1.0000e-04 - 10s/epoch - 7ms/step
# Epoch 26/60
#
# Epoch 26: val_accuracy improved from 0.98642 to 0.98667, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_2FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 10s - loss: 0.0015 - accuracy: 0.9998 - val_loss: 0.0700 - val_accuracy: 0.9867 - lr: 1.0000e-04 - 10s/epoch - 7ms/step
# Epoch 27/60
#
# Epoch 27: val_accuracy did not improve from 0.98667
# 1500/1500 - 9s - loss: 0.0013 - accuracy: 0.9999 - val_loss: 0.0696 - val_accuracy: 0.9863 - lr: 1.0000e-04 - 9s/epoch - 6ms/step
# Epoch 28/60
#
# Epoch 28: val_accuracy improved from 0.98667 to 0.98685, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_2FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 9s - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.0700 - val_accuracy: 0.9869 - lr: 1.0000e-04 - 9s/epoch - 6ms/step
# Epoch 29/60
#
# Epoch 29: val_accuracy did not improve from 0.98685
# 1500/1500 - 11s - loss: 0.0010 - accuracy: 0.9999 - val_loss: 0.0702 - val_accuracy: 0.9867 - lr: 1.0000e-04 - 11s/epoch - 7ms/step
# Epoch 30/60
#
# Epoch 30: val_accuracy did not improve from 0.98685
# 1500/1500 - 9s - loss: 8.5807e-04 - accuracy: 0.9999 - val_loss: 0.0716 - val_accuracy: 0.9865 - lr: 1.0000e-04 - 9s/epoch - 6ms/step
# Epoch 31/60
#
# Epoch 31: val_accuracy did not improve from 0.98685
# 1500/1500 - 10s - loss: 8.0750e-04 - accuracy: 1.0000 - val_loss: 0.0717 - val_accuracy: 0.9866 - lr: 1.0000e-04 - 10s/epoch - 6ms/step
# Epoch 32/60
#
# Epoch 32: val_accuracy did not improve from 0.98685
# 1500/1500 - 9s - loss: 6.8706e-04 - accuracy: 0.9999 - val_loss: 0.0726 - val_accuracy: 0.9863 - lr: 1.0000e-04 - 9s/epoch - 6ms/step
# Epoch 33/60
#
# Epoch 33: val_accuracy did not improve from 0.98685
# 1500/1500 - 9s - loss: 5.8654e-04 - accuracy: 1.0000 - val_loss: 0.0736 - val_accuracy: 0.9866 - lr: 1.0000e-04 - 9s/epoch - 6ms/step
# Epoch 34/60
#
# Epoch 34: val_accuracy did not improve from 0.98685
# 1500/1500 - 9s - loss: 5.8353e-04 - accuracy: 1.0000 - val_loss: 0.0741 - val_accuracy: 0.9866 - lr: 1.0000e-04 - 9s/epoch - 6ms/step
# Epoch 35/60
#
# Epoch 35: val_accuracy did not improve from 0.98685
# 1500/1500 - 9s - loss: 4.8451e-04 - accuracy: 1.0000 - val_loss: 0.0753 - val_accuracy: 0.9866 - lr: 1.0000e-04 - 9s/epoch - 6ms/step
# Epoch 36/60
#
# Epoch 36: val_accuracy did not improve from 0.98685
# 1500/1500 - 9s - loss: 3.9379e-04 - accuracy: 1.0000 - val_loss: 0.0765 - val_accuracy: 0.9865 - lr: 1.0000e-04 - 9s/epoch - 6ms/step
# Epoch 37/60
#
# Epoch 37: val_accuracy did not improve from 0.98685
# 1500/1500 - 10s - loss: 3.9012e-04 - accuracy: 1.0000 - val_loss: 0.0759 - val_accuracy: 0.9865 - lr: 1.0000e-04 - 10s/epoch - 6ms/step
# Epoch 38/60
#
# Epoch 38: val_accuracy did not improve from 0.98685
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 1500/1500 - 9s - loss: 3.4759e-04 - accuracy: 1.0000 - val_loss: 0.0766 - val_accuracy: 0.9865 - lr: 1.0000e-04 - 9s/epoch - 6ms/step
# Epoch 39/60
#
# Epoch 39: val_accuracy did not improve from 0.98685
# 1500/1500 - 9s - loss: 2.3030e-04 - accuracy: 1.0000 - val_loss: 0.0763 - val_accuracy: 0.9868 - lr: 1.0000e-05 - 9s/epoch - 6ms/step
# Epoch 40/60
#
# Epoch 40: val_accuracy did not improve from 0.98685
# 1500/1500 - 10s - loss: 1.9078e-04 - accuracy: 1.0000 - val_loss: 0.0769 - val_accuracy: 0.9869 - lr: 1.0000e-05 - 10s/epoch - 6ms/step
# Epoch 41/60
#
# Epoch 41: val_accuracy improved from 0.98685 to 0.98694, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_2FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 9s - loss: 1.8159e-04 - accuracy: 1.0000 - val_loss: 0.0771 - val_accuracy: 0.9869 - lr: 1.0000e-05 - 9s/epoch - 6ms/step
# Epoch 42/60
#
# Epoch 42: val_accuracy did not improve from 0.98694
# 1500/1500 - 9s - loss: 1.7708e-04 - accuracy: 1.0000 - val_loss: 0.0774 - val_accuracy: 0.9869 - lr: 1.0000e-05 - 9s/epoch - 6ms/step
# Epoch 43/60
#
# Epoch 43: val_accuracy did not improve from 0.98694
# 1500/1500 - 10s - loss: 1.7248e-04 - accuracy: 1.0000 - val_loss: 0.0775 - val_accuracy: 0.9869 - lr: 1.0000e-05 - 10s/epoch - 6ms/step
# Epoch 44/60
#
# Epoch 44: val_accuracy did not improve from 0.98694
# 1500/1500 - 10s - loss: 1.6719e-04 - accuracy: 1.0000 - val_loss: 0.0777 - val_accuracy: 0.9869 - lr: 1.0000e-05 - 10s/epoch - 7ms/step
# Epoch 45/60
#
# Epoch 45: val_accuracy did not improve from 0.98694
# 1500/1500 - 10s - loss: 1.6243e-04 - accuracy: 1.0000 - val_loss: 0.0779 - val_accuracy: 0.9869 - lr: 1.0000e-05 - 10s/epoch - 7ms/step
# Epoch 46/60
#
# Epoch 46: val_accuracy did not improve from 0.98694
# 1500/1500 - 8s - loss: 1.5959e-04 - accuracy: 1.0000 - val_loss: 0.0780 - val_accuracy: 0.9869 - lr: 1.0000e-05 - 8s/epoch - 5ms/step
# Epoch 47/60
#
# Epoch 47: val_accuracy improved from 0.98694 to 0.98700, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_2FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 9s - loss: 1.5632e-04 - accuracy: 1.0000 - val_loss: 0.0781 - val_accuracy: 0.9870 - lr: 1.0000e-05 - 9s/epoch - 6ms/step
# Epoch 48/60
#
# Epoch 48: val_accuracy did not improve from 0.98700
# 1500/1500 - 7s - loss: 1.5225e-04 - accuracy: 1.0000 - val_loss: 0.0784 - val_accuracy: 0.9868 - lr: 1.0000e-05 - 7s/epoch - 5ms/step
# Epoch 49/60
#
# Epoch 49: val_accuracy did not improve from 0.98700
# 1500/1500 - 7s - loss: 1.4902e-04 - accuracy: 1.0000 - val_loss: 0.0784 - val_accuracy: 0.9869 - lr: 1.0000e-05 - 7s/epoch - 5ms/step
# Epoch 50/60
#
# Epoch 50: val_accuracy did not improve from 0.98700
# 1500/1500 - 8s - loss: 1.4621e-04 - accuracy: 1.0000 - val_loss: 0.0787 - val_accuracy: 0.9869 - lr: 1.0000e-05 - 8s/epoch - 6ms/step
# Epoch 51/60
#
# Epoch 51: val_accuracy did not improve from 0.98700
# 1500/1500 - 9s - loss: 1.4244e-04 - accuracy: 1.0000 - val_loss: 0.0787 - val_accuracy: 0.9869 - lr: 1.0000e-05 - 9s/epoch - 6ms/step
# Epoch 52/60
#
# Epoch 52: val_accuracy did not improve from 0.98700
# 1500/1500 - 10s - loss: 1.3842e-04 - accuracy: 1.0000 - val_loss: 0.0791 - val_accuracy: 0.9869 - lr: 1.0000e-05 - 10s/epoch - 7ms/step
# Epoch 53/60
#
# Epoch 53: val_accuracy did not improve from 0.98700
# 1500/1500 - 10s - loss: 1.3682e-04 - accuracy: 1.0000 - val_loss: 0.0789 - val_accuracy: 0.9868 - lr: 1.0000e-05 - 10s/epoch - 7ms/step
# Epoch 54/60
#
# Epoch 54: val_accuracy did not improve from 0.98700
# 1500/1500 - 10s - loss: 1.3286e-04 - accuracy: 1.0000 - val_loss: 0.0792 - val_accuracy: 0.9869 - lr: 1.0000e-05 - 10s/epoch - 7ms/step
# Epoch 55/60
#
# Epoch 55: val_accuracy improved from 0.98700 to 0.98702, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_2FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 10s - loss: 1.3062e-04 - accuracy: 1.0000 - val_loss: 0.0793 - val_accuracy: 0.9870 - lr: 1.0000e-05 - 10s/epoch - 7ms/step
# Epoch 56/60
#
# Epoch 56: val_accuracy did not improve from 0.98702
# 1500/1500 - 10s - loss: 1.2798e-04 - accuracy: 1.0000 - val_loss: 0.0795 - val_accuracy: 0.9869 - lr: 1.0000e-05 - 10s/epoch - 7ms/step
# Epoch 57/60
#
# Epoch 57: val_accuracy did not improve from 0.98702
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 1500/1500 - 11s - loss: 1.2474e-04 - accuracy: 1.0000 - val_loss: 0.0798 - val_accuracy: 0.9869 - lr: 1.0000e-05 - 11s/epoch - 7ms/step
# Epoch 58/60
#
# Epoch 58: val_accuracy did not improve from 0.98702
# 1500/1500 - 10s - loss: 1.2001e-04 - accuracy: 1.0000 - val_loss: 0.0797 - val_accuracy: 0.9870 - lr: 1.0000e-06 - 10s/epoch - 6ms/step
# Epoch 59/60
#
# Epoch 59: val_accuracy did not improve from 0.98702
# 1500/1500 - 9s - loss: 1.1764e-04 - accuracy: 1.0000 - val_loss: 0.0797 - val_accuracy: 0.9869 - lr: 1.0000e-06 - 9s/epoch - 6ms/step
# Epoch 60/60
#
# Epoch 60: val_accuracy did not improve from 0.98702
# 1500/1500 - 11s - loss: 1.1712e-04 - accuracy: 1.0000 - val_loss: 0.0797 - val_accuracy: 0.9869 - lr: 1.0000e-06 - 11s/epoch - 7ms/step
# Epoch 1/60
#
# Epoch 1: val_accuracy improved from -inf to 0.96169, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 15s - loss: 0.1887 - accuracy: 0.9423 - val_loss: 0.1197 - val_accuracy: 0.9617 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 2/60
#
# Epoch 2: val_accuracy improved from 0.96169 to 0.97188, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 14s - loss: 0.0909 - accuracy: 0.9714 - val_loss: 0.0931 - val_accuracy: 0.9719 - lr: 0.0010 - 14s/epoch - 9ms/step
# Epoch 3/60
#
# Epoch 3: val_accuracy improved from 0.97188 to 0.97667, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 15s - loss: 0.0716 - accuracy: 0.9772 - val_loss: 0.0799 - val_accuracy: 0.9767 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 4/60
#
# Epoch 4: val_accuracy did not improve from 0.97667
# 1500/1500 - 15s - loss: 0.0593 - accuracy: 0.9807 - val_loss: 0.0904 - val_accuracy: 0.9722 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 5/60
#
# Epoch 5: val_accuracy improved from 0.97667 to 0.98092, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 13s - loss: 0.0509 - accuracy: 0.9835 - val_loss: 0.0645 - val_accuracy: 0.9809 - lr: 0.0010 - 13s/epoch - 8ms/step
# Epoch 6/60
#
# Epoch 6: val_accuracy did not improve from 0.98092
# 1500/1500 - 15s - loss: 0.0453 - accuracy: 0.9856 - val_loss: 0.0763 - val_accuracy: 0.9774 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 7/60
#
# Epoch 7: val_accuracy improved from 0.98092 to 0.98137, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 13s - loss: 0.0398 - accuracy: 0.9869 - val_loss: 0.0663 - val_accuracy: 0.9814 - lr: 0.0010 - 13s/epoch - 8ms/step
# Epoch 8/60
#
# Epoch 8: val_accuracy did not improve from 0.98137
# 1500/1500 - 13s - loss: 0.0354 - accuracy: 0.9883 - val_loss: 0.0724 - val_accuracy: 0.9800 - lr: 0.0010 - 13s/epoch - 8ms/step
# Epoch 9/60
#
# Epoch 9: val_accuracy improved from 0.98137 to 0.98190, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 12s - loss: 0.0328 - accuracy: 0.9888 - val_loss: 0.0689 - val_accuracy: 0.9819 - lr: 0.0010 - 12s/epoch - 8ms/step
# Epoch 10/60
#
# Epoch 10: val_accuracy did not improve from 0.98190
# 1500/1500 - 12s - loss: 0.0296 - accuracy: 0.9903 - val_loss: 0.0743 - val_accuracy: 0.9791 - lr: 0.0010 - 12s/epoch - 8ms/step
# Epoch 11/60
#
# Epoch 11: val_accuracy did not improve from 0.98190
# 1500/1500 - 12s - loss: 0.0267 - accuracy: 0.9911 - val_loss: 0.0724 - val_accuracy: 0.9818 - lr: 0.0010 - 12s/epoch - 8ms/step
# Epoch 12/60
#
# Epoch 12: val_accuracy improved from 0.98190 to 0.98287, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 13s - loss: 0.0248 - accuracy: 0.9918 - val_loss: 0.0684 - val_accuracy: 0.9829 - lr: 0.0010 - 13s/epoch - 9ms/step
# Epoch 13/60
#
# Epoch 13: val_accuracy did not improve from 0.98287
# 1500/1500 - 11s - loss: 0.0226 - accuracy: 0.9923 - val_loss: 0.0734 - val_accuracy: 0.9828 - lr: 0.0010 - 11s/epoch - 8ms/step
# Epoch 14/60
#
# Epoch 14: val_accuracy improved from 0.98287 to 0.98306, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 12s - loss: 0.0219 - accuracy: 0.9927 - val_loss: 0.0743 - val_accuracy: 0.9831 - lr: 0.0010 - 12s/epoch - 8ms/step
# Epoch 15/60
#
# Epoch 15: val_accuracy did not improve from 0.98306
# 1500/1500 - 12s - loss: 0.0204 - accuracy: 0.9932 - val_loss: 0.0820 - val_accuracy: 0.9815 - lr: 0.0010 - 12s/epoch - 8ms/step
# Epoch 16/60
#
# Epoch 16: val_accuracy did not improve from 0.98306
# 1500/1500 - 11s - loss: 0.0206 - accuracy: 0.9931 - val_loss: 0.0891 - val_accuracy: 0.9804 - lr: 0.0010 - 11s/epoch - 7ms/step
# Epoch 17/60
#
# Epoch 17: val_accuracy improved from 0.98306 to 0.98460, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 11s - loss: 0.0191 - accuracy: 0.9935 - val_loss: 0.0734 - val_accuracy: 0.9846 - lr: 0.0010 - 11s/epoch - 7ms/step
# Epoch 18/60
#
# Epoch 18: val_accuracy did not improve from 0.98460
# 1500/1500 - 10s - loss: 0.0179 - accuracy: 0.9942 - val_loss: 0.0721 - val_accuracy: 0.9842 - lr: 0.0010 - 10s/epoch - 7ms/step
# Epoch 19/60
#
# Epoch 19: val_accuracy did not improve from 0.98460
# 1500/1500 - 10s - loss: 0.0179 - accuracy: 0.9940 - val_loss: 0.0799 - val_accuracy: 0.9836 - lr: 0.0010 - 10s/epoch - 6ms/step
# Epoch 20/60
#
# Epoch 20: val_accuracy did not improve from 0.98460
# 1500/1500 - 11s - loss: 0.0161 - accuracy: 0.9947 - val_loss: 0.0832 - val_accuracy: 0.9839 - lr: 0.0010 - 11s/epoch - 7ms/step
# Epoch 21/60
#
# Epoch 21: val_accuracy did not improve from 0.98460
# 1500/1500 - 11s - loss: 0.0160 - accuracy: 0.9948 - val_loss: 0.0881 - val_accuracy: 0.9831 - lr: 0.0010 - 11s/epoch - 7ms/step
# Epoch 22/60
#
# Epoch 22: val_accuracy did not improve from 0.98460
# 1500/1500 - 10s - loss: 0.0160 - accuracy: 0.9948 - val_loss: 0.0965 - val_accuracy: 0.9821 - lr: 0.0010 - 10s/epoch - 7ms/step
# Epoch 23/60
#
# Epoch 23: val_accuracy did not improve from 0.98460
# 1500/1500 - 12s - loss: 0.0155 - accuracy: 0.9950 - val_loss: 0.0897 - val_accuracy: 0.9827 - lr: 0.0010 - 12s/epoch - 8ms/step
# Epoch 24/60
#
# Epoch 24: val_accuracy did not improve from 0.98460
# 1500/1500 - 11s - loss: 0.0151 - accuracy: 0.9951 - val_loss: 0.0947 - val_accuracy: 0.9829 - lr: 0.0010 - 11s/epoch - 7ms/step
# Epoch 25/60
#
# Epoch 25: val_accuracy did not improve from 0.98460
# 1500/1500 - 11s - loss: 0.0141 - accuracy: 0.9954 - val_loss: 0.1000 - val_accuracy: 0.9828 - lr: 0.0010 - 11s/epoch - 7ms/step
# Epoch 26/60
#
# Epoch 26: val_accuracy improved from 0.98460 to 0.98590, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 10s - loss: 0.0133 - accuracy: 0.9956 - val_loss: 0.0846 - val_accuracy: 0.9859 - lr: 0.0010 - 10s/epoch - 6ms/step
# Epoch 27/60
#
# Epoch 27: val_accuracy did not improve from 0.98590
# 1500/1500 - 9s - loss: 0.0135 - accuracy: 0.9955 - val_loss: 0.1121 - val_accuracy: 0.9811 - lr: 0.0010 - 9s/epoch - 6ms/step
# Epoch 28/60
#
# Epoch 28: val_accuracy did not improve from 0.98590
# 1500/1500 - 12s - loss: 0.0124 - accuracy: 0.9960 - val_loss: 0.0867 - val_accuracy: 0.9855 - lr: 0.0010 - 12s/epoch - 8ms/step
# Epoch 29/60
#
# Epoch 29: val_accuracy did not improve from 0.98590
# 1500/1500 - 11s - loss: 0.0142 - accuracy: 0.9956 - val_loss: 0.0926 - val_accuracy: 0.9850 - lr: 0.0010 - 11s/epoch - 7ms/step
# Epoch 30/60
#
# Epoch 30: val_accuracy did not improve from 0.98590
# 1500/1500 - 10s - loss: 0.0126 - accuracy: 0.9960 - val_loss: 0.0953 - val_accuracy: 0.9848 - lr: 0.0010 - 10s/epoch - 7ms/step
# Epoch 31/60
#
# Epoch 31: val_accuracy did not improve from 0.98590
# 1500/1500 - 11s - loss: 0.0120 - accuracy: 0.9964 - val_loss: 0.0993 - val_accuracy: 0.9843 - lr: 0.0010 - 11s/epoch - 7ms/step
# Epoch 32/60
#
# Epoch 32: val_accuracy did not improve from 0.98590
# 1500/1500 - 11s - loss: 0.0116 - accuracy: 0.9964 - val_loss: 0.1045 - val_accuracy: 0.9846 - lr: 0.0010 - 11s/epoch - 7ms/step
# Epoch 33/60
#
# Epoch 33: val_accuracy did not improve from 0.98590
# 1500/1500 - 10s - loss: 0.0130 - accuracy: 0.9958 - val_loss: 0.1001 - val_accuracy: 0.9855 - lr: 0.0010 - 10s/epoch - 7ms/step
# Epoch 34/60
#
# Epoch 34: val_accuracy did not improve from 0.98590
# 1500/1500 - 11s - loss: 0.0108 - accuracy: 0.9965 - val_loss: 0.1188 - val_accuracy: 0.9820 - lr: 0.0010 - 11s/epoch - 8ms/step
# Epoch 35/60
#
# Epoch 35: val_accuracy did not improve from 0.98590
# 1500/1500 - 9s - loss: 0.0113 - accuracy: 0.9965 - val_loss: 0.0984 - val_accuracy: 0.9851 - lr: 0.0010 - 9s/epoch - 6ms/step
# Epoch 36/60
#
# Epoch 36: val_accuracy did not improve from 0.98590
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 1500/1500 - 12s - loss: 0.0118 - accuracy: 0.9966 - val_loss: 0.1215 - val_accuracy: 0.9826 - lr: 0.0010 - 12s/epoch - 8ms/step
# Epoch 37/60
#
# Epoch 37: val_accuracy improved from 0.98590 to 0.98721, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 11s - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0885 - val_accuracy: 0.9872 - lr: 1.0000e-04 - 11s/epoch - 7ms/step
# Epoch 38/60
#
# Epoch 38: val_accuracy improved from 0.98721 to 0.98758, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 11s - loss: 4.3375e-04 - accuracy: 0.9999 - val_loss: 0.0896 - val_accuracy: 0.9876 - lr: 1.0000e-04 - 11s/epoch - 7ms/step
# Epoch 39/60
#
# Epoch 39: val_accuracy did not improve from 0.98758
# 1500/1500 - 9s - loss: 2.3735e-04 - accuracy: 1.0000 - val_loss: 0.0900 - val_accuracy: 0.9876 - lr: 1.0000e-04 - 9s/epoch - 6ms/step
# Epoch 40/60
#
# Epoch 40: val_accuracy did not improve from 0.98758
# 1500/1500 - 10s - loss: 1.9383e-04 - accuracy: 1.0000 - val_loss: 0.0917 - val_accuracy: 0.9875 - lr: 1.0000e-04 - 10s/epoch - 7ms/step
# Epoch 41/60
#
# Epoch 41: val_accuracy improved from 0.98758 to 0.98796, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 9s - loss: 1.3380e-04 - accuracy: 1.0000 - val_loss: 0.0927 - val_accuracy: 0.9880 - lr: 1.0000e-04 - 9s/epoch - 6ms/step
# Epoch 42/60
#
# Epoch 42: val_accuracy did not improve from 0.98796
# 1500/1500 - 10s - loss: 8.1171e-05 - accuracy: 1.0000 - val_loss: 0.0964 - val_accuracy: 0.9880 - lr: 1.0000e-04 - 10s/epoch - 7ms/step
# Epoch 43/60
#
# Epoch 43: val_accuracy did not improve from 0.98796
# 1500/1500 - 11s - loss: 1.0062e-04 - accuracy: 1.0000 - val_loss: 0.0988 - val_accuracy: 0.9878 - lr: 1.0000e-04 - 11s/epoch - 7ms/step
# Epoch 44/60
#
# Epoch 44: val_accuracy did not improve from 0.98796
# 1500/1500 - 10s - loss: 9.0230e-05 - accuracy: 1.0000 - val_loss: 0.1029 - val_accuracy: 0.9875 - lr: 1.0000e-04 - 10s/epoch - 7ms/step
# Epoch 45/60
#
# Epoch 45: val_accuracy improved from 0.98796 to 0.98829, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 10s - loss: 3.7874e-05 - accuracy: 1.0000 - val_loss: 0.1015 - val_accuracy: 0.9883 - lr: 1.0000e-04 - 10s/epoch - 7ms/step
# Epoch 46/60
#
# Epoch 46: val_accuracy did not improve from 0.98829
# 1500/1500 - 9s - loss: 9.9221e-05 - accuracy: 1.0000 - val_loss: 0.1045 - val_accuracy: 0.9880 - lr: 1.0000e-04 - 9s/epoch - 6ms/step
# Epoch 47/60
#
# Epoch 47: val_accuracy did not improve from 0.98829
# 1500/1500 - 9s - loss: 3.2508e-05 - accuracy: 1.0000 - val_loss: 0.1041 - val_accuracy: 0.9881 - lr: 1.0000e-04 - 9s/epoch - 6ms/step
# Epoch 48/60
#
# Epoch 48: val_accuracy did not improve from 0.98829
# 1500/1500 - 10s - loss: 5.4020e-05 - accuracy: 1.0000 - val_loss: 0.1067 - val_accuracy: 0.9880 - lr: 1.0000e-04 - 10s/epoch - 7ms/step
# Epoch 49/60
#
# Epoch 49: val_accuracy did not improve from 0.98829
# 1500/1500 - 10s - loss: 1.3264e-05 - accuracy: 1.0000 - val_loss: 0.1085 - val_accuracy: 0.9882 - lr: 1.0000e-04 - 10s/epoch - 7ms/step
# Epoch 50/60
#
# Epoch 50: val_accuracy improved from 0.98829 to 0.98842, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 12s - loss: 5.6451e-06 - accuracy: 1.0000 - val_loss: 0.1110 - val_accuracy: 0.9884 - lr: 1.0000e-04 - 12s/epoch - 8ms/step
# Epoch 51/60
#
# Epoch 51: val_accuracy did not improve from 0.98842
# 1500/1500 - 11s - loss: 9.4796e-05 - accuracy: 1.0000 - val_loss: 0.1141 - val_accuracy: 0.9881 - lr: 1.0000e-04 - 11s/epoch - 8ms/step
# Epoch 52/60
#
# Epoch 52: val_accuracy did not improve from 0.98842
# 1500/1500 - 10s - loss: 4.7633e-05 - accuracy: 1.0000 - val_loss: 0.1129 - val_accuracy: 0.9884 - lr: 1.0000e-04 - 10s/epoch - 6ms/step
# Epoch 53/60
#
# Epoch 53: val_accuracy did not improve from 0.98842
# 1500/1500 - 10s - loss: 5.3281e-06 - accuracy: 1.0000 - val_loss: 0.1130 - val_accuracy: 0.9883 - lr: 1.0000e-04 - 10s/epoch - 6ms/step
# Epoch 54/60
#
# Epoch 54: val_accuracy did not improve from 0.98842
# 1500/1500 - 11s - loss: 3.0121e-06 - accuracy: 1.0000 - val_loss: 0.1139 - val_accuracy: 0.9884 - lr: 1.0000e-04 - 11s/epoch - 7ms/step
# Epoch 55/60
#
# Epoch 55: val_accuracy improved from 0.98842 to 0.98846, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_3FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 10s - loss: 2.1607e-06 - accuracy: 1.0000 - val_loss: 0.1159 - val_accuracy: 0.9885 - lr: 1.0000e-04 - 10s/epoch - 7ms/step
# Epoch 56/60
#
# Epoch 56: val_accuracy did not improve from 0.98846
# 1500/1500 - 9s - loss: 2.7604e-06 - accuracy: 1.0000 - val_loss: 0.1193 - val_accuracy: 0.9884 - lr: 1.0000e-04 - 9s/epoch - 6ms/step
# Epoch 57/60
#
# Epoch 57: val_accuracy did not improve from 0.98846
# 1500/1500 - 10s - loss: 7.6574e-05 - accuracy: 1.0000 - val_loss: 0.1236 - val_accuracy: 0.9878 - lr: 1.0000e-04 - 10s/epoch - 6ms/step
# Epoch 58/60
#
# Epoch 58: val_accuracy did not improve from 0.98846
# 1500/1500 - 10s - loss: 1.6829e-05 - accuracy: 1.0000 - val_loss: 0.1233 - val_accuracy: 0.9881 - lr: 1.0000e-04 - 10s/epoch - 7ms/step
# Epoch 59/60
#
# Epoch 59: val_accuracy did not improve from 0.98846
# 1500/1500 - 9s - loss: 1.3479e-05 - accuracy: 1.0000 - val_loss: 0.1211 - val_accuracy: 0.9881 - lr: 1.0000e-04 - 9s/epoch - 6ms/step
# Epoch 60/60
#
# Epoch 60: val_accuracy did not improve from 0.98846
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 1500/1500 - 10s - loss: 8.5102e-06 - accuracy: 1.0000 - val_loss: 0.1222 - val_accuracy: 0.9882 - lr: 1.0000e-04 - 10s/epoch - 7ms/step
# Epoch 1/60
#
# Epoch 1: val_accuracy improved from -inf to 0.96567, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 14s - loss: 0.1865 - accuracy: 0.9426 - val_loss: 0.1148 - val_accuracy: 0.9657 - lr: 0.0010 - 14s/epoch - 10ms/step
# Epoch 2/60
#
# Epoch 2: val_accuracy improved from 0.96567 to 0.96931, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 13s - loss: 0.0948 - accuracy: 0.9702 - val_loss: 0.0977 - val_accuracy: 0.9693 - lr: 0.0010 - 13s/epoch - 8ms/step
# Epoch 3/60
#
# Epoch 3: val_accuracy improved from 0.96931 to 0.97544, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 14s - loss: 0.0745 - accuracy: 0.9768 - val_loss: 0.0791 - val_accuracy: 0.9754 - lr: 0.0010 - 14s/epoch - 9ms/step
# Epoch 4/60
#
# Epoch 4: val_accuracy improved from 0.97544 to 0.97623, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 14s - loss: 0.0632 - accuracy: 0.9800 - val_loss: 0.0772 - val_accuracy: 0.9762 - lr: 0.0010 - 14s/epoch - 9ms/step
# Epoch 5/60
#
# Epoch 5: val_accuracy improved from 0.97623 to 0.97865, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 13s - loss: 0.0544 - accuracy: 0.9827 - val_loss: 0.0736 - val_accuracy: 0.9786 - lr: 0.0010 - 13s/epoch - 9ms/step
# Epoch 6/60
#
# Epoch 6: val_accuracy did not improve from 0.97865
# 1500/1500 - 12s - loss: 0.0481 - accuracy: 0.9849 - val_loss: 0.0772 - val_accuracy: 0.9777 - lr: 0.0010 - 12s/epoch - 8ms/step
# Epoch 7/60
#
# Epoch 7: val_accuracy improved from 0.97865 to 0.98190, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 13s - loss: 0.0432 - accuracy: 0.9862 - val_loss: 0.0655 - val_accuracy: 0.9819 - lr: 0.0010 - 13s/epoch - 9ms/step
# Epoch 8/60
#
# Epoch 8: val_accuracy did not improve from 0.98190
# 1500/1500 - 13s - loss: 0.0387 - accuracy: 0.9875 - val_loss: 0.0633 - val_accuracy: 0.9818 - lr: 0.0010 - 13s/epoch - 9ms/step
# Epoch 9/60
#
# Epoch 9: val_accuracy did not improve from 0.98190
# 1500/1500 - 13s - loss: 0.0350 - accuracy: 0.9886 - val_loss: 0.0678 - val_accuracy: 0.9807 - lr: 0.0010 - 13s/epoch - 9ms/step
# Epoch 10/60
#
# Epoch 10: val_accuracy improved from 0.98190 to 0.98275, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 11s - loss: 0.0333 - accuracy: 0.9893 - val_loss: 0.0648 - val_accuracy: 0.9827 - lr: 0.0010 - 11s/epoch - 8ms/step
# Epoch 11/60
#
# Epoch 11: val_accuracy did not improve from 0.98275
# 1500/1500 - 12s - loss: 0.0292 - accuracy: 0.9903 - val_loss: 0.0677 - val_accuracy: 0.9820 - lr: 0.0010 - 12s/epoch - 8ms/step
# Epoch 12/60
#
# Epoch 12: val_accuracy improved from 0.98275 to 0.98379, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 13s - loss: 0.0287 - accuracy: 0.9908 - val_loss: 0.0626 - val_accuracy: 0.9838 - lr: 0.0010 - 13s/epoch - 9ms/step
# Epoch 13/60
#
# Epoch 13: val_accuracy improved from 0.98379 to 0.98423, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 13s - loss: 0.0256 - accuracy: 0.9915 - val_loss: 0.0629 - val_accuracy: 0.9842 - lr: 0.0010 - 13s/epoch - 8ms/step
# Epoch 14/60
#
# Epoch 14: val_accuracy did not improve from 0.98423
# 1500/1500 - 12s - loss: 0.0244 - accuracy: 0.9919 - val_loss: 0.0760 - val_accuracy: 0.9809 - lr: 0.0010 - 12s/epoch - 8ms/step
# Epoch 15/60
#
# Epoch 15: val_accuracy did not improve from 0.98423
# 1500/1500 - 12s - loss: 0.0231 - accuracy: 0.9924 - val_loss: 0.0711 - val_accuracy: 0.9833 - lr: 0.0010 - 12s/epoch - 8ms/step
# Epoch 16/60
#
# Epoch 16: val_accuracy did not improve from 0.98423
# 1500/1500 - 13s - loss: 0.0216 - accuracy: 0.9927 - val_loss: 0.0782 - val_accuracy: 0.9826 - lr: 0.0010 - 13s/epoch - 9ms/step
# Epoch 17/60
#
# Epoch 17: val_accuracy did not improve from 0.98423
# 1500/1500 - 13s - loss: 0.0202 - accuracy: 0.9935 - val_loss: 0.0802 - val_accuracy: 0.9820 - lr: 0.0010 - 13s/epoch - 8ms/step
# Epoch 18/60
#
# Epoch 18: val_accuracy improved from 0.98423 to 0.98481, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 12s - loss: 0.0198 - accuracy: 0.9933 - val_loss: 0.0699 - val_accuracy: 0.9848 - lr: 0.0010 - 12s/epoch - 8ms/step
# Epoch 19/60
#
# Epoch 19: val_accuracy did not improve from 0.98481
# 1500/1500 - 13s - loss: 0.0196 - accuracy: 0.9936 - val_loss: 0.0716 - val_accuracy: 0.9837 - lr: 0.0010 - 13s/epoch - 9ms/step
# Epoch 20/60
#
# Epoch 20: val_accuracy did not improve from 0.98481
# 1500/1500 - 12s - loss: 0.0173 - accuracy: 0.9944 - val_loss: 0.0758 - val_accuracy: 0.9840 - lr: 0.0010 - 12s/epoch - 8ms/step
# Epoch 21/60
#
# Epoch 21: val_accuracy did not improve from 0.98481
# 1500/1500 - 13s - loss: 0.0170 - accuracy: 0.9945 - val_loss: 0.0856 - val_accuracy: 0.9827 - lr: 0.0010 - 13s/epoch - 8ms/step
# Epoch 22/60
#
# Epoch 22: val_accuracy improved from 0.98481 to 0.98513, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 12s - loss: 0.0164 - accuracy: 0.9947 - val_loss: 0.0809 - val_accuracy: 0.9851 - lr: 0.0010 - 12s/epoch - 8ms/step
# Epoch 23/60
#
# Epoch 23: val_accuracy did not improve from 0.98513
# 1500/1500 - 13s - loss: 0.0162 - accuracy: 0.9948 - val_loss: 0.0946 - val_accuracy: 0.9803 - lr: 0.0010 - 13s/epoch - 9ms/step
# Epoch 24/60
#
# Epoch 24: val_accuracy did not improve from 0.98513
# 1500/1500 - 15s - loss: 0.0157 - accuracy: 0.9948 - val_loss: 0.0970 - val_accuracy: 0.9821 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 25/60
#
# Epoch 25: val_accuracy did not improve from 0.98513
# 1500/1500 - 16s - loss: 0.0165 - accuracy: 0.9948 - val_loss: 0.0847 - val_accuracy: 0.9828 - lr: 0.0010 - 16s/epoch - 10ms/step
# Epoch 26/60
#
# Epoch 26: val_accuracy did not improve from 0.98513
# 1500/1500 - 14s - loss: 0.0146 - accuracy: 0.9953 - val_loss: 0.0739 - val_accuracy: 0.9848 - lr: 0.0010 - 14s/epoch - 10ms/step
# Epoch 27/60
#
# Epoch 27: val_accuracy did not improve from 0.98513
# 1500/1500 - 13s - loss: 0.0134 - accuracy: 0.9957 - val_loss: 0.0842 - val_accuracy: 0.9841 - lr: 0.0010 - 13s/epoch - 8ms/step
# Epoch 28/60
#
# Epoch 28: val_accuracy did not improve from 0.98513
# 1500/1500 - 13s - loss: 0.0141 - accuracy: 0.9955 - val_loss: 0.0900 - val_accuracy: 0.9829 - lr: 0.0010 - 13s/epoch - 9ms/step
# Epoch 29/60
#
# Epoch 29: val_accuracy did not improve from 0.98513
# 1500/1500 - 13s - loss: 0.0140 - accuracy: 0.9955 - val_loss: 0.0802 - val_accuracy: 0.9848 - lr: 0.0010 - 13s/epoch - 9ms/step
# Epoch 30/60
#
# Epoch 30: val_accuracy did not improve from 0.98513
# 1500/1500 - 13s - loss: 0.0137 - accuracy: 0.9956 - val_loss: 0.0945 - val_accuracy: 0.9833 - lr: 0.0010 - 13s/epoch - 8ms/step
# Epoch 31/60
#
# Epoch 31: val_accuracy did not improve from 0.98513
# 1500/1500 - 12s - loss: 0.0134 - accuracy: 0.9958 - val_loss: 0.0936 - val_accuracy: 0.9836 - lr: 0.0010 - 12s/epoch - 8ms/step
# Epoch 32/60
#
# Epoch 32: val_accuracy did not improve from 0.98513
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 1500/1500 - 14s - loss: 0.0132 - accuracy: 0.9959 - val_loss: 0.0900 - val_accuracy: 0.9850 - lr: 0.0010 - 14s/epoch - 9ms/step
# Epoch 33/60
#
# Epoch 33: val_accuracy improved from 0.98513 to 0.98735, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 13s - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.0786 - val_accuracy: 0.9874 - lr: 1.0000e-04 - 13s/epoch - 9ms/step
# Epoch 34/60
#
# Epoch 34: val_accuracy improved from 0.98735 to 0.98756, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 12s - loss: 9.9450e-04 - accuracy: 0.9997 - val_loss: 0.0820 - val_accuracy: 0.9876 - lr: 1.0000e-04 - 12s/epoch - 8ms/step
# Epoch 35/60
#
# Epoch 35: val_accuracy improved from 0.98756 to 0.98773, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 11s - loss: 6.2251e-04 - accuracy: 0.9999 - val_loss: 0.0850 - val_accuracy: 0.9877 - lr: 1.0000e-04 - 11s/epoch - 7ms/step
# Epoch 36/60
#
# Epoch 36: val_accuracy improved from 0.98773 to 0.98785, saving model to _OA_results_eMnist_Digits_train_with_val/2130/Entanglement_pool_padded_0s/run_4FC/Entanglement_pool_padded_0s_2130model.keras
# 1500/1500 - 11s - loss: 4.0981e-04 - accuracy: 0.9999 - val_loss: 0.0893 - val_accuracy: 0.9879 - lr: 1.0000e-04 - 11s/epoch - 8ms/step
# Epoch 37/60
#
# Epoch 37: val_accuracy did not improve from 0.98785
# ...
# Epoch 55/60
#
# Epoch 55: val_accuracy did not improve from 0.97671
# 1500/1500 - 14s - loss: 0.0023 - accuracy: 0.9998 - val_loss: 0.1162 - val_accuracy: 0.9766 - lr: 1.0000e-05 - 14s/epoch - 9ms/step
# Epoch 56/60
#
# Epoch 56: val_accuracy did not improve from 0.97671
# 1500/1500 - 14s - loss: 0.0023 - accuracy: 0.9998 - val_loss: 0.1165 - val_accuracy: 0.9764 - lr: 1.0000e-05 - 14s/epoch - 9ms/step
# Epoch 57/60
#
# Epoch 57: val_accuracy did not improve from 0.97671
# 1500/1500 - 14s - loss: 0.0023 - accuracy: 0.9998 - val_loss: 0.1164 - val_accuracy: 0.9766 - lr: 1.0000e-05 - 14s/epoch - 9ms/step
# Epoch 58/60
#
# Epoch 58: val_accuracy did not improve from 0.97671
# 1500/1500 - 14s - loss: 0.0023 - accuracy: 0.9998 - val_loss: 0.1167 - val_accuracy: 0.9767 - lr: 1.0000e-05 - 14s/epoch - 9ms/step
# Epoch 59/60
#
# Epoch 59: val_accuracy did not improve from 0.97671
#
# Epoch 59: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 1500/1500 - 14s - loss: 0.0022 - accuracy: 0.9998 - val_loss: 0.1171 - val_accuracy: 0.9765 - lr: 1.0000e-05 - 14s/epoch - 9ms/step
# Epoch 60/60
#
# Epoch 60: val_accuracy did not improve from 0.97671
# 1500/1500 - 14s - loss: 0.0021 - accuracy: 0.9998 - val_loss: 0.1170 - val_accuracy: 0.9765 - lr: 1.0000e-06 - 14s/epoch - 9ms/step
# Epoch 1/60
#
# Epoch 1: val_accuracy improved from -inf to 0.93313, saving model to _OA_results_eMnist_Digits_train_with_val/2013/Entanglement_pool_summed/run_4FC/Entanglement_pool_summed_2013model.keras
# 1500/1500 - 16s - loss: 0.3807 - accuracy: 0.8800 - val_loss: 0.2136 - val_accuracy: 0.9331 - lr: 0.0010 - 16s/epoch - 11ms/step
# Epoch 2/60
#
# Epoch 2: val_accuracy improved from 0.93313 to 0.94288, saving model to _OA_results_eMnist_Digits_train_with_val/2013/Entanglement_pool_summed/run_4FC/Entanglement_pool_summed_2013model.keras
# 1500/1500 - 15s - loss: 0.2004 - accuracy: 0.9373 - val_loss: 0.1796 - val_accuracy: 0.9429 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 3/60
#
# Epoch 3: val_accuracy did not improve from 0.94288
# 1500/1500 - 15s - loss: 0.1641 - accuracy: 0.9479 - val_loss: 0.1803 - val_accuracy: 0.9428 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 4/60
#
# Epoch 4: val_accuracy improved from 0.94288 to 0.95388, saving model to _OA_results_eMnist_Digits_train_with_val/2013/Entanglement_pool_summed/run_4FC/Entanglement_pool_summed_2013model.keras
# 1500/1500 - 15s - loss: 0.1419 - accuracy: 0.9546 - val_loss: 0.1466 - val_accuracy: 0.9539 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 5/60
#
# Epoch 5: val_accuracy improved from 0.95388 to 0.96023, saving model to _OA_results_eMnist_Digits_train_with_val/2013/Entanglement_pool_summed/run_4FC/Entanglement_pool_summed_2013model.keras
# 1500/1500 - 15s - loss: 0.1274 - accuracy: 0.9591 - val_loss: 0.1272 - val_accuracy: 0.9602 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 6/60
#
# Epoch 6: val_accuracy did not improve from 0.96023
# 1500/1500 - 15s - loss: 0.1170 - accuracy: 0.9623 - val_loss: 0.1306 - val_accuracy: 0.9600 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 7/60
#
# Epoch 7: val_accuracy improved from 0.96023 to 0.96258, saving model to _OA_results_eMnist_Digits_train_with_val/2013/Entanglement_pool_summed/run_4FC/Entanglement_pool_summed_2013model.keras
# 1500/1500 - 15s - loss: 0.1063 - accuracy: 0.9659 - val_loss: 0.1194 - val_accuracy: 0.9626 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 8/60
#
# Epoch 8: val_accuracy did not improve from 0.96258
# 1500/1500 - 15s - loss: 0.0991 - accuracy: 0.9680 - val_loss: 0.1264 - val_accuracy: 0.9610 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 9/60
#
# Epoch 9: val_accuracy did not improve from 0.96258
# 1500/1500 - 15s - loss: 0.0936 - accuracy: 0.9691 - val_loss: 0.1342 - val_accuracy: 0.9576 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 10/60
#
# Epoch 10: val_accuracy improved from 0.96258 to 0.96648, saving model to _OA_results_eMnist_Digits_train_with_val/2013/Entanglement_pool_summed/run_4FC/Entanglement_pool_summed_2013model.keras
# 1500/1500 - 15s - loss: 0.0857 - accuracy: 0.9720 - val_loss: 0.1115 - val_accuracy: 0.9665 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 11/60
#
# Epoch 11: val_accuracy did not improve from 0.96648
# 1500/1500 - 15s - loss: 0.0810 - accuracy: 0.9732 - val_loss: 0.1157 - val_accuracy: 0.9643 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 12/60
#
# Epoch 12: val_accuracy improved from 0.96648 to 0.96688, saving model to _OA_results_eMnist_Digits_train_with_val/2013/Entanglement_pool_summed/run_4FC/Entanglement_pool_summed_2013model.keras
# 1500/1500 - 15s - loss: 0.0772 - accuracy: 0.9747 - val_loss: 0.1094 - val_accuracy: 0.9669 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 13/60
#
# Epoch 13: val_accuracy improved from 0.96688 to 0.96712, saving model to _OA_results_eMnist_Digits_train_with_val/2013/Entanglement_pool_summed/run_4FC/Entanglement_pool_summed_2013model.keras
# 1500/1500 - 15s - loss: 0.0717 - accuracy: 0.9763 - val_loss: 0.1102 - val_accuracy: 0.9671 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 14/60
#
# Epoch 14: val_accuracy improved from 0.96712 to 0.96733, saving model to _OA_results_eMnist_Digits_train_with_val/2013/Entanglement_pool_summed/run_4FC/Entanglement_pool_summed_2013model.keras
# 1500/1500 - 15s - loss: 0.0677 - accuracy: 0.9771 - val_loss: 0.1114 - val_accuracy: 0.9673 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 15/60
#
# Epoch 15: val_accuracy improved from 0.96733 to 0.96794, saving model to _OA_results_eMnist_Digits_train_with_val/2013/Entanglement_pool_summed/run_4FC/Entanglement_pool_summed_2013model.keras
# 1500/1500 - 15s - loss: 0.0664 - accuracy: 0.9779 - val_loss: 0.1061 - val_accuracy: 0.9679 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 16/60
#
# Epoch 16: val_accuracy improved from 0.96794 to 0.96869, saving model to _OA_results_eMnist_Digits_train_with_val/2013/Entanglement_pool_summed/run_4FC/Entanglement_pool_summed_2013model.keras
# 1500/1500 - 15s - loss: 0.0607 - accuracy: 0.9797 - val_loss: 0.1110 - val_accuracy: 0.9687 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 17/60
#
# Epoch 17: val_accuracy did not improve from 0.96869
# 1500/1500 - 15s - loss: 0.0590 - accuracy: 0.9803 - val_loss: 0.1138 - val_accuracy: 0.9673 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 18/60
#
# Epoch 18: val_accuracy improved from 0.96869 to 0.96940, saving model to _OA_results_eMnist_Digits_train_with_val/2013/Entanglement_pool_summed/run_4FC/Entanglement_pool_summed_2013model.keras
# 1500/1500 - 15s - loss: 0.0563 - accuracy: 0.9805 - val_loss: 0.1101 - val_accuracy: 0.9694 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 19/60
#
# Epoch 19: val_accuracy did not improve from 0.96940
# 1500/1500 - 15s - loss: 0.0534 - accuracy: 0.9822 - val_loss: 0.1155 - val_accuracy: 0.9686 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 20/60
#
# Epoch 20: val_accuracy did not improve from 0.96940
# 1500/1500 - 15s - loss: 0.0509 - accuracy: 0.9827 - val_loss: 0.1338 - val_accuracy: 0.9635 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 21/60
#
# Epoch 21: val_accuracy improved from 0.96940 to 0.97035, saving model to _OA_results_eMnist_Digits_train_with_val/2013/Entanglement_pool_summed/run_4FC/Entanglement_pool_summed_2013model.keras
# 1500/1500 - 15s - loss: 0.0487 - accuracy: 0.9838 - val_loss: 0.1127 - val_accuracy: 0.9704 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 22/60
#
# Epoch 22: val_accuracy did not improve from 0.97035
# 1500/1500 - 15s - loss: 0.0457 - accuracy: 0.9844 - val_loss: 0.1210 - val_accuracy: 0.9678 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 23/60
#
# Epoch 23: val_accuracy did not improve from 0.97035
# 1500/1500 - 15s - loss: 0.0470 - accuracy: 0.9838 - val_loss: 0.1184 - val_accuracy: 0.9678 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 24/60
#
# Epoch 24: val_accuracy did not improve from 0.97035
# 1500/1500 - 15s - loss: 0.0447 - accuracy: 0.9847 - val_loss: 0.1156 - val_accuracy: 0.9699 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 25/60
#
# Epoch 25: val_accuracy improved from 0.97035 to 0.97083, saving model to _OA_results_eMnist_Digits_train_with_val/2013/Entanglement_pool_summed/run_4FC/Entanglement_pool_summed_2013model.keras
# 1500/1500 - 15s - loss: 0.0417 - accuracy: 0.9856 - val_loss: 0.1189 - val_accuracy: 0.9708 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 26/60
#
# Epoch 26: val_accuracy did not improve from 0.97083
# 1500/1500 - 15s - loss: 0.0411 - accuracy: 0.9861 - val_loss: 0.1228 - val_accuracy: 0.9697 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 27/60
#
# Epoch 27: val_accuracy did not improve from 0.97083
# 1500/1500 - 15s - loss: 0.0381 - accuracy: 0.9869 - val_loss: 0.1299 - val_accuracy: 0.9681 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 28/60
#
# Epoch 28: val_accuracy did not improve from 0.97083
# 1500/1500 - 15s - loss: 0.0379 - accuracy: 0.9870 - val_loss: 0.1266 - val_accuracy: 0.9691 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 29/60
#
# Epoch 29: val_accuracy did not improve from 0.97083
# 1500/1500 - 15s - loss: 0.0365 - accuracy: 0.9872 - val_loss: 0.1346 - val_accuracy: 0.9680 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 30/60
#
# Epoch 30: val_accuracy did not improve from 0.97083
# 1500/1500 - 15s - loss: 0.0368 - accuracy: 0.9872 - val_loss: 0.1286 - val_accuracy: 0.9692 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 31/60
#
# Epoch 31: val_accuracy did not improve from 0.97083
# 1500/1500 - 15s - loss: 0.0333 - accuracy: 0.9884 - val_loss: 0.1315 - val_accuracy: 0.9704 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 32/60
#
# Epoch 32: val_accuracy did not improve from 0.97083
# 1500/1500 - 15s - loss: 0.0331 - accuracy: 0.9884 - val_loss: 0.1378 - val_accuracy: 0.9696 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 33/60
#
# Epoch 33: val_accuracy did not improve from 0.97083
# 1500/1500 - 15s - loss: 0.0317 - accuracy: 0.9893 - val_loss: 0.1472 - val_accuracy: 0.9677 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 34/60
#
# Epoch 34: val_accuracy did not improve from 0.97083
# 1500/1500 - 15s - loss: 0.0328 - accuracy: 0.9886 - val_loss: 0.1389 - val_accuracy: 0.9706 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 35/60
#
# Epoch 35: val_accuracy did not improve from 0.97083
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 1500/1500 - 15s - loss: 0.0314 - accuracy: 0.9892 - val_loss: 0.1324 - val_accuracy: 0.9702 - lr: 0.0010 - 15s/epoch - 10ms/step
# Epoch 36/60
#
# Epoch 36: val_accuracy improved from 0.97083 to 0.97633, saving model to _OA_results_eMnist_Digits_train_with_val/2013/Entanglement_pool_summed/run_4FC/Entanglement_pool_summed_2013model.keras
# 1500/1500 - 15s - loss: 0.0090 - accuracy: 0.9972 - val_loss: 0.1164 - val_accuracy: 0.9763 - lr: 1.0000e-04 - 15s/epoch - 10ms/step
# Epoch 37/60
#
# Epoch 37: val_accuracy did not improve from 0.97633
# 1500/1500 - 15s - loss: 0.0054 - accuracy: 0.9985 - val_loss: 0.1185 - val_accuracy: 0.9762 - lr: 1.0000e-04 - 15s/epoch - 10ms/step
# Epoch 38/60
#
# Epoch 38: val_accuracy improved from 0.97633 to 0.97656, saving model to _OA_results_eMnist_Digits_train_with_val/2013/Entanglement_pool_summed/run_4FC/Entanglement_pool_summed_2013model.keras
# 1500/1500 - 15s - loss: 0.0044 - accuracy: 0.9990 - val_loss: 0.1224 - val_accuracy: 0.9766 - lr: 1.0000e-04 - 15s/epoch - 10ms/step
# Epoch 39/60
#
# Epoch 39: val_accuracy improved from 0.97656 to 0.97677, saving model to _OA_results_eMnist_Digits_train_with_val/2013/Entanglement_pool_summed/run_4FC/Entanglement_pool_summed_2013model.keras
# 1500/1500 - 15s - loss: 0.0036 - accuracy: 0.9992 - val_loss: 0.1250 - val_accuracy: 0.9768 - lr: 1.0000e-04 - 15s/epoch - 10ms/step
# Epoch 40/60
#
# Epoch 40: val_accuracy did not improve from 0.97677
# 1500/1500 - 15s - loss: 0.0031 - accuracy: 0.9993 - val_loss: 0.1295 - val_accuracy: 0.9764 - lr: 1.0000e-04 - 15s/epoch - 10ms/step
# Epoch 41/60
#
# Epoch 41: val_accuracy did not improve from 0.97677
# 1500/1500 - 15s - loss: 0.0026 - accuracy: 0.9996 - val_loss: 0.1336 - val_accuracy: 0.9765 - lr: 1.0000e-04 - 15s/epoch - 10ms/step
# Epoch 42/60
#
# Epoch 42: val_accuracy did not improve from 0.97677
# 1500/1500 - 15s - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.1363 - val_accuracy: 0.9763 - lr: 1.0000e-04 - 15s/epoch - 10ms/step
# Epoch 43/60
#
# Epoch 43: val_accuracy did not improve from 0.97677
# 1500/1500 - 15s - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.1405 - val_accuracy: 0.9766 - lr: 1.0000e-04 - 15s/epoch - 10ms/step
# Epoch 44/60
#
# Epoch 44: val_accuracy improved from 0.97677 to 0.97690, saving model to _OA_results_eMnist_Digits_train_with_val/2013/Entanglement_pool_summed/run_4FC/Entanglement_pool_summed_2013model.keras
# 1500/1500 - 15s - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.1421 - val_accuracy: 0.9769 - lr: 1.0000e-04 - 15s/epoch - 10ms/step
# Epoch 45/60
#
# Epoch 45: val_accuracy did not improve from 0.97690
# 1500/1500 - 15s - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.1499 - val_accuracy: 0.9765 - lr: 1.0000e-04 - 15s/epoch - 10ms/step
# Epoch 46/60
#
# Epoch 46: val_accuracy improved from 0.97690 to 0.97715, saving model to _OA_results_eMnist_Digits_train_with_val/2013/Entanglement_pool_summed/run_4FC/Entanglement_pool_summed_2013model.keras
# 1500/1500 - 15s - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.1500 - val_accuracy: 0.9771 - lr: 1.0000e-04 - 15s/epoch - 10ms/step
# Epoch 47/60
#
# Epoch 47: val_accuracy did not improve from 0.97715
# 1500/1500 - 15s - loss: 9.6352e-04 - accuracy: 0.9999 - val_loss: 0.1567 - val_accuracy: 0.9765 - lr: 1.0000e-04 - 15s/epoch - 10ms/step
# Epoch 48/60
#
# Epoch 48: val_accuracy did not improve from 0.97715
# 1500/1500 - 15s - loss: 8.9924e-04 - accuracy: 0.9999 - val_loss: 0.1579 - val_accuracy: 0.9766 - lr: 1.0000e-04 - 15s/epoch - 10ms/step
# Epoch 49/60
#
# Epoch 49: val_accuracy did not improve from 0.97715
# 1500/1500 - 15s - loss: 8.8163e-04 - accuracy: 0.9999 - val_loss: 0.1632 - val_accuracy: 0.9762 - lr: 1.0000e-04 - 15s/epoch - 10ms/step
# Epoch 50/60
#
# Epoch 50: val_accuracy did not improve from 0.97715
# 1500/1500 - 15s - loss: 6.9444e-04 - accuracy: 0.9999 - val_loss: 0.1671 - val_accuracy: 0.9765 - lr: 1.0000e-04 - 15s/epoch - 10ms/step
# Epoch 51/60
#
# Epoch 51: val_accuracy did not improve from 0.97715
# 1500/1500 - 15s - loss: 6.9664e-04 - accuracy: 0.9999 - val_loss: 0.1731 - val_accuracy: 0.9763 - lr: 1.0000e-04 - 15s/epoch - 10ms/step
# Epoch 52/60
#
# Epoch 52: val_accuracy did not improve from 0.97715
# 1500/1500 - 15s - loss: 5.3794e-04 - accuracy: 0.9999 - val_loss: 0.1743 - val_accuracy: 0.9767 - lr: 1.0000e-04 - 15s/epoch - 10ms/step
# Epoch 53/60
#
# Epoch 53: val_accuracy did not improve from 0.97715
# 1500/1500 - 15s - loss: 5.9688e-04 - accuracy: 0.9999 - val_loss: 0.1735 - val_accuracy: 0.9760 - lr: 1.0000e-04 - 15s/epoch - 10ms/step
# Epoch 54/60
#
# Epoch 54: val_accuracy did not improve from 0.97715
# 1500/1500 - 15s - loss: 3.5822e-04 - accuracy: 1.0000 - val_loss: 0.1799 - val_accuracy: 0.9759 - lr: 1.0000e-04 - 15s/epoch - 10ms/step
# Epoch 55/60
#
# Epoch 55: val_accuracy did not improve from 0.97715
# 1500/1500 - 15s - loss: 4.4618e-04 - accuracy: 0.9999 - val_loss: 0.1838 - val_accuracy: 0.9759 - lr: 1.0000e-04 - 15s/epoch - 10ms/step
# Epoch 56/60
#
# Epoch 56: val_accuracy did not improve from 0.97715
#
# Epoch 56: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 1500/1500 - 15s - loss: 4.7484e-04 - accuracy: 0.9999 - val_loss: 0.1816 - val_accuracy: 0.9769 - lr: 1.0000e-04 - 15s/epoch - 10ms/step
# Epoch 57/60
#
# Epoch 57: val_accuracy did not improve from 0.97715
# 1500/1500 - 15s - loss: 1.6392e-04 - accuracy: 1.0000 - val_loss: 0.1809 - val_accuracy: 0.9770 - lr: 1.0000e-05 - 15s/epoch - 10ms/step
# Epoch 58/60
#
# Epoch 58: val_accuracy did not improve from 0.97715
# 1500/1500 - 15s - loss: 1.5044e-04 - accuracy: 1.0000 - val_loss: 0.1817 - val_accuracy: 0.9769 - lr: 1.0000e-05 - 15s/epoch - 10ms/step
# Epoch 59/60
#
# Epoch 59: val_accuracy did not improve from 0.97715
# 1500/1500 - 15s - loss: 1.4164e-04 - accuracy: 1.0000 - val_loss: 0.1833 - val_accuracy: 0.9769 - lr: 1.0000e-05 - 15s/epoch - 10ms/step
# Epoch 60/60
#
# Epoch 60: val_accuracy did not improve from 0.97715
# 1500/1500 - 15s - loss: 1.3519e-04 - accuracy: 1.0000 - val_loss: 0.1838 - val_accuracy: 0.9770 - lr: 1.0000e-05 - 15s/epoch - 10ms/step
