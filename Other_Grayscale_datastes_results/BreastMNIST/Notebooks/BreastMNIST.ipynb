# %% [markdown]
# ## Imports

# %%
# importing sys
import sys
# This is how you import modules that exist outside of working directory 
# adding mosaique to the system path
sys.path.insert(1, '/workspaces/QML-QPF/mosaiQue') 

import mosaique as mq
import scipy
from concurrent.futures import ProcessPoolExecutor, as_completed
import itertools
import numpy as np
import pennylane as qml
import os
from mosaique.models.operation import OperationLayer
from tensorflow import keras
import tensorflow as tf

# %%
# if the below cell raise this error [ModuleNotFoundError: No module named 'tensorrt']
# uncomment and run the next line, then restart the kernel 
# pip install tensorrt

# %% [markdown]
# ## Check GPU installation is working

# %%
import tensorrt as trt

print(f' tensorflow version {tf.__version__}')

print(f' tensorrt version {trt.__version__}')

print(tf.config.list_physical_devices('GPU'))

# %%
# Set the environment for asynchronous GPU usage
os.environ['TF_GPU_ALLOCATOR'] = 'cuda_malloc_async'

# %%
def operation():
    dev = qml.device("default.qubit.tf", wires=4)
    @qml.qnode(dev, interface='tf')
    def cnot(inputs):
        inputs = inputs * np.pi
        qml.AngleEmbedding(inputs[:,...], wires=range(4), rotation='Y')

        qml.CNOT(wires=[0, 1])
        qml.CNOT(wires=[2, 3])

        # Measurement producing 4 classical output values
        return [qml.expval(qml.PauliZ(j)) for j in range(4)]
    return cnot

# %%
def preset():
    # Import the images
    from medmnist import BreastMNIST
    # size of the images 
    size = 28
    # we'll run the code for 64 to see if we'll get different results
    train_data = BreastMNIST(split="train", download=True,size=size)
    test_data = BreastMNIST(split="test", download=True,size=size)
    # name of the folder where will save the filtered images for training
    
    # name of the folder where will save the filtered images for training
    tr_layer = mq.ConvolutionLayer4x4("_OA_results_BreastMNIST_train_with_val")
    # name of the folder where will save the filtered images for testing
    te_layer = mq.ConvolutionLayer4x4("_OA_results_BreastMNIST_test_with_val")
    
    
        
    #load the data set want to train
    (tr_images, tr_labels), (te_images, te_labels) = (train_data.imgs, train_data.labels), (test_data.imgs, test_data.labels)
    

    tr_layer.fit(tr_images)
    te_layer.fit(te_images)
    tr_images = tr_layer.transform(tr_images)
    te_images = te_layer.transform(te_images)
    return ((tr_layer, (tr_images, tr_labels)), (te_layer,(te_images, te_labels)))

with ProcessPoolExecutor() as executor:
    future = executor.submit(preset)

((train_layer, (train_images, train_labels)), (test_layer,(test_images, test_labels))) = future.result() #This blocks until the task completes

# %%
test_images.shape
# Out:
# (156, 196, 4)

# %%
permutations = np.asarray(list(itertools.permutations(range(4))))


def pool(x, call, p, l):
    op = OperationLayer(call())
    predict = l.post_transform(op.pre_op.predict(x,batch_size=1000))
    l.save(predict, p)

# %%
# # not using PorcessPoolExecutor

# for p in permutations:
#     pool(train_images[:,:,p],)

# %%
for j in range(3):
    with ProcessPoolExecutor(8) as executor:
        runner = {
            executor.submit(pool, x=train_images[:,:,p], call=operation, p=p, l=train_layer): p for p in permutations[8*j:8*(j+1)]
        }
        for future in as_completed(runner):
            runner.pop(future)
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step

# %%
for j in range(3):
    with ProcessPoolExecutor(8) as executor:
        runner = {
            executor.submit(pool, x=test_images[:,:,p], call=operation, p=p, l=test_layer): p for p in permutations[8*j:8*(j+1)]
        }
        for future in as_completed(runner):
            runner.pop(future)
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step

# %%
from keras.callbacks import CSVLogger, EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# change the subfolder name to save your data in different location based on what NN model you used
# it's a convenient way to avoid losing your training data of each model
# Here are some preset examples you can use
# 1 FC layer
# run_subfolder = "_1FC"
# run_subfolder = "_2nodes_2FC"
# # 2 FC layer
# run_subfolder = "_2FC"
# # 3 FC layer
run_subfolder = "_3FC"
# # 4 FC layer
# run_subfolder = "_4FC"
# early stopping epochs -- good practice between 10-20
patience = 15
def run(tr_images, label):
    log_dir = train_layer.name + "/run" + run_subfolder +  "/"
    log_dir += str(patience) +  "/"
    # print(' log_dir ', log_dir)
    log_file =  log_dir + label
    # print(' log_file ', log_file)
    os.makedirs(log_dir, exist_ok=True)
    
    csv_logger = CSVLogger(log_file)
    
    
    # tensorboard_callback = keras.callbacks.TensorBoard(
    #     log_dir=log_file,
    #     histogram_freq=1,
    #     write_graph=True,
    #     write_images=True,
    #     write_steps_per_second=True,
    #     update_freq='batch',
    #     profile_batch=1,
    #     embeddings_freq=1,
    #     embeddings_metadata=None
    # )
    
    number_of_classes = len(np.unique(test_labels))
    # Chose which model you want to use depending on the number of hidden layers
    # Uncomment the your model and run the code--pay attention to your folder/file naming to keep everything organized 
    ####---------------------------------------------------------------------####
    
    # # simple ANN model with 0 hidden layers: 1FC
    # q_model = keras.models.Sequential([
    #     keras.layers.Rescaling(scale=-1. / 127.5, offset=1),
    #     keras.layers.Flatten(),
    #     keras.layers.Dense(number_of_classes, activation="softmax")
    # ])
    
    ####---------------------------------------------------------------------####
    
    # # simple ANN model with 1 hidden layers: 2FC
    # q_model = keras.models.Sequential([
    #     keras.layers.Rescaling(scale=-1. / 127.5, offset=1),
    #     keras.layers.Flatten(),
    #     keras.layers.Dense(512, activation='relu'),
    #     keras.layers.Dense(number_of_classes, activation="softmax")
    # ])
    
    ####---------------------------------------------------------------------####
    
    # simple ANN model with 2 hidden layers: 3FC
    q_model = keras.models.Sequential([
        keras.layers.Rescaling(scale=-1. / 127.5, offset=1),
        keras.layers.Flatten(),
        keras.layers.Dense(512, activation='relu'),
        keras.layers.Dense(256, activation='relu'),
        keras.layers.Dense(number_of_classes, activation='softmax')
    ])
    
    ####---------------------------------------------------------------------####
    
    # # simple ANN model with 3 hidden layers: 4FC
    # q_model = keras.models.Sequential([
    #     keras.layers.Rescaling(scale=-1. / 127.5, offset=1),
    #     keras.layers.Flatten(),
    #     keras.layers.Dense(512, activation='relu'),
    #     keras.layers.Dense(256, activation='relu'),
    #     keras.layers.Dense(128, activation='relu'),
    #     keras.layers.Dense(number_of_classes, activation='softmax')
    # ])
    
    ####---------------------------------------------------------------------####
    
    q_model.compile(
        optimizer='adam',
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    
    # 
    batch_size = 128
    epochs = 60
    
    
    # Stop training when a monitored metric has stopped improving.
    Early_stop = EarlyStopping(monitor="val_accuracy",
                                min_delta=0, # Minimum change in the monitored quantity to qualify as an improvement, i.e. an absolute change of less than min_delta, will count as no improvement.
                                patience=patience, # Number of epochs with no improvement after which training will be stopped.
                                verbose=1, # 1 displays messages when the callback takes an action
                                mode="max", # will stop when the quantity monitored has stopped increasing
                                baseline=None,
                                restore_best_weights=True, # to restore model weights from the epoch with the best value of the monitored quantity
                                start_from_epoch=0, #  Number of epochs to wait before starting to monitor improvement.
                            )

    
    # Callback to save the Keras model or model weights at some frequency.
    checkpoint_filepath = log_file  + 'model.keras'
    model_checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath,
                                                monitor='val_accuracy',
                                                mode='max',
                                                verbose=1,
                                                save_best_only=True
                                                )
    # Reduce learning rate when a metric has stopped improving.
    reduce_lr_acc = ReduceLROnPlateau(monitor='val_accuracy',
                                        factor=0.1, # Float. Factor by which the learning rate will be reduced. new_lr = lr * factor.
                                        patience=10, # Integer. Number of epochs with no improvement after which learning rate will be reduced.
                                        verbose=1, # 1: update messages.
                                        mode="max", # 'max' mode it will be reduced when the quantity monitored has stopped increasing
                                        min_delta=0.0001, # Float. Threshold for measuring the new optimum, to only focus on significant changes.
                                        cooldown=0, #  Integer. Number of epochs to wait before resuming normal operation after the learning rate has been reduced.
                                        min_lr=0.0 #  Float. Lower bound on the learning rate.
                                    )


    
    q_history = q_model.fit(
        tr_images,
        train_labels,
        # validation_data=(te_images, test_labels),
        validation_split=0.2,
        batch_size=batch_size,
        epochs=epochs,
        verbose=2,
        # callbacks=[tensorboard_callback]
        callbacks = [Early_stop,csv_logger,model_checkpoint_callback, reduce_lr_acc]
    )

def model(variant, tr_layer):
    tr_images = tr_layer.open(variant)
    # te_images =  te_layer.open(variant)

    label = ''.join(map(str,variant))

    run(tr_images, label)

# %%
from matplotlib import pyplot as plt

# print(test_layer.open([0,1,3,2]).shape)

# post = test_layer.open([0,1,3,2])

# _min, _max = np.amin(post), np.amax(post)
# fig, axes = plt.subplots(1, 4, figsize=(16, 4))

# # Plot all output channels for quantum cnot
# for c in range(4):
#     axes[c].imshow(post[0,:,:,c],vmin = _min, vmax = _max)
    
post = train_layer.open([1,2,3,0])
post1 = train_layer.open([2,3,0,1])


_min, _max = np.amin(post), np.amax(post)
_min1, _max1 = np.amin(post1), np.amax(post1)
fig, axes = plt.subplots(2, 4, figsize=(16, 4))

# Plot all output channels for quantum cnot
for c in range(4):
    axes[0,c].imshow(post[0,:,:,c],vmin = _min, vmax = _max)
    axes[1,c].imshow(post1[0,:,:,c],vmin = _min1, vmax = _max1)

# %%
for j in range(3):
    with ProcessPoolExecutor(8) as executor:
        runner = {
            executor.submit(model,variant = p, tr_layer = train_layer): p for p in permutations[8*j:8*(j+1)]
        }
        for future in as_completed(runner):
            runner.pop(future)
# Out:
# Epoch 1/60
# Epoch 1/60
# Epoch 1/60
# Epoch 1/60
# Epoch 1/60
# Epoch 1/60
# Epoch 1/60
# Epoch 1/60
#
# Epoch 1: val_accuracy improved from -inf to 0.74545, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/0213model.keras
#
# Epoch 1: val_accuracy improved from -inf to 0.71818, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/0231model.keras
#
# Epoch 1: val_accuracy improved from -inf to 0.68182, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/0321model.keras
#
# Epoch 1: val_accuracy improved from -inf to 0.72727, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/0132model.keras
# 4/4 - 1s - loss: 0.7308 - accuracy: 0.5528 - val_loss: 0.6045 - val_accuracy: 0.7455 - lr: 0.0010 - 874ms/epoch - 218ms/step
# Epoch 2/60
#
# Epoch 1: val_accuracy improved from -inf to 0.73636, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/1023model.keras
# 4/4 - 1s - loss: 0.6597 - accuracy: 0.6628 - val_loss: 0.6483 - val_accuracy: 0.6818 - lr: 0.0010 - 875ms/epoch - 219ms/step
# Epoch 2/60
#
# Epoch 1: val_accuracy improved from -inf to 0.71818, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/0312model.keras
# 4/4 - 1s - loss: 0.6729 - accuracy: 0.6239 - val_loss: 0.6739 - val_accuracy: 0.7182 - lr: 0.0010 - 861ms/epoch - 215ms/step
# 4/4 - 1s - loss: 0.7757 - accuracy: 0.5436 - val_loss: 0.6750 - val_accuracy: 0.7273 - lr: 0.0010 - 863ms/epoch - 216ms/step
# Epoch 2/60
# Epoch 2/60
#
# Epoch 1: val_accuracy improved from -inf to 0.73636, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/1032model.keras
# 4/4 - 1s - loss: 0.6809 - accuracy: 0.6904 - val_loss: 0.6053 - val_accuracy: 0.7364 - lr: 0.0010 - 877ms/epoch - 219ms/step
#
# Epoch 1: val_accuracy improved from -inf to 0.69091, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/0123model.keras
# Epoch 2/60
#
# Epoch 2: val_accuracy did not improve from 0.74545
# 4/4 - 1s - loss: 0.7489 - accuracy: 0.5390 - val_loss: 0.6737 - val_accuracy: 0.7182 - lr: 0.0010 - 897ms/epoch - 224ms/step
# 4/4 - 0s - loss: 0.6447 - accuracy: 0.7202 - val_loss: 0.5786 - val_accuracy: 0.7364 - lr: 0.0010 - 50ms/epoch - 13ms/step
# Epoch 2/60
# Epoch 3/60
# 4/4 - 1s - loss: 0.6874 - accuracy: 0.6560 - val_loss: 0.6190 - val_accuracy: 0.6909 - lr: 0.0010 - 917ms/epoch - 229ms/step
# Epoch 2/60
#
# Epoch 2: val_accuracy did not improve from 0.72727
# 4/4 - 1s - loss: 0.6493 - accuracy: 0.6720 - val_loss: 0.5941 - val_accuracy: 0.7364 - lr: 0.0010 - 924ms/epoch - 231ms/step
# 4/4 - 0s - loss: 0.7312 - accuracy: 0.6858 - val_loss: 0.6095 - val_accuracy: 0.7182 - lr: 0.0010 - 48ms/epoch - 12ms/step
# Epoch 2/60
# Epoch 3/60
#
# Epoch 2: val_accuracy did not improve from 0.71818
# 4/4 - 0s - loss: 0.6683 - accuracy: 0.7179 - val_loss: 0.6257 - val_accuracy: 0.7182 - lr: 0.0010 - 58ms/epoch - 14ms/step
# Epoch 3/60
#
# Epoch 2: val_accuracy improved from 0.68182 to 0.74545, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/0321model.keras
#
# Epoch 2: val_accuracy did not improve from 0.73636
# 4/4 - 0s - loss: 0.6362 - accuracy: 0.6651 - val_loss: 0.5777 - val_accuracy: 0.7364 - lr: 0.0010 - 57ms/epoch - 14ms/step
# Epoch 3/60
#
# Epoch 3: val_accuracy improved from 0.74545 to 0.75455, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/0213model.keras
#
# Epoch 2: val_accuracy improved from 0.71818 to 0.72727, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/0312model.keras
# 4/4 - 0s - loss: 0.6005 - accuracy: 0.7018 - val_loss: 0.5989 - val_accuracy: 0.7455 - lr: 0.0010 - 93ms/epoch - 23ms/step
# Epoch 3/60
#
# Epoch 2: val_accuracy did not improve from 0.73636
# 4/4 - 0s - loss: 0.5990 - accuracy: 0.7202 - val_loss: 0.5389 - val_accuracy: 0.7545 - lr: 0.0010 - 62ms/epoch - 16ms/step
# 4/4 - 0s - loss: 0.5888 - accuracy: 0.7294 - val_loss: 0.6002 - val_accuracy: 0.6909 - lr: 0.0010 - 48ms/epoch - 12ms/step
#
# Epoch 3: val_accuracy did not improve from 0.72727
# Epoch 4/60
# Epoch 3/60
# 4/4 - 0s - loss: 0.6490 - accuracy: 0.6491 - val_loss: 0.6256 - val_accuracy: 0.6636 - lr: 0.0010 - 49ms/epoch - 12ms/step
# Epoch 4/60
#
# Epoch 2: val_accuracy improved from 0.69091 to 0.70000, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/0123model.keras
#
# Epoch 3: val_accuracy did not improve from 0.71818
# 4/4 - 0s - loss: 0.7029 - accuracy: 0.7064 - val_loss: 0.6064 - val_accuracy: 0.7273 - lr: 0.0010 - 72ms/epoch - 18ms/step
# 4/4 - 0s - loss: 0.5947 - accuracy: 0.7202 - val_loss: 0.6382 - val_accuracy: 0.6182 - lr: 0.0010 - 49ms/epoch - 12ms/step
# Epoch 3/60
# Epoch 4/60
# 4/4 - 0s - loss: 0.6224 - accuracy: 0.6720 - val_loss: 0.5876 - val_accuracy: 0.7000 - lr: 0.0010 - 90ms/epoch - 23ms/step
#
# Epoch 3: val_accuracy improved from 0.73636 to 0.75455, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/1023model.keras
#
# Epoch 4: val_accuracy improved from 0.75455 to 0.76364, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/0213model.keras
# Epoch 3/60
#
# Epoch 3: val_accuracy did not improve from 0.74545
# 4/4 - 0s - loss: 0.5682 - accuracy: 0.7110 - val_loss: 0.5814 - val_accuracy: 0.7364 - lr: 0.0010 - 54ms/epoch - 14ms/step
#
# Epoch 4: val_accuracy did not improve from 0.72727
# 4/4 - 0s - loss: 0.6338 - accuracy: 0.6445 - val_loss: 0.5987 - val_accuracy: 0.6727 - lr: 0.0010 - 45ms/epoch - 11ms/step
# Epoch 4/60
# Epoch 5/60
#
# Epoch 3: val_accuracy did not improve from 0.72727
# 4/4 - 0s - loss: 0.6182 - accuracy: 0.6950 - val_loss: 0.5853 - val_accuracy: 0.7091 - lr: 0.0010 - 47ms/epoch - 12ms/step
# Epoch 4/60
# 4/4 - 0s - loss: 0.5903 - accuracy: 0.7087 - val_loss: 0.5704 - val_accuracy: 0.7545 - lr: 0.0010 - 83ms/epoch - 21ms/step
#
# Epoch 4: val_accuracy did not improve from 0.71818
#
# Epoch 3: val_accuracy did not improve from 0.73636
# 4/4 - 0s - loss: 0.5581 - accuracy: 0.7202 - val_loss: 0.5427 - val_accuracy: 0.7636 - lr: 0.0010 - 63ms/epoch - 16ms/step
# Epoch 4/60
# 4/4 - 0s - loss: 0.5769 - accuracy: 0.7156 - val_loss: 0.6027 - val_accuracy: 0.6909 - lr: 0.0010 - 64ms/epoch - 16ms/step
# Epoch 5/60
# 4/4 - 0s - loss: 0.5734 - accuracy: 0.7339 - val_loss: 0.5911 - val_accuracy: 0.7000 - lr: 0.0010 - 56ms/epoch - 14ms/step
# Epoch 4/60
# Epoch 5/60
#
# Epoch 3: val_accuracy improved from 0.70000 to 0.71818, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/0123model.keras
#
# Epoch 5: val_accuracy improved from 0.72727 to 0.74545, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/0132model.keras
# 4/4 - 0s - loss: 0.5869 - accuracy: 0.7133 - val_loss: 0.5661 - val_accuracy: 0.7182 - lr: 0.0010 - 59ms/epoch - 15ms/step
# Epoch 4/60
#
# Epoch 4: val_accuracy did not improve from 0.72727
# 4/4 - 0s - loss: 0.6004 - accuracy: 0.6858 - val_loss: 0.5585 - val_accuracy: 0.7273 - lr: 0.0010 - 45ms/epoch - 11ms/step
# Epoch 5/60
#
# Epoch 4: val_accuracy did not improve from 0.74545
#
# Epoch 5: val_accuracy improved from 0.76364 to 0.80000, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/0213model.keras
# 4/4 - 0s - loss: 0.5419 - accuracy: 0.7431 - val_loss: 0.5692 - val_accuracy: 0.7364 - lr: 0.0010 - 61ms/epoch - 15ms/step
# Epoch 5/60
#
# Epoch 4: val_accuracy did not improve from 0.75455
#
# Epoch 5: val_accuracy did not improve from 0.71818
# 4/4 - 0s - loss: 0.5644 - accuracy: 0.7317 - val_loss: 0.5711 - val_accuracy: 0.7364 - lr: 0.0010 - 53ms/epoch - 13ms/step
# 4/4 - 0s - loss: 0.6026 - accuracy: 0.6812 - val_loss: 0.5801 - val_accuracy: 0.7455 - lr: 0.0010 - 67ms/epoch - 17ms/step
# 4/4 - 0s - loss: 0.5408 - accuracy: 0.7408 - val_loss: 0.5743 - val_accuracy: 0.7182 - lr: 0.0010 - 48ms/epoch - 12ms/step
# Epoch 5/60
# Epoch 6/60
# Epoch 6/60
#
# Epoch 4: val_accuracy improved from 0.73636 to 0.74545, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/1032model.keras
# 4/4 - 0s - loss: 0.5507 - accuracy: 0.7385 - val_loss: 0.5212 - val_accuracy: 0.8000 - lr: 0.0010 - 64ms/epoch - 16ms/step
# Epoch 6/60
#
# Epoch 5: val_accuracy did not improve from 0.75455
#
# Epoch 4: val_accuracy did not improve from 0.71818
#
# Epoch 5: val_accuracy improved from 0.72727 to 0.73636, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/0312model.keras
# 4/4 - 0s - loss: 0.5579 - accuracy: 0.7248 - val_loss: 0.5615 - val_accuracy: 0.7364 - lr: 0.0010 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.5575 - accuracy: 0.7248 - val_loss: 0.5581 - val_accuracy: 0.7182 - lr: 0.0010 - 55ms/epoch - 14ms/step
#
# Epoch 6: val_accuracy did not improve from 0.74545
# Epoch 6/60
# Epoch 5/60
#
# Epoch 5: val_accuracy improved from 0.74545 to 0.77273, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/0321model.keras
# 4/4 - 0s - loss: 0.5895 - accuracy: 0.6950 - val_loss: 0.5700 - val_accuracy: 0.7364 - lr: 0.0010 - 41ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.5496 - accuracy: 0.7477 - val_loss: 0.5570 - val_accuracy: 0.7455 - lr: 0.0010 - 92ms/epoch - 23ms/step
# Epoch 7/60
# Epoch 5/60
#
# Epoch 6: val_accuracy improved from 0.71818 to 0.74545, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/0231model.keras
#
# Epoch 6: val_accuracy did not improve from 0.80000
# 4/4 - 0s - loss: 0.5279 - accuracy: 0.7431 - val_loss: 0.5061 - val_accuracy: 0.7909 - lr: 0.0010 - 43ms/epoch - 11ms/step
# Epoch 7/60
# 4/4 - 0s - loss: 0.5671 - accuracy: 0.7202 - val_loss: 0.5322 - val_accuracy: 0.7364 - lr: 0.0010 - 77ms/epoch - 19ms/step
# Epoch 6/60
# 4/4 - 0s - loss: 0.5262 - accuracy: 0.7431 - val_loss: 0.5524 - val_accuracy: 0.7727 - lr: 0.0010 - 73ms/epoch - 18ms/step
# Epoch 6/60
# 4/4 - 0s - loss: 0.5283 - accuracy: 0.7569 - val_loss: 0.5742 - val_accuracy: 0.7455 - lr: 0.0010 - 73ms/epoch - 18ms/step
# Epoch 7/60
#
# Epoch 6: val_accuracy did not improve from 0.75455
# 4/4 - 0s - loss: 0.5396 - accuracy: 0.7408 - val_loss: 0.5475 - val_accuracy: 0.7545 - lr: 0.0010 - 53ms/epoch - 13ms/step
#
# Epoch 5: val_accuracy did not improve from 0.74545
#
# Epoch 5: val_accuracy improved from 0.71818 to 0.75455, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/0123model.keras
# 4/4 - 0s - loss: 0.5443 - accuracy: 0.7385 - val_loss: 0.5487 - val_accuracy: 0.7455 - lr: 0.0010 - 51ms/epoch - 13ms/step
# Epoch 7/60
# Epoch 6/60
#
# Epoch 7: val_accuracy did not improve from 0.74545
# 4/4 - 0s - loss: 0.5630 - accuracy: 0.7271 - val_loss: 0.5813 - val_accuracy: 0.6818 - lr: 0.0010 - 57ms/epoch - 14ms/step
# Epoch 8/60
#
# Epoch 7: val_accuracy did not improve from 0.80000
#
# Epoch 6: val_accuracy did not improve from 0.73636
# 4/4 - 0s - loss: 0.5173 - accuracy: 0.7431 - val_loss: 0.4976 - val_accuracy: 0.8000 - lr: 0.0010 - 58ms/epoch - 14ms/step
# 4/4 - 0s - loss: 0.5570 - accuracy: 0.7156 - val_loss: 0.5251 - val_accuracy: 0.7364 - lr: 0.0010 - 51ms/epoch - 13ms/step
#
# Epoch 6: val_accuracy did not improve from 0.77273
# 4/4 - 0s - loss: 0.5138 - accuracy: 0.7683 - val_loss: 0.5460 - val_accuracy: 0.7545 - lr: 0.0010 - 50ms/epoch - 12ms/step
# Epoch 7/60
# Epoch 8/60
# 4/4 - 0s - loss: 0.5363 - accuracy: 0.7362 - val_loss: 0.5533 - val_accuracy: 0.7545 - lr: 0.0010 - 80ms/epoch - 20ms/step
# Epoch 7/60
# Epoch 6/60
#
# Epoch 7: val_accuracy did not improve from 0.74545
# 4/4 - 0s - loss: 0.5173 - accuracy: 0.7592 - val_loss: 0.5860 - val_accuracy: 0.6909 - lr: 0.0010 - 52ms/epoch - 13ms/step
# Epoch 8/60
#
# Epoch 7: val_accuracy did not improve from 0.75455
# 4/4 - 0s - loss: 0.5283 - accuracy: 0.7477 - val_loss: 0.5465 - val_accuracy: 0.7545 - lr: 0.0010 - 49ms/epoch - 12ms/step
# Epoch 8/60
#
# Epoch 6: val_accuracy did not improve from 0.74545
# 4/4 - 0s - loss: 0.5291 - accuracy: 0.7615 - val_loss: 0.5621 - val_accuracy: 0.7091 - lr: 0.0010 - 52ms/epoch - 13ms/step
# Epoch 7/60
#
# Epoch 8: val_accuracy did not improve from 0.80000
#
# Epoch 8: val_accuracy did not improve from 0.74545
# 4/4 - 0s - loss: 0.5079 - accuracy: 0.7546 - val_loss: 0.4982 - val_accuracy: 0.8000 - lr: 0.0010 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.5521 - accuracy: 0.7385 - val_loss: 0.5662 - val_accuracy: 0.6909 - lr: 0.0010 - 56ms/epoch - 14ms/step
# Epoch 9/60
# Epoch 9/60
#
# Epoch 6: val_accuracy did not improve from 0.75455
# 4/4 - 0s - loss: 0.5201 - accuracy: 0.7592 - val_loss: 0.5354 - val_accuracy: 0.7273 - lr: 0.0010 - 42ms/epoch - 11ms/step
# Epoch 7/60
#
# Epoch 7: val_accuracy improved from 0.73636 to 0.75455, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/0312model.keras
#
# Epoch 7: val_accuracy did not improve from 0.77273
#
# Epoch 8: val_accuracy did not improve from 0.74545
# 4/4 - 0s - loss: 0.5028 - accuracy: 0.7661 - val_loss: 0.5488 - val_accuracy: 0.7455 - lr: 0.0010 - 48ms/epoch - 12ms/step
# 4/4 - 0s - loss: 0.5089 - accuracy: 0.7683 - val_loss: 0.5646 - val_accuracy: 0.7455 - lr: 0.0010 - 39ms/epoch - 10ms/step
# Epoch 8/60
# Epoch 9/60
# 4/4 - 0s - loss: 0.5377 - accuracy: 0.7408 - val_loss: 0.5260 - val_accuracy: 0.7545 - lr: 0.0010 - 67ms/epoch - 17ms/step
#
# Epoch 8: val_accuracy did not improve from 0.75455
# 4/4 - 0s - loss: 0.5178 - accuracy: 0.7638 - val_loss: 0.5703 - val_accuracy: 0.7182 - lr: 0.0010 - 42ms/epoch - 10ms/step
# Epoch 8/60
# Epoch 9/60
#
# Epoch 7: val_accuracy did not improve from 0.74545
# 4/4 - 0s - loss: 0.5264 - accuracy: 0.7523 - val_loss: 0.5621 - val_accuracy: 0.7000 - lr: 0.0010 - 42ms/epoch - 10ms/step
# Epoch 8/60
#
# Epoch 9: val_accuracy did not improve from 0.80000
# 4/4 - 0s - loss: 0.4986 - accuracy: 0.7661 - val_loss: 0.4923 - val_accuracy: 0.8000 - lr: 0.0010 - 39ms/epoch - 10ms/step
# Epoch 10/60
#
# Epoch 9: val_accuracy did not improve from 0.74545
#
# Epoch 8: val_accuracy did not improve from 0.77273
# 4/4 - 0s - loss: 0.4947 - accuracy: 0.7729 - val_loss: 0.5538 - val_accuracy: 0.7455 - lr: 0.0010 - 45ms/epoch - 11ms/step
# 4/4 - 0s - loss: 0.5025 - accuracy: 0.7890 - val_loss: 0.5538 - val_accuracy: 0.7364 - lr: 0.0010 - 44ms/epoch - 11ms/step
#
# Epoch 9: val_accuracy did not improve from 0.74545
# 4/4 - 0s - loss: 0.5353 - accuracy: 0.7569 - val_loss: 0.5429 - val_accuracy: 0.7273 - lr: 0.0010 - 57ms/epoch - 14ms/step
# Epoch 9/60
# Epoch 10/60
#
# Epoch 7: val_accuracy improved from 0.75455 to 0.76364, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/0123model.keras
# Epoch 10/60
#
# Epoch 9: val_accuracy did not improve from 0.75455
# 4/4 - 0s - loss: 0.5114 - accuracy: 0.7500 - val_loss: 0.5359 - val_accuracy: 0.7545 - lr: 0.0010 - 38ms/epoch - 9ms/step
# Epoch 10/60
#
# Epoch 8: val_accuracy did not improve from 0.74545
# 4/4 - 0s - loss: 0.5174 - accuracy: 0.7615 - val_loss: 0.5358 - val_accuracy: 0.7455 - lr: 0.0010 - 37ms/epoch - 9ms/step
# Epoch 9/60
#
# Epoch 8: val_accuracy did not improve from 0.75455
# 4/4 - 0s - loss: 0.5227 - accuracy: 0.7592 - val_loss: 0.5322 - val_accuracy: 0.7364 - lr: 0.0010 - 53ms/epoch - 13ms/step
# 4/4 - 0s - loss: 0.5076 - accuracy: 0.7592 - val_loss: 0.5314 - val_accuracy: 0.7636 - lr: 0.0010 - 76ms/epoch - 19ms/step
# Epoch 9/60
# Epoch 8/60
#
# Epoch 10: val_accuracy improved from 0.80000 to 0.80909, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/0213model.keras
#
# Epoch 9: val_accuracy did not improve from 0.77273
# 4/4 - 0s - loss: 0.4906 - accuracy: 0.7775 - val_loss: 0.5469 - val_accuracy: 0.7455 - lr: 0.0010 - 38ms/epoch - 10ms/step
# Epoch 10/60
#
# Epoch 10: val_accuracy did not improve from 0.74545
# 4/4 - 0s - loss: 0.5299 - accuracy: 0.7523 - val_loss: 0.5371 - val_accuracy: 0.7364 - lr: 0.0010 - 48ms/epoch - 12ms/step
#
# Epoch 9: val_accuracy did not improve from 0.74545
# 4/4 - 0s - loss: 0.5102 - accuracy: 0.7638 - val_loss: 0.5438 - val_accuracy: 0.7273 - lr: 0.0010 - 36ms/epoch - 9ms/step
# Epoch 11/60
# 4/4 - 0s - loss: 0.4916 - accuracy: 0.7729 - val_loss: 0.4905 - val_accuracy: 0.8091 - lr: 0.0010 - 71ms/epoch - 18ms/step
# Epoch 10/60
# Epoch 11/60
#
# Epoch 10: val_accuracy did not improve from 0.74545
# 4/4 - 0s - loss: 0.4954 - accuracy: 0.7890 - val_loss: 0.5687 - val_accuracy: 0.7091 - lr: 0.0010 - 56ms/epoch - 14ms/step
# Epoch 11/60
#
# Epoch 10: val_accuracy improved from 0.75455 to 0.76364, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/1023model.keras
#
# Epoch 9: val_accuracy did not improve from 0.75455
# 4/4 - 0s - loss: 0.5192 - accuracy: 0.7592 - val_loss: 0.5304 - val_accuracy: 0.7364 - lr: 0.0010 - 45ms/epoch - 11ms/step
# Epoch 10/60
#
# Epoch 8: val_accuracy did not improve from 0.76364
# 4/4 - 0s - loss: 0.4967 - accuracy: 0.7706 - val_loss: 0.5360 - val_accuracy: 0.7545 - lr: 0.0010 - 51ms/epoch - 13ms/step
# Epoch 9/60
#
# Epoch 10: val_accuracy did not improve from 0.74545
# 4/4 - 0s - loss: 0.5097 - accuracy: 0.7683 - val_loss: 0.5556 - val_accuracy: 0.7182 - lr: 0.0010 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.5033 - accuracy: 0.7661 - val_loss: 0.5279 - val_accuracy: 0.7636 - lr: 0.0010 - 80ms/epoch - 20ms/step
#
# Epoch 11: val_accuracy did not improve from 0.80909
#
# Epoch 10: val_accuracy did not improve from 0.77273
# Epoch 11/60
# 4/4 - 0s - loss: 0.4837 - accuracy: 0.7798 - val_loss: 0.4952 - val_accuracy: 0.7818 - lr: 0.0010 - 38ms/epoch - 10ms/step
# Epoch 11/60
# 4/4 - 0s - loss: 0.4873 - accuracy: 0.7798 - val_loss: 0.5432 - val_accuracy: 0.7545 - lr: 0.0010 - 54ms/epoch - 13ms/step
# Epoch 12/60
# Epoch 11/60
#
# Epoch 11: val_accuracy did not improve from 0.74545
# 4/4 - 0s - loss: 0.5183 - accuracy: 0.7661 - val_loss: 0.5425 - val_accuracy: 0.7273 - lr: 0.0010 - 59ms/epoch - 15ms/step
#
# Epoch 11: val_accuracy did not improve from 0.74545
# 4/4 - 0s - loss: 0.4896 - accuracy: 0.7798 - val_loss: 0.5613 - val_accuracy: 0.7182 - lr: 0.0010 - 55ms/epoch - 14ms/step
# Epoch 12/60
# Epoch 12/60
#
# Epoch 10: val_accuracy did not improve from 0.75455
# 4/4 - 0s - loss: 0.5096 - accuracy: 0.7592 - val_loss: 0.5201 - val_accuracy: 0.7455 - lr: 0.0010 - 49ms/epoch - 12ms/step
# Epoch 11/60
#
# Epoch 9: val_accuracy did not improve from 0.76364
# 4/4 - 0s - loss: 0.4909 - accuracy: 0.7775 - val_loss: 0.5371 - val_accuracy: 0.7455 - lr: 0.0010 - 50ms/epoch - 13ms/step
# Epoch 10/60
#
# Epoch 11: val_accuracy did not improve from 0.77273
#
# Epoch 11: val_accuracy did not improve from 0.74545
# 4/4 - 0s - loss: 0.4809 - accuracy: 0.7775 - val_loss: 0.5526 - val_accuracy: 0.7636 - lr: 0.0010 - 43ms/epoch - 11ms/step
#
# Epoch 11: val_accuracy did not improve from 0.76364
# 4/4 - 0s - loss: 0.5002 - accuracy: 0.7729 - val_loss: 0.5315 - val_accuracy: 0.7364 - lr: 0.0010 - 49ms/epoch - 12ms/step
# 4/4 - 0s - loss: 0.4961 - accuracy: 0.7706 - val_loss: 0.5425 - val_accuracy: 0.7364 - lr: 0.0010 - 49ms/epoch - 12ms/step
# Epoch 12/60
# Epoch 12/60
# Epoch 12/60
#
# Epoch 12: val_accuracy did not improve from 0.80909
# 4/4 - 0s - loss: 0.4807 - accuracy: 0.7844 - val_loss: 0.5038 - val_accuracy: 0.7455 - lr: 0.0010 - 55ms/epoch - 14ms/step
# Epoch 13/60
#
# Epoch 12: val_accuracy did not improve from 0.74545
# 4/4 - 0s - loss: 0.4854 - accuracy: 0.7867 - val_loss: 0.5490 - val_accuracy: 0.7273 - lr: 0.0010 - 48ms/epoch - 12ms/step
#
# Epoch 12: val_accuracy did not improve from 0.74545
# 4/4 - 0s - loss: 0.5123 - accuracy: 0.7752 - val_loss: 0.5521 - val_accuracy: 0.6818 - lr: 0.0010 - 53ms/epoch - 13ms/step
# Epoch 13/60
# Epoch 13/60
#
# Epoch 10: val_accuracy did not improve from 0.76364
# 4/4 - 0s - loss: 0.4861 - accuracy: 0.7752 - val_loss: 0.5298 - val_accuracy: 0.7636 - lr: 0.0010 - 44ms/epoch - 11ms/step
# Epoch 11/60
#
# Epoch 11: val_accuracy did not improve from 0.75455
# 4/4 - 0s - loss: 0.5035 - accuracy: 0.7729 - val_loss: 0.5234 - val_accuracy: 0.7455 - lr: 0.0010 - 62ms/epoch - 15ms/step
#
# Epoch 12: val_accuracy did not improve from 0.76364
# Epoch 12/60
#
# Epoch 12: val_accuracy did not improve from 0.77273
# 4/4 - 0s - loss: 0.4953 - accuracy: 0.7729 - val_loss: 0.5371 - val_accuracy: 0.7545 - lr: 0.0010 - 46ms/epoch - 11ms/step
#
# Epoch 12: val_accuracy did not improve from 0.74545
# Epoch 13/60
# 4/4 - 0s - loss: 0.4735 - accuracy: 0.7844 - val_loss: 0.5246 - val_accuracy: 0.7727 - lr: 0.0010 - 49ms/epoch - 12ms/step
# 4/4 - 0s - loss: 0.4988 - accuracy: 0.7706 - val_loss: 0.5349 - val_accuracy: 0.7273 - lr: 0.0010 - 47ms/epoch - 12ms/step
# Epoch 13/60
# Epoch 13/60
#
# Epoch 13: val_accuracy did not improve from 0.74545
# 4/4 - 0s - loss: 0.5076 - accuracy: 0.7775 - val_loss: 0.5420 - val_accuracy: 0.7000 - lr: 0.0010 - 37ms/epoch - 9ms/step
#
# Epoch 13: val_accuracy did not improve from 0.80909
# Epoch 14/60
# 4/4 - 0s - loss: 0.4773 - accuracy: 0.7844 - val_loss: 0.4913 - val_accuracy: 0.8000 - lr: 0.0010 - 53ms/epoch - 13ms/step
# Epoch 14/60
#
# Epoch 13: val_accuracy did not improve from 0.74545
# 4/4 - 0s - loss: 0.4772 - accuracy: 0.7890 - val_loss: 0.5348 - val_accuracy: 0.7455 - lr: 0.0010 - 52ms/epoch - 13ms/step
# Epoch 14/60
#
# Epoch 13: val_accuracy did not improve from 0.76364
#
# Epoch 11: val_accuracy did not improve from 0.76364
#
# Epoch 12: val_accuracy did not improve from 0.75455
# 4/4 - 0s - loss: 0.4776 - accuracy: 0.7844 - val_loss: 0.5469 - val_accuracy: 0.7091 - lr: 0.0010 - 53ms/epoch - 13ms/step
# 4/4 - 0s - loss: 0.4889 - accuracy: 0.7683 - val_loss: 0.5221 - val_accuracy: 0.7455 - lr: 0.0010 - 40ms/epoch - 10ms/step
# Epoch 12/60
# 4/4 - 0s - loss: 0.4947 - accuracy: 0.7752 - val_loss: 0.5287 - val_accuracy: 0.7545 - lr: 0.0010 - 45ms/epoch - 11ms/step
#
# Epoch 13: val_accuracy did not improve from 0.74545
# 4/4 - 0s - loss: 0.4932 - accuracy: 0.7706 - val_loss: 0.5459 - val_accuracy: 0.7273 - lr: 0.0010 - 42ms/epoch - 10ms/step
# Epoch 14/60
# Epoch 14/60
# Epoch 13/60
#
# Epoch 14: val_accuracy did not improve from 0.74545
# 4/4 - 0s - loss: 0.5027 - accuracy: 0.7844 - val_loss: 0.5318 - val_accuracy: 0.7364 - lr: 0.0010 - 36ms/epoch - 9ms/step
# Epoch 15/60
#
# Epoch 14: val_accuracy did not improve from 0.80909
#
# Epoch 13: val_accuracy did not improve from 0.77273
# 4/4 - 0s - loss: 0.4704 - accuracy: 0.7867 - val_loss: 0.4925 - val_accuracy: 0.7909 - lr: 0.0010 - 43ms/epoch - 11ms/step
# 4/4 - 0s - loss: 0.4734 - accuracy: 0.7959 - val_loss: 0.5263 - val_accuracy: 0.7636 - lr: 0.0010 - 59ms/epoch - 15ms/step
# Epoch 14/60
# Epoch 15/60
#
# Epoch 14: val_accuracy improved from 0.74545 to 0.77273, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/0231model.keras
#
# Epoch 12: val_accuracy did not improve from 0.76364
#
# Epoch 13: val_accuracy did not improve from 0.75455
# 4/4 - 0s - loss: 0.4908 - accuracy: 0.7890 - val_loss: 0.5252 - val_accuracy: 0.7545 - lr: 0.0010 - 46ms/epoch - 11ms/step
# 4/4 - 0s - loss: 0.4742 - accuracy: 0.7729 - val_loss: 0.5242 - val_accuracy: 0.7545 - lr: 0.0010 - 51ms/epoch - 13ms/step
# Epoch 14/60
#
# Epoch 14: val_accuracy did not improve from 0.76364
# 4/4 - 0s - loss: 0.4813 - accuracy: 0.7913 - val_loss: 0.5361 - val_accuracy: 0.7727 - lr: 0.0010 - 68ms/epoch - 17ms/step
#
# Epoch 15: val_accuracy did not improve from 0.74545
# Epoch 13/60
# 4/4 - 0s - loss: 0.4797 - accuracy: 0.7752 - val_loss: 0.5403 - val_accuracy: 0.7545 - lr: 0.0010 - 54ms/epoch - 14ms/step
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 15/60
#
# Epoch 14: val_accuracy did not improve from 0.74545
# Epoch 15/60
#
# Epoch 15: val_accuracy did not improve from 0.80909
# 4/4 - 0s - loss: 0.4938 - accuracy: 0.7844 - val_loss: 0.5435 - val_accuracy: 0.6818 - lr: 0.0010 - 50ms/epoch - 12ms/step
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 4/4 - 0s - loss: 0.4671 - accuracy: 0.7913 - val_loss: 0.4927 - val_accuracy: 0.7909 - lr: 0.0010 - 43ms/epoch - 11ms/step
# 4/4 - 0s - loss: 0.4893 - accuracy: 0.7706 - val_loss: 0.5364 - val_accuracy: 0.7273 - lr: 0.0010 - 58ms/epoch - 15ms/step
# Epoch 16/60
# Epoch 16/60
# Epoch 15/60
#
# Epoch 14: val_accuracy did not improve from 0.77273
# 4/4 - 0s - loss: 0.4729 - accuracy: 0.7706 - val_loss: 0.5477 - val_accuracy: 0.7545 - lr: 0.0010 - 61ms/epoch - 15ms/step
# Epoch 15/60
#
# Epoch 13: val_accuracy did not improve from 0.76364
#
# Epoch 14: val_accuracy did not improve from 0.75455
# 4/4 - 0s - loss: 0.4695 - accuracy: 0.7890 - val_loss: 0.5179 - val_accuracy: 0.7636 - lr: 0.0010 - 43ms/epoch - 11ms/step
# 4/4 - 0s - loss: 0.4860 - accuracy: 0.7844 - val_loss: 0.5207 - val_accuracy: 0.7545 - lr: 0.0010 - 48ms/epoch - 12ms/step
# Epoch 14/60
# Epoch 15/60
#
# Epoch 15: val_accuracy did not improve from 0.77273
#
# Epoch 16: val_accuracy did not improve from 0.80909
# 4/4 - 0s - loss: 0.4643 - accuracy: 0.8050 - val_loss: 0.4862 - val_accuracy: 0.7909 - lr: 0.0010 - 50ms/epoch - 12ms/step
# 4/4 - 0s - loss: 0.4715 - accuracy: 0.7890 - val_loss: 0.5668 - val_accuracy: 0.7091 - lr: 0.0010 - 56ms/epoch - 14ms/step
#
# Epoch 15: val_accuracy did not improve from 0.76364
#
# Epoch 16: val_accuracy did not improve from 0.74545
#
# Epoch 15: val_accuracy did not improve from 0.74545
# 4/4 - 0s - loss: 0.4858 - accuracy: 0.7706 - val_loss: 0.5542 - val_accuracy: 0.7273 - lr: 0.0010 - 57ms/epoch - 14ms/step
# Epoch 16/60
# Epoch 17/60
# 4/4 - 0s - loss: 0.4916 - accuracy: 0.7913 - val_loss: 0.5437 - val_accuracy: 0.6818 - lr: 1.0000e-04 - 55ms/epoch - 14ms/step
# 4/4 - 0s - loss: 0.4861 - accuracy: 0.7775 - val_loss: 0.5359 - val_accuracy: 0.7273 - lr: 1.0000e-04 - 54ms/epoch - 14ms/step
# Epoch 16/60
# Epoch 17/60
# Epoch 16/60
#
# Epoch 15: val_accuracy did not improve from 0.77273
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 4/4 - 0s - loss: 0.4625 - accuracy: 0.7890 - val_loss: 0.5159 - val_accuracy: 0.7727 - lr: 0.0010 - 58ms/epoch - 14ms/step
#
# Epoch 14: val_accuracy did not improve from 0.76364
# 4/4 - 0s - loss: 0.4666 - accuracy: 0.7913 - val_loss: 0.5244 - val_accuracy: 0.7364 - lr: 0.0010 - 43ms/epoch - 11ms/step
#
# Epoch 15: val_accuracy did not improve from 0.75455
# Epoch 15/60
# Epoch 16/60
# 4/4 - 0s - loss: 0.4821 - accuracy: 0.7890 - val_loss: 0.5172 - val_accuracy: 0.7455 - lr: 0.0010 - 43ms/epoch - 11ms/step
# Epoch 16/60
#
# Epoch 17: val_accuracy did not improve from 0.80909
# 4/4 - 0s - loss: 0.4626 - accuracy: 0.7982 - val_loss: 0.4847 - val_accuracy: 0.7909 - lr: 0.0010 - 47ms/epoch - 12ms/step
#
# Epoch 16: val_accuracy did not improve from 0.76364
# Epoch 18/60
# 4/4 - 0s - loss: 0.4718 - accuracy: 0.7867 - val_loss: 0.5194 - val_accuracy: 0.7455 - lr: 0.0010 - 47ms/epoch - 12ms/step
# Epoch 17/60
#
# Epoch 16: val_accuracy did not improve from 0.77273
#
# Epoch 17: val_accuracy did not improve from 0.74545
#
# Epoch 16: val_accuracy did not improve from 0.74545
# 4/4 - 0s - loss: 0.4732 - accuracy: 0.7982 - val_loss: 0.5482 - val_accuracy: 0.7091 - lr: 0.0010 - 57ms/epoch - 14ms/step
# 4/4 - 0s - loss: 0.4910 - accuracy: 0.7936 - val_loss: 0.5405 - val_accuracy: 0.7000 - lr: 1.0000e-04 - 53ms/epoch - 13ms/step
# 4/4 - 0s - loss: 0.4858 - accuracy: 0.7775 - val_loss: 0.5362 - val_accuracy: 0.7273 - lr: 1.0000e-04 - 53ms/epoch - 13ms/step
# Epoch 17/60
# Epoch 18/60
# Epoch 17/60
#
# Epoch 15: val_accuracy did not improve from 0.76364
#
# Epoch 16: val_accuracy did not improve from 0.75455
# 4/4 - 0s - loss: 0.4640 - accuracy: 0.7775 - val_loss: 0.5369 - val_accuracy: 0.7182 - lr: 0.0010 - 41ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.4775 - accuracy: 0.7890 - val_loss: 0.5194 - val_accuracy: 0.7545 - lr: 0.0010 - 39ms/epoch - 10ms/step
# Epoch 17/60
# Epoch 16/60
#
# Epoch 16: val_accuracy improved from 0.77273 to 0.78182, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/0321model.keras
#
# Epoch 17: val_accuracy did not improve from 0.76364
# 4/4 - 0s - loss: 0.4769 - accuracy: 0.7798 - val_loss: 0.5177 - val_accuracy: 0.7455 - lr: 0.0010 - 45ms/epoch - 11ms/step
#
# Epoch 18: val_accuracy did not improve from 0.74545
#
# Epoch 17: val_accuracy did not improve from 0.77273
#
# Epoch 18: val_accuracy did not improve from 0.80909
# 4/4 - 0s - loss: 0.4902 - accuracy: 0.7982 - val_loss: 0.5374 - val_accuracy: 0.7000 - lr: 1.0000e-04 - 40ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.4645 - accuracy: 0.7959 - val_loss: 0.5279 - val_accuracy: 0.7545 - lr: 0.0010 - 41ms/epoch - 10ms/step
# Epoch 18/60
# 4/4 - 0s - loss: 0.4563 - accuracy: 0.8005 - val_loss: 0.4990 - val_accuracy: 0.7455 - lr: 0.0010 - 52ms/epoch - 13ms/step
# Epoch 19/60
# Epoch 18/60
# Epoch 19/60
# 4/4 - 0s - loss: 0.4632 - accuracy: 0.7913 - val_loss: 0.5158 - val_accuracy: 0.7818 - lr: 1.0000e-04 - 82ms/epoch - 21ms/step
# Epoch 17/60
#
# Epoch 17: val_accuracy did not improve from 0.74545
# 4/4 - 0s - loss: 0.4854 - accuracy: 0.7775 - val_loss: 0.5374 - val_accuracy: 0.7182 - lr: 1.0000e-04 - 60ms/epoch - 15ms/step
#
# Epoch 16: val_accuracy did not improve from 0.76364
# Epoch 18/60
# 4/4 - 0s - loss: 0.4622 - accuracy: 0.7867 - val_loss: 0.5149 - val_accuracy: 0.7545 - lr: 0.0010 - 50ms/epoch - 13ms/step
# Epoch 17/60
#
# Epoch 17: val_accuracy did not improve from 0.75455
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 4/4 - 0s - loss: 0.4735 - accuracy: 0.7959 - val_loss: 0.5124 - val_accuracy: 0.7364 - lr: 0.0010 - 59ms/epoch - 15ms/step
# Epoch 18/60
#
# Epoch 18: val_accuracy improved from 0.76364 to 0.77273, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/1023model.keras
#
# Epoch 19: val_accuracy did not improve from 0.74545
# 4/4 - 0s - loss: 0.4894 - accuracy: 0.7936 - val_loss: 0.5342 - val_accuracy: 0.7000 - lr: 1.0000e-04 - 42ms/epoch - 11ms/step
# Epoch 20/60
#
# Epoch 18: val_accuracy did not improve from 0.77273
# 4/4 - 0s - loss: 0.4652 - accuracy: 0.7982 - val_loss: 0.5365 - val_accuracy: 0.7364 - lr: 0.0010 - 47ms/epoch - 12ms/step
#
# Epoch 19: val_accuracy did not improve from 0.80909
# 4/4 - 0s - loss: 0.4555 - accuracy: 0.7936 - val_loss: 0.4849 - val_accuracy: 0.7727 - lr: 0.0010 - 49ms/epoch - 12ms/step
# Epoch 19/60
# Epoch 20/60
#
# Epoch 18: val_accuracy did not improve from 0.74545
# 4/4 - 0s - loss: 0.4851 - accuracy: 0.7706 - val_loss: 0.5390 - val_accuracy: 0.7182 - lr: 1.0000e-04 - 47ms/epoch - 12ms/step
#
# Epoch 17: val_accuracy did not improve from 0.78182
# 4/4 - 0s - loss: 0.4614 - accuracy: 0.7982 - val_loss: 0.5177 - val_accuracy: 0.7636 - lr: 1.0000e-04 - 58ms/epoch - 15ms/step
# Epoch 19/60
# Epoch 18/60
# 4/4 - 0s - loss: 0.4713 - accuracy: 0.7752 - val_loss: 0.5337 - val_accuracy: 0.7727 - lr: 0.0010 - 77ms/epoch - 19ms/step
# Epoch 19/60
#
# Epoch 17: val_accuracy did not improve from 0.76364
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 4/4 - 0s - loss: 0.4553 - accuracy: 0.7959 - val_loss: 0.5221 - val_accuracy: 0.7364 - lr: 0.0010 - 57ms/epoch - 14ms/step
# Epoch 18/60
#
# Epoch 18: val_accuracy did not improve from 0.75455
# 4/4 - 0s - loss: 0.4707 - accuracy: 0.7890 - val_loss: 0.5122 - val_accuracy: 0.7364 - lr: 1.0000e-04 - 57ms/epoch - 14ms/step
# Epoch 19/60
# Restoring model weights from the end of the best epoch: 5.
#
# Epoch 19: val_accuracy did not improve from 0.77273
#
# Epoch 20: val_accuracy did not improve from 0.80909
#
# Epoch 20: val_accuracy did not improve from 0.74545
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 4/4 - 0s - loss: 0.4557 - accuracy: 0.8028 - val_loss: 0.5498 - val_accuracy: 0.7091 - lr: 0.0010 - 49ms/epoch - 12ms/step
# 4/4 - 0s - loss: 0.4886 - accuracy: 0.7959 - val_loss: 0.5331 - val_accuracy: 0.7091 - lr: 1.0000e-04 - 57ms/epoch - 14ms/step
# 4/4 - 0s - loss: 0.4496 - accuracy: 0.8119 - val_loss: 0.4756 - val_accuracy: 0.8000 - lr: 0.0010 - 50ms/epoch - 12ms/step
# Epoch 20: early stopping
# Epoch 20/60
# Epoch 21/60
# Restoring model weights from the end of the best epoch: 4.
#
# Epoch 19: val_accuracy did not improve from 0.77273
# 4/4 - 0s - loss: 0.4643 - accuracy: 0.7867 - val_loss: 0.5340 - val_accuracy: 0.7727 - lr: 0.0010 - 41ms/epoch - 10ms/step
#
# Epoch 19: val_accuracy did not improve from 0.74545
# Epoch 20/60
# 4/4 - 0s - loss: 0.4849 - accuracy: 0.7683 - val_loss: 0.5387 - val_accuracy: 0.7182 - lr: 1.0000e-04 - 49ms/epoch - 12ms/step
# Epoch 19: early stopping
#
# Epoch 18: val_accuracy did not improve from 0.76364
# 4/4 - 0s - loss: 0.4529 - accuracy: 0.7936 - val_loss: 0.5214 - val_accuracy: 0.7364 - lr: 1.0000e-04 - 39ms/epoch - 10ms/step
# Epoch 19/60
#
# Epoch 18: val_accuracy did not improve from 0.78182
# 4/4 - 0s - loss: 0.4596 - accuracy: 0.7982 - val_loss: 0.5215 - val_accuracy: 0.7455 - lr: 1.0000e-04 - 62ms/epoch - 15ms/step
# Epoch 19/60
#
# Epoch 19: val_accuracy did not improve from 0.75455
# 4/4 - 0s - loss: 0.4704 - accuracy: 0.7890 - val_loss: 0.5121 - val_accuracy: 0.7364 - lr: 1.0000e-04 - 46ms/epoch - 12ms/step
# Epoch 20/60
#
# Epoch 21: val_accuracy did not improve from 0.80909
# 4/4 - 0s - loss: 0.4521 - accuracy: 0.8005 - val_loss: 0.4756 - val_accuracy: 0.8000 - lr: 1.0000e-04 - 40ms/epoch - 10ms/step
# Epoch 22/60
#
# Epoch 20: val_accuracy did not improve from 0.77273
# 4/4 - 0s - loss: 0.4592 - accuracy: 0.8096 - val_loss: 0.5371 - val_accuracy: 0.7091 - lr: 0.0010 - 53ms/epoch - 13ms/step
# Epoch 21/60
#
# Epoch 20: val_accuracy did not improve from 0.77273
# 4/4 - 0s - loss: 0.4599 - accuracy: 0.7936 - val_loss: 0.5162 - val_accuracy: 0.7636 - lr: 0.0010 - 44ms/epoch - 11ms/step
#
# Epoch 19: val_accuracy did not improve from 0.76364
# 4/4 - 0s - loss: 0.4524 - accuracy: 0.7936 - val_loss: 0.5194 - val_accuracy: 0.7364 - lr: 1.0000e-04 - 38ms/epoch - 10ms/step
# Epoch 20/60
# Epoch 21/60
#
# Epoch 20: val_accuracy did not improve from 0.75455
# 4/4 - 0s - loss: 0.4703 - accuracy: 0.7890 - val_loss: 0.5120 - val_accuracy: 0.7364 - lr: 1.0000e-04 - 39ms/epoch - 10ms/step
# Epoch 21/60
#
# Epoch 19: val_accuracy did not improve from 0.78182
#
# Epoch 22: val_accuracy did not improve from 0.80909
# 4/4 - 0s - loss: 0.4512 - accuracy: 0.7982 - val_loss: 0.4771 - val_accuracy: 0.8000 - lr: 1.0000e-04 - 38ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.4577 - accuracy: 0.7913 - val_loss: 0.5253 - val_accuracy: 0.7455 - lr: 1.0000e-04 - 47ms/epoch - 12ms/step
# Epoch 23/60
# Epoch 20/60
#
# Epoch 21: val_accuracy did not improve from 0.77273
# 4/4 - 0s - loss: 0.4512 - accuracy: 0.8119 - val_loss: 0.5202 - val_accuracy: 0.7636 - lr: 0.0010 - 43ms/epoch - 11ms/step
# Epoch 22/60
#
# Epoch 21: val_accuracy did not improve from 0.77273
# 4/4 - 0s - loss: 0.4585 - accuracy: 0.7913 - val_loss: 0.5130 - val_accuracy: 0.7636 - lr: 0.0010 - 39ms/epoch - 10ms/step
# Epoch 22/60
#
# Epoch 20: val_accuracy did not improve from 0.76364
# 4/4 - 0s - loss: 0.4523 - accuracy: 0.7913 - val_loss: 0.5152 - val_accuracy: 0.7364 - lr: 1.0000e-04 - 48ms/epoch - 12ms/step
# Epoch 21/60
#
# Epoch 23: val_accuracy did not improve from 0.80909
# 4/4 - 0s - loss: 0.4497 - accuracy: 0.8050 - val_loss: 0.4795 - val_accuracy: 0.8000 - lr: 1.0000e-04 - 45ms/epoch - 11ms/step
# Epoch 24/60
#
# Epoch 21: val_accuracy did not improve from 0.75455
# 4/4 - 0s - loss: 0.4698 - accuracy: 0.7936 - val_loss: 0.5132 - val_accuracy: 0.7545 - lr: 1.0000e-04 - 57ms/epoch - 14ms/step
# Epoch 22/60
#
# Epoch 20: val_accuracy did not improve from 0.78182
# 4/4 - 0s - loss: 0.4573 - accuracy: 0.7936 - val_loss: 0.5285 - val_accuracy: 0.7545 - lr: 1.0000e-04 - 53ms/epoch - 13ms/step
# Epoch 21/60
#
# Epoch 22: val_accuracy did not improve from 0.77273
# 4/4 - 0s - loss: 0.4500 - accuracy: 0.8073 - val_loss: 0.5215 - val_accuracy: 0.7545 - lr: 0.0010 - 51ms/epoch - 13ms/step
# Epoch 23/60
#
# Epoch 22: val_accuracy did not improve from 0.77273
# 4/4 - 0s - loss: 0.4558 - accuracy: 0.7913 - val_loss: 0.5181 - val_accuracy: 0.7727 - lr: 0.0010 - 60ms/epoch - 15ms/step
# Epoch 23/60
#
# Epoch 21: val_accuracy did not improve from 0.76364
# 4/4 - 0s - loss: 0.4520 - accuracy: 0.7982 - val_loss: 0.5142 - val_accuracy: 0.7455 - lr: 1.0000e-04 - 56ms/epoch - 14ms/step
#
# Epoch 24: val_accuracy did not improve from 0.80909
# Epoch 22/60
# 4/4 - 0s - loss: 0.4486 - accuracy: 0.8096 - val_loss: 0.4829 - val_accuracy: 0.7909 - lr: 1.0000e-04 - 42ms/epoch - 10ms/step
# Epoch 25/60
#
# Epoch 21: val_accuracy did not improve from 0.78182
# 4/4 - 0s - loss: 0.4572 - accuracy: 0.7890 - val_loss: 0.5293 - val_accuracy: 0.7636 - lr: 1.0000e-04 - 44ms/epoch - 11ms/step
# Epoch 22/60
# Restoring model weights from the end of the best epoch: 7.
#
# Epoch 23: val_accuracy did not improve from 0.77273
# 4/4 - 0s - loss: 0.4462 - accuracy: 0.8050 - val_loss: 0.5256 - val_accuracy: 0.7091 - lr: 0.0010 - 45ms/epoch - 11ms/step
#
# Epoch 22: val_accuracy did not improve from 0.75455
# Epoch 24/60
# 4/4 - 0s - loss: 0.4694 - accuracy: 0.7936 - val_loss: 0.5139 - val_accuracy: 0.7545 - lr: 1.0000e-04 - 63ms/epoch - 16ms/step
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 7.
#
# Epoch 23: val_accuracy did not improve from 0.77273
#
# Epoch 22: val_accuracy did not improve from 0.76364
# 4/4 - 0s - loss: 0.4517 - accuracy: 0.7982 - val_loss: 0.5139 - val_accuracy: 0.7455 - lr: 1.0000e-04 - 46ms/epoch - 12ms/step
# 4/4 - 0s - loss: 0.4523 - accuracy: 0.7936 - val_loss: 0.5313 - val_accuracy: 0.7636 - lr: 0.0010 - 51ms/epoch - 13ms/step
# Epoch 22: early stopping
# Epoch 24/60
# Restoring model weights from the end of the best epoch: 10.
#
# Epoch 22: val_accuracy did not improve from 0.78182
#
# Epoch 25: val_accuracy did not improve from 0.80909
# 4/4 - 0s - loss: 0.4570 - accuracy: 0.7913 - val_loss: 0.5277 - val_accuracy: 0.7545 - lr: 1.0000e-04 - 46ms/epoch - 12ms/step
# 4/4 - 0s - loss: 0.4477 - accuracy: 0.8119 - val_loss: 0.4852 - val_accuracy: 0.7909 - lr: 1.0000e-04 - 59ms/epoch - 15ms/step
# Epoch 25: early stopping
# Epoch 23/60
#
# Epoch 24: val_accuracy did not improve from 0.77273
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 4/4 - 0s - loss: 0.4443 - accuracy: 0.8050 - val_loss: 0.5222 - val_accuracy: 0.7182 - lr: 0.0010 - 50ms/epoch - 12ms/step
# Epoch 25/60
#
# Epoch 24: val_accuracy did not improve from 0.77273
# 4/4 - 0s - loss: 0.4534 - accuracy: 0.7913 - val_loss: 0.5151 - val_accuracy: 0.7727 - lr: 0.0010 - 52ms/epoch - 13ms/step
# Epoch 25/60
#
# Epoch 23: val_accuracy did not improve from 0.78182
# 4/4 - 0s - loss: 0.4563 - accuracy: 0.7913 - val_loss: 0.5260 - val_accuracy: 0.7455 - lr: 1.0000e-04 - 58ms/epoch - 15ms/step
#
# Epoch 25: val_accuracy did not improve from 0.77273
# Epoch 24/60
# 4/4 - 0s - loss: 0.4411 - accuracy: 0.8119 - val_loss: 0.5225 - val_accuracy: 0.7182 - lr: 1.0000e-04 - 47ms/epoch - 12ms/step
# Epoch 26/60
#
# Epoch 25: val_accuracy did not improve from 0.77273
# 4/4 - 0s - loss: 0.4466 - accuracy: 0.8005 - val_loss: 0.5049 - val_accuracy: 0.7727 - lr: 0.0010 - 65ms/epoch - 16ms/step
# Epoch 26/60
#
# Epoch 24: val_accuracy did not improve from 0.78182
# 4/4 - 0s - loss: 0.4559 - accuracy: 0.7844 - val_loss: 0.5230 - val_accuracy: 0.7455 - lr: 1.0000e-04 - 56ms/epoch - 14ms/step
# Epoch 25/60
#
# Epoch 26: val_accuracy did not improve from 0.77273
# 4/4 - 0s - loss: 0.4411 - accuracy: 0.8119 - val_loss: 0.5228 - val_accuracy: 0.7182 - lr: 1.0000e-04 - 56ms/epoch - 14ms/step
# Epoch 27/60
#
# Epoch 25: val_accuracy did not improve from 0.78182
# 4/4 - 0s - loss: 0.4560 - accuracy: 0.7913 - val_loss: 0.5212 - val_accuracy: 0.7545 - lr: 1.0000e-04 - 44ms/epoch - 11ms/step
#
# Epoch 27: val_accuracy did not improve from 0.77273
# Epoch 26/60
# 4/4 - 0s - loss: 0.4407 - accuracy: 0.8096 - val_loss: 0.5220 - val_accuracy: 0.7182 - lr: 1.0000e-04 - 40ms/epoch - 10ms/step
# Epoch 28/60
#
# Epoch 26: val_accuracy did not improve from 0.77273
# 4/4 - 0s - loss: 0.4469 - accuracy: 0.8005 - val_loss: 0.5125 - val_accuracy: 0.7727 - lr: 0.0010 - 59ms/epoch - 15ms/step
# Epoch 27/60
#
# Epoch 28: val_accuracy did not improve from 0.77273
# 4/4 - 0s - loss: 0.4403 - accuracy: 0.8073 - val_loss: 0.5208 - val_accuracy: 0.7364 - lr: 1.0000e-04 - 46ms/epoch - 12ms/step
#
# Epoch 26: val_accuracy did not improve from 0.78182
# Epoch 29/60
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 4/4 - 0s - loss: 0.4555 - accuracy: 0.7959 - val_loss: 0.5222 - val_accuracy: 0.7455 - lr: 1.0000e-04 - 59ms/epoch - 15ms/step
# Epoch 27/60
#
# Epoch 27: val_accuracy did not improve from 0.77273
# 4/4 - 0s - loss: 0.4487 - accuracy: 0.7844 - val_loss: 0.5276 - val_accuracy: 0.7545 - lr: 0.0010 - 55ms/epoch - 14ms/step
# Epoch 28/60
# Restoring model weights from the end of the best epoch: 14.
#
# Epoch 27: val_accuracy did not improve from 0.78182
# 4/4 - 0s - loss: 0.4550 - accuracy: 0.7913 - val_loss: 0.5223 - val_accuracy: 0.7455 - lr: 1.0000e-05 - 46ms/epoch - 12ms/step
# Epoch 28/60
#
# Epoch 29: val_accuracy did not improve from 0.77273
#
# Epoch 28: val_accuracy improved from 0.77273 to 0.78182, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/1023model.keras
# 4/4 - 0s - loss: 0.4400 - accuracy: 0.8073 - val_loss: 0.5188 - val_accuracy: 0.7455 - lr: 1.0000e-04 - 63ms/epoch - 16ms/step
# Epoch 29: early stopping
# 4/4 - 0s - loss: 0.4428 - accuracy: 0.7959 - val_loss: 0.5033 - val_accuracy: 0.7818 - lr: 0.0010 - 64ms/epoch - 16ms/step
# Epoch 29/60
#
# Epoch 28: val_accuracy did not improve from 0.78182
# 4/4 - 0s - loss: 0.4549 - accuracy: 0.7913 - val_loss: 0.5224 - val_accuracy: 0.7455 - lr: 1.0000e-05 - 49ms/epoch - 12ms/step
# Epoch 29/60
#
# Epoch 29: val_accuracy did not improve from 0.78182
# 4/4 - 0s - loss: 0.4423 - accuracy: 0.8073 - val_loss: 0.5044 - val_accuracy: 0.7818 - lr: 0.0010 - 49ms/epoch - 12ms/step
# Epoch 30/60
#
# Epoch 29: val_accuracy did not improve from 0.78182
# 4/4 - 0s - loss: 0.4549 - accuracy: 0.7913 - val_loss: 0.5226 - val_accuracy: 0.7455 - lr: 1.0000e-05 - 51ms/epoch - 13ms/step
# Epoch 30/60
#
# Epoch 30: val_accuracy did not improve from 0.78182
# 4/4 - 0s - loss: 0.4388 - accuracy: 0.7982 - val_loss: 0.5163 - val_accuracy: 0.7727 - lr: 0.0010 - 45ms/epoch - 11ms/step
# Epoch 31/60
#
# Epoch 30: val_accuracy did not improve from 0.78182
# 4/4 - 0s - loss: 0.4549 - accuracy: 0.7913 - val_loss: 0.5228 - val_accuracy: 0.7455 - lr: 1.0000e-05 - 43ms/epoch - 11ms/step
# Epoch 31/60
#
# Epoch 31: val_accuracy did not improve from 0.78182
# 4/4 - 0s - loss: 0.4368 - accuracy: 0.8073 - val_loss: 0.5018 - val_accuracy: 0.7818 - lr: 0.0010 - 55ms/epoch - 14ms/step
# Epoch 32/60
# Restoring model weights from the end of the best epoch: 16.
#
# Epoch 31: val_accuracy did not improve from 0.78182
# 4/4 - 0s - loss: 0.4548 - accuracy: 0.7913 - val_loss: 0.5228 - val_accuracy: 0.7455 - lr: 1.0000e-05 - 47ms/epoch - 12ms/step
# Epoch 31: early stopping
#
# Epoch 32: val_accuracy did not improve from 0.78182
# 4/4 - 0s - loss: 0.4317 - accuracy: 0.8028 - val_loss: 0.5202 - val_accuracy: 0.7455 - lr: 0.0010 - 51ms/epoch - 13ms/step
# Epoch 33/60
#
# Epoch 33: val_accuracy did not improve from 0.78182
# 4/4 - 0s - loss: 0.4327 - accuracy: 0.8028 - val_loss: 0.5077 - val_accuracy: 0.7727 - lr: 0.0010 - 66ms/epoch - 17ms/step
# Epoch 34/60
#
# Epoch 34: val_accuracy did not improve from 0.78182
# 4/4 - 0s - loss: 0.4285 - accuracy: 0.8028 - val_loss: 0.4965 - val_accuracy: 0.7818 - lr: 0.0010 - 49ms/epoch - 12ms/step
# Epoch 35/60
#
# Epoch 35: val_accuracy did not improve from 0.78182
# 4/4 - 0s - loss: 0.4293 - accuracy: 0.8165 - val_loss: 0.5046 - val_accuracy: 0.7727 - lr: 0.0010 - 44ms/epoch - 11ms/step
# Epoch 36/60
#
# Epoch 36: val_accuracy did not improve from 0.78182
# 4/4 - 0s - loss: 0.4275 - accuracy: 0.8096 - val_loss: 0.5266 - val_accuracy: 0.7364 - lr: 0.0010 - 47ms/epoch - 12ms/step
# Epoch 37/60
#
# Epoch 37: val_accuracy did not improve from 0.78182
# 4/4 - 0s - loss: 0.4233 - accuracy: 0.8073 - val_loss: 0.4993 - val_accuracy: 0.7818 - lr: 0.0010 - 42ms/epoch - 10ms/step
# Epoch 38/60
#
# Epoch 38: val_accuracy did not improve from 0.78182
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 4/4 - 0s - loss: 0.4222 - accuracy: 0.8165 - val_loss: 0.4972 - val_accuracy: 0.7818 - lr: 0.0010 - 46ms/epoch - 12ms/step
# Epoch 39/60
#
# Epoch 39: val_accuracy did not improve from 0.78182
# 4/4 - 0s - loss: 0.4202 - accuracy: 0.8165 - val_loss: 0.4977 - val_accuracy: 0.7818 - lr: 1.0000e-04 - 44ms/epoch - 11ms/step
# Epoch 40/60
#
# Epoch 40: val_accuracy did not improve from 0.78182
# 4/4 - 0s - loss: 0.4196 - accuracy: 0.8142 - val_loss: 0.4992 - val_accuracy: 0.7727 - lr: 1.0000e-04 - 43ms/epoch - 11ms/step
# Epoch 41/60
#
# Epoch 41: val_accuracy did not improve from 0.78182
# 4/4 - 0s - loss: 0.4186 - accuracy: 0.8096 - val_loss: 0.5007 - val_accuracy: 0.7727 - lr: 1.0000e-04 - 42ms/epoch - 10ms/step
# Epoch 42/60
#
# Epoch 42: val_accuracy did not improve from 0.78182
# 4/4 - 0s - loss: 0.4180 - accuracy: 0.8050 - val_loss: 0.5025 - val_accuracy: 0.7727 - lr: 1.0000e-04 - 51ms/epoch - 13ms/step
# Epoch 43/60
# Restoring model weights from the end of the best epoch: 28.
#
# Epoch 43: val_accuracy did not improve from 0.78182
# 4/4 - 0s - loss: 0.4174 - accuracy: 0.8050 - val_loss: 0.5045 - val_accuracy: 0.7818 - lr: 1.0000e-04 - 52ms/epoch - 13ms/step
# Epoch 43: early stopping
# Epoch 1/60
# Epoch 1/60
# Epoch 1/60
# Epoch 1/60
# Epoch 1/60
# Epoch 1/60
# Epoch 1/60
# Epoch 1/60
#
# Epoch 1: val_accuracy improved from -inf to 0.64545, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/1230model.keras
#
# Epoch 1: val_accuracy improved from -inf to 0.52727, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/2013model.keras
#
# Epoch 1: val_accuracy improved from -inf to 0.65455, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/2103model.keras
#
# Epoch 1: val_accuracy improved from -inf to 0.66364, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/1302model.keras
#
# Epoch 1: val_accuracy improved from -inf to 0.70909, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/1320model.keras
# 4/4 - 1s - loss: 0.8482 - accuracy: 0.6858 - val_loss: 0.7208 - val_accuracy: 0.5273 - lr: 0.0010 - 860ms/epoch - 215ms/step
# 4/4 - 1s - loss: 0.5953 - accuracy: 0.7248 - val_loss: 0.6336 - val_accuracy: 0.6455 - lr: 0.0010 - 847ms/epoch - 212ms/step
# Epoch 2/60
# Epoch 2/60
#
# Epoch 1: val_accuracy improved from -inf to 0.66364, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/2031model.keras
#
# Epoch 1: val_accuracy improved from -inf to 0.70000, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/2130model.keras
# 4/4 - 1s - loss: 1.0292 - accuracy: 0.3601 - val_loss: 0.6983 - val_accuracy: 0.6636 - lr: 0.0010 - 846ms/epoch - 211ms/step
# Epoch 2/60
# 4/4 - 1s - loss: 0.6219 - accuracy: 0.6858 - val_loss: 0.6011 - val_accuracy: 0.6545 - lr: 0.0010 - 861ms/epoch - 215ms/step
# Epoch 2/60
#
# Epoch 1: val_accuracy improved from -inf to 0.74545, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/1203model.keras
# 4/4 - 1s - loss: 0.8105 - accuracy: 0.5023 - val_loss: 0.7360 - val_accuracy: 0.7091 - lr: 0.0010 - 864ms/epoch - 216ms/step
# Epoch 2/60
# 4/4 - 1s - loss: 0.6656 - accuracy: 0.6606 - val_loss: 0.6144 - val_accuracy: 0.6636 - lr: 0.0010 - 857ms/epoch - 214ms/step
# Epoch 2/60
# 4/4 - 1s - loss: 0.9822 - accuracy: 0.3509 - val_loss: 0.7032 - val_accuracy: 0.7000 - lr: 0.0010 - 885ms/epoch - 221ms/step
# Epoch 2/60
#
# Epoch 2: val_accuracy improved from 0.64545 to 0.69091, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/1230model.keras
#
# Epoch 2: val_accuracy improved from 0.52727 to 0.55455, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/2013model.keras
#
# Epoch 2: val_accuracy improved from 0.65455 to 0.69091, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/2103model.keras
# 4/4 - 1s - loss: 0.6461 - accuracy: 0.6284 - val_loss: 0.6097 - val_accuracy: 0.7455 - lr: 0.0010 - 900ms/epoch - 225ms/step
# Epoch 2/60
#
# Epoch 2: val_accuracy improved from 0.66364 to 0.74545, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/1302model.keras
# 4/4 - 0s - loss: 0.5770 - accuracy: 0.7362 - val_loss: 0.5683 - val_accuracy: 0.6909 - lr: 0.0010 - 74ms/epoch - 19ms/step
# Epoch 3/60
#
# Epoch 2: val_accuracy improved from 0.66364 to 0.72727, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/2031model.keras
# 4/4 - 0s - loss: 0.7405 - accuracy: 0.4908 - val_loss: 0.6943 - val_accuracy: 0.5545 - lr: 0.0010 - 89ms/epoch - 22ms/step
# 4/4 - 0s - loss: 0.5790 - accuracy: 0.7202 - val_loss: 0.5597 - val_accuracy: 0.6909 - lr: 0.0010 - 76ms/epoch - 19ms/step
# Epoch 3/60
# Epoch 3/60
#
# Epoch 2: val_accuracy improved from 0.70909 to 0.72727, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/1320model.keras
# 4/4 - 0s - loss: 0.7321 - accuracy: 0.6904 - val_loss: 0.7716 - val_accuracy: 0.7455 - lr: 0.0010 - 94ms/epoch - 24ms/step
#
# Epoch 2: val_accuracy improved from 0.70000 to 0.72727, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/2130model.keras
# Epoch 3/60
#
# Epoch 2: val_accuracy improved from 0.74545 to 0.77273, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/1203model.keras
# 4/4 - 0s - loss: 0.6091 - accuracy: 0.6927 - val_loss: 0.5809 - val_accuracy: 0.7273 - lr: 0.0010 - 88ms/epoch - 22ms/step
#
# Epoch 3: val_accuracy did not improve from 0.69091
# 4/4 - 0s - loss: 0.5699 - accuracy: 0.7225 - val_loss: 0.5701 - val_accuracy: 0.6909 - lr: 0.0010 - 45ms/epoch - 11ms/step
# Epoch 3/60
# Epoch 4/60
# ...
# 4/4 - 0s - loss: 0.4705 - accuracy: 0.7775 - val_loss: 0.5100 - val_accuracy: 0.7273 - lr: 0.0010 - 57ms/epoch - 14ms/step
# Epoch 20/60
# Epoch 22/60
#
# Epoch 18: val_accuracy improved from 0.80000 to 0.80909, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/3102model.keras
#
# Epoch 19: val_accuracy did not improve from 0.79091
# 4/4 - 0s - loss: 0.4618 - accuracy: 0.7867 - val_loss: 0.5426 - val_accuracy: 0.7000 - lr: 0.0010 - 44ms/epoch - 11ms/step
# Epoch 20/60
# 4/4 - 0s - loss: 0.4906 - accuracy: 0.7821 - val_loss: 0.5107 - val_accuracy: 0.8091 - lr: 0.0010 - 61ms/epoch - 15ms/step
#
# Epoch 21: val_accuracy did not improve from 0.79091
# 4/4 - 0s - loss: 0.4616 - accuracy: 0.7913 - val_loss: 0.5217 - val_accuracy: 0.7636 - lr: 1.0000e-04 - 64ms/epoch - 16ms/step
# Epoch 22/60
# Epoch 19/60
#
# Epoch 19: val_accuracy did not improve from 0.79091
#
# Epoch 21: val_accuracy did not improve from 0.76364
# 4/4 - 0s - loss: 0.4555 - accuracy: 0.8096 - val_loss: 0.5078 - val_accuracy: 0.7364 - lr: 0.0010 - 70ms/epoch - 17ms/step
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 20/60
# 4/4 - 0s - loss: 0.4842 - accuracy: 0.7821 - val_loss: 0.5190 - val_accuracy: 0.7636 - lr: 0.0010 - 68ms/epoch - 17ms/step
# Epoch 22/60
#
# Epoch 20: val_accuracy did not improve from 0.75455
#
# Epoch 20: val_accuracy did not improve from 0.79091
#
# Epoch 22: val_accuracy did not improve from 0.80000
# 4/4 - 0s - loss: 0.4575 - accuracy: 0.8028 - val_loss: 0.5204 - val_accuracy: 0.7091 - lr: 1.0000e-04 - 63ms/epoch - 16ms/step
# 4/4 - 0s - loss: 0.4652 - accuracy: 0.7729 - val_loss: 0.4994 - val_accuracy: 0.7636 - lr: 0.0010 - 63ms/epoch - 16ms/step
# 4/4 - 0s - loss: 0.4620 - accuracy: 0.7752 - val_loss: 0.5202 - val_accuracy: 0.7545 - lr: 0.0010 - 50ms/epoch - 12ms/step
# Epoch 21/60
# Epoch 23/60
# Epoch 21/60
#
# Epoch 22: val_accuracy did not improve from 0.79091
# 4/4 - 0s - loss: 0.4610 - accuracy: 0.7844 - val_loss: 0.5233 - val_accuracy: 0.7636 - lr: 1.0000e-04 - 46ms/epoch - 12ms/step
#
# Epoch 19: val_accuracy did not improve from 0.80909
# Epoch 23/60
# 4/4 - 0s - loss: 0.4887 - accuracy: 0.7913 - val_loss: 0.5042 - val_accuracy: 0.8000 - lr: 0.0010 - 52ms/epoch - 13ms/step
# Epoch 20/60
#
# Epoch 22: val_accuracy did not improve from 0.76364
#
# Epoch 21: val_accuracy did not improve from 0.75455
#
# Epoch 23: val_accuracy did not improve from 0.80000
# 4/4 - 0s - loss: 0.4788 - accuracy: 0.7867 - val_loss: 0.5212 - val_accuracy: 0.7545 - lr: 1.0000e-04 - 48ms/epoch - 12ms/step
# 4/4 - 0s - loss: 0.4573 - accuracy: 0.8050 - val_loss: 0.5219 - val_accuracy: 0.7182 - lr: 1.0000e-04 - 44ms/epoch - 11ms/step
# 4/4 - 0s - loss: 0.4635 - accuracy: 0.7936 - val_loss: 0.4964 - val_accuracy: 0.7727 - lr: 0.0010 - 45ms/epoch - 11ms/step
# Epoch 23/60
#
# Epoch 21: val_accuracy did not improve from 0.79091
#
# Epoch 20: val_accuracy did not improve from 0.79091
# Epoch 22/60
# Epoch 24/60
# 4/4 - 0s - loss: 0.4524 - accuracy: 0.8096 - val_loss: 0.5157 - val_accuracy: 0.7182 - lr: 0.0010 - 55ms/epoch - 14ms/step
# 4/4 - 0s - loss: 0.4593 - accuracy: 0.8005 - val_loss: 0.5076 - val_accuracy: 0.7909 - lr: 0.0010 - 47ms/epoch - 12ms/step
# Epoch 21/60
# Epoch 22/60
#
# Epoch 23: val_accuracy did not improve from 0.79091
# 4/4 - 0s - loss: 0.4606 - accuracy: 0.7867 - val_loss: 0.5248 - val_accuracy: 0.7636 - lr: 1.0000e-04 - 61ms/epoch - 15ms/step
# Epoch 24/60
#
# Epoch 20: val_accuracy did not improve from 0.80909
# 4/4 - 0s - loss: 0.4842 - accuracy: 0.7867 - val_loss: 0.5070 - val_accuracy: 0.7909 - lr: 0.0010 - 63ms/epoch - 16ms/step
# Epoch 21/60
#
# Epoch 21: val_accuracy did not improve from 0.79091
#
# Epoch 22: val_accuracy did not improve from 0.75455
# 4/4 - 0s - loss: 0.4510 - accuracy: 0.8005 - val_loss: 0.5114 - val_accuracy: 0.7273 - lr: 0.0010 - 44ms/epoch - 11ms/step
# 4/4 - 0s - loss: 0.4569 - accuracy: 0.8073 - val_loss: 0.5219 - val_accuracy: 0.7182 - lr: 1.0000e-04 - 50ms/epoch - 13ms/step
#
# Epoch 23: val_accuracy did not improve from 0.76364
#
# Epoch 24: val_accuracy did not improve from 0.80000
# Epoch 22/60
# Epoch 23/60
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 4/4 - 0s - loss: 0.4782 - accuracy: 0.7936 - val_loss: 0.5220 - val_accuracy: 0.7545 - lr: 1.0000e-04 - 56ms/epoch - 14ms/step
# 4/4 - 0s - loss: 0.4619 - accuracy: 0.7913 - val_loss: 0.5030 - val_accuracy: 0.7545 - lr: 0.0010 - 56ms/epoch - 14ms/step
# Epoch 24/60
#
# Epoch 22: val_accuracy did not improve from 0.79091
# Epoch 25/60
# 4/4 - 0s - loss: 0.4524 - accuracy: 0.8119 - val_loss: 0.5238 - val_accuracy: 0.7455 - lr: 0.0010 - 59ms/epoch - 15ms/step
# Epoch 23/60
# Restoring model weights from the end of the best epoch: 9.
#
# Epoch 24: val_accuracy did not improve from 0.79091
# 4/4 - 0s - loss: 0.4602 - accuracy: 0.7867 - val_loss: 0.5252 - val_accuracy: 0.7636 - lr: 1.0000e-04 - 50ms/epoch - 13ms/step
# Epoch 24: early stopping
#
# Epoch 21: val_accuracy did not improve from 0.80909
# 4/4 - 0s - loss: 0.4809 - accuracy: 0.7844 - val_loss: 0.5106 - val_accuracy: 0.8000 - lr: 0.0010 - 49ms/epoch - 12ms/step
# Epoch 22/60
# Restoring model weights from the end of the best epoch: 8.
#
# Epoch 23: val_accuracy did not improve from 0.75455
# 4/4 - 0s - loss: 0.4566 - accuracy: 0.8073 - val_loss: 0.5211 - val_accuracy: 0.7182 - lr: 1.0000e-04 - 48ms/epoch - 12ms/step
# Epoch 23: early stopping
#
# Epoch 22: val_accuracy did not improve from 0.79091
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 4/4 - 0s - loss: 0.4484 - accuracy: 0.8142 - val_loss: 0.5010 - val_accuracy: 0.7545 - lr: 0.0010 - 62ms/epoch - 16ms/step
# Epoch 23/60
#
# Epoch 24: val_accuracy did not improve from 0.76364
# 4/4 - 0s - loss: 0.4779 - accuracy: 0.7936 - val_loss: 0.5222 - val_accuracy: 0.7545 - lr: 1.0000e-04 - 63ms/epoch - 16ms/step
# Epoch 25/60
#
# Epoch 25: val_accuracy did not improve from 0.80000
# 4/4 - 0s - loss: 0.4583 - accuracy: 0.7798 - val_loss: 0.5030 - val_accuracy: 0.7545 - lr: 1.0000e-04 - 69ms/epoch - 17ms/step
#
# Epoch 23: val_accuracy did not improve from 0.79091
# 4/4 - 0s - loss: 0.4545 - accuracy: 0.7936 - val_loss: 0.5203 - val_accuracy: 0.7455 - lr: 0.0010 - 67ms/epoch - 17ms/step
# Epoch 26/60
# Epoch 24/60
#
# Epoch 22: val_accuracy did not improve from 0.80909
# 4/4 - 0s - loss: 0.4782 - accuracy: 0.7890 - val_loss: 0.5054 - val_accuracy: 0.7909 - lr: 0.0010 - 57ms/epoch - 14ms/step
# Epoch 23/60
#
# Epoch 23: val_accuracy did not improve from 0.79091
# 4/4 - 0s - loss: 0.4453 - accuracy: 0.8234 - val_loss: 0.5024 - val_accuracy: 0.7364 - lr: 1.0000e-04 - 44ms/epoch - 11ms/step
# Epoch 24/60
#
# Epoch 25: val_accuracy did not improve from 0.76364
# 4/4 - 0s - loss: 0.4776 - accuracy: 0.7936 - val_loss: 0.5219 - val_accuracy: 0.7545 - lr: 1.0000e-04 - 53ms/epoch - 13ms/step
# Epoch 26/60
#
# Epoch 26: val_accuracy did not improve from 0.80000
#
# Epoch 24: val_accuracy improved from 0.79091 to 0.80000, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/2301model.keras
# 4/4 - 0s - loss: 0.4580 - accuracy: 0.7821 - val_loss: 0.5035 - val_accuracy: 0.7545 - lr: 1.0000e-04 - 64ms/epoch - 16ms/step
# Epoch 27/60
#
# Epoch 24: val_accuracy did not improve from 0.79091
# 4/4 - 0s - loss: 0.4447 - accuracy: 0.8142 - val_loss: 0.5049 - val_accuracy: 0.7273 - lr: 1.0000e-04 - 51ms/epoch - 13ms/step
# Epoch 25/60
#
# Epoch 23: val_accuracy did not improve from 0.80909
# 4/4 - 0s - loss: 0.4751 - accuracy: 0.7913 - val_loss: 0.5022 - val_accuracy: 0.8091 - lr: 0.0010 - 76ms/epoch - 19ms/step
# 4/4 - 0s - loss: 0.4446 - accuracy: 0.8050 - val_loss: 0.5037 - val_accuracy: 0.8000 - lr: 0.0010 - 85ms/epoch - 21ms/step
# Epoch 25/60
# Epoch 24/60
# Restoring model weights from the end of the best epoch: 11.
#
# Epoch 26: val_accuracy did not improve from 0.76364
# 4/4 - 0s - loss: 0.4774 - accuracy: 0.7982 - val_loss: 0.5207 - val_accuracy: 0.7545 - lr: 1.0000e-04 - 60ms/epoch - 15ms/step
# Epoch 26: early stopping
#
# Epoch 27: val_accuracy did not improve from 0.80000
# 4/4 - 0s - loss: 0.4577 - accuracy: 0.7798 - val_loss: 0.5032 - val_accuracy: 0.7545 - lr: 1.0000e-04 - 63ms/epoch - 16ms/step
# Epoch 28/60
#
# Epoch 25: val_accuracy did not improve from 0.80000
# 4/4 - 0s - loss: 0.4511 - accuracy: 0.7959 - val_loss: 0.5094 - val_accuracy: 0.7636 - lr: 0.0010 - 46ms/epoch - 11ms/step
# Epoch 26/60
#
# Epoch 25: val_accuracy did not improve from 0.79091
# 4/4 - 0s - loss: 0.4441 - accuracy: 0.8096 - val_loss: 0.5071 - val_accuracy: 0.7273 - lr: 1.0000e-04 - 62ms/epoch - 16ms/step
# Epoch 26/60
#
# Epoch 24: val_accuracy did not improve from 0.80909
# 4/4 - 0s - loss: 0.4724 - accuracy: 0.7959 - val_loss: 0.5007 - val_accuracy: 0.8091 - lr: 0.0010 - 64ms/epoch - 16ms/step
# Epoch 25/60
#
# Epoch 28: val_accuracy did not improve from 0.80000
# 4/4 - 0s - loss: 0.4574 - accuracy: 0.7821 - val_loss: 0.5025 - val_accuracy: 0.7545 - lr: 1.0000e-04 - 50ms/epoch - 12ms/step
# Epoch 29/60
#
# Epoch 26: val_accuracy did not improve from 0.80000
# 4/4 - 0s - loss: 0.4385 - accuracy: 0.8165 - val_loss: 0.5251 - val_accuracy: 0.7364 - lr: 0.0010 - 54ms/epoch - 13ms/step
# Epoch 27/60
#
# Epoch 25: val_accuracy did not improve from 0.80909
#
# Epoch 26: val_accuracy did not improve from 0.79091
# 4/4 - 0s - loss: 0.4692 - accuracy: 0.7982 - val_loss: 0.5045 - val_accuracy: 0.7909 - lr: 0.0010 - 47ms/epoch - 12ms/step
# 4/4 - 0s - loss: 0.4440 - accuracy: 0.8096 - val_loss: 0.5101 - val_accuracy: 0.7273 - lr: 1.0000e-04 - 58ms/epoch - 15ms/step
# Epoch 26/60
# Epoch 27/60
# Restoring model weights from the end of the best epoch: 14.
#
# Epoch 27: val_accuracy did not improve from 0.80000
#
# Epoch 29: val_accuracy did not improve from 0.80000
# 4/4 - 0s - loss: 0.4412 - accuracy: 0.8142 - val_loss: 0.5186 - val_accuracy: 0.7545 - lr: 0.0010 - 53ms/epoch - 13ms/step
# 4/4 - 0s - loss: 0.4572 - accuracy: 0.7821 - val_loss: 0.5023 - val_accuracy: 0.7545 - lr: 1.0000e-04 - 63ms/epoch - 16ms/step
#
# Epoch 26: val_accuracy did not improve from 0.80909
# Epoch 28/60
# Epoch 29: early stopping
# 4/4 - 0s - loss: 0.4679 - accuracy: 0.7936 - val_loss: 0.5011 - val_accuracy: 0.7909 - lr: 0.0010 - 46ms/epoch - 12ms/step
# Epoch 27/60
# Restoring model weights from the end of the best epoch: 12.
#
# Epoch 27: val_accuracy did not improve from 0.79091
# 4/4 - 0s - loss: 0.4439 - accuracy: 0.8096 - val_loss: 0.5115 - val_accuracy: 0.7091 - lr: 1.0000e-04 - 57ms/epoch - 14ms/step
# Epoch 27: early stopping
#
# Epoch 28: val_accuracy did not improve from 0.80000
# 4/4 - 0s - loss: 0.4421 - accuracy: 0.8028 - val_loss: 0.5175 - val_accuracy: 0.7364 - lr: 0.0010 - 51ms/epoch - 13ms/step
# Epoch 29/60
#
# Epoch 27: val_accuracy improved from 0.80909 to 0.82727, saving model to _OA_results_BreastMNIST_train_with_val/run_1FC/15/3102model.keras
# 4/4 - 0s - loss: 0.4660 - accuracy: 0.7913 - val_loss: 0.4931 - val_accuracy: 0.8273 - lr: 0.0010 - 93ms/epoch - 23ms/step
# Epoch 28/60
#
# Epoch 29: val_accuracy did not improve from 0.80000
# 4/4 - 0s - loss: 0.4321 - accuracy: 0.8142 - val_loss: 0.4954 - val_accuracy: 0.7727 - lr: 0.0010 - 63ms/epoch - 16ms/step
# Epoch 30/60
#
# Epoch 28: val_accuracy did not improve from 0.82727
# 4/4 - 0s - loss: 0.4629 - accuracy: 0.7913 - val_loss: 0.4953 - val_accuracy: 0.8000 - lr: 0.0010 - 64ms/epoch - 16ms/step
# Epoch 29/60
#
# Epoch 30: val_accuracy did not improve from 0.80000
# 4/4 - 0s - loss: 0.4319 - accuracy: 0.8096 - val_loss: 0.5031 - val_accuracy: 0.7545 - lr: 0.0010 - 54ms/epoch - 13ms/step
# Epoch 31/60
#
# Epoch 29: val_accuracy did not improve from 0.82727
# 4/4 - 0s - loss: 0.4606 - accuracy: 0.8005 - val_loss: 0.4956 - val_accuracy: 0.7909 - lr: 0.0010 - 51ms/epoch - 13ms/step
#
# Epoch 31: val_accuracy did not improve from 0.80000
# Epoch 30/60
# 4/4 - 0s - loss: 0.4297 - accuracy: 0.8234 - val_loss: 0.5182 - val_accuracy: 0.7364 - lr: 0.0010 - 42ms/epoch - 11ms/step
# Epoch 32/60
#
# Epoch 30: val_accuracy did not improve from 0.82727
# 4/4 - 0s - loss: 0.4592 - accuracy: 0.7959 - val_loss: 0.4983 - val_accuracy: 0.7909 - lr: 0.0010 - 48ms/epoch - 12ms/step
#
# Epoch 32: val_accuracy did not improve from 0.80000
# Epoch 31/60
# 4/4 - 0s - loss: 0.4266 - accuracy: 0.8234 - val_loss: 0.4967 - val_accuracy: 0.7545 - lr: 0.0010 - 47ms/epoch - 12ms/step
# Epoch 33/60
#
# Epoch 33: val_accuracy did not improve from 0.80000
#
# Epoch 31: val_accuracy did not improve from 0.82727
# 4/4 - 0s - loss: 0.4239 - accuracy: 0.8188 - val_loss: 0.4982 - val_accuracy: 0.7545 - lr: 0.0010 - 44ms/epoch - 11ms/step
# 4/4 - 0s - loss: 0.4563 - accuracy: 0.7982 - val_loss: 0.4922 - val_accuracy: 0.8091 - lr: 0.0010 - 49ms/epoch - 12ms/step
# Epoch 34/60
# Epoch 32/60
#
# Epoch 34: val_accuracy did not improve from 0.80000
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 4/4 - 0s - loss: 0.4265 - accuracy: 0.8188 - val_loss: 0.5139 - val_accuracy: 0.7545 - lr: 0.0010 - 46ms/epoch - 11ms/step
# Epoch 35/60
#
# Epoch 32: val_accuracy did not improve from 0.82727
# 4/4 - 0s - loss: 0.4567 - accuracy: 0.8050 - val_loss: 0.4889 - val_accuracy: 0.8273 - lr: 0.0010 - 58ms/epoch - 15ms/step
# Epoch 33/60
#
# Epoch 35: val_accuracy did not improve from 0.80000
# 4/4 - 0s - loss: 0.4208 - accuracy: 0.8257 - val_loss: 0.5103 - val_accuracy: 0.7636 - lr: 1.0000e-04 - 47ms/epoch - 12ms/step
# Epoch 36/60
#
# Epoch 33: val_accuracy did not improve from 0.82727
# 4/4 - 0s - loss: 0.4529 - accuracy: 0.8005 - val_loss: 0.4991 - val_accuracy: 0.8000 - lr: 0.0010 - 45ms/epoch - 11ms/step
# Epoch 34/60
#
# Epoch 36: val_accuracy did not improve from 0.80000
# 4/4 - 0s - loss: 0.4199 - accuracy: 0.8280 - val_loss: 0.5069 - val_accuracy: 0.7545 - lr: 1.0000e-04 - 62ms/epoch - 16ms/step
# Epoch 37/60
#
# Epoch 34: val_accuracy did not improve from 0.82727
# 4/4 - 0s - loss: 0.4513 - accuracy: 0.8005 - val_loss: 0.5016 - val_accuracy: 0.7818 - lr: 0.0010 - 63ms/epoch - 16ms/step
# Epoch 35/60
#
# Epoch 35: val_accuracy did not improve from 0.82727
# 4/4 - 0s - loss: 0.4489 - accuracy: 0.7982 - val_loss: 0.4915 - val_accuracy: 0.7909 - lr: 0.0010 - 42ms/epoch - 11ms/step
#
# Epoch 37: val_accuracy did not improve from 0.80000
# Epoch 36/60
# 4/4 - 0s - loss: 0.4194 - accuracy: 0.8303 - val_loss: 0.5040 - val_accuracy: 0.7545 - lr: 1.0000e-04 - 56ms/epoch - 14ms/step
# Epoch 38/60
#
# Epoch 36: val_accuracy did not improve from 0.82727
# 4/4 - 0s - loss: 0.4477 - accuracy: 0.8005 - val_loss: 0.4825 - val_accuracy: 0.8182 - lr: 0.0010 - 47ms/epoch - 12ms/step
#
# Epoch 38: val_accuracy did not improve from 0.80000
# Epoch 37/60
# 4/4 - 0s - loss: 0.4187 - accuracy: 0.8257 - val_loss: 0.5023 - val_accuracy: 0.7545 - lr: 1.0000e-04 - 46ms/epoch - 12ms/step
# Epoch 39/60
# Restoring model weights from the end of the best epoch: 24.
#
# Epoch 37: val_accuracy did not improve from 0.82727
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 39: val_accuracy did not improve from 0.80000
# 4/4 - 0s - loss: 0.4461 - accuracy: 0.8050 - val_loss: 0.4847 - val_accuracy: 0.8000 - lr: 0.0010 - 62ms/epoch - 16ms/step
# 4/4 - 0s - loss: 0.4185 - accuracy: 0.8257 - val_loss: 0.5004 - val_accuracy: 0.7545 - lr: 1.0000e-04 - 60ms/epoch - 15ms/step
# Epoch 39: early stopping
# Epoch 38/60
#
# Epoch 38: val_accuracy did not improve from 0.82727
# 4/4 - 0s - loss: 0.4434 - accuracy: 0.8005 - val_loss: 0.4852 - val_accuracy: 0.7909 - lr: 1.0000e-04 - 52ms/epoch - 13ms/step
# Epoch 39/60
#
# Epoch 39: val_accuracy did not improve from 0.82727
# 4/4 - 0s - loss: 0.4432 - accuracy: 0.8028 - val_loss: 0.4857 - val_accuracy: 0.7909 - lr: 1.0000e-04 - 70ms/epoch - 17ms/step
# Epoch 40/60
#
# Epoch 40: val_accuracy did not improve from 0.82727
# 4/4 - 0s - loss: 0.4428 - accuracy: 0.8050 - val_loss: 0.4853 - val_accuracy: 0.7909 - lr: 1.0000e-04 - 68ms/epoch - 17ms/step
# Epoch 41/60
#
# Epoch 41: val_accuracy did not improve from 0.82727
# 4/4 - 0s - loss: 0.4427 - accuracy: 0.8050 - val_loss: 0.4853 - val_accuracy: 0.7909 - lr: 1.0000e-04 - 64ms/epoch - 16ms/step
# Epoch 42/60
# Restoring model weights from the end of the best epoch: 27.
#
# Epoch 42: val_accuracy did not improve from 0.82727
# 4/4 - 0s - loss: 0.4425 - accuracy: 0.8005 - val_loss: 0.4847 - val_accuracy: 0.7909 - lr: 1.0000e-04 - 56ms/epoch - 14ms/step
# Epoch 42: early stopping

# %%
# for ind, variant  in enumerate(permutations):

#     label = ''.join(map(str,variant))
#     print(ind, label)
#     tr_images = train_layer.open(variant)
#     te_images =  test_layer.open(variant)
#     run(tr_images,te_images,label)

# %%
# # run the network without filter
# P = ["NO-FILTER",]
# with ProcessPoolExecutor(8) as executor:
#     runner = {
#         executor.submit(run, label= p, tr_images = train_images, te_images= test_images): p for p in P
#     }
#     for future in as_completed(runner):
#         runner.pop(future)

# %%
with ProcessPoolExecutor(max_workers=None) as executor: # max_workers=None uses the number of CPU cores
    results = executor.map(run, (train_images,test_images,"_NO-FILTER"))

# %%
# run the network without filter

run(train_images, "NO-FILTER")
# Out:
# Epoch 1/60
# Epoch 1: val_accuracy improved from -inf to 0.75455, saving model to _OA_results_BreastMNIST_train_with_val/run_3FC/15/NO-FILTERmodel.keras
# 4/4 - 1s - loss: 0.7307 - accuracy: 0.6766 - val_loss: 0.5475 - val_accuracy: 0.7545 - lr: 0.0010 - 1s/epoch - 299ms/step
# Epoch 2/60
#
# Epoch 2: val_accuracy did not improve from 0.75455
# 4/4 - 0s - loss: 0.5144 - accuracy: 0.7729 - val_loss: 0.5204 - val_accuracy: 0.7364 - lr: 0.0010 - 82ms/epoch - 21ms/step
# Epoch 3/60
#
# Epoch 3: val_accuracy improved from 0.75455 to 0.80909, saving model to _OA_results_BreastMNIST_train_with_val/run_3FC/15/NO-FILTERmodel.keras
# 4/4 - 0s - loss: 0.4539 - accuracy: 0.7959 - val_loss: 0.4633 - val_accuracy: 0.8091 - lr: 0.0010 - 141ms/epoch - 35ms/step
# Epoch 4/60
#
# Epoch 4: val_accuracy did not improve from 0.80909
# 4/4 - 0s - loss: 0.4354 - accuracy: 0.8050 - val_loss: 0.4773 - val_accuracy: 0.7364 - lr: 0.0010 - 82ms/epoch - 20ms/step
# Epoch 5/60
#
# Epoch 5: val_accuracy did not improve from 0.80909
# 4/4 - 0s - loss: 0.4110 - accuracy: 0.8211 - val_loss: 0.7365 - val_accuracy: 0.5636 - lr: 0.0010 - 85ms/epoch - 21ms/step
# Epoch 6/60
#
# Epoch 6: val_accuracy did not improve from 0.80909
# 4/4 - 0s - loss: 0.4432 - accuracy: 0.8005 - val_loss: 0.4580 - val_accuracy: 0.8000 - lr: 0.0010 - 85ms/epoch - 21ms/step
# Epoch 7/60
#
# Epoch 7: val_accuracy did not improve from 0.80909
# 4/4 - 0s - loss: 0.3939 - accuracy: 0.8326 - val_loss: 0.5160 - val_accuracy: 0.7273 - lr: 0.0010 - 92ms/epoch - 23ms/step
# Epoch 8/60
#
# Epoch 8: val_accuracy did not improve from 0.80909
# 4/4 - 0s - loss: 0.3525 - accuracy: 0.8303 - val_loss: 0.4840 - val_accuracy: 0.7818 - lr: 0.0010 - 88ms/epoch - 22ms/step
# Epoch 9/60
#
# Epoch 9: val_accuracy improved from 0.80909 to 0.81818, saving model to _OA_results_BreastMNIST_train_with_val/run_3FC/15/NO-FILTERmodel.keras
# 4/4 - 0s - loss: 0.3451 - accuracy: 0.8463 - val_loss: 0.4414 - val_accuracy: 0.8182 - lr: 0.0010 - 135ms/epoch - 34ms/step
# Epoch 10/60
#
# Epoch 10: val_accuracy did not improve from 0.81818
# 4/4 - 0s - loss: 0.3055 - accuracy: 0.8601 - val_loss: 0.5563 - val_accuracy: 0.7182 - lr: 0.0010 - 74ms/epoch - 18ms/step
# Epoch 11/60
#
# Epoch 11: val_accuracy did not improve from 0.81818
# 4/4 - 0s - loss: 0.3053 - accuracy: 0.8739 - val_loss: 0.4777 - val_accuracy: 0.8091 - lr: 0.0010 - 88ms/epoch - 22ms/step
# Epoch 12/60
#
# Epoch 12: val_accuracy did not improve from 0.81818
# 4/4 - 0s - loss: 0.2885 - accuracy: 0.8761 - val_loss: 0.4857 - val_accuracy: 0.7818 - lr: 0.0010 - 85ms/epoch - 21ms/step
# Epoch 13/60
#
# Epoch 13: val_accuracy did not improve from 0.81818
# 4/4 - 0s - loss: 0.2444 - accuracy: 0.8945 - val_loss: 0.5100 - val_accuracy: 0.7727 - lr: 0.0010 - 88ms/epoch - 22ms/step
# Epoch 14/60
#
# Epoch 14: val_accuracy did not improve from 0.81818
# 4/4 - 0s - loss: 0.2469 - accuracy: 0.9266 - val_loss: 0.4732 - val_accuracy: 0.8000 - lr: 0.0010 - 85ms/epoch - 21ms/step
# Epoch 15/60
#
# Epoch 15: val_accuracy did not improve from 0.81818
# 4/4 - 0s - loss: 0.2340 - accuracy: 0.9083 - val_loss: 0.6180 - val_accuracy: 0.7091 - lr: 0.0010 - 90ms/epoch - 22ms/step
# Epoch 16/60
#
# Epoch 16: val_accuracy did not improve from 0.81818
# 4/4 - 0s - loss: 0.2266 - accuracy: 0.8945 - val_loss: 0.5292 - val_accuracy: 0.7545 - lr: 0.0010 - 82ms/epoch - 21ms/step
# Epoch 17/60
#
# Epoch 17: val_accuracy improved from 0.81818 to 0.82727, saving model to _OA_results_BreastMNIST_train_with_val/run_3FC/15/NO-FILTERmodel.keras
# 4/4 - 0s - loss: 0.1959 - accuracy: 0.9541 - val_loss: 0.4912 - val_accuracy: 0.8273 - lr: 0.0010 - 157ms/epoch - 39ms/step
# Epoch 18/60
#
# Epoch 18: val_accuracy did not improve from 0.82727
# 4/4 - 0s - loss: 0.1562 - accuracy: 0.9564 - val_loss: 0.4806 - val_accuracy: 0.8091 - lr: 0.0010 - 87ms/epoch - 22ms/step
# Epoch 19/60
#
# Epoch 19: val_accuracy did not improve from 0.82727
# 4/4 - 0s - loss: 0.1429 - accuracy: 0.9495 - val_loss: 0.5310 - val_accuracy: 0.8000 - lr: 0.0010 - 83ms/epoch - 21ms/step
# Epoch 20/60
#
# Epoch 20: val_accuracy did not improve from 0.82727
# 4/4 - 0s - loss: 0.1248 - accuracy: 0.9656 - val_loss: 0.5666 - val_accuracy: 0.7818 - lr: 0.0010 - 81ms/epoch - 20ms/step
# Epoch 21/60
#
# Epoch 21: val_accuracy did not improve from 0.82727
# 4/4 - 0s - loss: 0.1121 - accuracy: 0.9725 - val_loss: 0.5144 - val_accuracy: 0.8091 - lr: 0.0010 - 83ms/epoch - 21ms/step
# Epoch 22/60
#
# Epoch 22: val_accuracy did not improve from 0.82727
# 4/4 - 0s - loss: 0.0933 - accuracy: 0.9794 - val_loss: 0.5777 - val_accuracy: 0.7909 - lr: 0.0010 - 79ms/epoch - 20ms/step
# Epoch 23/60
#
# Epoch 23: val_accuracy did not improve from 0.82727
# 4/4 - 0s - loss: 0.0945 - accuracy: 0.9748 - val_loss: 0.5548 - val_accuracy: 0.8182 - lr: 0.0010 - 88ms/epoch - 22ms/step
# Epoch 24/60
#
# Epoch 24: val_accuracy improved from 0.82727 to 0.83636, saving model to _OA_results_BreastMNIST_train_with_val/run_3FC/15/NO-FILTERmodel.keras
# 4/4 - 0s - loss: 0.0685 - accuracy: 0.9862 - val_loss: 0.5204 - val_accuracy: 0.8364 - lr: 0.0010 - 129ms/epoch - 32ms/step
# Epoch 25/60
#
# Epoch 25: val_accuracy did not improve from 0.83636
# 4/4 - 0s - loss: 0.0582 - accuracy: 0.9885 - val_loss: 0.6814 - val_accuracy: 0.7727 - lr: 0.0010 - 78ms/epoch - 20ms/step
# Epoch 26/60
#
# Epoch 26: val_accuracy did not improve from 0.83636
# 4/4 - 0s - loss: 0.0531 - accuracy: 0.9885 - val_loss: 0.5590 - val_accuracy: 0.8273 - lr: 0.0010 - 86ms/epoch - 21ms/step
# Epoch 27/60
#
# Epoch 27: val_accuracy did not improve from 0.83636
# 4/4 - 0s - loss: 0.0468 - accuracy: 0.9931 - val_loss: 0.6528 - val_accuracy: 0.7545 - lr: 0.0010 - 89ms/epoch - 22ms/step
# Epoch 28/60
#
# Epoch 28: val_accuracy did not improve from 0.83636
# 4/4 - 0s - loss: 0.0388 - accuracy: 0.9908 - val_loss: 0.5356 - val_accuracy: 0.8182 - lr: 0.0010 - 86ms/epoch - 22ms/step
# Epoch 29/60
#
# Epoch 29: val_accuracy did not improve from 0.83636
# 4/4 - 0s - loss: 0.0418 - accuracy: 0.9931 - val_loss: 0.6489 - val_accuracy: 0.7727 - lr: 0.0010 - 87ms/epoch - 22ms/step
# Epoch 30/60
#
# Epoch 30: val_accuracy did not improve from 0.83636
# 4/4 - 0s - loss: 0.0282 - accuracy: 0.9977 - val_loss: 0.6494 - val_accuracy: 0.7727 - lr: 0.0010 - 91ms/epoch - 23ms/step
# Epoch 31/60
#
# Epoch 31: val_accuracy did not improve from 0.83636
# 4/4 - 0s - loss: 0.0195 - accuracy: 1.0000 - val_loss: 0.5913 - val_accuracy: 0.8000 - lr: 0.0010 - 86ms/epoch - 21ms/step
# Epoch 32/60
#
# Epoch 32: val_accuracy did not improve from 0.83636
# 4/4 - 0s - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.6426 - val_accuracy: 0.8000 - lr: 0.0010 - 88ms/epoch - 22ms/step
# Epoch 33/60
#
# Epoch 33: val_accuracy did not improve from 0.83636
# 4/4 - 0s - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.6497 - val_accuracy: 0.8091 - lr: 0.0010 - 91ms/epoch - 23ms/step
# Epoch 34/60
#
# Epoch 34: val_accuracy did not improve from 0.83636
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 4/4 - 0s - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.6991 - val_accuracy: 0.7909 - lr: 0.0010 - 88ms/epoch - 22ms/step
# Epoch 35/60
#
# Epoch 35: val_accuracy did not improve from 0.83636
# 4/4 - 0s - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.7102 - val_accuracy: 0.7909 - lr: 1.0000e-04 - 91ms/epoch - 23ms/step
# Epoch 36/60
#
# Epoch 36: val_accuracy did not improve from 0.83636
# 4/4 - 0s - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.7117 - val_accuracy: 0.7909 - lr: 1.0000e-04 - 93ms/epoch - 23ms/step
# Epoch 37/60
#
# Epoch 37: val_accuracy did not improve from 0.83636
# 4/4 - 0s - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.7094 - val_accuracy: 0.7909 - lr: 1.0000e-04 - 94ms/epoch - 23ms/step
# Epoch 38/60
#
# Epoch 38: val_accuracy did not improve from 0.83636
# 4/4 - 0s - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.6995 - val_accuracy: 0.7909 - lr: 1.0000e-04 - 88ms/epoch - 22ms/step
# Epoch 39/60
# Restoring model weights from the end of the best epoch: 24.
#
# Epoch 39: val_accuracy did not improve from 0.83636
# 4/4 - 0s - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.6915 - val_accuracy: 0.8091 - lr: 1.0000e-04 - 97ms/epoch - 24ms/step
# Epoch 39: early stopping

# %% [markdown]
# # Read Validation accuracy
# Now we will read from the csv and group the experiment validation for the last 30 epoch into the symmetries

# %%
# # change the subfolder name to save your data in different location based on what NN model you used
# # it's a convenient way to avoid losing your training data of each model
# # Here are some preset examples you can use
# # 1 FC layer
# run_subfolder = "_1FC"/
# # run_subfolder = "_2nodes_2FC"
# # # 2 FC layer
# run_subfolder = "_2FC"
# # # 3 FC layer
# run_subfolder = "_3FC"
# # # 4 FC layer
run_subfolder = "_4FC"
# early stopping epochs -- good practice between 10-20
patience = 15
log_dir = train_layer.name + "/run" + run_subfolder +  "/"
log_dir += str(patience) +  "/"

# %%
# group the index of the permutation by the symmetry of the filter

diagonal_index = [4, 5, 8, 9, 14, 15, 18, 19]
vertical_index = [0, 1, 6, 7, 16, 17, 22, 23]
horizontal_index = [2, 3, 10, 11, 12, 13, 20, 21]

# %% [markdown]
# ### Finding the best model/worst for each symmetry

# %%
import pandas as pd

diagonal_val_accuracy = []
vertical_val_accuracy = []
horizontal_val_accuracy = []

diagonal_max_accuracy, vertical_max_accuracy, horizontal_max_accuracy = 0, 0, 0
diagonal_min_accuracy, vertical_min_accuracy, horizontal_min_accuracy = 0, 0, 0
diagonal_best_model, vertical_best_model, horizontal_best_model = "", "", ""
diagonal_worst_model, vertical_worst_model, horizontal_worst_model = "", "", ""
diagonal_max_accuracy_filepath, vertical_max_accuracy_filepath, horizontal_max_accuracy_filepath = "", "", ""
diagonal_best_model_filepath, vertical_best_model_filepath, horizontal_best_model_filepath = "", "", ""


for ind, variant  in enumerate(permutations):
    label = ''.join(map(str,variant))
    # file = train_layer.name + "/run" + run_subfolder +  "/" + label
    file = log_dir + label
    # print(file)
    #read the csv file
    df = pd.read_csv(file)
    # print(df)
    # print("Max ", df['val_accuracy'].max())
    # the number of last validation accuracy
    tail_accuracy = 30
    # our models file path extension, we'll use it to capture the filepath to our models
    model_filepath_extension = "model.keras"
    # Checking only diagonal models
    if ind in diagonal_index:
        if not diagonal_max_accuracy:
            # Assuming the max accuracy of the first model is both the max and min of the entire model with
            # respect to a given symmetry
            diagonal_max_accuracy = df['val_accuracy'].max()
            diagonal_best_model = label
            # saving the file path of the model and accuracies
            diagonal_max_accuracy_filepath = file
            diagonal_best_model_filepath = file + model_filepath_extension
            # capturing the lowest out of the highest accuracies of our models
            diagonal_min_accuracy = df['val_accuracy'].max()
            diagonal_worst_model = label
        # This block will only start from the second model 
        elif diagonal_max_accuracy < df['val_accuracy'].max():
            diagonal_max_accuracy = df['val_accuracy'].max()
            diagonal_best_model = label
            # saving the file path of the model and accuracies
            diagonal_max_accuracy_filepath = file
            diagonal_best_model_filepath = file + model_filepath_extension
        # This block will only start from the second model    
        elif diagonal_min_accuracy > df['val_accuracy'].max():
            diagonal_min_accuracy = df['val_accuracy'].max()
            diagonal_worst_model = label
    
    # Checking only vertical models    
    elif ind in vertical_index:
        if not vertical_max_accuracy:
            # Assuming the max accuracy of the first model is both the max and min of the entire model with
            # respect to a given symmetry
            vertical_max_accuracy = df['val_accuracy'].max()
            vertical_best_model = label
            # saving the file path of the model and accuracies
            vertical_max_accuracy_filepath = file
            vertical_best_model_filepath = file + model_filepath_extension
            # capturing the lowest out of the highest accuracies of our models
            vertical_min_accuracy = df['val_accuracy'].max()
            vertical_worst_model = label
        # This block will only start from the second model    
        elif vertical_max_accuracy < df['val_accuracy'].max():
            vertical_max_accuracy =  df['val_accuracy'].max()
            vertical_best_model = label
            # saving the file path of the model and accuracies
            vertical_max_accuracy_filepath = file
            vertical_best_model_filepath = file + model_filepath_extension
        # This block will only start from the second model    
        elif vertical_min_accuracy > df['val_accuracy'].max():
            vertical_min_accuracy = df['val_accuracy'].max()
            vertical_worst_model = label
            
    # Checking only horizontal models
    elif ind in horizontal_index:
        if not horizontal_max_accuracy:
            # Assuming the max accuracy of the first model is both the max and min of the entire model with
            # respect to a given symmetry
            horizontal_max_accuracy = df['val_accuracy'].max()
            horizontal_best_model = label
            # saving the file path of the model and accuracies
            horizontal_max_accuracy_filepath = file
            horizontal_best_model_filepath = file + model_filepath_extension
            # capturing the lowest out of the highest accuracies of our models
            horizontal_min_accuracy = df['val_accuracy'].max()
            horizontal_worst_model = label
        # This block will only start from the second model    
        elif horizontal_max_accuracy < df['val_accuracy'].max():
            horizontal_max_accuracy = df['val_accuracy'].max()
            horizontal_best_model = label
            # saving the file path of the model and accuracies
            horizontal_max_accuracy_filepath = file
            horizontal_best_model_filepath = file + model_filepath_extension
        # This block will only start from the second model    
        elif horizontal_min_accuracy > df['val_accuracy'].max():
            horizontal_min_accuracy = df['val_accuracy'].max()
            horizontal_worst_model = label
            
# printing the models
print(f" The best diagonal model is: {diagonal_best_model} with accuracy {diagonal_max_accuracy}" )
print(f" The best diagonal model filepath is: {diagonal_best_model_filepath}")
print(f" The best diagonal model accuracy filepath is: {diagonal_max_accuracy_filepath}")
print(f" The worst diagonal model is: {diagonal_worst_model} with accuracy {diagonal_min_accuracy}" )

print("#"*70)
print(f" The best vertical model is: {vertical_best_model} with accuracy {vertical_max_accuracy}" )
print(f" The best vertical model filepath is: {diagonal_best_model_filepath}")
print(f" The best vertical model accuracy filepath is: {vertical_max_accuracy_filepath}")
print(f" The worst vertical model is: {vertical_worst_model} with accuracy {vertical_min_accuracy}" )
print("#"*70)
print(f" The best horizontal model is: {horizontal_best_model} with accuracy {horizontal_max_accuracy}" )
print(f" The best horizontal model filepath is: {horizontal_best_model_filepath}")
print(f" The best horizontal model accuracy filepath is: {horizontal_max_accuracy_filepath}")
print(f" The worst horizontal model is: {horizontal_worst_model} with accuracy {horizontal_min_accuracy}" )
# Out:
#  The best diagonal model is: 0312 with accuracy 0.8727272748947144
#  The best diagonal model filepath is: _OA_results_BreastMNIST_train_with_val/run_4FC/15/0312model.keras
#  The best diagonal model accuracy filepath is: _OA_results_BreastMNIST_train_with_val/run_4FC/15/0312
#  The worst diagonal model is: 3012 with accuracy 0.800000011920929
# ######################################################################
#  The best vertical model is: 0132 with accuracy 0.8636363744735718
#  The best vertical model filepath is: _OA_results_BreastMNIST_train_with_val/run_4FC/15/0312model.keras
#  The best vertical model accuracy filepath is: _OA_results_BreastMNIST_train_with_val/run_4FC/15/0132
#  The worst vertical model is: 2310 with accuracy 0.8090909123420715
# ######################################################################
#  The best horizontal model is: 2013 with accuracy 0.8818181753158569
#  The best horizontal model filepath is: _OA_results_BreastMNIST_train_with_val/run_4FC/15/2013model.keras
#  The best horizontal model accuracy filepath is: _OA_results_BreastMNIST_train_with_val/run_4FC/15/2013
#  The worst horizontal model is: 0213 with accuracy 0.8090909123420715

# %%
import pandas as pd

diagonal_val_accuracy = []
vertical_val_accuracy = []
horizontal_val_accuracy = []

for ind, variant  in enumerate(permutations):
    label = ''.join(map(str,variant))
    # file = train_layer.name + "/run" + run_subfolder +  "/" + label
    file = log_dir + label

    #read the csv file
    df = pd.read_csv(file)
    
    # the number of last validation accuracy
    tail_accuracy = 15
    diagonal_max_accuracy, vertical_max_accuracy, horizontal_max_accuracy = 0, 0, 0
    if ind in diagonal_index:
        diagonal_val_accuracy.append(df['val_accuracy'].tail(tail_accuracy).tolist())
        
    elif ind in vertical_index:
        vertical_val_accuracy.append(df['val_accuracy'].tail(tail_accuracy).tolist())
    
    elif ind in horizontal_index:
        horizontal_val_accuracy.append(df['val_accuracy'].tail(tail_accuracy).tolist())

# %%
# need to flatten the list to have all the data in a single list
diagonal_val_accuracy_flattened = [item for sublist in diagonal_val_accuracy for item in sublist]
vertical_val_accuracy_flattened = [item for sublist in vertical_val_accuracy for item in sublist]
horizontal_val_accuracy_flattened = [item for sublist in horizontal_val_accuracy for item in sublist]

# %%
# file = train_layer.name + "/run" + run_subfolder +  "/" + "NO-FILTER"
file = log_dir + "NO-FILTER"


df = pd.read_csv(file)
no_fitler_val_accuracy = df['val_accuracy'].tail(tail_accuracy).tolist()

# %% [markdown]
# ### No Filter model

# %%
nofilter_model_file_path = file + model_filepath_extension

# %%
import matplotlib.pyplot as plt

# Combine the data into a list of lists
data = [diagonal_val_accuracy_flattened, vertical_val_accuracy_flattened, horizontal_val_accuracy_flattened]

# Define the labels for the box plot
labels_plot = ['Diagonal', 'Vertical', 'Horizontal']

# Create the box plot
plt.boxplot(data, labels=labels_plot)

# Calculate the mean value of the no_filter list
mean_no_filter = np.mean(no_fitler_val_accuracy)
max_no_filter = np.max(no_fitler_val_accuracy)

# Add a horizontal line at the mean value of no_filter
plt.axhline(y= mean_no_filter, color='r', linestyle='--', label=f'Mean no Filter: {mean_no_filter:.4f}')
plt.axhline(y= max_no_filter, color='g', linestyle='--', label=f'Max no Filter: {max_no_filter:.4f}')

# plt.ylim(0.936,.97)
max_val_accuracy = np.max([diagonal_val_accuracy_flattened, vertical_val_accuracy_flattened, horizontal_val_accuracy_flattened])
plt.axhline(y= max_val_accuracy, color='b', linestyle='--', label=f'Max with Filter: {max_val_accuracy:.4f}')

# Add title and labels
number_of_hidden_layers = str(int(run_subfolder[1])-1)
plt.title(f'Box Plot of Val Accuracy with {number_of_hidden_layers} Hidden Layers')
plt.xlabel('Symmetries')
plt.ylabel('Val Accuracy')
# plt.legend(ncol=2, shadow=True)
# plt.legend(shadow=True)
# plt.legend()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# Save the figure with high quality
data_name = "eMnist_Digits"
figure_name = f"{log_dir}/{data_name}_{run_subfolder}_Val_Accuracy"
# plt.savefig(figure_name, dpi=300, bbox_inches='tight')
# Show the plot
plt.show()

# %% [markdown]
# ## Now let's evaluate our models

# %%
# Loading the models
diagonal_model = keras.saving.load_model(diagonal_best_model_filepath)
vertical_model = keras.saving.load_model(vertical_best_model_filepath)
horizontal_model = keras.saving.load_model(horizontal_best_model_filepath)
nofilter_model = keras.saving.load_model(nofilter_model_file_path)

# %%
# Evaluate the model on the test data using 
print("Evaluate on test data")
# Diagonal
diagonal_label = diagonal_max_accuracy_filepath[-4:]
diagonal_te_images =  test_layer.open(diagonal_label)
diagonal_results = diagonal_model.evaluate(diagonal_te_images, test_labels)
print("Diagonal test loss, test acc:", diagonal_results)
print("#"*70)
# Vertical
vertical_label = vertical_max_accuracy_filepath[-4:]
vertical_te_images =  test_layer.open(vertical_label)
vertical_results = vertical_model.evaluate(vertical_te_images, test_labels)
print("Vertical test loss, test acc:", vertical_results)
print("#"*70)
# Horizontal
horizontal_label = horizontal_max_accuracy_filepath[-4:]
horizontal_te_images =  test_layer.open(horizontal_label)
horizontal_results = horizontal_model.evaluate(horizontal_te_images, test_labels)
print("Horizontal test loss, test acc:", horizontal_results)
print("#"*70)
# No Filter
nofilter_te_images =  test_images
nofilter_te_results = nofilter_model.evaluate(nofilter_te_images, test_labels)
print("No Filter test loss, test acc:", nofilter_te_results)
print("#"*70)
# Out:
# Evaluate on test data
# 5/5 [==============================] - 0s 8ms/step - loss: 0.7374 - accuracy: 0.7885
# Diagonal test loss, test acc: [0.7373892068862915, 0.7884615659713745]
# ######################################################################
# 5/5 [==============================] - 0s 6ms/step - loss: 0.6978 - accuracy: 0.7564
# Vertical test loss, test acc: [0.6978088617324829, 0.7564102411270142]
# ######################################################################
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6953 - accuracy: 0.7564
# Horizontal test loss, test acc: [0.6952771544456482, 0.7564102411270142]
# ######################################################################
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5441 - accuracy: 0.7564
# No Filter test loss, test acc: [0.5441346764564514, 0.7564102411270142]
# ######################################################################

# %%
# data to build classification reports
Models_dict = {"diagonal" : {"label":diagonal_label, "model": diagonal_model, "test_images": diagonal_te_images,  "pred": ""},
               "vertical" : {"label":vertical_label, "model": vertical_model, "test_images": vertical_te_images, "pred": ""}, 
                "horizontal" : {"label":horizontal_label, "model": horizontal_model, "test_images": horizontal_te_images, "pred": ""},
            }

# %% [markdown]
#  ## Confusion Matrix

# %%
import seaborn as sns

# Function that creates a folder
def create_folder(folder_path):
   log_dir =  os.path.join(os.getcwd(), folder_path)
   os.makedirs(log_dir, exist_ok=True) 
   return log_dir

# creating a folder inside test_data folder to save the confusion matrices and classification reports 
# with name = number of Fully Connected FC layer used.
patience = 15
test_folder_path = test_layer.name  + "/" + run_subfolder +  "/"
# create_folder(test_folder_path)
test_folder_path += str(patience) +  "/"
# test_folder_path = test_layer.name + "/" + run_subfolder
create_folder(test_folder_path)
confusion_matrices_path = test_folder_path + "confusion_matrices"
create_folder(confusion_matrices_path)
# we
class_names = np.unique(test_labels)



def create_save_confusion_matrix(symmetry, Y_pred, label, test_labels=test_labels):
   """ Function that creates & saves as csv and png confusion matrix """
   try:
      # # Convert predictions classes to one hot vectors 
      # Y_pred_classes = np.argmax(Y_pred, axis=1) 
      # compute the confusion matrix
      confusion_mtx = tf.math.confusion_matrix(labels=test_labels,
                                                predictions=Y_pred
                                             )
      confusion_mtx_df = pd.DataFrame(confusion_mtx, index=class_names, columns=class_names)
      # file name to save the confusion matrix
      cm_file_name =  f"{confusion_matrices_path}/{symmetry}_{label}_confusion_matrix.csv"
      print
      # Save to a CSV file
      confusion_mtx_df.to_csv(cm_file_name)
      print(f"Confusion matrix saved to {cm_file_name}")
      print("#"*80)
      print(f"Confusion Matrix for {symmetry.capitalize()} Model")
      plt.figure(figsize=(10, 8))
      sns.heatmap(confusion_mtx, annot=True, fmt='g')
      # Save the figure with high quality
      # cm_file_name[:-4] taking off .csv extension to avoid errors
      plt.savefig(cm_file_name[:-4], dpi=300, bbox_inches='tight')
   
   except Exception as e:
      print(f"An error occurred while creating and saving the confusion_matrix: {e}")


# 
for symmetry, value in Models_dict.items():
   # Predict the values from the testing dataset
   value["pred"] = np.argmax(value["model"].predict(value["test_images"]), axis=1) 
   create_save_confusion_matrix(symmetry, Y_pred=value["pred"], label=value["label"], test_labels=test_labels)
# Out:
# 5/5 [==============================] - 0s 3ms/step
# Confusion matrix saved to _OA_results_BreastMNIST_test_with_val/_4FC/15/confusion_matrices/diagonal_0312_confusion_matrix.csv
# ################################################################################
# Confusion Matrix for Diagonal Model
# 5/5 [==============================] - 0s 4ms/step
# Confusion matrix saved to _OA_results_BreastMNIST_test_with_val/_4FC/15/confusion_matrices/vertical_0132_confusion_matrix.csv
# ################################################################################
# Confusion Matrix for Vertical Model
# 5/5 [==============================] - 0s 4ms/step
# Confusion matrix saved to _OA_results_BreastMNIST_test_with_val/_4FC/15/confusion_matrices/horizontal_2013_confusion_matrix.csv
# ################################################################################
# Confusion Matrix for Horizontal Model

# %% [markdown]
# ## classification report

# %%
from sklearn.metrics import classification_report

# # creating a folder inside test_data folder to save the classification reports with name = number of Fully Connected FC layer used.
# test_folder_path = test_layer.name + "/" + run_subfolder
# create_folder(test_folder_path)
# creating a folder inside test_data folder to save the classification reports
folder_path = test_folder_path  + "classification_reports"
create_folder(folder_path)


def save_classification_report_image(df_report, symmetry, label, folder_path, class_names=class_names):
    """ Function to save each classification report as an image with symmetry name and configuration e.g. 0123"""
    # extension for the files
    classification_report_image_extension = "_classification_report.png"
    try:
        plt.figure(figsize=(10, len(class_names) + 2))
        sns.heatmap(df_report,
                    annot=True,
                    fmt=".2f",
                    cbar=True)
        
        plt.title(f"{symmetry.capitalize()} Classification Report Metrics -- {label}")
        # Move x-axis labels to the top
        plt.tick_params(axis='x', which='major', top=True, bottom=False, labeltop=True, labelbottom=False)
        plt.xticks(rotation=0, ha='center') # Adjust rotation as needed

        # Save classification report as image
        file_name = f"{folder_path}/{symmetry}_{label}_{classification_report_image_extension}"
        plt.tight_layout()
        plt.savefig(file_name, dpi=300, bbox_inches='tight')
        plt.show()
        print(f"Successfully classification report saved to {file_name}")
    except Exception as e:
        print(f"An error occurred while creating and saving the classification report: {e}")




def create_save_classification_report(Y_pred, symmetry, label, test_labels=test_labels, folder_path=folder_path):
   # extension for classification reports inside the above folder
   classification_report_file_extension = "_classification_report.csv"

   try:
      # building report
      report = classification_report(y_true=test_labels,
                                    y_pred=Y_pred,
                                    output_dict=True
                                    )
      df_report = pd.DataFrame(report).transpose()

      # Save the DataFrame to a CSV file
      file_name = f"{folder_path}/{symmetry}_{label}_{classification_report_file_extension}"
      df_report.to_csv(file_name)
      print(f"Classification report saved to {file_name}")
      # save classification report as image
      save_classification_report_image(df_report=df_report, symmetry=symmetry, label=label, folder_path=folder_path)
      # 
      print("#"*70)
      print("\n")

      print(f" Classification Report for {symmetry}")
      print("\n")
      print(report)
      print("#"*70)
      print("\n")
   except Exception as e:
        print(f"An error occurred while creating and saving the classification report: {e}")
         
         
         
for symmetry, value in Models_dict.items():
    create_save_classification_report(symmetry=symmetry, label=value["label"], Y_pred=value["pred"])
    
print("#"*70)
print("End!")
# Out:
# Classification report saved to _OA_results_BreastMNIST_test_with_val/_4FC/15/classification_reports/diagonal_0312__classification_report.csv
# Successfully classification report saved to _OA_results_BreastMNIST_test_with_val/_4FC/15/classification_reports/diagonal_0312__classification_report.png
# ######################################################################
#
#
#  Classification Report for diagonal
#
#
# {'0': {'precision': 0.6153846153846154, 'recall': 0.5714285714285714, 'f1-score': 0.5925925925925926, 'support': 42.0}, '1': {'precision': 0.8461538461538461, 'recall': 0.868421052631579, 'f1-score': 0.8571428571428571, 'support': 114.0}, 'accuracy': 0.7884615384615384, 'macro avg': {'precision': 0.7307692307692308, 'recall': 0.7199248120300752, 'f1-score': 0.7248677248677249, 'support': 156.0}, 'weighted avg': {'precision': 0.7840236686390534, 'recall': 0.7884615384615384, 'f1-score': 0.7859177859177858, 'support': 156.0}}
# ######################################################################
#
#
# Classification report saved to _OA_results_BreastMNIST_test_with_val/_4FC/15/classification_reports/vertical_0132__classification_report.csv
# Successfully classification report saved to _OA_results_BreastMNIST_test_with_val/_4FC/15/classification_reports/vertical_0132__classification_report.png
# ######################################################################
#
#
#  Classification Report for vertical
#
#
# {'0': {'precision': 0.5769230769230769, 'recall': 0.35714285714285715, 'f1-score': 0.4411764705882353, 'support': 42.0}, '1': {'precision': 0.7923076923076923, 'recall': 0.9035087719298246, 'f1-score': 0.8442622950819673, 'support': 114.0}, 'accuracy': 0.7564102564102564, 'macro avg': {'precision': 0.6846153846153846, 'recall': 0.6303258145363408, 'f1-score': 0.6427193828351012, 'support': 156.0}, 'weighted avg': {'precision': 0.7343195266272189, 'recall': 0.7564102564102564, 'f1-score': 0.735739188487501, 'support': 156.0}}
# ######################################################################
#
#
# Classification report saved to _OA_results_BreastMNIST_test_with_val/_4FC/15/classification_reports/horizontal_2013__classification_report.csv
# Successfully classification report saved to _OA_results_BreastMNIST_test_with_val/_4FC/15/classification_reports/horizontal_2013__classification_report.png
# ######################################################################
#
#
#  Classification Report for horizontal
#
#
# {'0': {'precision': 0.5625, 'recall': 0.42857142857142855, 'f1-score': 0.4864864864864865, 'support': 42.0}, '1': {'precision': 0.8064516129032258, 'recall': 0.8771929824561403, 'f1-score': 0.8403361344537815, 'support': 114.0}, 'accuracy': 0.7564102564102564, 'macro avg': {'precision': 0.6844758064516129, 'recall': 0.6528822055137844, 'f1-score': 0.663411310470134, 'support': 156.0}, 'weighted avg': {'precision': 0.7407723325062034, 'recall': 0.7564102564102564, 'f1-score': 0.7450689215395098, 'support': 156.0}}
# ######################################################################
#
#
# ######################################################################
# End!
