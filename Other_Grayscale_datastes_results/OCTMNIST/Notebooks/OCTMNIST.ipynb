# %% [markdown]
# ## Imports

# %%
# importing sys
import sys
# This is how you import modules that exist outside of working directory 
# adding mosaique to the system path
sys.path.insert(1, '/workspaces/QML-QPF/mosaiQue') 

import mosaique as mq
import scipy
from concurrent.futures import ProcessPoolExecutor, as_completed
import itertools
import numpy as np
import pennylane as qml
import os
from mosaique.models.operation import OperationLayer
from tensorflow import keras
import tensorflow as tf

# %%
# if the below cell raise this error [ModuleNotFoundError: No module named 'tensorrt']
# uncomment and run the next line, then restart the kernel 
# pip install tensorrt

# %% [markdown]
# ## Check GPU installation is working

# %%
import tensorrt as trt

print(f' tensorflow version {tf.__version__}')

print(f' tensorrt version {trt.__version__}')

print(tf.config.list_physical_devices('GPU'))

# %%
# Set the environment for asynchronous GPU usage
os.environ['TF_GPU_ALLOCATOR'] = 'cuda_malloc_async'

# %%
def operation():
    dev = qml.device("default.qubit.tf", wires=4)
    @qml.qnode(dev, interface='tf')
    def cnot(inputs):
        inputs = inputs * np.pi
        qml.AngleEmbedding(inputs[:,...], wires=range(4), rotation='Y')

        qml.CNOT(wires=[0, 1])
        qml.CNOT(wires=[2, 3])

        # Measurement producing 4 classical output values
        return [qml.expval(qml.PauliZ(j)) for j in range(4)]
    return cnot

# %%
def preset():
    # Import the images
    from medmnist import OCTMNIST
    # size of the images 
    size = 28
    # we'll run the code for 64 to see if we'll get different results
    train_data = OCTMNIST(split="train", download=True,size=size)
    test_data = OCTMNIST(split="test", download=True,size=size)
    # name of the folder where will save the filtered images for training
    
    # name of the folder where will save the filtered images for training
    tr_layer = mq.ConvolutionLayer4x4("_OA_results_OCTMNIST_train_with_val")
    # name of the folder where will save the filtered images for testing
    te_layer = mq.ConvolutionLayer4x4("_OA_results_OCTMNIST_test_with_val")
    
    
        
    #load the data set want to train
    (tr_images, tr_labels), (te_images, te_labels) = (train_data.imgs, train_data.labels), (test_data.imgs, test_data.labels)
    

    tr_layer.fit(tr_images)
    te_layer.fit(te_images)
    tr_images = tr_layer.transform(tr_images)
    te_images = te_layer.transform(te_images)
    return ((tr_layer, (tr_images, tr_labels)), (te_layer,(te_images, te_labels)))

with ProcessPoolExecutor() as executor:
    future = executor.submit(preset)

((train_layer, (train_images, train_labels)), (test_layer,(test_images, test_labels))) = future.result() #This blocks until the task completes

# %%
test_images.shape
# Out:
# (1000, 196, 4)

# %%
np.unique(train_labels)
# Out:
# array([0, 1, 2, 3], dtype=uint8)

# %%
permutations = np.asarray(list(itertools.permutations(range(4))))

def pool(x, call, p, l):
    op = OperationLayer(call())
    predict = l.post_transform(op.pre_op.predict(x,batch_size=1000))
    l.save(predict, p)

# %%
# # not using PorcessPoolExecutor

# for p in permutations:
#     pool(train_images[:,:,p],)

# %%
for j in range(3):
    with ProcessPoolExecutor(8) as executor:
        runner = {
            executor.submit(pool, x=train_images[:,:,p], call=operation, p=p, l=train_layer): p for p in permutations[8*j:8*(j+1)]
        }
        for future in as_completed(runner):
            runner.pop(future)
# Out:
# 98/98 [==============================] - 83s 819ms/step
# 98/98 [==============================] - 86s 836ms/step
# 98/98 [==============================] - 86s 833ms/step
# 98/98 [==============================] - 88s 853ms/step
# 98/98 [==============================] - 88s 852ms/step
# 98/98 [==============================] - 88s 838ms/step
# 98/98 [==============================] - 88s 834ms/step
# 98/98 [==============================] - 87s 839ms/step
# 98/98 [==============================] - 85s 833ms/step
# 98/98 [==============================] - 84s 818ms/step
# 98/98 [==============================] - 88s 839ms/step
# 98/98 [==============================] - 86s 825ms/step
# 98/98 [==============================] - 88s 846ms/step
# 98/98 [==============================] - 86s 840ms/step
# 98/98 [==============================] - 88s 841ms/step
# 98/98 [==============================] - 87s 828ms/step
# 98/98 [==============================] - 65s 632ms/step
# 98/98 [==============================] - 67s 653ms/step
# 98/98 [==============================] - 67s 650ms/step
# 98/98 [==============================] - 69s 651ms/step
# 98/98 [==============================] - 67s 644ms/step
# 98/98 [==============================] - 67s 628ms/step
# 98/98 [==============================] - 65s 613ms/step
# 98/98 [==============================] - 66s 619ms/step

# %%
for j in range(3):
    with ProcessPoolExecutor(8) as executor:
        runner = {
            executor.submit(pool, x=test_images[:,:,p], call=operation, p=p, l=test_layer): p for p in permutations[8*j:8*(j+1)]
        }
        for future in as_completed(runner):
            runner.pop(future)
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step

# %%
from keras.callbacks import CSVLogger, EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# change the subfolder name to save your data in different location based on what NN model you used
# it's a convenient way to avoid losing your training data of each model
# Here are some preset examples you can use
# 1 FC layer
# run_subfolder = "_1FC"
# run_subfolder = "_2nodes_2FC"
# # 2 FC layer
# run_subfolder = "_2FC"
# # 3 FC layer
run_subfolder = "_3FC"
# # 4 FC layer
# run_subfolder = "_4FC"
# early stopping epochs -- good practice between 10-20
patience = 15
def run(tr_images, label):
    log_dir = train_layer.name + "/run" + run_subfolder +  "/"
    log_dir += str(patience) +  "/"
    # print(' log_dir ', log_dir)
    log_file =  log_dir + label
    # print(' log_file ', log_file)
    os.makedirs(log_dir, exist_ok=True)
    
    csv_logger = CSVLogger(log_file)
    
    
    # tensorboard_callback = keras.callbacks.TensorBoard(
    #     log_dir=log_file,
    #     histogram_freq=1,
    #     write_graph=True,
    #     write_images=True,
    #     write_steps_per_second=True,
    #     update_freq='batch',
    #     profile_batch=1,
    #     embeddings_freq=1,
    #     embeddings_metadata=None
    # )
    
    number_of_classes = len(np.unique(test_labels))
    # Chose which model you want to use depending on the number of hidden layers
    # Uncomment the your model and run the code--pay attention to your folder/file naming to keep everything organized 
    ####---------------------------------------------------------------------####
    
    # # simple ANN model with 0 hidden layers: 1FC
    # q_model = keras.models.Sequential([
    #     keras.layers.Rescaling(scale=-1. / 127.5, offset=1),
    #     keras.layers.Flatten(),
    #     keras.layers.Dense(number_of_classes, activation="softmax")
    # ])
    
    ####---------------------------------------------------------------------####
    
    # # simple ANN model with 1 hidden layers: 2FC
    # q_model = keras.models.Sequential([
    #     keras.layers.Rescaling(scale=-1. / 127.5, offset=1),
    #     keras.layers.Flatten(),
    #     keras.layers.Dense(512, activation='relu'),
    #     keras.layers.Dense(number_of_classes, activation="softmax")
    # ])
    
    ####---------------------------------------------------------------------####
    
    # simple ANN model with 2 hidden layers: 3FC
    q_model = keras.models.Sequential([
        keras.layers.Rescaling(scale=-1. / 127.5, offset=1),
        keras.layers.Flatten(),
        keras.layers.Dense(512, activation='relu'),
        keras.layers.Dense(256, activation='relu'),
        keras.layers.Dense(number_of_classes, activation='softmax')
    ])
    
    ####---------------------------------------------------------------------####
    
    # # simple ANN model with 3 hidden layers: 4FC
    # q_model = keras.models.Sequential([
    #     keras.layers.Rescaling(scale=-1. / 127.5, offset=1),
    #     keras.layers.Flatten(),
    #     keras.layers.Dense(512, activation='relu'),
    #     keras.layers.Dense(256, activation='relu'),
    #     keras.layers.Dense(128, activation='relu'),
    #     keras.layers.Dense(number_of_classes, activation='softmax')
    # ])
    
    ####---------------------------------------------------------------------####
    
    q_model.compile(
        optimizer='adam',
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    
    # 
    batch_size = 128
    epochs = 60
    
    
    # Stop training when a monitored metric has stopped improving.
    Early_stop = EarlyStopping(monitor="val_accuracy",
                                min_delta=0, # Minimum change in the monitored quantity to qualify as an improvement, i.e. an absolute change of less than min_delta, will count as no improvement.
                                patience=patience, # Number of epochs with no improvement after which training will be stopped.
                                verbose=1, # 1 displays messages when the callback takes an action
                                mode="max", # will stop when the quantity monitored has stopped increasing
                                baseline=None,
                                restore_best_weights=True, # to restore model weights from the epoch with the best value of the monitored quantity
                                start_from_epoch=0, #  Number of epochs to wait before starting to monitor improvement.
                            )

    
    # Callback to save the Keras model or model weights at some frequency.
    checkpoint_filepath = log_file  + 'model.keras'
    model_checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath,
                                                monitor='val_accuracy',
                                                mode='max',
                                                verbose=1,
                                                save_best_only=True
                                                )
    # Reduce learning rate when a metric has stopped improving.
    reduce_lr_acc = ReduceLROnPlateau(monitor='val_accuracy',
                                        factor=0.1, # Float. Factor by which the learning rate will be reduced. new_lr = lr * factor.
                                        patience=10, # Integer. Number of epochs with no improvement after which learning rate will be reduced.
                                        verbose=1, # 1: update messages.
                                        mode="max", # 'max' mode it will be reduced when the quantity monitored has stopped increasing
                                        min_delta=0.0001, # Float. Threshold for measuring the new optimum, to only focus on significant changes.
                                        cooldown=0, #  Integer. Number of epochs to wait before resuming normal operation after the learning rate has been reduced.
                                        min_lr=0.0 #  Float. Lower bound on the learning rate.
                                    )


    
    q_history = q_model.fit(
        tr_images,
        train_labels,
        # validation_data=(te_images, test_labels),
        validation_split=0.2,
        batch_size=batch_size,
        epochs=epochs,
        verbose=2,
        # callbacks=[tensorboard_callback]
        callbacks = [Early_stop,csv_logger,model_checkpoint_callback, reduce_lr_acc]
    )

def model(variant, tr_layer):
    tr_images = tr_layer.open(variant)
    # te_images =  te_layer.open(variant)

    label = ''.join(map(str,variant))

    run(tr_images, label)

# %%
from matplotlib import pyplot as plt

# print(test_layer.open([0,1,3,2]).shape)

# post = test_layer.open([0,1,3,2])

# _min, _max = np.amin(post), np.amax(post)
# fig, axes = plt.subplots(1, 4, figsize=(16, 4))

# # Plot all output channels for quantum cnot
# for c in range(4):
#     axes[c].imshow(post[0,:,:,c],vmin = _min, vmax = _max)
    
post = train_layer.open([1,2,3,0])
post1 = train_layer.open([2,3,0,1])


_min, _max = np.amin(post), np.amax(post)
_min1, _max1 = np.amin(post1), np.amax(post1)
fig, axes = plt.subplots(2, 4, figsize=(16, 4))

# Plot all output channels for quantum cnot
for c in range(4):
    axes[0,c].imshow(post[0,:,:,c],vmin = _min, vmax = _max)
    axes[1,c].imshow(post1[0,:,:,c],vmin = _min1, vmax = _max1)

# %%
for j in range(3):
    with ProcessPoolExecutor(8) as executor:
        runner = {
            executor.submit(model,variant = p, tr_layer = train_layer): p for p in permutations[8*j:8*(j+1)]
        }
        for future in as_completed(runner):
            runner.pop(future)
# Out:
# Epoch 1/60
# Epoch 1/60
# Epoch 1/60
# Epoch 1/60
# Epoch 1/60
# Epoch 1/60
# Epoch 1/60
# Epoch 1/60
#
# Epoch 1: val_accuracy improved from -inf to 0.60392, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0213model.keras
# 610/610 - 3s - loss: 1.0955 - accuracy: 0.5609 - val_loss: 1.0452 - val_accuracy: 0.6039 - lr: 0.0010 - 3s/epoch - 4ms/step
# Epoch 2/60
#
# Epoch 1: val_accuracy improved from -inf to 0.61469, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0231model.keras
#
# Epoch 1: val_accuracy improved from -inf to 0.58073, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0312model.keras
#
# Epoch 1: val_accuracy improved from -inf to 0.53431, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0321model.keras
#
# Epoch 1: val_accuracy improved from -inf to 0.58315, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/1032model.keras
# 610/610 - 3s - loss: 1.0826 - accuracy: 0.5676 - val_loss: 1.0352 - val_accuracy: 0.6147 - lr: 0.0010 - 3s/epoch - 4ms/step
# Epoch 2/60
#
# Epoch 1: val_accuracy improved from -inf to 0.57955, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0123model.keras
# 610/610 - 3s - loss: 1.1042 - accuracy: 0.5448 - val_loss: 1.1072 - val_accuracy: 0.5343 - lr: 0.0010 - 3s/epoch - 4ms/step
# Epoch 2/60
#
# Epoch 1: val_accuracy improved from -inf to 0.58935, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0132model.keras
# 610/610 - 3s - loss: 1.1103 - accuracy: 0.5427 - val_loss: 1.0771 - val_accuracy: 0.5807 - lr: 0.0010 - 3s/epoch - 4ms/step
# 610/610 - 3s - loss: 1.1090 - accuracy: 0.5447 - val_loss: 1.0535 - val_accuracy: 0.5831 - lr: 0.0010 - 3s/epoch - 4ms/step
# Epoch 2/60
# Epoch 2/60
#
# Epoch 1: val_accuracy improved from -inf to 0.58232, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/1023model.keras
# 610/610 - 3s - loss: 1.1103 - accuracy: 0.5449 - val_loss: 1.0583 - val_accuracy: 0.5796 - lr: 0.0010 - 3s/epoch - 4ms/step
# Epoch 2/60
# 610/610 - 3s - loss: 1.1132 - accuracy: 0.5359 - val_loss: 1.0586 - val_accuracy: 0.5894 - lr: 0.0010 - 3s/epoch - 4ms/step
# 610/610 - 3s - loss: 1.1054 - accuracy: 0.5452 - val_loss: 1.0657 - val_accuracy: 0.5823 - lr: 0.0010 - 3s/epoch - 4ms/step
# Epoch 2/60
# Epoch 2/60
#
# Epoch 2: val_accuracy improved from 0.60392 to 0.64059, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0213model.keras
# 610/610 - 1s - loss: 1.0132 - accuracy: 0.6207 - val_loss: 0.9899 - val_accuracy: 0.6406 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 3/60
#
# Epoch 2: val_accuracy improved from 0.61469 to 0.63808, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0231model.keras
#
# Epoch 2: val_accuracy improved from 0.58073 to 0.58161, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0312model.keras
#
# Epoch 2: val_accuracy improved from 0.53431 to 0.59515, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0321model.keras
#
# Epoch 2: val_accuracy improved from 0.58315 to 0.60828, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/1032model.keras
# 610/610 - 1s - loss: 1.0044 - accuracy: 0.6228 - val_loss: 0.9793 - val_accuracy: 0.6381 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 3/60
# 610/610 - 1s - loss: 1.0341 - accuracy: 0.6016 - val_loss: 1.0669 - val_accuracy: 0.5816 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 3/60
#
# Epoch 2: val_accuracy improved from 0.57955 to 0.60284, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0123model.keras
# 610/610 - 1s - loss: 1.0380 - accuracy: 0.5965 - val_loss: 1.0215 - val_accuracy: 0.5951 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 3/60
# 610/610 - 1s - loss: 1.0357 - accuracy: 0.5948 - val_loss: 1.0151 - val_accuracy: 0.6083 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 3/60
#
# Epoch 2: val_accuracy improved from 0.58935 to 0.61587, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0132model.keras
# 610/610 - 1s - loss: 1.0397 - accuracy: 0.5959 - val_loss: 1.0280 - val_accuracy: 0.6028 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 3/60
#
# Epoch 2: val_accuracy improved from 0.58232 to 0.61248, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/1023model.keras
# 610/610 - 1s - loss: 1.0361 - accuracy: 0.5959 - val_loss: 1.0135 - val_accuracy: 0.6159 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 3/60
# 610/610 - 1s - loss: 1.0307 - accuracy: 0.6008 - val_loss: 1.0079 - val_accuracy: 0.6125 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 3/60
#
# Epoch 3: val_accuracy improved from 0.58161 to 0.61341, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0312model.keras
# 610/610 - 2s - loss: 1.0077 - accuracy: 0.6179 - val_loss: 1.0003 - val_accuracy: 0.6134 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 4/60
#
# Epoch 3: val_accuracy did not improve from 0.63808
# 610/610 - 2s - loss: 0.9752 - accuracy: 0.6400 - val_loss: 0.9948 - val_accuracy: 0.6369 - lr: 0.0010 - 2s/epoch - 3ms/step
#
# Epoch 3: val_accuracy did not improve from 0.64059
# Epoch 4/60
# 610/610 - 2s - loss: 0.9796 - accuracy: 0.6396 - val_loss: 1.0305 - val_accuracy: 0.6395 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 4/60
#
# Epoch 3: val_accuracy improved from 0.60828 to 0.62300, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/1032model.keras
#
# Epoch 3: val_accuracy improved from 0.61248 to 0.62444, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/1023model.keras
# 610/610 - 2s - loss: 1.0092 - accuracy: 0.6117 - val_loss: 1.0330 - val_accuracy: 0.6230 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 4/60
# 610/610 - 1s - loss: 1.0018 - accuracy: 0.6178 - val_loss: 1.0080 - val_accuracy: 0.6244 - lr: 0.0010 - 1s/epoch - 2ms/step
#
# Epoch 3: val_accuracy improved from 0.60284 to 0.61320, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0123model.keras
# Epoch 4/60
#
# Epoch 3: val_accuracy improved from 0.59515 to 0.62756, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0321model.keras
# 610/610 - 2s - loss: 1.0102 - accuracy: 0.6144 - val_loss: 1.0024 - val_accuracy: 0.6132 - lr: 0.0010 - 2s/epoch - 3ms/step
#
# Epoch 3: val_accuracy improved from 0.61587 to 0.62736, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0132model.keras
# Epoch 4/60
# 610/610 - 2s - loss: 1.0117 - accuracy: 0.6125 - val_loss: 0.9979 - val_accuracy: 0.6276 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 4/60
# 610/610 - 2s - loss: 1.0042 - accuracy: 0.6177 - val_loss: 0.9909 - val_accuracy: 0.6274 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 4/60
#
# Epoch 4: val_accuracy improved from 0.63808 to 0.64198, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0231model.keras
# 610/610 - 2s - loss: 0.9562 - accuracy: 0.6480 - val_loss: 0.9776 - val_accuracy: 0.6420 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 5/60
#
# Epoch 4: val_accuracy improved from 0.64059 to 0.65316, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0213model.keras
#
# Epoch 4: val_accuracy improved from 0.61341 to 0.62864, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0312model.keras
# 610/610 - 2s - loss: 0.9602 - accuracy: 0.6485 - val_loss: 0.9484 - val_accuracy: 0.6532 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 5/60
# 610/610 - 2s - loss: 0.9884 - accuracy: 0.6277 - val_loss: 0.9979 - val_accuracy: 0.6286 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 5/60
#
# Epoch 4: val_accuracy did not improve from 0.62300
# 610/610 - 2s - loss: 0.9923 - accuracy: 0.6192 - val_loss: 0.9887 - val_accuracy: 0.6220 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 5/60
#
# Epoch 4: val_accuracy improved from 0.61320 to 0.62623, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0123model.keras
#
# Epoch 4: val_accuracy improved from 0.62444 to 0.62649, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/1023model.keras
#
# Epoch 4: val_accuracy improved from 0.62736 to 0.63157, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0132model.keras
# 610/610 - 2s - loss: 0.9958 - accuracy: 0.6199 - val_loss: 0.9880 - val_accuracy: 0.6262 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 5/60
# 610/610 - 2s - loss: 0.9847 - accuracy: 0.6280 - val_loss: 0.9995 - val_accuracy: 0.6265 - lr: 0.0010 - 2s/epoch - 3ms/step
# 610/610 - 2s - loss: 0.9833 - accuracy: 0.6266 - val_loss: 0.9776 - val_accuracy: 0.6316 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 5/60
#
# Epoch 4: val_accuracy did not improve from 0.62756
# Epoch 5/60
# 610/610 - 2s - loss: 0.9991 - accuracy: 0.6211 - val_loss: 0.9932 - val_accuracy: 0.6255 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 5/60
#
# Epoch 5: val_accuracy improved from 0.64198 to 0.66055, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0231model.keras
# 610/610 - 2s - loss: 0.9419 - accuracy: 0.6548 - val_loss: 0.9339 - val_accuracy: 0.6605 - lr: 0.0010 - 2s/epoch - 3ms/step
#
# Epoch 5: val_accuracy did not improve from 0.65316
# 610/610 - 2s - loss: 0.9489 - accuracy: 0.6519 - val_loss: 0.9387 - val_accuracy: 0.6499 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 6/60
# Epoch 6/60
#
# Epoch 5: val_accuracy did not improve from 0.62300
# 610/610 - 1s - loss: 0.9852 - accuracy: 0.6222 - val_loss: 0.9829 - val_accuracy: 0.6152 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 6/60
#
# Epoch 5: val_accuracy improved from 0.62864 to 0.63741, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0312model.keras
#
# Epoch 5: val_accuracy improved from 0.62649 to 0.63690, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/1023model.keras
# 610/610 - 2s - loss: 0.9767 - accuracy: 0.6337 - val_loss: 0.9704 - val_accuracy: 0.6374 - lr: 0.0010 - 2s/epoch - 3ms/step
#
# Epoch 5: val_accuracy improved from 0.62756 to 0.62946, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0321model.keras
#
# Epoch 5: val_accuracy did not improve from 0.62623
# Epoch 6/60
# 610/610 - 1s - loss: 0.9852 - accuracy: 0.6271 - val_loss: 0.9907 - val_accuracy: 0.6231 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 6/60
#
# Epoch 5: val_accuracy improved from 0.63157 to 0.63680, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0132model.keras
# 610/610 - 1s - loss: 0.9725 - accuracy: 0.6325 - val_loss: 0.9654 - val_accuracy: 0.6369 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 6/60
# 610/610 - 1s - loss: 0.9864 - accuracy: 0.6267 - val_loss: 0.9870 - val_accuracy: 0.6295 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 6/60
# 610/610 - 1s - loss: 0.9746 - accuracy: 0.6317 - val_loss: 0.9835 - val_accuracy: 0.6368 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 6/60
#
# Epoch 6: val_accuracy improved from 0.65316 to 0.65562, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0213model.keras
# 610/610 - 1s - loss: 0.9393 - accuracy: 0.6575 - val_loss: 0.9338 - val_accuracy: 0.6556 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 7/60
#
# Epoch 6: val_accuracy improved from 0.66055 to 0.66147, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0231model.keras
# 610/610 - 1s - loss: 0.9345 - accuracy: 0.6594 - val_loss: 0.9384 - val_accuracy: 0.6615 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 7/60
#
# Epoch 6: val_accuracy did not improve from 0.62300
# 610/610 - 1s - loss: 0.9761 - accuracy: 0.6282 - val_loss: 1.0002 - val_accuracy: 0.6097 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 7/60
#
# Epoch 6: val_accuracy improved from 0.63690 to 0.63787, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/1023model.keras
#
# Epoch 6: val_accuracy improved from 0.63741 to 0.63905, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0312model.keras
#
# Epoch 6: val_accuracy did not improve from 0.62946
# 610/610 - 1s - loss: 0.9805 - accuracy: 0.6305 - val_loss: 0.9756 - val_accuracy: 0.6279 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 7/60
# 610/610 - 1s - loss: 0.9640 - accuracy: 0.6385 - val_loss: 0.9576 - val_accuracy: 0.6379 - lr: 0.0010 - 1s/epoch - 2ms/step
#
# Epoch 6: val_accuracy improved from 0.62623 to 0.63593, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0123model.keras
# Epoch 7/60
# 610/610 - 1s - loss: 0.9705 - accuracy: 0.6376 - val_loss: 0.9626 - val_accuracy: 0.6391 - lr: 0.0010 - 1s/epoch - 2ms/step
#
# Epoch 6: val_accuracy did not improve from 0.63680
# Epoch 7/60
# 610/610 - 1s - loss: 0.9646 - accuracy: 0.6377 - val_loss: 0.9596 - val_accuracy: 0.6332 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 7/60
# 610/610 - 1s - loss: 0.9760 - accuracy: 0.6308 - val_loss: 0.9756 - val_accuracy: 0.6359 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 7/60
#
# Epoch 7: val_accuracy improved from 0.65562 to 0.66198, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0213model.keras
#
# Epoch 7: val_accuracy did not improve from 0.66147
# 610/610 - 2s - loss: 0.9265 - accuracy: 0.6612 - val_loss: 0.9416 - val_accuracy: 0.6613 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 8/60
#
# Epoch 7: val_accuracy improved from 0.62300 to 0.62418, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/1032model.keras
# 610/610 - 2s - loss: 0.9296 - accuracy: 0.6599 - val_loss: 0.9277 - val_accuracy: 0.6620 - lr: 0.0010 - 2s/epoch - 3ms/step
#
# Epoch 7: val_accuracy did not improve from 0.63680
# 610/610 - 2s - loss: 0.9557 - accuracy: 0.6410 - val_loss: 0.9698 - val_accuracy: 0.6237 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 8/60
# Epoch 8/60
# 610/610 - 2s - loss: 0.9714 - accuracy: 0.6310 - val_loss: 0.9934 - val_accuracy: 0.6242 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 8/60
#
# Epoch 7: val_accuracy did not improve from 0.63787
# 610/610 - 2s - loss: 0.9554 - accuracy: 0.6416 - val_loss: 0.9549 - val_accuracy: 0.6368 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 8/60
#
# Epoch 7: val_accuracy improved from 0.62946 to 0.63695, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0321model.keras
# 610/610 - 2s - loss: 0.9750 - accuracy: 0.6324 - val_loss: 0.9684 - val_accuracy: 0.6370 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 8/60
#
# Epoch 7: val_accuracy improved from 0.63905 to 0.64423, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0312model.keras
#
# Epoch 7: val_accuracy did not improve from 0.63593
# 610/610 - 2s - loss: 0.9728 - accuracy: 0.6337 - val_loss: 0.9932 - val_accuracy: 0.6326 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 8/60
# 610/610 - 2s - loss: 0.9636 - accuracy: 0.6400 - val_loss: 0.9535 - val_accuracy: 0.6442 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 8/60
#
# Epoch 8: val_accuracy did not improve from 0.66198
# 610/610 - 2s - loss: 0.9221 - accuracy: 0.6643 - val_loss: 0.9534 - val_accuracy: 0.6440 - lr: 0.0010 - 2s/epoch - 3ms/step
#
# Epoch 8: val_accuracy improved from 0.62418 to 0.63634, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/1032model.keras
# Epoch 9/60
#
# Epoch 8: val_accuracy improved from 0.66147 to 0.66798, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0231model.keras
# 610/610 - 2s - loss: 0.9636 - accuracy: 0.6357 - val_loss: 0.9660 - val_accuracy: 0.6363 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 9/60
#
# Epoch 8: val_accuracy improved from 0.63680 to 0.64203, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0132model.keras
# 610/610 - 2s - loss: 0.9189 - accuracy: 0.6654 - val_loss: 0.9108 - val_accuracy: 0.6680 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 9/60
# 610/610 - 2s - loss: 0.9519 - accuracy: 0.6426 - val_loss: 0.9701 - val_accuracy: 0.6420 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 9/60
#
# Epoch 8: val_accuracy improved from 0.63787 to 0.64757, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/1023model.keras
#
# Epoch 8: val_accuracy did not improve from 0.63695
# 610/610 - 2s - loss: 0.9716 - accuracy: 0.6337 - val_loss: 0.9869 - val_accuracy: 0.6186 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 9/60
# 610/610 - 2s - loss: 0.9499 - accuracy: 0.6446 - val_loss: 0.9433 - val_accuracy: 0.6476 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 9/60
#
# Epoch 8: val_accuracy did not improve from 0.64423
# 610/610 - 2s - loss: 0.9588 - accuracy: 0.6430 - val_loss: 0.9730 - val_accuracy: 0.6359 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 9/60
#
# Epoch 8: val_accuracy improved from 0.63593 to 0.63731, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0123model.keras
# 610/610 - 2s - loss: 0.9684 - accuracy: 0.6359 - val_loss: 0.9664 - val_accuracy: 0.6373 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 9/60
#
# Epoch 9: val_accuracy improved from 0.66198 to 0.66239, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0213model.keras
# 610/610 - 2s - loss: 0.9204 - accuracy: 0.6658 - val_loss: 0.9133 - val_accuracy: 0.6624 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 10/60
#
# Epoch 9: val_accuracy did not improve from 0.63634
# 610/610 - 1s - loss: 0.9589 - accuracy: 0.6373 - val_loss: 0.9832 - val_accuracy: 0.6342 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 10/60
#
# Epoch 9: val_accuracy did not improve from 0.63695
# 610/610 - 2s - loss: 0.9651 - accuracy: 0.6388 - val_loss: 0.9822 - val_accuracy: 0.6227 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 10/60
#
# Epoch 9: val_accuracy did not improve from 0.66798
# 610/610 - 2s - loss: 0.9141 - accuracy: 0.6685 - val_loss: 0.9046 - val_accuracy: 0.6674 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 10/60
#
# Epoch 9: val_accuracy did not improve from 0.64203
# 610/610 - 2s - loss: 0.9473 - accuracy: 0.6446 - val_loss: 0.9551 - val_accuracy: 0.6327 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 10/60
#
# Epoch 9: val_accuracy improved from 0.64423 to 0.64485, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0312model.keras
# 610/610 - 2s - loss: 0.9539 - accuracy: 0.6437 - val_loss: 0.9491 - val_accuracy: 0.6449 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 10/60
#
# Epoch 9: val_accuracy did not improve from 0.64757
# 610/610 - 2s - loss: 0.9472 - accuracy: 0.6437 - val_loss: 0.9567 - val_accuracy: 0.6408 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 10/60
#
# Epoch 9: val_accuracy did not improve from 0.63731
# 610/610 - 2s - loss: 0.9644 - accuracy: 0.6363 - val_loss: 0.9790 - val_accuracy: 0.6272 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 10/60
#
# Epoch 10: val_accuracy did not improve from 0.66239
# 610/610 - 1s - loss: 0.9168 - accuracy: 0.6675 - val_loss: 0.9106 - val_accuracy: 0.6618 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 11/60
#
# Epoch 10: val_accuracy did not improve from 0.63634
# 610/610 - 1s - loss: 0.9579 - accuracy: 0.6362 - val_loss: 0.9564 - val_accuracy: 0.6322 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 11/60
#
# Epoch 10: val_accuracy improved from 0.64203 to 0.64916, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0132model.keras
#
# Epoch 10: val_accuracy improved from 0.66798 to 0.66860, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0231model.keras
# 610/610 - 1s - loss: 0.9427 - accuracy: 0.6485 - val_loss: 0.9391 - val_accuracy: 0.6492 - lr: 0.0010 - 1s/epoch - 2ms/step
#
# Epoch 10: val_accuracy did not improve from 0.63695
# Epoch 11/60
# 610/610 - 1s - loss: 0.9631 - accuracy: 0.6383 - val_loss: 0.9922 - val_accuracy: 0.6122 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 11/60
# 610/610 - 1s - loss: 0.9098 - accuracy: 0.6687 - val_loss: 0.8998 - val_accuracy: 0.6686 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 11/60
#
# Epoch 10: val_accuracy did not improve from 0.64485
# 610/610 - 1s - loss: 0.9486 - accuracy: 0.6457 - val_loss: 0.9475 - val_accuracy: 0.6402 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 11/60
#
# Epoch 10: val_accuracy did not improve from 0.63731
# 610/610 - 1s - loss: 0.9609 - accuracy: 0.6377 - val_loss: 0.9611 - val_accuracy: 0.6350 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 11/60
#
# Epoch 10: val_accuracy did not improve from 0.64757
# 610/610 - 1s - loss: 0.9427 - accuracy: 0.6476 - val_loss: 0.9388 - val_accuracy: 0.6473 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 11/60
#
# Epoch 11: val_accuracy improved from 0.66239 to 0.66824, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0213model.keras
#
# Epoch 11: val_accuracy did not improve from 0.63634
# 610/610 - 1s - loss: 0.9545 - accuracy: 0.6379 - val_loss: 0.9872 - val_accuracy: 0.6040 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 12/60
# 610/610 - 2s - loss: 0.9070 - accuracy: 0.6709 - val_loss: 0.9059 - val_accuracy: 0.6682 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 12/60
#
# Epoch 11: val_accuracy did not improve from 0.64916
# 610/610 - 1s - loss: 0.9392 - accuracy: 0.6487 - val_loss: 0.9567 - val_accuracy: 0.6434 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 12/60
#
# Epoch 11: val_accuracy did not improve from 0.64757
# 610/610 - 1s - loss: 0.9373 - accuracy: 0.6490 - val_loss: 0.9577 - val_accuracy: 0.6363 - lr: 0.0010 - 1s/epoch - 2ms/step
#
# Epoch 11: val_accuracy improved from 0.63695 to 0.64341, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0321model.keras
# Epoch 12/60
#
# Epoch 11: val_accuracy did not improve from 0.64485
# 610/610 - 1s - loss: 0.9475 - accuracy: 0.6464 - val_loss: 0.9629 - val_accuracy: 0.6407 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 12/60
#
# Epoch 11: val_accuracy did not improve from 0.63731
#
# Epoch 11: val_accuracy improved from 0.66860 to 0.67127, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0231model.keras
# 610/610 - 1s - loss: 0.9560 - accuracy: 0.6413 - val_loss: 0.9549 - val_accuracy: 0.6343 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 12/60
# 610/610 - 2s - loss: 0.9617 - accuracy: 0.6407 - val_loss: 0.9618 - val_accuracy: 0.6434 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 12/60
# 610/610 - 2s - loss: 0.9055 - accuracy: 0.6715 - val_loss: 0.9018 - val_accuracy: 0.6713 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 12/60
#
# Epoch 12: val_accuracy improved from 0.63634 to 0.64075, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/1032model.keras
# 610/610 - 2s - loss: 0.9514 - accuracy: 0.6403 - val_loss: 0.9533 - val_accuracy: 0.6407 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 13/60
#
# Epoch 12: val_accuracy did not improve from 0.66824
# 610/610 - 2s - loss: 0.9069 - accuracy: 0.6708 - val_loss: 0.9278 - val_accuracy: 0.6535 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 13/60
#
# Epoch 12: val_accuracy did not improve from 0.64916
# 610/610 - 2s - loss: 0.9366 - accuracy: 0.6505 - val_loss: 0.9539 - val_accuracy: 0.6460 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 13/60
#
# Epoch 12: val_accuracy improved from 0.63731 to 0.64059, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0123model.keras
# 610/610 - 2s - loss: 0.9541 - accuracy: 0.6428 - val_loss: 0.9575 - val_accuracy: 0.6406 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 13/60
#
# Epoch 12: val_accuracy improved from 0.64757 to 0.64834, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/1023model.keras
#
# Epoch 12: val_accuracy did not improve from 0.64485
# 610/610 - 2s - loss: 0.9443 - accuracy: 0.6474 - val_loss: 0.9468 - val_accuracy: 0.6399 - lr: 0.0010 - 2s/epoch - 3ms/step
#
# Epoch 12: val_accuracy improved from 0.64341 to 0.64721, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0321model.keras
# Epoch 13/60
# 610/610 - 2s - loss: 0.9370 - accuracy: 0.6485 - val_loss: 0.9410 - val_accuracy: 0.6483 - lr: 0.0010 - 2s/epoch - 3ms/step
#
# Epoch 12: val_accuracy did not improve from 0.67127
# Epoch 13/60
# 610/610 - 2s - loss: 0.9022 - accuracy: 0.6713 - val_loss: 0.8947 - val_accuracy: 0.6685 - lr: 0.0010 - 2s/epoch - 3ms/step
# 610/610 - 2s - loss: 0.9562 - accuracy: 0.6423 - val_loss: 0.9588 - val_accuracy: 0.6472 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 13/60
# Epoch 13/60
#
# Epoch 13: val_accuracy did not improve from 0.66824
# 610/610 - 2s - loss: 0.9026 - accuracy: 0.6717 - val_loss: 0.9165 - val_accuracy: 0.6576 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 14/60
#
# Epoch 13: val_accuracy improved from 0.64075 to 0.64208, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/1032model.keras
#
# Epoch 13: val_accuracy did not improve from 0.64916
# 610/610 - 2s - loss: 0.9346 - accuracy: 0.6503 - val_loss: 0.9401 - val_accuracy: 0.6463 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 14/60
# 610/610 - 2s - loss: 0.9483 - accuracy: 0.6422 - val_loss: 0.9490 - val_accuracy: 0.6421 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 14/60
#
# Epoch 13: val_accuracy did not improve from 0.64721
# 610/610 - 2s - loss: 0.9555 - accuracy: 0.6443 - val_loss: 0.9511 - val_accuracy: 0.6457 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 14/60
#
# Epoch 13: val_accuracy improved from 0.67127 to 0.67470, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0231model.keras
#
# Epoch 13: val_accuracy did not improve from 0.64059
#
# Epoch 13: val_accuracy improved from 0.64485 to 0.65188, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0312model.keras
# 610/610 - 2s - loss: 0.9518 - accuracy: 0.6428 - val_loss: 0.9625 - val_accuracy: 0.6382 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 14/60
# 610/610 - 2s - loss: 0.8987 - accuracy: 0.6749 - val_loss: 0.8891 - val_accuracy: 0.6747 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 14/60
# 610/610 - 2s - loss: 0.9426 - accuracy: 0.6497 - val_loss: 0.9370 - val_accuracy: 0.6519 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 14/60
#
# Epoch 13: val_accuracy did not improve from 0.64834
# 610/610 - 2s - loss: 0.9310 - accuracy: 0.6519 - val_loss: 0.9643 - val_accuracy: 0.6253 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 14/60
#
# Epoch 14: val_accuracy improved from 0.66824 to 0.67342, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0213model.keras
# 610/610 - 1s - loss: 0.9001 - accuracy: 0.6734 - val_loss: 0.9053 - val_accuracy: 0.6734 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 15/60
#
# Epoch 14: val_accuracy did not improve from 0.64208
# 610/610 - 1s - loss: 0.9458 - accuracy: 0.6441 - val_loss: 0.9502 - val_accuracy: 0.6410 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 15/60
#
# Epoch 14: val_accuracy improved from 0.64916 to 0.64926, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0132model.keras
# 610/610 - 1s - loss: 0.9319 - accuracy: 0.6518 - val_loss: 0.9386 - val_accuracy: 0.6493 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 15/60
#
# Epoch 14: val_accuracy did not improve from 0.64721
# 610/610 - 1s - loss: 0.9543 - accuracy: 0.6434 - val_loss: 0.9606 - val_accuracy: 0.6342 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 15/60
#
# Epoch 14: val_accuracy improved from 0.67470 to 0.67568, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0231model.keras
#
# Epoch 14: val_accuracy did not improve from 0.64059
# 610/610 - 1s - loss: 0.9499 - accuracy: 0.6447 - val_loss: 0.9988 - val_accuracy: 0.6139 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 15/60
# 610/610 - 1s - loss: 0.8964 - accuracy: 0.6739 - val_loss: 0.9069 - val_accuracy: 0.6757 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 15/60
#
# Epoch 14: val_accuracy did not improve from 0.65188
# 610/610 - 1s - loss: 0.9404 - accuracy: 0.6513 - val_loss: 0.9399 - val_accuracy: 0.6475 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 15/60
#
# Epoch 14: val_accuracy improved from 0.64834 to 0.65126, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/1023model.keras
# 610/610 - 1s - loss: 0.9297 - accuracy: 0.6526 - val_loss: 0.9300 - val_accuracy: 0.6513 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 15/60
#
# Epoch 15: val_accuracy did not improve from 0.67342
# 610/610 - 1s - loss: 0.9011 - accuracy: 0.6726 - val_loss: 0.9029 - val_accuracy: 0.6652 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 16/60
#
# Epoch 15: val_accuracy improved from 0.64208 to 0.64290, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/1032model.keras
# 610/610 - 1s - loss: 0.9467 - accuracy: 0.6421 - val_loss: 0.9472 - val_accuracy: 0.6429 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 16/60
#
# Epoch 15: val_accuracy did not improve from 0.64926
# 610/610 - 1s - loss: 0.9305 - accuracy: 0.6523 - val_loss: 0.9396 - val_accuracy: 0.6491 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 16/60
#
# Epoch 15: val_accuracy improved from 0.64721 to 0.64890, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0321model.keras
# 610/610 - 1s - loss: 0.9515 - accuracy: 0.6446 - val_loss: 0.9533 - val_accuracy: 0.6489 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 16/60
#
# Epoch 15: val_accuracy did not improve from 0.67568
# 610/610 - 1s - loss: 0.8916 - accuracy: 0.6763 - val_loss: 0.9069 - val_accuracy: 0.6739 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 16/60
#
# Epoch 15: val_accuracy improved from 0.65188 to 0.65249, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0312model.keras
#
# Epoch 15: val_accuracy improved from 0.65126 to 0.65454, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/1023model.keras
#
# Epoch 15: val_accuracy improved from 0.64059 to 0.64562, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0123model.keras
# 610/610 - 1s - loss: 0.9366 - accuracy: 0.6521 - val_loss: 0.9372 - val_accuracy: 0.6525 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 16/60
# 610/610 - 1s - loss: 0.9491 - accuracy: 0.6427 - val_loss: 0.9647 - val_accuracy: 0.6456 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 16/60
# 610/610 - 1s - loss: 0.9297 - accuracy: 0.6525 - val_loss: 0.9274 - val_accuracy: 0.6545 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 16/60
#
# Epoch 16: val_accuracy did not improve from 0.67342
# 610/610 - 1s - loss: 0.8944 - accuracy: 0.6752 - val_loss: 0.9041 - val_accuracy: 0.6682 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 17/60
#
# Epoch 16: val_accuracy improved from 0.64926 to 0.65183, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0132model.keras
# 610/610 - 1s - loss: 0.9252 - accuracy: 0.6545 - val_loss: 0.9299 - val_accuracy: 0.6518 - lr: 0.0010 - 995ms/epoch - 2ms/step
# Epoch 17/60
#
# Epoch 16: val_accuracy did not improve from 0.64290
# 610/610 - 1s - loss: 0.9436 - accuracy: 0.6431 - val_loss: 0.9545 - val_accuracy: 0.6415 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 17/60
#
# Epoch 16: val_accuracy did not improve from 0.64890
# 610/610 - 1s - loss: 0.9521 - accuracy: 0.6441 - val_loss: 0.9528 - val_accuracy: 0.6397 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 17/60
#
# Epoch 16: val_accuracy improved from 0.67568 to 0.67686, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0231model.keras
# 610/610 - 1s - loss: 0.8916 - accuracy: 0.6764 - val_loss: 0.8905 - val_accuracy: 0.6769 - lr: 0.0010 - 1s/epoch - 2ms/step
#
# Epoch 16: val_accuracy did not improve from 0.64562
# 610/610 - 1s - loss: 0.9454 - accuracy: 0.6465 - val_loss: 0.9533 - val_accuracy: 0.6394 - lr: 0.0010 - 990ms/epoch - 2ms/step
# Epoch 17/60
# Epoch 17/60
#
# Epoch 16: val_accuracy did not improve from 0.65249
# 610/610 - 1s - loss: 0.9363 - accuracy: 0.6502 - val_loss: 0.9626 - val_accuracy: 0.6288 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 17/60
#
# Epoch 16: val_accuracy did not improve from 0.65454
# 610/610 - 1s - loss: 0.9248 - accuracy: 0.6545 - val_loss: 0.9400 - val_accuracy: 0.6449 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 17/60
#
# Epoch 17: val_accuracy improved from 0.65183 to 0.65265, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0132model.keras
# 610/610 - 1s - loss: 0.9292 - accuracy: 0.6510 - val_loss: 0.9331 - val_accuracy: 0.6526 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 18/60
#
# Epoch 17: val_accuracy did not improve from 0.67342
# 610/610 - 1s - loss: 0.8944 - accuracy: 0.6757 - val_loss: 0.8949 - val_accuracy: 0.6734 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 18/60
#
# Epoch 17: val_accuracy improved from 0.64290 to 0.64352, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/1032model.keras
#
# Epoch 17: val_accuracy did not improve from 0.64890
# 610/610 - 1s - loss: 0.9485 - accuracy: 0.6458 - val_loss: 0.9748 - val_accuracy: 0.6232 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 18/60
# 610/610 - 1s - loss: 0.9406 - accuracy: 0.6463 - val_loss: 0.9428 - val_accuracy: 0.6435 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 18/60
#
# Epoch 17: val_accuracy did not improve from 0.67686
# 610/610 - 1s - loss: 0.8905 - accuracy: 0.6755 - val_loss: 0.9000 - val_accuracy: 0.6749 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 18/60
#
# Epoch 17: val_accuracy did not improve from 0.64562
# 610/610 - 1s - loss: 0.9449 - accuracy: 0.6474 - val_loss: 0.9494 - val_accuracy: 0.6426 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 18/60
#
# Epoch 17: val_accuracy did not improve from 0.65454
# 610/610 - 1s - loss: 0.9248 - accuracy: 0.6542 - val_loss: 0.9260 - val_accuracy: 0.6497 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 18/60
#
# Epoch 17: val_accuracy did not improve from 0.65249
# 610/610 - 1s - loss: 0.9358 - accuracy: 0.6509 - val_loss: 0.9515 - val_accuracy: 0.6462 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 18/60
#
# Epoch 18: val_accuracy did not improve from 0.65265
# 610/610 - 1s - loss: 0.9250 - accuracy: 0.6547 - val_loss: 0.9377 - val_accuracy: 0.6417 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 19/60
#
# Epoch 18: val_accuracy did not improve from 0.67342
# 610/610 - 1s - loss: 0.8947 - accuracy: 0.6736 - val_loss: 0.9291 - val_accuracy: 0.6713 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 19/60
#
# Epoch 18: val_accuracy improved from 0.64890 to 0.64916, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0321model.keras
# 610/610 - 1s - loss: 0.9483 - accuracy: 0.6456 - val_loss: 0.9441 - val_accuracy: 0.6492 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 19/60
#
# Epoch 18: val_accuracy did not improve from 0.67686
# 610/610 - 1s - loss: 0.8883 - accuracy: 0.6783 - val_loss: 0.9019 - val_accuracy: 0.6694 - lr: 0.0010 - 1s/epoch - 2ms/step
#
# Epoch 18: val_accuracy did not improve from 0.64352
# Epoch 19/60
# 610/610 - 1s - loss: 0.9409 - accuracy: 0.6460 - val_loss: 0.9486 - val_accuracy: 0.6366 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 19/60
#
# Epoch 18: val_accuracy did not improve from 0.64562
# 610/610 - 1s - loss: 0.9449 - accuracy: 0.6467 - val_loss: 0.9400 - val_accuracy: 0.6454 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 19/60
#
# Epoch 18: val_accuracy did not improve from 0.65454
# 610/610 - 1s - loss: 0.9240 - accuracy: 0.6540 - val_loss: 0.9308 - val_accuracy: 0.6544 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 19/60
#
# Epoch 18: val_accuracy improved from 0.65249 to 0.65475, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0312model.keras
# 610/610 - 1s - loss: 0.9341 - accuracy: 0.6523 - val_loss: 0.9300 - val_accuracy: 0.6547 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 19/60
#
# Epoch 19: val_accuracy did not improve from 0.65265
# 610/610 - 1s - loss: 0.9237 - accuracy: 0.6564 - val_loss: 0.9273 - val_accuracy: 0.6507 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 20/60
#
# Epoch 19: val_accuracy improved from 0.67342 to 0.67409, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0213model.keras
# 610/610 - 1s - loss: 0.8905 - accuracy: 0.6777 - val_loss: 0.9007 - val_accuracy: 0.6741 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 20/60
#
# Epoch 19: val_accuracy did not improve from 0.64916
# 610/610 - 1s - loss: 0.9458 - accuracy: 0.6477 - val_loss: 0.9557 - val_accuracy: 0.6486 - lr: 0.0010 - 988ms/epoch - 2ms/step
# Epoch 20/60
#
# Epoch 19: val_accuracy did not improve from 0.67686
# 610/610 - 1s - loss: 0.8876 - accuracy: 0.6776 - val_loss: 0.8835 - val_accuracy: 0.6765 - lr: 0.0010 - 979ms/epoch - 2ms/step
# Epoch 20/60
#
# Epoch 19: val_accuracy improved from 0.64352 to 0.64382, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/1032model.keras
# 610/610 - 1s - loss: 0.9389 - accuracy: 0.6475 - val_loss: 0.9409 - val_accuracy: 0.6438 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 20/60
#
# Epoch 19: val_accuracy did not improve from 0.64562
# 610/610 - 1s - loss: 0.9428 - accuracy: 0.6467 - val_loss: 0.9634 - val_accuracy: 0.6320 - lr: 0.0010 - 967ms/epoch - 2ms/step
# Epoch 20/60
#
# Epoch 19: val_accuracy did not improve from 0.65454
# 610/610 - 1s - loss: 0.9231 - accuracy: 0.6547 - val_loss: 0.9411 - val_accuracy: 0.6458 - lr: 0.0010 - 975ms/epoch - 2ms/step
# Epoch 20/60
#
# Epoch 19: val_accuracy did not improve from 0.65475
# 610/610 - 1s - loss: 0.9298 - accuracy: 0.6533 - val_loss: 0.9308 - val_accuracy: 0.6537 - lr: 0.0010 - 927ms/epoch - 2ms/step
# Epoch 20/60
#
# Epoch 20: val_accuracy improved from 0.65265 to 0.65454, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0132model.keras
# 610/610 - 1s - loss: 0.9203 - accuracy: 0.6571 - val_loss: 0.9226 - val_accuracy: 0.6545 - lr: 0.0010 - 916ms/epoch - 2ms/step
# Epoch 21/60
#
# Epoch 20: val_accuracy did not improve from 0.67409
# 610/610 - 1s - loss: 0.8932 - accuracy: 0.6762 - val_loss: 0.8987 - val_accuracy: 0.6636 - lr: 0.0010 - 905ms/epoch - 1ms/step
# Epoch 21/60
#
# Epoch 20: val_accuracy improved from 0.64916 to 0.65172, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0321model.keras
#
# Epoch 20: val_accuracy improved from 0.67686 to 0.67870, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0231model.keras
# 610/610 - 1s - loss: 0.9439 - accuracy: 0.6478 - val_loss: 0.9498 - val_accuracy: 0.6517 - lr: 0.0010 - 949ms/epoch - 2ms/step
# Epoch 21/60
# 610/610 - 1s - loss: 0.8839 - accuracy: 0.6791 - val_loss: 0.8931 - val_accuracy: 0.6787 - lr: 0.0010 - 948ms/epoch - 2ms/step
# Epoch 21/60
#
# Epoch 20: val_accuracy did not improve from 0.64382
# 610/610 - 1s - loss: 0.9371 - accuracy: 0.6479 - val_loss: 0.9553 - val_accuracy: 0.6387 - lr: 0.0010 - 941ms/epoch - 2ms/step
# Epoch 21/60
#
# Epoch 20: val_accuracy did not improve from 0.64562
# 610/610 - 1s - loss: 0.9426 - accuracy: 0.6471 - val_loss: 0.9516 - val_accuracy: 0.6371 - lr: 0.0010 - 926ms/epoch - 2ms/step
# Epoch 21/60
#
# Epoch 20: val_accuracy did not improve from 0.65454
# 610/610 - 1s - loss: 0.9212 - accuracy: 0.6553 - val_loss: 0.9370 - val_accuracy: 0.6519 - lr: 0.0010 - 922ms/epoch - 2ms/step
# Epoch 21/60
#
# Epoch 20: val_accuracy did not improve from 0.65475
# 610/610 - 1s - loss: 0.9305 - accuracy: 0.6534 - val_loss: 0.9305 - val_accuracy: 0.6540 - lr: 0.0010 - 925ms/epoch - 2ms/step
# Epoch 21/60
#
# Epoch 21: val_accuracy improved from 0.65454 to 0.65731, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0132model.keras
#
# Epoch 21: val_accuracy did not improve from 0.67409
# 610/610 - 1s - loss: 0.8893 - accuracy: 0.6787 - val_loss: 0.8876 - val_accuracy: 0.6727 - lr: 0.0010 - 988ms/epoch - 2ms/step
# Epoch 22/60
# 610/610 - 1s - loss: 0.9171 - accuracy: 0.6589 - val_loss: 0.9348 - val_accuracy: 0.6573 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 22/60
#
# Epoch 21: val_accuracy did not improve from 0.67870
# 610/610 - 1s - loss: 0.8833 - accuracy: 0.6806 - val_loss: 0.8922 - val_accuracy: 0.6752 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 22/60
#
# Epoch 21: val_accuracy did not improve from 0.65172
# 610/610 - 1s - loss: 0.9446 - accuracy: 0.6476 - val_loss: 0.9416 - val_accuracy: 0.6475 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 22/60
#
# Epoch 21: val_accuracy did not improve from 0.64382
# 610/610 - 1s - loss: 0.9349 - accuracy: 0.6485 - val_loss: 0.9394 - val_accuracy: 0.6438 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 22/60
#
# Epoch 21: val_accuracy improved from 0.64562 to 0.64808, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0123model.keras
# 610/610 - 1s - loss: 0.9422 - accuracy: 0.6476 - val_loss: 0.9479 - val_accuracy: 0.6481 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 22/60
#
# Epoch 21: val_accuracy did not improve from 0.65454
# 610/610 - 1s - loss: 0.9183 - accuracy: 0.6578 - val_loss: 0.9242 - val_accuracy: 0.6467 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 22/60
#
# Epoch 21: val_accuracy did not improve from 0.65475
# 610/610 - 1s - loss: 0.9275 - accuracy: 0.6543 - val_loss: 0.9438 - val_accuracy: 0.6444 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 22/60
#
# Epoch 22: val_accuracy improved from 0.67409 to 0.67701, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0213model.keras
#
# Epoch 22: val_accuracy improved from 0.65731 to 0.65855, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0132model.keras
# 610/610 - 1s - loss: 0.8857 - accuracy: 0.6785 - val_loss: 0.8878 - val_accuracy: 0.6770 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 23/60
# 610/610 - 1s - loss: 0.9186 - accuracy: 0.6573 - val_loss: 0.9172 - val_accuracy: 0.6585 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 23/60
#
# Epoch 22: val_accuracy did not improve from 0.67870
# 610/610 - 1s - loss: 0.8818 - accuracy: 0.6798 - val_loss: 0.9049 - val_accuracy: 0.6740 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 23/60
#
# Epoch 22: val_accuracy did not improve from 0.65172
# 610/610 - 1s - loss: 0.9426 - accuracy: 0.6479 - val_loss: 0.9462 - val_accuracy: 0.6490 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 23/60
#
# Epoch 22: val_accuracy did not improve from 0.64382
# 610/610 - 1s - loss: 0.9356 - accuracy: 0.6477 - val_loss: 0.9518 - val_accuracy: 0.6344 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 23/60
#
# Epoch 22: val_accuracy improved from 0.65454 to 0.65701, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/1023model.keras
#
# Epoch 22: val_accuracy did not improve from 0.64808
# 610/610 - 1s - loss: 0.9413 - accuracy: 0.6478 - val_loss: 0.9454 - val_accuracy: 0.6407 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 23/60
# 610/610 - 1s - loss: 0.9188 - accuracy: 0.6587 - val_loss: 0.9157 - val_accuracy: 0.6570 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 23/60
#
# Epoch 22: val_accuracy did not improve from 0.65475
# 610/610 - 1s - loss: 0.9253 - accuracy: 0.6558 - val_loss: 0.9361 - val_accuracy: 0.6512 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 23/60
#
# Epoch 23: val_accuracy did not improve from 0.65855
# 610/610 - 1s - loss: 0.9168 - accuracy: 0.6585 - val_loss: 0.9180 - val_accuracy: 0.6572 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 24/60
#
# Epoch 23: val_accuracy did not improve from 0.67701
# 610/610 - 1s - loss: 0.8858 - accuracy: 0.6783 - val_loss: 0.8971 - val_accuracy: 0.6745 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 24/60
#
# Epoch 23: val_accuracy did not improve from 0.67870
# 610/610 - 1s - loss: 0.8817 - accuracy: 0.6802 - val_loss: 0.8817 - val_accuracy: 0.6744 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 24/60
#
# Epoch 23: val_accuracy did not improve from 0.65172
# 610/610 - 1s - loss: 0.9408 - accuracy: 0.6492 - val_loss: 0.9513 - val_accuracy: 0.6387 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 24/60
#
# Epoch 23: val_accuracy improved from 0.64382 to 0.64634, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/1032model.keras
# 610/610 - 1s - loss: 0.9342 - accuracy: 0.6484 - val_loss: 0.9387 - val_accuracy: 0.6463 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 24/60
#
# Epoch 23: val_accuracy did not improve from 0.65475
# 610/610 - 1s - loss: 0.9266 - accuracy: 0.6557 - val_loss: 0.9339 - val_accuracy: 0.6500 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 24/60
#
# Epoch 23: val_accuracy improved from 0.64808 to 0.65008, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0123model.keras
#
# Epoch 23: val_accuracy did not improve from 0.65701
# 610/610 - 1s - loss: 0.9173 - accuracy: 0.6577 - val_loss: 0.9205 - val_accuracy: 0.6529 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 24/60
# 610/610 - 1s - loss: 0.9392 - accuracy: 0.6475 - val_loss: 0.9378 - val_accuracy: 0.6501 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 24/60
#
# Epoch 24: val_accuracy did not improve from 0.65855
# 610/610 - 1s - loss: 0.9138 - accuracy: 0.6595 - val_loss: 0.9236 - val_accuracy: 0.6560 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 25/60
#
# Epoch 24: val_accuracy improved from 0.67701 to 0.67716, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0213model.keras
# 610/610 - 1s - loss: 0.8831 - accuracy: 0.6802 - val_loss: 0.8839 - val_accuracy: 0.6772 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 25/60
#
# Epoch 24: val_accuracy improved from 0.67870 to 0.67927, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0231model.keras
# 610/610 - 1s - loss: 0.8761 - accuracy: 0.6817 - val_loss: 0.8826 - val_accuracy: 0.6793 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 25/60
#
# Epoch 24: val_accuracy did not improve from 0.65701
# 610/610 - 1s - loss: 0.9144 - accuracy: 0.6588 - val_loss: 0.9189 - val_accuracy: 0.6520 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 25/60
#
# Epoch 24: val_accuracy did not improve from 0.65172
# 610/610 - 1s - loss: 0.9400 - accuracy: 0.6496 - val_loss: 0.9427 - val_accuracy: 0.6472 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 25/60
#
# Epoch 24: val_accuracy did not improve from 0.64634
# 610/610 - 1s - loss: 0.9334 - accuracy: 0.6496 - val_loss: 0.9393 - val_accuracy: 0.6440 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 25/60
#
# Epoch 24: val_accuracy did not improve from 0.65475
# 610/610 - 1s - loss: 0.9257 - accuracy: 0.6561 - val_loss: 0.9380 - val_accuracy: 0.6545 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 25/60
#
# Epoch 24: val_accuracy did not improve from 0.65008
# 610/610 - 1s - loss: 0.9360 - accuracy: 0.6503 - val_loss: 0.9509 - val_accuracy: 0.6449 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 25/60
#
# Epoch 25: val_accuracy improved from 0.65855 to 0.65926, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0132model.keras
# 610/610 - 1s - loss: 0.9182 - accuracy: 0.6583 - val_loss: 0.9117 - val_accuracy: 0.6593 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 26/60
#
# Epoch 25: val_accuracy did not improve from 0.67716
# 610/610 - 1s - loss: 0.8812 - accuracy: 0.6797 - val_loss: 0.9262 - val_accuracy: 0.6604 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 26/60
#
# Epoch 25: val_accuracy did not improve from 0.67927
# 610/610 - 1s - loss: 0.8764 - accuracy: 0.6829 - val_loss: 0.8755 - val_accuracy: 0.6784 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 26/60
#
# Epoch 25: val_accuracy did not improve from 0.65475
# 610/610 - 1s - loss: 0.9238 - accuracy: 0.6568 - val_loss: 0.9307 - val_accuracy: 0.6493 - lr: 0.0010 - 1s/epoch - 2ms/step
#
# Epoch 25: val_accuracy improved from 0.64634 to 0.64798, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/1032model.keras
# Epoch 26/60
#
# Epoch 25: val_accuracy improved from 0.65701 to 0.65783, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/1023model.keras
# 610/610 - 1s - loss: 0.9136 - accuracy: 0.6590 - val_loss: 0.9140 - val_accuracy: 0.6578 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 26/60
# 610/610 - 1s - loss: 0.9333 - accuracy: 0.6490 - val_loss: 0.9345 - val_accuracy: 0.6480 - lr: 0.0010 - 1s/epoch - 2ms/step
#
# Epoch 25: val_accuracy did not improve from 0.65172
# Epoch 26/60
# 610/610 - 1s - loss: 0.9388 - accuracy: 0.6505 - val_loss: 0.9477 - val_accuracy: 0.6516 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 26/60
#
# Epoch 25: val_accuracy did not improve from 0.65008
# 610/610 - 1s - loss: 0.9379 - accuracy: 0.6487 - val_loss: 0.9414 - val_accuracy: 0.6420 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 26/60
#
# Epoch 26: val_accuracy did not improve from 0.65926
# 610/610 - 1s - loss: 0.9138 - accuracy: 0.6600 - val_loss: 0.9215 - val_accuracy: 0.6590 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 27/60
#
# Epoch 26: val_accuracy did not improve from 0.67716
# 610/610 - 1s - loss: 0.8827 - accuracy: 0.6800 - val_loss: 0.8924 - val_accuracy: 0.6736 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 27/60
#
# Epoch 26: val_accuracy did not improve from 0.67927
# 610/610 - 1s - loss: 0.8780 - accuracy: 0.6827 - val_loss: 0.8963 - val_accuracy: 0.6768 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 27/60
#
# Epoch 26: val_accuracy did not improve from 0.64798
# 610/610 - 1s - loss: 0.9308 - accuracy: 0.6524 - val_loss: 0.9390 - val_accuracy: 0.6427 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 27/60
#
# Epoch 26: val_accuracy did not improve from 0.65475
# 610/610 - 2s - loss: 0.9230 - accuracy: 0.6557 - val_loss: 0.9601 - val_accuracy: 0.6322 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 27/60
#
# Epoch 26: val_accuracy did not improve from 0.65783
# 610/610 - 2s - loss: 0.9138 - accuracy: 0.6597 - val_loss: 0.9176 - val_accuracy: 0.6555 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 27/60
#
# Epoch 26: val_accuracy did not improve from 0.65172
# 610/610 - 2s - loss: 0.9383 - accuracy: 0.6509 - val_loss: 0.9347 - val_accuracy: 0.6503 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 27/60
#
# Epoch 26: val_accuracy did not improve from 0.65008
# 610/610 - 1s - loss: 0.9376 - accuracy: 0.6492 - val_loss: 0.9351 - val_accuracy: 0.6493 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 27/60
#
# Epoch 27: val_accuracy did not improve from 0.65926
# 610/610 - 1s - loss: 0.9143 - accuracy: 0.6594 - val_loss: 0.9215 - val_accuracy: 0.6533 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 28/60
#
# Epoch 27: val_accuracy did not improve from 0.67716
# 610/610 - 1s - loss: 0.8817 - accuracy: 0.6803 - val_loss: 0.8888 - val_accuracy: 0.6744 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 28/60
#
# Epoch 27: val_accuracy improved from 0.67927 to 0.68034, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/0231model.keras
# 610/610 - 1s - loss: 0.8772 - accuracy: 0.6819 - val_loss: 0.8783 - val_accuracy: 0.6803 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 28/60
#
# Epoch 27: val_accuracy did not improve from 0.65783
# 610/610 - 1s - loss: 0.9135 - accuracy: 0.6590 - val_loss: 0.9224 - val_accuracy: 0.6501 - lr: 0.0010 - 1s/epoch - 2ms/step
#
# ...
# Epoch 52/60
#
# Epoch 51: val_accuracy did not improve from 0.65526
# 610/610 - 2s - loss: 0.9128 - accuracy: 0.6603 - val_loss: 0.9239 - val_accuracy: 0.6544 - lr: 1.0000e-04 - 2s/epoch - 3ms/step
# Epoch 52/60
#
# Epoch 51: val_accuracy did not improve from 0.65526
# 610/610 - 2s - loss: 0.9082 - accuracy: 0.6597 - val_loss: 0.9213 - val_accuracy: 0.6512 - lr: 1.0000e-04 - 2s/epoch - 3ms/step
# Epoch 52/60
#
# Epoch 51: val_accuracy did not improve from 0.66049
# 610/610 - 2s - loss: 0.8976 - accuracy: 0.6654 - val_loss: 0.9087 - val_accuracy: 0.6589 - lr: 1.0000e-04 - 2s/epoch - 3ms/step
# Epoch 52/60
#
# Epoch 51: val_accuracy did not improve from 0.65506
# 610/610 - 2s - loss: 0.9187 - accuracy: 0.6577 - val_loss: 0.9244 - val_accuracy: 0.6531 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 52/60
#
# Epoch 51: val_accuracy did not improve from 0.66506
# 610/610 - 2s - loss: 0.8886 - accuracy: 0.6690 - val_loss: 0.9001 - val_accuracy: 0.6634 - lr: 1.0000e-04 - 2s/epoch - 3ms/step
# Epoch 52/60
#
# Epoch 51: val_accuracy did not improve from 0.68501
# 610/610 - 2s - loss: 0.8634 - accuracy: 0.6878 - val_loss: 0.8640 - val_accuracy: 0.6847 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 52/60
#
# Epoch 52: val_accuracy did not improve from 0.68470
# 610/610 - 2s - loss: 0.8598 - accuracy: 0.6880 - val_loss: 0.8651 - val_accuracy: 0.6840 - lr: 1.0000e-04 - 2s/epoch - 3ms/step
# Epoch 53/60
#
# Epoch 52: val_accuracy improved from 0.65526 to 0.65537, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/2301model.keras
#
# Epoch 52: val_accuracy did not improve from 0.66485
# 610/610 - 2s - loss: 0.9132 - accuracy: 0.6596 - val_loss: 0.9225 - val_accuracy: 0.6554 - lr: 1.0000e-04 - 2s/epoch - 3ms/step
# 610/610 - 2s - loss: 0.8984 - accuracy: 0.6679 - val_loss: 0.9020 - val_accuracy: 0.6585 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 53/60
# Epoch 53/60
#
# Epoch 52: val_accuracy did not improve from 0.65526
# 610/610 - 2s - loss: 0.9082 - accuracy: 0.6604 - val_loss: 0.9225 - val_accuracy: 0.6545 - lr: 1.0000e-04 - 2s/epoch - 3ms/step
# Epoch 53/60
#
# Epoch 52: val_accuracy did not improve from 0.66049
# 610/610 - 2s - loss: 0.8973 - accuracy: 0.6659 - val_loss: 0.9072 - val_accuracy: 0.6593 - lr: 1.0000e-04 - 2s/epoch - 3ms/step
# Epoch 53/60
#
# Epoch 52: val_accuracy did not improve from 0.65506
# 610/610 - 2s - loss: 0.9168 - accuracy: 0.6581 - val_loss: 0.9283 - val_accuracy: 0.6544 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 53/60
#
# Epoch 52: val_accuracy did not improve from 0.66506
# 610/610 - 2s - loss: 0.8884 - accuracy: 0.6694 - val_loss: 0.8986 - val_accuracy: 0.6619 - lr: 1.0000e-04 - 2s/epoch - 3ms/step
# Epoch 53/60
#
# Epoch 52: val_accuracy did not improve from 0.68501
# 610/610 - 1s - loss: 0.8599 - accuracy: 0.6887 - val_loss: 0.8712 - val_accuracy: 0.6790 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 53/60
#
# Epoch 53: val_accuracy did not improve from 0.65537
#
# Epoch 53: val_accuracy did not improve from 0.68470
# 610/610 - 1s - loss: 0.9125 - accuracy: 0.6604 - val_loss: 0.9237 - val_accuracy: 0.6525 - lr: 1.0000e-04 - 1s/epoch - 2ms/step
# 610/610 - 1s - loss: 0.8594 - accuracy: 0.6877 - val_loss: 0.8667 - val_accuracy: 0.6816 - lr: 1.0000e-04 - 1s/epoch - 2ms/step
# Epoch 54/60
# Epoch 54/60
#
# Epoch 53: val_accuracy improved from 0.66485 to 0.66603, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/3021model.keras
# 610/610 - 1s - loss: 0.8969 - accuracy: 0.6670 - val_loss: 0.9001 - val_accuracy: 0.6660 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 54/60
#
# Epoch 53: val_accuracy did not improve from 0.65526
# 610/610 - 1s - loss: 0.9080 - accuracy: 0.6605 - val_loss: 0.9216 - val_accuracy: 0.6536 - lr: 1.0000e-04 - 1s/epoch - 2ms/step
# Epoch 54/60
#
# Epoch 53: val_accuracy did not improve from 0.66049
# 610/610 - 1s - loss: 0.8974 - accuracy: 0.6661 - val_loss: 0.9102 - val_accuracy: 0.6583 - lr: 1.0000e-04 - 1s/epoch - 2ms/step
# Epoch 54/60
#
# Epoch 53: val_accuracy did not improve from 0.65506
# 610/610 - 1s - loss: 0.9198 - accuracy: 0.6562 - val_loss: 0.9307 - val_accuracy: 0.6503 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 54/60
#
# Epoch 53: val_accuracy did not improve from 0.66506
# 610/610 - 1s - loss: 0.8882 - accuracy: 0.6695 - val_loss: 0.8987 - val_accuracy: 0.6638 - lr: 1.0000e-04 - 1s/epoch - 2ms/step
# Epoch 54/60
#
# Epoch 53: val_accuracy did not improve from 0.68501
# 610/610 - 1s - loss: 0.8611 - accuracy: 0.6876 - val_loss: 0.8756 - val_accuracy: 0.6793 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 54/60
#
# Epoch 54: val_accuracy did not improve from 0.65537
# 610/610 - 1s - loss: 0.9125 - accuracy: 0.6597 - val_loss: 0.9252 - val_accuracy: 0.6516 - lr: 1.0000e-04 - 1s/epoch - 2ms/step
# Epoch 55/60
#
# Epoch 54: val_accuracy did not improve from 0.68470
# 610/610 - 1s - loss: 0.8595 - accuracy: 0.6874 - val_loss: 0.8655 - val_accuracy: 0.6845 - lr: 1.0000e-04 - 1s/epoch - 2ms/step
# Epoch 55/60
#
# Epoch 54: val_accuracy did not improve from 0.66603
# 610/610 - 1s - loss: 0.8999 - accuracy: 0.6671 - val_loss: 0.9026 - val_accuracy: 0.6613 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 55/60
#
# Epoch 54: val_accuracy did not improve from 0.65526
# 610/610 - 1s - loss: 0.9081 - accuracy: 0.6602 - val_loss: 0.9214 - val_accuracy: 0.6509 - lr: 1.0000e-04 - 1s/epoch - 2ms/step
# Epoch 55/60
#
# Epoch 54: val_accuracy did not improve from 0.65506
# 610/610 - 1s - loss: 0.9171 - accuracy: 0.6579 - val_loss: 0.9538 - val_accuracy: 0.6314 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 55/60
#
# Epoch 54: val_accuracy did not improve from 0.66049
# 610/610 - 1s - loss: 0.8972 - accuracy: 0.6667 - val_loss: 0.9078 - val_accuracy: 0.6584 - lr: 1.0000e-04 - 1s/epoch - 2ms/step
# Epoch 55/60
#
# Epoch 54: val_accuracy did not improve from 0.66506
# 610/610 - 1s - loss: 0.8888 - accuracy: 0.6695 - val_loss: 0.8990 - val_accuracy: 0.6636 - lr: 1.0000e-04 - 1s/epoch - 2ms/step
# Epoch 55/60
#
# Epoch 54: val_accuracy did not improve from 0.68501
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 610/610 - 1s - loss: 0.8607 - accuracy: 0.6878 - val_loss: 0.8778 - val_accuracy: 0.6769 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 55/60
#
# Epoch 55: val_accuracy did not improve from 0.68470
# 610/610 - 1s - loss: 0.8595 - accuracy: 0.6886 - val_loss: 0.8653 - val_accuracy: 0.6832 - lr: 1.0000e-04 - 1s/epoch - 2ms/step
# Epoch 56/60
#
# Epoch 55: val_accuracy improved from 0.65537 to 0.65603, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/2301model.keras
#
# Epoch 55: val_accuracy did not improve from 0.66603
# 610/610 - 1s - loss: 0.8993 - accuracy: 0.6668 - val_loss: 0.8977 - val_accuracy: 0.6643 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 56/60
# 610/610 - 1s - loss: 0.9126 - accuracy: 0.6599 - val_loss: 0.9226 - val_accuracy: 0.6560 - lr: 1.0000e-04 - 1s/epoch - 2ms/step
# Epoch 56/60
#
# Epoch 55: val_accuracy did not improve from 0.65526
# 610/610 - 1s - loss: 0.9080 - accuracy: 0.6605 - val_loss: 0.9204 - val_accuracy: 0.6545 - lr: 1.0000e-04 - 1s/epoch - 2ms/step
# Epoch 56/60
#
# Epoch 55: val_accuracy did not improve from 0.65506
# 610/610 - 1s - loss: 0.9185 - accuracy: 0.6563 - val_loss: 0.9261 - val_accuracy: 0.6532 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 56/60
#
# Epoch 55: val_accuracy did not improve from 0.66049
# 610/610 - 1s - loss: 0.8972 - accuracy: 0.6659 - val_loss: 0.9070 - val_accuracy: 0.6598 - lr: 1.0000e-04 - 1s/epoch - 2ms/step
# Epoch 56/60
#
# Epoch 55: val_accuracy did not improve from 0.66506
# 610/610 - 1s - loss: 0.8884 - accuracy: 0.6692 - val_loss: 0.8994 - val_accuracy: 0.6630 - lr: 1.0000e-04 - 1s/epoch - 2ms/step
# Epoch 56/60
#
# Epoch 55: val_accuracy improved from 0.68501 to 0.68640, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/3102model.keras
# 610/610 - 1s - loss: 0.8474 - accuracy: 0.6928 - val_loss: 0.8563 - val_accuracy: 0.6864 - lr: 1.0000e-04 - 1s/epoch - 2ms/step
# Epoch 56/60
#
# Epoch 56: val_accuracy did not improve from 0.68470
# 610/610 - 1s - loss: 0.8593 - accuracy: 0.6875 - val_loss: 0.8684 - val_accuracy: 0.6841 - lr: 1.0000e-04 - 1s/epoch - 2ms/step
# Epoch 57/60
#
# Epoch 56: val_accuracy did not improve from 0.66603
# 610/610 - 2s - loss: 0.8988 - accuracy: 0.6666 - val_loss: 0.8983 - val_accuracy: 0.6637 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 57/60
#
# Epoch 56: val_accuracy did not improve from 0.65526
# 610/610 - 1s - loss: 0.9082 - accuracy: 0.6603 - val_loss: 0.9209 - val_accuracy: 0.6521 - lr: 1.0000e-04 - 1s/epoch - 2ms/step
# Epoch 57/60
#
# Epoch 56: val_accuracy did not improve from 0.66506
# 610/610 - 1s - loss: 0.8883 - accuracy: 0.6693 - val_loss: 0.9012 - val_accuracy: 0.6643 - lr: 1.0000e-04 - 1s/epoch - 2ms/step
# Epoch 57/60
#
# Epoch 56: val_accuracy improved from 0.65506 to 0.65516, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/3012model.keras
#
# Epoch 56: val_accuracy did not improve from 0.65603
# 610/610 - 2s - loss: 0.9125 - accuracy: 0.6598 - val_loss: 0.9224 - val_accuracy: 0.6557 - lr: 1.0000e-04 - 2s/epoch - 3ms/step
# Epoch 57/60
# 610/610 - 2s - loss: 0.9162 - accuracy: 0.6586 - val_loss: 0.9196 - val_accuracy: 0.6552 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 57/60
#
# Epoch 56: val_accuracy did not improve from 0.66049
#
# Epoch 56: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 610/610 - 2s - loss: 0.8971 - accuracy: 0.6658 - val_loss: 0.9066 - val_accuracy: 0.6597 - lr: 1.0000e-04 - 2s/epoch - 3ms/step
# Epoch 57/60
#
# Epoch 56: val_accuracy did not improve from 0.68640
# 610/610 - 2s - loss: 0.8468 - accuracy: 0.6926 - val_loss: 0.8563 - val_accuracy: 0.6847 - lr: 1.0000e-04 - 2s/epoch - 3ms/step
# Epoch 57/60
#
# Epoch 57: val_accuracy did not improve from 0.68470
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 610/610 - 2s - loss: 0.8594 - accuracy: 0.6873 - val_loss: 0.8649 - val_accuracy: 0.6823 - lr: 1.0000e-04 - 2s/epoch - 3ms/step
# Epoch 58/60
#
# Epoch 57: val_accuracy improved from 0.66603 to 0.66655, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/3021model.keras
# 610/610 - 2s - loss: 0.8952 - accuracy: 0.6685 - val_loss: 0.9085 - val_accuracy: 0.6665 - lr: 0.0010 - 2s/epoch - 3ms/step
# Epoch 58/60
#
# Epoch 57: val_accuracy did not improve from 0.65526
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 610/610 - 2s - loss: 0.9079 - accuracy: 0.6602 - val_loss: 0.9217 - val_accuracy: 0.6527 - lr: 1.0000e-04 - 2s/epoch - 2ms/step
# Epoch 58/60
#
# Epoch 57: val_accuracy did not improve from 0.66506
# 610/610 - 1s - loss: 0.8882 - accuracy: 0.6696 - val_loss: 0.8982 - val_accuracy: 0.6620 - lr: 1.0000e-04 - 1s/epoch - 2ms/step
# Epoch 58/60
#
# Epoch 57: val_accuracy did not improve from 0.65603
# 610/610 - 1s - loss: 0.9124 - accuracy: 0.6599 - val_loss: 0.9219 - val_accuracy: 0.6556 - lr: 1.0000e-04 - 1s/epoch - 2ms/step
# Epoch 58/60
#
# Epoch 57: val_accuracy did not improve from 0.65516
# 610/610 - 1s - loss: 0.9157 - accuracy: 0.6593 - val_loss: 0.9334 - val_accuracy: 0.6405 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 58/60
#
# Epoch 57: val_accuracy did not improve from 0.66049
# 610/610 - 1s - loss: 0.8954 - accuracy: 0.6667 - val_loss: 0.9064 - val_accuracy: 0.6594 - lr: 1.0000e-05 - 1s/epoch - 2ms/step
# Epoch 58/60
#
# Epoch 57: val_accuracy did not improve from 0.68640
# 610/610 - 1s - loss: 0.8469 - accuracy: 0.6924 - val_loss: 0.8563 - val_accuracy: 0.6855 - lr: 1.0000e-04 - 1s/epoch - 2ms/step
# Epoch 58/60
#
# Epoch 58: val_accuracy did not improve from 0.68470
# 610/610 - 1s - loss: 0.8576 - accuracy: 0.6884 - val_loss: 0.8645 - val_accuracy: 0.6821 - lr: 1.0000e-05 - 973ms/epoch - 2ms/step
# Epoch 59/60
#
# Epoch 58: val_accuracy did not improve from 0.66655
# 610/610 - 1s - loss: 0.8969 - accuracy: 0.6687 - val_loss: 0.9277 - val_accuracy: 0.6457 - lr: 0.0010 - 939ms/epoch - 2ms/step
# Epoch 59/60
#
# Epoch 58: val_accuracy did not improve from 0.65526
# 610/610 - 1s - loss: 0.9064 - accuracy: 0.6608 - val_loss: 0.9199 - val_accuracy: 0.6545 - lr: 1.0000e-05 - 956ms/epoch - 2ms/step
# Epoch 59/60
#
# Epoch 58: val_accuracy did not improve from 0.65603
# 610/610 - 1s - loss: 0.9122 - accuracy: 0.6594 - val_loss: 0.9227 - val_accuracy: 0.6547 - lr: 1.0000e-04 - 931ms/epoch - 2ms/step
#
# Epoch 58: val_accuracy did not improve from 0.66506
# Epoch 59/60
# 610/610 - 1s - loss: 0.8881 - accuracy: 0.6697 - val_loss: 0.8996 - val_accuracy: 0.6644 - lr: 1.0000e-04 - 952ms/epoch - 2ms/step
# Epoch 59/60
#
# Epoch 58: val_accuracy did not improve from 0.65516
# 610/610 - 1s - loss: 0.9158 - accuracy: 0.6589 - val_loss: 0.9213 - val_accuracy: 0.6494 - lr: 0.0010 - 936ms/epoch - 2ms/step
# Epoch 59/60
#
# Epoch 58: val_accuracy did not improve from 0.66049
# 610/610 - 1s - loss: 0.8953 - accuracy: 0.6668 - val_loss: 0.9062 - val_accuracy: 0.6596 - lr: 1.0000e-05 - 945ms/epoch - 2ms/step
# Epoch 59/60
#
# Epoch 58: val_accuracy did not improve from 0.68640
# 610/610 - 1s - loss: 0.8467 - accuracy: 0.6930 - val_loss: 0.8567 - val_accuracy: 0.6850 - lr: 1.0000e-04 - 986ms/epoch - 2ms/step
# Epoch 59/60
#
# Epoch 59: val_accuracy did not improve from 0.68470
# 610/610 - 1s - loss: 0.8575 - accuracy: 0.6885 - val_loss: 0.8640 - val_accuracy: 0.6825 - lr: 1.0000e-05 - 1s/epoch - 2ms/step
# Epoch 60/60
#
# Epoch 59: val_accuracy did not improve from 0.65526
# 610/610 - 1s - loss: 0.9062 - accuracy: 0.6605 - val_loss: 0.9199 - val_accuracy: 0.6546 - lr: 1.0000e-05 - 1s/epoch - 2ms/step
#
# Epoch 59: val_accuracy did not improve from 0.66655
# Epoch 60/60
# 610/610 - 1s - loss: 0.8972 - accuracy: 0.6680 - val_loss: 0.8951 - val_accuracy: 0.6664 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 60/60
#
# Epoch 59: val_accuracy improved from 0.65603 to 0.65680, saving model to _OA_results_OCTMNIST_train_with_val/run_1FC/15/2301model.keras
# 610/610 - 1s - loss: 0.9125 - accuracy: 0.6591 - val_loss: 0.9221 - val_accuracy: 0.6568 - lr: 1.0000e-04 - 1s/epoch - 2ms/step
# Epoch 60/60
#
# Epoch 59: val_accuracy did not improve from 0.65516
# 610/610 - 1s - loss: 0.9136 - accuracy: 0.6594 - val_loss: 0.9330 - val_accuracy: 0.6440 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 60/60
#
# Epoch 59: val_accuracy did not improve from 0.66506
# 610/610 - 1s - loss: 0.8883 - accuracy: 0.6695 - val_loss: 0.8986 - val_accuracy: 0.6632 - lr: 1.0000e-04 - 1s/epoch - 2ms/step
# Epoch 60/60
#
# Epoch 59: val_accuracy did not improve from 0.66049
# 610/610 - 1s - loss: 0.8953 - accuracy: 0.6666 - val_loss: 0.9061 - val_accuracy: 0.6603 - lr: 1.0000e-05 - 1s/epoch - 2ms/step
# Epoch 60/60
#
# Epoch 59: val_accuracy did not improve from 0.68640
# 610/610 - 1s - loss: 0.8470 - accuracy: 0.6924 - val_loss: 0.8557 - val_accuracy: 0.6856 - lr: 1.0000e-04 - 1s/epoch - 2ms/step
# Epoch 60/60
#
# Epoch 60: val_accuracy did not improve from 0.68470
# 610/610 - 1s - loss: 0.8575 - accuracy: 0.6888 - val_loss: 0.8639 - val_accuracy: 0.6828 - lr: 1.0000e-05 - 1s/epoch - 2ms/step
#
# Epoch 60: val_accuracy did not improve from 0.66655
# 610/610 - 1s - loss: 0.8954 - accuracy: 0.6674 - val_loss: 0.9287 - val_accuracy: 0.6634 - lr: 0.0010 - 1s/epoch - 2ms/step
#
# Epoch 60: val_accuracy did not improve from 0.65526
# 610/610 - 1s - loss: 0.9062 - accuracy: 0.6608 - val_loss: 0.9199 - val_accuracy: 0.6547 - lr: 1.0000e-05 - 1s/epoch - 2ms/step
#
# Epoch 60: val_accuracy did not improve from 0.65680
# 610/610 - 1s - loss: 0.9121 - accuracy: 0.6606 - val_loss: 0.9236 - val_accuracy: 0.6545 - lr: 1.0000e-04 - 1s/epoch - 2ms/step
#
# Epoch 60: val_accuracy did not improve from 0.65516
# 610/610 - 1s - loss: 0.9171 - accuracy: 0.6588 - val_loss: 0.9333 - val_accuracy: 0.6492 - lr: 0.0010 - 1s/epoch - 2ms/step
#
# Epoch 60: val_accuracy did not improve from 0.66049
# 610/610 - 1s - loss: 0.8953 - accuracy: 0.6666 - val_loss: 0.9062 - val_accuracy: 0.6597 - lr: 1.0000e-05 - 1s/epoch - 2ms/step
#
# Epoch 60: val_accuracy did not improve from 0.66506
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 610/610 - 2s - loss: 0.8879 - accuracy: 0.6695 - val_loss: 0.8990 - val_accuracy: 0.6638 - lr: 1.0000e-04 - 2s/epoch - 3ms/step
#
# Epoch 60: val_accuracy did not improve from 0.68640
# 610/610 - 2s - loss: 0.8467 - accuracy: 0.6925 - val_loss: 0.8575 - val_accuracy: 0.6843 - lr: 1.0000e-04 - 2s/epoch - 4ms/step

# %%
# for ind, variant  in enumerate(permutations):

#     label = ''.join(map(str,variant))
#     print(ind, label)
#     tr_images = train_layer.open(variant)
#     te_images =  test_layer.open(variant)
#     run(tr_images,te_images,label)

# %%
# # run the network without filter
# P = ["NO-FILTER",]
# with ProcessPoolExecutor(8) as executor:
#     runner = {
#         executor.submit(run, label= p, tr_images = train_images, te_images= test_images): p for p in P
#     }
#     for future in as_completed(runner):
#         runner.pop(future)

# %%
with ProcessPoolExecutor(max_workers=None) as executor: # max_workers=None uses the number of CPU cores
    results = executor.map(run, (train_images,test_images,"_NO-FILTER"))

# %%
# run the network without filter

run(train_images, "NO-FILTER")
# Out:
# Epoch 1/60
#
# Epoch 1: val_accuracy improved from -inf to 0.60489, saving model to _OA_results_OCTMNIST_train_with_val/run_3FC/15/NO-FILTERmodel.keras
# 610/610 - 7s - loss: 1.0490 - accuracy: 0.5737 - val_loss: 1.0116 - val_accuracy: 0.6049 - lr: 0.0010 - 7s/epoch - 11ms/step
# Epoch 2/60
#
# Epoch 2: val_accuracy improved from 0.60489 to 0.67445, saving model to _OA_results_OCTMNIST_train_with_val/run_3FC/15/NO-FILTERmodel.keras
# 610/610 - 6s - loss: 0.9145 - accuracy: 0.6491 - val_loss: 0.8688 - val_accuracy: 0.6744 - lr: 0.0010 - 6s/epoch - 10ms/step
# Epoch 3/60
#
# Epoch 3: val_accuracy improved from 0.67445 to 0.68983, saving model to _OA_results_OCTMNIST_train_with_val/run_3FC/15/NO-FILTERmodel.keras
# 610/610 - 6s - loss: 0.8492 - accuracy: 0.6791 - val_loss: 0.8304 - val_accuracy: 0.6898 - lr: 0.0010 - 6s/epoch - 11ms/step
# Epoch 4/60
#
# Epoch 4: val_accuracy improved from 0.68983 to 0.70963, saving model to _OA_results_OCTMNIST_train_with_val/run_3FC/15/NO-FILTERmodel.keras
# 610/610 - 7s - loss: 0.7816 - accuracy: 0.7096 - val_loss: 0.7858 - val_accuracy: 0.7096 - lr: 0.0010 - 7s/epoch - 11ms/step
# Epoch 5/60
#
# Epoch 5: val_accuracy improved from 0.70963 to 0.73574, saving model to _OA_results_OCTMNIST_train_with_val/run_3FC/15/NO-FILTERmodel.keras
# 610/610 - 6s - loss: 0.7371 - accuracy: 0.7281 - val_loss: 0.7162 - val_accuracy: 0.7357 - lr: 0.0010 - 6s/epoch - 10ms/step
# Epoch 6/60
#
# Epoch 6: val_accuracy improved from 0.73574 to 0.74841, saving model to _OA_results_OCTMNIST_train_with_val/run_3FC/15/NO-FILTERmodel.keras
# 610/610 - 6s - loss: 0.7072 - accuracy: 0.7412 - val_loss: 0.6957 - val_accuracy: 0.7484 - lr: 0.0010 - 6s/epoch - 11ms/step
# Epoch 7/60
#
# Epoch 7: val_accuracy improved from 0.74841 to 0.75221, saving model to _OA_results_OCTMNIST_train_with_val/run_3FC/15/NO-FILTERmodel.keras
# 610/610 - 6s - loss: 0.6767 - accuracy: 0.7534 - val_loss: 0.6778 - val_accuracy: 0.7522 - lr: 0.0010 - 6s/epoch - 10ms/step
# Epoch 8/60
#
# Epoch 8: val_accuracy improved from 0.75221 to 0.75775, saving model to _OA_results_OCTMNIST_train_with_val/run_3FC/15/NO-FILTERmodel.keras
# 610/610 - 6s - loss: 0.6544 - accuracy: 0.7627 - val_loss: 0.6777 - val_accuracy: 0.7577 - lr: 0.0010 - 6s/epoch - 10ms/step
# Epoch 9/60
#
# Epoch 9: val_accuracy did not improve from 0.75775
# 610/610 - 7s - loss: 0.6416 - accuracy: 0.7674 - val_loss: 0.6841 - val_accuracy: 0.7575 - lr: 0.0010 - 7s/epoch - 11ms/step
# Epoch 10/60
#
# Epoch 10: val_accuracy improved from 0.75775 to 0.76672, saving model to _OA_results_OCTMNIST_train_with_val/run_3FC/15/NO-FILTERmodel.keras
# 610/610 - 6s - loss: 0.6273 - accuracy: 0.7734 - val_loss: 0.6462 - val_accuracy: 0.7667 - lr: 0.0010 - 6s/epoch - 9ms/step
# Epoch 11/60
#
# Epoch 11: val_accuracy improved from 0.76672 to 0.77616, saving model to _OA_results_OCTMNIST_train_with_val/run_3FC/15/NO-FILTERmodel.keras
# 610/610 - 6s - loss: 0.6077 - accuracy: 0.7811 - val_loss: 0.6317 - val_accuracy: 0.7762 - lr: 0.0010 - 6s/epoch - 9ms/step
# Epoch 12/60
#
# Epoch 12: val_accuracy improved from 0.77616 to 0.77729, saving model to _OA_results_OCTMNIST_train_with_val/run_3FC/15/NO-FILTERmodel.keras
# 610/610 - 5s - loss: 0.5980 - accuracy: 0.7842 - val_loss: 0.6175 - val_accuracy: 0.7773 - lr: 0.0010 - 5s/epoch - 9ms/step
# Epoch 13/60
#
# Epoch 13: val_accuracy did not improve from 0.77729
# 610/610 - 6s - loss: 0.5863 - accuracy: 0.7890 - val_loss: 0.6527 - val_accuracy: 0.7672 - lr: 0.0010 - 6s/epoch - 10ms/step
# Epoch 14/60
#
# Epoch 14: val_accuracy did not improve from 0.77729
# 610/610 - 7s - loss: 0.5745 - accuracy: 0.7946 - val_loss: 0.6349 - val_accuracy: 0.7724 - lr: 0.0010 - 7s/epoch - 11ms/step
# Epoch 15/60
#
# Epoch 15: val_accuracy improved from 0.77729 to 0.79032, saving model to _OA_results_OCTMNIST_train_with_val/run_3FC/15/NO-FILTERmodel.keras
# 610/610 - 6s - loss: 0.5726 - accuracy: 0.7943 - val_loss: 0.5908 - val_accuracy: 0.7903 - lr: 0.0010 - 6s/epoch - 9ms/step
# Epoch 16/60
#
# Epoch 16: val_accuracy did not improve from 0.79032
# 610/610 - 6s - loss: 0.5632 - accuracy: 0.7987 - val_loss: 0.6076 - val_accuracy: 0.7847 - lr: 0.0010 - 6s/epoch - 10ms/step
# Epoch 17/60
#
# Epoch 17: val_accuracy did not improve from 0.79032
# 610/610 - 5s - loss: 0.5492 - accuracy: 0.8034 - val_loss: 0.6460 - val_accuracy: 0.7691 - lr: 0.0010 - 5s/epoch - 8ms/step
# Epoch 18/60
#
# Epoch 18: val_accuracy improved from 0.79032 to 0.79344, saving model to _OA_results_OCTMNIST_train_with_val/run_3FC/15/NO-FILTERmodel.keras
# 610/610 - 5s - loss: 0.5438 - accuracy: 0.8054 - val_loss: 0.5876 - val_accuracy: 0.7934 - lr: 0.0010 - 5s/epoch - 9ms/step
# Epoch 19/60
#
# Epoch 19: val_accuracy did not improve from 0.79344
# 610/610 - 6s - loss: 0.5312 - accuracy: 0.8104 - val_loss: 0.6045 - val_accuracy: 0.7874 - lr: 0.0010 - 6s/epoch - 11ms/step
# Epoch 20/60
#
# Epoch 20: val_accuracy improved from 0.79344 to 0.79350, saving model to _OA_results_OCTMNIST_train_with_val/run_3FC/15/NO-FILTERmodel.keras
# 610/610 - 7s - loss: 0.5270 - accuracy: 0.8112 - val_loss: 0.5811 - val_accuracy: 0.7935 - lr: 0.0010 - 7s/epoch - 11ms/step
# Epoch 21/60
#
# Epoch 21: val_accuracy improved from 0.79350 to 0.80576, saving model to _OA_results_OCTMNIST_train_with_val/run_3FC/15/NO-FILTERmodel.keras
# 610/610 - 6s - loss: 0.5174 - accuracy: 0.8151 - val_loss: 0.5481 - val_accuracy: 0.8058 - lr: 0.0010 - 6s/epoch - 11ms/step
# Epoch 22/60
#
# Epoch 22: val_accuracy did not improve from 0.80576
# 610/610 - 6s - loss: 0.5076 - accuracy: 0.8182 - val_loss: 0.5766 - val_accuracy: 0.7966 - lr: 0.0010 - 6s/epoch - 9ms/step
# Epoch 23/60
#
# Epoch 23: val_accuracy did not improve from 0.80576
# 610/610 - 6s - loss: 0.5034 - accuracy: 0.8201 - val_loss: 0.6145 - val_accuracy: 0.7826 - lr: 0.0010 - 6s/epoch - 10ms/step
# Epoch 24/60
#
# Epoch 24: val_accuracy did not improve from 0.80576
# 610/610 - 6s - loss: 0.4942 - accuracy: 0.8228 - val_loss: 0.5775 - val_accuracy: 0.7992 - lr: 0.0010 - 6s/epoch - 10ms/step
# Epoch 25/60
#
# Epoch 25: val_accuracy did not improve from 0.80576
# 610/610 - 6s - loss: 0.4949 - accuracy: 0.8229 - val_loss: 0.6019 - val_accuracy: 0.7902 - lr: 0.0010 - 6s/epoch - 10ms/step
# Epoch 26/60
#
# Epoch 26: val_accuracy did not improve from 0.80576
# 610/610 - 6s - loss: 0.4834 - accuracy: 0.8283 - val_loss: 0.5703 - val_accuracy: 0.8035 - lr: 0.0010 - 6s/epoch - 10ms/step
# Epoch 27/60
#
# Epoch 27: val_accuracy improved from 0.80576 to 0.81294, saving model to _OA_results_OCTMNIST_train_with_val/run_3FC/15/NO-FILTERmodel.keras
# 610/610 - 6s - loss: 0.4821 - accuracy: 0.8266 - val_loss: 0.5393 - val_accuracy: 0.8129 - lr: 0.0010 - 6s/epoch - 10ms/step
# Epoch 28/60
#
# Epoch 28: val_accuracy did not improve from 0.81294
# 610/610 - 7s - loss: 0.4702 - accuracy: 0.8310 - val_loss: 0.5621 - val_accuracy: 0.8063 - lr: 0.0010 - 7s/epoch - 11ms/step
# Epoch 29/60
#
# Epoch 29: val_accuracy did not improve from 0.81294
# 610/610 - 5s - loss: 0.4665 - accuracy: 0.8331 - val_loss: 0.5437 - val_accuracy: 0.8117 - lr: 0.0010 - 5s/epoch - 9ms/step
# Epoch 30/60
#
# Epoch 30: val_accuracy improved from 0.81294 to 0.81601, saving model to _OA_results_OCTMNIST_train_with_val/run_3FC/15/NO-FILTERmodel.keras
# 610/610 - 6s - loss: 0.4575 - accuracy: 0.8365 - val_loss: 0.5401 - val_accuracy: 0.8160 - lr: 0.0010 - 6s/epoch - 11ms/step
# Epoch 31/60
#
# Epoch 31: val_accuracy improved from 0.81601 to 0.81807, saving model to _OA_results_OCTMNIST_train_with_val/run_3FC/15/NO-FILTERmodel.keras
# 610/610 - 7s - loss: 0.4550 - accuracy: 0.8370 - val_loss: 0.5288 - val_accuracy: 0.8181 - lr: 0.0010 - 7s/epoch - 11ms/step
# Epoch 32/60
#
# Epoch 32: val_accuracy did not improve from 0.81807
# 610/610 - 7s - loss: 0.4487 - accuracy: 0.8387 - val_loss: 0.5557 - val_accuracy: 0.8077 - lr: 0.0010 - 7s/epoch - 11ms/step
# Epoch 33/60
#
# Epoch 33: val_accuracy did not improve from 0.81807
# 610/610 - 6s - loss: 0.4427 - accuracy: 0.8409 - val_loss: 0.5768 - val_accuracy: 0.8035 - lr: 0.0010 - 6s/epoch - 11ms/step
# Epoch 34/60
#
# Epoch 34: val_accuracy did not improve from 0.81807
# 610/610 - 7s - loss: 0.4402 - accuracy: 0.8435 - val_loss: 0.5536 - val_accuracy: 0.8091 - lr: 0.0010 - 7s/epoch - 11ms/step
# Epoch 35/60
#
# Epoch 35: val_accuracy did not improve from 0.81807
# 610/610 - 5s - loss: 0.4316 - accuracy: 0.8447 - val_loss: 0.5624 - val_accuracy: 0.8057 - lr: 0.0010 - 5s/epoch - 9ms/step
# Epoch 36/60
#
# Epoch 36: val_accuracy did not improve from 0.81807
# 610/610 - 6s - loss: 0.4280 - accuracy: 0.8466 - val_loss: 0.5441 - val_accuracy: 0.8150 - lr: 0.0010 - 6s/epoch - 11ms/step
# Epoch 37/60
#
# Epoch 37: val_accuracy did not improve from 0.81807
# 610/610 - 7s - loss: 0.4245 - accuracy: 0.8469 - val_loss: 0.5618 - val_accuracy: 0.8128 - lr: 0.0010 - 7s/epoch - 11ms/step
# Epoch 38/60
#
# Epoch 38: val_accuracy did not improve from 0.81807
# 610/610 - 7s - loss: 0.4173 - accuracy: 0.8521 - val_loss: 0.5383 - val_accuracy: 0.8167 - lr: 0.0010 - 7s/epoch - 11ms/step
# Epoch 39/60
#
# Epoch 39: val_accuracy improved from 0.81807 to 0.82022, saving model to _OA_results_OCTMNIST_train_with_val/run_3FC/15/NO-FILTERmodel.keras
# 610/610 - 6s - loss: 0.4157 - accuracy: 0.8508 - val_loss: 0.5371 - val_accuracy: 0.8202 - lr: 0.0010 - 6s/epoch - 9ms/step
# Epoch 40/60
#
# Epoch 40: val_accuracy did not improve from 0.82022
# 610/610 - 6s - loss: 0.4101 - accuracy: 0.8535 - val_loss: 0.5538 - val_accuracy: 0.8144 - lr: 0.0010 - 6s/epoch - 9ms/step
# Epoch 41/60
#
# Epoch 41: val_accuracy did not improve from 0.82022
# 610/610 - 6s - loss: 0.4082 - accuracy: 0.8553 - val_loss: 0.5411 - val_accuracy: 0.8175 - lr: 0.0010 - 6s/epoch - 10ms/step
# Epoch 42/60
#
# Epoch 42: val_accuracy improved from 0.82022 to 0.82222, saving model to _OA_results_OCTMNIST_train_with_val/run_3FC/15/NO-FILTERmodel.keras
# 610/610 - 6s - loss: 0.4038 - accuracy: 0.8558 - val_loss: 0.5275 - val_accuracy: 0.8222 - lr: 0.0010 - 6s/epoch - 11ms/step
# Epoch 43/60
#
# Epoch 43: val_accuracy did not improve from 0.82222
# 610/610 - 7s - loss: 0.4018 - accuracy: 0.8560 - val_loss: 0.5362 - val_accuracy: 0.8201 - lr: 0.0010 - 7s/epoch - 11ms/step
# Epoch 44/60
#
# Epoch 44: val_accuracy did not improve from 0.82222
# 610/610 - 6s - loss: 0.3961 - accuracy: 0.8591 - val_loss: 0.5359 - val_accuracy: 0.8207 - lr: 0.0010 - 6s/epoch - 10ms/step
# Epoch 45/60
#
# Epoch 45: val_accuracy improved from 0.82222 to 0.82417, saving model to _OA_results_OCTMNIST_train_with_val/run_3FC/15/NO-FILTERmodel.keras
# 610/610 - 6s - loss: 0.3921 - accuracy: 0.8588 - val_loss: 0.5329 - val_accuracy: 0.8242 - lr: 0.0010 - 6s/epoch - 10ms/step
# Epoch 46/60
#
# Epoch 46: val_accuracy improved from 0.82417 to 0.82448, saving model to _OA_results_OCTMNIST_train_with_val/run_3FC/15/NO-FILTERmodel.keras
# 610/610 - 7s - loss: 0.3855 - accuracy: 0.8623 - val_loss: 0.5316 - val_accuracy: 0.8245 - lr: 0.0010 - 7s/epoch - 11ms/step
# Epoch 47/60
#
# Epoch 47: val_accuracy did not improve from 0.82448
# 610/610 - 6s - loss: 0.3850 - accuracy: 0.8620 - val_loss: 0.5352 - val_accuracy: 0.8239 - lr: 0.0010 - 6s/epoch - 10ms/step
# Epoch 48/60
#
# Epoch 48: val_accuracy did not improve from 0.82448
# 610/610 - 6s - loss: 0.3814 - accuracy: 0.8617 - val_loss: 0.5691 - val_accuracy: 0.8216 - lr: 0.0010 - 6s/epoch - 10ms/step
# Epoch 49/60
#
# Epoch 49: val_accuracy improved from 0.82448 to 0.82838, saving model to _OA_results_OCTMNIST_train_with_val/run_3FC/15/NO-FILTERmodel.keras
# 610/610 - 6s - loss: 0.3731 - accuracy: 0.8662 - val_loss: 0.5253 - val_accuracy: 0.8284 - lr: 0.0010 - 6s/epoch - 11ms/step
# Epoch 50/60
#
# Epoch 50: val_accuracy did not improve from 0.82838
# 610/610 - 6s - loss: 0.3699 - accuracy: 0.8672 - val_loss: 0.5359 - val_accuracy: 0.8222 - lr: 0.0010 - 6s/epoch - 10ms/step
# Epoch 51/60
#
# Epoch 51: val_accuracy did not improve from 0.82838
# 610/610 - 6s - loss: 0.3714 - accuracy: 0.8664 - val_loss: 0.5652 - val_accuracy: 0.8176 - lr: 0.0010 - 6s/epoch - 10ms/step
# Epoch 52/60
#
# Epoch 52: val_accuracy did not improve from 0.82838
# 610/610 - 6s - loss: 0.3722 - accuracy: 0.8679 - val_loss: 0.5552 - val_accuracy: 0.8278 - lr: 0.0010 - 6s/epoch - 10ms/step
# Epoch 53/60
#
# Epoch 53: val_accuracy improved from 0.82838 to 0.82945, saving model to _OA_results_OCTMNIST_train_with_val/run_3FC/15/NO-FILTERmodel.keras
# 610/610 - 6s - loss: 0.3647 - accuracy: 0.8693 - val_loss: 0.5350 - val_accuracy: 0.8295 - lr: 0.0010 - 6s/epoch - 11ms/step
# Epoch 54/60
#
# Epoch 54: val_accuracy did not improve from 0.82945
# 610/610 - 6s - loss: 0.3628 - accuracy: 0.8709 - val_loss: 0.5765 - val_accuracy: 0.8178 - lr: 0.0010 - 6s/epoch - 11ms/step
# Epoch 55/60
#
# Epoch 55: val_accuracy did not improve from 0.82945
# 610/610 - 6s - loss: 0.3544 - accuracy: 0.8736 - val_loss: 0.5592 - val_accuracy: 0.8278 - lr: 0.0010 - 6s/epoch - 9ms/step
# Epoch 56/60
#
# Epoch 56: val_accuracy did not improve from 0.82945
# 610/610 - 6s - loss: 0.3604 - accuracy: 0.8712 - val_loss: 0.5426 - val_accuracy: 0.8218 - lr: 0.0010 - 6s/epoch - 10ms/step
# Epoch 57/60
#
# Epoch 57: val_accuracy did not improve from 0.82945
# 610/610 - 7s - loss: 0.3512 - accuracy: 0.8736 - val_loss: 0.5594 - val_accuracy: 0.8220 - lr: 0.0010 - 7s/epoch - 11ms/step
# Epoch 58/60
#
# Epoch 58: val_accuracy did not improve from 0.82945
# 610/610 - 6s - loss: 0.3457 - accuracy: 0.8769 - val_loss: 0.5831 - val_accuracy: 0.8165 - lr: 0.0010 - 6s/epoch - 10ms/step
# Epoch 59/60
#
# Epoch 59: val_accuracy did not improve from 0.82945
# 610/610 - 6s - loss: 0.3567 - accuracy: 0.8756 - val_loss: 0.5585 - val_accuracy: 0.8239 - lr: 0.0010 - 6s/epoch - 10ms/step
# Epoch 60/60
#
# Epoch 60: val_accuracy did not improve from 0.82945
# 610/610 - 6s - loss: 0.3478 - accuracy: 0.8764 - val_loss: 0.5759 - val_accuracy: 0.8149 - lr: 0.0010 - 6s/epoch - 10ms/step

# %% [markdown]
# # Read Validation accuracy
# Now we will read from the csv and group the experiment validation for the last 30 epoch into the symmetries

# %%
# # change the subfolder name to save your data in different location based on what NN model you used
# # it's a convenient way to avoid losing your training data of each model
# # Here are some preset examples you can use
# # 1 FC layer
# run_subfolder = "_1FC"
# # run_subfolder = "_2nodes_2FC"
# # # 2 FC layer
# run_subfolder = "_2FC"
# # # 3 FC layer
# run_subfolder = "_3FC"
# # # 4 FC layer
run_subfolder = "_4FC"
# early stopping epochs -- good practice between 10-20
patience = 15
log_dir = train_layer.name + "/run" + run_subfolder +  "/"
log_dir += str(patience) +  "/"

# %%
# group the index of the permutation by the symmetry of the filter

diagonal_index = [4, 5, 8, 9, 14, 15, 18, 19]
vertical_index = [0, 1, 6, 7, 16, 17, 22, 23]
horizontal_index = [2, 3, 10, 11, 12, 13, 20, 21]

# %% [markdown]
# ### Finding the best model/worst for each symmetry

# %%
import pandas as pd

diagonal_val_accuracy = []
vertical_val_accuracy = []
horizontal_val_accuracy = []

diagonal_max_accuracy, vertical_max_accuracy, horizontal_max_accuracy = 0, 0, 0
diagonal_min_accuracy, vertical_min_accuracy, horizontal_min_accuracy = 0, 0, 0
diagonal_best_model, vertical_best_model, horizontal_best_model = "", "", ""
diagonal_worst_model, vertical_worst_model, horizontal_worst_model = "", "", ""
diagonal_max_accuracy_filepath, vertical_max_accuracy_filepath, horizontal_max_accuracy_filepath = "", "", ""
diagonal_best_model_filepath, vertical_best_model_filepath, horizontal_best_model_filepath = "", "", ""


for ind, variant  in enumerate(permutations):
    label = ''.join(map(str,variant))
    # file = train_layer.name + "/run" + run_subfolder +  "/" + label
    file = log_dir + label
    # print(file)
    #read the csv file
    df = pd.read_csv(file)
    # print(df)
    # print("Max ", df['val_accuracy'].max())
    # the number of last validation accuracy
    tail_accuracy = 30
    # our models file path extension, we'll use it to capture the filepath to our models
    model_filepath_extension = "model.keras"
    # Checking only diagonal models
    if ind in diagonal_index:
        if not diagonal_max_accuracy:
            # Assuming the max accuracy of the first model is both the max and min of the entire model with
            # respect to a given symmetry
            diagonal_max_accuracy = df['val_accuracy'].max()
            diagonal_best_model = label
            # saving the file path of the model and accuracies
            diagonal_max_accuracy_filepath = file
            diagonal_best_model_filepath = file + model_filepath_extension
            # capturing the lowest out of the highest accuracies of our models
            diagonal_min_accuracy = df['val_accuracy'].max()
            diagonal_worst_model = label
        # This block will only start from the second model 
        elif diagonal_max_accuracy < df['val_accuracy'].max():
            diagonal_max_accuracy = df['val_accuracy'].max()
            diagonal_best_model = label
            # saving the file path of the model and accuracies
            diagonal_max_accuracy_filepath = file
            diagonal_best_model_filepath = file + model_filepath_extension
        # This block will only start from the second model    
        elif diagonal_min_accuracy > df['val_accuracy'].max():
            diagonal_min_accuracy = df['val_accuracy'].max()
            diagonal_worst_model = label
    
    # Checking only vertical models    
    elif ind in vertical_index:
        if not vertical_max_accuracy:
            # Assuming the max accuracy of the first model is both the max and min of the entire model with
            # respect to a given symmetry
            vertical_max_accuracy = df['val_accuracy'].max()
            vertical_best_model = label
            # saving the file path of the model and accuracies
            vertical_max_accuracy_filepath = file
            vertical_best_model_filepath = file + model_filepath_extension
            # capturing the lowest out of the highest accuracies of our models
            vertical_min_accuracy = df['val_accuracy'].max()
            vertical_worst_model = label
        # This block will only start from the second model    
        elif vertical_max_accuracy < df['val_accuracy'].max():
            vertical_max_accuracy =  df['val_accuracy'].max()
            vertical_best_model = label
            # saving the file path of the model and accuracies
            vertical_max_accuracy_filepath = file
            vertical_best_model_filepath = file + model_filepath_extension
        # This block will only start from the second model    
        elif vertical_min_accuracy > df['val_accuracy'].max():
            vertical_min_accuracy = df['val_accuracy'].max()
            vertical_worst_model = label
            
    # Checking only horizontal models
    elif ind in horizontal_index:
        if not horizontal_max_accuracy:
            # Assuming the max accuracy of the first model is both the max and min of the entire model with
            # respect to a given symmetry
            horizontal_max_accuracy = df['val_accuracy'].max()
            horizontal_best_model = label
            # saving the file path of the model and accuracies
            horizontal_max_accuracy_filepath = file
            horizontal_best_model_filepath = file + model_filepath_extension
            # capturing the lowest out of the highest accuracies of our models
            horizontal_min_accuracy = df['val_accuracy'].max()
            horizontal_worst_model = label
        # This block will only start from the second model    
        elif horizontal_max_accuracy < df['val_accuracy'].max():
            horizontal_max_accuracy = df['val_accuracy'].max()
            horizontal_best_model = label
            # saving the file path of the model and accuracies
            horizontal_max_accuracy_filepath = file
            horizontal_best_model_filepath = file + model_filepath_extension
        # This block will only start from the second model    
        elif horizontal_min_accuracy > df['val_accuracy'].max():
            horizontal_min_accuracy = df['val_accuracy'].max()
            horizontal_worst_model = label
            
# printing the models
print(f" The best diagonal model is: {diagonal_best_model} with accuracy {diagonal_max_accuracy}" )
print(f" The best diagonal model filepath is: {diagonal_best_model_filepath}")
print(f" The best diagonal model accuracy filepath is: {diagonal_max_accuracy_filepath}")
print(f" The worst diagonal model is: {diagonal_worst_model} with accuracy {diagonal_min_accuracy}" )

print("#"*70)
print(f" The best vertical model is: {vertical_best_model} with accuracy {vertical_max_accuracy}" )
print(f" The best vertical model filepath is: {diagonal_best_model_filepath}")
print(f" The best vertical model accuracy filepath is: {vertical_max_accuracy_filepath}")
print(f" The worst vertical model is: {vertical_worst_model} with accuracy {vertical_min_accuracy}" )
print("#"*70)
print(f" The best horizontal model is: {horizontal_best_model} with accuracy {horizontal_max_accuracy}" )
print(f" The best horizontal model filepath is: {horizontal_best_model_filepath}")
print(f" The best horizontal model accuracy filepath is: {horizontal_max_accuracy_filepath}")
print(f" The worst horizontal model is: {horizontal_worst_model} with accuracy {horizontal_min_accuracy}" )
# Out:
#  The best diagonal model is: 2130 with accuracy 0.8394542336463928
#  The best diagonal model filepath is: _OA_results_OCTMNIST_train_with_val/run_4FC/15/2130model.keras
#  The best diagonal model accuracy filepath is: _OA_results_OCTMNIST_train_with_val/run_4FC/15/2130
#  The worst diagonal model is: 1230 with accuracy 0.8183730244636536
# ######################################################################
#  The best vertical model is: 2301 with accuracy 0.8376590013504028
#  The best vertical model filepath is: _OA_results_OCTMNIST_train_with_val/run_4FC/15/2130model.keras
#  The best vertical model accuracy filepath is: _OA_results_OCTMNIST_train_with_val/run_4FC/15/2301
#  The worst vertical model is: 1032 with accuracy 0.816680371761322
# ######################################################################
#  The best horizontal model is: 2013 with accuracy 0.8478662371635437
#  The best horizontal model filepath is: _OA_results_OCTMNIST_train_with_val/run_4FC/15/2013model.keras
#  The best horizontal model accuracy filepath is: _OA_results_OCTMNIST_train_with_val/run_4FC/15/2013
#  The worst horizontal model is: 0213 with accuracy 0.8321194052696228

# %%
import pandas as pd

diagonal_val_accuracy = []
vertical_val_accuracy = []
horizontal_val_accuracy = []

for ind, variant  in enumerate(permutations):
    label = ''.join(map(str,variant))
    # file = train_layer.name + "/run" + run_subfolder +  "/" + label
    file = log_dir + label

    #read the csv file
    df = pd.read_csv(file)
    
    # the number of last validation accuracy
    tail_accuracy = 15
    diagonal_max_accuracy, vertical_max_accuracy, horizontal_max_accuracy = 0, 0, 0
    if ind in diagonal_index:
        diagonal_val_accuracy.append(df['val_accuracy'].tail(tail_accuracy).tolist())
        
    elif ind in vertical_index:
        vertical_val_accuracy.append(df['val_accuracy'].tail(tail_accuracy).tolist())
    
    elif ind in horizontal_index:
        horizontal_val_accuracy.append(df['val_accuracy'].tail(tail_accuracy).tolist())

# %%
# need to flatten the list to have all the data in a single list
diagonal_val_accuracy_flattened = [item for sublist in diagonal_val_accuracy for item in sublist]
vertical_val_accuracy_flattened = [item for sublist in vertical_val_accuracy for item in sublist]
horizontal_val_accuracy_flattened = [item for sublist in horizontal_val_accuracy for item in sublist]

# %%
# file = train_layer.name + "/run" + run_subfolder +  "/" + "NO-FILTER"
file = log_dir + "NO-FILTER"


df = pd.read_csv(file)
no_fitler_val_accuracy = df['val_accuracy'].tail(tail_accuracy).tolist()

# %% [markdown]
# ### No Filter model

# %%
nofilter_model_file_path = file + model_filepath_extension

# %%
import matplotlib.pyplot as plt

# Combine the data into a list of lists
data = [diagonal_val_accuracy_flattened, vertical_val_accuracy_flattened, horizontal_val_accuracy_flattened]

# Define the labels for the box plot
labels_plot = ['Diagonal', 'Vertical', 'Horizontal']

# Create the box plot
plt.boxplot(data, labels=labels_plot)

# Calculate the mean value of the no_filter list
mean_no_filter = np.mean(no_fitler_val_accuracy)
max_no_filter = np.max(no_fitler_val_accuracy)

# Add a horizontal line at the mean value of no_filter
plt.axhline(y= mean_no_filter, color='r', linestyle='--', label=f'Mean no Filter: {mean_no_filter:.4f}')
plt.axhline(y= max_no_filter, color='g', linestyle='--', label=f'Max no Filter: {max_no_filter:.4f}')

# plt.ylim(0.936,.97)
max_val_accuracy = np.max([diagonal_val_accuracy_flattened, vertical_val_accuracy_flattened, horizontal_val_accuracy_flattened])
plt.axhline(y= max_val_accuracy, color='b', linestyle='--', label=f'Max with Filter: {max_val_accuracy:.4f}')

# Add title and labels
number_of_hidden_layers = str(int(run_subfolder[1])-1)
plt.title(f'Box Plot of Val Accuracy with {number_of_hidden_layers} Hidden Layers')
plt.xlabel('Symmetries')
plt.ylabel('Val Accuracy')
# plt.legend(ncol=2, shadow=True)
# plt.legend(shadow=True)
# plt.legend()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# Save the figure with high quality
data_name = "OCTMNIST"
figure_name = f"{log_dir}/{data_name}_{run_subfolder}_Val_Accuracy"
# plt.savefig(figure_name, dpi=300, bbox_inches='tight')
# Show the plot
plt.show()

# %% [markdown]
# ## Now let's evaluate our models

# %%
# Loading the models
diagonal_model = keras.saving.load_model(diagonal_best_model_filepath)
vertical_model = keras.saving.load_model(vertical_best_model_filepath)
horizontal_model = keras.saving.load_model(horizontal_best_model_filepath)
nofilter_model = keras.saving.load_model(nofilter_model_file_path)

# %%
# Evaluate the model on the test data using 
print("Evaluate on test data")
# Diagonal
diagonal_label = diagonal_max_accuracy_filepath[-4:]
diagonal_te_images =  test_layer.open(diagonal_label)
diagonal_results = diagonal_model.evaluate(diagonal_te_images, test_labels)
print("Diagonal test loss, test acc:", diagonal_results)
print("#"*70)
# Vertical
vertical_label = vertical_max_accuracy_filepath[-4:]
vertical_te_images =  test_layer.open(vertical_label)
vertical_results = vertical_model.evaluate(vertical_te_images, test_labels)
print("Vertical test loss, test acc:", vertical_results)
print("#"*70)
# Horizontal
horizontal_label = horizontal_max_accuracy_filepath[-4:]
horizontal_te_images =  test_layer.open(horizontal_label)
horizontal_results = horizontal_model.evaluate(horizontal_te_images, test_labels)
print("Horizontal test loss, test acc:", horizontal_results)
print("#"*70)
# No Filter
nofilter_te_images =  test_images
nofilter_te_results = nofilter_model.evaluate(nofilter_te_images, test_labels)
print("No Filter test loss, test acc:", nofilter_te_results)
print("#"*70)
# Out:
# Evaluate on test data
# 32/32 [==============================] - 1s 5ms/step - loss: 1.7634 - accuracy: 0.5960
# Diagonal test loss, test acc: [1.7633545398712158, 0.5960000157356262]
# ######################################################################
# 32/32 [==============================] - 0s 2ms/step - loss: 1.8096 - accuracy: 0.6040
# Vertical test loss, test acc: [1.8096373081207275, 0.6039999723434448]
# ######################################################################
# 14/32 [============>.................] - ETA: 0s - loss: 1.7296 - accuracy: 0.5938
# 32/32 [==============================] - 0s 4ms/step - loss: 1.5981 - accuracy: 0.6150
# Horizontal test loss, test acc: [1.5981167554855347, 0.6150000095367432]
# ######################################################################
# 32/32 [==============================] - 0s 5ms/step - loss: 1.5925 - accuracy: 0.5840
# No Filter test loss, test acc: [1.592537522315979, 0.5839999914169312]
# ######################################################################

# %%
# data to build classification reports
Models_dict = {"diagonal" : {"label":diagonal_label, "model": diagonal_model, "test_images": diagonal_te_images,  "pred": ""},
               "vertical" : {"label":vertical_label, "model": vertical_model, "test_images": vertical_te_images, "pred": ""}, 
                "horizontal" : {"label":horizontal_label, "model": horizontal_model, "test_images": horizontal_te_images, "pred": ""},
            }

# %% [markdown]
#  ## Confusion Matrix

# %%
import seaborn as sns

# Function that creates a folder
def create_folder(folder_path):
   log_dir =  os.path.join(os.getcwd(), folder_path)
   os.makedirs(log_dir, exist_ok=True) 
   return log_dir

# creating a folder inside test_data folder to save the confusion matrices and classification reports 
# with name = number of Fully Connected FC layer used.
patience = 15
test_folder_path = test_layer.name  + "/" + run_subfolder +  "/"
# create_folder(test_folder_path)
test_folder_path += str(patience) +  "/"
# test_folder_path = test_layer.name + "/" + run_subfolder
create_folder(test_folder_path)
confusion_matrices_path = test_folder_path + "confusion_matrices"
create_folder(confusion_matrices_path)
# we
class_names = np.unique(test_labels)



def create_save_confusion_matrix(symmetry, Y_pred, label, test_labels=test_labels):
   """ Function that creates & saves as csv and png confusion matrix """
   try:
      # # Convert predictions classes to one hot vectors 
      # Y_pred_classes = np.argmax(Y_pred, axis=1) 
      # compute the confusion matrix
      confusion_mtx = tf.math.confusion_matrix(labels=test_labels,
                                                predictions=Y_pred
                                             )
      confusion_mtx_df = pd.DataFrame(confusion_mtx, index=class_names, columns=class_names)
      # file name to save the confusion matrix
      cm_file_name =  f"{confusion_matrices_path}/{symmetry}_{label}_confusion_matrix.csv"
      print
      # Save to a CSV file
      confusion_mtx_df.to_csv(cm_file_name)
      print(f"Confusion matrix saved to {cm_file_name}")
      print("#"*80)
      print(f"Confusion Matrix for {symmetry.capitalize()} Model")
      plt.figure(figsize=(10, 8))
      sns.heatmap(confusion_mtx, annot=True, fmt='g')
      # Save the figure with high quality
      # cm_file_name[:-4] taking off .csv extension to avoid errors
      plt.savefig(cm_file_name[:-4], dpi=300, bbox_inches='tight')
   
   except Exception as e:
      print(f"An error occurred while creating and saving the confusion_matrix: {e}")


# 
for symmetry, value in Models_dict.items():
   # Predict the values from the testing dataset
   value["pred"] = np.argmax(value["model"].predict(value["test_images"]), axis=1) 
   create_save_confusion_matrix(symmetry, Y_pred=value["pred"], label=value["label"], test_labels=test_labels)
# Out:
# 32/32 [==============================] - 0s 4ms/step
# Confusion matrix saved to _OA_results_OCTMNIST_test_with_val/_4FC/15/confusion_matrices/diagonal_2130_confusion_matrix.csv
# ################################################################################
# Confusion Matrix for Diagonal Model
# 32/32 [==============================] - 0s 5ms/step
# Confusion matrix saved to _OA_results_OCTMNIST_test_with_val/_4FC/15/confusion_matrices/vertical_2301_confusion_matrix.csv
# ################################################################################
# Confusion Matrix for Vertical Model
# 32/32 [==============================] - 0s 3ms/step
# Confusion matrix saved to _OA_results_OCTMNIST_test_with_val/_4FC/15/confusion_matrices/horizontal_2013_confusion_matrix.csv
# ################################################################################
# Confusion Matrix for Horizontal Model

# %% [markdown]
# ## classification report

# %%
from sklearn.metrics import classification_report

# # creating a folder inside test_data folder to save the classification reports with name = number of Fully Connected FC layer used.
# test_folder_path = test_layer.name + "/" + run_subfolder
# create_folder(test_folder_path)
# creating a folder inside test_data folder to save the classification reports
folder_path = test_folder_path  + "classification_reports"
create_folder(folder_path)


def save_classification_report_image(df_report, symmetry, label, folder_path, class_names=class_names):
    """ Function to save each classification report as an image with symmetry name and configuration e.g. 0123"""
    # extension for the files
    classification_report_image_extension = "_classification_report.png"
    try:
        plt.figure(figsize=(10, len(class_names) + 2))
        sns.heatmap(df_report,
                    annot=True,
                    fmt=".2f",
                    cbar=True)
        
        plt.title(f"{symmetry.capitalize()} Classification Report Metrics -- {label}")
        # Move x-axis labels to the top
        plt.tick_params(axis='x', which='major', top=True, bottom=False, labeltop=True, labelbottom=False)
        plt.xticks(rotation=0, ha='center') # Adjust rotation as needed

        # Save classification report as image
        file_name = f"{folder_path}/{symmetry}_{label}_{classification_report_image_extension}"
        plt.tight_layout()
        plt.savefig(file_name, dpi=300, bbox_inches='tight')
        plt.show()
        print(f"Successfully classification report saved to {file_name}")
    except Exception as e:
        print(f"An error occurred while creating and saving the classification report: {e}")




def create_save_classification_report(Y_pred, symmetry, label, test_labels=test_labels, folder_path=folder_path):
   # extension for classification reports inside the above folder
   classification_report_file_extension = "_classification_report.csv"

   try:
      # building report
      report = classification_report(y_true=test_labels,
                                    y_pred=Y_pred,
                                    output_dict=True
                                    )
      df_report = pd.DataFrame(report).transpose()

      # Save the DataFrame to a CSV file
      file_name = f"{folder_path}/{symmetry}_{label}_{classification_report_file_extension}"
      df_report.to_csv(file_name)
      print(f"Classification report saved to {file_name}")
      # save classification report as image
      save_classification_report_image(df_report=df_report, symmetry=symmetry, label=label, folder_path=folder_path)
      # 
      print("#"*70)
      print("\n")

      print(f" Classification Report for {symmetry}")
      print("\n")
      print(report)
      print("#"*70)
      print("\n")
   except Exception as e:
        print(f"An error occurred while creating and saving the classification report: {e}")
         
         
         
for symmetry, value in Models_dict.items():
    create_save_classification_report(symmetry=symmetry, label=value["label"], Y_pred=value["pred"])
    
print("#"*70)
print("End!")
# Out:
# Classification report saved to _OA_results_OCTMNIST_test_with_val/_4FC/15/classification_reports/diagonal_2130__classification_report.csv
# Successfully classification report saved to _OA_results_OCTMNIST_test_with_val/_4FC/15/classification_reports/diagonal_2130__classification_report.png
# ######################################################################
#
#
#  Classification Report for diagonal
#
#
# {'0': {'precision': 0.5316455696202531, 'recall': 0.84, 'f1-score': 0.6511627906976745, 'support': 250.0}, '1': {'precision': 0.7755102040816326, 'recall': 0.608, 'f1-score': 0.6816143497757847, 'support': 250.0}, '2': {'precision': 0.6341463414634146, 'recall': 0.104, 'f1-score': 0.17869415807560138, 'support': 250.0}, '3': {'precision': 0.5652173913043478, 'recall': 0.832, 'f1-score': 0.6731391585760518, 'support': 250.0}, 'accuracy': 0.596, 'macro avg': {'precision': 0.626629876617412, 'recall': 0.596, 'f1-score': 0.546152614281278, 'support': 1000.0}, 'weighted avg': {'precision': 0.626629876617412, 'recall': 0.596, 'f1-score': 0.546152614281278, 'support': 1000.0}}
# ######################################################################
#
#
# Classification report saved to _OA_results_OCTMNIST_test_with_val/_4FC/15/classification_reports/vertical_2301__classification_report.csv
# Successfully classification report saved to _OA_results_OCTMNIST_test_with_val/_4FC/15/classification_reports/vertical_2301__classification_report.png
# ######################################################################
#
#
#  Classification Report for vertical
#
#
# {'0': {'precision': 0.5494505494505495, 'recall': 0.8, 'f1-score': 0.6514657980456026, 'support': 250.0}, '1': {'precision': 0.7857142857142857, 'recall': 0.616, 'f1-score': 0.6905829596412556, 'support': 250.0}, '2': {'precision': 0.6511627906976745, 'recall': 0.112, 'f1-score': 0.19112627986348124, 'support': 250.0}, '3': {'precision': 0.5591939546599496, 'recall': 0.888, 'f1-score': 0.6862442040185471, 'support': 250.0}, 'accuracy': 0.604, 'macro avg': {'precision': 0.6363803951306148, 'recall': 0.604, 'f1-score': 0.5548548103922216, 'support': 1000.0}, 'weighted avg': {'precision': 0.6363803951306148, 'recall': 0.604, 'f1-score': 0.5548548103922217, 'support': 1000.0}}
# ######################################################################
#
#
# Classification report saved to _OA_results_OCTMNIST_test_with_val/_4FC/15/classification_reports/horizontal_2013__classification_report.csv
# Successfully classification report saved to _OA_results_OCTMNIST_test_with_val/_4FC/15/classification_reports/horizontal_2013__classification_report.png
# ######################################################################
#
#
#  Classification Report for horizontal
#
#
# {'0': {'precision': 0.5408163265306123, 'recall': 0.848, 'f1-score': 0.660436137071651, 'support': 250.0}, '1': {'precision': 0.7801047120418848, 'recall': 0.596, 'f1-score': 0.6757369614512472, 'support': 250.0}, '2': {'precision': 0.6417910447761194, 'recall': 0.172, 'f1-score': 0.27129337539432175, 'support': 250.0}, '3': {'precision': 0.6028571428571429, 'recall': 0.844, 'f1-score': 0.7033333333333334, 'support': 250.0}, 'accuracy': 0.615, 'macro avg': {'precision': 0.6413923065514398, 'recall': 0.615, 'f1-score': 0.5776999518126384, 'support': 1000.0}, 'weighted avg': {'precision': 0.6413923065514398, 'recall': 0.615, 'f1-score': 0.5776999518126383, 'support': 1000.0}}
# ######################################################################
#
#
# ######################################################################
# End!
