# %% [markdown]
# ## Imports

# %%
# importing sys
import sys
# This is how you import modules that exist outside of working directory 
# adding mosaique to the system path
sys.path.insert(1, '/workspaces/QML-QPF/mosaiQue') 

import mosaique as mq
import scipy
from concurrent.futures import ProcessPoolExecutor, as_completed
import itertools
import numpy as np
import pennylane as qml
import os
from mosaique.models.operation import OperationLayer
from tensorflow import keras
import tensorflow as tf

# %% [markdown]
# ## Check GPU installation is working

# %%
# !pip install tensorrt
# !pip install medmnist

# %%
import tensorflow as tf 
import tensorrt as trt

print(f' tensorflow version {tf.__version__}')

print(f' tensorrt version {trt.__version__}')

print(tf.config.list_physical_devices('GPU'))

# %%
# Set the environment for asynchronous GPU usage
os.environ['TF_GPU_ALLOCATOR'] = 'cuda_malloc_async'

# %%
def operation():
    dev = qml.device("default.qubit.tf", wires=4)
    @qml.qnode(dev, interface='tf')
    def cnot(inputs):
        inputs = inputs * np.pi
        qml.AngleEmbedding(inputs[:,...], wires=range(4), rotation='Y')

        qml.CNOT(wires=[0, 1])
        qml.CNOT(wires=[2, 3])

        # Measurement producing 4 classical output values
        return [qml.expval(qml.PauliZ(j)) for j in range(4)]
    return cnot

# %%
def preset():
    # Import the images
    from medmnist import PneumoniaMNIST
    # size of the images 
    size = 64
    # we'll run the code for 64 to see if we'll get different results
    train_data = PneumoniaMNIST(split="train", download=True,size=size)
    test_data = PneumoniaMNIST(split="test", download=True,size=size)
    # name of the folder where will save the filtered images for training
    tr_layer = mq.ConvolutionLayer4x4("_OA_results_PneumoniaMNIST_train_with_val_64")
    # name of the folder where will save the filtered images for testing
    te_layer = mq.ConvolutionLayer4x4("_OA_results_PneumoniaMNIST_test_with_val_64")
    
    #load the data set want to train
    (tr_images, tr_labels), (te_images, te_labels) = (train_data.imgs, train_data.labels), (test_data.imgs, test_data.labels)
    # tr_size, tr_h, tr_w, te_size, te_h, te_w = *tr_images.shape, *te_images.shape
    # tr_images, te_images = tr_images.reshape(tr_size, tr_h, tr_w, 1), te_images.reshape(te_size, te_h, te_w, 1)
    
  
    tr_layer.fit(tr_images)
    te_layer.fit(te_images)
    # here is the problem wit transform : shape
    tr_images = tr_layer.transform(tr_images)
    te_images = te_layer.transform(te_images)
    return ((tr_layer, (tr_images, tr_labels)), (te_layer,(te_images, te_labels)))

with ProcessPoolExecutor() as executor:
    future = executor.submit(preset)

((train_layer, (train_images, train_labels)), (test_layer,(test_images, test_labels))) = future.result() #This blocks until the task completes

# %%
test_images.shape
# Out:
# (624, 1024, 4)

# %%
permutations = np.asarray(list(itertools.permutations(range(4))))

def pool(x, call, p, l):
    op = OperationLayer(call())
    predict = l.post_transform(op.pre_op.predict(x,batch_size=1000))
    l.save(predict, p)

# %%
# # not using PorcessPoolExecutor

# for p in permutations:
#     pool(train_images[:,:,p],)

# %%
train_images.shape
# Out:
# (4708, 1024, 4)

# %%
for j in range(3):
    with ProcessPoolExecutor(8) as executor:
        runner = {
            executor.submit(pool, x=train_images[:,:,p], call=operation, p=p, l=train_layer): p for p in permutations[8*j:8*(j+1)]
        }
        for future in as_completed(runner):
            runner.pop(future)
# Out:
# 5/5 [==============================] - 10s 2s/step
# 5/5 [==============================] - 11s 2s/step
# 5/5 [==============================] - 12s 2s/step
# 5/5 [==============================] - 12s 2s/step
# 5/5 [==============================] - 12s 2s/step
# 5/5 [==============================] - 12s 2s/step
# 5/5 [==============================] - 12s 2s/step
# 5/5 [==============================] - 12s 2s/step
# 5/5 [==============================] - 10s 2s/step
# 5/5 [==============================] - 10s 2s/step
# 5/5 [==============================] - 11s 2s/step
# 5/5 [==============================] - 11s 2s/step
# 5/5 [==============================] - 11s 2s/step
# 5/5 [==============================] - 11s 2s/step
# 5/5 [==============================] - 11s 2s/step
# 5/5 [==============================] - 11s 2s/step
# 5/5 [==============================] - 10s 2s/step
# 5/5 [==============================] - 10s 2s/step
# 5/5 [==============================] - 11s 2s/step
# 5/5 [==============================] - 11s 2s/step
# 5/5 [==============================] - 11s 2s/step
# 5/5 [==============================] - 12s 2s/step
# 5/5 [==============================] - 12s 2s/step
# 5/5 [==============================] - 11s 2s/step

# %%
for j in range(3):
    with ProcessPoolExecutor(8) as executor:
        runner = {
            executor.submit(pool, x=test_images[:,:,p], call=operation, p=p, l=test_layer): p for p in permutations[8*j:8*(j+1)]
        }
        for future in as_completed(runner):
            runner.pop(future)
# Out:
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step

# %%
from keras.callbacks import CSVLogger, EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# change the subfolder name to save your data in different location based on what NN model you used
# it's a convenient way to avoid losing your training data of each model
# Here are some preset examples you can use
# 1 FC layer
# run_subfolder = "_1FC"
# run_subfolder = "_2nodes_2FC"
# # 2 FC layer
# run_subfolder = "_2FC"
# # 3 FC layer
# run_subfolder = "_3FC"
# # 4 FC layer
run_subfolder = "_4FC"
# # # 10 FC layer
# run_subfolder = "_11FC"
# early stopping epochs -- good practice between 10-20
patience = 15
def run(tr_images, label):
    log_dir = train_layer.name + "/run" + run_subfolder +  "/"
    log_dir += str(patience) +  "/"
    # print(' log_dir ', log_dir)
    log_file =  log_dir + label
    # print(' log_file ', log_file)
    os.makedirs(log_dir, exist_ok=True)
    
    csv_logger = CSVLogger(log_file)
    
    
    # tensorboard_callback = keras.callbacks.TensorBoard(
    #     log_dir=log_file,
    #     histogram_freq=1,
    #     write_graph=True,
    #     write_images=True,
    #     write_steps_per_second=True,
    #     update_freq='batch',
    #     profile_batch=1,
    #     embeddings_freq=1,
    #     embeddings_metadata=None
    # )
    
    number_of_classes = len(np.unique(test_labels))
    # Chose which model you want to use depending on the number of hidden layers
    # Uncomment your model and run the code--pay attention to your folder/file naming to keep everything organized 
    ####---------------------------------------------------------------------####
    
    # # simple ANN model with 0 hidden layers: 1FC
    # q_model = keras.models.Sequential([
    #     keras.layers.Rescaling(scale=-1. / 127.5, offset=1),
    #     keras.layers.Flatten(),
    #     keras.layers.Dense(number_of_classes, activation="softmax")
    # ])
    
    ####---------------------------------------------------------------------####
    
    # # simple ANN model with 1 hidden layers: 2FC
    # q_model = keras.models.Sequential([
    #     keras.layers.Rescaling(scale=-1. / 127.5, offset=1),
    #     keras.layers.Flatten(),
    #     keras.layers.Dense(512, activation='relu'),
    #     keras.layers.Dense(number_of_classes, activation="softmax")
    # ])
    
    ####---------------------------------------------------------------------####
    
    # # simple ANN model with 2 hidden layers: 3FC
    # q_model = keras.models.Sequential([
    #     keras.layers.Rescaling(scale=-1. / 127.5, offset=1),
    #     keras.layers.Flatten(),
    #     keras.layers.Dense(512, activation='relu'),
    #     keras.layers.Dense(256, activation='relu'),
    #     keras.layers.Dense(number_of_classes, activation='softmax')
    # ])
    
    ####---------------------------------------------------------------------####
    
    # simple ANN model with 3 hidden layers: 4FC
    q_model = keras.models.Sequential([
        keras.layers.Rescaling(scale=-1. / 127.5, offset=1),
        keras.layers.Flatten(),
        keras.layers.Dense(512, activation='relu'),
        keras.layers.Dense(256, activation='relu'),
        keras.layers.Dense(128, activation='relu'),
        keras.layers.Dense(number_of_classes, activation='softmax')
    ])
    
    ####---------------------------------------------------------------------####
    
    
    # # simple ANN model with 10 hidden layers: 11FC
    # q_model = keras.models.Sequential([
    #     # Rescale pixel values from [0, 255] to [-1, 1]
    #     keras.layers.Rescaling(scale=-1. / 127.5, offset=1),
    #     # Flatten the 2D image into a 1D vector
    #     keras.layers.Flatten(),
    #     # Ten hidden Dense layers (decreasing width to help generalize on MNIST)
    #     keras.layers.Dense(512, activation='relu'),
    #     keras.layers.Dense(512, activation='relu'),
    #     keras.layers.Dense(512, activation='relu'),
    #     keras.layers.Dense(512, activation='relu'),

    #     keras.layers.Dense(256, activation='relu'),
    #     keras.layers.Dense(256, activation='relu'),

    #     keras.layers.Dense(128, activation='relu'),
    #     keras.layers.Dense(128, activation='relu'),

    #     keras.layers.Dense(64, activation='relu'),
    #     keras.layers.Dense(64, activation='relu'),

    #     # Final classification layer
    #     keras.layers.Dense(number_of_classes, activation='softmax')
    # ])
    
    ####---------------------------------------------------------------------####
    
    
    
    q_model.compile(
        optimizer='adam',
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    
    # 
    batch_size = 128
    epochs = 60
    
    
    # Stop training when a monitored metric has stopped improving.
    Early_stop = EarlyStopping(monitor="val_accuracy",
                                min_delta=0, # Minimum change in the monitored quantity to qualify as an improvement, i.e. an absolute change of less than min_delta, will count as no improvement.
                                patience=patience, # Number of epochs with no improvement after which training will be stopped.
                                verbose=1, # 1 displays messages when the callback takes an action
                                mode="max", # will stop when the quantity monitored has stopped increasing
                                baseline=None,
                                restore_best_weights=True, # to restore model weights from the epoch with the best value of the monitored quantity
                                start_from_epoch=0, #  Number of epochs to wait before starting to monitor improvement.
                            )

    
    # Callback to save the Keras model or model weights at some frequency.
    checkpoint_filepath = log_file  + 'model.keras'
    model_checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath,
                                                monitor='val_accuracy',
                                                mode='max',
                                                verbose=1,
                                                save_best_only=True
                                                )
    # Reduce learning rate when a metric has stopped improving.
    reduce_lr_acc = ReduceLROnPlateau(monitor='val_accuracy',
                                        factor=0.1, # Float. Factor by which the learning rate will be reduced. new_lr = lr * factor.
                                        patience=10, # Integer. Number of epochs with no improvement after which learning rate will be reduced.
                                        verbose=1, # 1: update messages.
                                        mode="max", # 'max' mode it will be reduced when the quantity monitored has stopped increasing
                                        min_delta=0.0001, # Float. Threshold for measuring the new optimum, to only focus on significant changes.
                                        cooldown=0, #  Integer. Number of epochs to wait before resuming normal operation after the learning rate has been reduced.
                                        min_lr=0.0 #  Float. Lower bound on the learning rate.
                                    )


    
    q_history = q_model.fit(
        tr_images,
        train_labels,
        # validation_data=(te_images, test_labels),
        validation_split=0.2,
        batch_size=batch_size,
        epochs=epochs,
        verbose=2,
        # callbacks=[tensorboard_callback]
        callbacks = [Early_stop,csv_logger,model_checkpoint_callback, reduce_lr_acc]
    )

def model(variant, tr_layer):
    tr_images = tr_layer.open(variant)
    # te_images =  te_layer.open(variant)

    label = ''.join(map(str,variant))

    run(tr_images, label)

# %%
from matplotlib import pyplot as plt

# print(test_layer.open([1,2,3,0]).shape)

post = train_layer.open([1,2,3,0])
post1 = train_layer.open([2,3,0,1])


_min, _max = np.amin(post), np.amax(post)
_min1, _max1 = np.amin(post1), np.amax(post1)
fig, axes = plt.subplots(2, 4, figsize=(16, 4))

# Plot all output channels for quantum cnot
for c in range(4):
    axes[0,c].imshow(post[0,:,:,c],vmin = _min, vmax = _max)
    axes[1,c].imshow(post1[0,:,:,c],vmin = _min1, vmax = _max1)

# %%
post = train_layer.open([1,2,3,0])
post.shape
# Out:
# (4708, 32, 32, 4)

# %%
for j in range(3):
    with ProcessPoolExecutor(8) as executor:
        runner = {
            executor.submit(model,variant = p, tr_layer = train_layer): p for p in permutations[8*j:8*(j+1)]
        }
        for future in as_completed(runner):
            runner.pop(future)
# Out:
# Epoch 1/60
# Epoch 1/60
# Epoch 1/60
# Epoch 1/60
# Epoch 1/60
# Epoch 1/60
# Epoch 1/60
# Epoch 1/60
#
# Epoch 1: val_accuracy improved from -inf to 0.94374, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0123model.keras
#
# Epoch 1: val_accuracy improved from -inf to 0.94480, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0213model.keras
#
# Epoch 1: val_accuracy improved from -inf to 0.94692, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0132model.keras
#
# Epoch 1: val_accuracy improved from -inf to 0.93737, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0312model.keras
#
# Epoch 1: val_accuracy improved from -inf to 0.93737, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0321model.keras
#
# Epoch 1: val_accuracy improved from -inf to 0.94692, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/1032model.keras
#
# Epoch 1: val_accuracy improved from -inf to 0.95223, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/1023model.keras
#
# Epoch 1: val_accuracy improved from -inf to 0.95011, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0231model.keras
# 30/30 - 2s - loss: 0.4400 - accuracy: 0.8441 - val_loss: 0.1528 - val_accuracy: 0.9437 - lr: 0.0010 - 2s/epoch - 70ms/step
# Epoch 2/60
# 30/30 - 2s - loss: 0.3737 - accuracy: 0.8728 - val_loss: 0.1686 - val_accuracy: 0.9374 - lr: 0.0010 - 2s/epoch - 70ms/step
# Epoch 2/60
# 30/30 - 2s - loss: 0.3810 - accuracy: 0.8779 - val_loss: 0.1578 - val_accuracy: 0.9448 - lr: 0.0010 - 2s/epoch - 72ms/step
# 30/30 - 2s - loss: 0.4001 - accuracy: 0.8670 - val_loss: 0.1821 - val_accuracy: 0.9374 - lr: 0.0010 - 2s/epoch - 69ms/step
# 30/30 - 2s - loss: 0.2747 - accuracy: 0.8930 - val_loss: 0.1243 - val_accuracy: 0.9522 - lr: 0.0010 - 2s/epoch - 71ms/step
# Epoch 2/60
# 30/30 - 2s - loss: 0.3377 - accuracy: 0.8861 - val_loss: 0.1391 - val_accuracy: 0.9501 - lr: 0.0010 - 2s/epoch - 71ms/step
# Epoch 2/60
# Epoch 2/60
# 30/30 - 2s - loss: 0.4058 - accuracy: 0.8672 - val_loss: 0.1575 - val_accuracy: 0.9469 - lr: 0.0010 - 2s/epoch - 71ms/step
# Epoch 2/60
# Epoch 2/60
# 30/30 - 2s - loss: 0.3777 - accuracy: 0.8688 - val_loss: 0.1378 - val_accuracy: 0.9469 - lr: 0.0010 - 2s/epoch - 72ms/step
# Epoch 2/60
#
# Epoch 2: val_accuracy did not improve from 0.94692
# 30/30 - 1s - loss: 0.1404 - accuracy: 0.9488 - val_loss: 0.1605 - val_accuracy: 0.9331 - lr: 0.0010 - 767ms/epoch - 26ms/step
# Epoch 3/60
#
# Epoch 2: val_accuracy improved from 0.94374 to 0.94692, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0123model.keras
#
# Epoch 2: val_accuracy improved from 0.95011 to 0.95541, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0231model.keras
#
# Epoch 2: val_accuracy improved from 0.93737 to 0.95648, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0321model.keras
#
# Epoch 2: val_accuracy improved from 0.93737 to 0.95860, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0312model.keras
#
# Epoch 2: val_accuracy improved from 0.95223 to 0.96178, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/1023model.keras
#
# Epoch 2: val_accuracy improved from 0.94692 to 0.95754, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0132model.keras
#
# Epoch 2: val_accuracy improved from 0.94480 to 0.95966, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0213model.keras
# 30/30 - 1s - loss: 0.1404 - accuracy: 0.9445 - val_loss: 0.1186 - val_accuracy: 0.9565 - lr: 0.0010 - 995ms/epoch - 33ms/step
# 30/30 - 1s - loss: 0.1152 - accuracy: 0.9543 - val_loss: 0.1059 - val_accuracy: 0.9618 - lr: 0.0010 - 995ms/epoch - 33ms/step
# Epoch 3/60
# Epoch 3/60
# 30/30 - 1s - loss: 0.1353 - accuracy: 0.9469 - val_loss: 0.1389 - val_accuracy: 0.9469 - lr: 0.0010 - 1s/epoch - 34ms/step
# Epoch 3/60
# 30/30 - 1s - loss: 0.1336 - accuracy: 0.9488 - val_loss: 0.1156 - val_accuracy: 0.9554 - lr: 0.0010 - 1s/epoch - 34ms/step
# Epoch 3/60
# 30/30 - 1s - loss: 0.1301 - accuracy: 0.9464 - val_loss: 0.1130 - val_accuracy: 0.9586 - lr: 0.0010 - 1s/epoch - 35ms/step
# Epoch 3/60
# 30/30 - 1s - loss: 0.1260 - accuracy: 0.9511 - val_loss: 0.1127 - val_accuracy: 0.9575 - lr: 0.0010 - 1s/epoch - 34ms/step
# Epoch 3/60
# 30/30 - 1s - loss: 0.1355 - accuracy: 0.9461 - val_loss: 0.1134 - val_accuracy: 0.9597 - lr: 0.0010 - 1s/epoch - 36ms/step
# Epoch 3/60
#
# Epoch 3: val_accuracy improved from 0.94692 to 0.95541, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/1032model.keras
# 30/30 - 1s - loss: 0.1305 - accuracy: 0.9495 - val_loss: 0.1199 - val_accuracy: 0.9554 - lr: 0.0010 - 690ms/epoch - 23ms/step
# Epoch 4/60
#
# Epoch 3: val_accuracy improved from 0.94692 to 0.95860, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0123model.keras
#
# Epoch 3: val_accuracy improved from 0.96178 to 0.96391, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/1023model.keras
#
# Epoch 3: val_accuracy improved from 0.95541 to 0.96178, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0231model.keras
#
# Epoch 3: val_accuracy did not improve from 0.95860
# 30/30 - 1s - loss: 0.1057 - accuracy: 0.9607 - val_loss: 0.1210 - val_accuracy: 0.9575 - lr: 0.0010 - 784ms/epoch - 26ms/step
#
# Epoch 3: val_accuracy improved from 0.95648 to 0.95966, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0321model.keras
# Epoch 4/60
#
# Epoch 3: val_accuracy improved from 0.95966 to 0.96285, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0213model.keras
#
# Epoch 3: val_accuracy improved from 0.95754 to 0.96285, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0132model.keras
#
# Epoch 4: val_accuracy improved from 0.95541 to 0.96391, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/1032model.keras
# 30/30 - 1s - loss: 0.1105 - accuracy: 0.9559 - val_loss: 0.1096 - val_accuracy: 0.9586 - lr: 0.0010 - 979ms/epoch - 33ms/step
# Epoch 4/60
# 30/30 - 1s - loss: 0.1064 - accuracy: 0.9599 - val_loss: 0.1109 - val_accuracy: 0.9628 - lr: 0.0010 - 936ms/epoch - 31ms/step
# Epoch 4/60
# 30/30 - 1s - loss: 0.1057 - accuracy: 0.9591 - val_loss: 0.1125 - val_accuracy: 0.9597 - lr: 0.0010 - 1s/epoch - 34ms/step
# Epoch 4/60
# 30/30 - 1s - loss: 0.1162 - accuracy: 0.9541 - val_loss: 0.1108 - val_accuracy: 0.9628 - lr: 0.0010 - 1s/epoch - 34ms/step
# 30/30 - 1s - loss: 0.0950 - accuracy: 0.9636 - val_loss: 0.1145 - val_accuracy: 0.9639 - lr: 0.0010 - 1s/epoch - 36ms/step
# 30/30 - 1s - loss: 0.1012 - accuracy: 0.9618 - val_loss: 0.1126 - val_accuracy: 0.9618 - lr: 0.0010 - 1s/epoch - 36ms/step
# Epoch 4/60
# Epoch 4/60
# Epoch 4/60
# 30/30 - 1s - loss: 0.0967 - accuracy: 0.9636 - val_loss: 0.1011 - val_accuracy: 0.9639 - lr: 0.0010 - 674ms/epoch - 22ms/step
# Epoch 5/60
#
# Epoch 4: val_accuracy improved from 0.95860 to 0.96285, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0312model.keras
# 30/30 - 1s - loss: 0.0919 - accuracy: 0.9673 - val_loss: 0.1140 - val_accuracy: 0.9628 - lr: 0.0010 - 713ms/epoch - 24ms/step
# Epoch 5/60
#
# Epoch 4: val_accuracy improved from 0.95860 to 0.96072, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0123model.keras
#
# Epoch 4: val_accuracy did not improve from 0.96285
# 30/30 - 1s - loss: 0.0920 - accuracy: 0.9639 - val_loss: 0.1136 - val_accuracy: 0.9597 - lr: 0.0010 - 771ms/epoch - 26ms/step
#
# Epoch 4: val_accuracy did not improve from 0.95966
# Epoch 5/60
# 30/30 - 1s - loss: 0.0952 - accuracy: 0.9610 - val_loss: 0.1241 - val_accuracy: 0.9575 - lr: 0.0010 - 784ms/epoch - 26ms/step
# Epoch 5/60
#
# Epoch 4: val_accuracy did not improve from 0.96391
# 30/30 - 1s - loss: 0.0757 - accuracy: 0.9724 - val_loss: 0.1454 - val_accuracy: 0.9544 - lr: 0.0010 - 741ms/epoch - 25ms/step
#
# Epoch 4: val_accuracy improved from 0.96285 to 0.96391, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0132model.keras
# Epoch 5/60
#
# Epoch 4: val_accuracy improved from 0.96178 to 0.96603, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0231model.keras
#
# Epoch 5: val_accuracy improved from 0.96391 to 0.96603, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/1032model.keras
# 30/30 - 1s - loss: 0.1166 - accuracy: 0.9525 - val_loss: 0.1067 - val_accuracy: 0.9607 - lr: 0.0010 - 907ms/epoch - 30ms/step
# Epoch 5/60
# 30/30 - 1s - loss: 0.0806 - accuracy: 0.9719 - val_loss: 0.0987 - val_accuracy: 0.9660 - lr: 0.0010 - 939ms/epoch - 31ms/step
# Epoch 5/60
# 30/30 - 1s - loss: 0.0931 - accuracy: 0.9673 - val_loss: 0.0980 - val_accuracy: 0.9639 - lr: 0.0010 - 965ms/epoch - 32ms/step
# Epoch 5/60
# 30/30 - 1s - loss: 0.0772 - accuracy: 0.9711 - val_loss: 0.0964 - val_accuracy: 0.9660 - lr: 0.0010 - 925ms/epoch - 31ms/step
# Epoch 6/60
#
# Epoch 5: val_accuracy did not improve from 0.96285
# 30/30 - 1s - loss: 0.0878 - accuracy: 0.9647 - val_loss: 0.1065 - val_accuracy: 0.9618 - lr: 0.0010 - 697ms/epoch - 23ms/step
# Epoch 6/60
#
# Epoch 5: val_accuracy improved from 0.96285 to 0.96391, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0213model.keras
#
# Epoch 5: val_accuracy improved from 0.96391 to 0.96815, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/1023model.keras
#
# Epoch 5: val_accuracy improved from 0.95966 to 0.96391, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0321model.keras
#
# Epoch 5: val_accuracy improved from 0.96072 to 0.96178, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0123model.keras
# 30/30 - 1s - loss: 0.0817 - accuracy: 0.9671 - val_loss: 0.0997 - val_accuracy: 0.9639 - lr: 0.0010 - 883ms/epoch - 29ms/step
# Epoch 6/60
#
# Epoch 5: val_accuracy did not improve from 0.96603
# 30/30 - 1s - loss: 0.0672 - accuracy: 0.9740 - val_loss: 0.1090 - val_accuracy: 0.9650 - lr: 0.0010 - 673ms/epoch - 22ms/step
# Epoch 6/60
#
# Epoch 6: val_accuracy did not improve from 0.96603
# 30/30 - 1s - loss: 0.0654 - accuracy: 0.9740 - val_loss: 0.0991 - val_accuracy: 0.9639 - lr: 0.0010 - 643ms/epoch - 21ms/step
# Epoch 7/60
#
# Epoch 5: val_accuracy did not improve from 0.96391
# 30/30 - 1s - loss: 0.0822 - accuracy: 0.9689 - val_loss: 0.1050 - val_accuracy: 0.9628 - lr: 0.0010 - 685ms/epoch - 23ms/step
# Epoch 6/60
# 30/30 - 1s - loss: 0.0808 - accuracy: 0.9695 - val_loss: 0.1126 - val_accuracy: 0.9682 - lr: 0.0010 - 920ms/epoch - 31ms/step
# Epoch 6/60
# 30/30 - 1s - loss: 0.0878 - accuracy: 0.9655 - val_loss: 0.1029 - val_accuracy: 0.9639 - lr: 0.0010 - 949ms/epoch - 32ms/step
# Epoch 6/60
# 30/30 - 1s - loss: 0.1010 - accuracy: 0.9631 - val_loss: 0.1111 - val_accuracy: 0.9618 - lr: 0.0010 - 891ms/epoch - 30ms/step
# Epoch 6/60
#
# Epoch 6: val_accuracy improved from 0.96285 to 0.96815, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0312model.keras
# 30/30 - 1s - loss: 0.0642 - accuracy: 0.9748 - val_loss: 0.1105 - val_accuracy: 0.9682 - lr: 0.0010 - 861ms/epoch - 29ms/step
# Epoch 7/60
#
# Epoch 6: val_accuracy did not improve from 0.96391
# 30/30 - 1s - loss: 0.0693 - accuracy: 0.9724 - val_loss: 0.1144 - val_accuracy: 0.9618 - lr: 0.0010 - 798ms/epoch - 27ms/step
# Epoch 7/60
#
# Epoch 6: val_accuracy did not improve from 0.96603
# 30/30 - 1s - loss: 0.0647 - accuracy: 0.9756 - val_loss: 0.0984 - val_accuracy: 0.9660 - lr: 0.0010 - 783ms/epoch - 26ms/step
# Epoch 7/60
#
# Epoch 7: val_accuracy did not improve from 0.96603
# 30/30 - 1s - loss: 0.0534 - accuracy: 0.9804 - val_loss: 0.1027 - val_accuracy: 0.9660 - lr: 0.0010 - 808ms/epoch - 27ms/step
#
# Epoch 6: val_accuracy did not improve from 0.96391
# Epoch 8/60
#
# Epoch 6: val_accuracy improved from 0.96178 to 0.96709, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0123model.keras
# 30/30 - 1s - loss: 0.0632 - accuracy: 0.9782 - val_loss: 0.1185 - val_accuracy: 0.9565 - lr: 0.0010 - 781ms/epoch - 26ms/step
# Epoch 7/60
#
# Epoch 6: val_accuracy improved from 0.96391 to 0.97028, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0132model.keras
#
# Epoch 6: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 0.0657 - accuracy: 0.9734 - val_loss: 0.1283 - val_accuracy: 0.9586 - lr: 0.0010 - 797ms/epoch - 27ms/step
# Epoch 7/60
# 30/30 - 1s - loss: 0.0785 - accuracy: 0.9711 - val_loss: 0.0966 - val_accuracy: 0.9671 - lr: 0.0010 - 924ms/epoch - 31ms/step
# Epoch 7/60
# 30/30 - 1s - loss: 0.0735 - accuracy: 0.9742 - val_loss: 0.1010 - val_accuracy: 0.9703 - lr: 0.0010 - 1s/epoch - 33ms/step
# Epoch 7/60
#
# Epoch 7: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 0.0526 - accuracy: 0.9801 - val_loss: 0.1058 - val_accuracy: 0.9671 - lr: 0.0010 - 728ms/epoch - 24ms/step
# Epoch 8/60
#
# Epoch 7: val_accuracy improved from 0.96391 to 0.96815, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0213model.keras
#
# Epoch 7: val_accuracy did not improve from 0.96603
# 30/30 - 1s - loss: 0.0541 - accuracy: 0.9796 - val_loss: 0.1099 - val_accuracy: 0.9660 - lr: 0.0010 - 823ms/epoch - 27ms/step
# Epoch 8/60
#
# Epoch 8: val_accuracy improved from 0.96603 to 0.96709, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/1032model.keras
#
# Epoch 7: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 0.0519 - accuracy: 0.9830 - val_loss: 0.1214 - val_accuracy: 0.9565 - lr: 0.0010 - 800ms/epoch - 27ms/step
# Epoch 8/60
#
# Epoch 7: val_accuracy improved from 0.96391 to 0.96815, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0321model.keras
#
# Epoch 7: val_accuracy did not improve from 0.96709
# 30/30 - 1s - loss: 0.0636 - accuracy: 0.9766 - val_loss: 0.1244 - val_accuracy: 0.9650 - lr: 0.0010 - 753ms/epoch - 25ms/step
# Epoch 8/60
# 30/30 - 1s - loss: 0.0564 - accuracy: 0.9774 - val_loss: 0.0963 - val_accuracy: 0.9682 - lr: 0.0010 - 1s/epoch - 34ms/step
# Epoch 8/60
# 30/30 - 1s - loss: 0.0574 - accuracy: 0.9764 - val_loss: 0.1031 - val_accuracy: 0.9671 - lr: 0.0010 - 1s/epoch - 34ms/step
# Epoch 9/60
#
# Epoch 8: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 0.0393 - accuracy: 0.9857 - val_loss: 0.1516 - val_accuracy: 0.9554 - lr: 0.0010 - 729ms/epoch - 24ms/step
# Epoch 9/60
# 30/30 - 1s - loss: 0.0544 - accuracy: 0.9788 - val_loss: 0.1111 - val_accuracy: 0.9682 - lr: 0.0010 - 1s/epoch - 34ms/step
# Epoch 8/60
#
# Epoch 7: val_accuracy did not improve from 0.97028
# 30/30 - 1s - loss: 0.0691 - accuracy: 0.9745 - val_loss: 0.1134 - val_accuracy: 0.9692 - lr: 0.0010 - 866ms/epoch - 29ms/step
# Epoch 8/60
#
# Epoch 8: val_accuracy did not improve from 0.96603
# 30/30 - 1s - loss: 0.0351 - accuracy: 0.9870 - val_loss: 0.1506 - val_accuracy: 0.9565 - lr: 0.0010 - 701ms/epoch - 23ms/step
# Epoch 9/60
#
# Epoch 8: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 0.0606 - accuracy: 0.9753 - val_loss: 0.1162 - val_accuracy: 0.9660 - lr: 0.0010 - 789ms/epoch - 26ms/step
# Epoch 9/60
#
# Epoch 8: val_accuracy did not improve from 0.96709
# 30/30 - 1s - loss: 0.0602 - accuracy: 0.9774 - val_loss: 0.1064 - val_accuracy: 0.9618 - lr: 0.0010 - 799ms/epoch - 27ms/step
# Epoch 9/60
#
# Epoch 8: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 0.0601 - accuracy: 0.9764 - val_loss: 0.1196 - val_accuracy: 0.9639 - lr: 0.0010 - 805ms/epoch - 27ms/step
# Epoch 9/60
#
# Epoch 8: val_accuracy did not improve from 0.96815
#
# Epoch 9: val_accuracy did not improve from 0.96709
# 30/30 - 1s - loss: 0.0524 - accuracy: 0.9790 - val_loss: 0.1040 - val_accuracy: 0.9639 - lr: 0.0010 - 823ms/epoch - 27ms/step
# Epoch 10/60
# 30/30 - 1s - loss: 0.0512 - accuracy: 0.9804 - val_loss: 0.1294 - val_accuracy: 0.9682 - lr: 0.0010 - 804ms/epoch - 27ms/step
# Epoch 9/60
#
# Epoch 9: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 0.0522 - accuracy: 0.9790 - val_loss: 0.1152 - val_accuracy: 0.9682 - lr: 0.0010 - 851ms/epoch - 28ms/step
# Epoch 10/60
#
# Epoch 8: val_accuracy did not improve from 0.97028
# 30/30 - 1s - loss: 0.0708 - accuracy: 0.9695 - val_loss: 0.1036 - val_accuracy: 0.9650 - lr: 0.0010 - 881ms/epoch - 29ms/step
# Epoch 9/60
#
# Epoch 9: val_accuracy did not improve from 0.96603
# 30/30 - 1s - loss: 0.0439 - accuracy: 0.9798 - val_loss: 0.1054 - val_accuracy: 0.9639 - lr: 0.0010 - 795ms/epoch - 26ms/step
# Epoch 10/60
#
# Epoch 9: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 0.0403 - accuracy: 0.9849 - val_loss: 0.1343 - val_accuracy: 0.9618 - lr: 0.0010 - 767ms/epoch - 26ms/step
# Epoch 10/60
#
# Epoch 9: val_accuracy improved from 0.96815 to 0.97028, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0213model.keras
#
# Epoch 10: val_accuracy did not improve from 0.96709
# 30/30 - 1s - loss: 0.0351 - accuracy: 0.9867 - val_loss: 0.1257 - val_accuracy: 0.9650 - lr: 0.0010 - 770ms/epoch - 26ms/step
# Epoch 11/60
#
# Epoch 9: val_accuracy improved from 0.96709 to 0.96815, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0123model.keras
#
# Epoch 10: val_accuracy improved from 0.96815 to 0.96921, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0312model.keras
#
# Epoch 9: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 0.0437 - accuracy: 0.9827 - val_loss: 0.1156 - val_accuracy: 0.9660 - lr: 0.0010 - 785ms/epoch - 26ms/step
# Epoch 10/60
#
# Epoch 9: val_accuracy did not improve from 0.97028
# 30/30 - 1s - loss: 0.0451 - accuracy: 0.9835 - val_loss: 0.1001 - val_accuracy: 0.9682 - lr: 0.0010 - 729ms/epoch - 24ms/step
# Epoch 10/60
# 30/30 - 1s - loss: 0.0502 - accuracy: 0.9785 - val_loss: 0.0985 - val_accuracy: 0.9703 - lr: 0.0010 - 996ms/epoch - 33ms/step
# Epoch 10/60
# 30/30 - 1s - loss: 0.0531 - accuracy: 0.9796 - val_loss: 0.1196 - val_accuracy: 0.9682 - lr: 0.0010 - 1s/epoch - 36ms/step
# Epoch 10/60
# 30/30 - 1s - loss: 0.0330 - accuracy: 0.9870 - val_loss: 0.1128 - val_accuracy: 0.9692 - lr: 0.0010 - 950ms/epoch - 32ms/step
# Epoch 11/60
#
# Epoch 10: val_accuracy improved from 0.96603 to 0.96709, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0231model.keras
#
# Epoch 10: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 0.0300 - accuracy: 0.9894 - val_loss: 0.1352 - val_accuracy: 0.9586 - lr: 0.0010 - 763ms/epoch - 25ms/step
# Epoch 11/60
# 30/30 - 1s - loss: 0.0239 - accuracy: 0.9920 - val_loss: 0.1125 - val_accuracy: 0.9671 - lr: 0.0010 - 941ms/epoch - 31ms/step
# Epoch 11/60
#
# Epoch 10: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 0.0346 - accuracy: 0.9878 - val_loss: 0.1302 - val_accuracy: 0.9682 - lr: 0.0010 - 740ms/epoch - 25ms/step
# Epoch 11/60
#
# Epoch 11: val_accuracy improved from 0.96709 to 0.96815, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/1032model.keras
#
# Epoch 10: val_accuracy did not improve from 0.97028
# 30/30 - 1s - loss: 0.0371 - accuracy: 0.9873 - val_loss: 0.1258 - val_accuracy: 0.9628 - lr: 0.0010 - 718ms/epoch - 24ms/step
# Epoch 11/60
#
# Epoch 10: val_accuracy did not improve from 0.97028
# 30/30 - 1s - loss: 0.0620 - accuracy: 0.9761 - val_loss: 0.1118 - val_accuracy: 0.9618 - lr: 0.0010 - 717ms/epoch - 24ms/step
# Epoch 11/60
#
# Epoch 10: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 0.0415 - accuracy: 0.9835 - val_loss: 0.1151 - val_accuracy: 0.9628 - lr: 0.0010 - 719ms/epoch - 24ms/step
# Epoch 11/60
# 30/30 - 1s - loss: 0.0285 - accuracy: 0.9902 - val_loss: 0.1230 - val_accuracy: 0.9682 - lr: 0.0010 - 962ms/epoch - 32ms/step
# Epoch 12/60
#
# Epoch 11: val_accuracy did not improve from 0.96921
# 30/30 - 1s - loss: 0.0261 - accuracy: 0.9902 - val_loss: 0.1387 - val_accuracy: 0.9660 - lr: 0.0010 - 786ms/epoch - 26ms/step
# Epoch 12/60
#
# Epoch 11: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 0.0325 - accuracy: 0.9888 - val_loss: 0.1608 - val_accuracy: 0.9554 - lr: 0.0010 - 815ms/epoch - 27ms/step
# Epoch 12/60
#
# Epoch 11: val_accuracy did not improve from 0.96709
# 30/30 - 1s - loss: 0.0235 - accuracy: 0.9912 - val_loss: 0.1264 - val_accuracy: 0.9618 - lr: 0.0010 - 777ms/epoch - 26ms/step
# Epoch 12/60
#
# Epoch 11: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 0.0313 - accuracy: 0.9875 - val_loss: 0.1830 - val_accuracy: 0.9554 - lr: 0.0010 - 799ms/epoch - 27ms/step
# Epoch 12/60
#
# Epoch 11: val_accuracy did not improve from 0.97028
# 30/30 - 1s - loss: 0.0489 - accuracy: 0.9817 - val_loss: 0.1219 - val_accuracy: 0.9650 - lr: 0.0010 - 809ms/epoch - 27ms/step
# Epoch 12/60
#
# Epoch 11: val_accuracy did not improve from 0.97028
# 30/30 - 1s - loss: 0.0318 - accuracy: 0.9894 - val_loss: 0.1193 - val_accuracy: 0.9692 - lr: 0.0010 - 797ms/epoch - 27ms/step
# Epoch 12/60
#
# Epoch 11: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 0.0321 - accuracy: 0.9870 - val_loss: 0.1300 - val_accuracy: 0.9639 - lr: 0.0010 - 788ms/epoch - 26ms/step
# Epoch 12/60
#
# Epoch 12: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 0.0218 - accuracy: 0.9912 - val_loss: 0.1938 - val_accuracy: 0.9490 - lr: 0.0010 - 800ms/epoch - 27ms/step
# Epoch 13/60
#
# Epoch 12: val_accuracy did not improve from 0.96921
# 30/30 - 1s - loss: 0.0321 - accuracy: 0.9878 - val_loss: 0.2240 - val_accuracy: 0.9544 - lr: 0.0010 - 787ms/epoch - 26ms/step
# Epoch 13/60
#
# Epoch 12: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 0.0210 - accuracy: 0.9926 - val_loss: 0.1347 - val_accuracy: 0.9671 - lr: 0.0010 - 780ms/epoch - 26ms/step
# Epoch 13/60
#
# Epoch 12: val_accuracy improved from 0.96709 to 0.96921, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0231model.keras
#
# Epoch 12: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 0.0364 - accuracy: 0.9865 - val_loss: 0.1631 - val_accuracy: 0.9533 - lr: 0.0010 - 827ms/epoch - 28ms/step
# Epoch 13/60
#
# Epoch 12: val_accuracy did not improve from 0.97028
# 30/30 - 1s - loss: 0.0277 - accuracy: 0.9907 - val_loss: 0.1057 - val_accuracy: 0.9618 - lr: 0.0010 - 823ms/epoch - 27ms/step
# Epoch 13/60
#
# Epoch 12: val_accuracy did not improve from 0.97028
# 30/30 - 1s - loss: 0.0220 - accuracy: 0.9920 - val_loss: 0.1462 - val_accuracy: 0.9618 - lr: 0.0010 - 802ms/epoch - 27ms/step
# 30/30 - 1s - loss: 0.0178 - accuracy: 0.9944 - val_loss: 0.1373 - val_accuracy: 0.9692 - lr: 0.0010 - 1s/epoch - 36ms/step
#
# Epoch 13: val_accuracy did not improve from 0.96815
# Epoch 13/60
# Epoch 13/60
# 30/30 - 1s - loss: 0.0348 - accuracy: 0.9841 - val_loss: 0.1714 - val_accuracy: 0.9554 - lr: 0.0010 - 723ms/epoch - 24ms/step
#
# Epoch 12: val_accuracy did not improve from 0.96815
# Epoch 14/60
# 30/30 - 1s - loss: 0.0307 - accuracy: 0.9888 - val_loss: 0.1292 - val_accuracy: 0.9671 - lr: 0.0010 - 801ms/epoch - 27ms/step
# Epoch 13/60
#
# Epoch 13: val_accuracy did not improve from 0.96921
# 30/30 - 1s - loss: 0.0400 - accuracy: 0.9862 - val_loss: 0.1766 - val_accuracy: 0.9628 - lr: 0.0010 - 831ms/epoch - 28ms/step
# Epoch 14/60
#
# Epoch 13: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 0.0133 - accuracy: 0.9960 - val_loss: 0.1470 - val_accuracy: 0.9650 - lr: 0.0010 - 933ms/epoch - 31ms/step
# Epoch 14/60
#
# Epoch 13: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 0.0385 - accuracy: 0.9827 - val_loss: 0.1488 - val_accuracy: 0.9607 - lr: 0.0010 - 800ms/epoch - 27ms/step
# Epoch 14/60
#
# Epoch 13: val_accuracy did not improve from 0.97028
# 30/30 - 1s - loss: 0.0212 - accuracy: 0.9931 - val_loss: 0.1123 - val_accuracy: 0.9660 - lr: 0.0010 - 795ms/epoch - 26ms/step
# Epoch 14/60
#
# Epoch 13: val_accuracy improved from 0.96921 to 0.97240, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0231model.keras
#
# Epoch 13: val_accuracy did not improve from 0.97028
# 30/30 - 1s - loss: 0.0245 - accuracy: 0.9896 - val_loss: 0.1430 - val_accuracy: 0.9618 - lr: 0.0010 - 842ms/epoch - 28ms/step
# Epoch 14/60
#
# Epoch 13: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 0.0251 - accuracy: 0.9907 - val_loss: 0.1443 - val_accuracy: 0.9586 - lr: 0.0010 - 815ms/epoch - 27ms/step
# Epoch 14/60
#
# Epoch 14: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 0.0253 - accuracy: 0.9923 - val_loss: 0.1279 - val_accuracy: 0.9639 - lr: 0.0010 - 857ms/epoch - 29ms/step
# Epoch 15/60
#
# Epoch 14: val_accuracy did not improve from 0.96921
# 30/30 - 1s - loss: 0.0443 - accuracy: 0.9814 - val_loss: 0.1137 - val_accuracy: 0.9692 - lr: 0.0010 - 792ms/epoch - 26ms/step
# Epoch 15/60
# 30/30 - 1s - loss: 0.0176 - accuracy: 0.9928 - val_loss: 0.1416 - val_accuracy: 0.9724 - lr: 0.0010 - 1s/epoch - 35ms/step
# Epoch 14/60
#
# Epoch 14: val_accuracy improved from 0.96815 to 0.96921, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/1023model.keras
#
# Epoch 14: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 0.0252 - accuracy: 0.9912 - val_loss: 0.1310 - val_accuracy: 0.9682 - lr: 0.0010 - 797ms/epoch - 27ms/step
# Epoch 15/60
#
# Epoch 14: val_accuracy did not improve from 0.97028
# 30/30 - 1s - loss: 0.0139 - accuracy: 0.9958 - val_loss: 0.1386 - val_accuracy: 0.9660 - lr: 0.0010 - 796ms/epoch - 27ms/step
# Epoch 15/60
#
# Epoch 14: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 0.0334 - accuracy: 0.9859 - val_loss: 0.1582 - val_accuracy: 0.9607 - lr: 0.0010 - 801ms/epoch - 27ms/step
#
# Epoch 14: val_accuracy did not improve from 0.97028
# Epoch 15/60
# 30/30 - 1s - loss: 0.0168 - accuracy: 0.9936 - val_loss: 0.1383 - val_accuracy: 0.9703 - lr: 0.0010 - 822ms/epoch - 27ms/step
# 30/30 - 1s - loss: 0.0166 - accuracy: 0.9936 - val_loss: 0.1760 - val_accuracy: 0.9692 - lr: 0.0010 - 1s/epoch - 35ms/step
# Epoch 15/60
# Epoch 15/60
#
# Epoch 15: val_accuracy did not improve from 0.96921
# 30/30 - 1s - loss: 0.0248 - accuracy: 0.9912 - val_loss: 0.1340 - val_accuracy: 0.9660 - lr: 0.0010 - 752ms/epoch - 25ms/step
# Epoch 16/60
#
# Epoch 15: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 0.0160 - accuracy: 0.9950 - val_loss: 0.1465 - val_accuracy: 0.9671 - lr: 0.0010 - 841ms/epoch - 28ms/step
# Epoch 16/60
#
# Epoch 14: val_accuracy did not improve from 0.97240
# 30/30 - 1s - loss: 0.0114 - accuracy: 0.9958 - val_loss: 0.1522 - val_accuracy: 0.9671 - lr: 0.0010 - 758ms/epoch - 25ms/step
# Epoch 15/60
#
# Epoch 15: val_accuracy did not improve from 0.97028
#
# Epoch 15: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 0.0093 - accuracy: 0.9979 - val_loss: 0.1465 - val_accuracy: 0.9703 - lr: 0.0010 - 808ms/epoch - 27ms/step
# 30/30 - 1s - loss: 0.0149 - accuracy: 0.9955 - val_loss: 0.1501 - val_accuracy: 0.9660 - lr: 0.0010 - 856ms/epoch - 29ms/step
# Epoch 16/60
# Epoch 16/60
#
# Epoch 15: val_accuracy did not improve from 0.96921
# 30/30 - 1s - loss: 0.0195 - accuracy: 0.9931 - val_loss: 0.1742 - val_accuracy: 0.9650 - lr: 0.0010 - 785ms/epoch - 26ms/step
# Epoch 16/60
#
# Epoch 15: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 0.0254 - accuracy: 0.9912 - val_loss: 0.1460 - val_accuracy: 0.9682 - lr: 0.0010 - 800ms/epoch - 27ms/step
#
# Epoch 15: val_accuracy did not improve from 0.97028
# Epoch 16/60
# 30/30 - 1s - loss: 0.0114 - accuracy: 0.9976 - val_loss: 0.1470 - val_accuracy: 0.9639 - lr: 0.0010 - 798ms/epoch - 27ms/step
# Epoch 16/60
#
# Epoch 16: val_accuracy improved from 0.96921 to 0.97134, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0312model.keras
#
# Epoch 16: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 0.0215 - accuracy: 0.9918 - val_loss: 0.1568 - val_accuracy: 0.9650 - lr: 0.0010 - 791ms/epoch - 26ms/step
# Epoch 17/60
#
# Epoch 15: val_accuracy did not improve from 0.97240
# 30/30 - 1s - loss: 0.0071 - accuracy: 0.9987 - val_loss: 0.1694 - val_accuracy: 0.9671 - lr: 0.0010 - 781ms/epoch - 26ms/step
# Epoch 16/60
# 30/30 - 1s - loss: 0.0107 - accuracy: 0.9979 - val_loss: 0.1533 - val_accuracy: 0.9713 - lr: 0.0010 - 996ms/epoch - 33ms/step
# Epoch 17/60
#
# Epoch 16: val_accuracy did not improve from 0.96815
#
# Epoch 16: val_accuracy did not improve from 0.97028
# 30/30 - 1s - loss: 0.0079 - accuracy: 0.9989 - val_loss: 0.1487 - val_accuracy: 0.9660 - lr: 0.0010 - 788ms/epoch - 26ms/step
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 17/60
# 30/30 - 1s - loss: 0.0100 - accuracy: 0.9971 - val_loss: 0.1584 - val_accuracy: 0.9692 - lr: 0.0010 - 802ms/epoch - 27ms/step
# Epoch 17/60
#
# Epoch 16: val_accuracy did not improve from 0.96921
# 30/30 - 1s - loss: 0.0094 - accuracy: 0.9968 - val_loss: 0.1820 - val_accuracy: 0.9597 - lr: 0.0010 - 773ms/epoch - 26ms/step
# Epoch 17/60
#
# Epoch 16: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 0.0352 - accuracy: 0.9854 - val_loss: 0.1426 - val_accuracy: 0.9650 - lr: 0.0010 - 787ms/epoch - 26ms/step
# Epoch 17/60
#
# Epoch 16: val_accuracy did not improve from 0.97028
# 30/30 - 1s - loss: 0.0144 - accuracy: 0.9947 - val_loss: 0.1680 - val_accuracy: 0.9544 - lr: 0.0010 - 791ms/epoch - 26ms/step
# Epoch 17/60
#
# Epoch 17: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 0.0162 - accuracy: 0.9942 - val_loss: 0.1551 - val_accuracy: 0.9650 - lr: 0.0010 - 760ms/epoch - 25ms/step
# Epoch 18/60
#
# Epoch 16: val_accuracy did not improve from 0.97240
# 30/30 - 1s - loss: 0.0215 - accuracy: 0.9923 - val_loss: 0.3641 - val_accuracy: 0.9246 - lr: 0.0010 - 831ms/epoch - 28ms/step
# Epoch 17/60
#
# Epoch 17: val_accuracy improved from 0.97134 to 0.97240, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0312model.keras
# 30/30 - 1s - loss: 0.0050 - accuracy: 0.9989 - val_loss: 0.1438 - val_accuracy: 0.9724 - lr: 0.0010 - 1s/epoch - 35ms/step
# Epoch 18/60
#
# Epoch 17: val_accuracy did not improve from 0.97028
# 30/30 - 1s - loss: 0.0046 - accuracy: 0.9995 - val_loss: 0.1546 - val_accuracy: 0.9703 - lr: 1.0000e-04 - 753ms/epoch - 25ms/step
# Epoch 18/60
#
# Epoch 17: val_accuracy improved from 0.96815 to 0.97028, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0321model.keras
#
# Epoch 17: val_accuracy did not improve from 0.96921
# 30/30 - 1s - loss: 0.0264 - accuracy: 0.9888 - val_loss: 0.2030 - val_accuracy: 0.9618 - lr: 0.0010 - 752ms/epoch - 25ms/step
#
# Epoch 17: val_accuracy did not improve from 0.96815
#
# Epoch 17: val_accuracy did not improve from 0.97028
# 30/30 - 1s - loss: 0.0285 - accuracy: 0.9888 - val_loss: 0.1733 - val_accuracy: 0.9628 - lr: 0.0010 - 743ms/epoch - 25ms/step
# 30/30 - 1s - loss: 0.0143 - accuracy: 0.9950 - val_loss: 0.1714 - val_accuracy: 0.9639 - lr: 0.0010 - 732ms/epoch - 24ms/step
# Epoch 18/60
# Epoch 18/60
# Epoch 18/60
#
# Epoch 18: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 0.0088 - accuracy: 0.9987 - val_loss: 0.1794 - val_accuracy: 0.9565 - lr: 0.0010 - 750ms/epoch - 25ms/step
# Epoch 19/60
# 30/30 - 1s - loss: 0.0105 - accuracy: 0.9971 - val_loss: 0.1563 - val_accuracy: 0.9703 - lr: 0.0010 - 978ms/epoch - 33ms/step
# Epoch 18/60
#
# Epoch 17: val_accuracy did not improve from 0.97240
# 30/30 - 1s - loss: 0.0410 - accuracy: 0.9835 - val_loss: 0.1618 - val_accuracy: 0.9618 - lr: 0.0010 - 772ms/epoch - 26ms/step
# Epoch 18/60
#
# Epoch 18: val_accuracy did not improve from 0.97240
# 30/30 - 1s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1570 - val_accuracy: 0.9713 - lr: 0.0010 - 798ms/epoch - 27ms/step
# Epoch 19/60
#
# Epoch 18: val_accuracy improved from 0.97028 to 0.97134, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0132model.keras
#
# Epoch 18: val_accuracy did not improve from 0.97028
# 30/30 - 1s - loss: 0.0062 - accuracy: 0.9987 - val_loss: 0.1677 - val_accuracy: 0.9671 - lr: 0.0010 - 810ms/epoch - 27ms/step
#
# Epoch 18: val_accuracy did not improve from 0.96921
# Epoch 19/60
# 30/30 - 1s - loss: 0.0219 - accuracy: 0.9928 - val_loss: 0.1652 - val_accuracy: 0.9586 - lr: 0.0010 - 819ms/epoch - 27ms/step
# Epoch 19/60
#
# Epoch 18: val_accuracy did not improve from 0.96815
#
# Epoch 19: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 0.0134 - accuracy: 0.9947 - val_loss: 0.2000 - val_accuracy: 0.9575 - lr: 0.0010 - 822ms/epoch - 27ms/step
# 30/30 - 1s - loss: 0.0203 - accuracy: 0.9931 - val_loss: 0.1719 - val_accuracy: 0.9628 - lr: 0.0010 - 858ms/epoch - 29ms/step
# Epoch 20/60
# Epoch 19/60
#
# Epoch 18: val_accuracy did not improve from 0.97028
# 30/30 - 1s - loss: 0.0202 - accuracy: 0.9912 - val_loss: 0.1592 - val_accuracy: 0.9703 - lr: 0.0010 - 784ms/epoch - 26ms/step
# Epoch 19/60
# 30/30 - 1s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.1544 - val_accuracy: 0.9713 - lr: 1.0000e-04 - 1s/epoch - 35ms/step
# Epoch 19/60
#
# Epoch 18: val_accuracy did not improve from 0.97240
# 30/30 - 1s - loss: 0.0218 - accuracy: 0.9923 - val_loss: 0.1529 - val_accuracy: 0.9607 - lr: 0.0010 - 818ms/epoch - 27ms/step
# Epoch 19/60
#
# Epoch 19: val_accuracy did not improve from 0.97240
# 30/30 - 1s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1639 - val_accuracy: 0.9682 - lr: 0.0010 - 765ms/epoch - 26ms/step
# Epoch 20/60
#
# Epoch 19: val_accuracy did not improve from 0.97028
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 30/30 - 1s - loss: 0.0049 - accuracy: 0.9987 - val_loss: 0.1796 - val_accuracy: 0.9660 - lr: 0.0010 - 811ms/epoch - 27ms/step
# Epoch 20/60
#
# Epoch 19: val_accuracy did not improve from 0.96921
# 30/30 - 1s - loss: 0.0080 - accuracy: 0.9979 - val_loss: 0.1797 - val_accuracy: 0.9671 - lr: 0.0010 - 827ms/epoch - 28ms/step
#
# Epoch 19: val_accuracy did not improve from 0.96815
# Epoch 20/60
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 30/30 - 1s - loss: 0.0144 - accuracy: 0.9952 - val_loss: 0.1537 - val_accuracy: 0.9682 - lr: 0.0010 - 787ms/epoch - 26ms/step
# Epoch 20/60
#
# Epoch 19: val_accuracy did not improve from 0.97028
# 30/30 - 1s - loss: 0.0098 - accuracy: 0.9981 - val_loss: 0.2320 - val_accuracy: 0.9544 - lr: 0.0010 - 814ms/epoch - 27ms/step
# Epoch 20/60
#
# Epoch 20: val_accuracy did not improve from 0.96815
#
# Epoch 19: val_accuracy did not improve from 0.97134
# 30/30 - 1s - loss: 0.0069 - accuracy: 0.9987 - val_loss: 0.1911 - val_accuracy: 0.9660 - lr: 0.0010 - 904ms/epoch - 30ms/step
# 30/30 - 1s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.1536 - val_accuracy: 0.9692 - lr: 1.0000e-04 - 786ms/epoch - 26ms/step
# Epoch 21/60
# Epoch 20/60
#
# Epoch 19: val_accuracy did not improve from 0.97240
# 30/30 - 1s - loss: 0.0154 - accuracy: 0.9942 - val_loss: 0.2227 - val_accuracy: 0.9544 - lr: 0.0010 - 845ms/epoch - 28ms/step
# Epoch 20/60
#
# Epoch 20: val_accuracy improved from 0.97240 to 0.97452, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0312model.keras
# 30/30 - 1s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1627 - val_accuracy: 0.9745 - lr: 0.0010 - 999ms/epoch - 33ms/step
# Epoch 21/60
#
# Epoch 20: val_accuracy did not improve from 0.96815
#
# Epoch 20: val_accuracy did not improve from 0.96921
# 30/30 - 1s - loss: 0.0052 - accuracy: 0.9992 - val_loss: 0.1520 - val_accuracy: 0.9682 - lr: 1.0000e-04 - 779ms/epoch - 26ms/step
# 30/30 - 1s - loss: 0.0130 - accuracy: 0.9955 - val_loss: 0.1726 - val_accuracy: 0.9639 - lr: 0.0010 - 795ms/epoch - 26ms/step
#
# Epoch 20: val_accuracy did not improve from 0.97028
# Epoch 21/60
# 30/30 - 1s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1779 - val_accuracy: 0.9650 - lr: 1.0000e-04 - 822ms/epoch - 27ms/step
# Epoch 21/60
# Epoch 21/60
#
# Epoch 20: val_accuracy did not improve from 0.97028
# 30/30 - 1s - loss: 0.0213 - accuracy: 0.9899 - val_loss: 0.1676 - val_accuracy: 0.9544 - lr: 0.0010 - 764ms/epoch - 25ms/step
# Epoch 21/60
#
# Epoch 20: val_accuracy did not improve from 0.97134
# 30/30 - 1s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1577 - val_accuracy: 0.9692 - lr: 1.0000e-04 - 781ms/epoch - 26ms/step
# Epoch 21/60
#
# Epoch 21: val_accuracy did not improve from 0.96815
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 20: val_accuracy did not improve from 0.97240
# 30/30 - 1s - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.1792 - val_accuracy: 0.9650 - lr: 0.0010 - 845ms/epoch - 28ms/step
# 30/30 - 1s - loss: 0.0290 - accuracy: 0.9888 - val_loss: 0.1830 - val_accuracy: 0.9650 - lr: 0.0010 - 734ms/epoch - 24ms/step
# Epoch 22/60
# Epoch 21/60
#
# Epoch 21: val_accuracy did not improve from 0.97452
# 30/30 - 1s - loss: 7.8964e-04 - accuracy: 1.0000 - val_loss: 0.1721 - val_accuracy: 0.9713 - lr: 0.0010 - 782ms/epoch - 26ms/step
# Epoch 22/60
#
# Epoch 21: val_accuracy improved from 0.96815 to 0.97028, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0123model.keras
#
# Epoch 21: val_accuracy did not improve from 0.97028
# 30/30 - 1s - loss: 0.0219 - accuracy: 0.9910 - val_loss: 0.2172 - val_accuracy: 0.9575 - lr: 0.0010 - 782ms/epoch - 26ms/step
# Epoch 22/60
#
# Epoch 21: val_accuracy did not improve from 0.96921
# 30/30 - 1s - loss: 0.0096 - accuracy: 0.9963 - val_loss: 0.1834 - val_accuracy: 0.9639 - lr: 0.0010 - 869ms/epoch - 29ms/step
# Epoch 22/60
#
# Epoch 21: val_accuracy did not improve from 0.97028
# 30/30 - 1s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1785 - val_accuracy: 0.9660 - lr: 1.0000e-04 - 883ms/epoch - 29ms/step
# Epoch 22/60
#
# Epoch 21: val_accuracy did not improve from 0.97134
# 30/30 - 1s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1552 - val_accuracy: 0.9703 - lr: 1.0000e-04 - 773ms/epoch - 26ms/step
# Epoch 22/60
#
# Epoch 22: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1788 - val_accuracy: 0.9671 - lr: 1.0000e-04 - 754ms/epoch - 25ms/step
# Epoch 23/60
#
# Epoch 21: val_accuracy did not improve from 0.97240
# 30/30 - 1s - loss: 0.0191 - accuracy: 0.9926 - val_loss: 0.1742 - val_accuracy: 0.9671 - lr: 0.0010 - 795ms/epoch - 26ms/step
# Epoch 22/60
# 30/30 - 1s - loss: 0.0039 - accuracy: 0.9997 - val_loss: 0.1535 - val_accuracy: 0.9703 - lr: 1.0000e-04 - 1s/epoch - 34ms/step
# Epoch 22/60
#
# Epoch 22: val_accuracy did not improve from 0.97452
# 30/30 - 1s - loss: 5.5873e-04 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9713 - lr: 0.0010 - 733ms/epoch - 24ms/step
# Epoch 23/60
#
# Epoch 22: val_accuracy did not improve from 0.97028
# 30/30 - 1s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1793 - val_accuracy: 0.9660 - lr: 1.0000e-04 - 834ms/epoch - 28ms/step
#
# Epoch 22: val_accuracy improved from 0.96921 to 0.97240, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/1023model.keras
# Epoch 23/60
#
# Epoch 23: val_accuracy improved from 0.96815 to 0.96921, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/1032model.keras
#
# Epoch 22: val_accuracy did not improve from 0.97134
# 30/30 - 1s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1577 - val_accuracy: 0.9692 - lr: 1.0000e-04 - 840ms/epoch - 28ms/step
# Epoch 23/60
#
# Epoch 22: val_accuracy did not improve from 0.97028
# 30/30 - 1s - loss: 0.0103 - accuracy: 0.9965 - val_loss: 0.1607 - val_accuracy: 0.9692 - lr: 0.0010 - 935ms/epoch - 31ms/step
#
# Epoch 22: val_accuracy did not improve from 0.97240
# 30/30 - 1s - loss: 0.0044 - accuracy: 0.9995 - val_loss: 0.1817 - val_accuracy: 0.9713 - lr: 0.0010 - 805ms/epoch - 27ms/step
# Epoch 23/60
# Epoch 23/60
#
# Epoch 22: val_accuracy improved from 0.97028 to 0.97134, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0123model.keras
# 30/30 - 1s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1795 - val_accuracy: 0.9692 - lr: 1.0000e-04 - 985ms/epoch - 33ms/step
# Epoch 24/60
# 30/30 - 1s - loss: 0.0033 - accuracy: 0.9997 - val_loss: 0.1808 - val_accuracy: 0.9724 - lr: 0.0010 - 1s/epoch - 36ms/step
# Epoch 23/60
# 30/30 - 1s - loss: 0.0033 - accuracy: 0.9997 - val_loss: 0.1526 - val_accuracy: 0.9713 - lr: 1.0000e-04 - 1s/epoch - 34ms/step
# Epoch 23/60
#
# Epoch 23: val_accuracy did not improve from 0.97452
# 30/30 - 1s - loss: 4.3532e-04 - accuracy: 1.0000 - val_loss: 0.1820 - val_accuracy: 0.9713 - lr: 0.0010 - 754ms/epoch - 25ms/step
# Epoch 24/60
#
# Epoch 23: val_accuracy did not improve from 0.97028
# 30/30 - 1s - loss: 9.2064e-04 - accuracy: 1.0000 - val_loss: 0.1800 - val_accuracy: 0.9660 - lr: 1.0000e-04 - 789ms/epoch - 26ms/step
# Epoch 24/60
#
# Epoch 23: val_accuracy did not improve from 0.97134
# 30/30 - 1s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1569 - val_accuracy: 0.9703 - lr: 1.0000e-04 - 799ms/epoch - 27ms/step
# Epoch 24/60
#
# Epoch 23: val_accuracy did not improve from 0.97028
# 30/30 - 1s - loss: 0.0030 - accuracy: 0.9995 - val_loss: 0.1851 - val_accuracy: 0.9671 - lr: 0.0010 - 761ms/epoch - 25ms/step
# Epoch 24/60
#
# Epoch 23: val_accuracy did not improve from 0.97240
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 30/30 - 1s - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.1844 - val_accuracy: 0.9692 - lr: 0.0010 - 783ms/epoch - 26ms/step
# Epoch 24/60
#
# Epoch 23: val_accuracy did not improve from 0.97240
# 30/30 - 1s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1863 - val_accuracy: 0.9724 - lr: 0.0010 - 761ms/epoch - 25ms/step
# Epoch 24/60
#
# Epoch 24: val_accuracy did not improve from 0.96921
# 30/30 - 1s - loss: 9.3327e-04 - accuracy: 1.0000 - val_loss: 0.1804 - val_accuracy: 0.9692 - lr: 1.0000e-04 - 813ms/epoch - 27ms/step
# Epoch 25/60
#
# Epoch 23: val_accuracy did not improve from 0.97134
# 30/30 - 1s - loss: 0.0030 - accuracy: 0.9997 - val_loss: 0.1537 - val_accuracy: 0.9713 - lr: 1.0000e-04 - 837ms/epoch - 28ms/step
# Epoch 24/60
#
# Epoch 24: val_accuracy did not improve from 0.97452
# 30/30 - 1s - loss: 3.6755e-04 - accuracy: 1.0000 - val_loss: 0.1894 - val_accuracy: 0.9703 - lr: 0.0010 - 856ms/epoch - 29ms/step
# Epoch 25/60
# Restoring model weights from the end of the best epoch: 9.
#
# Epoch 24: val_accuracy did not improve from 0.97028
# 30/30 - 1s - loss: 8.7129e-04 - accuracy: 1.0000 - val_loss: 0.1806 - val_accuracy: 0.9650 - lr: 1.0000e-04 - 814ms/epoch - 27ms/step
# Epoch 24: early stopping
#
# Epoch 24: val_accuracy did not improve from 0.97134
# 30/30 - 1s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1595 - val_accuracy: 0.9703 - lr: 1.0000e-04 - 798ms/epoch - 27ms/step
# Epoch 25/60
#
# Epoch 24: val_accuracy did not improve from 0.97028
# 30/30 - 1s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1810 - val_accuracy: 0.9703 - lr: 0.0010 - 795ms/epoch - 26ms/step
# Epoch 25/60
#
# Epoch 24: val_accuracy did not improve from 0.97240
# 30/30 - 1s - loss: 9.1410e-04 - accuracy: 1.0000 - val_loss: 0.1853 - val_accuracy: 0.9724 - lr: 1.0000e-04 - 805ms/epoch - 27ms/step
# Epoch 25/60
#
# Epoch 24: val_accuracy did not improve from 0.97240
# 30/30 - 1s - loss: 7.1866e-04 - accuracy: 1.0000 - val_loss: 0.1870 - val_accuracy: 0.9724 - lr: 0.0010 - 781ms/epoch - 26ms/step
# Epoch 25/60
#
# Epoch 25: val_accuracy did not improve from 0.96921
# 30/30 - 1s - loss: 8.6084e-04 - accuracy: 1.0000 - val_loss: 0.1812 - val_accuracy: 0.9671 - lr: 1.0000e-04 - 850ms/epoch - 28ms/step
# Epoch 26/60
#
# Epoch 25: val_accuracy did not improve from 0.97452
#
# Epoch 24: val_accuracy did not improve from 0.97134
# 30/30 - 1s - loss: 3.7439e-04 - accuracy: 1.0000 - val_loss: 0.1879 - val_accuracy: 0.9703 - lr: 0.0010 - 666ms/epoch - 22ms/step
# 30/30 - 1s - loss: 0.0028 - accuracy: 0.9997 - val_loss: 0.1547 - val_accuracy: 0.9713 - lr: 1.0000e-04 - 809ms/epoch - 27ms/step
# Epoch 26/60
# Epoch 25/60
#
# Epoch 25: val_accuracy did not improve from 0.97028
# 30/30 - 1s - loss: 5.2360e-04 - accuracy: 1.0000 - val_loss: 0.1858 - val_accuracy: 0.9682 - lr: 0.0010 - 710ms/epoch - 24ms/step
# Epoch 26/60
#
# Epoch 25: val_accuracy did not improve from 0.97240
# 30/30 - 1s - loss: 7.5387e-04 - accuracy: 1.0000 - val_loss: 0.1857 - val_accuracy: 0.9724 - lr: 1.0000e-04 - 690ms/epoch - 23ms/step
# Epoch 26/60
#
# Epoch 25: val_accuracy did not improve from 0.97134
# 30/30 - 1s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1592 - val_accuracy: 0.9703 - lr: 1.0000e-04 - 776ms/epoch - 26ms/step
# Epoch 26/60
#
# Epoch 25: val_accuracy did not improve from 0.97240
# 30/30 - 1s - loss: 4.0616e-04 - accuracy: 1.0000 - val_loss: 0.1948 - val_accuracy: 0.9724 - lr: 0.0010 - 695ms/epoch - 23ms/step
# Epoch 26/60
#
# Epoch 26: val_accuracy did not improve from 0.96921
# 30/30 - 1s - loss: 8.1018e-04 - accuracy: 1.0000 - val_loss: 0.1823 - val_accuracy: 0.9671 - lr: 1.0000e-04 - 749ms/epoch - 25ms/step
# Epoch 27/60
#
# Epoch 26: val_accuracy did not improve from 0.97452
# 30/30 - 1s - loss: 2.6322e-04 - accuracy: 1.0000 - val_loss: 0.1908 - val_accuracy: 0.9713 - lr: 0.0010 - 697ms/epoch - 23ms/step
# Epoch 27/60
#
# Epoch 25: val_accuracy improved from 0.97134 to 0.97240, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/0123model.keras
# 30/30 - 1s - loss: 0.0026 - accuracy: 0.9997 - val_loss: 0.1562 - val_accuracy: 0.9724 - lr: 1.0000e-04 - 916ms/epoch - 31ms/step
# Epoch 26/60
#
# Epoch 26: val_accuracy did not improve from 0.97240
# 30/30 - 1s - loss: 7.0239e-04 - accuracy: 1.0000 - val_loss: 0.1854 - val_accuracy: 0.9724 - lr: 1.0000e-04 - 649ms/epoch - 22ms/step
# Epoch 27/60
#
# Epoch 26: val_accuracy did not improve from 0.97134
# 30/30 - 1s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1594 - val_accuracy: 0.9703 - lr: 1.0000e-04 - 640ms/epoch - 21ms/step
# Epoch 27/60
#
# Epoch 26: val_accuracy did not improve from 0.97028
# 30/30 - 1s - loss: 4.0434e-04 - accuracy: 1.0000 - val_loss: 0.1926 - val_accuracy: 0.9703 - lr: 0.0010 - 729ms/epoch - 24ms/step
# Epoch 27/60
#
# Epoch 26: val_accuracy did not improve from 0.97240
# 30/30 - 1s - loss: 2.8047e-04 - accuracy: 1.0000 - val_loss: 0.1958 - val_accuracy: 0.9724 - lr: 0.0010 - 643ms/epoch - 21ms/step
# Epoch 27/60
#
# Epoch 27: val_accuracy did not improve from 0.96921
# 30/30 - 1s - loss: 7.6565e-04 - accuracy: 1.0000 - val_loss: 0.1828 - val_accuracy: 0.9671 - lr: 1.0000e-04 - 680ms/epoch - 23ms/step
# Epoch 28/60
#
# Epoch 27: val_accuracy did not improve from 0.97452
# 30/30 - 1s - loss: 2.2761e-04 - accuracy: 1.0000 - val_loss: 0.1956 - val_accuracy: 0.9713 - lr: 0.0010 - 671ms/epoch - 22ms/step
# Epoch 28/60
#
# Epoch 26: val_accuracy did not improve from 0.97240
# 30/30 - 1s - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.1569 - val_accuracy: 0.9724 - lr: 1.0000e-04 - 691ms/epoch - 23ms/step
# Epoch 27/60
#
# Epoch 27: val_accuracy did not improve from 0.97240
# 30/30 - 1s - loss: 6.5116e-04 - accuracy: 1.0000 - val_loss: 0.1854 - val_accuracy: 0.9713 - lr: 1.0000e-04 - 677ms/epoch - 23ms/step
# Epoch 28/60
#
# Epoch 27: val_accuracy did not improve from 0.97134
# 30/30 - 1s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1613 - val_accuracy: 0.9703 - lr: 1.0000e-04 - 729ms/epoch - 24ms/step
# Epoch 28/60
#
# Epoch 27: val_accuracy did not improve from 0.97028
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 30/30 - 1s - loss: 3.4052e-04 - accuracy: 1.0000 - val_loss: 0.1982 - val_accuracy: 0.9692 - lr: 0.0010 - 716ms/epoch - 24ms/step
# Epoch 28/60
#
# Epoch 27: val_accuracy did not improve from 0.97240
# 30/30 - 1s - loss: 2.6680e-04 - accuracy: 1.0000 - val_loss: 0.1985 - val_accuracy: 0.9713 - lr: 0.0010 - 702ms/epoch - 23ms/step
# Epoch 28/60
#
# Epoch 28: val_accuracy did not improve from 0.96921
# 30/30 - 1s - loss: 7.2628e-04 - accuracy: 1.0000 - val_loss: 0.1835 - val_accuracy: 0.9671 - lr: 1.0000e-04 - 664ms/epoch - 22ms/step
# Epoch 29/60
#
# Epoch 28: val_accuracy did not improve from 0.97452
# 30/30 - 1s - loss: 1.9400e-04 - accuracy: 1.0000 - val_loss: 0.1942 - val_accuracy: 0.9724 - lr: 0.0010 - 716ms/epoch - 24ms/step
# Epoch 29/60
#
# Epoch 27: val_accuracy did not improve from 0.97240
# 30/30 - 1s - loss: 0.0022 - accuracy: 0.9997 - val_loss: 0.1574 - val_accuracy: 0.9724 - lr: 1.0000e-04 - 725ms/epoch - 24ms/step
# Epoch 28/60
# Restoring model weights from the end of the best epoch: 13.
#
# Epoch 28: val_accuracy did not improve from 0.97240
# 30/30 - 1s - loss: 6.2153e-04 - accuracy: 1.0000 - val_loss: 0.1859 - val_accuracy: 0.9713 - lr: 1.0000e-04 - 722ms/epoch - 24ms/step
# Epoch 28: early stopping
#
# Epoch 28: val_accuracy did not improve from 0.97134
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 30/30 - 1s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1619 - val_accuracy: 0.9703 - lr: 1.0000e-04 - 710ms/epoch - 24ms/step
# Epoch 29/60
#
# Epoch 28: val_accuracy did not improve from 0.97028
# 30/30 - 1s - loss: 2.8535e-04 - accuracy: 1.0000 - val_loss: 0.1967 - val_accuracy: 0.9703 - lr: 1.0000e-04 - 723ms/epoch - 24ms/step
# Epoch 29/60
#
# Epoch 28: val_accuracy did not improve from 0.97240
# 30/30 - 1s - loss: 2.2020e-04 - accuracy: 1.0000 - val_loss: 0.1987 - val_accuracy: 0.9713 - lr: 0.0010 - 710ms/epoch - 24ms/step
# Epoch 29/60
#
# Epoch 29: val_accuracy did not improve from 0.96921
# 30/30 - 1s - loss: 6.9877e-04 - accuracy: 1.0000 - val_loss: 0.1842 - val_accuracy: 0.9671 - lr: 1.0000e-04 - 726ms/epoch - 24ms/step
# Epoch 30/60
#
# Epoch 29: val_accuracy did not improve from 0.97452
# 30/30 - 1s - loss: 1.6750e-04 - accuracy: 1.0000 - val_loss: 0.1980 - val_accuracy: 0.9713 - lr: 0.0010 - 687ms/epoch - 23ms/step
# Epoch 30/60
#
# Epoch 28: val_accuracy did not improve from 0.97240
# 30/30 - 1s - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.1591 - val_accuracy: 0.9724 - lr: 1.0000e-04 - 606ms/epoch - 20ms/step
# Epoch 29/60
#
# Epoch 29: val_accuracy did not improve from 0.97134
# ...
# Epoch 25/60
# Epoch 24/60
#
# Epoch 24: val_accuracy did not improve from 0.97558
# 30/30 - 1s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1599 - val_accuracy: 0.9735 - lr: 1.0000e-04 - 707ms/epoch - 24ms/step
# Epoch 25/60
#
# Epoch 24: val_accuracy did not improve from 0.96921
# 30/30 - 1s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1693 - val_accuracy: 0.9650 - lr: 1.0000e-04 - 763ms/epoch - 25ms/step
# Epoch 25/60
#
# Epoch 24: val_accuracy did not improve from 0.97346
# 30/30 - 1s - loss: 0.0127 - accuracy: 0.9971 - val_loss: 0.1723 - val_accuracy: 0.9671 - lr: 0.0010 - 744ms/epoch - 25ms/step
# Epoch 25/60
#
# Epoch 23: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 9.7611e-04 - accuracy: 1.0000 - val_loss: 0.1926 - val_accuracy: 0.9650 - lr: 0.0010 - 816ms/epoch - 27ms/step
# Epoch 24/60
#
# Epoch 24: val_accuracy did not improve from 0.97346
# 30/30 - 1s - loss: 6.2530e-04 - accuracy: 1.0000 - val_loss: 0.1760 - val_accuracy: 0.9713 - lr: 0.0010 - 723ms/epoch - 24ms/step
# Epoch 25/60
#
# Epoch 24: val_accuracy did not improve from 0.97028
# 30/30 - 1s - loss: 3.0897e-04 - accuracy: 1.0000 - val_loss: 0.2062 - val_accuracy: 0.9692 - lr: 0.0010 - 746ms/epoch - 25ms/step
#
# Epoch 25: val_accuracy did not improve from 0.97346
# Epoch 25/60
# 30/30 - 1s - loss: 4.6491e-04 - accuracy: 1.0000 - val_loss: 0.2058 - val_accuracy: 0.9692 - lr: 0.0010 - 741ms/epoch - 25ms/step
# Epoch 26/60
#
# Epoch 25: val_accuracy did not improve from 0.97558
# 30/30 - 1s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1613 - val_accuracy: 0.9735 - lr: 1.0000e-04 - 737ms/epoch - 25ms/step
# Epoch 26/60
# Restoring model weights from the end of the best epoch: 10.
#
# Epoch 25: val_accuracy did not improve from 0.96921
# 30/30 - 1s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1699 - val_accuracy: 0.9639 - lr: 1.0000e-04 - 843ms/epoch - 28ms/step
# Epoch 25: early stopping
#
# Epoch 25: val_accuracy did not improve from 0.97346
# 30/30 - 1s - loss: 0.0389 - accuracy: 0.9859 - val_loss: 0.1545 - val_accuracy: 0.9682 - lr: 0.0010 - 734ms/epoch - 24ms/step
# Epoch 26/60
#
# Epoch 24: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 4.5400e-04 - accuracy: 1.0000 - val_loss: 0.1951 - val_accuracy: 0.9682 - lr: 0.0010 - 721ms/epoch - 24ms/step
# Epoch 25/60
#
# Epoch 25: val_accuracy did not improve from 0.97346
# 30/30 - 1s - loss: 4.8730e-04 - accuracy: 1.0000 - val_loss: 0.1780 - val_accuracy: 0.9713 - lr: 0.0010 - 709ms/epoch - 24ms/step
#
# Epoch 25: val_accuracy did not improve from 0.97028
# Epoch 26/60
# 30/30 - 1s - loss: 2.4088e-04 - accuracy: 1.0000 - val_loss: 0.2071 - val_accuracy: 0.9703 - lr: 0.0010 - 705ms/epoch - 24ms/step
# Epoch 26/60
#
# Epoch 26: val_accuracy did not improve from 0.97346
# 30/30 - 1s - loss: 4.0031e-04 - accuracy: 1.0000 - val_loss: 0.2087 - val_accuracy: 0.9692 - lr: 0.0010 - 697ms/epoch - 23ms/step
# Epoch 27/60
#
# Epoch 26: val_accuracy did not improve from 0.97558
# 30/30 - 1s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1622 - val_accuracy: 0.9756 - lr: 1.0000e-04 - 656ms/epoch - 22ms/step
# Epoch 27/60
#
# Epoch 26: val_accuracy did not improve from 0.97346
# 30/30 - 1s - loss: 0.0250 - accuracy: 0.9923 - val_loss: 0.1717 - val_accuracy: 0.9660 - lr: 0.0010 - 654ms/epoch - 22ms/step
# Epoch 27/60
#
# Epoch 25: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 3.1057e-04 - accuracy: 1.0000 - val_loss: 0.1964 - val_accuracy: 0.9660 - lr: 0.0010 - 655ms/epoch - 22ms/step
# Epoch 26/60
#
# Epoch 26: val_accuracy did not improve from 0.97346
#
# Epoch 26: val_accuracy did not improve from 0.97028
# 30/30 - 1s - loss: 4.2422e-04 - accuracy: 1.0000 - val_loss: 0.1822 - val_accuracy: 0.9713 - lr: 0.0010 - 647ms/epoch - 22ms/step
# 30/30 - 1s - loss: 2.1188e-04 - accuracy: 1.0000 - val_loss: 0.2126 - val_accuracy: 0.9692 - lr: 0.0010 - 646ms/epoch - 22ms/step
#
# Epoch 27: val_accuracy did not improve from 0.97558
# Epoch 27/60
# 30/30 - 1s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1628 - val_accuracy: 0.9735 - lr: 1.0000e-04 - 614ms/epoch - 20ms/step
# Epoch 27/60
#
# Epoch 27: val_accuracy did not improve from 0.97346
# Epoch 28/60
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 30/30 - 1s - loss: 3.4701e-04 - accuracy: 1.0000 - val_loss: 0.2125 - val_accuracy: 0.9692 - lr: 0.0010 - 635ms/epoch - 21ms/step
# Epoch 28/60
#
# Epoch 27: val_accuracy did not improve from 0.97346
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 30/30 - 1s - loss: 0.0112 - accuracy: 0.9971 - val_loss: 0.2201 - val_accuracy: 0.9554 - lr: 0.0010 - 617ms/epoch - 21ms/step
# Epoch 28/60
#
# Epoch 26: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 2.4414e-04 - accuracy: 1.0000 - val_loss: 0.2040 - val_accuracy: 0.9671 - lr: 0.0010 - 633ms/epoch - 21ms/step
# Epoch 27/60
#
# Epoch 28: val_accuracy did not improve from 0.97558
# 30/30 - 1s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1649 - val_accuracy: 0.9735 - lr: 1.0000e-04 - 620ms/epoch - 21ms/step
# Epoch 29/60
#
# Epoch 27: val_accuracy improved from 0.97028 to 0.97134, saving model to _OA_results_PneumoniaMNIST_train_64/run_3FC/15/3021model.keras
#
# Epoch 28: val_accuracy did not improve from 0.97346
# 30/30 - 1s - loss: 2.9746e-04 - accuracy: 1.0000 - val_loss: 0.2124 - val_accuracy: 0.9692 - lr: 1.0000e-04 - 618ms/epoch - 21ms/step
#
# Epoch 27: val_accuracy did not improve from 0.97346
# 30/30 - 1s - loss: 3.5274e-04 - accuracy: 1.0000 - val_loss: 0.1864 - val_accuracy: 0.9724 - lr: 0.0010 - 641ms/epoch - 21ms/step
# Epoch 29/60
# Epoch 28/60
# 30/30 - 1s - loss: 1.7594e-04 - accuracy: 1.0000 - val_loss: 0.2149 - val_accuracy: 0.9713 - lr: 0.0010 - 805ms/epoch - 27ms/step
# Epoch 28/60
#
# Epoch 28: val_accuracy did not improve from 0.97346
# 30/30 - 1s - loss: 0.0111 - accuracy: 0.9955 - val_loss: 0.1719 - val_accuracy: 0.9713 - lr: 1.0000e-04 - 623ms/epoch - 21ms/step
# Epoch 29/60
#
# Epoch 27: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 1.4538e-04 - accuracy: 1.0000 - val_loss: 0.2049 - val_accuracy: 0.9671 - lr: 0.0010 - 634ms/epoch - 21ms/step
# Epoch 28/60
#
# Epoch 28: val_accuracy did not improve from 0.97346
# 30/30 - 1s - loss: 2.9959e-04 - accuracy: 1.0000 - val_loss: 0.1879 - val_accuracy: 0.9724 - lr: 0.0010 - 609ms/epoch - 20ms/step
#
# Epoch 29: val_accuracy did not improve from 0.97558
# 30/30 - 1s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1654 - val_accuracy: 0.9745 - lr: 1.0000e-04 - 632ms/epoch - 21ms/step
# Epoch 29/60
# Epoch 30/60
#
# Epoch 29: val_accuracy did not improve from 0.97346
# 30/30 - 1s - loss: 2.8339e-04 - accuracy: 1.0000 - val_loss: 0.2127 - val_accuracy: 0.9682 - lr: 1.0000e-04 - 638ms/epoch - 21ms/step
# Epoch 30/60
#
# Epoch 28: val_accuracy did not improve from 0.97134
# 30/30 - 1s - loss: 1.5081e-04 - accuracy: 1.0000 - val_loss: 0.2192 - val_accuracy: 0.9703 - lr: 0.0010 - 696ms/epoch - 23ms/step
# Epoch 29/60
#
# Epoch 29: val_accuracy did not improve from 0.97346
# 30/30 - 1s - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.1657 - val_accuracy: 0.9703 - lr: 1.0000e-04 - 626ms/epoch - 21ms/step
# Epoch 30/60
#
# Epoch 28: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 1.2059e-04 - accuracy: 1.0000 - val_loss: 0.2058 - val_accuracy: 0.9671 - lr: 0.0010 - 630ms/epoch - 21ms/step
# Epoch 29/60
#
# Epoch 29: val_accuracy did not improve from 0.97346
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 30/30 - 1s - loss: 2.5190e-04 - accuracy: 1.0000 - val_loss: 0.1928 - val_accuracy: 0.9713 - lr: 0.0010 - 622ms/epoch - 21ms/step
# Epoch 30/60
#
# Epoch 30: val_accuracy did not improve from 0.97558
# 30/30 - 1s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1662 - val_accuracy: 0.9735 - lr: 1.0000e-04 - 630ms/epoch - 21ms/step
#
# Epoch 30: val_accuracy did not improve from 0.97346
# Epoch 31/60
# 30/30 - 1s - loss: 2.7901e-04 - accuracy: 1.0000 - val_loss: 0.2128 - val_accuracy: 0.9682 - lr: 1.0000e-04 - 637ms/epoch - 21ms/step
# Epoch 31/60
#
# Epoch 29: val_accuracy did not improve from 0.97134
# 30/30 - 1s - loss: 1.3069e-04 - accuracy: 1.0000 - val_loss: 0.2235 - val_accuracy: 0.9703 - lr: 0.0010 - 676ms/epoch - 23ms/step
# Epoch 30/60
#
# Epoch 30: val_accuracy did not improve from 0.97346
# 30/30 - 1s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1676 - val_accuracy: 0.9703 - lr: 1.0000e-04 - 644ms/epoch - 21ms/step
# Epoch 31/60
#
# Epoch 29: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 1.0978e-04 - accuracy: 1.0000 - val_loss: 0.2122 - val_accuracy: 0.9671 - lr: 0.0010 - 645ms/epoch - 22ms/step
# Epoch 30/60
#
# Epoch 30: val_accuracy did not improve from 0.97346
# 30/30 - 1s - loss: 2.0859e-04 - accuracy: 1.0000 - val_loss: 0.1932 - val_accuracy: 0.9713 - lr: 1.0000e-04 - 627ms/epoch - 21ms/step
# Epoch 31/60
#
# Epoch 31: val_accuracy did not improve from 0.97346
# 30/30 - 1s - loss: 2.7323e-04 - accuracy: 1.0000 - val_loss: 0.2132 - val_accuracy: 0.9692 - lr: 1.0000e-04 - 650ms/epoch - 22ms/step
# Epoch 32/60
#
# Epoch 31: val_accuracy did not improve from 0.97558
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 30/30 - 1s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1668 - val_accuracy: 0.9745 - lr: 1.0000e-04 - 707ms/epoch - 24ms/step
# Epoch 32/60
#
# Epoch 30: val_accuracy did not improve from 0.97134
# 30/30 - 1s - loss: 1.1775e-04 - accuracy: 1.0000 - val_loss: 0.2282 - val_accuracy: 0.9692 - lr: 0.0010 - 569ms/epoch - 19ms/step
# Epoch 31/60
#
# Epoch 31: val_accuracy did not improve from 0.97346
# 30/30 - 1s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1696 - val_accuracy: 0.9703 - lr: 1.0000e-04 - 692ms/epoch - 23ms/step
# Epoch 32/60
#
# Epoch 30: val_accuracy did not improve from 0.96815
# 30/30 - 1s - loss: 9.4361e-05 - accuracy: 1.0000 - val_loss: 0.2117 - val_accuracy: 0.9671 - lr: 0.0010 - 621ms/epoch - 21ms/step
#
# Epoch 31: val_accuracy did not improve from 0.97346
# Epoch 31/60
# 30/30 - 1s - loss: 2.0444e-04 - accuracy: 1.0000 - val_loss: 0.1939 - val_accuracy: 0.9713 - lr: 1.0000e-04 - 578ms/epoch - 19ms/step
# Epoch 32/60
# Restoring model weights from the end of the best epoch: 17.
#
# Epoch 32: val_accuracy did not improve from 0.97346
#
# Epoch 32: val_accuracy did not improve from 0.97558
# 30/30 - 1s - loss: 2.6887e-04 - accuracy: 1.0000 - val_loss: 0.2135 - val_accuracy: 0.9682 - lr: 1.0000e-04 - 620ms/epoch - 21ms/step
# 30/30 - 1s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1672 - val_accuracy: 0.9756 - lr: 1.0000e-05 - 580ms/epoch - 19ms/step
# Epoch 32: early stopping
# Epoch 33/60
#
# Epoch 31: val_accuracy did not improve from 0.97134
# 30/30 - 1s - loss: 9.9484e-05 - accuracy: 1.0000 - val_loss: 0.2282 - val_accuracy: 0.9703 - lr: 0.0010 - 577ms/epoch - 19ms/step
# Epoch 32/60
# Restoring model weights from the end of the best epoch: 17.
#
# Epoch 31: val_accuracy did not improve from 0.96815
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 30/30 - 1s - loss: 8.8267e-05 - accuracy: 1.0000 - val_loss: 0.2152 - val_accuracy: 0.9682 - lr: 0.0010 - 566ms/epoch - 19ms/step
# Epoch 32/60
#
# Epoch 32: val_accuracy did not improve from 0.97346
# 30/30 - 1s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1712 - val_accuracy: 0.9703 - lr: 1.0000e-04 - 583ms/epoch - 19ms/step
# Epoch 32: early stopping
#
# Epoch 32: val_accuracy did not improve from 0.97346
# 30/30 - 1s - loss: 2.0135e-04 - accuracy: 1.0000 - val_loss: 0.1942 - val_accuracy: 0.9713 - lr: 1.0000e-04 - 572ms/epoch - 19ms/step
# Epoch 33/60
#
# Epoch 33: val_accuracy did not improve from 0.97558
# 30/30 - 1s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1673 - val_accuracy: 0.9756 - lr: 1.0000e-05 - 523ms/epoch - 17ms/step
# Epoch 34/60
#
# Epoch 32: val_accuracy did not improve from 0.97134
# 30/30 - 0s - loss: 9.3500e-05 - accuracy: 1.0000 - val_loss: 0.2348 - val_accuracy: 0.9692 - lr: 0.0010 - 480ms/epoch - 16ms/step
# Epoch 33/60
#
# Epoch 32: val_accuracy did not improve from 0.96815
# 30/30 - 0s - loss: 7.7702e-05 - accuracy: 1.0000 - val_loss: 0.2152 - val_accuracy: 0.9671 - lr: 1.0000e-04 - 454ms/epoch - 15ms/step
# Epoch 33/60
#
# Epoch 33: val_accuracy did not improve from 0.97346
# 30/30 - 0s - loss: 1.9972e-04 - accuracy: 1.0000 - val_loss: 0.1949 - val_accuracy: 0.9713 - lr: 1.0000e-04 - 446ms/epoch - 15ms/step
# Epoch 34/60
#
# Epoch 34: val_accuracy did not improve from 0.97558
# 30/30 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1675 - val_accuracy: 0.9735 - lr: 1.0000e-05 - 440ms/epoch - 15ms/step
# Epoch 35/60
#
# Epoch 33: val_accuracy did not improve from 0.97134
# 30/30 - 0s - loss: 8.0235e-05 - accuracy: 1.0000 - val_loss: 0.2394 - val_accuracy: 0.9692 - lr: 0.0010 - 408ms/epoch - 14ms/step
# Epoch 34/60
# Restoring model weights from the end of the best epoch: 19.
#
# Epoch 33: val_accuracy did not improve from 0.96815
# 30/30 - 0s - loss: 7.7323e-05 - accuracy: 1.0000 - val_loss: 0.2154 - val_accuracy: 0.9671 - lr: 1.0000e-04 - 448ms/epoch - 15ms/step
#
# Epoch 34: val_accuracy did not improve from 0.97346
# 30/30 - 0s - loss: 1.9461e-04 - accuracy: 1.0000 - val_loss: 0.1949 - val_accuracy: 0.9713 - lr: 1.0000e-04 - 442ms/epoch - 15ms/step
# Epoch 34/60
# Epoch 34: early stopping
#
# Epoch 35: val_accuracy did not improve from 0.97558
# 30/30 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1676 - val_accuracy: 0.9735 - lr: 1.0000e-05 - 419ms/epoch - 14ms/step
# Epoch 36/60
#
# Epoch 34: val_accuracy did not improve from 0.97134
# 30/30 - 0s - loss: 7.1655e-05 - accuracy: 1.0000 - val_loss: 0.2398 - val_accuracy: 0.9703 - lr: 0.0010 - 392ms/epoch - 13ms/step
# Epoch 35/60
#
# Epoch 34: val_accuracy did not improve from 0.96815
# 30/30 - 0s - loss: 7.6424e-05 - accuracy: 1.0000 - val_loss: 0.2159 - val_accuracy: 0.9682 - lr: 1.0000e-04 - 352ms/epoch - 12ms/step
# Epoch 35/60
# Restoring model weights from the end of the best epoch: 21.
#
# Epoch 36: val_accuracy did not improve from 0.97558
# 30/30 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1678 - val_accuracy: 0.9735 - lr: 1.0000e-05 - 367ms/epoch - 12ms/step
# Epoch 36: early stopping
#
# Epoch 35: val_accuracy did not improve from 0.97134
# 30/30 - 0s - loss: 6.3660e-05 - accuracy: 1.0000 - val_loss: 0.2443 - val_accuracy: 0.9703 - lr: 0.0010 - 340ms/epoch - 11ms/step
# Epoch 36/60
#
# Epoch 35: val_accuracy did not improve from 0.96815
# 30/30 - 0s - loss: 7.5674e-05 - accuracy: 1.0000 - val_loss: 0.2160 - val_accuracy: 0.9682 - lr: 1.0000e-04 - 310ms/epoch - 10ms/step
# Epoch 36/60
#
# Epoch 36: val_accuracy did not improve from 0.97134
# 30/30 - 0s - loss: 5.6574e-05 - accuracy: 1.0000 - val_loss: 0.2473 - val_accuracy: 0.9692 - lr: 0.0010 - 328ms/epoch - 11ms/step
# Epoch 37/60
# Restoring model weights from the end of the best epoch: 21.
#
# Epoch 36: val_accuracy did not improve from 0.96815
# 30/30 - 0s - loss: 7.5010e-05 - accuracy: 1.0000 - val_loss: 0.2162 - val_accuracy: 0.9682 - lr: 1.0000e-04 - 440ms/epoch - 15ms/step
# Epoch 36: early stopping
#
# Epoch 37: val_accuracy did not improve from 0.97134
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 30/30 - 0s - loss: 5.1658e-05 - accuracy: 1.0000 - val_loss: 0.2500 - val_accuracy: 0.9692 - lr: 0.0010 - 412ms/epoch - 14ms/step
# Epoch 38/60
#
# Epoch 38: val_accuracy did not improve from 0.97134
# 30/30 - 0s - loss: 4.7755e-05 - accuracy: 1.0000 - val_loss: 0.2501 - val_accuracy: 0.9692 - lr: 1.0000e-04 - 457ms/epoch - 15ms/step
# Epoch 39/60
#
# Epoch 39: val_accuracy did not improve from 0.97134
# 30/30 - 0s - loss: 4.6926e-05 - accuracy: 1.0000 - val_loss: 0.2497 - val_accuracy: 0.9703 - lr: 1.0000e-04 - 459ms/epoch - 15ms/step
# Epoch 40/60
#
# Epoch 40: val_accuracy did not improve from 0.97134
# 30/30 - 0s - loss: 4.6440e-05 - accuracy: 1.0000 - val_loss: 0.2499 - val_accuracy: 0.9703 - lr: 1.0000e-04 - 456ms/epoch - 15ms/step
# Epoch 41/60
#
# Epoch 41: val_accuracy did not improve from 0.97134
# 30/30 - 0s - loss: 4.5919e-05 - accuracy: 1.0000 - val_loss: 0.2504 - val_accuracy: 0.9703 - lr: 1.0000e-04 - 380ms/epoch - 13ms/step
# Epoch 42/60
# Restoring model weights from the end of the best epoch: 27.
#
# Epoch 42: val_accuracy did not improve from 0.97134
# 30/30 - 0s - loss: 4.5491e-05 - accuracy: 1.0000 - val_loss: 0.2503 - val_accuracy: 0.9703 - lr: 1.0000e-04 - 375ms/epoch - 12ms/step
# Epoch 42: early stopping

# %%
# for ind, variant  in enumerate(permutations):

#     label = ''.join(map(str,variant))
#     print(ind, label)
#     tr_images = train_layer.open(variant)
#     te_images =  test_layer.open(variant)
#     run(tr_images,te_images,label)

# %%
# run the network without filter

run(train_images, "NO-FILTER")
# Out:
# Epoch 1/60
#
# Epoch 1: val_accuracy improved from -inf to 0.93843, saving model to _OA_results_PneumoniaMNIST_train_64/run_1FC/15/NO-FILTERmodel.keras
# 30/30 - 1s - loss: 0.2791 - accuracy: 0.8688 - val_loss: 0.1663 - val_accuracy: 0.9384 - lr: 0.0010 - 767ms/epoch - 26ms/step
# Epoch 2/60
#
# Epoch 2: val_accuracy improved from 0.93843 to 0.94480, saving model to _OA_results_PneumoniaMNIST_train_64/run_1FC/15/NO-FILTERmodel.keras
# 30/30 - 0s - loss: 0.1574 - accuracy: 0.9392 - val_loss: 0.1423 - val_accuracy: 0.9448 - lr: 0.0010 - 269ms/epoch - 9ms/step
# Epoch 3/60
#
# Epoch 3: val_accuracy did not improve from 0.94480
# 30/30 - 0s - loss: 0.1434 - accuracy: 0.9466 - val_loss: 0.1485 - val_accuracy: 0.9374 - lr: 0.0010 - 224ms/epoch - 7ms/step
# Epoch 4/60
#
# Epoch 4: val_accuracy improved from 0.94480 to 0.95223, saving model to _OA_results_PneumoniaMNIST_train_64/run_1FC/15/NO-FILTERmodel.keras
# 30/30 - 0s - loss: 0.1449 - accuracy: 0.9464 - val_loss: 0.1353 - val_accuracy: 0.9522 - lr: 0.0010 - 261ms/epoch - 9ms/step
# Epoch 5/60
#
# Epoch 5: val_accuracy improved from 0.95223 to 0.95860, saving model to _OA_results_PneumoniaMNIST_train_64/run_1FC/15/NO-FILTERmodel.keras
# 30/30 - 0s - loss: 0.1266 - accuracy: 0.9527 - val_loss: 0.1196 - val_accuracy: 0.9586 - lr: 0.0010 - 242ms/epoch - 8ms/step
# Epoch 6/60
#
# Epoch 6: val_accuracy did not improve from 0.95860
# 30/30 - 0s - loss: 0.1238 - accuracy: 0.9543 - val_loss: 0.1215 - val_accuracy: 0.9533 - lr: 0.0010 - 236ms/epoch - 8ms/step
# Epoch 7/60
#
# Epoch 7: val_accuracy did not improve from 0.95860
# 30/30 - 0s - loss: 0.1192 - accuracy: 0.9578 - val_loss: 0.1235 - val_accuracy: 0.9533 - lr: 0.0010 - 234ms/epoch - 8ms/step
# Epoch 8/60
#
# Epoch 8: val_accuracy did not improve from 0.95860
# 30/30 - 0s - loss: 0.1143 - accuracy: 0.9567 - val_loss: 0.1195 - val_accuracy: 0.9565 - lr: 0.0010 - 182ms/epoch - 6ms/step
# Epoch 9/60
#
# Epoch 9: val_accuracy improved from 0.95860 to 0.95966, saving model to _OA_results_PneumoniaMNIST_train_64/run_1FC/15/NO-FILTERmodel.keras
# 30/30 - 0s - loss: 0.1114 - accuracy: 0.9570 - val_loss: 0.1175 - val_accuracy: 0.9597 - lr: 0.0010 - 249ms/epoch - 8ms/step
# Epoch 10/60
#
# Epoch 10: val_accuracy improved from 0.95966 to 0.96072, saving model to _OA_results_PneumoniaMNIST_train_64/run_1FC/15/NO-FILTERmodel.keras
# 30/30 - 0s - loss: 0.1081 - accuracy: 0.9610 - val_loss: 0.1156 - val_accuracy: 0.9607 - lr: 0.0010 - 236ms/epoch - 8ms/step
# Epoch 11/60
#
# Epoch 11: val_accuracy did not improve from 0.96072
# 30/30 - 0s - loss: 0.1090 - accuracy: 0.9580 - val_loss: 0.1349 - val_accuracy: 0.9427 - lr: 0.0010 - 189ms/epoch - 6ms/step
# Epoch 12/60
#
# Epoch 12: val_accuracy did not improve from 0.96072
# 30/30 - 0s - loss: 0.1006 - accuracy: 0.9626 - val_loss: 0.1164 - val_accuracy: 0.9597 - lr: 0.0010 - 202ms/epoch - 7ms/step
# Epoch 13/60
#
# Epoch 13: val_accuracy did not improve from 0.96072
# 30/30 - 0s - loss: 0.0974 - accuracy: 0.9647 - val_loss: 0.1197 - val_accuracy: 0.9544 - lr: 0.0010 - 224ms/epoch - 7ms/step
# Epoch 14/60
#
# Epoch 14: val_accuracy did not improve from 0.96072
# 30/30 - 0s - loss: 0.0955 - accuracy: 0.9649 - val_loss: 0.1181 - val_accuracy: 0.9586 - lr: 0.0010 - 234ms/epoch - 8ms/step
# Epoch 15/60
#
# Epoch 15: val_accuracy did not improve from 0.96072
# 30/30 - 0s - loss: 0.0960 - accuracy: 0.9644 - val_loss: 0.1152 - val_accuracy: 0.9586 - lr: 0.0010 - 220ms/epoch - 7ms/step
# Epoch 16/60
#
# Epoch 16: val_accuracy improved from 0.96072 to 0.96285, saving model to _OA_results_PneumoniaMNIST_train_64/run_1FC/15/NO-FILTERmodel.keras
# 30/30 - 0s - loss: 0.0953 - accuracy: 0.9647 - val_loss: 0.1128 - val_accuracy: 0.9628 - lr: 0.0010 - 250ms/epoch - 8ms/step
# Epoch 17/60
#
# Epoch 17: val_accuracy did not improve from 0.96285
# 30/30 - 0s - loss: 0.0893 - accuracy: 0.9697 - val_loss: 0.1148 - val_accuracy: 0.9607 - lr: 0.0010 - 223ms/epoch - 7ms/step
# Epoch 18/60
#
# Epoch 18: val_accuracy did not improve from 0.96285
# 30/30 - 0s - loss: 0.0898 - accuracy: 0.9676 - val_loss: 0.1145 - val_accuracy: 0.9597 - lr: 0.0010 - 232ms/epoch - 8ms/step
# Epoch 19/60
#
# Epoch 19: val_accuracy did not improve from 0.96285
# 30/30 - 0s - loss: 0.0861 - accuracy: 0.9689 - val_loss: 0.1155 - val_accuracy: 0.9597 - lr: 0.0010 - 237ms/epoch - 8ms/step
# Epoch 20/60
#
# Epoch 20: val_accuracy did not improve from 0.96285
# 30/30 - 0s - loss: 0.0872 - accuracy: 0.9689 - val_loss: 0.1230 - val_accuracy: 0.9554 - lr: 0.0010 - 239ms/epoch - 8ms/step
# Epoch 21/60
#
# Epoch 21: val_accuracy did not improve from 0.96285
# 30/30 - 0s - loss: 0.0900 - accuracy: 0.9660 - val_loss: 0.1184 - val_accuracy: 0.9586 - lr: 0.0010 - 236ms/epoch - 8ms/step
# Epoch 22/60
#
# Epoch 22: val_accuracy did not improve from 0.96285
# 30/30 - 0s - loss: 0.0827 - accuracy: 0.9697 - val_loss: 0.1205 - val_accuracy: 0.9554 - lr: 0.0010 - 245ms/epoch - 8ms/step
# Epoch 23/60
#
# Epoch 23: val_accuracy did not improve from 0.96285
# 30/30 - 0s - loss: 0.0789 - accuracy: 0.9713 - val_loss: 0.1256 - val_accuracy: 0.9512 - lr: 0.0010 - 217ms/epoch - 7ms/step
# Epoch 24/60
#
# Epoch 24: val_accuracy did not improve from 0.96285
# 30/30 - 0s - loss: 0.0822 - accuracy: 0.9719 - val_loss: 0.1330 - val_accuracy: 0.9522 - lr: 0.0010 - 190ms/epoch - 6ms/step
# Epoch 25/60
#
# Epoch 25: val_accuracy did not improve from 0.96285
# 30/30 - 0s - loss: 0.0781 - accuracy: 0.9729 - val_loss: 0.1390 - val_accuracy: 0.9459 - lr: 0.0010 - 207ms/epoch - 7ms/step
# Epoch 26/60
#
# Epoch 26: val_accuracy did not improve from 0.96285
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 30/30 - 0s - loss: 0.0805 - accuracy: 0.9687 - val_loss: 0.1248 - val_accuracy: 0.9554 - lr: 0.0010 - 194ms/epoch - 6ms/step
# Epoch 27/60
#
# Epoch 27: val_accuracy did not improve from 0.96285
# 30/30 - 0s - loss: 0.0720 - accuracy: 0.9761 - val_loss: 0.1157 - val_accuracy: 0.9628 - lr: 1.0000e-04 - 172ms/epoch - 6ms/step
# Epoch 28/60
#
# Epoch 28: val_accuracy did not improve from 0.96285
# 30/30 - 0s - loss: 0.0709 - accuracy: 0.9750 - val_loss: 0.1167 - val_accuracy: 0.9575 - lr: 1.0000e-04 - 211ms/epoch - 7ms/step
# Epoch 29/60
#
# Epoch 29: val_accuracy did not improve from 0.96285
# 30/30 - 0s - loss: 0.0707 - accuracy: 0.9756 - val_loss: 0.1175 - val_accuracy: 0.9597 - lr: 1.0000e-04 - 223ms/epoch - 7ms/step
# Epoch 30/60
#
# Epoch 30: val_accuracy did not improve from 0.96285
# 30/30 - 0s - loss: 0.0705 - accuracy: 0.9750 - val_loss: 0.1160 - val_accuracy: 0.9628 - lr: 1.0000e-04 - 220ms/epoch - 7ms/step
# Epoch 31/60
# Restoring model weights from the end of the best epoch: 16.
#
# Epoch 31: val_accuracy did not improve from 0.96285
# 30/30 - 0s - loss: 0.0705 - accuracy: 0.9756 - val_loss: 0.1173 - val_accuracy: 0.9597 - lr: 1.0000e-04 - 193ms/epoch - 6ms/step
# Epoch 31: early stopping

# %% [markdown]
# # Read Validation accuracy
# Now we will read from the csv and group the experiment validation for the last 30 epoch into the symmetries

# %%
# # change the subfolder name to save your data in different location based on what NN model you used
# # it's a convenient way to avoid losing your training data of each model
# # Here are some preset examples you can use
# # 1 FC layer
# run_subfolder = "_1FC"
# # run_subfolder = "_2nodes_2FC"
# # # 2 FC layer
# run_subfolder = "_2FC"
# # # 3 FC layer
# run_subfolder = "_3FC"
# # # 4 FC layer
run_subfolder = "_4FC"
# # # 11 FC layer
# run_subfolder = "_11FC"
# early stopping epochs -- good practice between 10-20
patience = 15
log_dir = train_layer.name + "/run" + run_subfolder +  "/"
log_dir += str(patience) +  "/"

# %%
# group the index of the permutation by the symmetry of the filter

diagonal_index = [4, 5, 8, 9, 14, 15, 18, 19]
vertical_index = [0, 1, 6, 7, 16, 17, 22, 23]
horizontal_index = [2, 3, 10, 11, 12, 13, 20, 21]

# %% [markdown]
# ### Finding the best model/worst for each symmetry

# %%
import pandas as pd

diagonal_val_accuracy = []
vertical_val_accuracy = []
horizontal_val_accuracy = []

diagonal_max_accuracy, vertical_max_accuracy, horizontal_max_accuracy = 0, 0, 0
diagonal_min_accuracy, vertical_min_accuracy, horizontal_min_accuracy = 0, 0, 0
diagonal_best_model, vertical_best_model, horizontal_best_model = "", "", ""
diagonal_worst_model, vertical_worst_model, horizontal_worst_model = "", "", ""
diagonal_max_accuracy_filepath, vertical_max_accuracy_filepath, horizontal_max_accuracy_filepath = "", "", ""
diagonal_best_model_filepath, vertical_best_model_filepath, horizontal_best_model_filepath = "", "", ""


for ind, variant  in enumerate(permutations):
    label = ''.join(map(str,variant))
    # file = train_layer.name + "/run" + run_subfolder +  "/" + label
    file = log_dir + label
    # print(file)
    #read the csv file
    df = pd.read_csv(file)
    # print(df)
    # print("Max ", df['val_accuracy'].max())
    # the number of last validation accuracy
    tail_accuracy = 30
    # our models file path extension, we'll use it to capture the filepath to our models
    model_filepath_extension = "model.keras"
    # Checking only diagonal models
    if ind in diagonal_index:
        if not diagonal_max_accuracy:
            # Assuming the max accuracy of the first model is both the max and min of the entire model with
            # respect to a given symmetry
            diagonal_max_accuracy = df['val_accuracy'].max()
            diagonal_best_model = label
            # saving the file path of the model and accuracies
            diagonal_max_accuracy_filepath = file
            diagonal_best_model_filepath = file + model_filepath_extension
            # capturing the lowest out of the highest accuracies of our models
            diagonal_min_accuracy = df['val_accuracy'].max()
            diagonal_worst_model = label
        # This block will only start from the second model 
        elif diagonal_max_accuracy < df['val_accuracy'].max():
            diagonal_max_accuracy = df['val_accuracy'].max()
            diagonal_best_model = label
            # saving the file path of the model and accuracies
            diagonal_max_accuracy_filepath = file
            diagonal_best_model_filepath = file + model_filepath_extension
        # This block will only start from the second model    
        elif diagonal_min_accuracy > df['val_accuracy'].max():
            diagonal_min_accuracy = df['val_accuracy'].max()
            diagonal_worst_model = label
    
    # Checking only vertical models    
    elif ind in vertical_index:
        if not vertical_max_accuracy:
            # Assuming the max accuracy of the first model is both the max and min of the entire model with
            # respect to a given symmetry
            vertical_max_accuracy = df['val_accuracy'].max()
            vertical_best_model = label
            # saving the file path of the model and accuracies
            vertical_max_accuracy_filepath = file
            vertical_best_model_filepath = file + model_filepath_extension
            # capturing the lowest out of the highest accuracies of our models
            vertical_min_accuracy = df['val_accuracy'].max()
            vertical_worst_model = label
        # This block will only start from the second model    
        elif vertical_max_accuracy < df['val_accuracy'].max():
            vertical_max_accuracy =  df['val_accuracy'].max()
            vertical_best_model = label
            # saving the file path of the model and accuracies
            vertical_max_accuracy_filepath = file
            vertical_best_model_filepath = file + model_filepath_extension
        # This block will only start from the second model    
        elif vertical_min_accuracy > df['val_accuracy'].max():
            vertical_min_accuracy = df['val_accuracy'].max()
            vertical_worst_model = label
            
    # Checking only horizontal models
    elif ind in horizontal_index:
        if not horizontal_max_accuracy:
            # Assuming the max accuracy of the first model is both the max and min of the entire model with
            # respect to a given symmetry
            horizontal_max_accuracy = df['val_accuracy'].max()
            horizontal_best_model = label
            # saving the file path of the model and accuracies
            horizontal_max_accuracy_filepath = file
            horizontal_best_model_filepath = file + model_filepath_extension
            # capturing the lowest out of the highest accuracies of our models
            horizontal_min_accuracy = df['val_accuracy'].max()
            horizontal_worst_model = label
        # This block will only start from the second model    
        elif horizontal_max_accuracy < df['val_accuracy'].max():
            horizontal_max_accuracy = df['val_accuracy'].max()
            horizontal_best_model = label
            # saving the file path of the model and accuracies
            horizontal_max_accuracy_filepath = file
            horizontal_best_model_filepath = file + model_filepath_extension
        # This block will only start from the second model    
        elif horizontal_min_accuracy > df['val_accuracy'].max():
            horizontal_min_accuracy = df['val_accuracy'].max()
            horizontal_worst_model = label
            
# printing the models
print(f" The best diagonal model is: {diagonal_best_model} with accuracy {diagonal_max_accuracy}" )
print(f" The best diagonal model filepath is: {diagonal_best_model_filepath}")
print(f" The best diagonal model accuracy filepath is: {diagonal_max_accuracy_filepath}")
print(f" The worst diagonal model is: {diagonal_worst_model} with accuracy {diagonal_min_accuracy}" )

print("#"*70)
print(f" The best vertical model is: {vertical_best_model} with accuracy {vertical_max_accuracy}" )
print(f" The best vertical model filepath is: {diagonal_best_model_filepath}")
print(f" The best vertical model accuracy filepath is: {vertical_max_accuracy_filepath}")
print(f" The worst vertical model is: {vertical_worst_model} with accuracy {vertical_min_accuracy}" )
print("#"*70)
print(f" The best horizontal model is: {horizontal_best_model} with accuracy {horizontal_max_accuracy}" )
print(f" The best horizontal model filepath is: {horizontal_best_model_filepath}")
print(f" The best horizontal model accuracy filepath is: {horizontal_max_accuracy_filepath}")
print(f" The worst horizontal model is: {horizontal_worst_model} with accuracy {horizontal_min_accuracy}" )
# Out:
#  The best diagonal model is: 0321 with accuracy 0.9734607338905334
#  The best diagonal model filepath is: _OA_results_PneumoniaMNIST_train_with_val_64/run_4FC/15/0321model.keras
#  The best diagonal model accuracy filepath is: _OA_results_PneumoniaMNIST_train_with_val_64/run_4FC/15/0321
#  The worst diagonal model is: 0312 with accuracy 0.9702759981155396
# ######################################################################
#  The best vertical model is: 2301 with accuracy 0.9745222926139832
#  The best vertical model filepath is: _OA_results_PneumoniaMNIST_train_with_val_64/run_4FC/15/0321model.keras
#  The best vertical model accuracy filepath is: _OA_results_PneumoniaMNIST_train_with_val_64/run_4FC/15/2301
#  The worst vertical model is: 0123 with accuracy 0.9702759981155396
# ######################################################################
#  The best horizontal model is: 3102 with accuracy 0.9755838513374328
#  The best horizontal model filepath is: _OA_results_PneumoniaMNIST_train_with_val_64/run_4FC/15/3102model.keras
#  The best horizontal model accuracy filepath is: _OA_results_PneumoniaMNIST_train_with_val_64/run_4FC/15/3102
#  The worst horizontal model is: 1320 with accuracy 0.9702759981155396

# %%
import pandas as pd

diagonal_val_accuracy = []
vertical_val_accuracy = []
horizontal_val_accuracy = []

for ind, variant  in enumerate(permutations):
    label = ''.join(map(str,variant))
    # file = train_layer.name + "/run" + run_subfolder +  "/" + label
    file = log_dir + label

    #read the csv file
    df = pd.read_csv(file)
    
    # the number of last validation accuracy
    tail_accuracy = 15
    diagonal_max_accuracy, vertical_max_accuracy, horizontal_max_accuracy = 0, 0, 0
    if ind in diagonal_index:
        diagonal_val_accuracy.append(df['val_accuracy'].tail(tail_accuracy).tolist())
        
    elif ind in vertical_index:
        vertical_val_accuracy.append(df['val_accuracy'].tail(tail_accuracy).tolist())
    
    elif ind in horizontal_index:
        horizontal_val_accuracy.append(df['val_accuracy'].tail(tail_accuracy).tolist())

# %%
# need to flatten the list to have all the data in a single list
diagonal_val_accuracy_flattened = [item for sublist in diagonal_val_accuracy for item in sublist]
vertical_val_accuracy_flattened = [item for sublist in vertical_val_accuracy for item in sublist]
horizontal_val_accuracy_flattened = [item for sublist in horizontal_val_accuracy for item in sublist]

# %%
# file = train_layer.name + "/run" + run_subfolder +  "/" + "NO-FILTER"
file = log_dir + "NO-FILTER"


df = pd.read_csv(file)
no_fitler_val_accuracy = df['val_accuracy'].tail(tail_accuracy).tolist()

# %% [markdown]
# ### No Filter model

# %%
nofilter_model_file_path = file + model_filepath_extension

# %%
import matplotlib.pyplot as plt

# Combine the data into a list of lists
data = [diagonal_val_accuracy_flattened, vertical_val_accuracy_flattened, horizontal_val_accuracy_flattened]

# Define the labels for the box plot
labels_plot = ['Diagonal', 'Vertical', 'Horizontal']

# Create the box plot
plt.boxplot(data, labels=labels_plot)

# Calculate the mean value of the no_filter list
mean_no_filter = np.mean(no_fitler_val_accuracy)
max_no_filter = np.max(no_fitler_val_accuracy)

# Add a horizontal line at the mean value of no_filter
plt.axhline(y= mean_no_filter, color='r', linestyle='--', label=f'Mean no Filter: {mean_no_filter:.4f}')
plt.axhline(y= max_no_filter, color='g', linestyle='--', label=f'Max no Filter: {max_no_filter:.4f}')

# plt.ylim(0.936,.97)
max_val_accuracy = np.max([diagonal_val_accuracy_flattened, vertical_val_accuracy_flattened, horizontal_val_accuracy_flattened])
plt.axhline(y= max_val_accuracy, color='b', linestyle='--', label=f'Max with Filter: {max_val_accuracy:.4f}')

# Add title and labels
number_of_hidden_layers = str(int(run_subfolder[1])-1)
plt.title(f'Box Plot of Val Accuracy with {number_of_hidden_layers} Hidden Layers')
plt.xlabel('Symmetries')
plt.ylabel('Val Accuracy')
# plt.legend(ncol=2, shadow=True)
# plt.legend(shadow=True)
# plt.legend()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# Save the figure with high quality
data_name = "PneumoniaMNIST"
figure_name = f"{log_dir}/{data_name}_{run_subfolder}_Val_Accuracy"
# plt.savefig(figure_name, dpi=300, bbox_inches='tight')
# Show the plot
plt.show()

# %% [markdown]
# ## Now let's evaluate our models

# %%
# Loading the models
diagonal_model = keras.saving.load_model(diagonal_best_model_filepath)
vertical_model = keras.saving.load_model(vertical_best_model_filepath)
horizontal_model = keras.saving.load_model(horizontal_best_model_filepath)
nofilter_model = keras.saving.load_model(nofilter_model_file_path)

# %%
# Evaluate the model on the test data using 
print("Evaluate on test data")
# Diagonal
diagonal_label = diagonal_max_accuracy_filepath[-4:]
diagonal_te_images =  test_layer.open(diagonal_label)
diagonal_results = diagonal_model.evaluate(diagonal_te_images, test_labels)
print("Diagonal test loss, test acc:", diagonal_results)
print("#"*70)
# Vertical
vertical_label = vertical_max_accuracy_filepath[-4:]
vertical_te_images =  test_layer.open(vertical_label)
vertical_results = vertical_model.evaluate(vertical_te_images, test_labels)
print("Vertical test loss, test acc:", vertical_results)
print("#"*70)
# Horizontal
horizontal_label = horizontal_max_accuracy_filepath[-4:]
horizontal_te_images =  test_layer.open(horizontal_label)
horizontal_results = horizontal_model.evaluate(horizontal_te_images, test_labels)
print("Horizontal test loss, test acc:", horizontal_results)
print("#"*70)
# No Filter
nofilter_te_images =  test_images
nofilter_te_results = nofilter_model.evaluate(nofilter_te_images, test_labels)
print("No Filter test loss, test acc:", nofilter_te_results)
print("#"*70)
# Out:
# Evaluate on test data
# 20/20 [==============================] - 0s 5ms/step - loss: 1.1761 - accuracy: 0.8590
# Diagonal test loss, test acc: [1.1761400699615479, 0.8589743375778198]
# ######################################################################
# 20/20 [==============================] - 0s 4ms/step - loss: 1.0496 - accuracy: 0.8558
# Vertical test loss, test acc: [1.049576759338379, 0.8557692170143127]
# ######################################################################
# 20/20 [==============================] - 0s 5ms/step - loss: 1.1951 - accuracy: 0.8574
# Horizontal test loss, test acc: [1.1950726509094238, 0.8573718070983887]
# ######################################################################
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4346 - accuracy: 0.8333
# No Filter test loss, test acc: [1.4346497058868408, 0.8333333134651184]
# ######################################################################

# %%
# data to build classification reports
Models_dict = {"diagonal" : {"label":diagonal_label, "model": diagonal_model, "test_images": diagonal_te_images,  "pred": ""},
               "vertical" : {"label":vertical_label, "model": vertical_model, "test_images": vertical_te_images, "pred": ""}, 
                "horizontal" : {"label":horizontal_label, "model": horizontal_model, "test_images": horizontal_te_images, "pred": ""},
            }

# %% [markdown]
#  ## Confusion Matrix

# %%
import seaborn as sns

# Function that creates a folder
def create_folder(folder_path):
   log_dir =  os.path.join(os.getcwd(), folder_path)
   os.makedirs(log_dir, exist_ok=True) 
   return log_dir

# creating a folder inside test_data folder to save the confusion matrices and classification reports 
# with name = number of Fully Connected FC layer used.
patience = 15
test_folder_path = test_layer.name  + "/" + run_subfolder +  "/"
# create_folder(test_folder_path)
test_folder_path += str(patience) +  "/"
# test_folder_path = test_layer.name + "/" + run_subfolder
create_folder(test_folder_path)
confusion_matrices_path = test_folder_path + "confusion_matrices"
create_folder(confusion_matrices_path)
# we
class_names = np.unique(test_labels)



def create_save_confusion_matrix(symmetry, Y_pred, label, test_labels=test_labels):
   """ Function that creates & saves as csv and png confusion matrix """
   try:
      # # Convert predictions classes to one hot vectors 
      # Y_pred_classes = np.argmax(Y_pred, axis=1) 
      # compute the confusion matrix
      confusion_mtx = tf.math.confusion_matrix(labels=test_labels,
                                                predictions=Y_pred
                                             )
      confusion_mtx_df = pd.DataFrame(confusion_mtx, index=class_names, columns=class_names)
      # file name to save the confusion matrix
      cm_file_name =  f"{confusion_matrices_path}/{symmetry}_{label}_confusion_matrix.csv"
      print
      # Save to a CSV file
      confusion_mtx_df.to_csv(cm_file_name)
      print(f"Confusion matrix saved to {cm_file_name}")
      print("#"*80)
      print(f"Confusion Matrix for {symmetry.capitalize()} Model")
      plt.figure(figsize=(10, 8))
      sns.heatmap(confusion_mtx, annot=True, fmt='g')
      # Save the figure with high quality
      # cm_file_name[:-4] taking off .csv extension to avoid errors
      plt.savefig(cm_file_name[:-4], dpi=300, bbox_inches='tight')
   
   except Exception as e:
      print(f"An error occurred while creating and saving the confusion_matrix: {e}")


# 
for symmetry, value in Models_dict.items():
   # Predict the values from the testing dataset
   value["pred"] = np.argmax(value["model"].predict(value["test_images"]), axis=1) 
   create_save_confusion_matrix(symmetry, Y_pred=value["pred"], label=value["label"], test_labels=test_labels)
# Out:
# 20/20 [==============================] - 0s 5ms/step
# Confusion matrix saved to _OA_results_PneumoniaMNIST_test_with_val_64/_4FC/15/confusion_matrices/diagonal_0321_confusion_matrix.csv
# ################################################################################
# Confusion Matrix for Diagonal Model
# 20/20 [==============================] - 0s 4ms/step
# Confusion matrix saved to _OA_results_PneumoniaMNIST_test_with_val_64/_4FC/15/confusion_matrices/vertical_2301_confusion_matrix.csv
# ################################################################################
# Confusion Matrix for Vertical Model
# 20/20 [==============================] - 0s 4ms/step
# Confusion matrix saved to _OA_results_PneumoniaMNIST_test_with_val_64/_4FC/15/confusion_matrices/horizontal_3102_confusion_matrix.csv
# ################################################################################
# Confusion Matrix for Horizontal Model

# %% [markdown]
# ## classification report

# %%
from sklearn.metrics import classification_report

# # creating a folder inside test_data folder to save the classification reports with name = number of Fully Connected FC layer used.
# test_folder_path = test_layer.name + "/" + run_subfolder
# create_folder(test_folder_path)
# creating a folder inside test_data folder to save the classification reports
folder_path = test_folder_path  + "classification_reports"
create_folder(folder_path)


def save_classification_report_image(df_report, symmetry, label, folder_path, class_names=class_names):
    """ Function to save each classification report as an image with symmetry name and configuration e.g. 0123"""
    # extension for the files
    classification_report_image_extension = "_classification_report.png"
    try:
        plt.figure(figsize=(10, len(class_names) + 2))
        sns.heatmap(df_report,
                    annot=True,
                    fmt=".2f",
                    cbar=True)
        
        plt.title(f"{symmetry.capitalize()} Classification Report Metrics -- {label}")
        # Move x-axis labels to the top
        plt.tick_params(axis='x', which='major', top=True, bottom=False, labeltop=True, labelbottom=False)
        plt.xticks(rotation=0, ha='center') # Adjust rotation as needed

        # Save classification report as image
        file_name = f"{folder_path}/{symmetry}_{label}_{classification_report_image_extension}"
        plt.tight_layout()
        plt.savefig(file_name, dpi=300, bbox_inches='tight')
        plt.show()
        print(f"Successfully classification report saved to {file_name}")
    except Exception as e:
        print(f"An error occurred while creating and saving the classification report: {e}")




def create_save_classification_report(Y_pred, symmetry, label, test_labels=test_labels, folder_path=folder_path):
   # extension for classification reports inside the above folder
   classification_report_file_extension = "_classification_report.csv"

   try:
      # building report
      report = classification_report(y_true=test_labels,
                                    y_pred=Y_pred,
                                    output_dict=True
                                    )
      df_report = pd.DataFrame(report).transpose()

      # Save the DataFrame to a CSV file
      file_name = f"{folder_path}/{symmetry}_{label}_{classification_report_file_extension}"
      df_report.to_csv(file_name)
      print(f"Classification report saved to {file_name}")
      # save classification report as image
      save_classification_report_image(df_report=df_report, symmetry=symmetry, label=label, folder_path=folder_path)
      # 
      print("#"*70)
      print("\n")

      print(f" Classification Report for {symmetry}")
      print("\n")
      print(report)
      print("#"*70)
      print("\n")
   except Exception as e:
        print(f"An error occurred while creating and saving the classification report: {e}")
         
         
         
for symmetry, value in Models_dict.items():
    create_save_classification_report(symmetry=symmetry, label=value["label"], Y_pred=value["pred"])
    
print("#"*70)
print("End!")
# Out:
# Classification report saved to _OA_results_PneumoniaMNIST_test_with_val_64/_4FC/15/classification_reports/diagonal_0321__classification_report.csv
# Successfully classification report saved to _OA_results_PneumoniaMNIST_test_with_val_64/_4FC/15/classification_reports/diagonal_0321__classification_report.png
# ######################################################################
#
#
#  Classification Report for diagonal
#
#
# {'0': {'precision': 0.9802631578947368, 'recall': 0.6367521367521367, 'f1-score': 0.772020725388601, 'support': 234.0}, '1': {'precision': 0.8199152542372882, 'recall': 0.9923076923076923, 'f1-score': 0.8979118329466357, 'support': 390.0}, 'accuracy': 0.8589743589743589, 'macro avg': {'precision': 0.9000892060660125, 'recall': 0.8145299145299145, 'f1-score': 0.8349662791676183, 'support': 624.0}, 'weighted avg': {'precision': 0.8800457181088314, 'recall': 0.8589743589743589, 'f1-score': 0.8507026676123727, 'support': 624.0}}
# ######################################################################
#
#
# Classification report saved to _OA_results_PneumoniaMNIST_test_with_val_64/_4FC/15/classification_reports/vertical_2301__classification_report.csv
# Successfully classification report saved to _OA_results_PneumoniaMNIST_test_with_val_64/_4FC/15/classification_reports/vertical_2301__classification_report.png
# ######################################################################
#
#
#  Classification Report for vertical
#
#
# {'0': {'precision': 0.9736842105263158, 'recall': 0.6324786324786325, 'f1-score': 0.7668393782383419, 'support': 234.0}, '1': {'precision': 0.8177966101694916, 'recall': 0.9897435897435898, 'f1-score': 0.8955916473317865, 'support': 390.0}, 'accuracy': 0.8557692307692307, 'macro avg': {'precision': 0.8957404103479036, 'recall': 0.8111111111111111, 'f1-score': 0.8312155127850642, 'support': 624.0}, 'weighted avg': {'precision': 0.8762544603033007, 'recall': 0.8557692307692307, 'f1-score': 0.8473095464217448, 'support': 624.0}}
# ######################################################################
#
#
# Classification report saved to _OA_results_PneumoniaMNIST_test_with_val_64/_4FC/15/classification_reports/horizontal_3102__classification_report.csv
# Successfully classification report saved to _OA_results_PneumoniaMNIST_test_with_val_64/_4FC/15/classification_reports/horizontal_3102__classification_report.png
# ######################################################################
#
#
#  Classification Report for horizontal
#
#
# {'0': {'precision': 0.967741935483871, 'recall': 0.6410256410256411, 'f1-score': 0.7712082262210797, 'support': 234.0}, '1': {'precision': 0.8208955223880597, 'recall': 0.9871794871794872, 'f1-score': 0.8963911525029103, 'support': 390.0}, 'accuracy': 0.8573717948717948, 'macro avg': {'precision': 0.8943187289359653, 'recall': 0.8141025641025641, 'f1-score': 0.833799689361995, 'support': 624.0}, 'weighted avg': {'precision': 0.875962927298989, 'recall': 0.8573717948717948, 'f1-score': 0.8494475551472238, 'support': 624.0}}
# ######################################################################
#
#
# ######################################################################
# End!
